# %%
# Import Libraries
import re
import random
import numpy as np
import pandas as pd
from collections import OrderedDict, Counter
from sklearn import metrics, svm
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, roc_auc_score

# %% [markdown]
# # Extract Transactions

# %%
DREHEM_IDS = 'clean_drehem_ids.txt'
QUEEN_ARCHIVES_IDS = 'queen_archives_pids.txt'
QUEEN_OIP_IDS = 'oip_pids.txt'

labels = {}
labels["domesticated_animal"] = ["[ox]", "[cow]", "[sheep]", "[goat]", "[lamb]", "[~sheep]", "[equid]"] # account for plural
labels["wild_animal"] = ["[bear]", "[gazelle]", "[mountain]"] # account for "mountain animal" and plural
labels["dead_animal"] = ["[die]"] # find "die" before finding domesticated or wild
labels["leather_object"] = ["[boots]", "[sandals]"]
labels["precious_object"] = ["[copper]", "[bronze]", "[silver]", "[gold]"]
labels["wool"] = ["[wool]", "[~wool]"]
labels["queens_archive"] = []

class Transaction:
    def __init__(self, p_id):
        self.p_id = p_id
        self.lines = list()
        self.lemmas = OrderedDict() # Maps Sumerian text to its lemmatized form
        self.label = {} # Maps label to List of defining text
        self.sumerian_lemmas = []
        
    # Create mapping of Sumerian text to its lemmatized form
    def get_lemmatization(self):
        first_line = 0
        for i, s in enumerate(self.lines):
            if s.startswith("1."):
                  first_line = i
                  break
        while first_line < len(self.lines)-1:
            if self.lines[first_line] and self.lines[first_line][0].isnumeric() and self.lines[first_line+1].startswith("#lem"):
                self.lemmas[self.lines[first_line]] = self.lines[first_line+1]
                first_line += 2
            else:
                first_line += 1
                
        return self.lemmas
    
    # Get Sumerian lemmatized text only
    def get_sumerian_lemma(self):
        #print(item.sumerian_lemmas)
        item.sumerian_lemmas = []
        for k, v in self.lemmas.items():
            #print(v)
            result = re.findall(" .*\[[a-z]+\]", v)
            if len(result) == 0:
                continue
            lemmas = [s[:s.index("[")].strip() for s in result[0].split(";") if re.search("\[", s)]
            self.sumerian_lemmas += lemmas
        return self.sumerian_lemmas
    
    # Find the most likely label
    def set_label(self):
        def find_label(label, line, found) :
            for val in labels[label]:
                if val in line: 
                    if label in found.keys():
                        found[label].append(line)
                    else:
                        found[label] = [line]
                    return True
        found = {}
        for line in self.lines:
            label = None
            if line == '@object seal':
                found['seal'] = [line]
            # Priority 1: Check for dead animal
            if find_label("dead_animal", line, found): continue
            # Priority 2: Check for wild animal
            if find_label("wild_animal", line, found): continue
            # Priority 3: Check for domesticated animal
            if find_label("domesticated_animal", line, found): continue
            # Priority 4: Check leather, wool, or precious object
            if find_label("leather_object", line, found): continue
            if find_label("precious_object", line, found): continue
            if find_label("wool", line, found): break
        # If none match, label as "Unknown"
        if len(found.keys()) == 0:
            found["Unknown"] = [self.lines]
        self.label = found
        return found
            
    
# Read ORACC files to find transactions with p_ids in `ids`
def read_files(subdir, ids, reverse=False):
    transactions = list()
    for i in range(1, 16):
        file_name = ""
        if i < 10:
            file_name += subdir + "p00" + str(i) + ".atf"
        else:
            file_name += subdir + "p0" + str(i) + ".atf"
        
        curr_transaction = None
        
        with open(file_name, encoding="utf8") as file:
            print("Opening:", file_name)
            for line in file:
                line = line.strip()
                if line.startswith('&P'):
                    p_id = line.split()[0][1:]
                    if (not reverse and p_id in ids):
                        ids.remove(p_id)
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    elif (reverse and p_id not in ids and len(transactions) <= 200):
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    else:
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        curr_transaction = None
                else:
                    if curr_transaction:
                        curr_transaction.lines.append(line)
        
        if curr_transaction:
            transactions.append(curr_transaction)
    
    #print(ids)
    #assert len(ids) == 0
    print("Number of transactions:", len(transactions))
    return transactions

# Return the IDs of docs to annotate
def get_drehem_ids(file):
    lst = list()
    with open(file, encoding="utf8") as f:
        for line in f:
            if line.startswith("P"):
                line = line.strip()
                lst.append(line)
    return lst

# %%
list_drehem_ids = get_drehem_ids(DREHEM_IDS)
list_queen_ids = get_drehem_ids(QUEEN_ARCHIVES_IDS)
list_oip_queen_ids = get_drehem_ids(QUEEN_OIP_IDS)
complete_list = list_drehem_ids + list_queen_ids + list_oip_queen_ids

non_queen_list = read_files("raw-data/", list_drehem_ids)
queen_training_list = read_files("raw-data/", list_queen_ids)
queen_test_set = read_files("raw-data/", list_oip_queen_ids)
# Out:
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 429
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 275
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 120

# %%
# Populate training and data set

for item in queen_training_list:
    item.get_lemmatization()
    item.set_label()
    
for item in non_queen_list:
    item.get_lemmatization()
    item.set_label()
    
for item in queen_test_set:
    item.get_lemmatization()
    item.set_label()
    
            
training_data = []
training_labels = []
test_data = []
test_labels = []

for item in queen_training_list[:175]:
    training_data.append(" ".join(item.get_sumerian_lemma()))
    training_labels.append("queen")
    
for i in range(len(non_queen_list)):
    if i < 350:
        training_data.append(" ".join(non_queen_list[i].get_sumerian_lemma()))
        training_labels.append("not queen")
    else:
        test_data.append(" ".join(non_queen_list[i].get_sumerian_lemma()))
        test_labels.append("not queen")
        
for item in queen_test_set:
    test_data.append(" ".join(item.get_sumerian_lemma()))
    test_labels.append("queen")
    
for item in queen_training_list[175:]:
    test_data.append(" ".join(item.get_sumerian_lemma()))
    test_labels.append("queen")

print(len(training_data))
print(len(training_labels))
print(len(test_data))
print(len(test_labels))

all_data = training_data + test_data
all_labels = training_labels + test_labels

queen_data = [x for x, y in zip(all_data, all_labels) if y == "queen"]
queen_labels = ["queen"] * len(queen_data)
non_queen_data = [x for x, y in zip(all_data, all_labels) if y == "not queen"]
non_queen_labels = ["not queen"] * len(non_queen_data)
# Out:
# 525
# 525
# 299
# 299

# %% [markdown]
# # Multinomial Naive Bayes Classifer
# First pass at classifying Queen's Archives transactions.
#
# We will use the following measures to determine how well our classifier does.
#
# <b>Accuracy</b>:
# (# true positives + # true negatives) / total #<br><br>
# <b>Recall</b>:
# true positives / (true positives + false positives) <br>
# High recall means that an algorithm returned most of the relevant results <br><br>
# <b>Precision</b>:
# true positives / (true positives + false negatives) <br>
# High precision means that an algorithm returned substantially more relevant results than irrelevant ones

# %%
# Bag of Words model (Unigram)
count_vect = CountVectorizer(analyzer = "word",
                                          tokenizer = None,    
                                          preprocessor = None,
                                          ngram_range = (1, 1),
                                          binary = False,
                                          strip_accents='unicode',
                                          token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = count_vect.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# Classifier
bag_of_words_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = count_vect.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = bag_of_words_classifier.predict(X_new_tfidf)
    
print("Accuracy: ", np.mean(predicted == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, predicted, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, predicted, ["queen", "not queen"], average="macro")))
# Out:
# (525, 368)
# Accuracy:  0.8595317725752508
# Recall:  0.9004890678941312
# Precision:  0.824953314659197

# %%
# Bigram Model
bigram_vectorizer = CountVectorizer(analyzer = "word",
                                    tokenizer = None,
                                    preprocessor = None,
                                    ngram_range = (2, 2),
                                    strip_accents='unicode',
                                    token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = bigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# Classifier
bigram_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = bigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

bigram_multinomial_nb_prediction = bigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(bigram_multinomial_nb_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, bigram_multinomial_nb_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, bigram_multinomial_nb_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (525, 2476)
# Accuracy:  0.8996655518394648
# Recall:  0.9237054085155351
# Precision:  0.861512027491409

# %%
# Trigram Model
trigram_vectorizer = CountVectorizer(analyzer = "word",
                                    tokenizer = None,
                                    preprocessor = None,
                                    ngram_range = (3, 3),
                                    strip_accents='unicode',
                                    token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = trigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# Classifier
trigram_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = trigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

trigram_prediction = trigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(trigram_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, trigram_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, trigram_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (525, 4711)
# Accuracy:  0.8929765886287625
# Recall:  0.9151035673187572
# Precision:  0.8541728031418754

# %%
# Unigram and Bigram Model
uni_and_bigram_vectorizer = CountVectorizer(analyzer = "word",
                                            tokenizer = None,
                                            preprocessor = None,
                                            binary = False,
                                            ngram_range = (1,2),
                                            strip_accents='unicode',
                                            token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = uni_and_bigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# Classifier
uni_and_bigram_classifier = MultinomialNB(0.5).fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = uni_and_bigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

uni_and_bigram_prediction = uni_and_bigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(uni_and_bigram_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, uni_and_bigram_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, uni_and_bigram_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (525, 2844)
# Accuracy:  0.9163879598662207
# Recall:  0.9350690448791714
# Precision:  0.8799748743718593

# %% [markdown]
# From above, we can see the unigram-bigram model does the best. This is the one we will use later on.

# %% [markdown]
# # Predict

# %% [markdown]
# We will now do a preliminary prediction using just the (unigram-bigram) Naive Bayes Classifier. All files will be read in to get a tentative result for the size of the Queen's Archive.

# %%
# Read all files to get all Drehem transactions
def read_files(subdir, ids, reverse=False):
    transactions = list()
    for i in range(1, 16):
        file_name = ""
        if i < 10:
            file_name += subdir + "p00" + str(i) + ".atf"
        else:
            file_name += subdir + "p0" + str(i) + ".atf"
        
        curr_transaction = None
        
        with open(file_name, encoding="utf8") as file:
            print("Opening:", file_name)
            for line in file:
                line = line.strip()
                if line.startswith('&P'):
                    p_id = line.split()[0][1:]
                    #print(p_id)
                    if (not reverse and p_id in ids):
                        ids.remove(p_id)
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    elif (reverse and p_id not in ids and len(transactions) <= 200):
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    else:
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        curr_transaction = None
                else:
                    if curr_transaction:
                        curr_transaction.lines.append(line)
        
        if curr_transaction:
            transactions.append(curr_transaction)
    
    print("Number of transactions:", len(transactions))
    return transactions

# Return the IDs of docs to annotate
def get_drehem_ids(file):
    lst = list()
    with open(file, encoding="utf8") as f:
        for line in f:
            line = line.strip()
            lst.append("P" + line)
    return lst

# %%
all_ids = get_drehem_ids("drehem_p_ids.txt")
all_transactions = read_files("raw-data/", all_ids)
# Out:
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 14594

# %%
data = []
mapping = {}
labs = []

for t in all_transactions:
    t.get_lemmatization()
    labs.append(t.set_label())
    lemma = " ".join(t.get_sumerian_lemma())
    data.append(lemma)
    if lemma in mapping:
        mapping[lemma].append(t)
    else:
        mapping[lemma] = [t]
        
# Predict
X_new_counts = uni_and_bigram_vectorizer.transform(data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

uni_and_bigram_prediction = uni_and_bigram_classifier.predict(X_new_tfidf)

# %%
# Small sample of results
for doc, category in zip(data[:30], uni_and_bigram_prediction[:30]):
    print('%r => %s' % (doc, category))
# Out:
# 'udu kišib ki lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'udu niga sila ga uš ud ki šu teŋ itud mu u hulu' => not queen
# 'sila sila mu.DU zabardab maškim u udu maš uš ekišibak ud lal ki itud mu us hulu' => not queen
# 'mašgal niga udu uš ud šag ki šu teŋ itud mu lugal' => not queen
# 'udu a sag udu niga mašgal niga udu sila ga kir ga uš ud ki šu teŋ itud mu lugal' => not queen
# 'udu niga sila niga udu sila ensik sila ensik sila mu.DU itud mu en maš pad ud' => not queen
# 'mašgal niga egia ensik ragaba maškim itud ud lal zal ki ŋiri dubsar itud mu en huŋ udu' => not queen
# 'amar mašda mašda amar amar mašda sila amar mašda maš sila ensik mu.DU dab itud gu mu us hulu ud' => not queen
# 'mašgal ki ensik dab itud mu huŋ udu' => not queen
# 'sila zabardab sila ensik sila ensik mu.DU dab itud akiti mu u mada ud hulu ud' => not queen
# 'mašgal niga lu maškim itud ud zal ki itud mu lugal hulu' => not queen
# 'gud ab mu.DU lugal ki bala zig ensik dab ziga itud mu en maš pad' => not queen
# 'lal udu udu u u sila gub sila gub šugid udu a gukkal lal maš gub uzud ašgar ki ensik ud mu.DU dab itud mu du' => not queen
# 'udu sadug šag udu uš mu sipad šu teŋ ki itud mu us hulu' => not queen
# 'udu sadug šag udu u maš uš mu urgir sipad urgir šu teŋ ki itud mu us hulu' => not queen
# 'udunita u kir ur itud uzud kir ur udunita mašgal itud akiti sadug u mu e du' => queen
# 'udu u mašgal u uš sadug urgir sipad urgir šu teŋ ugula ki ŋiri dubsar itud mu lugal dim udu' => not queen
# 'sila sila mu.DU sila sila mu.DU en sila mu.DU zabardab maškim gud niga u uš emuhaldim ud ziga itud mu en maš pad' => not queen
# 'udu mašgal udu mašgal šagia maškim šag mu.DU ud ki ŋiri dubsar itud mu du' => not queen
# 'šugid emuhaldim mu gardu sukkal maškim itud ud zal ki itud mu en huŋ' => not queen
# 'u uzud šugid emuhaldim mu gardu maškim šag ašag ud ki ŋiri dubsar itud mu en huŋ' => not queen
# 'durah munus sila sila sila sila sila ud mu.DU dab itud mu huŋ' => not queen
# 'sila ud ki dab itud mu huŋ' => not queen
# 'sila mu.DU zabardab maškim ud ki itud mu u mada ud hulu' => not queen
# 'mašda ekišibak mu.DU ud ki itud mu u mada ud hulu' => not queen
# 'mašgal babbar ud ki dab ŋiri itud mu huŋ udu' => not queen
# 'sila ga kir ga maš ga ašgar ga utuda ud ki itud mu lugal' => not queen
# 'udu niga udu aslum ud lal ki dab itud mu huŋ' => not queen
# 'udu niga sag us gukkal niga u niga udu uzud sila kir uš ud ki šu teŋ itud mu lugal' => not queen
# 'sila ga kir ga maš ga ašgar ga utuda ud šag dab itud mu lugal' => not queen

# %%
# Percentange of Queen transactions
print(len([i for i in uni_and_bigram_prediction if i == "queen"])/len(uni_and_bigram_prediction))
# Out:
# 0.05543373989310676

# %% [markdown]
# # SVM

# %% [markdown]
# Now we will try to improve our classification by using an SVM, or a Support Vector Machine. We'll use `GridSearchCV` to determine the best hyperparameters for our model.
#
# We will use the following hyperparameters:
#
# **Kernel:** A transformation function; takes in data and transforms it into different forms.
#
# The kernels we will use are linear and RBF (radial basis function).
# RBF kernels are useful when there is no prior knowledge about the data.
#
# **Gamma:** Influence of a single sample.
#
# A low `gamma` value means a single sample can have a very large influence on the classifier; a high `gamma` value means its influence is more limited.
#
# **C:** Regularization parameter - trades off between model simplicity and classification accuracy.
#
# A low `C` value means a very smooth decision surface (easy to explain); a high `C` value means high accuracy but possible overfitting.

# %% [markdown]
# ### Pre-classification Check

# %% [markdown]
# Ideally, we want to use all of our training data to train our model for the best accuracy. Because we won't be holding anything back for validation, we should make sure that this is appropriate first; given our data, the model should be able to generalize well to other data.
#
# The following section is very intensive and will take a long time to run (roughly 30 minutes for this dataset) but only needs to be run once. Here we do a k-fold cross-validation with 10 folds. For each of 10 iterations, 9 sections are used as training for a model and one section is held out for validation. For each section, we make sure to include the same proportion of queen and non-queen samples as with the overall data.
#
# After running this, visually inspect the results and make sure that the results for each fold are similar; that is, there is no section where results drop dramatically, as this would indicate that the data does not generalize well to other data

# %%
# Only run this section once

n1 = len(queen_data)
n2 = len(non_queen_data)
q_fold_size = [i * (n1 // 10) for i in range(10)] + [n1] 
nq_fold_size = [i * (n2 // 10) for i in range(10)] + [n2] 
all_pred = []
all_true_lab = []
acc = []
rec = []
prec = []

for i in range(10):
    print("Starting fold", i)
    q_start, q_end = q_fold_size[i], q_fold_size[i + 1]
    nq_start, nq_end = nq_fold_size[i], nq_fold_size[i + 1]
    test_data = queen_data[q_start:q_end] + non_queen_data[nq_start:nq_end]
    test_labels = queen_labels[q_start:q_end] + non_queen_labels[nq_start:nq_end]
    training_data = queen_data[:q_start] + queen_data[q_end:] + non_queen_data[:nq_start] + non_queen_data[nq_end:]
    training_labels = queen_labels[:q_start] + queen_labels[q_end:] + non_queen_labels[:nq_start] + non_queen_labels[nq_end:]

    uni_bi_vect = CountVectorizer(analyzer = "word",
                                  ngram_range = (1,2),
                                  token_pattern='(?u)\\b\\w+\\b')

    # Train
    X_train_counts = uni_bi_vect.fit_transform(training_data)

    # Get TF-IDF
    tfidf_transformer = TfidfTransformer()
    X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

    # Classifier
    params = [{'kernel': ['rbf', 'linear'],
              'gamma': [1e-4, 1e-3, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 100],
              'C': [1, 5, 10, 50]}]
    uni_bi_clf = GridSearchCV(svm.SVC(decision_function_shape='ovr'), params)
    uni_bi_clf.fit(X_train_tfidf, training_labels)
    print("Best parameters found:")
    print(uni_bi_clf.best_params_)

    # Predict
    X_new_counts = uni_bi_vect.transform(test_data)
    X_new_tfidf = tfidf_transformer.transform(X_new_counts)
    all_pred.extend(uni_bi_clf.predict(X_new_tfidf))
    all_true_lab.extend(test_labels)
    
    uni_bi_pred = uni_bi_clf.predict(X_new_tfidf)

    acc.append(np.mean(uni_bi_pred == test_labels))
    rec.append(metrics.recall_score(test_labels, uni_bi_pred, ["queen", "not queen"], average="macro"))
    prec.append(metrics.precision_score(test_labels, uni_bi_pred, ["queen", "not queen"], average="macro"))

print("Total Accuracy: ", sum([1 if all_pred[i] == all_true_lab[i] else 0 for i in range(len(all_pred))])/len(all_pred))
print("Average Accuracy: ", sum(acc) / len(acc))
print("Total Recall: ", str(metrics.recall_score(all_true_lab, all_pred, ["queen", "not queen"], average="macro")))
print("Average Recall: ", sum(rec) / len(rec))
print("Total Precision: ", str(metrics.precision_score(all_true_lab, all_pred, ["queen", "not queen"], average="macro")))
print("Average Precision: ", sum(prec) / len(prec))

# %% [markdown]
# Once the generalizability of the data is verified, we will use all of our pre-labeled data to train the model.

# %%
uni_bi_vect = CountVectorizer(analyzer = "word",
                                  ngram_range = (1,2),
                                  token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = uni_bi_vect.fit_transform(all_data) 

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# Classifier
params = [{'kernel': ['rbf', 'linear'],
          'gamma': [1e-4, 1e-3, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 100],
          'C': [1, 5, 10, 50]}]
uni_bi_clf = GridSearchCV(svm.SVC(decision_function_shape='ovr'), params)
uni_bi_clf.fit(X_train_tfidf, all_labels)
print("Best parameters found:")
print(uni_bi_clf.best_params_)

X_all_counts = uni_bi_vect.transform(data) 
X_all_tfidf = tfidf_transformer.transform(X_all_counts)
uni_bi_pred_v2 = uni_bi_clf.predict(X_all_tfidf)
print("Percentage Queens' Texts Predicted")
print(len([i for i in uni_bi_pred_v2 if i == 'queen'])/len(uni_bi_pred_v2))
# Out:
# Best parameters found:
# {'C': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Percentage Queens' Texts Predicted
# 0.06838426750719474

# %%
queen_data = [x for x, y in zip(data, uni_bi_pred_v2) if y == "queen"]
non_queens = [x for x, y in zip(data, uni_bi_pred_v2) if y == "not queen"]
non_queen_labs = [x for x, y in zip(labs, uni_bi_pred_v2) if y == "not queen"]
print(len(non_queens))
# Out:
# 13596

# %% [markdown]
# ## Separating into Archives

# %% [markdown]
# Now that we have our classifier, we'll separate the data into archives. We'll also do an inspection of the text that was labeled as "Unknown" to see if there are more labels we can use to classify.

# %%
dead_animal_archive = []
domesticated_animal_archive = []
wild_animal_archive = []
leather_object_archive = []
precious_object_archive = []
wool_archive = []
seal_archive = []
Unknown_archive = []
Unknown_labs = []

for x, y in zip(non_queens, non_queen_labs):
    if "seal" in y.keys():
        seal_archive.append(x)
    else:
        lab = max(y, key = lambda x: len(y[x]))
        if lab == "Unknown":
            Unknown_labs.append(list(y.values()))
        if "animal" in lab and "dead_animal" in y.keys():
            dead_animal_archive.append(x)
        else:
            exec(lab + "_archive.append(x)")
      
print("Dead Animals archive size:", len(dead_animal_archive))
print("Domesticated Animals archive size:", len(domesticated_animal_archive))
print("Leather Objects archive size:", len(leather_object_archive))
print("Precious Objects archive size:", len(precious_object_archive))
print("Wild Animals archive size:", len(wild_animal_archive))
print("Wool archive size:", len(wool_archive))
print("Seal archive size:", len(seal_archive))
print("Unknown archive size:", len(Unknown_archive))
# Out:
# {'domesticated_animal': ['#lem: n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]', '#lem: n; sila[lamb]; ga[milk]'], 'dead_animal': ['#lem: uš[die]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]', '#lem: n; sila[lamb]; FN', '#lem: n; u[ewe]; n; udu[sheep]; n; maš[goat]'], 'dead_animal': ['#lem: uš[die]; ekišibak[storeroom]']}
# {'domesticated_animal': ['#lem: n; mašgal[goat]; niga[fattened]; n; udu[sheep]'], 'dead_animal': ['#lem: uš[die]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; a[water]; u; sag[rare]', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; mašgal[goat]; niga[fattened]', '#lem: n; udu[sheep]', '#lem: n; sila[lamb]; ga[milk]', '#lem: n; kir[lamb]; ga[milk]'], 'dead_animal': ['#lem: uš[die]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]; niga[fattened]', '#lem: n; udu[sheep]; n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; PN', '#lem: mu[year]; en[priest]; DN; maš[goat]; pad[find]']}
# {'domesticated_animal': ['#lem: n; mašgal[goat]; niga[fattened]', '#lem: n; udu[sheep]']}
# {'wild_animal': ['#lem: n; amar[young]; mašda[gazelle]; DN', '#lem: n; mašda[gazelle]; n; amar[young]; u; u', '#lem: n; amar[young]; mašda[gazelle]', '#lem: n; amar[young]; mašda[gazelle]'], 'domesticated_animal': ['#lem: n; sila[lamb]; PN; FN', '#lem: n; maš[goat]; PN', '#lem: n; sila[lamb]; ensik[ruler]; GN']}
# {'domesticated_animal': ['#lem: n; mašgal[goat]', '#lem: n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]']}
# {'domesticated_animal': ['#lem: n; mašgal[goat]; niga[fattened]']}
# {'domesticated_animal': ['#lem: n; gud[ox]', '#lem: n; ab[cow]', '#lem: mu[year]; en[priest]; DN; maš[goat]; pad[find]']}
# {'domesticated_animal': ['#lem: n; lal[small]; n; udu[sheep]', '#lem: n; udu[sheep]; barsuga[~sheep]', '#lem: n; u[ewe]; barsuga[~sheep]', '#lem: n; sila[lamb]; gub[stand]', '#lem: n; sila[lamb]; gub[stand]; barsuga[~sheep]', '#lem: šugid[~animal]; udu[sheep]; a[water]; gukkal[sheep]', '#lem: n; n; lal[small]; n; maš[goat]; gub[stand]', '#lem: n; n; n; uzud[goat]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; sadug[offerings]; FN', '#lem: n; n; udu[sheep]'], 'dead_animal': ['#lem: uš[die]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; sadug[offerings]; FN', '#lem: n; n; udu[sheep]', '#lem: n; u[ewe]; n; maš[goat]'], 'dead_animal': ['#lem: uš[die]; mu[year]; urgir[dog]']}
# {'domesticated_animal': ['#lem: n; n; udu[sheep]; u[grass]', '#lem: n; mašgal[goat]; u[grass]', '#lem: n; udu[sheep]'], 'dead_animal': ['#lem: uš[die]; sadug[offerings]; urgir[dog]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; FN', '#lem: n; sila[lamb]; FN', '#lem: n; sila[lamb]; FN', '#lem: n; sila[lamb]; FN', '#lem: n; sila[lamb]; FN', '#lem: mu[year]; en[priest]; DN; maš[goat]; pad[find]'], 'dead_animal': ['#lem: n; gud[ox]; niga[fattened]; n; u[ewe]; uš[die]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; n; mašgal[goat]', '#lem: n; udu[sheep]; n; mašgal[goat]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) lulim-nita₂', '#lem: n; X', '2. šu-gid₂ e₂-muhaldim', '#lem: šugid[~animal]; emuhaldim[kitchen]', '3. mu gar₃-du-ne-še₃', '#lem: mu[year]; gardu[soldier]', '4. dingir-dan sukkal maškim', '#lem: PN; sukkal[secretary]; maškim[administrator]', '5. iti u₄ 1(u) 6(diš) ba-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '6. ki lu₂-dingir-ra-ta', '#lem: ki[place]; PN', '@reverse', '1. ba-zi', '#lem: PN', '$ 1 line blank', '2. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '3. mu en eridu{ki} ba-hun', '#lem: mu[year]; en[priest]; GN; huŋ[hire]', '@left', '1. 1(diš)', '#lem: n']]}
# {'domesticated_animal': ['#lem: n; uzud[goat]']}
# {'domesticated_animal': ['#lem: n; durah[goat]; munus[woman]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN']}
# {'domesticated_animal': ['#lem: n; sila[lamb]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; FN']}
# {'wild_animal': ['#lem: n; mašda[gazelle]']}
# {'domesticated_animal': ['#lem: n; mašgal[goat]; babbar[white]', '#lem: n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; ga[milk]', '#lem: n; kir[lamb]; ga[milk]', '#lem: n; maš[goat]; ga[milk]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]', '#lem: n; udu[sheep]; aslum[sheep]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sag[rare]; us[side]', '#lem: n; gukkal[sheep]; niga[fattened]', '#lem: n; udu[sheep]', '#lem: n; uzud[goat]', '#lem: n; sila[lamb]', '#lem: n; kir[lamb]'], 'dead_animal': ['#lem: uš[die]; ud[sun]; n; n']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; ga[milk]', '#lem: n; kir[lamb]; ga[milk]', '#lem: n; maš[goat]; ga[milk]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]', '#lem: n; sila[lamb]', '#lem: n; maš[goat]', '#lem: n; sila[lamb]; ga[milk]', '#lem: n; maš[goat]; ga[milk]'], 'dead_animal': ['#lem: uš[die]']}
# {'domesticated_animal': ['#lem: n; ab[cow]', '#lem: n; udu[sheep]', '#lem: n; mašgal[goat]', '#lem: n; uzud[goat]', '#lem: n; sila[lamb]; ga[milk]', '#lem: n; gud[ox]; n; udu[sheep]'], 'dead_animal': ['#lem: uš[die]; ud[sun]; n']}
# {'domesticated_animal': ['#lem: n; n; gud[ox]; niga[fattened]', '#lem: n; n; gud[ox]']}
# {'domesticated_animal': ['#lem: gud[ox]; niŋgur[property]; PN', '#lem: gud[ox]; de[bring]', '#lem: mu[year]; en[priest]; TN; GN; maš[goat]; pad[find]']}
# {'leather_object': ['#lem: n; n; suhub[boots]; eban[pair]']}
# {'domesticated_animal': ['#lem: n; n; gud[ox]; n; n; ab[cow]', '#lem: n; gud[ox]; amar[young]; ga[milk]', '#lem: n; ab[cow]; n; sila[lamb]', '#lem: n; sila[lamb]; PN', '#lem: n; udu[sheep]; n; mašgal[goat]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; en[priest]; TN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN; muhaldim[cook]', '#lem: n; sila[lamb]; PN'], 'wild_animal': ['#lem: n; amar[young]; mašda[gazelle]; PN', '#lem: n; amar[young]; mašda[gazelle]; PN', '#lem: n; amar[young]; mašda[gazelle]; PN', '#lem: n; amar[young]; mašda[gazelle]; PN']}
# {'domesticated_animal': ['#lem: n; gud[ox]; n; n; udu[sheep]; šugid[~animal]', '#lem: n; gud[ox]; n; udu[sheep]; šugid[~animal]'], 'dead_animal': ['#lem: n; udu[sheep]; uš[die]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(ban₂) zi₃-gu', '#lem: n; zidgu[flour]', '2. sa₂-du₁₁-še₃', '#lem: sadug[offerings]', '3. ki lu₂-du₁₀-ga-mu#-ta#', '#lem: ki[place]; PN', '4. ba-zi', '#lem: PN', '@reverse', '1. iti ezem-an-na', '#lem: itud[moon]; MN', '2. mu e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; e[house]; TN; GN; du[build]', '@left', '1. [...]', '#lem: AN']]}
# {'domesticated_animal': ['#lem: n; gud[ox]; n; ab[cow]; emuhaldim[kitchen]', '#lem: n; gud[ox]; n; ab[cow]', '#lem: n; gud[ox]; n; ab[cow]', '#lem: n; gud[ox]; n; ab[cow]', '#lem: n; gud[ox]; n; ab[cow]', '#lem: n; gud[ox]; ud[sun]; n', '#lem: n; gud[ox]; n; ab[cow]', '#lem: n; ab[cow]; ud[sun]; n', '#lem: n; gud[ox]; n; ab[cow]', '#lem: n; gud[ox]; n; ab[cow]; ud[sun]; n', '#lem: n; gud[ox]; n; ab[cow]; ud[sun]; n; n', '#lem: n; gud[ox]; ud[sun]; n; n', '#lem: n; n; gud[ox]; n; ab[cow]', '#lem: n; gud[ox]; ud[sun]; n; n', '#lem: n; gud[ox]; n; ab[cow]', '#lem: n; gud[ox]; n; ab[cow]; ud[sun]; n; n', '#lem: n; gud[ox]; n; ab[cow]; ud[sun]; n; n', '#lem: n; gud[ox]; n; ab[cow]; ud[sun]; n; n', '#lem: n; gud[ox]; ud[sun]; n; n', '#lem: šuniŋin[total]; n; n; gud[ox]', '#lem: šuniŋin[total]; n; n; ab[cow]', '#lem: n; n; n; gud[ox]; ab[cow]; hi[mix]']}
# {'domesticated_animal': ['#lem: n; mašgal[goat]; u']}
# {'domesticated_animal': ['#lem: n; n; udu[sheep]; maš[goat]; hi[mix]']}
# {'domesticated_animal': ['#lem: n; n; udu[sheep]; niga[fattened]', '#lem: n; n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; FN', '#lem: n; sila[lamb]; FN', '#lem: n; sila[lamb]; FN']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; n; maš[goat]; n; sila[lamb]; FN', '#lem: n; udu[sheep]; n; maš[goat]; n; sila[lamb]; FN', '#lem: n; sila[lamb]; DN', '#lem: n; sila[lamb]; DN', '#lem: n; sila[lamb]; DN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; FN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; TN', '#lem: n; sila[lamb]; FN', '#lem: šuniŋin[total]; n; ab[cow]; mu[year]; u; n; n; udu[sheep]', '#lem: šuniŋin[total]; n; lal[small]; n; udu[sheep]; n; n; maš[goat]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; aslum[sheep]; niga[fattened]; n; us[side]', '#lem: n; udu[sheep]; niga[fattened]; n; us[side]', '#lem: n; sila[lamb]', '#lem: n; mašgal[goat]; niga[fattened]; n; us[side]', '#lem: n; sila[lamb]', '#lem: n; udu[sheep]; u[grass]', '#lem: n; sila[lamb]', '#lem: n; udu[sheep]; niga[fattened]; sag[rare]', '#lem: n; udu[sheep]; aslum[sheep]; niga[fattened]; sag[rare]', '#lem: n; udu[sheep]; aslum[sheep]; niga[fattened]; sag[rare]; us[side]', '#lem: n; udu[sheep]; aslum[sheep]; niga[fattened]; n; us[side]', '#lem: n; n; n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; kir[lamb]; gub[stand]', '#lem: n; udu[sheep]; n; n; udu[sheep]; X', '#lem: n; mašgal[goat]; X', '#lem: n; uzud[goat]; X; n; mašgal[goat]; X', '#lem: n; n; udu[sheep]; n; mašgal[goat]', '#lem: n; n; mašgal[goat]; n; mašgal[goat]; X', '#lem: n; kir[lamb]; gub[stand]; n; n; udu[sheep]', '#lem: n; n; udu[sheep]; X', '#lem: n; uzud[goat]; X; n; lal[small]; n; mašgal[goat]; X', '#lem: n; udu[sheep]; ŋiri[foot]; PN', '#lem: n; n; mašgal[goat]; n; mašgal[goat]; X', '#lem: šuniŋin[total]; n; n; n; udu[sheep]; n; n; n; udu[sheep]; X', '#lem: šuniŋin[total]; n; kir[lamb]; gub[stand]; n; n; mašgal[goat]', '#lem: šuniŋin[total]; n; n; n; mašgal[goat]; X', '#lem: šuniŋin[total]; n; n; uzud[goat]; X']}
# {'domesticated_animal': ['#lem: n; gukkal[sheep]; ŋešdu[breeder]', '#lem: n; u[ewe]; gukkal[sheep]'], 'wild_animal': ['#lem: n; lal[small]; n; udu[sheep]; hursaŋ[mountain]', '#lem: n; u[ewe]; hursaŋ[mountain]']}
# {'domesticated_animal': ['#lem: n; gukkal[sheep]; n; gukkal[sheep]; ŋešdu[breeder]', '#lem: u; gukkal[sheep]; n; gukkal[sheep]', '#lem: AN; u; n; udu[sheep]', '#lem: n; sila[lamb]; niga[fattened]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; ensik[ruler]; GN', '#lem: n; sila[lamb]; PN; GN', '#lem: n; sila[lamb]; niga[fattened]; PN; šabra[administrator]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN; dubsar[scribe]', '#lem: n; sila[lamb]; PN', '#lem: n; udu[sheep]; aslum[sheep]; ŋešdu[breeder]', '#lem: n; gukkal[sheep]; PN; FN', '#lem: n; maš[goat]; u; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; šag[heart]']}
# {'domesticated_animal': ['#lem: u; n; udu[sheep]; niga[fattened]; sag[rare]; us[side]', '#lem: u; n; udu[sheep]; niga[fattened]; n; us[side]', '#lem: n; udu[sheep]; niga[fattened]; n; us[side]', '#lem: n; udu[sheep]; u[grass]']}
# {'domesticated_animal': ['#lem: n; n; gud[ox]', '#lem: n; n; n; lal[small]; n; udu[sheep]', '#lem: n; lal[small]; n; maš[goat]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]', '#lem: n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; ga[milk]'], 'dead_animal': ['#lem: uš[die]']}
# {'domesticated_animal': ['#lem: u; gud[ox]; niga[fattened]']}
# {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]', '#lem: n; amar[young]; gud[ox]', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; gukkal[sheep]; niga[fattened]', '#lem: n; sila[lamb]', '#lem: n; kir[lamb]; niga[fattened]', '#lem: n; mašgal[goat]; niga[fattened]', '#lem: n; uzud[goat]; niga[fattened]', '#lem: n; udu[sheep]', '#lem: n; mašgal[goat]', '#lem: n; sila[lamb]; barŋal[~sheep]'], 'dead_animal': ['#lem: uš[die]; ud[sun]; n; n']}
# {'dead_animal': ['#lem: uš[die]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]', '#lem: n; sila[lamb]; AN', '#lem: n; mašgal[goat]'], 'dead_animal': ['#lem: uš[die]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) 3(u) sa gi', '#lem: n; n; sa[roast]; gi[reed]', '2. 2(ban₂) še ad-nu-ha', '#lem: n; še[barley]; X', '3. nu-banda₃ nir-i₃-da-gal₂', '#lem: nubanda[overseer]; PN', '@reverse', '1. giri₃ ur-mes', '#lem: ŋiri[foot]; PN', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 4(geš₂) 2(u) 4(diš) sa gi', '#lem: n; n; n; sa[roast]; gi[reed]', '2. sa₂-du₁₁ ur-{d}ba-ba₆', '#lem: sadug[offerings]; PN', '3. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '@reverse', '1. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '2. mu us₂-sa bad₃ ba-du₃', '#lem: mu[year]; us[follow]; bad[wall]; du[build]', '@seal 1', '$seal illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '@reverse', '$ blank space', '# seal impression', '@seal 1', '$ illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) gu₂ gi', '#lem: n; gu[pulse]; gi[reed]', '2. [ṣe]-li#-{d}iškur', '#lem: X', '@reverse', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '2. ur-{geš}gigir ugula', '#lem: PN; ugula[overseer]', '@reverse', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) guruš', '#lem: n; ŋuruš[male]', '2. u₄ 1(geš₂) 3(u)-še₃', '#lem: ud[sun]; n; n', '3. ma₂-da-ga-aš ma₂ gid₂-da', '#lem: X; ma[ship]; gid[long]', '4. 1(diš) guruš nagar', '#lem: n; ŋuruš[male]; nagar[carpenter]', '5. u₄ 2(u) 5(diš) [...-še₃]', '#lem: ud[sun]; n; n; DN', '6. [...]', '#lem: AN', '@reverse', '1. ki lu₂-[...]', '#lem: ki[place]; PN', '2. kišib₃ lugal-[...]', '#lem: kišib[seal]; PN', '3. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(geš₂) 5(u) 5(diš) guruš u₄ 1(diš)-še₃', '#lem: n; n; n; ŋuruš[male]; ud[sun]; n', '2. ki ba-saga gu-za-la₂-ta', '#lem: ki[place]; X; guzala[official]', '3. lu₂-sa₆-i₃-zu', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(geš₂) 4(u) guruš u₄ 1(diš)-še₃', '#lem: n; n; ŋuruš[male]; ud[sun]; n', '2. ki-su₇ a-ša₃ muru₁₃? gub-ba', '#lem: kisur[locus]; ašag[field]; FN; gub[stand]', '3. ugula ur-e₂-nun', '#lem: ugula[overseer]; PN', '@reverse', '1. kišib₃ da-a-gi₄', '#lem: kišib[seal]; PN', '2. mu {d}amar-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 8(diš) guruš u₄ 1(diš)-še₃', '#lem: n; ŋuruš[male]; ud[sun]; n', '2. a-ša₃ {geš}ma-nu-ta', '#lem: ašag[field]; manu[wood]', '3. še zi-ga', '#lem: še[barley]; ziga[expenditure]', '4. giri₃ nigar{gar}-ki-du₁₀', '#lem: ŋiri[foot]; PN', '@reverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. mu us₂-sa an-ša-an{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) guruš dub-sar', '#lem: n; ŋuruš[male]; dubsar[scribe]', '2. u₄ 4(u) 5(diš)-še₃', '#lem: ud[sun]; n; n', '3. uri₅{ki}-ma gub-ba', '#lem: GN; gub[stand]', '4. ugula a-a-gi-na', '#lem: ugula[overseer]; PN', '@reverse', '1. la-ni-mu i₃-dab₅', '#lem: PN; dab[seize]', '$ blank space', '# seal impression', '2. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(ban₂) še lugal', '#lem: n; še[barley]; lugal[king]', '2. [...] kas₄', '#lem: AN; kaš[runner]', '3. kišib₃ ur-{d}šara₂ ša₁₃-dub-ba', '#lem: kišib[seal]; PN; bisaŋdubak[archivist]', '@reverse', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) še gur 1(barig)-ta', '#lem: n; še[barley]; gur[unit]; n', '2. 3(aš) 1(barig) ziz₂ gur', '#lem: n; n; ziz[emmer]; gur[unit]', '3. ur-{d}a-šar₂', '#lem: PN', '@reverse', '1. ARAD₂-e₂-ninnu', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [x] 4(aš) ziz₂ gur si-sa₂-ta', '#lem: u; n; ziz[emmer]; gur[unit]; sisa[fair]', '2. 3(aš) gig gur', '#lem: n; kib[wheat]; gur[unit]', '3. ki lu₂-{d}er₃-ra-ta', '#lem: ki[place]; PN', '@reverse', '1. ha-lu₅-lu₅', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) 4(barig) še gur lugal', '#lem: n; n; še[barley]; gur[unit]; lugal[king]', '2. 2(aš) 2(barig) ziz₂ gur', '#lem: n; n; ziz[emmer]; gur[unit]', '3. kišib₃ ARAD₂', '#lem: kišib[seal]; arad[slave]', '4. ki ur-{d}suen-ta', '#lem: ki[place]; PN', '5. 1(barig) še lugal-gaba', '#lem: n; še[barley]; PN', '6. šu+nigin 4(aš) 2(barig) še gur', '#lem: šuniŋin[total]; n; n; še[barley]; gur[unit]', '@left', '1. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. ur-{d}[...]', '#lem: PN', '2. iti [...]', '#lem: itud[moon]; AN', '3. mu [...]{ki} ba-hul', '#lem: mu[year]; u; hulu[bad]', '']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(aš) 1(barig) 3(ban₂) 2(diš) sila₃ še gur', '#lem: n; n; n; n; sila[unit]; še[barley]; gur[unit]', '2. [mu]-kuₓ(DU) {d}šara₂', '#lem: mu.DU[delivery]; TN', '3. [...] a-pi₄-sal₄{ki}', '#lem: AN; GN', '4. [u₃ muš]-bi-an{ki}', '#lem: u[and]; GN', '5. [gu₂]-de₃-na-ta', '#lem: GN', '$ rest broken', '@reverse', '$ blank space', '1. mu [...]{ki} ba-hul', '#lem: mu[year]; u; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 2(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '2. sa₂-du₁₁ {d}šara₂', '#lem: sadug[offerings]; TN', '3. iti 1(u) 2(diš)-kam', '#lem: itud[moon]; n; n', '4. ki gu-du-du-ta', '#lem: ki[place]; PN', '5. kišib₃ ka-ku₃', '#lem: kišib[seal]; PN', '@reverse', '1. mu si-ma-num₂{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ beginning broken', '1ʾ. [...] da-[...]', '#lem: AN; PN', '2ʾ. 1(barig) 3(ban₂) er₁₁-ra-a', '#lem: n; n; PN', '3ʾ. 1(barig) 3(ban₂) a-ba-ki-ni', '#lem: n; n; PN', '4ʾ. 1(barig) 3(ban₂) lugal-ezem', '#lem: n; n; PN', '5ʾ. 1(barig) 3(ban₂) al-lu', '#lem: n; n; PN', '6ʾ. 1(barig) 3(ban₂) lu₂-{d}nin-šubur', '#lem: n; n; PN', '7ʾ. kikken₂ sa₂-du₁₁ [...]', '#lem: kinkin[miller]; sadug[offerings]; AN', '8ʾ. 1(barig) a-gu-gu# [...]', '#lem: n; PN; AN', '@reverse', '1. 1(barig) ur-{d}ma-mi', '#lem: n; PN', '2. 1(barig) ur-gu₂?-de₃?-na', '#lem: n; PN', '3. 2(barig) ur-{d}er₃-ra šu-i', '#lem: n; PN; šuʾi[barber]', '4. 1(barig) 3(ban₂) ša₃-ad-da ma₂-lah₅', '#lem: n; n; PN; malah[sailor]', '5. 5(ban₂) ur-saga i₃-du₈', '#lem: n; X; idu[doorkeeper]', '6. 1(barig) 1(ban₂) ad-da-mu nu-{geš}kiri₆', '#lem: n; n; PN; nukirik[gardener]', '7. 1(barig) 3(ban₂) pa₃-da nu-{geš}kiri₆', '#lem: n; n; PN; nukirik[gardener]', '8. 2(barig) lu₂-saga aga₃-us₂', '#lem: n; X; agaʾus[soldier]', '9. 3(ban₂) ur-{d}gilgamesₓ(|BIL₃.GA.MES|) [...]', '#lem: n; PN; AN', '10. 1(barig) 5(ban₂) 3(diš) lugal-a₂-zi-da [...]', '#lem: n; n; n; PN; AN', '$ rest broken']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ beginning broken', '1ʾ. [...] numun', '#lem: AN; numun[seed]', '2ʾ. ur-{d}geštin-an-ka', '#lem: PN', '3ʾ. [...] 1(u) 8(aš) x x še gur', '#lem: AN; n; n; u; u; še[barley]; gur[unit]', '4ʾ. ur-{d}nin-šubur nu-banda₃', '#lem: PN; nubanda[overseer]', '5ʾ. kišib₃ lu₂-eb-gal', '#lem: kišib[seal]; PN', '@reverse', '1. giri₃ lugal-mas-su', '#lem: ŋiri[foot]; PN', '2. 2(geš₂) 1(u) 4(aš) še gur', '#lem: n; n; n; še[barley]; gur[unit]', '3. ur-{geš}gigir nu-banda₃-gu₄', '#lem: PN; PN', '4. kišib₃ ur-{d}en-lil₂-la₂', '#lem: kišib[seal]; PN', '5. [...] ur-ge₆-par₄', '#lem: AN; PN', '$ rest broken']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. x x x še gur lugal', '#lem: u; u; u; še[barley]; gur[unit]; lugal[king]', '2. sag-nig₂-gur₁₁-ra-kam', '#lem: X', '3. ša₃-bi-ta', '#lem: šag[heart]', '4. 8(aš) gur kišib₃ ur-{d}suen', '#lem: n; gur[unit]; kišib[seal]; PN', '5. 2(aš) 1(barig) 5(ban₂) gur kišib₃ a-du-mu', '#lem: n; n; n; gur[unit]; kišib[seal]; PN', '@reverse', '$ broken']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [n] še gur lugal', '#lem: n; še[barley]; gur[unit]; lugal[king]', '2. maš nu-tuku', '#lem: maš[interest]; tuku[acquire]', '3. mu sag-{d}nanna-zu-še₃', '#lem: mu[year]; PN', '4. ki ur-e₁₁-e dam-gar₃-ta', '#lem: ki[place]; PN; damgar[merchant]', '# in irregular sequence', '@reverse', '1. ur-ba-gara₂', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 9(geš₂) 5(u) 4(barig) 2(ban₂) 6(diš) sila₃ še gur lugal', '#lem: n; n; n; n; n; sila[unit]; še[barley]; gur[unit]; lugal[king]', '3. a₂ ma₂ hun-ga₂', '#lem: a[arm]; ma[ship]; huŋ[hire]', '4. 2(u) 7(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '5. esir₂-a sa₁₀-a', '#lem: esir[bitumen]; X', '6. 1(u) 2(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '7. {geš}mi-ri₂-za', '#lem: miriza[plank]', '@reverse', '1. sa₁₀-a', '#lem: X', '2. ki ARAD₂-ta', '#lem: ki[place]; PN', '3. lugal-e-ba-<an>-sa₆', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '5. mu bad₃ ba-du₃', '#lem: mu[year]; bad[wall]; du[build]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 3(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '2. a₂ ma₂ hun-ga₂', '#lem: a[arm]; ma[ship]; huŋ[hire]', '3. i₇ e₃-ka', '#lem: id[river]; e[chaff]', '4. ki šabra bu₃-u₂-du-ta', '#lem: ki[place]; šabra[administrator]; PN', '@reverse', '1. lugal-e-ba-an-sa₆', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu ša-aš-ru{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(barig) 3(ban₂) dabin gu saga', '#lem: n; n; dabin[semolina]; gu[cord]; sag[rare]', '2. kišib₃ šeš-kal-la-ta zi-zi-dam', '#lem: kišib[seal]; PN; PN', '@reverse']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(aš) 1(barig) 4(ban₂) kaš du gur lugal', '#lem: n; n; n; kaš[beer]; du[go]; gur[unit]; lugal[king]', '2. zi-ga nin₉-tur-tur-ra', '#lem: ziga[expenditure]; PN', '3. ki si-NE-e-ta', '#lem: ki[place]; PN', '@reverse', '$ blank']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...] 6(aš) <kaš> saga sa₂-du₁₁', '#lem: AN; n; kaš[beer]; sag[rare]; sadug[offerings]', '2. 8(aš) la₂ 1(diš) sila₃ du diri', '#lem: n; lal[small]; n; sila[unit]; du[go]; dirig[exceed]', '3. 3(aš) saga elam-še₃', '#lem: n; sag[rare]; GN', '4. u₄ 1(u) 5(diš)-kam', '#lem: ud[sun]; n; n', '@reverse', '1. ki [...]-la-ta', '#lem: ki[place]; PN', '2. [...]-kal-la', '#lem: u', '3. [...]', '#lem: AN']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]-ka', '#lem: PN', '2. 6(aš)#? du ka e₂-sanga?', '#lem: n; du[go]; kag[mouth]; X', '3. o o o saga elam-še₃ du₁₁-ga', '#lem: u; u; u; sag[rare]; GN; duga[affliction]', '4. u₄ 1(u) la₂ 1(diš@t)-kam', '#lem: ud[sun]; n; lal[small]; n', '5. 4(aš) la₂ 4(diš) sila₃ du diri', '#lem: n; lal[small]; n; sila[unit]; du[go]; dirig[exceed]', '6. o o o saga du diri', '#lem: u; u; u; sag[rare]; du[go]; dirig[exceed]', '7. o o o saga elam-še₃ du₁₁?', '#lem: u; u; u; sag[rare]; GN; dug[pot]', '8. u₄ 1(u)-kam', '#lem: ud[sun]; n', '@reverse', '1. 1(aš) du sa₂-du₁₁', '#lem: n; du[go]; sadug[offerings]', '2. 2(aš) saga 7(aš) du diri', '#lem: n; sag[rare]; n; du[go]; dirig[exceed]', '3. u₄ 1(u) 1(diš)-kam', '#lem: ud[sun]; n; n', '4. u₄ 1(u) 2(diš) nu-tuku', '#lem: ud[sun]; n; n; tuku[acquire]', '5.  ki# {d}šara₂-a-zi-ta', '#lem: ki[place]; PN', '6. kišib₃ a-kal-la', '#lem: kišib[seal]; PN', '7. mu# lu-lu-bu-um{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '8. [...]', '#lem: AN', '@seal 1', '$(not given)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(ban₂) zi₃-gu [...] lugal', '#lem: n; zidgu[flour]; AN; lugal[king]', '2. 1(ban₂) zi₃ [...]', '#lem: n; zid[flour]; AN', '3. 1(barig) kaš dida saga', '#lem: n; kaš[beer]; dida[wort]; sag[rare]', '4. 1(barig) kaš dida du', '#lem: n; kaš[beer]; dida[wort]; du[go]', '5. 1(u) 5(diš) ku₆ kun-zi-[da]', '#lem: n; n; kud[fish]; kunzida[weir]', '@reverse', '1. 1(ban₂) [...]', '#lem: n; AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. ša₃-gal [...] maš [...] mu', '#lem: šaggal[food]; AN; maš[interest]; AN; mu[year]', '5. [...]-še₃', '#lem: DN', '6. [...]', '#lem: AN', '7. [...]', '#lem: AN']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(ban₂) 5(diš) sila₃ zu₂-lum', '#lem: n; n; sila[unit]; zulum[date]', '2. 1(barig) kaš dida du', '#lem: n; kaš[beer]; dida[wort]; du[go]', '3. 1(barig) kaš dida saga 1(ban₂) 5(diš) sila₃ <kaš du>', '#lem: n; kaš[beer]; dida[wort]; sag[rare]; n; n; sila[unit]; kaš[beer]; du[go]', '4. 1(barig) 3(ban₂) dabin', '#lem: n; n; dabin[semolina]', '5. 2(diš) sila₃ i₃-nun', '#lem: n; sila[unit]; inun[ghee]', '6. 2(diš) sila₃ ga-ar₃', '#lem: n; sila[unit]; gaʾar[cheese]', '7. x sila₃ i₃-nun du₁₀-ga', '#lem: u; sila[unit]; inun[ghee]; dug[good]', '8. x sila₃ i₃-gu du₁₀-ga', '#lem: u; sila[unit]; X; dug[good]', '9. [x] sila₃ bappir du₁₀-ga', '#lem: u; sila[unit]; bappir[~beer]; dug[good]', '$ rest broken', '@reverse', '$ beginning broken', '1ʾ. [x sila₃] eša', '#lem: u; sila[unit]; eša[flour]', '2ʾ. [...] zi₃ dub-dub', '#lem: AN; zid[flour]; dubdub[~flour]', '3ʾ. [...] 2(ban₂) zi₃-gu du', '#lem: AN; n; zidgu[flour]; du[go]', '4ʾ. 1(diš) sila₃ i₃-nun', '#lem: n; sila[unit]; inun[ghee]', '5ʾ. 1(diš) sila₃ ga-ar₃', '#lem: n; sila[unit]; gaʾar[cheese]', '6ʾ. 1(diš) sila₃ bappir du₁₀-ga', '#lem: n; sila[unit]; bappir[~beer]; dug[good]', '7ʾ. siskur₂ ša₃ e₂-a', '#lem: siškur[prayer]; šag[heart]; e[house]', '8ʾ. [...] 3(ban₂) zi₃ gur', '#lem: AN; n; zid[flour]; gur[unit]', '9ʾ. [...] 3(ban₂) eša', '#lem: AN; n; eša[flour]', '10ʾ. [...] 3(ban₂) zi₃ dub-dub', '#lem: AN; n; zid[flour]; dubdub[~flour]', '@left', '1. [mu {d}x]-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 8(diš) {geš}a-ra ma₂ 4(u) gur', '#lem: n; ara[~boat]; ma[ship]; n; gur[unit]', '2. še-ta sa₁₀-a', '#lem: še[barley]; X', '3. 3(u) 7(aš) gu₂ 4(u) 2(diš) ma-na mangaga', '#lem: n; n; gu[pulse]; n; n; mana[unit]; mangaga[fibers]', '4. 3(aš) 3(barig) 6(diš) sila₃ dabin gur', '#lem: n; n; n; sila[unit]; dabin[semolina]; gur[unit]', '5. 6(aš) 4(barig) 1(ban₂) kaš du gur', '#lem: n; n; n; kaš[beer]; du[go]; gur[unit]', '6. 2(ban₂) 8(diš) sila₃ eša', '#lem: n; n; sila[unit]; eša[flour]', '7. 1(ban₂) 5(diš) sila₃ zi₃-sig₁₅', '#lem: n; n; sila[unit]; zidsig[flour]', '@reverse', '1. ki ARAD₂-ta', '#lem: ki[place]; PN', '2. lu₂-sa₆-i₃-zu', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '$ blank space', '4. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(barig) 3(ban₂) 5(diš) sila₃ {u₂}gamun₂ babbar', '#lem: n; n; n; sila[unit]; X; babbar[white]', '2. 1(ban₂) {u₂}gamun₂ ge₆', '#lem: n; X; ŋi[night]', '3. 2(aš) 1(barig) še-lu₂ gur', '#lem: n; n; šelu[coriander]; gur[unit]', '4. 1(aš) gu₂-gal gur', '#lem: n; gugal[inspector]; gur[unit]', '5. 8(diš) sila₃ gu₂-tur', '#lem: n; sila[unit]; gutur[lentil?]', '6. ki lu₂-{d}šara₂ lu₂ tir-ta', '#lem: ki[place]; PN; lu[person]; tir[forest]', '@reverse', '$ blank space', '1. mu us₂-sa a-ra₂ 3(diš@t)-kam si-mu-ru-um{ki} ba-hul', '#lem: mu[year]; us[follow]; ara[times]; n; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) zu₂-lum gur lugal', '#lem: n; zulum[date]; gur[unit]; lugal[king]', '2. lu₂-bulug₃-ga₂', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '4. kišib₃ a-kal-la', '#lem: kišib[seal]; PN', '@reverse', '1. mu e₂ puzur₄-da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]', '$ blank space']]}
# {'domesticated_animal': ['#lem: n; udu[sheep]; n; n; maš[goat]', '#lem: n; udu[sheep]', '#lem: n; n; maš[goat]']}
# {'domesticated_animal': ['#lem: u; udunita[ram]; barsuga[~sheep]', '#lem: n; AN; sila[lamb]; barsuga[~sheep]']}
# {'dead_animal': ['#lem: n; udunita[ram]; uš[die]; barŋal[~sheep]']}
# {'domesticated_animal': ['#lem: n; šu[hand]; gud[ox]', '#lem: n; anše[equid]', '#lem: deg[collect]; gud[ox]; X', '#lem: ŋiri[foot]; PN; unud[cowherd]; u[and]; PN; sipad[shepherd]; anše[equid]']}
# {'domesticated_animal': ['#lem: n; n; gud[ox]; niga[fattened]', '#lem: n; gud[ox]; niga[fattened]', '#lem: n; gud[ox]; niga[fattened]']}
# {'domesticated_animal': ['#lem: n; ab[cow]; ga[milk]', '#lem: n; gud[ox]; ga[milk]', '#lem: n; n; udu[sheep]; barŋal[~sheep]', '#lem: n; sila[lamb]; barŋal[~sheep]', '#lem: n; n; maš[goat]', '#lem: n; udu[sheep]; barŋal[~sheep]'], 'wild_animal': ['#lem: mu[year]; mašda[gazelle]; šeŋbar[animal]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; barŋal[~sheep]', '#lem: n; u[ewe]; barsuga[~sheep]', '#lem: n; u; barsuga[~sheep]', '#lem: n; AN; barsuga[~sheep]', '#lem: n; uzud[goat]', '#lem: n; mašgal[goat]', '#lem: n; maš[goat]']}
# {'domesticated_animal': ['#lem: n; n; maš[goat]', '#lem: maš[goat]; magur[barge]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; barŋal[~sheep]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@object tag', '@obverse', '1. pisan-dub-ba', '#lem: bisaŋdubak[archivist]', '2. sag-nig₂-gur₁₁-ra', '#lem: X', '3. ša₃-bi su-ga', '#lem: šag[heart]; sug[replace]', '4. kas₄ šuš₃', '#lem: kaš[runner]; kuš[official]', '5. i₃-gal₂', '#lem: ŋal[be]', '@reverse', '$blank space', '']]}
# {'domesticated_animal': ['#lem: PN; sipad[shepherd]; udu[sheep]; ŋi[night]']}
# {'domesticated_animal': ['#lem: ab[cow]; tur[stall]', '#lem: u[and]; gudapin[ox]']}
# {'domesticated_animal': ['#lem: ab[cow]; tur[stall]', '#lem: u[and]; gudapin[ox]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) 2/3(diš) ma-na 8(diš) gin₂ igi 4(diš)-gal₂ ku₃', '#lem: n; šanabi[two-thirds]; mana[unit]; n; giŋ[unit]; igi[face]; n; kug[metal]', '2. ki da-da-ga-ta', '#lem: ki[place]; PN', '3. ur-{d}dumu-zi-da', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '$ broken']]}
# {'precious_object': ['#lem: n; mana[unit]; n; n; giŋ[unit]; lal[small]; n; še[barley]; kugbabbar[silver]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. igi 3(diš)-gal₂ 5(diš) še ku₃', '#lem: igi[face]; n; n; še[barley]; kug[metal]', '2. ki {d}šara₂-za-me-ta', '#lem: ki[place]; PN', '3. da-da-ga', '#lem: PN', '@reverse', '1. mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
# {'precious_object': ['#lem: n; mana[unit]; n; giŋ[unit]; kugbabbar[silver]'], 'domesticated_animal': ['#lem: laʾu[arrears]; sug[replace]; udu[sheep]']}
# {'precious_object': ['#lem: n; mana[unit]; kugbabbar[silver]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) gin₂ ku₃', '#lem: n; giŋ[unit]; kug[metal]', '2. la₂-ia₃ su-ga', '#lem: laʾu[arrears]; sug[replace]', '3. ki ur-{d}en-ki lunga-ta', '#lem: ki[place]; PN; lungak[brewer]', '@reverse', '1. da-da-ga', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš@t)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
# {'precious_object': ['#lem: n; n; giŋ[unit]; n; n; n; še[barley]; kugbabbar[silver]']}
# {'precious_object': ['#lem: n; giŋ[unit]; kugbabbar[silver]', '#lem: n; n; giŋ[unit]; kugbabbar[silver]', '#lem: n; giŋ[unit]; kugbabbar[silver]']}
# {'precious_object': ['#lem: n; mana[unit]; n; n; giŋ[unit]; lal[small]; n; še[barley]; kugbabbar[silver]']}
# {'precious_object': ['#lem: n; mana[unit]; n; n; giŋ[unit]; n; n; n; še[barley]; kugbabbar[silver]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) gin₂ ku₃', '#lem: n; giŋ[unit]; kug[metal]', '2. šu-nir gu₂-<de₃-na>-še₃', '#lem: šunir[emblem]; ON', '3. mu us₂-sa a-ra₂ 1(u) la₂ 1(diš)-kam si-mu-ru-um{ki} ba-hul', '#lem: mu[year]; us[follow]; ara[times]; n; lal[small]; n; GN; hulu[bad]', '@reverse', '$blank space']]}
# {'precious_object': ['#lem: n; giŋ[unit]; kugbabbar[silver]', '#lem: n; giŋ[unit]; kugbabbar[silver]'], 'domesticated_animal': ['#lem: gud[ox]; X; PN']}
# {'precious_object': ['#lem: n; šanabi[two-thirds]; giŋ[unit]; n; še[barley]; kugbabbar[silver]']}
# {'precious_object': ['#lem: n; giŋ[unit]; kugbabbar[silver]']}
# {'precious_object': ['#lem: n; n; giŋ[unit]; kugbabbar[silver]'], 'domesticated_animal': ['#lem: sa[pay for]; gud[ox]; gu[neck]']}
# {'precious_object': ['#lem: n; giŋ[unit]; kugbabbar[silver]']}
# {'precious_object': ['#lem: šanabi[two-thirds]; mana[unit]; ibiza[loss]; kugsig[gold]; kug[metal]; egal[palace]; e[leave]']}
# {'domesticated_animal': ['#lem: mu[year]; en[priest]; DN; maš[goat]; pad[find]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(gešʾu) 8(geš₂) 3(u) sa gu', '#lem: n; n; n; sa[roast]; gu[cord]', '2. ki ensi₂-ta', '#lem: ki[place]; ensik[ruler]', '3. da-da-ga šu ba-ti', '#lem: PN; šu[hand]; teŋ[approach]', '@reverse', '1. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [n] 8(aš) gu₂ 2(u) 8(diš) 5/6(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; n; n; mana[unit]; X', '2. mu an-ša-an{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '3. [n] 2(aš) gu₂ 3(u) 4(diš) ma-na siki [...]', '#lem: n; n; gu[pulse]; n; n; mana[unit]; siki[hair]; AN', '4. 1(u) 8(aš) gu₂ 5(u) la₂ 2/3(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; lal[small]; šanabi[two-thirds]; mana[unit]; X', '5. a-ra₂ 1(diš)-kam', '#lem: ara[times]; n', '6. 7(aš) gu₂ 5(u) la₂ 1(diš@t) ma-na [siki ...]', '#lem: n; gu[pulse]; n; lal[small]; n; mana[unit]; siki[hair]; AN', '7. a-ra₂ 2(diš)-kam', '#lem: ara[times]; n', '8. ki ur-e₁₁-e-ta', '#lem: ki[place]; PN', '9. 3(aš) gu₂ 1(u) 3(diš) 2/3(diš) ma-na [siki ...]', '#lem: n; gu[pulse]; n; n; šanabi[two-thirds]; mana[unit]; siki[hair]; AN', '10. a-pi₄-sal₄{ki}-ta', '#lem: GN', '11. [...] 8(diš) [...]', '#lem: AN; n; AN', '@reverse', '1. [...]', '#lem: AN', '2. ki ur-{d}šara₂ [...]', '#lem: ki[place]; PN; AN', '$ blank space', '3. mu us₂-sa an-[ša-an{ki} ba-hul]', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '$ blank space']]}
# {'wool': ['#lem: n; gu[pulse]; n; n; mana[unit]; siki[hair]; ŋirgul[~wool]']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) 5(aš) gu₂ 3(u) 5(diš) 2/3(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; n; šanabi[two-thirds]; mana[unit]; X', '2. ku₃-bi 2(diš) 1/2(diš) ma-na 3(diš) 1/2(diš) gin₂ 1(u) 2(diš) še', '#lem: kug[metal]; n; n; mana[unit]; n; n; giŋ[unit]; n; n; še[barley]', '3. ki ensi₂-ta', '#lem: ki[place]; ensik[ruler]', '@reverse', '1. ur#?-dumu#-zi-da#', '#lem: X', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '$ blank space']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) gu₂ siki-gi', '#lem: n; gu[pulse]; X', '2. siki udu-lah₅', '#lem: siki[hair]; X', '3. giri₃ kas₄ šuš₃', '#lem: ŋiri[foot]; kaš[runner]; kuš[official]', '4. mu ku₃ gu-za {d}en-lil₂-la₂ ba-dim₂', '#lem: mu[year]; kug[metal]; guza[chair]; PN; dim[create]', '@reverse', '$blank space']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(aš) gu₂ 2(u) 8(diš) ma-na siki', '#lem: n; gu[pulse]; n; n; mana[unit]; siki[hair]', '2. siki udu-lah₅', '#lem: siki[hair]; X', '3. kas₄ šu ba-ti', '#lem: kaš[runner]; šu[hand]; teŋ[approach]', '@reverse', '4. mu en-mah-gal-an-na [en {d}nanna ba-hun-ga₂]', '#lem: mu[year]; PN; en[priest]; DN; huŋ[hire]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 1(diš) tug₂ sag uš-bar', '#lem: n; n; tug[textile]; saŋ[head]; ušbar[weaver]', '2. tug₂ sa-gi₄-a', '#lem: tug[textile]; X', '3. ki ur-ama-na-ta', '#lem: ki[place]; PN', '4. ur-{d}iškur', '#lem: PN', '5. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. mu {d}nanna kar-zi-da a-ra₂ 2(diš)-kam', '#lem: mu[year]; DN; TN; ara[times]; n', '2. e₂-a-na kuₓ(KWU147)', '#lem: e[house]; X']]}
# {'leather_object': ['#lem: suhub[boots]; im[clay]; še[barley]; eban[pair]'], 'domesticated_animal': ['#lem: n; kuš[skin]; maš[goat]; PN; PN']}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. ki lugal-šu-nir', '#lem: ki[place]; PN', '4. ma-an-zi-zi', '#lem: X', '5. u₃ ur-{d}suen-ta', '#lem: u[and]; PN', '6. gu-du-du', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. iti ezem-{d}[...]', '#lem: itud[moon]; PN', '3. [mu] {d}šu-{d}suen# [ma]-da [za-ab-ša]-li[{ki} ba-hul]', '#lem: mu[year]; TN; mada[land]; GN; hulu[bad]']]}
# {'precious_object': ['#lem: kugsig[gold]; huš[reddish]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]'], 'wild_animal': ['#lem: ki[place]; PN; MAR.TU[westerner]; kur[mountain]; MAR.TU[westerner]; ma[ship]; gub[stand]']}
# {'domesticated_animal': ['#lem: n; gud[ox]; n; udu[sheep]', '#lem: n; udu[sheep]; aslum[sheep]', '#lem: n; gukkal[sheep]; n; mašgal[goat]', '#lem: n; maš[goat]', '#lem: n; sila[lamb]', '#lem: mu[year]; en[priest]; DN; maš[goat]; pad[find]']}
# {'domesticated_animal': ['#lem: u; n; AN; u; gud[ox]', '#lem: n; n; AN; n; lal[small]; n; udu[sheep]', '#lem: n; n; n; maš[goat]', '#lem: AN; n; gud[ox]; gunu[speckled]', '#lem: AN; gud[ox]; PN; MAR.TU[westerner]', '#lem: AN; n; gud[ox]; gunu[speckled]', '#lem: AN; gud[ox]; ŋešdu[breeder]; gunu[speckled]', '#lem: n; sila[lamb]; ensik[ruler]; GN', '#lem: n; sila[lamb]; PN']}
# {'domesticated_animal': ['#lem: n; sila[lamb]', '#lem: n; gud[ox]; n; udu[sheep]', '#lem: n; gukkal[sheep]', '#lem: n; udu[sheep]; aslum[sheep]', '#lem: n; mašgal[goat]'], 'wild_animal': ['#lem: n; mašda[gazelle]', '#lem: n; amar[young]; mašda[gazelle]']}
# {'domesticated_animal': ['#lem: n; gud[ox]; ŋešdu[breeder]; gunu[speckled]', '#lem: n; gud[ox]; ŋešdu[breeder]', '#lem: n; gud[ox]; gunu[speckled]', '#lem: n; gud[ox]', '#lem: n; sila[lamb]; PN; FN', '#lem: n; sila[lamb]; niga[fattened]; PN; šabra[administrator]', '#lem: n; sila[lamb]; ensik[ruler]; X']}
# {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]; X', '#lem: n; amar[young]; gud[ox]; ga[milk]; MAR.TU[westerner]', '#lem: n; kir[lamb]; ga[milk]', '#lem: n; maš[goat]; ga[milk]'], 'dead_animal': ['#lem: uš[die]; ud[sun]; n; n']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; FN', '#lem: n; maš[goat]; FN', '#lem: n; gud[ox]; n; u[ewe]', '#lem: n; gud[ox]; n; u[ewe]', '#lem: n; gud[ox]; n; u[ewe]']}
# {'domesticated_animal': ['#lem: n; n; dusu[equid]; munus[woman]', '#lem: n; dusu[equid]; munus[woman]; mu[year]; n'], 'wild_animal': ['#lem: namraʾak[booty]; kur[mountain]; MAR.TU[westerner]']}
# {'domesticated_animal': ['#lem: n; n; lal[small]; n; udu[sheep]; niga[fattened]; gudeʾusa[drover]', '#lem: n; sila[lamb]; niga[fattened]', '#lem: n; sila[lamb]; zabardab[official]', '#lem: n; sila[lamb]; PN', '#lem: n; udu[sheep]; n; mašgal[goat]; n; maš[goat]', '#lem: n; gud[ox]; niga[fattened]; n; maš[goat]', '#lem: n; n; udu[sheep]; n; maš[goat]', '#lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; udu[sheep]; n; uzud[goat]; maš[goat]; nua[~animal]', '#lem: n; udu[sheep]; n; maš[goat]; PN; dumu[child]; PN', '#lem: n; X; n; dusu[equid]; munus[woman]'], 'wild_animal': ['#lem: namraʾak[booty]; kur[mountain]; MAR.TU[westerner]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; niga[fattened]; FN', '#lem: n; sila[lamb]; FN', '#lem: n; maš[goat]; eʾuzga[building]', '#lem: n; gud[ox]; n; ab[cow]', '#lem: n; n; udu[sheep]; n; n; u[ewe]', '#lem: n; uzud[goat]; šugid[~animal]; emuhaldim[kitchen]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]', '#lem: n; mašgal[goat]']}
# {'domesticated_animal': ['#lem: n; gud[ox]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]']}
# {'domesticated_animal': ['#lem: n; gukkal[sheep]; n; gukkal[sheep]; babbar[white]', '#lem: n; n; udu[sheep]; aslum[sheep]; n; udu[sheep]', '#lem: n; lal[small]; n; mašgal[goat]', '#lem: n; udu[sheep]; aslum[sheep]; n; udu[sheep]', '#lem: n; mašgal[goat]', '#lem: n; gud[ox]', '#lem: n; gud[ox]; n; udu[sheep]; aslum[sheep]', '#lem: n; udu[sheep]; n; mašgal[goat]', '#lem: n; gud[ox]; n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN; ensik[ruler]', '#lem: n; maš[goat]; PN; ragaba[rider]', '#lem: n; sila[lamb]; en[priest]; TN', '#lem: n; sila[lamb]; ensik[ruler]; GN', '#lem: n; sila[lamb]; PN; nubanda[overseer]', '#lem: n; sila[lamb]; ensik[ruler]; GN', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; PN; dikud[judge]', '#lem: n; sila[lamb]; PN; ensik[ruler]', '#lem: n; sila[lamb]; PN; FN', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; sila[lamb]; ensik[ruler]; X', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; ga[milk]', '#lem: n; kir[lamb]; ga[milk]', '#lem: n; sila[lamb]; PN; sukkal[secretary]', '#lem: n; gud[ox]', '#lem: n; n; udu[sheep]', '#lem: n; sila[lamb]', '#lem: n; mašgal[goat]', '#lem: n; sila[lamb]', '#lem: n; udu[sheep]; X', '#lem: n; udu[sheep]; X', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; udu[sheep]; aslum[sheep]', '#lem: n; udu[sheep]; aslum[sheep]; ga[milk]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; ensik[ruler]; GN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; ensik[ruler]; GN', '#lem: n; gud[ox]; niga[fattened]', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; n; udu[sheep]', '#lem: n; maš[goat]', '#lem: n; gud[ox]; niga[fattened]', '#lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]', '#lem: n; n; udu[sheep]', '#lem: n; maš[goat]', '#lem: n; sila[lamb]; PN; šabra[administrator]', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; udu[sheep]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; PN', '#lem: n; maš[goat]; PN', '#lem: n; udu[sheep]; ŋi[night]; ŋešdu[breeder]', '#lem: n; sila[lamb]', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; udu[sheep]; aslum[sheep]; niga[fattened]', '#lem: n; sila[lamb]; PN; ensik[ruler]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; u', '#lem: n; sila[lamb]; PN', '#lem: n; maš[goat]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; ga[milk]', '#lem: n; sila[lamb]; AN', '#lem: n; udu[sheep]; aslum[sheep]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; ku[place]; ensik[ruler]', '#lem: n; sila[lamb]; PN; šabra[administrator]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; u', '#lem: n; sila[lamb]; AN', '#lem: n; n; udu[sheep]', '#lem: n; sila[lamb]', '#lem: n; mašgal[goat]', '#lem: n; lal[small]; n; udu[sheep]', '#lem: n; udu[sheep]; aslum[sheep]', '#lem: n; mašgal[goat]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; da[cvve]; gala[singer]', '#lem: n; sila[lamb]; PN; ensik[ruler]', '#lem: n; sila[lamb]; da[cvve]; FN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN; FN', '#lem: n; sila[lamb]; ensik[ruler]; AN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; u', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; AN', '#lem: n; sila[lamb]; udu[sheep]; TN', '#lem: n; sila[lamb]; PN; nubanda[overseer]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN; galamah[singer]', '#lem: n; sila[lamb]; PN; dubsar[scribe]', '#lem: n; mašgal[goat]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; en[priest]; TN', '#lem: n; sila[lamb]; u', '#lem: n; sila[lamb]', '#lem: n; kir[lamb]; aslum[sheep]', '#lem: n; gukkal[sheep]', '#lem: n; u[ewe]; gukkal[sheep]', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]', '#lem: n; maš[goat]; PN', '#lem: n; sila[lamb]', '#lem: n; sila[lamb]; PN', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; sila[lamb]; niga[fattened]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; udu[sheep]; n; sila[lamb]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]',  ...
# {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]', '#lem: n; gud[ox]']}
# {'wild_animal': ['#lem: n; amar[young]; mašda[gazelle]; munus[woman]', '#lem: n; udu[sheep]; n; mašda[gazelle]'], 'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
# {'domesticated_animal': ['#lem: u; maš[goat]; niga[fattened]; n; us[side]', '#lem: n; udu[sheep]; niga[fattened]; n; us[side]', '#lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]', '#lem: n; mašgal[goat]; niga[fattened]; gudeʾusa[drover]', '#lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]', '#lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]', '#lem: n; mašgal[goat]; niga[fattened]; gudeʾusa[drover]', '#lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]', '#lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]', '#lem: n; mašgal[goat]; niga[fattened]; gudeʾusa[drover]', '#lem: n; udu[sheep]; niga[fattened]; sag[rare]; us[side]', '#lem: n; udu[sheep]; niga[fattened]; n; us[side]']}
# ...
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
# {'precious_object': ['#lem: n; mana[unit]; n; giŋ[unit]; kugbabbar[silver]'], 'domesticated_animal': ['#lem: udu[sheep]; dirig[exceed]; de[bring]']}
# {'domesticated_animal': ['#lem: AN; udu[sheep]; n; n; n; sila[lamb]', '#lem: u; n; n; n; maš[goat]', '#lem: n; uzud[goat]; n; ašgar[kid]', '#lem: n; udu[sheep]; n; sila[lamb]; n; maš[goat]', '#lem: n; n; udu[sheep]; n; maš[goat]; sadug[offerings]; kud[cut]', '#lem: n; udu[sheep]; ŋiri[foot]; PN', '#lem: n; n; udu[sheep]; ŋiri[foot]; PN; lu[person]; PN', '#lem: n; udu[sheep]; ŋiri[foot]; PN; šeš[brother]; PN', '#lem: n; n; udu[sheep]; n; n; n; maš[goat]', '#lem: šuniŋin[total]; n; n; n; udu[sheep]', '#lem: šuniŋin[total]; n; n; n; sila[lamb]', '#lem: šuniŋin[total]; n; n; u[ewe]; n; n; n; n; maš[goat]', '#lem: šuniŋin[total]; n; uzud[goat]; n; ašgar[kid]']}
# {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(diš) šeg₉-bar-nita₂', '#lem: n; X', '2. 5(diš) šeg₉-bar-nita₂ mu 1(diš)', '#lem: n; X; mu[year]; n', '3. 3(diš) šeg₉-bar munus', '#lem: n; šeŋbar[animal]; munus[woman]', '4. 7(diš) šeg₉-bar munus mu 1(diš)', '#lem: n; šeŋbar[animal]; munus[woman]; mu[year]; n', '5. u₄ 3(diš)-kam', '#lem: ud[sun]; n', '@reverse', '1. ki ab-ba-sa₆-ga-ta', '#lem: ki[place]; PN', '2. lu₂-dingir-ra i₃-dab₅', '#lem: PN; dab[seize]', '3. iti ezem-me-ki-gal₂', '#lem: itud[moon]; MN', '4. mu ša-aš-ru{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@left', '1. 1(u) 8(diš)', '#lem: n; n']]}
# {'dead_animal': ['#lem: n; udu[sheep]; uš[die]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; PN; damgar[merchant]', '#lem: n; sila[lamb]; PN; damgar[merchant]', '#lem: n; sila[lamb]; ensik[ruler]; GN', '#lem: n; sila[lamb]; ensik[ruler]; GN', '#lem: n; sila[lamb]; PN; nubanda[overseer]', '#lem: n; sila[lamb]; PN; nubanda[overseer]', '#lem: n; udu[sheep]; n; sila[lamb]', '#lem: n; udu[sheep]; niga[fattened]; n; gukkal[sheep]; niga[fattened]', '#lem: n; maš[goat]; n; sila[lamb]', '#lem: n; gukkal[sheep]; niga[fattened]; n; sila[lamb]'], 'wild_animal': ['#lem: n; amar[young]; mašda[gazelle]; AN']}
# {'domesticated_animal': ['#lem: n; n; udu[sheep]', '#lem: n; sila[lamb]', '#lem: n; n; n; maš[goat]', '#lem: n; udu[sheep]; sadug[offerings]; kud[cut]', '#lem: n; n; udu[sheep]; n; n; maš[goat]', '#lem: n; n; udu[sheep]; ki[place]; PN', '#lem: n; udu[sheep]; ki[place]; PN', '#lem: n; udu[sheep]; sadug[offerings]; kud[cut]', '#lem: šuniŋin[total]; n; n; n; udu[sheep]', '#lem: šuniŋin[total]; n; maš[goat]']}
# {'domesticated_animal': ['#lem: n; n; udu[sheep]; šag[heart]; udu[sheep]; šugid[~animal]', '#lem: n; udu[sheep]; ki[place]; PN', '#lem: n; sila[lamb]; mu.DU[delivery]', '#lem: n; n; udu[sheep]; GN', '#lem: n; n; udu[sheep]; eʾudu[sheephouse]', '#lem: n; udu[sheep]; ki[place]; PN', '#lem: n; n; udu[sheep]; AN', '#lem: n; n; udu[sheep]; emuhaldim[kitchen]; ud[sun]; n; n', '#lem: n; n; udu[sheep]; ud[sun]; n; n', '#lem: n; maš[goat]; X', '#lem: n; maš[goat]; PN', '#lem: n; n; udu[sheep]; situm[balance]'], 'dead_animal': ['#lem: n; udu[sheep]; uš[die]', '#lem: n; udu[sheep]; n; sila[lamb]; uš[die]; PN; ud[sun]; n']}
# {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]']}
# {'domesticated_animal': ['#lem: n; gud[ox]']}
# {'domesticated_animal': ['#lem: n; uzud[goat]; maš[goat]; nua[~animal]', '#lem: n; udu[sheep]', '#lem: n; sila[lamb]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]', '#lem: n; sila[lamb]; niga[fattened]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; e[house]; taka[abandon]', '#lem: n; sila[lamb]; kiŋgia[messenger]', '#lem: n; sila[lamb]; n; maš[goat]', '#lem: n; sila[lamb]; kiŋgia[messenger]', '#lem: n; sila[lamb]; ŋiri[foot]; agaʾus[soldier]; PN', '#lem: n; udu[sheep]; PN; dubsar[scribe]', '#lem: n; sila[lamb]; agaʾus[soldier]; PN', '#lem: n; udu[sheep]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; maš[goat]; PN', '#lem: n; sila[lamb]; ŋiri[foot]; PN', '#lem: n; maš[goat]; ŋiri[foot]; duga[affliction]', '#lem: n; sila[lamb]; dirig[exceed]; n; sila[lamb]; laʾu[arrears]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]', '#lem: n; udu[sheep]; PN; niga[fattened]', '#lem: n; n; mašgal[goat]; X', '#lem: n; gud[ox]; n; n; udu[sheep]']}
# {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) amar maš-da₃-nita₂', '#lem: n; amar[young]; X', '2. e₂-uz-ga', '#lem: eʾuzga[building]', '3. mu-kuₓ(DU) i₃-lal₃-lum', '#lem: mu.DU[delivery]; PN', '4. ur-{d}ba-ba₆ maškim', '#lem: PN; maškim[administrator]', '5. u₄ 2(u) 9(diš)-kam', '#lem: ud[sun]; n; n', '@reverse', '1. ki ab-ba-sa₆-ga-ta', '#lem: ki[place]; PN', '2. ba-zi', '#lem: PN', '3. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '4. mu hu-uh₂-nu-ri{ki}', '#lem: mu[year]; GN', '@left', '1. 1(diš)', '#lem: n']]}
# {'domesticated_animal': ['#lem: n; dusu[equid]; munus[woman]', '#lem: n; dusu[equid]; munus[woman]; šugid[~animal]', '#lem: n; dusu[equid]; munus[woman]; mu[year]; n', '#lem: n; dusu[equid]; munus[woman]; mu[year]; n', '#lem: n; dusu[equid]; munus[woman]; amar[young]; ga[milk]']}
# {'domesticated_animal': ['#lem: n; gud[ox]; n; udu[sheep]', '#lem: n; udu[sheep]; n; mašgal[goat]', '#lem: gud[ox]; n; n; udu[sheep]']}
# {'precious_object': ['#lem: n; mana[unit]; kugbabbar[silver]']}
# {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@object seal', '@surface a', '1. a-ha-ni-šu', '#lem: PN', '2. sipa lugal', '#lem: sipad[shepherd]; lugal[king]']]}
# {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) maš-da', '#lem: n; mašda[stone]', '2. u₄ 2(u) 5(diš)-kam', '#lem: ud[sun]; n; n', '3. ki ab-ba-sa₆-ga-ta', '#lem: ki[place]; PN', '4. lu₂-dingir-ra', '#lem: PN', '@reverse', '1. i₃-dab₅', '#lem: dab[seize]', '2. iti ezem-me-ki-gal₂', '#lem: itud[moon]; MN', '3. mu hu-uh₂-nu-ri{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@left', '1. 1(diš)', '#lem: n']]}
# {'domesticated_animal': ['#lem: n; n; udu[sheep]']}
# {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '2. wi-bi-za-la₂', '#lem: X', '3. u₄ 9(diš)-kam', '#lem: ud[sun]; n', '4. ki ab-ba-sa₆-ga-ta', '#lem: ki[place]; PN', '@reverse', '1. ta₂-hi-iš-a-tal', '#lem: PN', '2. i₃-dab₅', '#lem: dab[seize]', '3. iti ezem-{d}nin-a-zu', '#lem: itud[moon]; MN', '4. mu hu-uh₂-nu-ri{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@left', '1. 1(diš)', '#lem: n']]}
# {'dead_animal': ['#lem: uš[die]; ud[sun]; n']}
# {'domesticated_animal': ['#lem: n; n; gud[ox]; niga[fattened]', '#lem: n; gud[ox]; niga[fattened]; ki[place]; PN', '#lem: n; ab[cow]; kišib[seal]; PN', '#lem: gud[ox]; mu[year]; na[man]', '#lem: n; gud[ox]; niga[fattened]; kišib[seal]; PN', '#lem: n; gud[ox]; niga[fattened]; kišib[seal]; PN; dikud[judge]', '#lem: n; gud[ox]; niga[fattened]; kišib[seal]; PN', '#lem: n; gud[ox]; niga[fattened]; kišib[seal]; PN', '#lem: n; gud[ox]; niga[fattened]; sukkalmah[official]', '#lem: n; gud[ox]; niga[fattened]; PN; nubanda[overseer]', '#lem: n; gud[ox]; niga[fattened]; n; gud[ox]', '#lem: n; gud[ox]; niga[fattened]; ku[place]', '#lem: n; gud[ox]; niga[fattened]; PN', '#lem: n; gud[ox]; niga[fattened]; PN', '#lem: n; gud[ox]; niga[fattened]; PN; lu[person]; uzu[flesh]', '#lem: n; gud[ox]; niga[fattened]; PN', '#lem: n; gud[ox]; PN']}
# {'domesticated_animal': ['#lem: udu[sheep]; gu[eat]', '#lem: n; gud[ox]; n; ab[cow]; šugid[~animal]; emuhaldim[kitchen]', '#lem: n; ab[cow]; šugid[~animal]; emuhaldim[kitchen]', '#lem: n; gud[ox]; n; ab[cow]; šugid[~animal]; emuhaldim[kitchen]', '#lem: n; gud[ox]; šugid[~animal]; emuhaldim[kitchen]', '#lem: n; gud[ox]; PN', '#lem: n; gud[ox]; n; ab[cow]; šugid[~animal]; emuhaldim[kitchen]', '#lem: n; gud[ox]; šugid[~animal]; emuhaldim[kitchen]; ud[sun]; n; n', '#lem: n; ab[cow]; šugid[~animal]; emuhaldim[kitchen]; ud[sun]; n; n', '#lem: n; ab[cow]; šugid[~animal]; emuhaldim[kitchen]; ud[sun]; n; n', '#lem: n; gud[ox]; šugid[~animal]; emuhaldim[kitchen]; ud[sun]; n; n', '#lem: n; ab[cow]; GN; mu[year]; erin[people]; marsa[shipyard]; ma[ship]; PN; gub[stand]', '#lem: n; gud[ox]; n; ab[cow]; šugid[~animal]; emuhaldim[kitchen]', '#lem: n; ab[cow]; mu[year]; lu[person]; GN', '#lem: n; gud[ox]; mu[year]; gardu[soldier]', '#lem: n; ab[cow]; šugid[~animal]; emuhaldim[kitchen]', '#lem: šuniŋin[total]; n; n; gud[ox]; n; n; ab[cow]', '#lem: šuniŋin[total]; n; gud[ox]; niŋba[gift]; lugal[king]']}
# {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]', '#lem: ab[cow]; n; ki[place]; ŋar[place]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; n; us[side]; n; udu[sheep]; niga[fattened]', '#lem: n; gukkal[sheep]; niga[fattened]; PN', '#lem: n; udu[sheep]; niga[fattened]; TN', '#lem: n; udu[sheep]; niga[fattened]; n; us[side]', '#lem: n; mašgal[goat]; dara[red]; n; us[side]', '#lem: n; udu[sheep]; niga[fattened]; PN; MAR.TU[westerner]', '#lem: n; udu[sheep]; niga[fattened]; šu[hand]; gin[firm]', '#lem: n; udu[sheep]; niga[fattened]; niŋ[thing]; dirig[exceed]']}
# {'domesticated_animal': ['#lem: n; n; udu[sheep]; mu[year]; u[ewe]', '#lem: n; sila[lamb]; mu[year]; kir[lamb]', '#lem: n; n; mašgal[goat]; mu[year]; ašgar[kid]']}
# {'domesticated_animal': ['#lem: n; n; udu[sheep]; niga[fattened]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]', '#lem: n; udu[sheep]; niga[fattened]', '#lem: n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; uzud[goat]'], 'dead_animal': ['#lem: uš[die]; ekišibak[storeroom]']}
# {'domesticated_animal': ['#lem: n; mašgal[goat]; X; gunu[speckled]']}
# {'domesticated_animal': ['#lem: laʾu[arrears]; n; n; gud[ox]; AN', '#lem: n; n; n; udu[sheep]; maš[goat]; hi[mix]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; eʾuzga[building]', '#lem: n; udu[sheep]; niga[fattened]; n; us[side]', '#lem: n; udu[sheep]; aslum[sheep]; niga[fattened]', '#lem: n; u[ewe]; aslum[sheep]; niga[fattened]; n; us[side]', '#lem: n; sila[lamb]; niga[fattened]', '#lem: n; kir[lamb]; niga[fattened]', '#lem: n; mašgal[goat]; X; niga[fattened]; sag[rare]', '#lem: n; mašgal[goat]; dara[red]; niga[fattened]', '#lem: n; sila[lamb]', '#lem: n; n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]', '#lem: n; udu[sheep]']}
# {'domesticated_animal': ['#lem: n; gukkal[sheep]; PN', '#lem: n; gud[ox]; n; udunita[ram]', '#lem: n; mašgal[goat]; niga[fattened]', '#lem: n; udu[sheep]; n; udu[sheep]; aslum[sheep]', '#lem: n; n; gukkal[sheep]; n; n; sila[lamb]'], 'wild_animal': ['#lem: n; maš[goat]; n; mašda[gazelle]; munus[woman]']}
# {'domesticated_animal': ['#lem: šaggal[food]; gud[ox]; niga[fattened]; n', '#lem: gud[ox]; niga[fattened]; še[barley]; kum[hot]', '#lem: šaggal[food]; udu[sheep]; niga[fattened]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; ud[sun]; n', '#lem: n; sila[lamb]; ud[sun]; n', '#lem: n; sila[lamb]; ud[sun]; n', '#lem: n; sila[lamb]; ud[sun]; n', '#lem: n; sila[lamb]; ud[sun]; n', '#lem: n; sila[lamb]; ud[sun]; n', '#lem: n; sila[lamb]; ud[sun]; n; n', '#lem: n; sila[lamb]; n; maš[goat]; ud[sun]; n; n', '#lem: n; sila[lamb]; n; maš[goat]; ud[sun]; n; n', '#lem: n; sila[lamb]; ud[sun]; n; n', '#lem: n; sila[lamb]; ud[sun]; n; n', '#lem: n; sila[lamb]; ud[sun]; n; n', '#lem: n; sila[lamb]; ud[sun]; n', '#lem: šuniŋin[total]; n; sila[lamb]', '#lem: šuniŋin[total]; n; maš[goat]', '#lem: udu[sheep]']}
# {'precious_object': ['#lem: n; mana[unit]; n; giŋ[unit]; kugbabbar[silver]', '#lem: ŋiri[dagger]; kugsig[gold]; ŋiri[foot]; n; igi[face]; n', '#lem: u[and]; kugsig[gold]; sisa[fair]; n']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; PN; kuš[official]', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; X', '#lem: šuniŋin[total]; n; sila[lamb]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; PN', '#lem: n; udu[sheep]; PN', '#lem: ud[sun]; iku[unit]; udu[sheep]; X', '#lem: udu[sheep]']}
# {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]', '#lem: n; gud[ox]; u[grass]']}
# {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(diš) {uruda}gur₁₀', '#lem: n; kin[sickle]', '2. ki šu-eš₁₈-dar-ta', '#lem: ki[place]; PN', '3. a-hu-du₁₀ engar', '#lem: PN; engar[farmer]', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. a-ša₃ kir₁₁-TAR{ki}', '#lem: ašag[field]; X', '2. iti maš-da₃-gu₇', '#lem: itud[moon]; MN', '3. mu us₂-sa en eridu{ki} ba-hun', '#lem: mu[year]; us[follow]; en[priest]; GN; huŋ[hire]', '@seal 1', '1. a-hu-du₁₀', '#lem: PN', '2. dumu ga-[...]', '#lem: dumu[child]; PN']]}
# {'domesticated_animal': ['#lem: n; sa[roast]; gi[reed]; udu[sheep]; n; šeŋ[cook]']}
# {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) geš ka peš₅ ša₃-kal e₂-se₃-ga', '#lem: n; ŋeš[tree]; kag[mouth]; peš[anoint]; PN; X', '2. uš-bar nam-duₓ(GIN₂)-la₂-a', '#lem: ušbar[weaver]; X', '3. ki lu₂-sa₆-ga-ta', '#lem: ki[place]; PN', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '5. a-hu-ni', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. ša₃ puzur₄-iš-{d}da-gan', '#lem: šag[heart]; X', '3. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '4. mu en {d}nanna {d}amar-{d}suen-ra-ki-ag₂-an-na ba-hun', '#lem: mu[year]; en[priest]; DN; PN; huŋ[hire]', '@left', '1. 2(diš)', '#lem: n']]}
# {'precious_object': ['#lem: šanabi[two-thirds]; šag[heart]; n; n; giŋ[unit]; kugbabbar[silver]']}
# {'domesticated_animal': ['#lem: n; udu[sheep]; PN; šagia[cup-bearer]'], 'dead_animal': ['#lem: n; udu[sheep]; uš[die]; emuhaldim[kitchen]']}
# {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(geš₂) 5(u) 3(diš) geme₂ sag-dub', '#lem: n; n; n; geme[worker]; saŋdub[laborer]', '2. 3(u) 1(diš) dumu-munus 1(aš) gur', '#lem: n; n; dumumunus[daughter]; n; gur[unit]', '3. 1(u) 3(diš) dumu-nita₂', '#lem: n; n; dumunita[son]', '4. 1(u) 5(diš) dumu-munus', '#lem: n; n; dumumunus[daughter]', '5. šu+nigin 2(geš₂) 5(u) 2(diš) sag-dub', '#lem: šuniŋin[total]; n; n; n; saŋdub[laborer]', '@reverse', '1. nam-ra-ak [a-ru-a] {d}[šara₂-še₃]', '#lem: namraʾak[booty]; arua[offering]; FN', '2. iri ša-ri₂-ib?-hu-um-ma{ki}', '#lem: iri[city]; GN', '# edition has it', '3. ur-{d}li₉-si₄ ensi₂ umma{ki} i₃-dab₅', '#lem: PN; ensik[ruler]; GN; dab[seize]', '4. iti šu-eš-ša 1(diš)', '#lem: itud[moon]; MN; n', '# some text moved to next line', '5. mu en {d}nanna ba-hun', '#lem: mu[year]; en[priest]; DN; huŋ[hire]', '']]}
# {'domesticated_animal': ['#lem: n; ŋešnud[bed]; umbin[implement]; gud[ox]; PN; zabar[bronze]; ŋar[place]', '#lem: n; ŋešnud[bed]; umbin[implement]; gud[ox]; PN; urud[copper]; ŋar[place]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN', '#lem: n; sila[lamb]; PN']}
# {'domesticated_animal': ['#lem: gud[ox]; udu[sheep]; ziga[expenditure]'], 'dead_animal': ['#lem: u[and]; uš[die]; de[bring]']}
# {'domesticated_animal': ['#lem: n; sila[lamb]']}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
lem_lists = [list(x.values())[0] for x in non_queen_labs]
lines = []
for lem in lem_lists:
    for line in lem:
        if line[:5] == "#lem:":
            lines.append(line)
line_string = "".join(lines)
translations = [t.strip() for t in re.split(";|#lem:|\|", line_string) if t != "" and len(t) > 2 and "[" in t]

# %%
trans_dict = {}
for tr in translations:
    word, defn = re.split("\[", tr)
    if defn[-1] == "]":
        defn = defn[:-1]
    if defn in trans_dict.keys():
        trans_dict[defn].append(word)
    else:
        trans_dict[defn] = [word]

# %%
# Checking what words fall under the Unknown category

Unknown_lines = [x[0][0] for x in Unknown_labs]
Unknown_lemmas = []
for l in Unknown_lines:
    for val in l:
        if val[:5] == "#lem:":
            Unknown_lemmas.append(val)

# %%
line_string_unknown = "".join(Unknown_lemmas)
translations_unknown = list(set([t.strip() for t in re.split(";|#lem:|\|", line_string_unknown) if t != "" and len(t) > 2 and "[" in t]))
# print(translations_unknown)

for tr in translations_unknown:
    word, defn = re.split("\[", tr)
    if defn[-1] == "]":
        defn = defn[:-1]
    if defn in trans_dict.keys():
        trans_dict[defn].append(word)
    else:
        trans_dict[defn] = [word]
        
for k, v in trans_dict.items():
    trans_dict[k] = list(set(v))

# %%
non_tagged_words = re.findall("\[(.*?)\]", " ".join(Unknown_lemmas))
non_tagged_freq = Counter(non_tagged_words)
sorted_words_by_freq = sorted(list(non_tagged_freq.keys()), key = lambda x: (-non_tagged_freq[x], x))
words_with_sumerian = [[x, trans_dict[x]] for x in sorted_words_by_freq]
# print(words_with_sumerian)

# %%
unknown_words = open('unknown_text_words.csv', 'w', encoding='utf-8')
unknown_words.write("Word, Frequency, List of Sumerian Words\n")
for w, defs in words_with_sumerian:
    unknown_words.write(w + ", " + str(non_tagged_freq[w]) + ", " + str(defs) + "\n")
unknown_words.close()

# %%
id_archive_map = {}
    
for text in dead_animal_archive:
    t_list = mapping[text]
    for t in t_list:
        id_archive_map[t.p_id] = "dead animal"

for text in wild_animal_archive:
    t_list = mapping[text]
    for t in t_list:
        id_archive_map[t.p_id] = "wild animal"
    
for text in domesticated_animal_archive:
    t_list = mapping[text]
    for t in t_list:
        id_archive_map[t.p_id] = "domesticated animal"
        
for text in leather_object_archive:
    t_list = mapping[text]
    for t in t_list:
        id_archive_map[t.p_id] = "leather object"
    
for text in precious_object_archive:
    t_list = mapping[text]
    for t in t_list:
        id_archive_map[t.p_id] = "precious object"

for text in wool_archive:
    t_list = mapping[text]
    for t in t_list:
        id_archive_map[t.p_id] = "wool"
    
for text in Unknown_archive:
    t_list = mapping[text]
    for t in t_list:
        id_archive_map[t.p_id] = "unknown"

for text in queen_data:
    t_list = mapping[text]
    for t in t_list:
        id_archive_map[t.p_id] = "queen"
# Out:
# 14594

# %%
# Write results of archive classification to CSV file

archive = open('archive_map.csv', 'w', encoding='utf-8')
archive.write("PID,Archive\n")
for k, v in id_archive_map.items():
    archive.write(k + "," + v + "\n")
archive.close()

# %% [markdown]
# ## Random Sample Creation

# %%
training_ids = [id[1:] for id in complete_list]
all_texts_ids = list(id_archive_map.keys())
non_training_ids = [id for id in all_texts_ids if id not in training_ids]

random_indices = random.sample(range(len(non_training_ids)), 50)
random_ids = [non_training_ids[index] for index in range(len(non_training_ids)) if index in random_indices]

random_sample_ids = []
random_sample_texts = []
random_sample_labels = []

for text, t_list in mapping.items():
    for t in t_list:
        if t.p_id in random_ids:
            random_sample_ids.append(t.p_id)
            random_sample_texts.append(text)
            random_sample_labels.append(id_archive_map[t.p_id])
            
# print(random_sample_labels)
# print(random_sample_texts)

# %%
# Write results of random sample to CSV file
# import unicodecsv as csv

sample = open('random_sample.csv', 'w', encoding='utf-8')
sample.write("PID,Text,Archive\n")
for i in range(len(random_sample_ids)):
# for i in range(1):
    sample.write(random_sample_ids[i] + "," + random_sample_texts[i] + "," + random_sample_labels[i] + "\n")
sample.close()

# %% [markdown]
# ## Multiple Transactions

# %%
t = None
for tr in all_transactions:
#     if tr.p_id == "P125693":
#     if tr.p_id == "P142790":
    if tr.p_id == "P430140":
#     if tr.p_id == "P124036":
        t = tr
        break
t.lines
# Out:
# ['#project: epsd2/u3adm/p013',
#  '#atf: use unicode',
#  '#atf: lang sux',
#  '@object seal',
#  '@surface a',
#  '1. an-ne₂-ba-ab-du₇',
#  '#lem: PN',
#  '2. dub-sar',
#  '#lem: dubsar[scribe]',
#  '3. dumu ka-sa₆',
#  '#lem: dumu[child]; X']

# %%
use = [line for line in t.lines if line[:5] == "#lem:" or line[0] not in "#@"]
use_str = "\n".join(use)
# use_str
re.findall("([1-9]\. [1-9]+\(.*\) .*\n#lem: n; .+\[.+\]\n)", use_str)
# Out:
# ['4. 4(diš) udu niga 1(diš) sila₄#\n#lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]\n',
#  '5. 3(diš) udu niga 1(diš) sila₄\n#lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]\n']

# %%
# for t in all_transactions:
#     if t.p_id in random_sample_ids:
#         print(t.p_id)
#         print(" ".join(t.get_sumerian_lemma()))
