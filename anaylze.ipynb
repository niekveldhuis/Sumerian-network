# %%
# %load get_roles_edited.py
# Out:
# completed raw-data/p001.atf
# completed raw-data/p002.atf
# completed raw-data/p003.atf
# completed raw-data/p004.atf
# completed raw-data/p005.atf
# completed raw-data/p006.atf
# completed raw-data/p007.atf
# completed raw-data/p008.atf
# completed raw-data/p009.atf
# completed raw-data/p010.atf
# completed raw-data/p011.atf
# completed raw-data/p012.atf
# completed raw-data/p013.atf
# completed raw-data/p014.atf
# completed raw-data/p015.atf
# ***Total of  14594  transactions.***
# 384  transactions DO NOT have PN.
# 10576  transactions contain a word ki[place].
# 2617  transactions contain a word šu ba-ti.
# 210  transactions contain a word ra₂-gaba.

# %%
ls_txt_containing_PN = list()
for trans in complete_transaction_ls:
    txt,translit = transaction_ls.split("\n")
    print(trans.ls_lines_containing_PN)
# Out:
# ['2. kišib₃ lu₂-{d}suen\n#lem: kišib[seal]; PN', '3. ki ab-ba-kal-la-ta\n#lem: ki[place]; PN', '4. ba-zi#\n#lem: PN', '1. ur-ku₃-nun-na#\n#lem: PN']
# ['5. ki lu₂-dingir-ra-ta\n#lem: ki[place]; PN', '1. ur-nigar{gar}\n#lem: PN']
# ['3. mu-kuₓ(DU) nu-i₃-da\n#lem: mu.DU[delivery]; PN', '1. ki na-sa₆-ta [ba]-zi\n#lem: ki[place]; PN; PN']
# ['1. ki lu₂-dingir-ra-ta\n#lem: ki[place]; PN', '2. ur-nigar{gar}\n#lem: PN', '5. mu# [{d}]amar#-{d}suen lugal\n#lem: mu[year]; PN; lugal[king]']
# ['2. ki lu₂-dingir-ra-ta\n#lem: ki[place]; PN', '3. ur-nigar{gar}\n#lem: PN', '6. mu {d}amar-{d}suen lugal\n#lem: mu[year]; PN; lugal[king]']
# ['2. lugal-pa-e₃\n#lem: PN', '2. 1(diš) sila₄ ARAD₂-mu\n#lem: n; sila[lamb]; PN']
# ...
