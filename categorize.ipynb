# %%
# Import Libraries
import re
import numpy as np
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from collections import OrderedDict, Counter
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Extract Transactions

# %%
DREHEM_IDS = 'drehem_annotate_ids.txt'
QUEEN_ARCHIVES_IDS = 'queen_archives_pids.txt'
QUEEN_OIP_IDS = 'oip_pids.txt'

labels = {}
labels["domesticated_animal"] = ["ox", "cow", "sheep", "goat", "lamb"] # account for plural
labels["wild_animal"] = ["bear", "gazelle", "mountain"] # account for "mountain animal" and plural
labels["dead_animal"] = ["[die]"] # find "die" before finding domesticated or wild
labels["leather_object"] = ["boots", "sandals"]
labels["precious_object"] = ["copper", "bronze", "silver", "gold"]
labels["wool"] = ["wool"]
labels["queens_archive"] = []
# wool,

class Transaction:
    def __init__(self, p_id):
        self.p_id = p_id
        self.lines = list()
        self.lemmas = OrderedDict() # Maps Sumerian text to its lemmatized form
        self.label = {} # Maps label to List of defining text
        self.sumerian_lemmas = []
        
    # Create mapping of Sumerian text to its lemmatized form
    def get_lemmatization(self):
        first_line = 0
        for i, s in enumerate(self.lines):
            if s.startswith("1."):
                  first_line = i
                  break
        while first_line < len(self.lines)-1:
            if self.lines[first_line] and self.lines[first_line][0].isnumeric() and self.lines[first_line+1].startswith("#lem"):
                self.lemmas[self.lines[first_line]] = self.lines[first_line+1]
                first_line += 2
            else:
                first_line += 1
                
        return self.lemmas
    
    # Get Sumerian lemmatized text only
    def get_sumerian_lemma(self):
        #print(item.sumerian_lemmas)
        item.sumerian_lemmas = []
        for k, v in self.lemmas.items():
            #print(v)
            result = re.findall(" .*\[[a-z]+\]", v)
            if len(result) == 0:
                continue
            lemmas = [s[:s.index("[")].strip() for s in result[0].split(";") if re.search("\[", s)]
            self.sumerian_lemmas += lemmas
        return self.sumerian_lemmas
    
    # Find the most likely label
    def set_label(self):
        def find_label(label, line, found) :
            for val in labels[label]:
                if val in line: 
                    if label in found.keys():
                        found[label].append(line)
                    else:
                        found[label] = [line]
                    return True
        found = {}
        for line in self.lines:
            label = None
            # Priority 1: Check for dead animal
            if find_label("dead_animal", line, found): break
            # Priority 2: Check for wild animal
            if find_label("wild_animal", line, found): break
            # Priority 3: Check for domesticated animal
            if find_label("domesticated_animal", line, found): break
            # Priority 4: Check leather, wool, or precious object
            if find_label("leather_object", line, found): break
            if find_label("precious_object", line, found): break
            if find_label("wool", line, found): break
        # If none match, label as "Unknown"
        if len(found.keys()) == 0:
            found["Unknown"] = [self.lines]
        self.label = found
        return found
            
    
# Read ORACC files to find transactions with p_ids in `ids`
def read_files(subdir, ids):
    transactions = list()
    for i in range(1, 16):
        file_name = ""
        if i < 10:
            file_name += subdir + "p00" + str(i) + ".atf"
        else:
            file_name += subdir + "p0" + str(i) + ".atf"
        
        curr_transaction = None
        
        with open(file_name, encoding="utf8") as file:
            print("Opening:", file_name)
            for line in file:
                line = line.strip()
                if line.startswith('&P'):
                    p_id = line.split()[0][1:] # line[line.index("="):] if (line.index("=") != -1) else line.split()[0][1:]
                    if p_id in ids:
                        ids.remove(p_id)
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    else:
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        curr_transaction = None
                else:
                    if curr_transaction:
                        curr_transaction.lines.append(line)
        
        if curr_transaction:
            transactions.append(curr_transaction)
    
    #print(ids)
    #assert len(ids) == 0
    print("Number of transactions:", len(transactions))
    return transactions

# Return the IDs of docs to annotate
def get_drehem_ids(file):
    lst = list()
    with open(file, encoding="utf8") as f:
        for line in f:
            line = line.strip()
            lst.append(line)
    return lst

# %%
list_drehem_ids = get_drehem_ids(DREHEM_IDS)
list_queen_ids = get_drehem_ids(QUEEN_ARCHIVES_IDS)
list_oip_queen_ids = get_drehem_ids(QUEEN_OIP_IDS)
#complete_list = list_drehem_ids + list_queen_ids + list_oip_queen_ids

#all_transactions = read_files("raw-data/", complete_list)
non_queen_list = read_files("raw-data/", list_drehem_ids)
queen_training_list = read_files("raw-data/", list_queen_ids)
queen_test_set = read_files("raw-data/", list_oip_queen_ids)
# Out:
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 314
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 212
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 120

# %%
queen_unknowns = 0

for item in queen_training_list:
    print(item.p_id)
    for k,v in item.get_lemmatization().items():
        print(k)
        print(v)
    item.set_label()
    print("Hardcode label: ", item.label)
    print("\n")
    if "Unknown" in item.label.keys():
        queen_unknowns += 1
            
print("Number unknown: ", queen_unknowns, "out of ", len(queen_training_list))
# Out:
# P101878
# 1. 1(diš) šah₂-NE-tur-nita₂-geš-gi-gur₄
# #lem: n; X
# 2. 2(diš) uz-tur
# #lem: n; PN
# 3. 3(diš) ir₇{mušen}
# #lem: n; irsaŋ[pigeon]
# 4. 1(u) 4(diš) tu-gur₄{mušen}
# #lem: n; n; tugur[dove]
# 5. ma₂!-an-na-še₃
# #lem: ON
# 6. iti-ta u₄ 2(u) 4(diš) ba-ta-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 1. zi-ga a₂-bi₂-la-tum
# #lem: ziga[expenditure]; PN
# 2. iti a₂#-ki-ti
# #lem: itud[moon]; akiti[festival]
# 3. mu ša-aš-ru{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur-nita₂-geš-gi-gur₄', '#lem: n; X', '2. 2(diš) uz-tur', '#lem: n; PN', '3. 3(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '4. 1(u) 4(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '5. ma₂!-an-na-še₃', '#lem: ON', '6. iti-ta u₄ 2(u) 4(diš) ba-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '@reverse', '$ blank space', '1. zi-ga a₂-bi₂-la-tum', '#lem: ziga[expenditure]; PN', '2. iti a₂#-ki-ti', '#lem: itud[moon]; akiti[festival]', '3. mu ša-aš-ru{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P102133
# 1. 2(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 2. e₂ {d}be-<la>-ad-suh-ner
# #lem: e[house]; PN
# 3. u₃ [{d}]be-<la>-at-dar-ra#-e₂-ba-an#
# #lem: u[and]; X
# 1. ur-{d}dumu-zi-da maškim#
# #lem: PN; maškim[administrator]
# 2. zi-ga
# #lem: ziga[expenditure]
# 3. ki šu-ku-bu-um
# #lem: ki[place]; PN
# 4. iti ezem-an-na
# #lem: itud[moon]; MN
# 5. mu us₂-sa en eridu{ki}-ga ba-hun-ga₂
# #lem: mu[year]; us[follow]; en[priest]; GN; huŋ[hire]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P102370
# 1. 1(diš) maš₂
# #lem: n; maš[goat]
# 2. e₂ {d}al-la gu-la
# #lem: e[house]; DN; gal[big]
# 3. 1(diš) sila₄
# #lem: n; sila[lamb]
# 4. e₂ {d}nin-e₂-gal
# #lem: e[house]; FN
# 2. e₂ {d}en-lil₂
# #lem: e[house]; FN
# 3. siskur₂ e₂-u₄-7(diš) ša₃ nibru{ki}
# #lem: siškur[prayer]; X; šag[heart]; GN
# 4. giri₃ nin-ga₂
# #lem: ŋiri[foot]; PN
# 5. zi-ga šabra
# #lem: ziga[expenditure]; šabra[administrator]
# 6. iti u₅-bi₂{mušen}-gu₇
# #lem: itud[moon]; MN
# 1. mu a-ra₂ 2(diš)-kam-aš {d}nanna kar-zi-da
# #lem: mu[year]; ara[times]; n; DN; TN
# Hardcode label:  {'domesticated_animal': ['#lem: n; maš[goat]']}
#
#
# P102376
# 1. 4(diš) [...]
# #lem: n; AN
# 2. 1(diš) [...]
# #lem: n; AN
# 3. 1/3(diš) gu x x
# #lem: n; gu[cord]; u; u
# 4. 1(diš) sila₄
# #lem: n; sila[lamb]
# 5. šu-eš₁₈-dar dumu-lugal
# #lem: PN; FN
# 6. mu-kuₓ(DU) {d}šul-gi-si₂-im-tum
# #lem: mu.DU[delivery]; PN
# 1. a₂-bi₂-la-tum i₃#-dab₅
# #lem: PN; dab[seize]
# 2. iti ezem-{d}šul-gi
# #lem: itud[moon]; MN
# 3. mu si-mu-ru-um{ki} lu-lu-bu{ki#} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul
# #lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P102625
# 1. 2(u) la₂ 1(diš) ma-na siki tug₂ šar₃
# #lem: n; lal[small]; n; mana[unit]; siki[hair]; tug[textile]; šar[~cloth]
# 2. 2(u) la₂ 1(diš) ma-na siki tug₂ 3(diš)-kam us₂
# #lem: n; lal[small]; n; mana[unit]; siki[hair]; tug[textile]; n; us[side]
# 3. siki {d}šul-gi-si₂-im-tum
# #lem: siki[hair]; PN
# 4. e₂-gal-ta e₃-a#
# #lem: egal[palace]; e[leave]
# 5. i-di₃-er₃-ra
# #lem: PN
# 6. šu ba-an-ti
# #lem: šu[hand]; teŋ[approach]
# 1. iti ezem-mah
# #lem: itud[moon]; MN
# 2. mu ki-maš{ki} hu-ur₅-ti{ki} u₃#! ma-da-bi u₄ aš-a ba-hul
# #lem: mu[year]; GN; GN; u[and]; mada[land]; ud[sun]; X; hulu[bad]
# 1. i-di₃-er₃-ra
# #lem: PN
# 2. dub-sar
# #lem: dubsar[scribe]
# 3. dumu ku-da-šum
# #lem: dumu[child]; PN
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) la₂ 1(diš) ma-na siki tug₂ šar₃', '#lem: n; lal[small]; n; mana[unit]; siki[hair]; tug[textile]; šar[~cloth]', '2. 2(u) la₂ 1(diš) ma-na siki tug₂ 3(diš)-kam us₂', '#lem: n; lal[small]; n; mana[unit]; siki[hair]; tug[textile]; n; us[side]', '3. siki {d}šul-gi-si₂-im-tum', '#lem: siki[hair]; PN', '$ blank space', '4. e₂-gal-ta e₃-a#', '#lem: egal[palace]; e[leave]', '5. i-di₃-er₃-ra', '#lem: PN', '6. šu ba-an-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. iti ezem-mah', '#lem: itud[moon]; MN', '$ blank space', '2. mu ki-maš{ki} hu-ur₅-ti{ki} u₃#! ma-da-bi u₄ aš-a ba-hul', '#lem: mu[year]; GN; GN; u[and]; mada[land]; ud[sun]; X; hulu[bad]', '@seal 1', '1. i-di₃-er₃-ra', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ku-da-šum', '#lem: dumu[child]; PN']]}
#
#
# P103307
# 1. [...]
# #lem: AN
# 2. [...] 1(diš)
# #lem: AN; n
# 3. [...] x gub-ba [...]{ki}
# #lem: AN; u; gub[stand]; u
# 4. [...]-ta
# #lem: FN
# 5. [...]
# #lem: AN
# 1. [x] {d}šul-gi-[si]-im-ti
# #lem: u; PN
# 2. ki lu₂-uru₁₁{ki}-ta
# #lem: ki[place]; PN
# 3. iti a₂-ki-ti
# #lem: itud[moon]; akiti[festival]
# 4. {d}en-lil₂-la₂ i₃-dab₅
# #lem: PN; dab[seize]
# 5. šu+nigin 1(u) ab₂
# #lem: šuniŋin[total]; n; ab[cow]
# 6. šu+nigin 3(diš) gu₄
# #lem: šuniŋin[total]; n; gud[ox]
# 7. mu ur-bi₂-lum{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: šuniŋin[total]; n; ab[cow]']}
#
#
# P103540
# 1. 3(aš) še gur lugal
# #lem: n; še[barley]; gur[unit]; lugal[king]
# 2. kišib₃ ba-aq-ri
# #lem: kišib[seal]; PN
# 3. lu₂ {d}šul-gi-si₂-im-ti
# #lem: lu[person]; PN
# 4. ki im-ti-dam-ta
# #lem: ki[place]; PN
# 1. a-hu-wa-qar
# #lem: PN
# 2. šu ba-ti
# #lem: šu[hand]; teŋ[approach]
# 3. iti ki-siki-{d}nin-[a-zu]
# #lem: itud[moon]; MN
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) še gur lugal', '#lem: n; še[barley]; gur[unit]; lugal[king]', '2. kišib₃ ba-aq-ri', '#lem: kišib[seal]; PN', '3. lu₂ {d}šul-gi-si₂-im-ti', '#lem: lu[person]; PN', '4. ki im-ti-dam-ta', '#lem: ki[place]; PN', '@reverse', '1. a-hu-wa-qar', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '$ blank space', '3. iti ki-siki-{d}nin-[a-zu]', '#lem: itud[moon]; MN']]}
#
#
# P103726
# 1. 1(diš) gu₄ niga
# #lem: n; gud[ox]; niga[fattened]
# 2. 3(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 3. iti-ta u₄ 5(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 4. 1(diš) gu₄ niga
# #lem: n; gud[ox]; niga[fattened]
# 5. 1(diš) gu₄ u₂
# #lem: n; gud[ox]; u[grass]
# 6. ba-uš₂
# #lem: uš[die]
# 7. iti-ta u₄ 1(u) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 1. zi-ga ki kalam-he₂-na-gi-ta
# #lem: ziga[expenditure]; ki[place]; PN
# 2. e₂-gal-la ba-an-kuₓ(KWU147)
# #lem: egal[palace]; X
# 3. iti ezem-me-ki-gal₂
# #lem: itud[moon]; MN
# 4. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]']}
#
#
# P103797
# 1. 1(diš) tu{mušen}
# #lem: n; tum[dove]
# 2. lu₂ uru₁₁{ki}
# #lem: lu[person]; GN
# 3. 1(geš₂) la₂ 2(diš) tu-gur₄{mušen}
# #lem: n; lal[small]; n; tugur[dove]
# 4. te-ze₂-en₆-ma-ma
# #lem: PN
# 5. 2(diš) ir₇{mušen}
# #lem: n; irsaŋ[pigeon]
# 6. bar-bar-li₂-a
# #lem: PN
# 1. iti-ta u₄ 6(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 2. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti
# #lem: mu.DU[delivery]; PN
# 3. a₂-bi₂-li₂-a i₃-dab₅
# #lem: PN; dab[seize]
# 4. iti ki-siki-{d}nin-a-zu
# #lem: itud[moon]; MN
# 5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; e[house]; X; du[build]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) tu{mušen}', '#lem: n; tum[dove]', '2. lu₂ uru₁₁{ki}', '#lem: lu[person]; GN', '3. 1(geš₂) la₂ 2(diš) tu-gur₄{mušen}', '#lem: n; lal[small]; n; tugur[dove]', '4. te-ze₂-en₆-ma-ma', '#lem: PN', '5. 2(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '6. bar-bar-li₂-a', '#lem: PN', '@reverse', '1. iti-ta u₄ 6(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '2. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '3. a₂-bi₂-li₂-a i₃-dab₅', '#lem: PN; dab[seize]', '4. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]']]}
#
#
# P104807
# 1. 3(diš) [...]
# #lem: n; AN
# 2. 2(diš) šah₂-gur₄ munus-geš#-[gi x]
# #lem: n; X; munusŋešgi[performer]; u
# 3. 3(diš) šah₂-gur₄-nita₂-geš#-[gi x]
# #lem: n; X; u
# 4. 1(u) 4(diš) šah₂-šaganₓ(AMA){gan} [...]
# #lem: n; n; X; AN
# 5. 2(diš) šah₂-gur₄ munus-geš-gi u₂
# #lem: n; X; munusŋešgi[performer]; u[grass]
# 6. 2(u) 5(diš) šah₂-NE-gur₄-munus-geš-gi u₂
# #lem: n; n; X; u[grass]
# 7. 1(u) 2(diš) šah₂-nita₂-geš-gi u₂
# #lem: n; n; X; u[grass]
# 8. [...] 1(diš) šah₂-gur₄-nita₂-geš-gi u₂
# #lem: AN; n; X; u[grass]
# 9. 3(u) 4(diš) šah₂-NE-tur-nita₂-geš-gi
# #lem: n; n; X
# 1. 5(diš) šah₂-šaganₓ(AMA){gan} iri
# #lem: n; X; iri[city]
# 2. 5(diš) šah₂-nita₂ iri
# #lem: n; X; iri[city]
# 3. 3(diš) šah₂-NE-tur munus iri
# #lem: n; X; munus[woman]; iri[city]
# 4. 2(diš) šah₂-NE-tur-nita₂ iri
# #lem: n; X; iri[city]
# 5. 4(diš) u₅{mušen}
# #lem: n; u[goose]
# 6. 1(u) 4(diš) uz-tur
# #lem: n; n; PN
# 7. 1(diš) uz{mušen}
# #lem: n; uz[duck]
# 8. 1(u) 2(diš) ir₇{mušen}
# #lem: n; n; irsaŋ[pigeon]
# 9. 2(u) 1(diš) tu-gur₄{mušen}
# #lem: n; n; tugur[dove]
# 10. [...]
# #lem: AN
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(diš) [...]', '#lem: n; AN', '2. 2(diš) šah₂-gur₄ munus-geš#-[gi x]', '#lem: n; X; munusŋešgi[performer]; u', '3. 3(diš) šah₂-gur₄-nita₂-geš#-[gi x]', '#lem: n; X; u', '4. 1(u) 4(diš) šah₂-šaganₓ(AMA){gan} [...]', '#lem: n; n; X; AN', '5. 2(diš) šah₂-gur₄ munus-geš-gi u₂', '#lem: n; X; munusŋešgi[performer]; u[grass]', '6. 2(u) 5(diš) šah₂-NE-gur₄-munus-geš-gi u₂', '#lem: n; n; X; u[grass]', '7. 1(u) 2(diš) šah₂-nita₂-geš-gi u₂', '#lem: n; n; X; u[grass]', '8. [...] 1(diš) šah₂-gur₄-nita₂-geš-gi u₂', '#lem: AN; n; X; u[grass]', '9. 3(u) 4(diš) šah₂-NE-tur-nita₂-geš-gi', '#lem: n; n; X', '@reverse', '1. 5(diš) šah₂-šaganₓ(AMA){gan} iri', '#lem: n; X; iri[city]', '2. 5(diš) šah₂-nita₂ iri', '#lem: n; X; iri[city]', '3. 3(diš) šah₂-NE-tur munus iri', '#lem: n; X; munus[woman]; iri[city]', '4. 2(diš) šah₂-NE-tur-nita₂ iri', '#lem: n; X; iri[city]', '5. 4(diš) u₅{mušen}', '#lem: n; u[goose]', '6. 1(u) 4(diš) uz-tur', '#lem: n; n; PN', '7. 1(diš) uz{mušen}', '#lem: n; uz[duck]', '8. 1(u) 2(diš) ir₇{mušen}', '#lem: n; n; irsaŋ[pigeon]', '9. 2(u) 1(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '$ blank space', '10. [...]', '#lem: AN']]}
#
#
# P105808
# 1. 1(u) uz-tur
# #lem: n; PN
# 2. wa-at-ra-at
# #lem: PN
# 3. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 4. {d}šul-gi-si₂-im-ti
# #lem: PN
# 5. ša₃ uri₅{ki}-ma
# #lem: šag[heart]; GN
# 1. a₂-bi₂-li₂-a
# #lem: PN
# 2. i₃-dab₅
# #lem: dab[seize]
# 3. iti ezem-mah
# #lem: itud[moon]; MN
# 4. mu us₂-sa bad₃ ma-da ba-du₃
# #lem: mu[year]; us[follow]; bad[wall]; mada[land]; du[build]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) uz-tur', '#lem: n; PN', '2. wa-at-ra-at', '#lem: PN', '3. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '4. {d}šul-gi-si₂-im-ti', '#lem: PN', '5. ša₃ uri₅{ki}-ma', '#lem: šag[heart]; GN', '@reverse', '1. a₂-bi₂-li₂-a', '#lem: PN', '2. i₃-dab₅', '#lem: dab[seize]', '3. iti ezem-mah', '#lem: itud[moon]; MN', '4. mu us₂-sa bad₃ ma-da ba-du₃', '#lem: mu[year]; us[follow]; bad[wall]; mada[land]; du[build]']]}
#
#
# P105814
# 1. 5(diš) uz-tur
# #lem: n; PN
# 2. dam šar-ru-um-i₃-li₂
# #lem: dam[spouse]; PN
# 3. iti-ta u₄ 2(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 4. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 1. {d}šul-gi-si₂-im-ti
# #lem: PN
# 2. a₂-bi₂-la-tum i₃-dab₅
# #lem: PN; dab[seize]
# 3. iti ezem-me-ki-gal₂
# #lem: itud[moon]; MN
# 4. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul
# #lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) uz-tur', '#lem: n; PN', '2. dam šar-ru-um-i₃-li₂', '#lem: dam[spouse]; PN', '3. iti-ta u₄ 2(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. {d}šul-gi-si₂-im-ti', '#lem: PN', '2. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '3. iti ezem-me-ki-gal₂', '#lem: itud[moon]; MN', '4. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P105818
# 1. 1(u) 5(diš) {anše}kunga₂-nita₂
# #lem: n; n; X
# 2. 5(diš) {anše}kunga₂ munus
# #lem: n; kunga[equid]; munus[woman]
# 3. mu-kuₓ(DU) lugal-nir-gal₂
# #lem: mu.DU[delivery]; PN
# 4. ki na-ra-am-i₃-li₂-ta
# #lem: ki[place]; PN
# 1. lugal-an-na-ab-tum₂
# #lem: PN
# 2. i₃-dab₅
# #lem: dab[seize]
# 3. iti ezem-{d}šul-gi
# #lem: itud[moon]; MN
# 4. mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# #lem: mu[year]; GN; u[and]; GN; hulu[bad]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 5(diš) {anše}kunga₂-nita₂', '#lem: n; n; X', '2. 5(diš) {anše}kunga₂ munus', '#lem: n; kunga[equid]; munus[woman]', '3. mu-kuₓ(DU) lugal-nir-gal₂', '#lem: mu.DU[delivery]; PN', '4. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '@reverse', '1. lugal-an-na-ab-tum₂', '#lem: PN', '2. i₃-dab₅', '#lem: dab[seize]', '3. iti ezem-{d}šul-gi', '#lem: itud[moon]; MN', '4. mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul', '#lem: mu[year]; GN; u[and]; GN; hulu[bad]']]}
#
#
# P105825
# 1. 1(diš) gu₄
# #lem: n; gud[ox]
# 2. ša-da-zi lu₂ ur-bi₂-lum{ki}
# #lem: PN; lu[person]; GN
# 3. 7(diš) gu₄
# #lem: n; gud[ox]
# 4. 3(diš) ab₂
# #lem: n; ab[cow]
# 5. maš-da-re-a
# #lem: mašdarea[payment]
# 6. ma-da ur-bi₂-lum{ki}-ka
# #lem: mada[land]; GN
# 1. mu-kuₓ(DU) lugal
# #lem: mu.DU[delivery]; lugal[king]
# 2. be-li₂-a-zu i₃-dab₅
# #lem: PN; dab[seize]
# 3. ki na-ra-am-i₃-li₂
# #lem: ki[place]; PN
# 4. giri₃ lu₂-{d}nanna sagi
# #lem: ŋiri[foot]; PN; šagia[cup-bearer]
# 5. iti maš-da₃-gu₇
# #lem: itud[moon]; MN
# 6. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P105826
# 1. 3(diš) gu₄
# #lem: n; gud[ox]
# 2. ki na-sa₆-ta
# #lem: ki[place]; PN
# 3. {d}en-lil₂-la₂ i₃-dab₅
# #lem: PN; dab[seize]
# 4. gu₄ ab-ba-iri
# #lem: gud[ox]; PN
# 1. giri₃ AN-x-[(x)]
# #lem: ŋiri[foot]; u
# 2. iti ezem-me-ki-gal₂
# #lem: itud[moon]; MN
# 3. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P105828
# 1. 1(diš) gu₄ niga
# #lem: n; gud[ox]; niga[fattened]
# 2. 3(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 3. 5(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 4. 1(diš) maš₂-gal niga
# #lem: n; mašgal[goat]; niga[fattened]
# 1. 1(diš) {munus}aš₂-gar₃ niga
# #lem: n; ašgar[kid]; niga[fattened]
# 2. nir-i₃-da-gal₂
# #lem: PN
# 3. iti-ta u₄ 1(u) 5(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 4. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti
# #lem: mu.DU[delivery]; PN
# 5. {d}šul-gi-i₃-li₂ i₃-dab₅
# #lem: PN; dab[seize]
# 6. iti ezem-mah
# #lem: itud[moon]; MN
# 7. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]']}
#
#
# P105879
# 1. 1(diš) sila₄ {d}en-lil₂
# #lem: n; sila[lamb]; FN
# 2. 1(diš) sila₄ {d}nin-lil₂
# #lem: n; sila[lamb]; FN
# 3. mu-kuₓ(DU) ur-tilla₅ sanga
# #lem: mu.DU[delivery]; PN; FN
# 4. tu-ra-am-{d}da-gan maškim
# #lem: PN; maškim[administrator]
# 5. 1(diš) {munus}aš₂-gar₃ niga e₂-uz-ga
# #lem: n; ašgar[kid]; niga[fattened]; eʾuzga[building]
# 6. mu#-kuₓ(DU) i₃-lal₃-lum
# #lem: mu.DU[delivery]; PN
# 7. a#-a-kal-la maškim
# #lem: PN; maškim[administrator]
# 1. [u₄] 1(u) 4(diš)-kam
# #lem: ud[sun]; n; n
# 2. [ki] ab#-ba-sa₆-ga-ta ba-zi
# #lem: ki[place]; PN; PN
# 3. iti u₅-bi₂-gu₇
# #lem: itud[moon]; MN
# 4. mu us₂-sa [{d}]gu-za {d}en-lil₂-la₂ ba-dim₂
# #lem: mu[year]; us[follow]; ON; PN; dim[create]
# 1. 3(diš)
# #lem: n
# Hardcode label:  {'domesticated_animal': ['#lem: n; sila[lamb]; FN']}
#
#
# P105930
# 1. 2(diš) sila₄ 1(diš) maš₂-gal
# #lem: n; sila[lamb]; n; mašgal[goat]
# 2. u₄ 1(u) 5(diš)-kam
# #lem: ud[sun]; n; n
# 3. ki ab-ba-sa₆-ga-ta
# #lem: ki[place]; PN
# 4. in-ta-e₃-a
# #lem: PN
# 1. i₃-dab₅
# #lem: dab[seize]
# 2. iti še-sag₁₁-ku₅
# #lem: itud[moon]; MN
# 3. mu en-unu₆-gal {d}inanna ba-hun
# #lem: mu[year]; X; TN; huŋ[hire]
# 1. 3(diš)
# #lem: n
# Hardcode label:  {'domesticated_animal': ['#lem: n; sila[lamb]; n; mašgal[goat]']}
#
#
# P106116
# 1. 1(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 2. la₂-ia₃ su-ga
# #lem: laʾu[arrears]; sug[replace]
# 3. a₂-bi₂-la-tum
# #lem: PN
# 4. ur-{d}lugal-edin-ka i₃-dab₅
# #lem: PN; dab[seize]
# 1. iti a₂-ki-ti
# #lem: itud[moon]; akiti[festival]
# 2. mu us₂-sa ur-bi₂-lum{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
#
#
# P106141
# 1. 2(diš) udu
# #lem: n; udu[sheep]
# 2. ṣe-lu-uš-{d}da-gan
# #lem: X
# 3. 2(diš) sila₄
# #lem: n; sila[lamb]
# 4. te-ze₂-en₆-{d}ma!-ma!
# #lem: PN
# 5. 1(diš) maš₂ gub nita
# #lem: n; maš[goat]; gub[stand]; nita[male]
# 6. u₃-tu-da e₂-kurušda
# #lem: utuda[offspring]; X
# 1. 1(diš) udu 1(diš) maš₂
# #lem: n; udu[sheep]; n; maš[goat]
# 2. puzur₄-eš₁₈?-dar?
# #lem: X
# 3. 1(diš) sila₄
# #lem: n; sila[lamb]
# 4. ur-nigar
# #lem: PN
# 5. 1(diš) sila₄
# #lem: n; sila[lamb]
# 6. {d}nin-lil₂-he₂-em-ti
# #lem: PN
# 7. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 8. a₂-bi₂-la-tum i₃-dab₅
# #lem: PN; dab[seize]
# 9. iti maš-ku₃-gu₇
# #lem: itud[moon]; MN
# 1. mu a-ra₂ 3(diš)-kam-aš kar₂-har{ki} ba-hul
# #lem: mu[year]; ara[times]; n; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]']}
#
#
# P106143
# 1. 1(diš) udu gu₄-e-us₂-sa
# #lem: n; udu[sheep]; gudeʾusa[drover]
# 2. {d}inanna
# #lem: TN
# 3. 1(diš) maš₂-gal u₂
# #lem: n; mašgal[goat]; u[grass]
# 4. {d}mes-lam-ta-e₃-a
# #lem: DN
# 5. 1(diš) maš₂ {d}na-na-a
# #lem: n; maš[goat]; DN
# 6. iti-ta u₄ 1(u) la₂ 1(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; lal[small]; n; zal[pass]
# 7. 1(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 8. {d}inanna unu{ki}-ga
# #lem: TN; GN
# 1. 1(diš) maš₂-gal u₂
# #lem: n; mašgal[goat]; u[grass]
# 2. {d}inanna nibru{ki}
# #lem: TN; GN
# 3. iti-ta u₄ 1(u) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 4. giri₃ a-a-{d}nanna-ar-kal-la
# #lem: ŋiri[foot]; PN
# 5. zi-ga ki kalam-he₂-na-gi-ta
# #lem: ziga[expenditure]; ki[place]; PN
# 6. iti ezem-mah
# #lem: itud[moon]; MN
# 7. mu us₂-sa ki-maš{ki} [hu]-ur₅-ti{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; gudeʾusa[drover]']}
#
#
# P106153
# 1. 2(diš) sila₄
# #lem: n; sila[lamb]
# 2. dumu-munus a-ba-{d}en-lil₂-gin₇
# #lem: dumumunus[daughter]; PN
# 3. 1(diš) sila₄
# #lem: n; sila[lamb]
# 4. e-te-<al>-pu₃-{d}da-gan
# #lem: PN
# 1. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 2. {d}šul-gi-si₂-im-tum
# #lem: PN
# 3. be-li₂-du₁₀ i₃-dab₅
# #lem: PN; dab[seize]
# 4. iti maš-ku₃-gu₇
# #lem: itud[moon]; MN
# 5. mu us₂-sa an-ša-an{ki} ba-hul mu us₂-sa-bi
# #lem: mu[year]; us[follow]; GN; hulu[bad]; mu[year]; us[follow]
# Hardcode label:  {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P106164
# 1. 1(diš) šah₂-NE-tur munus geš-gi gaba
# #lem: n; X; munus[woman]; gi[thicket]; gaba[chest]
# 2. 1(diš) šah₂-NE-tur munus geš-gi
# #lem: n; X; munus[woman]; gi[thicket]
# 3. 1(diš) šah₂-NE-tur-nita₂ geš-gi
# #lem: n; X; gi[thicket]
# 1. me-{d}eš₁₈?-dar?-še₃
# #lem: PN
# 2. iti-ta u₄ 2(u) 3(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 3. zi-ga a₂-bi₂-la-tum
# #lem: ziga[expenditure]; PN
# 4. iti ezem-me-ki-gal₂
# #lem: itud[moon]; MN
# 5. mu ša-aš-ru{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur munus geš-gi gaba', '#lem: n; X; munus[woman]; gi[thicket]; gaba[chest]', '2. 1(diš) šah₂-NE-tur munus geš-gi', '#lem: n; X; munus[woman]; gi[thicket]', '3. 1(diš) šah₂-NE-tur-nita₂ geš-gi', '#lem: n; X; gi[thicket]', '@reverse', '1. me-{d}eš₁₈?-dar?-še₃', '#lem: PN', '2. iti-ta u₄ 2(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '3. zi-ga a₂-bi₂-la-tum', '#lem: ziga[expenditure]; PN', '4. iti ezem-me-ki-gal₂', '#lem: itud[moon]; MN', '5. mu ša-aš-ru{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P106166
# 1. 2(diš) udu u₂ 1(diš) maš₂
# #lem: n; udu[sheep]; u[grass]; n; maš[goat]
# 2. nin-u₃-ma
# #lem: PN
# 3. 1(diš) udu u₂ 1(diš) maš₂
# #lem: n; udu[sheep]; u[grass]; n; maš[goat]
# 4. dumu-munus ki-ni-a ša₃-zu
# #lem: dumumunus[daughter]; ki[place]; DN
# 5. 1(diš) maš₂
# #lem: n; maš[goat]
# 6. e₂-a-ba-ni
# #lem: PN
# 7. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 1. šu-ku₈-bu-um i₃-dab₅
# #lem: PN; dab[seize]
# 2. iti a₂-ki-ti
# #lem: itud[moon]; akiti[festival]
# 3. mu a-ra₂ 2(diš)-kam kar₂-har{ki} ba-hul
# #lem: mu[year]; ara[times]; n; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]; n; maš[goat]']}
#
#
# P106169
# 1. 1(u) 4(diš) uz-tur
# #lem: n; n; PN
# 2. la₂-ia₃ su-ga i-bi₂-{d}suen mu ha-li₂-li₂-še₃
# #lem: laʾu[arrears]; sug[replace]; PN; mu[year]; PN
# 3. iti-ta u₄ 1(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 4. 1(u) la₂ 1(diš) ir₇{mušen}
# #lem: n; lal[small]; n; irsaŋ[pigeon]
# 5. 2(diš) tu-gur₄{mušen}
# #lem: n; tugur[dove]
# 1. {d}nin-lil₂-he₂-em-ti
# #lem: PN
# 2. iti-ta u₄ 5(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 3. mu-kuₓ(DU) {d}šul-gi-si₂-im-tum-ma
# #lem: mu.DU[delivery]; PN
# 4. a₂-bi₂-li₂-a i₃-dab₅
# #lem: PN; dab[seize]
# 5. iti a₂-ki-ti
# #lem: itud[moon]; akiti[festival]
# 6. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; us[follow]; e[house]; X; du[build]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 4(diš) uz-tur', '#lem: n; n; PN', '2. la₂-ia₃ su-ga i-bi₂-{d}suen mu ha-li₂-li₂-še₃', '#lem: laʾu[arrears]; sug[replace]; PN; mu[year]; PN', '3. iti-ta u₄ 1(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '4. 1(u) la₂ 1(diš) ir₇{mušen}', '#lem: n; lal[small]; n; irsaŋ[pigeon]', '5. 2(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '@reverse', '1. {d}nin-lil₂-he₂-em-ti', '#lem: PN', '2. iti-ta u₄ 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '3. mu-kuₓ(DU) {d}šul-gi-si₂-im-tum-ma', '#lem: mu.DU[delivery]; PN', '4. a₂-bi₂-li₂-a i₃-dab₅', '#lem: PN; dab[seize]', '5. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '6. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; us[follow]; e[house]; X; du[build]']]}
#
#
# P106172
# 1. 1(diš) šah₂-NE-tur munus geš-gi
# #lem: n; X; munus[woman]; gi[thicket]
# 2. 2(diš) tu-gur₄{mušen}
# #lem: n; tugur[dove]
# 3. iti-ta u₄ 2(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 4. 1(diš) uz-tur
# #lem: n; PN
# 5. 1(diš) ir₇{mušen}
# #lem: n; irsaŋ[pigeon]
# 6. iti-ta u₄ 3(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 7. ba-uš₂ e₂-gal-la ba-an-kuₓ(KWU147)
# #lem: uš[die]; egal[palace]; X
# 8. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 9. siskur₂ {d}al-la-tum
# #lem: siškur[prayer]; DN
# 10. 1(diš) udu gu₄-e-us₂-sa
# #lem: n; udu[sheep]; gudeʾusa[drover]
# 1. siskur₂ {d}i₇-lu₂-ru-gu₂-[ka]
# #lem: siškur[prayer]; DN
# 2. iti-ta u₄ 5(diš)? ba-[ra-zal]
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 3. 1(diš) tu-gur₄[{mušen}]
# #lem: n; tugur[dove]
# 4. iti-ta u₄ 6(diš) [ba-ra-zal]
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 5. ba-uš₂ e₂-gal-[la ba-an-kuₓ(KWU147)]
# #lem: uš[die]; egal[palace]; X
# 6. zi-ga x-[...]-tum
# #lem: ziga[expenditure]; u
# 7. iti u₅-bi₂-gu₇
# #lem: itud[moon]; MN
# 8. mu us₂-sa si-[mu-ru]-um{ki} lu-lu-bu-um{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul
# #lem: mu[year]; us[follow]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]
# Hardcode label:  {'dead_animal': ['#lem: uš[die]; egal[palace]; X']}
#
#
# P106216
# 1. 1(diš) {munus}aš₂-gar₃
# #lem: n; ašgar[kid]
# 2. da igi-{d}en-lil₂
# #lem: dag[side]; PN
# 3. 4(diš) udu u₂ 1(diš) sila₄
# #lem: n; udu[sheep]; u[grass]; n; sila[lamb]
# 4. dam ba-ni-lum
# #lem: dam[spouse]; PN
# 5. 1(diš) sila₄ i-su₂-a-ri-ik
# #lem: n; sila[lamb]; X
# 1. 1(diš) sila₄ en {d}inanna
# #lem: n; sila[lamb]; en[priest]; TN
# 2. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti
# #lem: mu.DU[delivery]; PN
# 3. be-li₂-du₁₀ i₃-dab₅
# #lem: PN; dab[seize]
# 4. iti ses-da-gu₇
# #lem: itud[moon]; MN
# 5. mu bad₃ ma-da ba-du₃-a
# #lem: mu[year]; bad[wall]; mada[land]; du[go]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]; n; sila[lamb]']}
#
#
# P106292
# 1. 4(diš) udu 2(diš) u₈
# #lem: n; udu[sheep]; n; u[ewe]
# 2. iti ezem-mah
# #lem: itud[moon]; MN
# 3. 1(diš) udu 3(diš) u₈
# #lem: n; udu[sheep]; n; u[ewe]
# 4. iti ezem-an-na
# #lem: itud[moon]; MN
# 5. 2(diš) udu 1(diš) u₈
# #lem: n; udu[sheep]; n; u[ewe]
# 6. 2(diš) maš₂ 1(diš) sila₄
# #lem: n; maš[goat]; n; sila[lamb]
# 7. iti ezem-me-ki-gal₂
# #lem: itud[moon]; MN
# 8. 2(diš) udu 1(diš) u₈
# #lem: n; udu[sheep]; n; u[ewe]
# 1. 3(diš) maš₂
# #lem: n; maš[goat]
# 2. iti še-sag₁₁-ku₅
# #lem: itud[moon]; MN
# 3. sa₂-du₁₁ {d}be-la-at-suh-ner
# #lem: sadug[offerings]; PN
# 4. {d}be-la-at-dar-ra-ba-an
# #lem: PN
# 5. an-nu-ni-tum
# #lem: PN
# 6. u₃ {d}ul?-ma-<ši>-tum
# #lem: u[and]; DN
# 7. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; us[follow]; e[house]; X; du[build]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; n; u[ewe]']}
#
#
# P106293
# 1. 1(diš) uz-tur
# #lem: n; PN
# 2. mušen-du₃-ne
# #lem: mušendu[bird-catcher]
# 3. iti-ta u₄ 1(u) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 4. 1(diš) uz-tur
# #lem: n; PN
# 5. 1(diš) uz babbar₂
# #lem: n; uz[duck]; babbar[white]
# 6. te-ze₂-en₆-ma-ti
# #lem: PN
# 1. 1(diš) uz babbar₂
# #lem: n; uz[duck]; babbar[white]
# 2. {d}suen-na-da
# #lem: DN
# 3. iti-ta u₄ 2(u) la₂ 1(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; lal[small]; n; zal[pass]
# 4. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 5. {d}šul-gi-si₂-im-ti
# #lem: PN
# 6. a₂-bi₂-li₂-a i₃-dab₅
# #lem: PN; dab[seize]
# 7. iti ezem-mah
# #lem: itud[moon]; MN
# 8. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; us[follow]; e[house]; X; du[build]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) uz-tur', '#lem: n; PN', '2. mušen-du₃-ne', '#lem: mušendu[bird-catcher]', '3. iti-ta u₄ 1(u) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '4. 1(diš) uz-tur', '#lem: n; PN', '5. 1(diš) uz babbar₂', '#lem: n; uz[duck]; babbar[white]', '6. te-ze₂-en₆-ma-ti', '#lem: PN', '@reverse', '1. 1(diš) uz babbar₂', '#lem: n; uz[duck]; babbar[white]', '2. {d}suen-na-da', '#lem: DN', '3. iti-ta u₄ 2(u) la₂ 1(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; lal[small]; n; zal[pass]', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '5. {d}šul-gi-si₂-im-ti', '#lem: PN', '6. a₂-bi₂-li₂-a i₃-dab₅', '#lem: PN; dab[seize]', '7. iti ezem-mah', '#lem: itud[moon]; MN', '8. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; us[follow]; e[house]; X; du[build]']]}
#
#
# P106860
# 1. 1(diš) sila₄
# #lem: n; sila[lamb]
# 2. ka₂ eš₃
# #lem: kan[gate]; eš[shrine]
# 3. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 4. 1(diš) sila₄
# #lem: n; sila[lamb]
# 5. ka₂ ge₆-par₄-ra
# #lem: kan[gate]; ŋipar[cloister]
# 6. 1(diš) sila₄
# #lem: n; sila[lamb]
# 7. {d}na-na-a
# #lem: DN
# 1. a-ra₂ 1(diš)-kam
# #lem: ara[times]; n
# 2. 1(diš) sila₄ ka₂ ge₆-par₄-ra
# #lem: n; sila[lamb]; kan[gate]; ŋipar[cloister]
# 3. a-ra₂ 2(diš)-kam
# #lem: ara[times]; n
# 4. iti-ta u₄ 1(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 5. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 6. 1(diš) sila₄ ka₂ ge₆-par₄-ra
# #lem: n; sila[lamb]; kan[gate]; ŋipar[cloister]
# 7. a-ra₂ 3(diš)-kam
# #lem: ara[times]; n
# 8. iti-ta u₄ 2(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 9. zi-ga ur-{d}lugal-edin#-ka
# #lem: ziga[expenditure]; PN
# 10. ša₃ unu{ki}-ga
# #lem: šag[heart]; GN
# 11. iti maš-da₃-gu₇
# #lem: itud[moon]; MN
# 1. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P107553
# 1. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 2. {d}ul-ma-si-tum#
# #lem: DN
# 3. 3(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 4. siskur₂ an-nu-ni-tum
# #lem: siškur[prayer]; PN
# 5. u₄ e-ru-ba-tum dingir gu₄-gu₄-ka
# #lem: ud[sun]; erubatum[festival]; diŋir[deity]; gud[ox]
# 6. zi-ga a-hi-ma kurušda
# #lem: ziga[expenditure]; PN; kurušda[fattener]
# 1. giri₃ a₂-bi₂-li₂-a
# #lem: ŋiri[foot]; PN
# 2. iti ezem-{d}nin-a-zu
# #lem: itud[moon]; MN
# 3. mu {d}nanna kar-zi-da e₂-a-na ba-an-ku₄?
# #lem: mu[year]; DN; TN; e[house]; X
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P107554
# 1. 1(diš) gu₄
# #lem: n; gud[ox]
# 2. 9(diš) udu u₂ 1(diš) maš₂
# #lem: n; udu[sheep]; u[grass]; n; maš[goat]
# 3. hu-ba-a šagina
# #lem: PN; šakkanak[general]
# 4. 1(diš) maš₂
# #lem: n; maš[goat]
# 5. dam al-la
# #lem: dam[spouse]; PN
# 6. 1(diš) maš₂
# #lem: n; maš[goat]
# 7. dam ur-nigar{gar}
# #lem: dam[spouse]; PN
# 1. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 2. {d}šul-gi-si₂-im-tum
# #lem: PN
# 3. be-li₂-du₁₀ i₃-dab₅
# #lem: PN; dab[seize]
# 4. iti ezem-{d}nin-a-zu
# #lem: itud[moon]; MN
# 5. mu us₂-sa a-ra₂ 3(diš)-kam si-mu-ru-um{ki} ba-hul
# #lem: mu[year]; us[follow]; ara[times]; n; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P107555
# 1. 1(diš) gu₄
# #lem: n; gud[ox]
# 2. 5(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 3. igi-kar₂ dam sukkal-mah
# #lem: PN; dam[spouse]; sukkalmah[official]
# 4. 2(diš) {munus}aš₂-gar₃ niga
# #lem: n; ašgar[kid]; niga[fattened]
# 5. ma₂ an-na-še₃
# #lem: ma[ship]; DN
# 1. zi-ga
# #lem: ziga[expenditure]
# 2. be-li₂-du₁₀
# #lem: PN
# 3. iti ezem-me-ki-gal₂
# #lem: itud[moon]; MN
# 4. mu us₂-sa an-ša-an{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P107556
# 1. 2(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 2. 1(diš) sila₄ niga
# #lem: n; sila[lamb]; niga[fattened]
# 3. mu dam dan-ni-a-še₃
# #lem: mu[year]; dam[spouse]; X
# 4. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 5. siskur₂ {d}al-la-tum
# #lem: siškur[prayer]; DN
# 6. 1(diš) udu niga 1(diš) maš₂
# #lem: n; udu[sheep]; niga[fattened]; n; maš[goat]
# 7. e₂ {d}al-la-gu-la
# #lem: e[house]; TN
# 8. 2(diš) udu niga 1(diš) sila₄
# #lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]
# 9. e₂ {d}nin-lil₂-la₂
# #lem: e[house]; DN
# 1. 1(diš) udu niga 1(diš) maš₂
# #lem: n; udu[sheep]; niga[fattened]; n; maš[goat]
# 2. e₂ {d}en-lil₂-la₂
# #lem: e[house]; PN
# 3. 1(diš) udu gu₄-e-us₂-sa
# #lem: n; udu[sheep]; gudeʾusa[drover]
# 4. e₂ {d}nin-e₂-gi₄-a
# #lem: e[house]; DN
# 5. eš₃-eš₃ e₂-u₄-7(diš) ša₃ nibru{ki}
# #lem: ešeš[festival]; X; šag[heart]; GN
# 6. giri₃ nin-ga₂
# #lem: ŋiri[foot]; PN
# 7. zi-ga be-li₂-du₁₀ kurušda
# #lem: ziga[expenditure]; PN; kurušda[fattener]
# 8. iti ezem-{d}nin-a-zu
# #lem: itud[moon]; MN
# 9. mu bad₃ ma-da ba-du₃
# #lem: mu[year]; bad[wall]; mada[land]; du[build]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sadug[offerings]']}
#
#
# P107557
# 1. 1(diš) ad₇ sila₄
# #lem: n; X; sila[lamb]
# 2. mu geme₂ uš-bar-e-ne-še₃
# #lem: mu[year]; geme[worker]; ušbar[weaver]
# 3. 1(diš) ad₇ sila₄
# #lem: n; X; sila[lamb]
# 4. mu geme₂ uš-bar-e-ne-še₃
# #lem: mu[year]; geme[worker]; ušbar[weaver]
# 5. kiš{ki}-še₃
# #lem: GN
# 1. ugula gu₃-zi-de₂-a
# #lem: ugula[overseer]; PN
# 2. 1(diš) sila₄ še nig₂-gu₇ nin-ga₂-še₃
# #lem: n; sila[lamb]; še[barley]; niŋgu[food]; nin[lady]
# 3. zi-ga a₂-bi₂-li₂-a
# #lem: ziga[expenditure]; PN
# 4. iti u₅-bi₂-gu₇
# #lem: itud[moon]; MN
# 5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; e[house]; X; du[build]
# Hardcode label:  {'domesticated_animal': ['#lem: n; X; sila[lamb]']}
#
#
# P107558
# 1. 3(diš) udu u₂ 1(diš) sila₄
# #lem: n; udu[sheep]; u[grass]; n; sila[lamb]
# 2. i-mi-{d}suen
# #lem: PN
# 3. 2(diš) udu u₂ 1(diš) maš₂
# #lem: n; udu[sheep]; u[grass]; n; maš[goat]
# 4. gur₁₁-ra-a
# #lem: X
# 5. 1(diš) {munus}aš₂-gar₃
# #lem: n; ašgar[kid]
# 6. lu₂ uru₁₁{ki}
# #lem: lu[person]; GN
# 1. 1(diš) sila₄ ma-da-ti
# #lem: n; sila[lamb]; X
# 2. 1(diš) maš₂ dam [...]-da-[...]
# #lem: n; maš[goat]; dam[spouse]; u
# 3. mu-kuₓ(DU) {d}šul-gi-si₂-im-tum
# #lem: mu.DU[delivery]; PN
# 4. a₂-bi₂-li₂-a i₃-dab₅
# #lem: PN; dab[seize]
# 5. iti ki-siki-{d}nin-[a]-zu
# #lem: itud[moon]; MN
# 6. mu e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; e[house]; X; du[build]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]; n; sila[lamb]']}
#
#
# P107559
# 1. 2(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 2. 1(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 3. siskur₂ sag u₄-sakar
# #lem: siškur[prayer]; saŋ[head]; usakar[moon]
# 4. ša₃ unu{ki}-ga
# #lem: šag[heart]; GN
# 1. giri₃ {d}šul-gi-{d}utu-igi-mu
# #lem: ŋiri[foot]; PN
# 2. iti-ta u₄ 3(u) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 3. zi-ga a₂-bi₂-li₂-a
# #lem: ziga[expenditure]; PN
# 4. iti a₂-ki-ti
# #lem: itud[moon]; akiti[festival]
# 5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; e[house]; X; du[build]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P107560
# 1. 6(diš) uz-tur
# #lem: n; PN
# 2. ur-{d}šul-gi-ra
# #lem: PN
# 3. iti-ta u₄ 2(u) 5(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 4. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 5. {d}šul-gi-si₂-im-tum-ma
# #lem: PN
# 1. a₂-bi₂-li₂-a
# #lem: PN
# 2. i₃-dab₅
# #lem: dab[seize]
# 3. iti šu-eš-ša
# #lem: itud[moon]; MN
# 4. mu e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; e[house]; X; du[build]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(diš) uz-tur', '#lem: n; PN', '2. ur-{d}šul-gi-ra', '#lem: PN', '3. iti-ta u₄ 2(u) 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '5. {d}šul-gi-si₂-im-tum-ma', '#lem: PN', '@reverse', '1. a₂-bi₂-li₂-a', '#lem: PN', '2. i₃-dab₅', '#lem: dab[seize]', '3. iti šu-eš-ša', '#lem: itud[moon]; MN', '4. mu e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]']]}
#
#
# P107561
# 1. 2(diš) udu 1(diš) maš₂
# #lem: n; udu[sheep]; n; maš[goat]
# 2. dam dan-ni-a
# #lem: dam[spouse]; PN
# 3. 1(diš) maš₂
# #lem: n; maš[goat]
# 4. i-zu-a-ri₂-ik ensi₂
# #lem: PN; ensik[ruler]
# 5. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 1. {d}šul-gi-si₂-im-tum-ma
# #lem: PN
# 2. a₂-bi₂-li₂-a
# #lem: PN
# 3. i₃-dab₅
# #lem: dab[seize]
# 4. iti šu-eš-ša
# #lem: itud[moon]; MN
# 5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; e[house]; X; du[build]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; n; maš[goat]']}
#
#
# P107562
# 1. 1(diš) šah₂-NE-tur geš-gi ba-uš₂
# #lem: n; X; gi[thicket]; uš[die]
# 2. geme₂ uš-bar-e-ne
# #lem: geme[worker]; ušbar[weaver]
# 3. šu ba-ti-eš
# #lem: šu[hand]; teŋ[approach]
# 1. iti-ta u₄ 2(u) 2(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 2. zi-ga
# #lem: ziga[expenditure]
# 3. a₂-bi₂-li₂-a
# #lem: PN
# 4. iti ses-da-gu₇
# #lem: itud[moon]; MN
# 5. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; us[follow]; e[house]; X; du[build]
# Hardcode label:  {'dead_animal': ['#lem: n; X; gi[thicket]; uš[die]']}
#
#
# P107563
# 1. 3(diš) uz-tur
# #lem: n; PN
# 2. e₂-gi₄-a inim-{d}šara₂
# #lem: egia[bride]; PN
# 3. iti-ta# u₄ 2(u) 9(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 4. 2(diš) [...] uz-tur
# #lem: n; AN; PN
# 1. {d}nin-lil₂-tum-im-ti
# #lem: PN
# 2. iti-ta u₄ 3(u) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 3. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 4. a₂-bi₂-li₂-a
# #lem: PN
# 5. i₃-dab₅
# #lem: dab[seize]
# 6. iti šu-eš-ša
# #lem: itud[moon]; MN
# 7. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; us[follow]; e[house]; X; du[build]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(diš) uz-tur', '#lem: n; PN', '2. e₂-gi₄-a inim-{d}šara₂', '#lem: egia[bride]; PN', '3. iti-ta# u₄ 2(u) 9(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. 2(diš) [...] uz-tur', '#lem: n; AN; PN', '@reverse', '1. {d}nin-lil₂-tum-im-ti', '#lem: PN', '2. iti-ta u₄ 3(u) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '3. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '4. a₂-bi₂-li₂-a', '#lem: PN', '5. i₃-dab₅', '#lem: dab[seize]', '6. iti šu-eš-ša', '#lem: itud[moon]; MN', '7. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; us[follow]; e[house]; X; du[build]']]}
#
#
# P107564
# 1. 1(diš) udu# [...]
# #lem: n; udu[sheep]; AN
# 2. nig₂-ki-zah₃ {d}iškur
# #lem: X; DN
# 3. ma-šum maškim
# #lem: PN; maškim[administrator]
# 4. 1(diš) sila₄ ba-uš₂
# #lem: n; sila[lamb]; uš[die]
# 5. e₂-gal-la ba-an-ku₄?
# #lem: egal[palace]; X
# 6. 5(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 7. ma-ma-a
# #lem: PN
# 1. 1(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 2. siskur₂ {d}al-la-tum
# #lem: siškur[prayer]; DN
# 3. ša₃ uri₅{ki}-ma
# #lem: šag[heart]; GN
# 4. giri₃ a₂-bi₂-li₂-a
# #lem: ŋiri[foot]; PN
# 5. zi-ga a₂-bi₂-li₂-a
# #lem: ziga[expenditure]; PN
# 6. iti maš-da₃-gu₇
# #lem: itud[moon]; MN
# 7. mu us₂-sa e₂ puzur₄#-iš-{d}[da-gan ba-du₃ mu us₂-sa-bi]
# #lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; AN']}
#
#
# P107641
# 1. la₂-ia₃ 1(diš) gu₄
# #lem: laʾu[arrears]; n; gud[ox]
# 2. la₂-ia₃ 4(u) 1(diš) ir₇{mušen}
# #lem: laʾu[arrears]; n; n; irsaŋ[pigeon]
# 3. [la₂]-ia₃ 5(u) 3(diš) tu-gur₄{mušen}
# #lem: laʾu[arrears]; n; n; tugur[dove]
# 4. a₂-bi₂-la-tum# kurušda
# #lem: PN; kurušda[fattener]
# 1. in-da-gal₂
# #lem: ŋal[be]
# 2. kišib₃-ta tur-ra
# #lem: kišib[seal]; tur[small]
# 3. iti šu-eš-ša
# #lem: itud[moon]; MN
# 4. mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# #lem: mu[year]; GN; u[and]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: laʾu[arrears]; n; gud[ox]']}
#
#
# P107651
# 1. 1(diš) gu₄
# #lem: n; gud[ox]
# 2. 4(u) udu
# #lem: n; udu[sheep]
# 3. 2(u) la₂ [x] maš₂
# #lem: n; lal[small]; u; maš[goat]
# 4. 1(u) 4(diš) {munus}aš₂-gar₃
# #lem: n; n; ašgar[kid]
# 5. ug₇-ug₇-ga-am₃
# #lem: ug[die]
# 1. e₂-gal-la ba-an-ku₄?
# #lem: egal[palace]; X
# 2. zi-ga ur-{d}lugal-edin-ka
# #lem: ziga[expenditure]; PN
# 3. iti ezem-an-na
# #lem: itud[moon]; MN
# 4. mu ki-maš{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P107669
# 1. 1(diš) sila₄
# #lem: n; sila[lamb]
# 2. ka₂ ge₆-par₄-ra
# #lem: kan[gate]; ŋipar[cloister]
# 3. zi-ga ur-{d}lugal-edin-ka
# #lem: ziga[expenditure]; PN
# 4. ša₃ unu{ki}-ga
# #lem: šag[heart]; GN
# 1. iti maš-da₃-gu₇
# #lem: itud[moon]; MN
# 2. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P107671
# 1. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 2. 1(diš) maš₂
# #lem: n; maš[goat]
# 3. ka₂ eš₃
# #lem: kan[gate]; eš[shrine]
# 4. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 5. ka₂ ge₆-par₄-ra
# #lem: kan[gate]; ŋipar[cloister]
# 1. 1(diš) udu niga gu₄-e-us₂-sa
# #lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]
# 2. {d}na-na-a
# #lem: DN
# 3. iti-ta u₄ 1(u) 3(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 4. zi-ga ur-{d}lugal-edin-ka
# #lem: ziga[expenditure]; PN
# 5. iti maš-da₃-gu₇
# #lem: itud[moon]; MN
# 6. mu us₂-sa ki-maš{ki} u₃ hu-ur-ti{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; u[and]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P107677
# 1. 2(diš) gu₄
# #lem: n; gud[ox]
# 2. 2(diš) udu niga gu₄-e-[us₂-sa]
# #lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]
# 3. 2(diš) sila₄ niga
# #lem: n; sila[lamb]; niga[fattened]
# 4. 9(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 5. 1(diš) {munus}aš₂-gar₃
# #lem: n; ašgar[kid]
# 1. 9(diš) maš₂-gal
# #lem: n; mašgal[goat]
# 2. 1(diš) maš-da₃
# #lem: n; mašda[gazelle]
# 3. ri-ri-ga-am₃#
# #lem: deg[collect]
# 4. e₂-gal-la ba-an#-[ku₄?]
# #lem: egal[palace]; X
# 5. iti-ta u₄ 1(u) 6(diš)-kam
# #lem: itud[moon]; ud[sun]; n; n
# 6. zi-ga ur-{d}lugal-edin-ka
# #lem: ziga[expenditure]; PN
# 7. iti ses-da-gu₇
# #lem: itud[moon]; MN
# 8. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P107679
# 1. x udu niga sa₂-du₁₁
# #lem: u; udu[sheep]; niga[fattened]; sadug[offerings]
# 2. 1(diš) sila₄
# #lem: n; sila[lamb]
# 3. ka eš₃
# #lem: kag[mouth]; eš[shrine]
# 4. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 5. ka ge₆-par₄-ra
# #lem: kag[mouth]; ŋipar[cloister]
# 6. 1(diš) sila₄
# #lem: n; sila[lamb]
# 1. {d}na-na-a
# #lem: DN
# 2. iti-ta u₄ 7(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 3. zi-ga ur-{d}lugal-edin-ka
# #lem: ziga[expenditure]; PN
# 4. ša₃ unu{ki}
# #lem: šag[heart]; GN
# 5. iti u₅-bi₂-gu₇
# #lem: itud[moon]; MN
# 6. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: u; udu[sheep]; niga[fattened]; sadug[offerings]']}
#
#
# P107682
# 1. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 2. nig₂-gu₇ nin-ga₂-še₃
# #lem: niŋgu[food]; nin[lady]
# 3. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 4. gi-ra-num₂! {d}inanna
# #lem: giranum[wailing]; TN
# 5. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 6. 1(diš) maš₂-gal niga
# #lem: n; mašgal[goat]; niga[fattened]
# 7. {d}be-la-at-suh-ner
# #lem: PN
# 8. u₃ {d}be-la-at-dar-ra-ba-an
# #lem: u[and]; PN
# 9. [...]
# #lem: AN
# 1. [...]
# #lem: AN
# 2. 1(diš) sila₄
# #lem: n; sila[lamb]
# 3. siskur₂ u₄ 1(u) 5(diš)-kam
# #lem: siškur[prayer]; ud[sun]; n; n
# 4. giri₃ ARAD₂-zu-ni
# #lem: ŋiri[foot]; arad[slave]
# 5. 1(diš) udu niga gu₄-e-us₂-sa
# #lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]
# 6. ba-uš₂ e₂-gal-la ba-an-ku₄?
# #lem: uš[die]; egal[palace]; X
# 7. iti-ta u₄ 1(u) 4(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 8. zi-ga ur-{d}lugal-edin-ka
# #lem: ziga[expenditure]; PN
# 9. iti ki-siki-{d}nin-a-zu
# #lem: itud[moon]; MN
# 10. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sadug[offerings]']}
#
#
# P107685
# 1. 5(diš) uz-tur
# #lem: n; PN
# 2. ba-uš₂ e₂-gal-la ba-an-ku₄?
# #lem: uš[die]; egal[palace]; X
# 3. iti-ta u₄ 2(u) 8(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 1. zi-ga
# #lem: ziga[expenditure]
# 2. ur-{d}lugal-edin-<ka>
# #lem: PN
# 3. iti ki-siki-{d}nin-a-zu
# #lem: itud[moon]; MN
# 4. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'dead_animal': ['#lem: uš[die]; egal[palace]; X']}
#
#
# P107696
# 1. 1(u) uz-tur
# #lem: n; PN
# 2. dam a₂-bi₂-li₂
# #lem: dam[spouse]; PN
# 3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 4. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 5. {d}šul-gi-si₂-im-tum
# #lem: PN
# 1. {d}šul-gi-i₃-li₂ i₃-dab₅
# #lem: PN; dab[seize]
# 2. iti ezem-mah
# #lem: itud[moon]; MN
# 3. mu us₂-sa ki-maš{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p002', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) uz-tur', '#lem: n; PN', '2. dam a₂-bi₂-li₂', '#lem: dam[spouse]; PN', '3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '5. {d}šul-gi-si₂-im-tum', '#lem: PN', '@reverse', '1. {d}šul-gi-i₃-li₂ i₃-dab₅', '#lem: PN; dab[seize]', '2. iti ezem-mah', '#lem: itud[moon]; MN', '3. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P107982
# 1. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 2. gi-ra-num₂ {d}inanna
# #lem: giranum[wailing]; TN
# 3. 1(diš) maš₂ {d}nin-sun₂
# #lem: n; maš[goat]; FN
# 4. 1(diš) sila₄ nig₂-ki-zah₃ ša₃ e₂-gal
# #lem: n; sila[lamb]; X; šag[heart]; egal[palace]
# 5. 1(diš) udu niga 1(diš) maš₂-gal
# #lem: n; udu[sheep]; niga[fattened]; n; mašgal[goat]
# 6. {d}be-la-at-suh-ner
# #lem: PN
# 1. u₃ {d}be-la-at-dar-ra-ba-an
# #lem: u[and]; PN
# 2. 1(diš) udu niga {d}nanna
# #lem: n; udu[sheep]; niga[fattened]; DN
# 3. 1(diš) udu niga 1(diš) maš₂
# #lem: n; udu[sheep]; niga[fattened]; n; maš[goat]
# 4. siskur₂ ša₃ unu{ki}
# #lem: siškur[prayer]; šag[heart]; GN
# 5. giri₃ ma-šum
# #lem: ŋiri[foot]; PN
# 6. siskur₂ u₄-sakar
# #lem: siškur[prayer]; usakar[moon]
# 7. iti-ta u₄ 3(u) ba-ta-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 8. zi-ga
# #lem: ziga[expenditure]
# 9. iti ses-da-gu₇
# #lem: itud[moon]; MN
# 10. mu ša-aš-ru{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P107984
# 1. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 2. 1(diš) udu gu₄-e-us₂-sa
# #lem: n; udu[sheep]; gudeʾusa[drover]
# 3. 1(diš) sila₄
# #lem: n; sila[lamb]
# 4. ga-la-a
# #lem: PN
# 5. iti-ta u₄ 2(u) 3(diš) ba-ta-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 6. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 1. {d}šul-gi-<<gi>>-si₂-im-tum-ma
# #lem: PN
# 2. a₂-bi₂-la-tum i₃-dab₅
# #lem: PN; dab[seize]
# 3. iti ezem-{d}nin-a-zu
# #lem: itud[moon]; MN
# 4. mu ša-aš-ru{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P107999
# 1. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 2. 1(diš) maš₂-gal gu₄-e-us₂-sa
# #lem: n; mašgal[goat]; gudeʾusa[drover]
# 3. 1(diš) šah₂-tur munus geš-gi LAGAB niga
# #lem: n; X; munus[woman]; gi[thicket]; X; niga[fattened]
# 4. igi-kar₂ e₂-a-nu-uh₂-ši-še₃
# #lem: PN; PN
# 5. giri₃ be-li₂-ba-ni
# #lem: ŋiri[foot]; PN
# 6. 1(diš) udu 1(diš) šah₂-tur-nita₂
# #lem: n; udu[sheep]; n; X
# 7. ba-uš₂ e₂-gal-la ba-an-ku₄?
# #lem: uš[die]; egal[palace]; X
# 1. 1(diš) šah₂-tur munus geš-gi
# #lem: n; X; munus[woman]; gi[thicket]
# 2. nig₂-gu₇ nin-ga₂-še₃
# #lem: niŋgu[food]; nin[lady]
# 3. iti-ta u₄ 2(u) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 4. zi-ga ur-{d}lugal-edin-ka
# #lem: ziga[expenditure]; PN
# 5. iti ezem-me-ki-gal₂
# #lem: itud[moon]; MN
# 6. mu ur-bi₂-lum{ki}
# #lem: mu[year]; GN
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sadug[offerings]']}
#
#
# P108740
# 1. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 2. siskur₂ ša₃-ge gu-ru-a
# #lem: siškur[prayer]; šag[heart]; PN
# 3. 1(diš) udu niga gi-ra-num₂ {d}inanna
# #lem: n; udu[sheep]; niga[fattened]; giranum[wailing]; TN
# 4. 1(diš) udu niga 1(diš) maš₂-gal niga
# #lem: n; udu[sheep]; niga[fattened]; n; mašgal[goat]; niga[fattened]
# 5. siskur₂ {d}be-la-at-suh₆-ner u₃ {d}be-la-at-dar-ra-ba-an
# #lem: siškur[prayer]; PN; u[and]; PN
# 6. 2(diš) udu niga 1(diš) udu u₂
# #lem: n; udu[sheep]; niga[fattened]; n; udu[sheep]; u[grass]
# 7. siskur₂ e₂-u₄-1(u)-5(diš) ša₃ unu{ki}
# #lem: siškur[prayer]; X; šag[heart]; GN
# 8. giri₃ be-li₂-ba-ni
# #lem: ŋiri[foot]; PN
# 1. ša₃ e₂ sag-da-na
# #lem: šag[heart]; e[house]; GN
# 2. 2(diš) udu niga 1(diš) sila₄
# #lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]
# 3. ka eš₃
# #lem: kag[mouth]; eš[shrine]
# 4. 1(diš) sila₄ nig₂-ki-zah₃ {d}na-na-a
# #lem: n; sila[lamb]; X; DN
# 5. 1(diš) maš₂ er₂ iri nigin₂-na
# #lem: n; maš[goat]; er[tears]; iri[city]; X
# 6. 1(diš) maš₂ u₄ zi-ga-ze₂-na
# #lem: n; maš[goat]; ud[sun]; PN
# 7. 1(diš) udu niga ka ge₆-par₄-ra
# #lem: n; udu[sheep]; niga[fattened]; kag[mouth]; ŋipar[cloister]
# 8. 1(diš) udu niga 1(diš) sila₄
# #lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]
# 9. e₂ {d}na-na-a
# #lem: e[house]; DN
# 10. giri₃ nin-ga₂
# #lem: ŋiri[foot]; PN
# 11. ša₃ unu{ki}-ga
# #lem: šag[heart]; GN
# 12. zi-ga be-li₂-du₁₀ kurušda
# #lem: ziga[expenditure]; PN; kurušda[fattener]
# 13. iti ezem-{d}nin-a-zu
# #lem: itud[moon]; MN
# 1. mu bad₃ ma-da ba-du₃-a
# #lem: mu[year]; bad[wall]; mada[land]; du[go]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sadug[offerings]']}
#
#
# P109483
# 1. 1(diš) gu₄ niga
# #lem: n; gud[ox]; niga[fattened]
# 2. ma₂ an-na
# #lem: ma[ship]; anna[metal]
# 3. ša₃ unu{ki}-ga
# #lem: šag[heart]; GN
# 4. giri₃ bar-bar-re
# #lem: ŋiri[foot]; PN
# 1. zi-ga
# #lem: ziga[expenditure]
# 2. be-li₂-du₁₀
# #lem: PN
# 3. iti a₂-ki-ti
# #lem: itud[moon]; akiti[festival]
# 4. mu an-ša-an{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]']}
#
#
# P109484
# 1. 1(diš) sila₄
# #lem: n; sila[lamb]
# 2. dam sukkal-mah
# #lem: dam[spouse]; sukkalmah[official]
# 3. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 4. {d}šul-gi-si₂-im-tum
# #lem: PN
# 1. [be-li₂]-du₁₀# i₃-dab₅
# #lem: PN; dab[seize]
# 2. [iti] maš#-ku₃-gu₇
# #lem: itud[moon]; MN
# 3. mu us₂-sa an-ša-an{ki} ba-hul mu us₂-sa-bi
# #lem: mu[year]; us[follow]; GN; hulu[bad]; mu[year]; us[follow]
# Hardcode label:  {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P109485
# 1. 2(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 2. 1(diš) sila₄
# #lem: n; sila[lamb]
# 3. ama-bara₂
# #lem: PN
# 4. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 5. be-li₂-du₁₀ i₃-dab₅
# #lem: PN; dab[seize]
# 1. iti ezem-an-na
# #lem: itud[moon]; MN
# 2. mu {d}nanna kar-zi-da
# #lem: mu[year]; DN; TN
# 3. a-ra₂ 2(diš)-kam-aš
# #lem: ara[times]; n
# 4. e₂-a-na ba-an-kuₓ(KWU147)
# #lem: e[house]; X
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P109486
# 1. 1(diš) uz-tur
# #lem: n; PN
# 2. 6(diš) tu-gur₄{mušen}
# #lem: n; tugur[dove]
# 3. iti-ta u₄ 2(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 4. [nig₂]-gu₇ nin-ga₂-še₃
# #lem: niŋgu[food]; nin[lady]
# 1. zi-ga
# #lem: ziga[expenditure]
# 2. a₂-bi₂-li₂-a
# #lem: PN
# 3. iti a₂-ki-ti
# #lem: itud[moon]; akiti[festival]
# 4. mu e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; e[house]; X; du[build]
# ...
# 11. kaš-de₂-a an-nu-ni-tum
# #lem: kašdea[banquet]; PN
# 12. iti-ta u₄ 7(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 13. zi-ga a₂-bi₂-li₂-[a]
# #lem: ziga[expenditure]; PN
# 14. iti ezem-{d}šul-gi
# #lem: itud[moon]; MN
# 1. mu us₂-sa [e₂] puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; us[follow]; e[house]; X; du[build]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; siškur[prayer]']}
#
#
# P135038
# 1. 3(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 2. 3(diš) gu₄ u₂
# #lem: n; gud[ox]; u[grass]
# 3. siskur₂ sag u₄-sakar ša₃ unu{ki}-ga
# #lem: siškur[prayer]; saŋ[head]; usakar[moon]; šag[heart]; GN
# 4. giri₃ a₂-bi₂-li₂-a
# #lem: ŋiri[foot]; PN
# 5. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 6. gi-ra-num₂ {d}inanna
# #lem: giranum[wailing]; TN
# 7. 1(diš) udu niga 1(diš) udu u₂
# #lem: n; udu[sheep]; niga[fattened]; n; udu[sheep]; u[grass]
# 8. siskur₂ {d}be-la-at-suh-ner
# #lem: siškur[prayer]; PN
# 9. u₃ {d}be-la-at-dar-ra-ba-an
# #lem: u[and]; PN
# 10. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 1. siskur₂ {d}nanna
# #lem: siškur[prayer]; DN
# 2. 1(diš) sila₄
# #lem: n; sila[lamb]
# 3. nig₂-ki-zah₃ u₄-sakar ša₃ e₂-gal-la
# #lem: X; usakar[moon]; šag[heart]; egal[palace]
# 4. 1(diš) maš₂
# #lem: n; maš[goat]
# 5. siskur₂ {d}nin-sun₂-ka
# #lem: siškur[prayer]; PN
# 6. iti-ta u₄ 3(u) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 7. zi-ga a₂-bi₂-li₂-a
# #lem: ziga[expenditure]; PN
# 8. iti maš-da₃-gu₇
# #lem: itud[moon]; MN
# 9. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃ mu us₂-sa-bi
# #lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
#
#
# P135039
# 1. [...] niga
# #lem: AN; niga[fattened]
# 2. [...] niga
# #lem: AN; niga[fattened]
# 3. [...]-na-še₃
# #lem: DN
# 4. [x] udu niga
# #lem: u; udu[sheep]; niga[fattened]
# 5. e₂ {d}na-na-a
# #lem: e[house]; DN
# 6. 1(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 7. eš₃ ge₆-zal
# #lem: eš[shrine]; X
# 8. ša₃ unu{ki}-ga
# #lem: šag[heart]; GN
# 9. giri₃ [x]-x-NI-[x]
# #lem: ŋiri[foot]; u
# 10. 1(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 11. gi-ra-num₂ {d}inanna
# #lem: giranum[wailing]; TN
# 1. a-ra₂ 1(diš)-kam
# #lem: ara[times]; n
# 2. 3(diš) udu niga 3(diš) sila₄ niga
# #lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]; niga[fattened]
# 3. ma₂ an-na-še₃
# #lem: ma[ship]; DN
# 4. 1(diš) udu li-bur-si₂-im-ti
# #lem: n; udu[sheep]; PN
# 5. 1(diš) maš₂-gal eš₁₈?-dar?-um-mi
# #lem: n; mašgal[goat]; PN
# 7. gi-ra-num₂ {d}inanna
# #lem: giranum[wailing]; TN
# 8. [a]-ra₂ 2(diš)-kam
# #lem: ara[times]; n
# 9. [iti-ta] u₄ 2(u) 6(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 10. [zi-ga] a₂-bi₂-li₂-a
# #lem: ziga[expenditure]; PN
# 11. [ša₃ e₂] sag-da-[na]
# #lem: šag[heart]; e[house]; GN
# 12. [iti ezem-{d}]šul-gi
# #lem: itud[moon]; MN
# 13. [mu us₂-sa e₂] puzur₄-[iš-{d}da]-gan [ba-du₃] mu us₂-sa-bi
# #lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]
# Hardcode label:  {'domesticated_animal': ['#lem: u; udu[sheep]; niga[fattened]']}
#
#
# P135044
# 1. 1(diš) tu-gur₄{mušen}
# #lem: n; tugur[dove]
# 2. nig₂-gu₇ nin-ga₂-še₃
# #lem: niŋgu[food]; nin[lady]
# 3. 1(diš) uz-tur
# #lem: n; PN
# 4. 3(diš) ir₇{mušen}
# #lem: n; irsaŋ[pigeon]
# 5. 2(diš) tu-gur₄{mušen}
# #lem: n; tugur[dove]
# 6. ba-uš₂ e₂-gal-la ba-an-kuₓ(KWU147)
# #lem: uš[die]; egal[palace]; X
# 1. iti-ta u₄ 2(u) 2(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 2. zi-ga ur-{d}lugal-edin-ka
# #lem: ziga[expenditure]; PN
# 3. iti a₂-ki-ti
# #lem: itud[moon]; akiti[festival]
# 4. mu us₂-sa ur-bi₂-lum{ki} ba-hul
# #lem: mu[year]; us[follow]; GN; hulu[bad]
# Hardcode label:  {'dead_animal': ['#lem: uš[die]; egal[palace]; X']}
#
#
# P135045
# 1. 1(diš) šah₂-NE-tur munus geš-gi
# #lem: n; X; munus[woman]; gi[thicket]
# 2. 1(diš) uz-tur
# #lem: n; PN
# 3. 5(diš) tu-gur₄{mušen}
# #lem: n; tugur[dove]
# 4. nig₂-gu₇ nin-ga₂-še₃
# #lem: niŋgu[food]; nin[lady]
# 5. [...]
# #lem: AN
# 6. [...]
# #lem: AN
# 1. 2(diš) šah₂-NE-tur munus geš-gi
# #lem: n; X; munus[woman]; gi[thicket]
# 3. 1(u) 3(diš) tu-gur₄{mušen}
# #lem: n; n; tugur[dove]
# 4. ba-uš₂ e₂-gal-la ba-an-kuₓ(KWU147)
# #lem: uš[die]; egal[palace]; X
# 5. iti-ta u₄ 3(u) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 6. zi-ga ur-{d}lugal-edin-[ka]
# #lem: ziga[expenditure]; PN
# 7. iti šu-eš₅-ša
# #lem: itud[moon]; MN
# 8. mu ki-maš{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'dead_animal': ['#lem: uš[die]; egal[palace]; X']}
#
#
# P135046
# 1. 1(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 2. an
# #lem: an[sky]
# 3. 2(diš) udu u₂
# #lem: n; udu[sheep]; u[grass]
# 4. nig₂-ki-zah₃-še₃
# #lem: X
# 5. 2(diš) gu₄ u₂
# #lem: n; gud[ox]; u[grass]
# 6. 2(diš) udu niga
# #lem: n; udu[sheep]; niga[fattened]
# 7. 2(diš) udu niga gu₄-e-us₂-sa
# #lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]
# 8. 2(diš) maš₂
# #lem: n; maš[goat]
# 9. na-ab-ri₂-um-še₃
# #lem: X
# 1. {d}be-la-at-suh-ner
# #lem: PN
# 2. u₃ {d}be-la-at-dar-ra-ba-an
# #lem: u[and]; PN
# 3. 1(diš) udu niga 1(diš) sila₄
# #lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]
# 4. {d}al-la-tum
# #lem: DN
# 5. 1(diš) udu u₂ 1(diš) maš₂
# #lem: n; udu[sheep]; u[grass]; n; maš[goat]
# 6. {d}iš-ha-ra u₃ {d}be-la-at-na-qar
# #lem: DN; u[and]; PN
# 7. 1(diš) sila₄ an-nu-ni-tum
# #lem: n; sila[lamb]; PN
# 8. 1(diš) maš₂ {d}na-na-a
# #lem: n; maš[goat]; DN
# 9. iti-ta u₄ 6(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; zal[pass]
# 10. zi-ga ur-{d}lugal-edin-[ka]
# #lem: ziga[expenditure]; PN
# 11. ša₃! uri₅[{ki}]-ma
# #lem: šag[heart]; GN
# 12. iti ezem-mah
# #lem: itud[moon]; MN
# 13. mu ki-maš{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
#
#
# P135048
# 1. 2(diš) udu niga kaš-de₂-a lugal
# #lem: n; udu[sheep]; niga[fattened]; kašdea[banquet]; lugal[king]
# 2. u₄ iri-sa₁₂-rig₇{ki}-ta mu-kuₓ(DU)-ra
# #lem: ud[sun]; GN; mu.DU[delivery]
# 3. iti-ta u₄ 1(u) 3(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 4. 1(diš) udu niga nig₂-gu₇ lugal-še₃ ša₃ e₂-gal-ka
# #lem: n; udu[sheep]; niga[fattened]; niŋgu[food]; lugal[king]; šag[heart]; egal[palace]
# 5. 1(diš) udu niga siskur₂ {d}inanna
# #lem: n; udu[sheep]; niga[fattened]; siškur[prayer]; TN
# 6. 1(diš) udu niga 1(diš) u₈
# #lem: n; udu[sheep]; niga[fattened]; n; u[ewe]
# 7. siskur₂ {d}be-la-at-suh-ner
# #lem: siškur[prayer]; PN
# 1. 2(diš) sila₄
# #lem: n; sila[lamb]
# 2. nig₂-ki-zah₃ e₂ {d}be-la-at-suh-ner
# #lem: X; e[house]; PN
# 3. giri₃ ur-{d}dumu-zi-da
# #lem: ŋiri[foot]; PN
# 4. 1(diš) udu niga 1(diš) maš₂-gal niga
# #lem: n; udu[sheep]; niga[fattened]; n; mašgal[goat]; niga[fattened]
# 5. 1(diš) u₈ siskur₂ ša₃ unu{ki}-ga e₂-u₄-1(u)-5(diš)
# #lem: n; u[ewe]; siškur[prayer]; šag[heart]; GN; X
# 6. iti-ta u₄ 1(u) 4(diš) ba-ta-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 7. 4(diš) udu u₂ ri-ri-ga-am₃ e₂-gal-la ba-an-kuₓ(KWU147)
# #lem: n; udu[sheep]; u[grass]; deg[collect]; egal[palace]; X
# 8. zi-ga a₂-bi₂-la-tum
# #lem: ziga[expenditure]; PN
# 9. iti ezem-an-na
# #lem: itud[moon]; MN
# 10. mu ša-aš-ru{ki} ba-hul
# #lem: mu[year]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; kašdea[banquet]; lugal[king]']}
#
#
# P135050
# 1. maš₂ x
# #lem: maš[goat]; u
# 2. {d}ul-ma-ši-tum
# #lem: DN
# 3. giri₃ nin-ha-ma-ti
# #lem: ŋiri[foot]; PN
# 4. 1(diš) maš₂-gal niga
# #lem: n; mašgal[goat]; niga[fattened]
# 5. {d}inanna
# #lem: TN
# 6. 1(diš) maš₂-gal niga
# #lem: n; mašgal[goat]; niga[fattened]
# 1. {d}nin-šubur
# #lem: FN
# 2. giri₃ da-ak-ma-keš₂-še₃
# #lem: ŋiri[foot]; PN
# 3. zi-ga ki kalam-he₂-na-gi-ta
# #lem: ziga[expenditure]; ki[place]; PN
# 4. iti-ta u₄ 2(u) 3(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 5. iti ezem-mah
# #lem: itud[moon]; MN
# 6. [mu]
# #lem: mu[year]
# Hardcode label:  {'domesticated_animal': ['#lem: maš[goat]; u']}
#
#
# P135051
# 1. 2(diš) maš₂-nita₂
# #lem: n; X
# 2. 2(diš) {munus}aš₂-gar₃
# #lem: n; ašgar[kid]
# 3. 2(diš) u₈ 2(diš) udu-nita₂
# #lem: n; u[ewe]; n; udunita[ram]
# 4. iti ezem-{d}šul-gi
# #lem: itud[moon]; MN
# 5. 4(diš) u₈ 2(diš) udu-nita₂
# #lem: n; u[ewe]; n; udunita[ram]
# 6. 2(diš) {munus}aš₂-gar₃
# #lem: n; ašgar[kid]
# 7. iti šu-eš-ša
# #lem: itud[moon]; MN
# 1. sa₂-du₁₁ {d}be-la-at-suh-ner
# #lem: sadug[offerings]; PN
# 2. {d}be-la-at-dar-ra-ba-an
# #lem: PN
# 3. an-nu-ni-tum
# #lem: PN
# 4. u₃ {d}ul-ma-ši-tum
# #lem: u[and]; DN
# 5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃
# #lem: mu[year]; e[house]; X; du[build]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) maš₂-nita₂', '#lem: n; X', '2. 2(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '3. 2(diš) u₈ 2(diš) udu-nita₂', '#lem: n; u[ewe]; n; udunita[ram]', '4. iti ezem-{d}šul-gi', '#lem: itud[moon]; MN', '5. 4(diš) u₈ 2(diš) udu-nita₂', '#lem: n; u[ewe]; n; udunita[ram]', '6. 2(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '7. iti šu-eš-ša', '#lem: itud[moon]; MN', '@reverse', '1. sa₂-du₁₁ {d}be-la-at-suh-ner', '#lem: sadug[offerings]; PN', '2. {d}be-la-at-dar-ra-ba-an', '#lem: PN', '3. an-nu-ni-tum', '#lem: PN', '4. u₃ {d}ul-ma-ši-tum', '#lem: u[and]; DN', '5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]']]}
#
#
# P142143
# 1. 2(diš) udu [...] 1(diš) maš₂
# #lem: n; udu[sheep]; AN; n; maš[goat]
# 2. a-ta-x
# #lem: u
# 3. 1(diš) gu₄ 8(diš) udu
# #lem: n; gud[ox]; n; udu[sheep]
# 4. 3(diš) maš₂
# #lem: n; maš[goat]
# 5. ur-{d}šul-pa-e₃
# #lem: PN
# 6. 4(diš) udu 1(diš) maš₂
# #lem: n; udu[sheep]; n; maš[goat]
# 7. nir-i₃-da-gal₂
# #lem: PN
# 8. 3(diš) udu 1(diš) maš₂
# #lem: n; udu[sheep]; n; maš[goat]
# 1. ama-bara₂
# #lem: PN
# 2. 1(diš) maš₂ e₂-a-ba-ni ensi₂
# #lem: n; maš[goat]; PN; ensik[ruler]
# 3. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti
# #lem: mu.DU[delivery]; PN
# 4. iti ezem-mah
# #lem: itud[moon]; MN
# 5. mu a-ra₂ 3(diš)-kam-aš si-mu-ru-um{ki} [ba-hul]
# #lem: mu[year]; ara[times]; n; GN; hulu[bad]
# 1. gaba-ri 3(diš)-kam
# #lem: gabari[copy]; n
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; AN; n; maš[goat]']}
#
#
# P142367
# 1. [x] maš₂ u₄ 1(diš)-kam
# #lem: u; maš[goat]; ud[sun]; n
# 2. 3(diš) maš₂ u₄ 2(diš)-kam
# #lem: n; maš[goat]; ud[sun]; n
# 3. 3(diš) udu u₄ 5(diš)-kam
# #lem: n; udu[sheep]; ud[sun]; n
# 4. 1(u) udu u₄ 6(diš)-kam
# #lem: n; udu[sheep]; ud[sun]; n
# 5. 2(diš) maš₂ u₄ 7(diš)-kam
# #lem: n; maš[goat]; ud[sun]; n
# 6. 3(geš₂) 3(u) 3(diš) udu x ki-maš{ki} u₄ 1(u) la₂ 1(diš)-kam
# #lem: n; n; n; udu[sheep]; u; GN; ud[sun]; n; lal[small]; n
# 7. 3(diš) udu u₄ 1(u)-kam
# #lem: n; udu[sheep]; ud[sun]; n
# 8. 2(diš) maš₂ u₄ 1(u) 4(diš)-kam
# #lem: n; maš[goat]; ud[sun]; n; n
# 9. 3(diš) udu u₄ 1(u) 5(diš)-kam
# #lem: n; udu[sheep]; ud[sun]; n; n
# 10. 2(diš) udu u₄ 2(u) la₂ 3(diš)-kam
# #lem: n; udu[sheep]; ud[sun]; n; lal[small]; n
# 11. 7(diš) udu u₄ 2(u) la₂ 2(diš)-kam
# #lem: n; udu[sheep]; ud[sun]; n; lal[small]; n
# 12. 1(diš) maš₂ u₄ 2(u) 1(diš)-kam
# #lem: n; maš[goat]; ud[sun]; n; n
# 13. 3(diš) udu u₄ 2(u) 2(diš)-kam
# #lem: n; udu[sheep]; ud[sun]; n; n
# 14. 3(diš) [x] u₄ 2(u) 3(diš)-kam
# #lem: n; u; ud[sun]; n; n
# 15. 6(diš) maš₂ sila₄ u₄ 2(u) 4(diš)-kam
# #lem: n; maš[goat]; sila[lamb]; ud[sun]; n; n
# 16. 3(diš) maš₂ u₄ 2(u) 5(diš)-kam
# #lem: n; maš[goat]; ud[sun]; n; n
# 17. 1(diš) sila₄ u₄ 3(u) la₂ 3(diš)-kam
# #lem: n; sila[lamb]; ud[sun]; n; lal[small]; n
# 1. 1(diš) maš₂ u₄ 3(u) la₂ 2(diš)-kam
# #lem: n; maš[goat]; ud[sun]; n; lal[small]; n
# 2. 2(diš) udu u₄ 3(u) la₂ 1(diš)-kam
# #lem: n; udu[sheep]; ud[sun]; n; lal[small]; n
# 3. [mu]-kuₓ(DU) iti maš-ku₃-gu₇
# #lem: mu.DU[delivery]; itud[moon]; MN
# 4. [mu] us₂-sa e₂ puzur₄-[iš-{d}]da-gan ba-du₃
# #lem: mu[year]; us[follow]; e[house]; X; du[build]
# 1. [x] la₂ 1(diš) udu maš₂ hi-a
# #lem: u; lal[small]; n; udu[sheep]; maš[goat]; hi[mix]
# Hardcode label:  {'domesticated_animal': ['#lem: u; maš[goat]; ud[sun]; n']}
#
#
# P142399
# 1. 3(diš) uz-tur
# #lem: n; PN
# 2. nin₉ ṣe-lu-uš-{d}da-gan ba-du₃
# #lem: nin[sister]; X; du[build]
# 3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 4. mu-kuₓ(DU)
# #lem: mu.DU[delivery]
# 1. {d}šul-gi-si₂-im-tum-še₃
# #lem: PN
# 2. a₂-bi₂-li₂-a i₃-dab₅
# #lem: PN; dab[seize]
# 3. iti šu-eš₅-ša
# #lem: itud[moon]; MN
# 4. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃ mu us₂-sa-bi
# #lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(diš) uz-tur', '#lem: n; PN', '2. nin₉ ṣe-lu-uš-{d}da-gan ba-du₃', '#lem: nin[sister]; X; du[build]', '3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. {d}šul-gi-si₂-im-tum-še₃', '#lem: PN', '2. a₂-bi₂-li₂-a i₃-dab₅', '#lem: PN; dab[seize]', '3. iti šu-eš₅-ša', '#lem: itud[moon]; MN', '4. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃ mu us₂-sa-bi', '#lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]']]}
#
#
# P142400
# 1. 5(diš) ir₇{mušen}
# #lem: n; irsaŋ[pigeon]
# 2. dam ur-nigar
# #lem: dam[spouse]; PN
# 3. 5(diš) ir₇{mušen}
# #lem: n; irsaŋ[pigeon]
# 4. 1(u) 4(diš) tu-gur₄{mušen}
# #lem: n; n; tugur[dove]
# 5. [x] x x ki
# #lem: u; u; u; ki[place]
# 6. [...]
# #lem: AN
# 1. [...]
# #lem: AN
# 2. {d}[šul-gi]-si₂#-im-tum
# #lem: PN
# 3. a₂-bi₂-la-tum i₃-dab₅
# #lem: PN; dab[seize]
# 4. iti ses-da-gu₇
# #lem: itud[moon]; MN
# 5. mu si-mu-ru-um{ki} u₃ lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-ma-aš ba-hul
# #lem: mu[year]; GN; u[and]; GN; ara[times]; n; lal[small]; n; hulu[bad]
# Hardcode label:  {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. dam ur-nigar', '#lem: dam[spouse]; PN', '3. 5(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '4. 1(u) 4(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '5. [x] x x ki', '#lem: u; u; u; ki[place]', '6. [...]', '#lem: AN', '@reverse', '1. [...]', '#lem: AN', '2. {d}[šul-gi]-si₂#-im-tum', '#lem: PN', '3. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '4. iti ses-da-gu₇', '#lem: itud[moon]; MN', '5. mu si-mu-ru-um{ki} u₃ lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-ma-aš ba-hul', '#lem: mu[year]; GN; u[and]; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P142401
# 1. 1(diš) udu niga sa₂-du₁₁
# #lem: n; udu[sheep]; niga[fattened]; sadug[offerings]
# 2. gudu₄ {d}be-la-at-suh-ner
# #lem: FN; PN
# 3. 3(diš) x [...]
# #lem: n; u; AN
# 4. [...]
# #lem: AN
# 1. [...]
# #lem: AN
# 2. zi-ga [ki ur-lugal]-edin-ka
# #lem: ziga[expenditure]; ki[place]; PN
# 3. iti šu-eš₅-ša
# #lem: itud[moon]; MN
# 4. mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# #lem: mu[year]; GN; u[and]; GN; hulu[bad]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sadug[offerings]']}
#
#
# P142619
# 1. 1(diš) udu niga 1(diš) sila₄ niga
# #lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]; niga[fattened]
# 2. 2(diš) gukkal niga#
# #lem: n; gukkal[sheep]; niga[fattened]
# 3. 5(diš) gukkal
# #lem: n; gukkal[sheep]
# 4. 1(diš) maš₂ ga
# #lem: n; maš[goat]; ga[milk]
# 5. e₂-muhaldim
# #lem: emuhaldim[kitchen]
# 6. ki-a-nag {d}šul-gi-ra-še₃
# #lem: kiʾanaŋ[locus]; PN
# 7. 1(diš) udu niga 1(diš) gukkal
# #lem: n; udu[sheep]; niga[fattened]; n; gukkal[sheep]
# 1. ki-a-nag geme₂-{d}nin-lil₂-la₂
# #lem: kiʾanaŋ[locus]; PN
# 2. 1(diš) gukkal ki-a-nag {d}šul-gi-si₂-im-ti
# #lem: n; gukkal[sheep]; kiʾanaŋ[locus]; PN
# 3. na-ra-am-i₃-li₂ maškim
# #lem: PN; maškim[administrator]
# 4. iti u₄ 2(u) 8(diš) ba-zal
# #lem: itud[moon]; ud[sun]; n; n; zal[pass]
# 5. ki na-lu₅-ta ba-zi
# #lem: ki[place]; PN; PN
# 6. ša₃ uri₅{ki}-ma
# #lem: šag[heart]; GN
# 7. iti u₅-bi₂{mušen}-gu₇
# #lem: itud[moon]; MN
# 8. mu {d}amar-{d}suen lugal
# #lem: mu[year]; PN; lugal[king]
# Hardcode label:  {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]; niga[fattened]']}
#
#
# P142856
# 1. 1(diš) sila₄ nig₂-ki-zah₃ {d}na-na-a
# #lem: n; sila[lamb]; X; DN
# 2. ša₃ e₂-gal-še₃
# #lem: šag[heart]; egal[palace]
# 3. i-pi₅-iq-er₃-ra maškim
# #lem: PN; maškim[administrator]
# 4. ša₃ uri₅{ki}-ma
# #lem: šag[heart]; GN
# 1. 1(diš) maš₂ ka₂? x x
# #lem: n; maš[goat]; kan[gate]; u; u
# 2. giri₃ nin-ga₂
# #lem: ŋiri[foot]; PN
# 3. 1(diš) sila₃ nig₂-ki-zah₃ ka₂ kurušda-še₃
# #lem: n; sila[unit]; X; kan[gate]; kurušda[fattener]
# 4. i-pi₅-iq-er₃-ra maškim
# #lem: PN; maškim[administrator]
# 5. ša₃ unu{ki}-ga
# #lem: šag[heart]; GN
# 6. zi-ga ensi₂
# #lem: ziga[expenditure]; ensik[ruler]
# 7. iti ezem-an-na
# #lem: itud[moon]; MN
# Hardcode label:  {'domesticated_animal': ['#lem: n; sila[lamb]; X; DN']}
#
#
# Number unknown:  53 out of  212

# %% [markdown]
# # Analysis
#
# Only 53/212 of the Queen's archives do not fit into one of the 6 labels. This means that in Queen's Archives transactions, similar commodities are being traded.
#
# Goal: find features that identify a transaction as belonging to Queen's archives

# %% [markdown]
# # Look at total unknowns

# %%
unknowns = []
for item in lst:
    print(item[0], item[1])
    print("\n")
    if "Unknown" in item[1].keys():
        unknowns.append(item)
# Out:
# P100041 {'domesticated_animal': ['#lem: n; udu[sheep]']}
#
#
# P100189 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P100190 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P100191 {'domesticated_animal': ['#lem: n; mašgal[goat]; niga[fattened]; n; udu[sheep]']}
#
#
# P100211 {'domesticated_animal': ['#lem: n; udu[sheep]; a[water]; u; sag[rare]']}
#
#
# P100214 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]; niga[fattened]']}
#
#
# P100215 {'domesticated_animal': ['#lem: n; mašgal[goat]; niga[fattened]']}
#
#
# P100217 {'wild_animal': ['#lem: n; amar[young]; mašda[gazelle]; DN']}
#
#
# P100218 {'domesticated_animal': ['#lem: n; mašgal[goat]']}
#
#
# P100219 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P100220 {'domesticated_animal': ['#lem: n; mašgal[goat]; niga[fattened]']}
#
#
# P100221 {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P100222 {'domesticated_animal': ['#lem: n; lal[small]; n; udu[sheep]']}
#
#
# P100223 {'domesticated_animal': ['#lem: n; udu[sheep]; sadug[offerings]; FN']}
#
#
# P100224 {'domesticated_animal': ['#lem: n; udu[sheep]; sadug[offerings]; FN']}
#
#
# P100226 {'domesticated_animal': ['#lem: n; kir[lamb]; ur[pluck]']}
#
#
# P100227 {'domesticated_animal': ['#lem: n; n; udu[sheep]; u[grass]']}
#
#
# P100228 {'domesticated_animal': ['#lem: n; sila[lamb]; FN']}
#
#
# P100229 {'domesticated_animal': ['#lem: n; udu[sheep]; n; mašgal[goat]']}
#
#
# P100230 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) lulim-nita₂', '#lem: n; X', '2. šu-gid₂ e₂-muhaldim', '#lem: šugid[~animal]; emuhaldim[kitchen]', '3. mu gar₃-du-ne-še₃', '#lem: mu[year]; gardu[soldier]', '4. dingir-dan sukkal maškim', '#lem: PN; sukkal[secretary]; maškim[administrator]', '5. iti u₄ 1(u) 6(diš) ba-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '6. ki lu₂-dingir-ra-ta', '#lem: ki[place]; PN', '@reverse', '1. ba-zi', '#lem: PN', '$ 1 line blank', '2. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '3. mu en eridu{ki} ba-hun', '#lem: mu[year]; en[priest]; GN; huŋ[hire]', '@left', '1. 1(diš)', '#lem: n']]}
#
#
# P100231 {'domesticated_animal': ['#lem: n; uzud[goat]']}
#
#
# P100232 {'domesticated_animal': ['#lem: n; durah[goat]; munus[woman]']}
#
#
# P100259 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P100260 {'domesticated_animal': ['#lem: n; sila[lamb]; FN']}
#
#
# P100261 {'wild_animal': ['#lem: n; mašda[gazelle]']}
#
#
# P100262 {'domesticated_animal': ['#lem: n; mašgal[goat]; babbar[white]']}
#
#
# P100263 {'domesticated_animal': ['#lem: n; sila[lamb]; ga[milk]']}
#
#
# P100264 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P100265 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sag[rare]; us[side]']}
#
#
# P100266 {'domesticated_animal': ['#lem: n; sila[lamb]; ga[milk]']}
#
#
# P100267 {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P100268 {'domesticated_animal': ['#lem: n; udu[sheep]']}
#
#
# P100269 {'domesticated_animal': ['#lem: n; ab[cow]']}
#
#
# P100270 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P100271 {'domesticated_animal': ['#lem: n; udu[sheep]; n; maš[goat]']}
#
#
# P100272 {'domesticated_animal': ['#lem: n; n; gud[ox]; niga[fattened]']}
#
#
# P100273 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sadug[offerings]']}
#
#
# P100278 {'domesticated_animal': ['#lem: gud[ox]; niŋgur[property]; PN']}
#
#
# P100281 {'leather_object': ['#lem: n; n; suhub[boots]; eban[pair]']}
#
#
# P100284 {'domesticated_animal': ['#lem: n; n; gud[ox]; n; n; ab[cow]']}
#
#
# P100287 {'domesticated_animal': ['#lem: n; gud[ox]; n; n; udu[sheep]; šugid[~animal]']}
#
#
# P100292 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(ban₂) zi₃-gu', '#lem: n; zidgu[flour]', '2. sa₂-du₁₁-še₃', '#lem: sadug[offerings]', '3. ki lu₂-du₁₀-ga-mu#-ta#', '#lem: ki[place]; PN', '4. ba-zi', '#lem: PN', '@reverse', '1. iti ezem-an-na', '#lem: itud[moon]; MN', '2. mu e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; e[house]; TN; GN; du[build]', '@left', '1. [...]', '#lem: AN']]}
#
#
# P100296 {'dead_animal': ['#lem: uš[die]']}
#
#
# P100297 {'domesticated_animal': ['#lem: n; gud[ox]; n; ab[cow]; emuhaldim[kitchen]']}
#
#
# P100317 {'domesticated_animal': ['#lem: n; mašgal[goat]; u']}
#
#
# P100318 {'domesticated_animal': ['#lem: n; n; udu[sheep]; maš[goat]; hi[mix]']}
#
#
# P100320 {'domesticated_animal': ['#lem: n; n; udu[sheep]; niga[fattened]']}
#
#
# P100321 {'domesticated_animal': ['#lem: n; sila[lamb]; FN']}
#
#
# P100327 {'domesticated_animal': ['#lem: n; udu[sheep]; n; maš[goat]; n; sila[lamb]; FN']}
#
#
# P100328 {'domesticated_animal': ['#lem: n; udu[sheep]; aslum[sheep]; niga[fattened]; n; us[side]']}
#
#
# P100329 {'domesticated_animal': ['#lem: n; kir[lamb]; gub[stand]']}
#
#
# P100330 {'domesticated_animal': ['#lem: n; gukkal[sheep]; ŋešdu[breeder]']}
#
#
# P100331 {'domesticated_animal': ['#lem: n; gukkal[sheep]; n; gukkal[sheep]; ŋešdu[breeder]']}
#
#
# P100332 {'domesticated_animal': ['#lem: u; n; udu[sheep]; niga[fattened]; sag[rare]; us[side]']}
#
#
# P100333 {'domesticated_animal': ['#lem: n; n; gud[ox]']}
#
#
# P100334 {'domesticated_animal': ['#lem: n; udu[sheep]']}
#
#
# P100335 {'domesticated_animal': ['#lem: n; udu[sheep]']}
#
#
# P100336 {'domesticated_animal': ['#lem: u; gud[ox]; niga[fattened]']}
#
#
# P100337 {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]']}
#
#
# P100338 {'dead_animal': ['#lem: uš[die]']}
#
#
# P100339 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P100342 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) 3(u) sa gi', '#lem: n; n; sa[roast]; gi[reed]', '2. 2(ban₂) še ad-nu-ha', '#lem: n; še[barley]; X', '3. nu-banda₃ nir-i₃-da-gal₂', '#lem: nubanda[overseer]; PN', '@reverse', '1. giri₃ ur-mes', '#lem: ŋiri[foot]; PN', '@seal 1', '$ (legend broken)']]}
#
#
# P100346 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 4(geš₂) 2(u) 4(diš) sa gi', '#lem: n; n; n; sa[roast]; gi[reed]', '2. sa₂-du₁₁ ur-{d}ba-ba₆', '#lem: sadug[offerings]; PN', '3. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '@reverse', '1. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '2. mu us₂-sa bad₃ ba-du₃', '#lem: mu[year]; us[follow]; bad[wall]; du[build]', '@seal 1', '$seal illegible']]}
#
#
# P100375 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '@reverse', '$ blank space', '# seal impression', '@seal 1', '$ illegible']]}
#
#
# P100377 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) gu₂ gi', '#lem: n; gu[pulse]; gi[reed]', '2. [ṣe]-li#-{d}iškur', '#lem: X', '@reverse', '@seal 1', '$ (legend broken)']]}
#
#
# P100378 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '2. ur-{geš}gigir ugula', '#lem: PN; ugula[overseer]', '@reverse', '@seal 1', '$ (legend broken)']]}
#
#
# P100501 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) guruš', '#lem: n; ŋuruš[male]', '2. u₄ 1(geš₂) 3(u)-še₃', '#lem: ud[sun]; n; n', '3. ma₂-da-ga-aš ma₂ gid₂-da', '#lem: X; ma[ship]; gid[long]', '4. 1(diš) guruš nagar', '#lem: n; ŋuruš[male]; nagar[carpenter]', '5. u₄ 2(u) 5(diš) [...-še₃]', '#lem: ud[sun]; n; n; DN', '6. [...]', '#lem: AN', '@reverse', '1. ki lu₂-[...]', '#lem: ki[place]; PN', '2. kišib₃ lugal-[...]', '#lem: kišib[seal]; PN', '3. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
#
#
# P100564 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(geš₂) 5(u) 5(diš) guruš u₄ 1(diš)-še₃', '#lem: n; n; n; ŋuruš[male]; ud[sun]; n', '2. ki ba-saga gu-za-la₂-ta', '#lem: ki[place]; X; guzala[official]', '3. lu₂-sa₆-i₃-zu', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P100584 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(geš₂) 4(u) guruš u₄ 1(diš)-še₃', '#lem: n; n; ŋuruš[male]; ud[sun]; n', '2. ki-su₇ a-ša₃ muru₁₃? gub-ba', '#lem: kisur[locus]; ašag[field]; FN; gub[stand]', '3. ugula ur-e₂-nun', '#lem: ugula[overseer]; PN', '@reverse', '1. kišib₃ da-a-gi₄', '#lem: kišib[seal]; PN', '2. mu {d}amar-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]', '@seal 1', '$ (legend broken)']]}
#
#
# P100591 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 8(diš) guruš u₄ 1(diš)-še₃', '#lem: n; ŋuruš[male]; ud[sun]; n', '2. a-ša₃ {geš}ma-nu-ta', '#lem: ašag[field]; manu[wood]', '3. še zi-ga', '#lem: še[barley]; ziga[expenditure]', '4. giri₃ nigar{gar}-ki-du₁₀', '#lem: ŋiri[foot]; PN', '@reverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. mu us₂-sa an-ša-an{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
#
#
# P100608 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) guruš dub-sar', '#lem: n; ŋuruš[male]; dubsar[scribe]', '2. u₄ 4(u) 5(diš)-še₃', '#lem: ud[sun]; n; n', '3. uri₅{ki}-ma gub-ba', '#lem: GN; gub[stand]', '4. ugula a-a-gi-na', '#lem: ugula[overseer]; PN', '@reverse', '1. la-ni-mu i₃-dab₅', '#lem: PN; dab[seize]', '$ blank space', '# seal impression', '2. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ illegible']]}
#
#
# P100615 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(ban₂) še lugal', '#lem: n; še[barley]; lugal[king]', '2. [...] kas₄', '#lem: AN; kaš[runner]', '3. kišib₃ ur-{d}šara₂ ša₁₃-dub-ba', '#lem: kišib[seal]; PN; bisaŋdubak[archivist]', '@reverse', '@seal 1', '$ (legend broken)']]}
#
#
# P100616 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) še gur 1(barig)-ta', '#lem: n; še[barley]; gur[unit]; n', '2. 3(aš) 1(barig) ziz₂ gur', '#lem: n; n; ziz[emmer]; gur[unit]', '3. ur-{d}a-šar₂', '#lem: PN', '@reverse', '1. ARAD₂-e₂-ninnu', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
#
#
# P100617 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [x] 4(aš) ziz₂ gur si-sa₂-ta', '#lem: u; n; ziz[emmer]; gur[unit]; sisa[fair]', '2. 3(aš) gig gur', '#lem: n; kib[wheat]; gur[unit]', '3. ki lu₂-{d}er₃-ra-ta', '#lem: ki[place]; PN', '@reverse', '1. ha-lu₅-lu₅', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
#
#
# P100618 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) 4(barig) še gur lugal', '#lem: n; n; še[barley]; gur[unit]; lugal[king]', '2. 2(aš) 2(barig) ziz₂ gur', '#lem: n; n; ziz[emmer]; gur[unit]', '3. kišib₃ ARAD₂', '#lem: kišib[seal]; arad[slave]', '4. ki ur-{d}suen-ta', '#lem: ki[place]; PN', '5. 1(barig) še lugal-gaba', '#lem: n; še[barley]; PN', '6. šu+nigin 4(aš) 2(barig) še gur', '#lem: šuniŋin[total]; n; n; še[barley]; gur[unit]', '@left', '1. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. ur-{d}[...]', '#lem: PN', '2. iti [...]', '#lem: itud[moon]; AN', '3. mu [...]{ki} ba-hul', '#lem: mu[year]; u; hulu[bad]', '']]}
#
#
# P100623 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(aš) 1(barig) 3(ban₂) 2(diš) sila₃ še gur', '#lem: n; n; n; n; sila[unit]; še[barley]; gur[unit]', '2. [mu]-kuₓ(DU) {d}šara₂', '#lem: mu.DU[delivery]; TN', '3. [...] a-pi₄-sal₄{ki}', '#lem: AN; GN', '4. [u₃ muš]-bi-an{ki}', '#lem: u[and]; GN', '5. [gu₂]-de₃-na-ta', '#lem: GN', '$ rest broken', '@reverse', '$ blank space', '1. mu [...]{ki} ba-hul', '#lem: mu[year]; u; hulu[bad]']]}
#
#
# P100625 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 2(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '2. sa₂-du₁₁ {d}šara₂', '#lem: sadug[offerings]; TN', '3. iti 1(u) 2(diš)-kam', '#lem: itud[moon]; n; n', '4. ki gu-du-du-ta', '#lem: ki[place]; PN', '5. kišib₃ ka-ku₃', '#lem: kišib[seal]; PN', '@reverse', '1. mu si-ma-num₂{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
#
#
# P100627 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ beginning broken', '1ʾ. [...] da-[...]', '#lem: AN; PN', '2ʾ. 1(barig) 3(ban₂) er₁₁-ra-a', '#lem: n; n; PN', '3ʾ. 1(barig) 3(ban₂) a-ba-ki-ni', '#lem: n; n; PN', '4ʾ. 1(barig) 3(ban₂) lugal-ezem', '#lem: n; n; PN', '5ʾ. 1(barig) 3(ban₂) al-lu', '#lem: n; n; PN', '6ʾ. 1(barig) 3(ban₂) lu₂-{d}nin-šubur', '#lem: n; n; PN', '7ʾ. kikken₂ sa₂-du₁₁ [...]', '#lem: kinkin[miller]; sadug[offerings]; AN', '8ʾ. 1(barig) a-gu-gu# [...]', '#lem: n; PN; AN', '@reverse', '1. 1(barig) ur-{d}ma-mi', '#lem: n; PN', '2. 1(barig) ur-gu₂?-de₃?-na', '#lem: n; PN', '3. 2(barig) ur-{d}er₃-ra šu-i', '#lem: n; PN; šuʾi[barber]', '4. 1(barig) 3(ban₂) ša₃-ad-da ma₂-lah₅', '#lem: n; n; PN; malah[sailor]', '5. 5(ban₂) ur-saga i₃-du₈', '#lem: n; X; idu[doorkeeper]', '6. 1(barig) 1(ban₂) ad-da-mu nu-{geš}kiri₆', '#lem: n; n; PN; nukirik[gardener]', '7. 1(barig) 3(ban₂) pa₃-da nu-{geš}kiri₆', '#lem: n; n; PN; nukirik[gardener]', '8. 2(barig) lu₂-saga aga₃-us₂', '#lem: n; X; agaʾus[soldier]', '9. 3(ban₂) ur-{d}gilgamesₓ(|BIL₃.GA.MES|) [...]', '#lem: n; PN; AN', '10. 1(barig) 5(ban₂) 3(diš) lugal-a₂-zi-da [...]', '#lem: n; n; n; PN; AN', '$ rest broken']]}
#
#
# P100628 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ beginning broken', '1ʾ. [...] numun', '#lem: AN; numun[seed]', '2ʾ. ur-{d}geštin-an-ka', '#lem: PN', '3ʾ. [...] 1(u) 8(aš) x x še gur', '#lem: AN; n; n; u; u; še[barley]; gur[unit]', '4ʾ. ur-{d}nin-šubur nu-banda₃', '#lem: PN; nubanda[overseer]', '5ʾ. kišib₃ lu₂-eb-gal', '#lem: kišib[seal]; PN', '@reverse', '1. giri₃ lugal-mas-su', '#lem: ŋiri[foot]; PN', '2. 2(geš₂) 1(u) 4(aš) še gur', '#lem: n; n; n; še[barley]; gur[unit]', '3. ur-{geš}gigir nu-banda₃-gu₄', '#lem: PN; PN', '4. kišib₃ ur-{d}en-lil₂-la₂', '#lem: kišib[seal]; PN', '5. [...] ur-ge₆-par₄', '#lem: AN; PN', '$ rest broken']]}
#
#
# P100641 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. x x x še gur lugal', '#lem: u; u; u; še[barley]; gur[unit]; lugal[king]', '2. sag-nig₂-gur₁₁-ra-kam', '#lem: X', '3. ša₃-bi-ta', '#lem: šag[heart]', '4. 8(aš) gur kišib₃ ur-{d}suen', '#lem: n; gur[unit]; kišib[seal]; PN', '5. 2(aš) 1(barig) 5(ban₂) gur kišib₃ a-du-mu', '#lem: n; n; n; gur[unit]; kišib[seal]; PN', '@reverse', '$ broken']]}
#
#
# P100643 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [n] še gur lugal', '#lem: n; še[barley]; gur[unit]; lugal[king]', '2. maš nu-tuku', '#lem: maš[interest]; tuku[acquire]', '3. mu sag-{d}nanna-zu-še₃', '#lem: mu[year]; PN', '4. ki ur-e₁₁-e dam-gar₃-ta', '#lem: ki[place]; PN; damgar[merchant]', '# in irregular sequence', '@reverse', '1. ur-ba-gara₂', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
#
#
# P100644 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 9(geš₂) 5(u) 4(barig) 2(ban₂) 6(diš) sila₃ še gur lugal', '#lem: n; n; n; n; n; sila[unit]; še[barley]; gur[unit]; lugal[king]', '3. a₂ ma₂ hun-ga₂', '#lem: a[arm]; ma[ship]; huŋ[hire]', '4. 2(u) 7(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '5. esir₂-a sa₁₀-a', '#lem: esir[bitumen]; X', '6. 1(u) 2(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '7. {geš}mi-ri₂-za', '#lem: miriza[plank]', '@reverse', '1. sa₁₀-a', '#lem: X', '2. ki ARAD₂-ta', '#lem: ki[place]; PN', '3. lugal-e-ba-<an>-sa₆', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '5. mu bad₃ ba-du₃', '#lem: mu[year]; bad[wall]; du[build]']]}
#
#
# P100645 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 3(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '2. a₂ ma₂ hun-ga₂', '#lem: a[arm]; ma[ship]; huŋ[hire]', '3. i₇ e₃-ka', '#lem: id[river]; e[chaff]', '4. ki šabra bu₃-u₂-du-ta', '#lem: ki[place]; šabra[administrator]; PN', '@reverse', '1. lugal-e-ba-an-sa₆', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu ša-aš-ru{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P100653 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(barig) 3(ban₂) dabin gu saga', '#lem: n; n; dabin[semolina]; gu[cord]; sag[rare]', '2. kišib₃ šeš-kal-la-ta zi-zi-dam', '#lem: kišib[seal]; PN; PN', '@reverse']]}
#
#
# P100656 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(aš) 1(barig) 4(ban₂) kaš du gur lugal', '#lem: n; n; n; kaš[beer]; du[go]; gur[unit]; lugal[king]', '2. zi-ga nin₉-tur-tur-ra', '#lem: ziga[expenditure]; PN', '3. ki si-NE-e-ta', '#lem: ki[place]; PN', '@reverse', '$ blank']]}
#
#
# P100658 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...] 6(aš) <kaš> saga sa₂-du₁₁', '#lem: AN; n; kaš[beer]; sag[rare]; sadug[offerings]', '2. 8(aš) la₂ 1(diš) sila₃ du diri', '#lem: n; lal[small]; n; sila[unit]; du[go]; dirig[exceed]', '3. 3(aš) saga elam-še₃', '#lem: n; sag[rare]; GN', '4. u₄ 1(u) 5(diš)-kam', '#lem: ud[sun]; n; n', '@reverse', '1. ki [...]-la-ta', '#lem: ki[place]; PN', '2. [...]-kal-la', '#lem: u', '3. [...]', '#lem: AN']]}
#
#
# P100661 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]-ka', '#lem: PN', '2. 6(aš)#? du ka e₂-sanga?', '#lem: n; du[go]; kag[mouth]; X', '3. o o o saga elam-še₃ du₁₁-ga', '#lem: u; u; u; sag[rare]; GN; duga[affliction]', '4. u₄ 1(u) la₂ 1(diš@t)-kam', '#lem: ud[sun]; n; lal[small]; n', '5. 4(aš) la₂ 4(diš) sila₃ du diri', '#lem: n; lal[small]; n; sila[unit]; du[go]; dirig[exceed]', '6. o o o saga du diri', '#lem: u; u; u; sag[rare]; du[go]; dirig[exceed]', '7. o o o saga elam-še₃ du₁₁?', '#lem: u; u; u; sag[rare]; GN; dug[pot]', '8. u₄ 1(u)-kam', '#lem: ud[sun]; n', '@reverse', '1. 1(aš) du sa₂-du₁₁', '#lem: n; du[go]; sadug[offerings]', '2. 2(aš) saga 7(aš) du diri', '#lem: n; sag[rare]; n; du[go]; dirig[exceed]', '3. u₄ 1(u) 1(diš)-kam', '#lem: ud[sun]; n; n', '4. u₄ 1(u) 2(diš) nu-tuku', '#lem: ud[sun]; n; n; tuku[acquire]', '5.  ki# {d}šara₂-a-zi-ta', '#lem: ki[place]; PN', '6. kišib₃ a-kal-la', '#lem: kišib[seal]; PN', '7. mu# lu-lu-bu-um{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '8. [...]', '#lem: AN', '@seal 1', '$(not given)']]}
#
#
# P100670 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(ban₂) zi₃-gu [...] lugal', '#lem: n; zidgu[flour]; AN; lugal[king]', '2. 1(ban₂) zi₃ [...]', '#lem: n; zid[flour]; AN', '3. 1(barig) kaš dida saga', '#lem: n; kaš[beer]; dida[wort]; sag[rare]', '4. 1(barig) kaš dida du', '#lem: n; kaš[beer]; dida[wort]; du[go]', '5. 1(u) 5(diš) ku₆ kun-zi-[da]', '#lem: n; n; kud[fish]; kunzida[weir]', '@reverse', '1. 1(ban₂) [...]', '#lem: n; AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. ša₃-gal [...] maš [...] mu', '#lem: šaggal[food]; AN; maš[interest]; AN; mu[year]', '5. [...]-še₃', '#lem: DN', '6. [...]', '#lem: AN', '7. [...]', '#lem: AN']]}
#
#
# P100672 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(ban₂) 5(diš) sila₃ zu₂-lum', '#lem: n; n; sila[unit]; zulum[date]', '2. 1(barig) kaš dida du', '#lem: n; kaš[beer]; dida[wort]; du[go]', '3. 1(barig) kaš dida saga 1(ban₂) 5(diš) sila₃ <kaš du>', '#lem: n; kaš[beer]; dida[wort]; sag[rare]; n; n; sila[unit]; kaš[beer]; du[go]', '4. 1(barig) 3(ban₂) dabin', '#lem: n; n; dabin[semolina]', '5. 2(diš) sila₃ i₃-nun', '#lem: n; sila[unit]; inun[ghee]', '6. 2(diš) sila₃ ga-ar₃', '#lem: n; sila[unit]; gaʾar[cheese]', '7. x sila₃ i₃-nun du₁₀-ga', '#lem: u; sila[unit]; inun[ghee]; dug[good]', '8. x sila₃ i₃-gu du₁₀-ga', '#lem: u; sila[unit]; X; dug[good]', '9. [x] sila₃ bappir du₁₀-ga', '#lem: u; sila[unit]; bappir[~beer]; dug[good]', '$ rest broken', '@reverse', '$ beginning broken', '1ʾ. [x sila₃] eša', '#lem: u; sila[unit]; eša[flour]', '2ʾ. [...] zi₃ dub-dub', '#lem: AN; zid[flour]; dubdub[~flour]', '3ʾ. [...] 2(ban₂) zi₃-gu du', '#lem: AN; n; zidgu[flour]; du[go]', '4ʾ. 1(diš) sila₃ i₃-nun', '#lem: n; sila[unit]; inun[ghee]', '5ʾ. 1(diš) sila₃ ga-ar₃', '#lem: n; sila[unit]; gaʾar[cheese]', '6ʾ. 1(diš) sila₃ bappir du₁₀-ga', '#lem: n; sila[unit]; bappir[~beer]; dug[good]', '7ʾ. siskur₂ ša₃ e₂-a', '#lem: siškur[prayer]; šag[heart]; e[house]', '8ʾ. [...] 3(ban₂) zi₃ gur', '#lem: AN; n; zid[flour]; gur[unit]', '9ʾ. [...] 3(ban₂) eša', '#lem: AN; n; eša[flour]', '10ʾ. [...] 3(ban₂) zi₃ dub-dub', '#lem: AN; n; zid[flour]; dubdub[~flour]', '@left', '1. [mu {d}x]-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]']]}
#
#
# P100673 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 8(diš) {geš}a-ra ma₂ 4(u) gur', '#lem: n; ara[~boat]; ma[ship]; n; gur[unit]', '2. še-ta sa₁₀-a', '#lem: še[barley]; X', '3. 3(u) 7(aš) gu₂ 4(u) 2(diš) ma-na mangaga', '#lem: n; n; gu[pulse]; n; n; mana[unit]; mangaga[fibers]', '4. 3(aš) 3(barig) 6(diš) sila₃ dabin gur', '#lem: n; n; n; sila[unit]; dabin[semolina]; gur[unit]', '5. 6(aš) 4(barig) 1(ban₂) kaš du gur', '#lem: n; n; n; kaš[beer]; du[go]; gur[unit]', '6. 2(ban₂) 8(diš) sila₃ eša', '#lem: n; n; sila[unit]; eša[flour]', '7. 1(ban₂) 5(diš) sila₃ zi₃-sig₁₅', '#lem: n; n; sila[unit]; zidsig[flour]', '@reverse', '1. ki ARAD₂-ta', '#lem: ki[place]; PN', '2. lu₂-sa₆-i₃-zu', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '$ blank space', '4. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P100675 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(barig) 3(ban₂) 5(diš) sila₃ {u₂}gamun₂ babbar', '#lem: n; n; n; sila[unit]; X; babbar[white]', '2. 1(ban₂) {u₂}gamun₂ ge₆', '#lem: n; X; ŋi[night]', '3. 2(aš) 1(barig) še-lu₂ gur', '#lem: n; n; šelu[coriander]; gur[unit]', '4. 1(aš) gu₂-gal gur', '#lem: n; gugal[inspector]; gur[unit]', '5. 8(diš) sila₃ gu₂-tur', '#lem: n; sila[unit]; gutur[lentil?]', '6. ki lu₂-{d}šara₂ lu₂ tir-ta', '#lem: ki[place]; PN; lu[person]; tir[forest]', '@reverse', '$ blank space', '1. mu us₂-sa a-ra₂ 3(diš@t)-kam si-mu-ru-um{ki} ba-hul', '#lem: mu[year]; us[follow]; ara[times]; n; GN; hulu[bad]']]}
#
#
# P100678 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) zu₂-lum gur lugal', '#lem: n; zulum[date]; gur[unit]; lugal[king]', '2. lu₂-bulug₃-ga₂', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '4. kišib₃ a-kal-la', '#lem: kišib[seal]; PN', '@reverse', '1. mu e₂ puzur₄-da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]', '$ blank space']]}
#
#
# P100681 {'domesticated_animal': ['#lem: n; udu[sheep]; n; n; maš[goat]']}
#
#
# P100691 {'domesticated_animal': ['#lem: u; udunita[ram]; barsuga[~sheep]']}
#
#
# P100699 {'dead_animal': ['#lem: n; udunita[ram]; uš[die]; barŋal[~sheep]']}
#
#
# P100739 {'domesticated_animal': ['#lem: n; šu[hand]; gud[ox]']}
#
#
# P100746 {'domesticated_animal': ['#lem: n; n; gud[ox]; niga[fattened]']}
#
#
# P100749 {'domesticated_animal': ['#lem: n; ab[cow]; ga[milk]']}
#
#
# P100751 {'domesticated_animal': ['#lem: n; udu[sheep]; barŋal[~sheep]']}
#
#
# P100752 {'domesticated_animal': ['#lem: n; n; maš[goat]']}
#
#
# P100756 {'domesticated_animal': ['#lem: n; udu[sheep]; barŋal[~sheep]']}
#
#
# P100761 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@object tag', '@obverse', '1. pisan-dub-ba', '#lem: bisaŋdubak[archivist]', '2. sag-nig₂-gur₁₁-ra', '#lem: X', '3. ša₃-bi su-ga', '#lem: šag[heart]; sug[replace]', '4. kas₄ šuš₃', '#lem: kaš[runner]; kuš[official]', '5. i₃-gal₂', '#lem: ŋal[be]', '@reverse', '$blank space', '']]}
#
#
# P100764 {'domesticated_animal': ['#lem: PN; sipad[shepherd]; udu[sheep]; ŋi[night]']}
#
#
# P100766 {'domesticated_animal': ['#lem: ab[cow]; tur[stall]']}
#
#
# P100767 {'domesticated_animal': ['#lem: ab[cow]; tur[stall]']}
#
#
# P100768 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) 2/3(diš) ma-na 8(diš) gin₂ igi 4(diš)-gal₂ ku₃', '#lem: n; šanabi[two-thirds]; mana[unit]; n; giŋ[unit]; igi[face]; n; kug[metal]', '2. ki da-da-ga-ta', '#lem: ki[place]; PN', '3. ur-{d}dumu-zi-da', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '$ broken']]}
#
#
# P100769 {'precious_object': ['#lem: n; mana[unit]; n; n; giŋ[unit]; lal[small]; n; še[barley]; kugbabbar[silver]']}
#
#
# P100771 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. igi 3(diš)-gal₂ 5(diš) še ku₃', '#lem: igi[face]; n; n; še[barley]; kug[metal]', '2. ki {d}šara₂-za-me-ta', '#lem: ki[place]; PN', '3. da-da-ga', '#lem: PN', '@reverse', '1. mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P100774 {'precious_object': ['#lem: n; mana[unit]; n; giŋ[unit]; kugbabbar[silver]']}
#
#
# P100775 {'precious_object': ['#lem: n; mana[unit]; kugbabbar[silver]']}
#
#
# P100776 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) gin₂ ku₃', '#lem: n; giŋ[unit]; kug[metal]', '2. la₂-ia₃ su-ga', '#lem: laʾu[arrears]; sug[replace]', '3. ki ur-{d}en-ki lunga-ta', '#lem: ki[place]; PN; lungak[brewer]', '@reverse', '1. da-da-ga', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš@t)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P100781 {'precious_object': ['#lem: n; n; giŋ[unit]; n; n; n; še[barley]; kugbabbar[silver]']}
#
#
# P100782 {'precious_object': ['#lem: n; giŋ[unit]; kugbabbar[silver]']}
#
#
# P100783 {'precious_object': ['#lem: n; mana[unit]; n; n; giŋ[unit]; lal[small]; n; še[barley]; kugbabbar[silver]']}
#
#
# P100784 {'precious_object': ['#lem: n; mana[unit]; n; n; giŋ[unit]; n; n; n; še[barley]; kugbabbar[silver]']}
#
#
# P100786 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) gin₂ ku₃', '#lem: n; giŋ[unit]; kug[metal]', '2. šu-nir gu₂-<de₃-na>-še₃', '#lem: šunir[emblem]; ON', '3. mu us₂-sa a-ra₂ 1(u) la₂ 1(diš)-kam si-mu-ru-um{ki} ba-hul', '#lem: mu[year]; us[follow]; ara[times]; n; lal[small]; n; GN; hulu[bad]', '@reverse', '$blank space']]}
#
#
# P100788 {'precious_object': ['#lem: n; giŋ[unit]; kugbabbar[silver]']}
#
#
# P100792 {'precious_object': ['#lem: n; šanabi[two-thirds]; giŋ[unit]; n; še[barley]; kugbabbar[silver]']}
#
#
# P100794 {'precious_object': ['#lem: n; giŋ[unit]; kugbabbar[silver]']}
#
#
# P100795 {'precious_object': ['#lem: n; n; giŋ[unit]; kugbabbar[silver]']}
#
#
# P100797 {'precious_object': ['#lem: n; giŋ[unit]; kugbabbar[silver]']}
#
#
# P100798 {'precious_object': ['#lem: šanabi[two-thirds]; mana[unit]; ibiza[loss]; kugsig[gold]; kug[metal]; egal[palace]; e[leave]']}
#
#
# P100799 {'domesticated_animal': ['#lem: mu[year]; en[priest]; DN; maš[goat]; pad[find]']}
#
#
# P100810 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(gešʾu) 8(geš₂) 3(u) sa gu', '#lem: n; n; n; sa[roast]; gu[cord]', '2. ki ensi₂-ta', '#lem: ki[place]; ensik[ruler]', '3. da-da-ga šu ba-ti', '#lem: PN; šu[hand]; teŋ[approach]', '@reverse', '1. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P100811 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [n] 8(aš) gu₂ 2(u) 8(diš) 5/6(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; n; n; mana[unit]; X', '2. mu an-ša-an{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '3. [n] 2(aš) gu₂ 3(u) 4(diš) ma-na siki [...]', '#lem: n; n; gu[pulse]; n; n; mana[unit]; siki[hair]; AN', '4. 1(u) 8(aš) gu₂ 5(u) la₂ 2/3(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; lal[small]; šanabi[two-thirds]; mana[unit]; X', '5. a-ra₂ 1(diš)-kam', '#lem: ara[times]; n', '6. 7(aš) gu₂ 5(u) la₂ 1(diš@t) ma-na [siki ...]', '#lem: n; gu[pulse]; n; lal[small]; n; mana[unit]; siki[hair]; AN', '7. a-ra₂ 2(diš)-kam', '#lem: ara[times]; n', '8. ki ur-e₁₁-e-ta', '#lem: ki[place]; PN', '9. 3(aš) gu₂ 1(u) 3(diš) 2/3(diš) ma-na [siki ...]', '#lem: n; gu[pulse]; n; n; šanabi[two-thirds]; mana[unit]; siki[hair]; AN', '10. a-pi₄-sal₄{ki}-ta', '#lem: GN', '11. [...] 8(diš) [...]', '#lem: AN; n; AN', '@reverse', '1. [...]', '#lem: AN', '2. ki ur-{d}šara₂ [...]', '#lem: ki[place]; PN; AN', '$ blank space', '3. mu us₂-sa an-[ša-an{ki} ba-hul]', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '$ blank space']]}
#
#
# P100813 {'wool': ['#lem: n; gu[pulse]; n; n; mana[unit]; siki[hair]; ŋirgul[~wool]']}
#
#
# P100814 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) 5(aš) gu₂ 3(u) 5(diš) 2/3(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; n; šanabi[two-thirds]; mana[unit]; X', '2. ku₃-bi 2(diš) 1/2(diš) ma-na 3(diš) 1/2(diš) gin₂ 1(u) 2(diš) še', '#lem: kug[metal]; n; n; mana[unit]; n; n; giŋ[unit]; n; n; še[barley]', '3. ki ensi₂-ta', '#lem: ki[place]; ensik[ruler]', '@reverse', '1. ur#?-dumu#-zi-da#', '#lem: X', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '$ blank space']]}
#
#
# P100815 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) gu₂ siki-gi', '#lem: n; gu[pulse]; X', '2. siki udu-lah₅', '#lem: siki[hair]; X', '3. giri₃ kas₄ šuš₃', '#lem: ŋiri[foot]; kaš[runner]; kuš[official]', '4. mu ku₃ gu-za {d}en-lil₂-la₂ ba-dim₂', '#lem: mu[year]; kug[metal]; guza[chair]; PN; dim[create]', '@reverse', '$blank space']]}
#
#
# P100816 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(aš) gu₂ 2(u) 8(diš) ma-na siki', '#lem: n; gu[pulse]; n; n; mana[unit]; siki[hair]', '2. siki udu-lah₅', '#lem: siki[hair]; X', '3. kas₄ šu ba-ti', '#lem: kaš[runner]; šu[hand]; teŋ[approach]', '@reverse', '4. mu en-mah-gal-an-na [en {d}nanna ba-hun-ga₂]', '#lem: mu[year]; PN; en[priest]; DN; huŋ[hire]']]}
#
#
# P100819 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 1(diš) tug₂ sag uš-bar', '#lem: n; n; tug[textile]; saŋ[head]; ušbar[weaver]', '2. tug₂ sa-gi₄-a', '#lem: tug[textile]; X', '3. ki ur-ama-na-ta', '#lem: ki[place]; PN', '4. ur-{d}iškur', '#lem: PN', '5. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. mu {d}nanna kar-zi-da a-ra₂ 2(diš)-kam', '#lem: mu[year]; DN; TN; ara[times]; n', '2. e₂-a-na kuₓ(KWU147)', '#lem: e[house]; X']]}
#
#
# P100820 {'wild_animal': ['#lem: X; šagia[cup-bearer]']}
#
#
# P100837 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. ki lugal-šu-nir', '#lem: ki[place]; PN', '4. ma-an-zi-zi', '#lem: X', '5. u₃ ur-{d}suen-ta', '#lem: u[and]; PN', '6. gu-du-du', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. iti ezem-{d}[...]', '#lem: itud[moon]; PN', '3. [mu] {d}šu-{d}suen# [ma]-da [za-ab-ša]-li[{ki} ba-hul]', '#lem: mu[year]; TN; mada[land]; GN; hulu[bad]']]}
#
#
# P100838 {'precious_object': ['#lem: kugsig[gold]; huš[reddish]']}
#
#
# P100967 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P100968 {'domesticated_animal': ['#lem: n; gud[ox]; n; udu[sheep]']}
#
#
# P100971 {'domesticated_animal': ['#lem: u; n; AN; u; gud[ox]']}
#
#
# P100972 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P100973 {'domesticated_animal': ['#lem: n; gud[ox]; ŋešdu[breeder]; gunu[speckled]']}
#
#
# P100974 {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]; X']}
#
#
# P100975 {'domesticated_animal': ['#lem: n; sila[lamb]; FN']}
#
#
# P100976 {'wild_animal': ['#lem: namraʾak[booty]; kur[mountain]; MAR.TU[westerner]']}
#
#
# P100977 {'domesticated_animal': ['#lem: n; n; lal[small]; n; udu[sheep]; niga[fattened]; gudeʾusa[drover]']}
#
#
# P100978 {'domesticated_animal': ['#lem: n; sila[lamb]; niga[fattened]; FN']}
#
#
# P100980 {'domesticated_animal': ['#lem: n; udu[sheep]']}
#
#
# P100981 {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P100982 {'domesticated_animal': ['#lem: n; gukkal[sheep]; n; gukkal[sheep]; babbar[white]']}
#
#
# P100983 {'domesticated_animal': ['#lem: n; sila[lamb]; PN']}
#
#
# P100984 {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]']}
#
#
# P100985 {'wild_animal': ['#lem: n; amar[young]; mašda[gazelle]; munus[woman]']}
#
#
# P100986 {'domesticated_animal': ['#lem: u; maš[goat]; niga[fattened]; n; us[side]']}
#
#
# P100987 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '@column 1', '$ beginning broken', '1ʾ. [...] x [...] kaš# saga 4(diš) sila₃ zi₃-gu-ta', '#lem: AN; u; AN; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '2ʾ. 1(u) guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '3ʾ. lu₂ šimašgi{ki}-me-eš₃', '#lem: lu[person]; X', '4ʾ. 1(diš) guruš 6(diš) sila₃ kaš saga 4(diš) sila₃ zi₃-gu', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '5ʾ. lu₂ ša-ri-it-x{ki}', '#lem: lu[person]; u', '6ʾ. 2(diš) guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '7ʾ. lu₂ hu-ur-ti{ki}-me-eš₂', '#lem: lu[person]; X', '8ʾ. 1(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '9ʾ. kas₄-me-eš₂ ša₃ en-nu-ga₂', '#lem: X; šag[heart]; ennuŋ[imprisonment]', '10ʾ. giri₃# be-li₂-šar', '#lem: ŋiri[foot]; PN', '11ʾ. ki na-we-er-dingir', '#lem: ki[place]; X', '12ʾ. 4(ban₂)# kaš saga#', '#lem: n; kaš[beer]; sag[rare]', '13ʾ. n(barig)# kaš du', '#lem: X; kaš[beer]; du[go]', '14ʾ. 2(ban₂)# zi₃-gu saga', '#lem: n; zidgu[flour]; sag[rare]', '15ʾ. 5(ban₂) dabin sa', '#lem: n; dabin[semolina]; sa[roast]', '16ʾ. 2(u)# sa gi', '#lem: n; sa[roast]; gi[reed]', '17ʾ. 1(aš)# gu₂# {geš}ma-nu', '#lem: n; gu[pulse]; manu[wood]', '18ʾ. ba#-na#-na# lu₂ mar-ha-ši{ki}', '#lem: PN; lu[person]; GN', '19ʾ. 1(diš)# guruš 1(ban₂) kaš saga 1(ban₂) zi₃-gu', '#lem: n; ŋuruš[male]; n; kaš[beer]; sag[rare]; n; zidgu[flour]', '20ʾ. 2(diš)# guruš 1(ban₂) kaš saga 5(diš) sila₃ zi₃-gu-ta', '#lem: n; ŋuruš[male]; n; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '21ʾ. [sukkal] eme#-bala lu₂ mar-ha-ši{ki} gub-ba-me-eš₂', '#lem: sukkal[secretary]; emebala[translator]; lu[person]; GN; gub[stand]', '22ʾ. n(ban₂)# kaš saga# 1(ban₂) zi₃-gu saga#', '#lem: X; kaš[beer]; sag[rare]; n; zidgu[flour]; sag[rare]', '23ʾ. [n(u)] sa gi', '#lem: X; sa[roast]; gi[reed]', '24ʾ. a#-ri-du-bu-uk', '#lem: PN', '25ʾ. [x] dumu-ni 5(diš) sila₃ kaš saga 5(diš) sila₃ zi₃-gu-ta', '#lem: u; dumu[child]; n; sila[unit]; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '26ʾ. x guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: u; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '27ʾ. [x] guruš# 2(diš) sila₃ zi₃', '#lem: u; ŋuruš[male]; n; sila[unit]; zid[flour]', '28ʾ. [...] 1(diš)# sila₃# kaš', '#lem: AN; n; sila[unit]; kaš[beer]', '29ʾ. [...] x zi₃#', '#lem: AN; u; zid[flour]', '30ʾ. [...]', '#lem: AN', '@column 2', '$ beginning broken', '1ʾ. lu₂#-[...]', '#lem: PN', '2ʾ. 2(diš) guruš 4(diš) [...]', '#lem: n; ŋuruš[male]; n; AN', '3ʾ. lu₂ hu-la#-[...]', '#lem: lu[person]; u', '4ʾ. 2(ban₂) kaš saga [...]', '#lem: n; kaš[beer]; sag[rare]; AN', '5ʾ. 3(diš) x [...]', '#lem: n; u; AN', '6ʾ. hu-un-zi [...]', '#lem: X; AN', '7ʾ. 1(ban₂) kaš 1(ban₂) zi₃ 2(diš) [...]', '#lem: n; kaš[beer]; n; zid[flour]; n; AN', '8ʾ. še₃-eš₃-ba mar-[...]', '#lem: X; u', '9ʾ. 5(diš) sila₃ kaš 5(diš) sila₃ [...]', '#lem: n; sila[unit]; kaš[beer]; n; sila[unit]; AN', '10ʾ. ša-bu-lum sag-[...]', '#lem: X; PN', '11ʾ. 2(ban₂) kaš sag 1(ban₂) zi₃-gu# saga#', '#lem: n; kaš[beer]; saŋ[head]; n; zidgu[flour]; sag[rare]', '12ʾ. 5(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '13ʾ. kal-ad-da', '#lem: kal[rare]', '14ʾ. 5(diš) lu₂ us₂-sa-ni-me-[eš₂]', '#lem: n; lu[person]; X', '15ʾ. 1(barig) 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '16ʾ. 2(ban₂) kaš saga 2(ban₂) kaš du', '#lem: n; kaš[beer]; sag[rare]; n; kaš[beer]; du[go]', '17ʾ. 1(ban₂) zi₃-gu saga', '#lem: n; zidgu[flour]; sag[rare]', '18ʾ. 1(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '19ʾ. a-bu-du₁₀ lu₂ ma-ri₂{ki}', '#lem: PN; lu[person]; GN', '20ʾ. 2(diš) ab-ba 1(ban₂) kaš 5(diš) sila₃ zi₃ 1(diš) x [x]', '#lem: n; abba[father]; n; kaš[beer]; n; sila[unit]; zid[flour]; n; u; u', '21ʾ. 1(u) 5( ...
#
#
# P100988 {'domesticated_animal': ['#lem: AN; gud[ox]; gunu[speckled]']}
#
#
# P100989 {'domesticated_animal': ['#lem: n; amar[young]; gud[ox]; ga[milk]; MAR.TU[westerner]']}
#
#
# P100990 {'domesticated_animal': ['#lem: mu[year]; en[priest]; TN; GN; maš[goat]; pad[find]']}
#
#
# P100992 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(u) 1(diš) [...]{mušen}', '#lem: n; n; u', '2. sag? x x x', '#lem: saŋ[head]; u; u; u', '3. 1(u) 5(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '4. a-da-na-ah mušen-du₃', '#lem: PN; mušendu[bird-catcher]', '5. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '6. {d}šul-gi-si₂-im-ti', '#lem: PN', '@reverse', '1. a₂-bi₂-li₂-a', '#lem: PN', '2. i₃-dab₅', '#lem: dab[seize]', '3. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '4. mu us₂-sa bad₃ ma-da ba-du₃', '#lem: mu[year]; us[follow]; bad[wall]; mada[land]; du[build]']]}
#
#
# P100993 {'dead_animal': ['#lem: n; PN; uš[die]']}
#
#
# P100994 {'domesticated_animal': ['#lem: n; uzud[goat]; X']}
#
#
# P100995 {'domesticated_animal': ['#lem: n; maš[goat]']}
#
#
# P100996 {'domesticated_animal': ['#lem: n; udu[sheep]; ud[sun]; n; n']}
#
#
# P100997 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P100998 {'wild_animal': ['#lem: n; udu[sheep]; X; hursaŋ[mountain]']}
#
#
# P100999 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...] 6(geš₂) 2(u) 3(diš)? [...]', '#lem: AN; n; n; n; AN', '4. 2(gešʾu) 5(geš₂) [...]', '#lem: n; n; AN', '5. kišib₃ siki-ba sipa-e-ne', '#lem: kišib[seal]; sikiba[ration]; FN', '@reverse', '1. [iti] ses-da-gu₇-[ta]', '#lem: itud[moon]; MN', '2. [iti] ezem-{d}nin-a-zu-še₃', '#lem: itud[moon]; MN', '3. zi-ga', '#lem: ziga[expenditure]', '4. ki ur-ku₃-nun-na', '#lem: ki[place]; PN', '5. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@left', '1. [...] 5(u) la₂ 1(diš) [...]', '#lem: AN; n; lal[small]; n; AN']]}
#
#
# P101000 {'domesticated_animal': ['#lem: n; mašgal[goat]']}
#
#
# P101001 {'domesticated_animal': ['#lem: n; ab[cow]']}
#
#
# P101002 {'domesticated_animal': ['#lem: n; udu[sheep]']}
#
#
# P101003 {'domesticated_animal': ['#lem: n; n; gud[ox]']}
#
#
# P101004 {'domesticated_animal': ['#lem: n; n; gud[ox]; niga[fattened]']}
#
#
# P101005 {'domesticated_animal': ['#lem: n; udu[sheep]']}
#
#
# P101006 {'domesticated_animal': ['#lem: n; n; udu[sheep]']}
#
#
# P101007 {'domesticated_animal': ['#lem: n; n; sila[lamb]; kiŋgia[messenger]']}
#
#
# P101008 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P101009 {'domesticated_animal': ['#lem: n; uzud[goat]']}
#
#
# P101010 {'domesticated_animal': ['#lem: n; lal[small]; n; udu[sheep]']}
#
#
# P101011 {'domesticated_animal': ['#lem: kišib[seal]; sipad[shepherd]; sila[lamb]; ga[milk]']}
#
#
# P101012 {'leather_object': ['#lem: n; suhub[boots]; dušia[stone]; eban[pair]']}
#
#
# P101013 {'domesticated_animal': ['#lem: šag[heart]; mu.DU[delivery]; udu[sheep]; AN']}
#
#
# P101014 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) {uruda}ha-bu₃-da', '#lem: n; habuda[hoe]', '2. ša₃ umma{ki}-ta', '#lem: šag[heart]; GN', '3. a-pi₄-sal{ki}-še₃', '#lem: GN', '# sic sal', '4. giri₃ [...]-ku₅ sukkal', '#lem: ŋiri[foot]; u; sukkal[secretary]', '5. x-x-nanna', '#lem: u', '@reverse', '1. ki al-lu-ta', '#lem: ki[place]; PN', '2. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '3. mu {d}šu-{d}suen lugal', '#lem: mu[year]; TN; lugal[king]']]}
#
#
# P101015 {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]; n; sila[lamb]']}
#
#
# P101016 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sag[rare]']}
#
#
# P101017 {'domesticated_animal': ['#lem: n; mašgal[goat]; X; u[grass]']}
#
#
# P101019 {'domesticated_animal': ['#lem: AN; n; udu[sheep]; šugid[~animal]']}
#
#
# P101021 {'domesticated_animal': ['#lem: n; sila[lamb]; gaba[chest]']}
#
#
# P101225 {'domesticated_animal': ['#lem: n; n; n; kuš[skin]; udu[sheep]']}
#
#
# P101265 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) geš tug₂', '#lem: n; ŋeš[tree]; tug[textile]', '2. 1(diš) geš nig₂-ar₃ mar-ma-tag', '#lem: n; ŋeš[tree]; niŋara[groats]; X', '3. 1(diš) geš ha-gar-gu₇', '#lem: n; ŋeš[tree]; X', '4. 1(diš) geš uzu', '#lem: n; ŋeš[tree]; uzu[flesh]', '5. 1(barig) 3(ban₂) zi₃-gu', '#lem: n; n; zidgu[flour]', '6. 1(barig) 3(ban₂) dabin', '#lem: n; n; dabin[semolina]', '7. 4(ban₂) 4(diš) sila₃ ninda du', '#lem: n; n; sila[unit]; ninda[bread]; du[go]', '8. 1(diš) dug dida saga', '#lem: n; dug[pot]; dida[wort]; sag[rare]', '9. 1(diš) dug dida du', '#lem: n; dug[pot]; dida[wort]; du[go]', '10. [...]', '#lem: AN', '@reverse', '1. ma₂-a gar-ra', '#lem: ma[ship]; ŋar[place]', '2. gu₃-du₈-a{ki}-še₃', '#lem: GN', '3. iti ezem-{d}šu-{d}suen', '#lem: itud[moon]; MN', '4. u₄ 1(u) 4(diš) ba-zal-la', '#lem: ud[sun]; n; n; zal[pass]']]}
#
#
# P101296 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) eme₆ dusu₂', '#lem: n; eme[donkey]; dusu[equid]', '2. 1(diš) amar eme₆ dusu₂', '#lem: n; amar[young]; eme[donkey]; dusu[equid]', '3. anše babbar₂', '#lem: anše[equid]; babbar[white]', '4. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '5. bar-bar', '#lem: bar[outside]', '@reverse', '1. i₃-dab₅', '#lem: dab[seize]', '2. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '3. mu [dumu-munus] lugal ensi₂ [an]-ša-an-na-ke₄ ba-an-tuku', '#lem: mu[year]; dumumunus[daughter]; lugal[king]; ensik[ruler]; PN; tuku[acquire]']]}
#
#
# P101297 {'domesticated_animal': ['#lem: n; gud[ox]; n; udu[sheep]; n; maš[goat]']}
#
#
# P101298 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P101299 {'domesticated_animal': ['#lem: n; lal[small]; n; gud[ox]; hi[mix]']}
#
#
# P101300 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P101301 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) {anše}kunga₂-nita₂', '#lem: n; X', '2. 3(diš) {anše}kunga₂ munus', '#lem: n; kunga[equid]; munus[woman]', '3. mu-kuₓ(DU) lugal', '#lem: mu.DU[delivery]; lugal[king]', '4. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '@reverse', '1. lugal-an-na-ab-tum₂ i₃-dab₅', '#lem: PN; dab[seize]', '2. iti ses-da-gu₇', '#lem: itud[moon]; MN', '3. mu si-mu-ru-um{ki} u₃ lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; u[and]; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P101302 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P101303 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. a₂ geš-gar-ra nu-{geš}kiri₆', '#lem: a[arm]; X; nukirik[gardener]', '3. iti-ta u₄ 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '4. 1(geš₂) 2(u) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '5. ba-gu-um mušen-du₃', '#lem: PN; mušendu[bird-catcher]', '6. iti-ta u₄ 1(u) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '@reverse', '1. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '2. {d}šul-gi-si₂-im-tum', '#lem: PN', '3. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '4. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '5. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P101304 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-nita₂ iri niga', '#lem: n; X; iri[city]; niga[fattened]', '2. 1(diš) šah₂-nita₂ iri geš niga', '#lem: n; X; iri[city]; ŋeš[tree]; niga[fattened]', '3. ur-{d}lugal-edin-ka', '#lem: PN', '4. 5(diš) šah₂-NE-tur-nita₂ iri', '#lem: n; X; iri[city]', '5. 5(diš) šah₂-NE-tur-nita₂', '#lem: n; X', '@reverse', '1. sa₂-du₁₁ ku₅-ta', '#lem: sadug[offerings]; kud[cut]', '2. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '3. ur-{d}lugal-edin-ka i₃-dab₅', '#lem: PN; dab[seize]', '4. iti ezem-an-na', '#lem: itud[moon]; MN', '5. mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul', '#lem: mu[year]; GN; u[and]; GN; hulu[bad]']]}
#
#
# P101305 {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]; X']}
#
#
# P101306 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P101307 {'wild_animal': ['#lem: n; n; n; mašda[gazelle]']}
#
#
# P101308 {'domesticated_animal': ['#lem: n; udu[sheep]; n; u[ewe]']}
#
#
# P101309 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '2. puzur₄-eš₁₈?-dar?', '#lem: X', '3. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '4. {d}šul-gi-si₂-im-tum', '#lem: PN', '@reverse', '1. {d}šul-gi-i₃-li₂ i₃-dab₅', '#lem: PN; dab[seize]', '2. iti ezem-{d}nin-a-zu', '#lem: itud[moon]; MN', '3. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P101310 {'domesticated_animal': ['#lem: n; maš[goat]']}
#
#
# P101311 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P101312 {'domesticated_animal': ['#lem: n; n; n; udu[sheep]; niga[fattened]']}
#
#
# ...
#
#
# P128118 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P128127 {'domesticated_animal': ['#lem: n; maš[goat]']}
#
#
# P128392 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P128393 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) la₂ 1(diš) gur₄{mušen}', '#lem: n; lal[small]; n; X', '2. lu₂-uru₁₁{ki}', '#lem: PN', '3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU) {d}šul-gi-si₂-im-tum', '#lem: mu.DU[delivery]; PN', '5. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '6. iti u₅-bi₂-gu₇', '#lem: itud[moon]; MN', '7. mu us₂-sa si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; us[follow]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P128394 {'domesticated_animal': ['#lem: n; sila[lamb]; utuda[offspring]; X']}
#
#
# P128395 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. e₂-u₆-še₃', '#lem: X', '3. 2(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '4. be-li₂-ba-ni', '#lem: PN', '5. iti-ta u₄ 3(u) la₂ 1(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; lal[small]; n; zal[pass]', '@reverse', '1. mu-kuₓ(DU)#', '#lem: mu.DU[delivery]', '2. {d}šul-gi-si₂-im-ti', '#lem: PN', '3. a₂-bi₂-li₂-a', '#lem: PN', '4. i₃-dab₅', '#lem: dab[seize]', '5. iti ezem-{d}nin-a-zu', '#lem: itud[moon]; MN', '6. mu us₂-sa e₂ puzur₄#-iš-{d}da-gan ba-du₃', '#lem: mu[year]; us[follow]; e[house]; X; du[build]']]}
#
#
# P128396 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P128810 {'domesticated_animal': ['#lem: n; gukkal[sheep]']}
#
#
# P128811 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P128812 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P128813 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) uz babbar', '#lem: n; uz[duck]; babbar[white]', '2. ka-ku₃-ga', '#lem: X', '3. mu-kuₓ(DU) {d}šul-gi-<si₂>-im-tum', '#lem: mu.DU[delivery]; PN', '@reverse', '1. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '2. iti-ta u₄ 1(u) 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '3. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '4. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš) kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; kam[tune?]; hulu[bad]']]}
#
#
# P128814 {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
#
#
# P128815 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]']}
#
#
# P128816 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) uz-tur', '#lem: n; PN', '2. ka-ku₃-ga', '#lem: X', '3. iti-ta u₄ 2(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '4. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '@reverse', '1. {d}šul-gi-i₃-li₂', '#lem: PN', '2. i₃-dab₅', '#lem: dab[seize]', '3. iti ezem-mah', '#lem: itud[moon]; MN', '4. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P129415 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; n; maš[goat]']}
#
#
# P129416 {'domesticated_animal': ['#lem: n; sila[lamb]']}
#
#
# P129417 {'Unknown': [['#project: epsd2/u3adm/p007', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. e₂-gal-[ta] e₃-a', '#lem: egal[palace]; e[leave]', '3. iti-[ta u₄ 2(u) 1(diš) ba]-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. 1(diš) [...]', '#lem: n; AN', '5. 4(diš) [...]', '#lem: n; AN', '6. [...]', '#lem: AN', '7. iti-ta u₄ 2(u) 2(diš) ba-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '8. 1(u) 3(diš) ir₇{mušen}', '#lem: n; n; irsaŋ[pigeon]', '9. la₂-ia₃ su-ga i-bi₂-{d}suen', '#lem: laʾu[arrears]; sug[replace]; PN', '10. iti-ta u₄ 2(u) 3(diš) ba-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '@reverse', '1. 3(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. bar-bar-li₂-a', '#lem: PN', '3. iti-ta u₄ 2(u) 4(diš) ba-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU) {d}šul-gi-si₂-im-<<im>>-tum', '#lem: mu.DU[delivery]; PN', '5. [a₂]-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '6. iti ses-da-gu₇', '#lem: itud[moon]; MN', '7. mu ša-aš-šu₂-ru-um{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P129418 {'domesticated_animal': ['#lem: n; n; udu[sheep]; u[grass]']}
#
#
# P129451 {'domesticated_animal': ['#lem: n; mašgal[goat]']}
#
#
# P129452 {'domesticated_animal': ['#lem: n; maš[goat]']}
#
#
# P129454 {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
#
#
# P129455 {'Unknown': [['#project: epsd2/u3adm/p007', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-ze₂-da munus geš-gi u₃-tu-da', '#lem: n; X; munus[woman]; gi[thicket]; utuda[offspring]', '2. 1(diš) uz-tur', '#lem: n; PN', '3. nig₂-gu₇ nin-ga₂-še₃', '#lem: niŋgu[food]; nin[lady]', '4. 2(diš) šah₂-ze₂-da munus geš-gi u₃-tu-da', '#lem: n; X; munus[woman]; gi[thicket]; utuda[offspring]', '5. 1(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '6. ri-ri-ga-am₃', '#lem: deg[collect]', '@reverse', '1. e₂-gal-la ba-an-kuₓ(KWU147)', '#lem: egal[palace]; X', '2. iti-ta u₄ 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '3. zi-ga', '#lem: ziga[expenditure]', '4. a₂-bi₂-la-tum', '#lem: PN', '5. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '6. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃ mu us₂-sa-bi', '#lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]']]}
#
#
# P129456 {'Unknown': [['#project: epsd2/u3adm/p007', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur-nita₂-geš-gi', '#lem: n; X', '2. iti-ta u₄ 2(u) 4(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '3. 1(diš) šah₂-NE-tur-nita₂-geš-gi', '#lem: n; X', '4. 5(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '5. u₄ dab₅-ba-še₃', '#lem: ud[sun]; dab[seize]', '6. iti-ta 2(u) 6(diš) ba-ra-zal', '#lem: itud[moon]; n; n; zal[pass]', '7. nig₂-gu₇ nin-ga₂-še₃', '#lem: niŋgu[food]; nin[lady]', '8. 1(diš) ir₇{mušen} 1(diš) tu-gur₄{mušen}', '#lem: n; irsaŋ[pigeon]; n; tugur[dove]', '@reverse', '1. iti-ta u₄ 2(u) 7(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '2. a-ra₂ 1(diš)-kam', '#lem: ara[times]; n', '3. iti-ta u₄ 2(u) 8(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. a-ra₂ 2(diš)-kam', '#lem: ara[times]; n', '5. 1(diš) šah₂-NE-tur munus-geš-gi', '#lem: n; X; munusŋešgi[performer]', '6. iti-ta u₄ 2(u) 9(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '7. ri-ri-ga-am₃ e₂-gal-la ba-an-kuₓ(KWU147)', '#lem: deg[collect]; egal[palace]; X', '8. zi-ga a₂-bi₂-la-tum', '#lem: ziga[expenditure]; PN', '9. iti še-sag₁₁-ku₅ min?', '#lem: itud[moon]; MN; min[two]', '10. mu us₂#-sa#? e₂#? |KA×KAR₂.ŠA|#? iš#-da#-gan# [...] mu us₂-sa-bi', '#lem: mu[year]; us[follow]; e[house]; X; X; AN; mu[year]; us[follow]']]}
#
#
# P129463 {'Unknown': [['#project: epsd2/u3adm/p007', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur munus geš-gi', '#lem: n; X; munus[woman]; gi[thicket]', '2. ša₃ e₂-gal-še₃', '#lem: šag[heart]; egal[palace]', '3. 7(diš) uz-tur', '#lem: n; PN', '4. 1(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '@reverse', '1. ri-ri-ga-am₃', '#lem: deg[collect]', '2. e₂-gal-la ba-an-kuₓ(KWU147)', '#lem: egal[palace]; X', '3. iti-ta u₄ 1(u) 9(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. zi-ga {d}šul-gi-i₃-li₂', '#lem: ziga[expenditure]; PN', '5. iti ezem-me-ki-gal₂', '#lem: itud[moon]; MN', '6. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P129700 {'leather_object': ['#lem: n; suhub[boots]; dušia[stone]; eban[pair]']}
#
#
# P130407 {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]; n; maš[goat]']}
#
#
# P134153 {'domesticated_animal': ['#lem: AN; udu[sheep]; u']}
#
#
# P134154 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; gudeʾusa[drover]']}
#
#
# P134155 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) uz-tur', '#lem: n; PN', '2. 5(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '3. nig₂-gu₇ nin-ga₂-še₃', '#lem: niŋgu[food]; nin[lady]', '4. iti-ta u₄ 8(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '@reverse', '1. zi-ga', '#lem: ziga[expenditure]', '2. a₂-bi₂-li₂-a', '#lem: PN', '3. iti u₅-bi₂-gu₇', '#lem: itud[moon]; MN', '4. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; us[follow]; e[house]; X; du[build]']]}
#
#
# P134156 {'domesticated_animal': ['#lem: n; gud[ox]']}
#
#
# P134233 {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
#
#
# P134234 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. [...] x a', '#lem: AN; u; a[water]', '5. [...] x', '#lem: AN; u', '@reverse', '1. ki šu-ku₈-bu-um-ma-ta', '#lem: ki[place]; PN', '2. iti šu-eš-ša', '#lem: itud[moon]; MN', '3. mu dumu-munus lugal ensi₂ an-ša-an{ki}-ke₄ ba-an-tuku', '#lem: mu[year]; dumumunus[daughter]; lugal[king]; ensik[ruler]; GN; tuku[acquire]', '5. gaba-ri', '#lem: gabari[copy]']]}
#
#
# P134235 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; PN']}
#
#
# P134759 {'precious_object': ['#lem: n; zahum[basin]; kugbabbar[silver]']}
#
#
# P134840 {'domesticated_animal': ['#lem: n; mašgal[goat]']}
#
#
# P134841 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) uz-tur', '#lem: n; PN', '2. ši-ba-at-e₂-kur', '#lem: PN', '3. iti-ta u₄ 1(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. 1(diš) uz-tur', '#lem: n; PN', '@reverse', '$ beginning broken', '1ʾ. [...]', '#lem: AN', '2ʾ. u₄ [x]-kam#', '#lem: ud[sun]; n', '3ʾ. mu-kuₓ(DU) {d}šul-gi-si₂-im-tum', '#lem: mu.DU[delivery]; PN', '4ʾ. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '5ʾ. iti ezem-an-na', '#lem: itud[moon]; MN', '6ʾ. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P134842 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) uz-tur', '#lem: n; PN', '2. 2(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '3. nir-i₃-da-gal₂', '#lem: PN', '4. iti-ta u₄ 1(u) 1(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '@reverse', '1. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '2. ur-{d}lugal-edin-ka i₃-dab₅', '#lem: PN; dab[seize]', '3. iti maš-da₃-gu₇', '#lem: itud[moon]; MN', '4. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P135036 {'domesticated_animal': ['#lem: n; gud[ox]; niga[fattened]']}
#
#
# P135037 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; siškur[prayer]']}
#
#
# P135038 {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
#
#
# P135039 {'domesticated_animal': ['#lem: u; udu[sheep]; niga[fattened]']}
#
#
# P135044 {'dead_animal': ['#lem: uš[die]; egal[palace]; X']}
#
#
# P135045 {'dead_animal': ['#lem: uš[die]; egal[palace]; X']}
#
#
# P135046 {'domesticated_animal': ['#lem: n; udu[sheep]; u[grass]']}
#
#
# P135048 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; kašdea[banquet]; lugal[king]']}
#
#
# P135050 {'domesticated_animal': ['#lem: maš[goat]; u']}
#
#
# P135051 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) maš₂-nita₂', '#lem: n; X', '2. 2(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '3. 2(diš) u₈ 2(diš) udu-nita₂', '#lem: n; u[ewe]; n; udunita[ram]', '4. iti ezem-{d}šul-gi', '#lem: itud[moon]; MN', '5. 4(diš) u₈ 2(diš) udu-nita₂', '#lem: n; u[ewe]; n; udunita[ram]', '6. 2(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '7. iti šu-eš-ša', '#lem: itud[moon]; MN', '@reverse', '1. sa₂-du₁₁ {d}be-la-at-suh-ner', '#lem: sadug[offerings]; PN', '2. {d}be-la-at-dar-ra-ba-an', '#lem: PN', '3. an-nu-ni-tum', '#lem: PN', '4. u₃ {d}ul-ma-ši-tum', '#lem: u[and]; DN', '5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]']]}
#
#
# P142143 {'domesticated_animal': ['#lem: n; udu[sheep]; AN; n; maš[goat]']}
#
#
# P142367 {'domesticated_animal': ['#lem: u; maš[goat]; ud[sun]; n']}
#
#
# P142399 {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(diš) uz-tur', '#lem: n; PN', '2. nin₉ ṣe-lu-uš-{d}da-gan ba-du₃', '#lem: nin[sister]; X; du[build]', '3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. {d}šul-gi-si₂-im-tum-še₃', '#lem: PN', '2. a₂-bi₂-li₂-a i₃-dab₅', '#lem: PN; dab[seize]', '3. iti šu-eš₅-ša', '#lem: itud[moon]; MN', '4. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃ mu us₂-sa-bi', '#lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]']]}
#
#
# P142400 {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. dam ur-nigar', '#lem: dam[spouse]; PN', '3. 5(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '4. 1(u) 4(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '5. [x] x x ki', '#lem: u; u; u; ki[place]', '6. [...]', '#lem: AN', '@reverse', '1. [...]', '#lem: AN', '2. {d}[šul-gi]-si₂#-im-tum', '#lem: PN', '3. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '4. iti ses-da-gu₇', '#lem: itud[moon]; MN', '5. mu si-mu-ru-um{ki} u₃ lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-ma-aš ba-hul', '#lem: mu[year]; GN; u[and]; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P142401 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; sadug[offerings]']}
#
#
# P142619 {'domesticated_animal': ['#lem: n; udu[sheep]; niga[fattened]; n; sila[lamb]; niga[fattened]']}
#
#
# P142856 {'domesticated_animal': ['#lem: n; sila[lamb]; X; DN']}
#
#
# P101020 {'Unknown': [['#project: epsd2/u3adm/p014', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '2. bu-ra-an-hu-uh₂-ra-an', '#lem: X', '3. 1(geš₂) 2(u) 5(diš) sa gi', '#lem: n; n; n; sa[roast]; gi[reed]', '4. sahar-ki-ti', '#lem: X', '5. 1(u) sa gi 1(diš) dam', '#lem: n; sa[roast]; gi[reed]; n; dam[spouse]', '6. 3(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '@reverse', '1. šu ba ur ha-ab-ru', '#lem: šu[hand]; ba[allot]; ur[dog]; PN', '2. nu-banda₃ nir-i₃-da-gal₂', '#lem: nubanda[overseer]; PN', '$ blank space', '3. iti ezem-{d}nin-<a>-zu', '#lem: itud[moon]; MN', '@seal 1', '1. lu₂-du₁₀-ga', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ...', '#lem: dumu[child]; AN', '']]}
#
#
# P101022 {'domesticated_animal': ['#lem: n; šaggal[food]; udu[sheep]; PN']}
#
#
# P101018 {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf: lang sux', '@object tag', '@obverse', '1. 5(ban₂)# 8(diš) sila₃ zi₃ gazₓ(KUM)', '#lem: n; n; sila[unit]; zid[flour]; X', '2. sa₂-du₁₁ ku₅-da', '#lem: sadug[offerings]; PN', '3. bala er₃-ra-gar₃?', '#lem: bala[turn]; PN', '4. mu šu-šu#-mu-dar#', '#lem: mu[year]; X', '@reverse', '1. kišib₃# tu#-ra#-am-[i₃-li₂]', '#lem: kišib[seal]; PN', '2. [...] x', '#lem: AN; u', '3. iti# a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '4. mu e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; e[house]; TN; GN; du[build]', '@seal 1', '$ (illegible)', '']]}
#
#
# P101266 {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ blank space', '1. [...] x?', '#lem: AN; u', '2. [...] i₃? u₂-ki-im#', '#lem: AN; i[oil]; X', '3. [...] i₃-du₁₀-ga a-du₁₀', '#lem: AN; X; dug[good]', '4. nu-banda₃', '#lem: nubanda[overseer]', '5. ni-zu-hu#? šu-ma#-[x]', '#lem: X; u', '@reverse', '1. [...]-x-ga-ru#-ti-im#', '#lem: u', '2. [...] ti-u₂-ga₂?#', '#lem: AN; X', '3. [...] lu₂#-a₂-zi-da', '#lem: AN; PN', '$ blank space']]}

# %%
# Print unknowns
print("Transactions with unknown labels:\n")
num = 0

for item in unknowns:
    print(item[0], item[1])
    print("\n")
    num += 1

print("Number without labels:", num)
# Out:
# Transactions with unknown labels:
#
# P100230 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) lulim-nita₂', '#lem: n; X', '2. šu-gid₂ e₂-muhaldim', '#lem: šugid[~animal]; emuhaldim[kitchen]', '3. mu gar₃-du-ne-še₃', '#lem: mu[year]; gardu[soldier]', '4. dingir-dan sukkal maškim', '#lem: PN; sukkal[secretary]; maškim[administrator]', '5. iti u₄ 1(u) 6(diš) ba-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '6. ki lu₂-dingir-ra-ta', '#lem: ki[place]; PN', '@reverse', '1. ba-zi', '#lem: PN', '$ 1 line blank', '2. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '3. mu en eridu{ki} ba-hun', '#lem: mu[year]; en[priest]; GN; huŋ[hire]', '@left', '1. 1(diš)', '#lem: n']]}
#
#
# P100292 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(ban₂) zi₃-gu', '#lem: n; zidgu[flour]', '2. sa₂-du₁₁-še₃', '#lem: sadug[offerings]', '3. ki lu₂-du₁₀-ga-mu#-ta#', '#lem: ki[place]; PN', '4. ba-zi', '#lem: PN', '@reverse', '1. iti ezem-an-na', '#lem: itud[moon]; MN', '2. mu e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; e[house]; TN; GN; du[build]', '@left', '1. [...]', '#lem: AN']]}
#
#
# P100342 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) 3(u) sa gi', '#lem: n; n; sa[roast]; gi[reed]', '2. 2(ban₂) še ad-nu-ha', '#lem: n; še[barley]; X', '3. nu-banda₃ nir-i₃-da-gal₂', '#lem: nubanda[overseer]; PN', '@reverse', '1. giri₃ ur-mes', '#lem: ŋiri[foot]; PN', '@seal 1', '$ (legend broken)']]}
#
#
# P100346 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 4(geš₂) 2(u) 4(diš) sa gi', '#lem: n; n; n; sa[roast]; gi[reed]', '2. sa₂-du₁₁ ur-{d}ba-ba₆', '#lem: sadug[offerings]; PN', '3. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '@reverse', '1. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '2. mu us₂-sa bad₃ ba-du₃', '#lem: mu[year]; us[follow]; bad[wall]; du[build]', '@seal 1', '$seal illegible']]}
#
#
# P100375 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '@reverse', '$ blank space', '# seal impression', '@seal 1', '$ illegible']]}
#
#
# P100377 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) gu₂ gi', '#lem: n; gu[pulse]; gi[reed]', '2. [ṣe]-li#-{d}iškur', '#lem: X', '@reverse', '@seal 1', '$ (legend broken)']]}
#
#
# P100378 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '2. ur-{geš}gigir ugula', '#lem: PN; ugula[overseer]', '@reverse', '@seal 1', '$ (legend broken)']]}
#
#
# P100501 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) guruš', '#lem: n; ŋuruš[male]', '2. u₄ 1(geš₂) 3(u)-še₃', '#lem: ud[sun]; n; n', '3. ma₂-da-ga-aš ma₂ gid₂-da', '#lem: X; ma[ship]; gid[long]', '4. 1(diš) guruš nagar', '#lem: n; ŋuruš[male]; nagar[carpenter]', '5. u₄ 2(u) 5(diš) [...-še₃]', '#lem: ud[sun]; n; n; DN', '6. [...]', '#lem: AN', '@reverse', '1. ki lu₂-[...]', '#lem: ki[place]; PN', '2. kišib₃ lugal-[...]', '#lem: kišib[seal]; PN', '3. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
#
#
# P100564 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(geš₂) 5(u) 5(diš) guruš u₄ 1(diš)-še₃', '#lem: n; n; n; ŋuruš[male]; ud[sun]; n', '2. ki ba-saga gu-za-la₂-ta', '#lem: ki[place]; X; guzala[official]', '3. lu₂-sa₆-i₃-zu', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P100584 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(geš₂) 4(u) guruš u₄ 1(diš)-še₃', '#lem: n; n; ŋuruš[male]; ud[sun]; n', '2. ki-su₇ a-ša₃ muru₁₃? gub-ba', '#lem: kisur[locus]; ašag[field]; FN; gub[stand]', '3. ugula ur-e₂-nun', '#lem: ugula[overseer]; PN', '@reverse', '1. kišib₃ da-a-gi₄', '#lem: kišib[seal]; PN', '2. mu {d}amar-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]', '@seal 1', '$ (legend broken)']]}
#
#
# P100591 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 8(diš) guruš u₄ 1(diš)-še₃', '#lem: n; ŋuruš[male]; ud[sun]; n', '2. a-ša₃ {geš}ma-nu-ta', '#lem: ašag[field]; manu[wood]', '3. še zi-ga', '#lem: še[barley]; ziga[expenditure]', '4. giri₃ nigar{gar}-ki-du₁₀', '#lem: ŋiri[foot]; PN', '@reverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. mu us₂-sa an-ša-an{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
#
#
# P100608 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) guruš dub-sar', '#lem: n; ŋuruš[male]; dubsar[scribe]', '2. u₄ 4(u) 5(diš)-še₃', '#lem: ud[sun]; n; n', '3. uri₅{ki}-ma gub-ba', '#lem: GN; gub[stand]', '4. ugula a-a-gi-na', '#lem: ugula[overseer]; PN', '@reverse', '1. la-ni-mu i₃-dab₅', '#lem: PN; dab[seize]', '$ blank space', '# seal impression', '2. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ illegible']]}
#
#
# P100615 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(ban₂) še lugal', '#lem: n; še[barley]; lugal[king]', '2. [...] kas₄', '#lem: AN; kaš[runner]', '3. kišib₃ ur-{d}šara₂ ša₁₃-dub-ba', '#lem: kišib[seal]; PN; bisaŋdubak[archivist]', '@reverse', '@seal 1', '$ (legend broken)']]}
#
#
# P100616 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) še gur 1(barig)-ta', '#lem: n; še[barley]; gur[unit]; n', '2. 3(aš) 1(barig) ziz₂ gur', '#lem: n; n; ziz[emmer]; gur[unit]', '3. ur-{d}a-šar₂', '#lem: PN', '@reverse', '1. ARAD₂-e₂-ninnu', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
#
#
# P100617 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [x] 4(aš) ziz₂ gur si-sa₂-ta', '#lem: u; n; ziz[emmer]; gur[unit]; sisa[fair]', '2. 3(aš) gig gur', '#lem: n; kib[wheat]; gur[unit]', '3. ki lu₂-{d}er₃-ra-ta', '#lem: ki[place]; PN', '@reverse', '1. ha-lu₅-lu₅', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
#
#
# P100618 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) 4(barig) še gur lugal', '#lem: n; n; še[barley]; gur[unit]; lugal[king]', '2. 2(aš) 2(barig) ziz₂ gur', '#lem: n; n; ziz[emmer]; gur[unit]', '3. kišib₃ ARAD₂', '#lem: kišib[seal]; arad[slave]', '4. ki ur-{d}suen-ta', '#lem: ki[place]; PN', '5. 1(barig) še lugal-gaba', '#lem: n; še[barley]; PN', '6. šu+nigin 4(aš) 2(barig) še gur', '#lem: šuniŋin[total]; n; n; še[barley]; gur[unit]', '@left', '1. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. ur-{d}[...]', '#lem: PN', '2. iti [...]', '#lem: itud[moon]; AN', '3. mu [...]{ki} ba-hul', '#lem: mu[year]; u; hulu[bad]', '']]}
#
#
# P100623 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(aš) 1(barig) 3(ban₂) 2(diš) sila₃ še gur', '#lem: n; n; n; n; sila[unit]; še[barley]; gur[unit]', '2. [mu]-kuₓ(DU) {d}šara₂', '#lem: mu.DU[delivery]; TN', '3. [...] a-pi₄-sal₄{ki}', '#lem: AN; GN', '4. [u₃ muš]-bi-an{ki}', '#lem: u[and]; GN', '5. [gu₂]-de₃-na-ta', '#lem: GN', '$ rest broken', '@reverse', '$ blank space', '1. mu [...]{ki} ba-hul', '#lem: mu[year]; u; hulu[bad]']]}
#
#
# P100625 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 2(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '2. sa₂-du₁₁ {d}šara₂', '#lem: sadug[offerings]; TN', '3. iti 1(u) 2(diš)-kam', '#lem: itud[moon]; n; n', '4. ki gu-du-du-ta', '#lem: ki[place]; PN', '5. kišib₃ ka-ku₃', '#lem: kišib[seal]; PN', '@reverse', '1. mu si-ma-num₂{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
#
#
# P100627 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ beginning broken', '1ʾ. [...] da-[...]', '#lem: AN; PN', '2ʾ. 1(barig) 3(ban₂) er₁₁-ra-a', '#lem: n; n; PN', '3ʾ. 1(barig) 3(ban₂) a-ba-ki-ni', '#lem: n; n; PN', '4ʾ. 1(barig) 3(ban₂) lugal-ezem', '#lem: n; n; PN', '5ʾ. 1(barig) 3(ban₂) al-lu', '#lem: n; n; PN', '6ʾ. 1(barig) 3(ban₂) lu₂-{d}nin-šubur', '#lem: n; n; PN', '7ʾ. kikken₂ sa₂-du₁₁ [...]', '#lem: kinkin[miller]; sadug[offerings]; AN', '8ʾ. 1(barig) a-gu-gu# [...]', '#lem: n; PN; AN', '@reverse', '1. 1(barig) ur-{d}ma-mi', '#lem: n; PN', '2. 1(barig) ur-gu₂?-de₃?-na', '#lem: n; PN', '3. 2(barig) ur-{d}er₃-ra šu-i', '#lem: n; PN; šuʾi[barber]', '4. 1(barig) 3(ban₂) ša₃-ad-da ma₂-lah₅', '#lem: n; n; PN; malah[sailor]', '5. 5(ban₂) ur-saga i₃-du₈', '#lem: n; X; idu[doorkeeper]', '6. 1(barig) 1(ban₂) ad-da-mu nu-{geš}kiri₆', '#lem: n; n; PN; nukirik[gardener]', '7. 1(barig) 3(ban₂) pa₃-da nu-{geš}kiri₆', '#lem: n; n; PN; nukirik[gardener]', '8. 2(barig) lu₂-saga aga₃-us₂', '#lem: n; X; agaʾus[soldier]', '9. 3(ban₂) ur-{d}gilgamesₓ(|BIL₃.GA.MES|) [...]', '#lem: n; PN; AN', '10. 1(barig) 5(ban₂) 3(diš) lugal-a₂-zi-da [...]', '#lem: n; n; n; PN; AN', '$ rest broken']]}
#
#
# P100628 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ beginning broken', '1ʾ. [...] numun', '#lem: AN; numun[seed]', '2ʾ. ur-{d}geštin-an-ka', '#lem: PN', '3ʾ. [...] 1(u) 8(aš) x x še gur', '#lem: AN; n; n; u; u; še[barley]; gur[unit]', '4ʾ. ur-{d}nin-šubur nu-banda₃', '#lem: PN; nubanda[overseer]', '5ʾ. kišib₃ lu₂-eb-gal', '#lem: kišib[seal]; PN', '@reverse', '1. giri₃ lugal-mas-su', '#lem: ŋiri[foot]; PN', '2. 2(geš₂) 1(u) 4(aš) še gur', '#lem: n; n; n; še[barley]; gur[unit]', '3. ur-{geš}gigir nu-banda₃-gu₄', '#lem: PN; PN', '4. kišib₃ ur-{d}en-lil₂-la₂', '#lem: kišib[seal]; PN', '5. [...] ur-ge₆-par₄', '#lem: AN; PN', '$ rest broken']]}
#
#
# P100641 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. x x x še gur lugal', '#lem: u; u; u; še[barley]; gur[unit]; lugal[king]', '2. sag-nig₂-gur₁₁-ra-kam', '#lem: X', '3. ša₃-bi-ta', '#lem: šag[heart]', '4. 8(aš) gur kišib₃ ur-{d}suen', '#lem: n; gur[unit]; kišib[seal]; PN', '5. 2(aš) 1(barig) 5(ban₂) gur kišib₃ a-du-mu', '#lem: n; n; n; gur[unit]; kišib[seal]; PN', '@reverse', '$ broken']]}
#
#
# P100643 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [n] še gur lugal', '#lem: n; še[barley]; gur[unit]; lugal[king]', '2. maš nu-tuku', '#lem: maš[interest]; tuku[acquire]', '3. mu sag-{d}nanna-zu-še₃', '#lem: mu[year]; PN', '4. ki ur-e₁₁-e dam-gar₃-ta', '#lem: ki[place]; PN; damgar[merchant]', '# in irregular sequence', '@reverse', '1. ur-ba-gara₂', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
#
#
# P100644 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 9(geš₂) 5(u) 4(barig) 2(ban₂) 6(diš) sila₃ še gur lugal', '#lem: n; n; n; n; n; sila[unit]; še[barley]; gur[unit]; lugal[king]', '3. a₂ ma₂ hun-ga₂', '#lem: a[arm]; ma[ship]; huŋ[hire]', '4. 2(u) 7(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '5. esir₂-a sa₁₀-a', '#lem: esir[bitumen]; X', '6. 1(u) 2(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '7. {geš}mi-ri₂-za', '#lem: miriza[plank]', '@reverse', '1. sa₁₀-a', '#lem: X', '2. ki ARAD₂-ta', '#lem: ki[place]; PN', '3. lugal-e-ba-<an>-sa₆', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '5. mu bad₃ ba-du₃', '#lem: mu[year]; bad[wall]; du[build]']]}
#
#
# P100645 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 3(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '2. a₂ ma₂ hun-ga₂', '#lem: a[arm]; ma[ship]; huŋ[hire]', '3. i₇ e₃-ka', '#lem: id[river]; e[chaff]', '4. ki šabra bu₃-u₂-du-ta', '#lem: ki[place]; šabra[administrator]; PN', '@reverse', '1. lugal-e-ba-an-sa₆', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu ša-aš-ru{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P100653 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(barig) 3(ban₂) dabin gu saga', '#lem: n; n; dabin[semolina]; gu[cord]; sag[rare]', '2. kišib₃ šeš-kal-la-ta zi-zi-dam', '#lem: kišib[seal]; PN; PN', '@reverse']]}
#
#
# P100656 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(aš) 1(barig) 4(ban₂) kaš du gur lugal', '#lem: n; n; n; kaš[beer]; du[go]; gur[unit]; lugal[king]', '2. zi-ga nin₉-tur-tur-ra', '#lem: ziga[expenditure]; PN', '3. ki si-NE-e-ta', '#lem: ki[place]; PN', '@reverse', '$ blank']]}
#
#
# P100658 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...] 6(aš) <kaš> saga sa₂-du₁₁', '#lem: AN; n; kaš[beer]; sag[rare]; sadug[offerings]', '2. 8(aš) la₂ 1(diš) sila₃ du diri', '#lem: n; lal[small]; n; sila[unit]; du[go]; dirig[exceed]', '3. 3(aš) saga elam-še₃', '#lem: n; sag[rare]; GN', '4. u₄ 1(u) 5(diš)-kam', '#lem: ud[sun]; n; n', '@reverse', '1. ki [...]-la-ta', '#lem: ki[place]; PN', '2. [...]-kal-la', '#lem: u', '3. [...]', '#lem: AN']]}
#
#
# P100661 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]-ka', '#lem: PN', '2. 6(aš)#? du ka e₂-sanga?', '#lem: n; du[go]; kag[mouth]; X', '3. o o o saga elam-še₃ du₁₁-ga', '#lem: u; u; u; sag[rare]; GN; duga[affliction]', '4. u₄ 1(u) la₂ 1(diš@t)-kam', '#lem: ud[sun]; n; lal[small]; n', '5. 4(aš) la₂ 4(diš) sila₃ du diri', '#lem: n; lal[small]; n; sila[unit]; du[go]; dirig[exceed]', '6. o o o saga du diri', '#lem: u; u; u; sag[rare]; du[go]; dirig[exceed]', '7. o o o saga elam-še₃ du₁₁?', '#lem: u; u; u; sag[rare]; GN; dug[pot]', '8. u₄ 1(u)-kam', '#lem: ud[sun]; n', '@reverse', '1. 1(aš) du sa₂-du₁₁', '#lem: n; du[go]; sadug[offerings]', '2. 2(aš) saga 7(aš) du diri', '#lem: n; sag[rare]; n; du[go]; dirig[exceed]', '3. u₄ 1(u) 1(diš)-kam', '#lem: ud[sun]; n; n', '4. u₄ 1(u) 2(diš) nu-tuku', '#lem: ud[sun]; n; n; tuku[acquire]', '5.  ki# {d}šara₂-a-zi-ta', '#lem: ki[place]; PN', '6. kišib₃ a-kal-la', '#lem: kišib[seal]; PN', '7. mu# lu-lu-bu-um{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '8. [...]', '#lem: AN', '@seal 1', '$(not given)']]}
#
#
# P100670 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(ban₂) zi₃-gu [...] lugal', '#lem: n; zidgu[flour]; AN; lugal[king]', '2. 1(ban₂) zi₃ [...]', '#lem: n; zid[flour]; AN', '3. 1(barig) kaš dida saga', '#lem: n; kaš[beer]; dida[wort]; sag[rare]', '4. 1(barig) kaš dida du', '#lem: n; kaš[beer]; dida[wort]; du[go]', '5. 1(u) 5(diš) ku₆ kun-zi-[da]', '#lem: n; n; kud[fish]; kunzida[weir]', '@reverse', '1. 1(ban₂) [...]', '#lem: n; AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. ša₃-gal [...] maš [...] mu', '#lem: šaggal[food]; AN; maš[interest]; AN; mu[year]', '5. [...]-še₃', '#lem: DN', '6. [...]', '#lem: AN', '7. [...]', '#lem: AN']]}
#
#
# P100672 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(ban₂) 5(diš) sila₃ zu₂-lum', '#lem: n; n; sila[unit]; zulum[date]', '2. 1(barig) kaš dida du', '#lem: n; kaš[beer]; dida[wort]; du[go]', '3. 1(barig) kaš dida saga 1(ban₂) 5(diš) sila₃ <kaš du>', '#lem: n; kaš[beer]; dida[wort]; sag[rare]; n; n; sila[unit]; kaš[beer]; du[go]', '4. 1(barig) 3(ban₂) dabin', '#lem: n; n; dabin[semolina]', '5. 2(diš) sila₃ i₃-nun', '#lem: n; sila[unit]; inun[ghee]', '6. 2(diš) sila₃ ga-ar₃', '#lem: n; sila[unit]; gaʾar[cheese]', '7. x sila₃ i₃-nun du₁₀-ga', '#lem: u; sila[unit]; inun[ghee]; dug[good]', '8. x sila₃ i₃-gu du₁₀-ga', '#lem: u; sila[unit]; X; dug[good]', '9. [x] sila₃ bappir du₁₀-ga', '#lem: u; sila[unit]; bappir[~beer]; dug[good]', '$ rest broken', '@reverse', '$ beginning broken', '1ʾ. [x sila₃] eša', '#lem: u; sila[unit]; eša[flour]', '2ʾ. [...] zi₃ dub-dub', '#lem: AN; zid[flour]; dubdub[~flour]', '3ʾ. [...] 2(ban₂) zi₃-gu du', '#lem: AN; n; zidgu[flour]; du[go]', '4ʾ. 1(diš) sila₃ i₃-nun', '#lem: n; sila[unit]; inun[ghee]', '5ʾ. 1(diš) sila₃ ga-ar₃', '#lem: n; sila[unit]; gaʾar[cheese]', '6ʾ. 1(diš) sila₃ bappir du₁₀-ga', '#lem: n; sila[unit]; bappir[~beer]; dug[good]', '7ʾ. siskur₂ ša₃ e₂-a', '#lem: siškur[prayer]; šag[heart]; e[house]', '8ʾ. [...] 3(ban₂) zi₃ gur', '#lem: AN; n; zid[flour]; gur[unit]', '9ʾ. [...] 3(ban₂) eša', '#lem: AN; n; eša[flour]', '10ʾ. [...] 3(ban₂) zi₃ dub-dub', '#lem: AN; n; zid[flour]; dubdub[~flour]', '@left', '1. [mu {d}x]-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]']]}
#
#
# P100673 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 8(diš) {geš}a-ra ma₂ 4(u) gur', '#lem: n; ara[~boat]; ma[ship]; n; gur[unit]', '2. še-ta sa₁₀-a', '#lem: še[barley]; X', '3. 3(u) 7(aš) gu₂ 4(u) 2(diš) ma-na mangaga', '#lem: n; n; gu[pulse]; n; n; mana[unit]; mangaga[fibers]', '4. 3(aš) 3(barig) 6(diš) sila₃ dabin gur', '#lem: n; n; n; sila[unit]; dabin[semolina]; gur[unit]', '5. 6(aš) 4(barig) 1(ban₂) kaš du gur', '#lem: n; n; n; kaš[beer]; du[go]; gur[unit]', '6. 2(ban₂) 8(diš) sila₃ eša', '#lem: n; n; sila[unit]; eša[flour]', '7. 1(ban₂) 5(diš) sila₃ zi₃-sig₁₅', '#lem: n; n; sila[unit]; zidsig[flour]', '@reverse', '1. ki ARAD₂-ta', '#lem: ki[place]; PN', '2. lu₂-sa₆-i₃-zu', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '$ blank space', '4. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P100675 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(barig) 3(ban₂) 5(diš) sila₃ {u₂}gamun₂ babbar', '#lem: n; n; n; sila[unit]; X; babbar[white]', '2. 1(ban₂) {u₂}gamun₂ ge₆', '#lem: n; X; ŋi[night]', '3. 2(aš) 1(barig) še-lu₂ gur', '#lem: n; n; šelu[coriander]; gur[unit]', '4. 1(aš) gu₂-gal gur', '#lem: n; gugal[inspector]; gur[unit]', '5. 8(diš) sila₃ gu₂-tur', '#lem: n; sila[unit]; gutur[lentil?]', '6. ki lu₂-{d}šara₂ lu₂ tir-ta', '#lem: ki[place]; PN; lu[person]; tir[forest]', '@reverse', '$ blank space', '1. mu us₂-sa a-ra₂ 3(diš@t)-kam si-mu-ru-um{ki} ba-hul', '#lem: mu[year]; us[follow]; ara[times]; n; GN; hulu[bad]']]}
#
#
# P100678 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) zu₂-lum gur lugal', '#lem: n; zulum[date]; gur[unit]; lugal[king]', '2. lu₂-bulug₃-ga₂', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '4. kišib₃ a-kal-la', '#lem: kišib[seal]; PN', '@reverse', '1. mu e₂ puzur₄-da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]', '$ blank space']]}
#
#
# P100761 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@object tag', '@obverse', '1. pisan-dub-ba', '#lem: bisaŋdubak[archivist]', '2. sag-nig₂-gur₁₁-ra', '#lem: X', '3. ša₃-bi su-ga', '#lem: šag[heart]; sug[replace]', '4. kas₄ šuš₃', '#lem: kaš[runner]; kuš[official]', '5. i₃-gal₂', '#lem: ŋal[be]', '@reverse', '$blank space', '']]}
#
#
# P100768 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) 2/3(diš) ma-na 8(diš) gin₂ igi 4(diš)-gal₂ ku₃', '#lem: n; šanabi[two-thirds]; mana[unit]; n; giŋ[unit]; igi[face]; n; kug[metal]', '2. ki da-da-ga-ta', '#lem: ki[place]; PN', '3. ur-{d}dumu-zi-da', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '$ broken']]}
#
#
# P100771 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. igi 3(diš)-gal₂ 5(diš) še ku₃', '#lem: igi[face]; n; n; še[barley]; kug[metal]', '2. ki {d}šara₂-za-me-ta', '#lem: ki[place]; PN', '3. da-da-ga', '#lem: PN', '@reverse', '1. mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P100776 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) gin₂ ku₃', '#lem: n; giŋ[unit]; kug[metal]', '2. la₂-ia₃ su-ga', '#lem: laʾu[arrears]; sug[replace]', '3. ki ur-{d}en-ki lunga-ta', '#lem: ki[place]; PN; lungak[brewer]', '@reverse', '1. da-da-ga', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš@t)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P100786 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) gin₂ ku₃', '#lem: n; giŋ[unit]; kug[metal]', '2. šu-nir gu₂-<de₃-na>-še₃', '#lem: šunir[emblem]; ON', '3. mu us₂-sa a-ra₂ 1(u) la₂ 1(diš)-kam si-mu-ru-um{ki} ba-hul', '#lem: mu[year]; us[follow]; ara[times]; n; lal[small]; n; GN; hulu[bad]', '@reverse', '$blank space']]}
#
#
# P100810 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(gešʾu) 8(geš₂) 3(u) sa gu', '#lem: n; n; n; sa[roast]; gu[cord]', '2. ki ensi₂-ta', '#lem: ki[place]; ensik[ruler]', '3. da-da-ga šu ba-ti', '#lem: PN; šu[hand]; teŋ[approach]', '@reverse', '1. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P100811 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [n] 8(aš) gu₂ 2(u) 8(diš) 5/6(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; n; n; mana[unit]; X', '2. mu an-ša-an{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '3. [n] 2(aš) gu₂ 3(u) 4(diš) ma-na siki [...]', '#lem: n; n; gu[pulse]; n; n; mana[unit]; siki[hair]; AN', '4. 1(u) 8(aš) gu₂ 5(u) la₂ 2/3(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; lal[small]; šanabi[two-thirds]; mana[unit]; X', '5. a-ra₂ 1(diš)-kam', '#lem: ara[times]; n', '6. 7(aš) gu₂ 5(u) la₂ 1(diš@t) ma-na [siki ...]', '#lem: n; gu[pulse]; n; lal[small]; n; mana[unit]; siki[hair]; AN', '7. a-ra₂ 2(diš)-kam', '#lem: ara[times]; n', '8. ki ur-e₁₁-e-ta', '#lem: ki[place]; PN', '9. 3(aš) gu₂ 1(u) 3(diš) 2/3(diš) ma-na [siki ...]', '#lem: n; gu[pulse]; n; n; šanabi[two-thirds]; mana[unit]; siki[hair]; AN', '10. a-pi₄-sal₄{ki}-ta', '#lem: GN', '11. [...] 8(diš) [...]', '#lem: AN; n; AN', '@reverse', '1. [...]', '#lem: AN', '2. ki ur-{d}šara₂ [...]', '#lem: ki[place]; PN; AN', '$ blank space', '3. mu us₂-sa an-[ša-an{ki} ba-hul]', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '$ blank space']]}
#
#
# P100814 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) 5(aš) gu₂ 3(u) 5(diš) 2/3(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; n; šanabi[two-thirds]; mana[unit]; X', '2. ku₃-bi 2(diš) 1/2(diš) ma-na 3(diš) 1/2(diš) gin₂ 1(u) 2(diš) še', '#lem: kug[metal]; n; n; mana[unit]; n; n; giŋ[unit]; n; n; še[barley]', '3. ki ensi₂-ta', '#lem: ki[place]; ensik[ruler]', '@reverse', '1. ur#?-dumu#-zi-da#', '#lem: X', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '$ blank space']]}
#
#
# P100815 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) gu₂ siki-gi', '#lem: n; gu[pulse]; X', '2. siki udu-lah₅', '#lem: siki[hair]; X', '3. giri₃ kas₄ šuš₃', '#lem: ŋiri[foot]; kaš[runner]; kuš[official]', '4. mu ku₃ gu-za {d}en-lil₂-la₂ ba-dim₂', '#lem: mu[year]; kug[metal]; guza[chair]; PN; dim[create]', '@reverse', '$blank space']]}
#
#
# P100816 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(aš) gu₂ 2(u) 8(diš) ma-na siki', '#lem: n; gu[pulse]; n; n; mana[unit]; siki[hair]', '2. siki udu-lah₅', '#lem: siki[hair]; X', '3. kas₄ šu ba-ti', '#lem: kaš[runner]; šu[hand]; teŋ[approach]', '@reverse', '4. mu en-mah-gal-an-na [en {d}nanna ba-hun-ga₂]', '#lem: mu[year]; PN; en[priest]; DN; huŋ[hire]']]}
#
#
# P100819 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 1(diš) tug₂ sag uš-bar', '#lem: n; n; tug[textile]; saŋ[head]; ušbar[weaver]', '2. tug₂ sa-gi₄-a', '#lem: tug[textile]; X', '3. ki ur-ama-na-ta', '#lem: ki[place]; PN', '4. ur-{d}iškur', '#lem: PN', '5. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. mu {d}nanna kar-zi-da a-ra₂ 2(diš)-kam', '#lem: mu[year]; DN; TN; ara[times]; n', '2. e₂-a-na kuₓ(KWU147)', '#lem: e[house]; X']]}
#
#
# P100837 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. ki lugal-šu-nir', '#lem: ki[place]; PN', '4. ma-an-zi-zi', '#lem: X', '5. u₃ ur-{d}suen-ta', '#lem: u[and]; PN', '6. gu-du-du', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. iti ezem-{d}[...]', '#lem: itud[moon]; PN', '3. [mu] {d}šu-{d}suen# [ma]-da [za-ab-ša]-li[{ki} ba-hul]', '#lem: mu[year]; TN; mada[land]; GN; hulu[bad]']]}
#
#
# P100987 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '@column 1', '$ beginning broken', '1ʾ. [...] x [...] kaš# saga 4(diš) sila₃ zi₃-gu-ta', '#lem: AN; u; AN; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '2ʾ. 1(u) guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '3ʾ. lu₂ šimašgi{ki}-me-eš₃', '#lem: lu[person]; X', '4ʾ. 1(diš) guruš 6(diš) sila₃ kaš saga 4(diš) sila₃ zi₃-gu', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '5ʾ. lu₂ ša-ri-it-x{ki}', '#lem: lu[person]; u', '6ʾ. 2(diš) guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '7ʾ. lu₂ hu-ur-ti{ki}-me-eš₂', '#lem: lu[person]; X', '8ʾ. 1(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '9ʾ. kas₄-me-eš₂ ša₃ en-nu-ga₂', '#lem: X; šag[heart]; ennuŋ[imprisonment]', '10ʾ. giri₃# be-li₂-šar', '#lem: ŋiri[foot]; PN', '11ʾ. ki na-we-er-dingir', '#lem: ki[place]; X', '12ʾ. 4(ban₂)# kaš saga#', '#lem: n; kaš[beer]; sag[rare]', '13ʾ. n(barig)# kaš du', '#lem: X; kaš[beer]; du[go]', '14ʾ. 2(ban₂)# zi₃-gu saga', '#lem: n; zidgu[flour]; sag[rare]', '15ʾ. 5(ban₂) dabin sa', '#lem: n; dabin[semolina]; sa[roast]', '16ʾ. 2(u)# sa gi', '#lem: n; sa[roast]; gi[reed]', '17ʾ. 1(aš)# gu₂# {geš}ma-nu', '#lem: n; gu[pulse]; manu[wood]', '18ʾ. ba#-na#-na# lu₂ mar-ha-ši{ki}', '#lem: PN; lu[person]; GN', '19ʾ. 1(diš)# guruš 1(ban₂) kaš saga 1(ban₂) zi₃-gu', '#lem: n; ŋuruš[male]; n; kaš[beer]; sag[rare]; n; zidgu[flour]', '20ʾ. 2(diš)# guruš 1(ban₂) kaš saga 5(diš) sila₃ zi₃-gu-ta', '#lem: n; ŋuruš[male]; n; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '21ʾ. [sukkal] eme#-bala lu₂ mar-ha-ši{ki} gub-ba-me-eš₂', '#lem: sukkal[secretary]; emebala[translator]; lu[person]; GN; gub[stand]', '22ʾ. n(ban₂)# kaš saga# 1(ban₂) zi₃-gu saga#', '#lem: X; kaš[beer]; sag[rare]; n; zidgu[flour]; sag[rare]', '23ʾ. [n(u)] sa gi', '#lem: X; sa[roast]; gi[reed]', '24ʾ. a#-ri-du-bu-uk', '#lem: PN', '25ʾ. [x] dumu-ni 5(diš) sila₃ kaš saga 5(diš) sila₃ zi₃-gu-ta', '#lem: u; dumu[child]; n; sila[unit]; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '26ʾ. x guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: u; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '27ʾ. [x] guruš# 2(diš) sila₃ zi₃', '#lem: u; ŋuruš[male]; n; sila[unit]; zid[flour]', '28ʾ. [...] 1(diš)# sila₃# kaš', '#lem: AN; n; sila[unit]; kaš[beer]', '29ʾ. [...] x zi₃#', '#lem: AN; u; zid[flour]', '30ʾ. [...]', '#lem: AN', '@column 2', '$ beginning broken', '1ʾ. lu₂#-[...]', '#lem: PN', '2ʾ. 2(diš) guruš 4(diš) [...]', '#lem: n; ŋuruš[male]; n; AN', '3ʾ. lu₂ hu-la#-[...]', '#lem: lu[person]; u', '4ʾ. 2(ban₂) kaš saga [...]', '#lem: n; kaš[beer]; sag[rare]; AN', '5ʾ. 3(diš) x [...]', '#lem: n; u; AN', '6ʾ. hu-un-zi [...]', '#lem: X; AN', '7ʾ. 1(ban₂) kaš 1(ban₂) zi₃ 2(diš) [...]', '#lem: n; kaš[beer]; n; zid[flour]; n; AN', '8ʾ. še₃-eš₃-ba mar-[...]', '#lem: X; u', '9ʾ. 5(diš) sila₃ kaš 5(diš) sila₃ [...]', '#lem: n; sila[unit]; kaš[beer]; n; sila[unit]; AN', '10ʾ. ša-bu-lum sag-[...]', '#lem: X; PN', '11ʾ. 2(ban₂) kaš sag 1(ban₂) zi₃-gu# saga#', '#lem: n; kaš[beer]; saŋ[head]; n; zidgu[flour]; sag[rare]', '12ʾ. 5(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '13ʾ. kal-ad-da', '#lem: kal[rare]', '14ʾ. 5(diš) lu₂ us₂-sa-ni-me-[eš₂]', '#lem: n; lu[person]; X', '15ʾ. 1(barig) 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '16ʾ. 2(ban₂) kaš saga 2(ban₂) kaš du', '#lem: n; kaš[beer]; sag[rare]; n; kaš[beer]; du[go]', '17ʾ. 1(ban₂) zi₃-gu saga', '#lem: n; zidgu[flour]; sag[rare]', '18ʾ. 1(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '19ʾ. a-bu-du₁₀ lu₂ ma-ri₂{ki}', '#lem: PN; lu[person]; GN', '20ʾ. 2(diš) ab-ba 1(ban₂) kaš 5(diš) sila₃ zi₃ 1(diš) x [x]', '#lem: n; abba[father]; n; kaš[beer]; n; sila[unit]; zid[flour]; n; u; u', '21ʾ. 1(u) 5( ...
#
#
# P100992 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(u) 1(diš) [...]{mušen}', '#lem: n; n; u', '2. sag? x x x', '#lem: saŋ[head]; u; u; u', '3. 1(u) 5(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '4. a-da-na-ah mušen-du₃', '#lem: PN; mušendu[bird-catcher]', '5. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '6. {d}šul-gi-si₂-im-ti', '#lem: PN', '@reverse', '1. a₂-bi₂-li₂-a', '#lem: PN', '2. i₃-dab₅', '#lem: dab[seize]', '3. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '4. mu us₂-sa bad₃ ma-da ba-du₃', '#lem: mu[year]; us[follow]; bad[wall]; mada[land]; du[build]']]}
#
#
# P100999 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...] 6(geš₂) 2(u) 3(diš)? [...]', '#lem: AN; n; n; n; AN', '4. 2(gešʾu) 5(geš₂) [...]', '#lem: n; n; AN', '5. kišib₃ siki-ba sipa-e-ne', '#lem: kišib[seal]; sikiba[ration]; FN', '@reverse', '1. [iti] ses-da-gu₇-[ta]', '#lem: itud[moon]; MN', '2. [iti] ezem-{d}nin-a-zu-še₃', '#lem: itud[moon]; MN', '3. zi-ga', '#lem: ziga[expenditure]', '4. ki ur-ku₃-nun-na', '#lem: ki[place]; PN', '5. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@left', '1. [...] 5(u) la₂ 1(diš) [...]', '#lem: AN; n; lal[small]; n; AN']]}
#
#
# P101014 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) {uruda}ha-bu₃-da', '#lem: n; habuda[hoe]', '2. ša₃ umma{ki}-ta', '#lem: šag[heart]; GN', '3. a-pi₄-sal{ki}-še₃', '#lem: GN', '# sic sal', '4. giri₃ [...]-ku₅ sukkal', '#lem: ŋiri[foot]; u; sukkal[secretary]', '5. x-x-nanna', '#lem: u', '@reverse', '1. ki al-lu-ta', '#lem: ki[place]; PN', '2. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '3. mu {d}šu-{d}suen lugal', '#lem: mu[year]; TN; lugal[king]']]}
#
#
# P101265 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) geš tug₂', '#lem: n; ŋeš[tree]; tug[textile]', '2. 1(diš) geš nig₂-ar₃ mar-ma-tag', '#lem: n; ŋeš[tree]; niŋara[groats]; X', '3. 1(diš) geš ha-gar-gu₇', '#lem: n; ŋeš[tree]; X', '4. 1(diš) geš uzu', '#lem: n; ŋeš[tree]; uzu[flesh]', '5. 1(barig) 3(ban₂) zi₃-gu', '#lem: n; n; zidgu[flour]', '6. 1(barig) 3(ban₂) dabin', '#lem: n; n; dabin[semolina]', '7. 4(ban₂) 4(diš) sila₃ ninda du', '#lem: n; n; sila[unit]; ninda[bread]; du[go]', '8. 1(diš) dug dida saga', '#lem: n; dug[pot]; dida[wort]; sag[rare]', '9. 1(diš) dug dida du', '#lem: n; dug[pot]; dida[wort]; du[go]', '10. [...]', '#lem: AN', '@reverse', '1. ma₂-a gar-ra', '#lem: ma[ship]; ŋar[place]', '2. gu₃-du₈-a{ki}-še₃', '#lem: GN', '3. iti ezem-{d}šu-{d}suen', '#lem: itud[moon]; MN', '4. u₄ 1(u) 4(diš) ba-zal-la', '#lem: ud[sun]; n; n; zal[pass]']]}
#
#
# P101296 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) eme₆ dusu₂', '#lem: n; eme[donkey]; dusu[equid]', '2. 1(diš) amar eme₆ dusu₂', '#lem: n; amar[young]; eme[donkey]; dusu[equid]', '3. anše babbar₂', '#lem: anše[equid]; babbar[white]', '4. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '5. bar-bar', '#lem: bar[outside]', '@reverse', '1. i₃-dab₅', '#lem: dab[seize]', '2. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '3. mu [dumu-munus] lugal ensi₂ [an]-ša-an-na-ke₄ ba-an-tuku', '#lem: mu[year]; dumumunus[daughter]; lugal[king]; ensik[ruler]; PN; tuku[acquire]']]}
#
#
# P101301 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) {anše}kunga₂-nita₂', '#lem: n; X', '2. 3(diš) {anše}kunga₂ munus', '#lem: n; kunga[equid]; munus[woman]', '3. mu-kuₓ(DU) lugal', '#lem: mu.DU[delivery]; lugal[king]', '4. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '@reverse', '1. lugal-an-na-ab-tum₂ i₃-dab₅', '#lem: PN; dab[seize]', '2. iti ses-da-gu₇', '#lem: itud[moon]; MN', '3. mu si-mu-ru-um{ki} u₃ lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; u[and]; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P101303 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. a₂ geš-gar-ra nu-{geš}kiri₆', '#lem: a[arm]; X; nukirik[gardener]', '3. iti-ta u₄ 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '4. 1(geš₂) 2(u) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '5. ba-gu-um mušen-du₃', '#lem: PN; mušendu[bird-catcher]', '6. iti-ta u₄ 1(u) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '@reverse', '1. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '2. {d}šul-gi-si₂-im-tum', '#lem: PN', '3. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '4. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '5. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P101304 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-nita₂ iri niga', '#lem: n; X; iri[city]; niga[fattened]', '2. 1(diš) šah₂-nita₂ iri geš niga', '#lem: n; X; iri[city]; ŋeš[tree]; niga[fattened]', '3. ur-{d}lugal-edin-ka', '#lem: PN', '4. 5(diš) šah₂-NE-tur-nita₂ iri', '#lem: n; X; iri[city]', '5. 5(diš) šah₂-NE-tur-nita₂', '#lem: n; X', '@reverse', '1. sa₂-du₁₁ ku₅-ta', '#lem: sadug[offerings]; kud[cut]', '2. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '3. ur-{d}lugal-edin-ka i₃-dab₅', '#lem: PN; dab[seize]', '4. iti ezem-an-na', '#lem: itud[moon]; MN', '5. mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul', '#lem: mu[year]; GN; u[and]; GN; hulu[bad]']]}
#
#
# P101309 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '2. puzur₄-eš₁₈?-dar?', '#lem: X', '3. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '4. {d}šul-gi-si₂-im-tum', '#lem: PN', '@reverse', '1. {d}šul-gi-i₃-li₂ i₃-dab₅', '#lem: PN; dab[seize]', '2. iti ezem-{d}nin-a-zu', '#lem: itud[moon]; MN', '3. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P101313 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '@column 1', '1. 2(barig) 5(diš) sila₃ še lugal', '#lem: n; n; sila[unit]; še[barley]; lugal[king]', '2. un-za-mu engar', '#lem: PN; engar[farmer]', '3. 3(ban₂) šeš-kal-la dumu-ni', '#lem: n; PN; dumu[child]', '4. 1(barig) 1(ban₂) 5(diš) sila₃ lu₂-me-lam₂', '#lem: n; n; n; sila[unit]; PN', '5. 1(barig) 1(ban₂) 5(diš) ur-a-ka-sahar', '#lem: n; n; n; PN', '6. un-za-mu i₃-dab₅', '#lem: PN; dab[seize]', '7. 2(barig) 5(diš) zi-zi-ga-ni engar', '#lem: n; n; zig[rise]; engar[farmer]', '8. 5(ban₂) ka-ba-lu₂-sa₆', '#lem: n; X', '9. 5(ban₂) lu₂-dingir-ra', '#lem: n; PN', '10. dumu-ni-me', '#lem: dumu[child]', '11. 1(barig) 1(ban₂) 5(diš) igi-ni-da-a', '#lem: n; n; n; PN', '12. zi-zi-ga-ni i₃-dab₅', '#lem: zig[rise]; dab[seize]', '13. 2(barig) 5(diš) ur-{d}utu engar', '#lem: n; n; PN; engar[farmer]', '14. 5(ban₂) ur-{d}ba-ba₆', '#lem: n; PN', '15. 1(barig) 1(ban₂) 5(diš) lu₂-gi-gun₄{ki}', '#lem: n; n; n; PN', '16. dumu-ni-me', '#lem: dumu[child]', '17. 1(barig) 1(ban₂) 5(diš) {d}utu-ug₃-e', '#lem: n; n; n; PN', '18. 1(ban₂) ur-{d}su₄-an-na dumu-ni', '#lem: n; X; dumu[child]', '19. ur-{d}utu i₃-dab₅', '#lem: PN; dab[seize]', '20. 2(barig) 5(diš) ur-{d}iškur engar', '#lem: n; n; PN; engar[farmer]', '21. 5(ban₂) i₃-šub-da', '#lem: n; šub[fall]', '22. 1(barig) 1(ban₂) 5(diš) ar-ši-ah', '#lem: n; n; n; PN', '@column 2', '1. 5(ban₂) a-hu-šu-ni', '#lem: n; PN', '2. ur-{d}iškur# i₃-dab₅', '#lem: PN; dab[seize]', '3. 2(barig) 5(diš) ur-{d}su₄-an-na engar', '#lem: n; n; X; engar[farmer]', '4. 1(barig) lu₂-{d}nanše', '#lem: n; PN', '5. 1(barig) dingir-ra', '#lem: n; X', '6. 1(barig) lugal-ur₂-ra-ni', '#lem: n; WN', '7. ur-{d}su₄-an-na i₃-dab₅', '#lem: X; dab[seize]', '8. 2(barig) 5(diš) lugal-za₃-ge-si engar', '#lem: n; n; PN; engar[farmer]', '9. 1(barig) 1(ban₂) 5(diš) engar-dumu', '#lem: n; n; n; X', '10. 1(ban₂) 5(diš) ab-ba-gi-na dumu-ni', '#lem: n; n; PN; dumu[child]', '11. 1(barig) da-da-a', '#lem: n; PN', '12. 3(ban₂) im-ti-dam', '#lem: n; PN', '13. lugal-za₃-ge-si i₃-dab₅', '#lem: PN; dab[seize]', '14. engar ša₃-gu₄-me', '#lem: engar[farmer]; šagud[drover]', '15. 1(barig) 1(ban₂) 5(diš) ur-{d}nun-gal', '#lem: n; n; n; PN', '16. 1(ban₂) lugal-ušumgal dumu-ni', '#lem: n; X; dumu[child]', '17. {geš}šinig-da tuš-a', '#lem: šinig[tamarisk]; tuš[sit]', '$ blank space', '18. a-ša₃ ga₂?-sug?-ge-hu-ra', '#lem: ašag[field]; FN', '@reverse', '@column 1', '1. 2(barig) 4(diš) [...]', '#lem: n; n; AN', '2. 1(barig) ARAD₂', '#lem: n; arad[slave]', '3. 1(barig) x-igi-x-da#', '#lem: n; u', '4. 1(barig) 1(ban₂) 5(diš) ad-da', '#lem: n; n; n; adda[father]', '5. 1(ban₂) lugal-ušumgal dumu-ni', '#lem: n; X; dumu[child]', '6. ur-{d}nin-geš-zi-da i₃-dab₅', '#lem: PN; dab[seize]', '7. 2(barig) 5(diš) ur-{d}ig-alim engar', '#lem: n; n; PN; engar[farmer]', '8. 3(ban₂) x-x', '#lem: n; u', '9. 1(barig) igi-ni-da-a', '#lem: n; PN', '10. 1(diš) 2(barig) 5(diš) ARAD₂-mu x-x', '#lem: n; n; n; PN; u', '11. ur-{d}ig-alim i₃-dab₅', '#lem: PN; dab[seize]', '12. a-ša₃ a-za-ru-um-da-gi', '#lem: ašag[field]; PN', '13. 2(barig) 5(diš) {d}ba-ba₆-da-nu-me-a engar', '#lem: n; n; PN; engar[farmer]', '14. 1(barig) 1(ban₂) 5(diš) ur-{d}lamma', '#lem: n; n; n; PN', '15. 1(barig) 1(ban₂) 5(diš) lugal-ša₃-la₂', '#lem: n; n; n; PN', '16. 1(ban₂) lu₂-gi-na dumu-ni', '#lem: n; PN; dumu[child]', '17. 3(ban₂) ku-ru-ub-er₃-ra', '#lem: n; PN', '18. [{d}ba]-ba₆-da-nu-me-a i₃-dab₅', '#lem: PN; dab[seize]', '19. [x] 5(diš) lu₂-banda₃{da} geš-gi-da tuš-a', '#lem: u; n; PN; gi[thicket]; tuš[sit]', '20. a#-ša₃ lum-ma-da-mu₂-a', '#lem: ašag[field]; FN', '@column 2', '1. 2(barig) 5(diš) lu₂-{d}geš-bar-e₃ engar', '#lem: n; n; PN; engar[farmer]', '2. 1(barig) lu₂-{d}nanna dumu-ni', '#lem: n; PN; dumu[child]', '3. 1(barig) 1(ban₂) 5(diš) x-ga-ra-ni', '#lem: n; n; n; u', '4. 1(ban₂) 5(diš) ur-{d}iškur', '#lem: n; n; PN', '5. 1(ban₂) giri₃-ni-i₃-sa₆', '#lem: n; PN', '6. dumu-ni-me', '#lem: dumu[c ...
#
#
# P101320 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) amar maš-da₃-nita₂', '#lem: n; amar[young]; X', '2. u₄ 7(diš)-kam', '#lem: ud[sun]; n', '3. [ki] lugal-amar-ku₃-ta', '#lem: ki[place]; PN', '4. u₂-[ta₂]-mi-šar-ra-am [i₃-dab₅]', '#lem: PN; dab[seize]', '@reverse', '1. iti ses-da-gu₇', '#lem: itud[moon]; MN', '2. mu en-nun-e-{d}amar-{d}suen-ra-ki-ag₂ en eridu{ki} ba-hun', '#lem: mu[year]; PN; en[priest]; GN; huŋ[hire]', '@left', '1. 2(diš)', '#lem: n']]}
#
#
# P101334 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [x] amar maš-da₃-nita₂', '#lem: u; amar[young]; X', '2. a₂!(DA)-ge₆-il₂-la sanga', '#lem: PN; FN', '# sic insertion', '3. ki na-we-er-dingir-ta', '#lem: ki[place]; PN', '4. ta₂-hi-iš-a-tal', '#lem: PN', '@reverse', '1. i₃-dab₅', '#lem: dab[seize]', '2. iti ses-da-gu₇', '#lem: itud[moon]; MN', '3. mu us₂-sa si-ma-num₂{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '@seal 1', '@column 1', '1. {d}šu-{d}suen', '#lem: TN', '2. lugal kal-ga', '#lem: lugal[king]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '@column 2', '1. ta₂-hi-iš-a-tal', '#lem: PN', '2. maš₂-šu-gid₂-gid₂', '#lem: maššugidgid[diviner]', '3. ARAD₂-[zu]', '#lem: arad[slave]']]}
#
#
# P101376 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur munus geš-gi', '#lem: n; X; munus[woman]; gi[thicket]', '2. 1(diš) šah₂-NE-tur-nita₂ geš-gi', '#lem: n; X; gi[thicket]', '3. 1(diš) amar-sag uz-tur!', '#lem: n; amarsag[duckling]; PN', '4. 1(diš) amar x [x] x', '#lem: n; amar[young]; u; u; u', '5. 2(diš) šah₂-NE?-tur#? x x', '#lem: n; X; u; u', '6. [...]', '#lem: AN', '@reverse', '1. [...]', '#lem: AN', '2. 4(diš) uz-tur', '#lem: n; PN', '3. 1(u) 2(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '4. ri-ri-ga-am₃ e₂-gal-la ba-an-kuₓ(KWU147)', '#lem: deg[collect]; egal[palace]; X', '5. iti-ta u₄ 1(u) 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '6. zi-ga ur!-{d}lugal-edin!', '#lem: ziga[expenditure]; PN', '7. iti u₅-bi₂-gu₇', '#lem: itud[moon]; MN', '8. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P101383 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur munus geš-gi', '#lem: n; X; munus[woman]; gi[thicket]', '2. 1(diš) uz-tur', '#lem: n; PN', '3. iti-ta u₄ 1(u) 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. 1(diš) šah₂-NE-tur munus geš-gi', '#lem: n; X; munus[woman]; gi[thicket]', '5. 1(diš) uz-tur', '#lem: n; PN', '6. 5(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '7. iti-ta u₄ 2(u) la₂ 1(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; lal[small]; n; zal[pass]', '@reverse', '1. lugal-ra gaba-ri-a ša₃ lam-KA{ki}-ga', '#lem: PN; gabari[copy]; šag[heart]; GN', '2. 4(diš) uz-tur', '#lem: n; PN', '3. 1(diš) u₅-sim{mušen}', '#lem: n; usim[bird]', '4. ri-ri-ga-am₃ e₂-gal-la ba-an-kuₓ(KWU147)', '#lem: deg[collect]; egal[palace]; X', '5. iti-ta u₄ 2(u) 2(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '6. zi-ga a₂-bi₂-la-tum', '#lem: ziga[expenditure]; PN', '7. iti maš-ku₃-gu₇', '#lem: itud[moon]; MN', '8. mu us₂-sa ša-aš-ru{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P101393 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) dusu₂-nita₂', '#lem: n; X', '2. lu₂ na-hi-mu-um', '#lem: lu[person]; PN', '3. 1(diš) dusu₂ munus', '#lem: n; dusu[equid]; munus[woman]', '4. mu-da-num₂', '#lem: X', '5. dumu na-ap-la-num₂', '#lem: dumu[child]; PN', '6. 1(diš) dur₃#', '#lem: n; dur[donkey]', '@reverse', '1. ra-ha-u₃', '#lem: PN', '2. mar-tu', '#lem: MAR.TU[westerner]', '3. ki šu-{d}idim-ta#', '#lem: ki[place]; X', '# idim = asz.asz@inv', '4. ba-zi', '#lem: PN', '5. iti šu-eš₅-ša', '#lem: itud[moon]; MN', '6. mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} mu-hul', '#lem: mu[year]; PN; lugal[king]; GN; hulu[bad]']]}
#
#
# P101878 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur-nita₂-geš-gi-gur₄', '#lem: n; X', '2. 2(diš) uz-tur', '#lem: n; PN', '3. 3(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '4. 1(u) 4(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '5. ma₂!-an-na-še₃', '#lem: ON', '6. iti-ta u₄ 2(u) 4(diš) ba-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '@reverse', '$ blank space', '1. zi-ga a₂-bi₂-la-tum', '#lem: ziga[expenditure]; PN', '2. iti a₂#-ki-ti', '#lem: itud[moon]; akiti[festival]', '3. mu ša-aš-ru{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P102625 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) la₂ 1(diš) ma-na siki tug₂ šar₃', '#lem: n; lal[small]; n; mana[unit]; siki[hair]; tug[textile]; šar[~cloth]', '2. 2(u) la₂ 1(diš) ma-na siki tug₂ 3(diš)-kam us₂', '#lem: n; lal[small]; n; mana[unit]; siki[hair]; tug[textile]; n; us[side]', '3. siki {d}šul-gi-si₂-im-tum', '#lem: siki[hair]; PN', '$ blank space', '4. e₂-gal-ta e₃-a#', '#lem: egal[palace]; e[leave]', '5. i-di₃-er₃-ra', '#lem: PN', '6. šu ba-an-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. iti ezem-mah', '#lem: itud[moon]; MN', '$ blank space', '2. mu ki-maš{ki} hu-ur₅-ti{ki} u₃#! ma-da-bi u₄ aš-a ba-hul', '#lem: mu[year]; GN; GN; u[and]; mada[land]; ud[sun]; X; hulu[bad]', '@seal 1', '1. i-di₃-er₃-ra', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ku-da-šum', '#lem: dumu[child]; PN']]}
#
#
# P103540 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) še gur lugal', '#lem: n; še[barley]; gur[unit]; lugal[king]', '2. kišib₃ ba-aq-ri', '#lem: kišib[seal]; PN', '3. lu₂ {d}šul-gi-si₂-im-ti', '#lem: lu[person]; PN', '4. ki im-ti-dam-ta', '#lem: ki[place]; PN', '@reverse', '1. a-hu-wa-qar', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '$ blank space', '3. iti ki-siki-{d}nin-[a-zu]', '#lem: itud[moon]; MN']]}
#
#
# P103797 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) tu{mušen}', '#lem: n; tum[dove]', '2. lu₂ uru₁₁{ki}', '#lem: lu[person]; GN', '3. 1(geš₂) la₂ 2(diš) tu-gur₄{mušen}', '#lem: n; lal[small]; n; tugur[dove]', '4. te-ze₂-en₆-ma-ma', '#lem: PN', '5. 2(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '6. bar-bar-li₂-a', '#lem: PN', '@reverse', '1. iti-ta u₄ 6(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '2. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '3. a₂-bi₂-li₂-a i₃-dab₅', '#lem: PN; dab[seize]', '4. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]']]}
#
#
# P104807 {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(diš) [...]', '#lem: n; AN', '2. 2(diš) šah₂-gur₄ munus-geš#-[gi x]', '#lem: n; X; munusŋešgi[performer]; u', '3. 3(diš) šah₂-gur₄-nita₂-geš#-[gi x]', '#lem: n; X; u', '4. 1(u) 4(diš) šah₂-šaganₓ(AMA){gan} [...]', '#lem: n; n; X; AN', '5. 2(diš) šah₂-gur₄ munus-geš-gi u₂', '#lem: n; X; munusŋešgi[performer]; u[grass]', '6. 2(u) 5(diš) šah₂-NE-gur₄-munus-geš-gi u₂', '#lem: n; n; X; u[grass]', '7. 1(u) 2(diš) šah₂-nita₂-geš-gi u₂', '#lem: n; n; X; u[grass]', '8. [...] 1(diš) šah₂-gur₄-nita₂-geš-gi u₂', '#lem: AN; n; X; u[grass]', '9. 3(u) 4(diš) šah₂-NE-tur-nita₂-geš-gi', '#lem: n; n; X', '@reverse', '1. 5(diš) šah₂-šaganₓ(AMA){gan} iri', '#lem: n; X; iri[city]', '2. 5(diš) šah₂-nita₂ iri', '#lem: n; X; iri[city]', '3. 3(diš) šah₂-NE-tur munus iri', '#lem: n; X; munus[woman]; iri[city]', '4. 2(diš) šah₂-NE-tur-nita₂ iri', '#lem: n; X; iri[city]', '5. 4(diš) u₅{mušen}', '#lem: n; u[goose]', '6. 1(u) 4(diš) uz-tur', '#lem: n; n; PN', '7. 1(diš) uz{mušen}', '#lem: n; uz[duck]', '8. 1(u) 2(diš) ir₇{mušen}', '#lem: n; n; irsaŋ[pigeon]', '9. 2(u) 1(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '$ blank space', '10. [...]', '#lem: AN']]}
#
#
# ...
#
#
# P126364 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) amar sag uz-tur', '#lem: n; amar[young]; saŋ[head]; PN', '2. šu-eš₁₈-dar', '#lem: PN', '3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '@reverse', '1. ur-{d}lugal-edin-ka i₃-dab₅', '#lem: PN; dab[seize]', '2. iti maš-da₃-gu₇', '#lem: itud[moon]; MN', '3. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P126369 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]-x', '#lem: u', '2. [... {d}be-la-at]-suh-ner#', '#lem: AN; PN', '3. [u₃ {d}]be#-la-at-dar-<ra>-ba-<an>-še₃', '#lem: u[and]; PN', '4. zi-ga a-hi-ma', '#lem: ziga[expenditure]; PN', '5. ša₃ uri₅{ki}-ma', '#lem: šag[heart]; GN', '@reverse', '1. giri₃ ur-{d}dumu-zi-da e₃-x', '#lem: ŋiri[foot]; PN; PN', '$ 1 line blank', '2. iti ezem-{d}nin-a-zu', '#lem: itud[moon]; MN', '3. mu us₂-sa an-ša-an{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P126379 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...] saga#', '#lem: AN; sag[rare]', '2. [...]', '#lem: AN', '3. [...]-x dam da-x-ki', '#lem: u; dam[spouse]; PN', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. [šu]-ku₈#-bu-um i₃-dab₅', '#lem: PN; dab[seize]', '2. iti ezem-an-na', '#lem: itud[moon]; MN', '3. mu us₂-sa en eridu{ki}-ga ba-hun-ga₂', '#lem: mu[year]; us[follow]; en[priest]; GN; huŋ[hire]']]}
#
#
# P126388 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. mu#-kuₓ(DU) lugal', '#lem: mu.DU[delivery]; lugal[king]', '3. [ki na]-sa₆-ta', '#lem: ki[place]; PN', '4. ab-ba-[sa₆-ga] i₃-dab₅', '#lem: PN; dab[seize]', '5. kišib₃# {d}lamma-igi-du#', '#lem: kišib[seal]; PN', '@reverse', '1. iti diri še-sag₁₁-ku₅', '#lem: itud[moon]; dirig[exceed]; MN', '2. mu# si-mu-ru-um u₃ lu-lu-bu{ki} [a]-ra₂# 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; u[and]; GN; ara[times]; n; lal[small]; n; hulu[bad]', '@seal 1', '@column 1', '1. {d}šul-gi', '#lem: TN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '@column 2', '1. lugal an ub-da limmu₂-ba', '#lem: lugal[king]; an[sky]; anubda[quarter]; limmu[four]', '2. {d}lamma-[igi-du]', '#lem: PN', '3. ra₂-[gaba]', '#lem: ragaba[rider]', '4. ARAD₂-zu', '#lem: arad[slave]', '', '']]}
#
#
# P128393 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) la₂ 1(diš) gur₄{mušen}', '#lem: n; lal[small]; n; X', '2. lu₂-uru₁₁{ki}', '#lem: PN', '3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU) {d}šul-gi-si₂-im-tum', '#lem: mu.DU[delivery]; PN', '5. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '6. iti u₅-bi₂-gu₇', '#lem: itud[moon]; MN', '7. mu us₂-sa si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; us[follow]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P128395 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. e₂-u₆-še₃', '#lem: X', '3. 2(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '4. be-li₂-ba-ni', '#lem: PN', '5. iti-ta u₄ 3(u) la₂ 1(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; lal[small]; n; zal[pass]', '@reverse', '1. mu-kuₓ(DU)#', '#lem: mu.DU[delivery]', '2. {d}šul-gi-si₂-im-ti', '#lem: PN', '3. a₂-bi₂-li₂-a', '#lem: PN', '4. i₃-dab₅', '#lem: dab[seize]', '5. iti ezem-{d}nin-a-zu', '#lem: itud[moon]; MN', '6. mu us₂-sa e₂ puzur₄#-iš-{d}da-gan ba-du₃', '#lem: mu[year]; us[follow]; e[house]; X; du[build]']]}
#
#
# P128813 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) uz babbar', '#lem: n; uz[duck]; babbar[white]', '2. ka-ku₃-ga', '#lem: X', '3. mu-kuₓ(DU) {d}šul-gi-<si₂>-im-tum', '#lem: mu.DU[delivery]; PN', '@reverse', '1. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '2. iti-ta u₄ 1(u) 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '3. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '4. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš) kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; kam[tune?]; hulu[bad]']]}
#
#
# P128816 {'Unknown': [['#project: epsd2/u3adm/p006', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) uz-tur', '#lem: n; PN', '2. ka-ku₃-ga', '#lem: X', '3. iti-ta u₄ 2(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '4. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '@reverse', '1. {d}šul-gi-i₃-li₂', '#lem: PN', '2. i₃-dab₅', '#lem: dab[seize]', '3. iti ezem-mah', '#lem: itud[moon]; MN', '4. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P129417 {'Unknown': [['#project: epsd2/u3adm/p007', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. e₂-gal-[ta] e₃-a', '#lem: egal[palace]; e[leave]', '3. iti-[ta u₄ 2(u) 1(diš) ba]-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. 1(diš) [...]', '#lem: n; AN', '5. 4(diš) [...]', '#lem: n; AN', '6. [...]', '#lem: AN', '7. iti-ta u₄ 2(u) 2(diš) ba-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '8. 1(u) 3(diš) ir₇{mušen}', '#lem: n; n; irsaŋ[pigeon]', '9. la₂-ia₃ su-ga i-bi₂-{d}suen', '#lem: laʾu[arrears]; sug[replace]; PN', '10. iti-ta u₄ 2(u) 3(diš) ba-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '@reverse', '1. 3(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. bar-bar-li₂-a', '#lem: PN', '3. iti-ta u₄ 2(u) 4(diš) ba-ta-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU) {d}šul-gi-si₂-im-<<im>>-tum', '#lem: mu.DU[delivery]; PN', '5. [a₂]-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '6. iti ses-da-gu₇', '#lem: itud[moon]; MN', '7. mu ša-aš-šu₂-ru-um{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
#
#
# P129455 {'Unknown': [['#project: epsd2/u3adm/p007', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-ze₂-da munus geš-gi u₃-tu-da', '#lem: n; X; munus[woman]; gi[thicket]; utuda[offspring]', '2. 1(diš) uz-tur', '#lem: n; PN', '3. nig₂-gu₇ nin-ga₂-še₃', '#lem: niŋgu[food]; nin[lady]', '4. 2(diš) šah₂-ze₂-da munus geš-gi u₃-tu-da', '#lem: n; X; munus[woman]; gi[thicket]; utuda[offspring]', '5. 1(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '6. ri-ri-ga-am₃', '#lem: deg[collect]', '@reverse', '1. e₂-gal-la ba-an-kuₓ(KWU147)', '#lem: egal[palace]; X', '2. iti-ta u₄ 5(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '3. zi-ga', '#lem: ziga[expenditure]', '4. a₂-bi₂-la-tum', '#lem: PN', '5. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '6. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃ mu us₂-sa-bi', '#lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]']]}
#
#
# P129456 {'Unknown': [['#project: epsd2/u3adm/p007', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur-nita₂-geš-gi', '#lem: n; X', '2. iti-ta u₄ 2(u) 4(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '3. 1(diš) šah₂-NE-tur-nita₂-geš-gi', '#lem: n; X', '4. 5(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '5. u₄ dab₅-ba-še₃', '#lem: ud[sun]; dab[seize]', '6. iti-ta 2(u) 6(diš) ba-ra-zal', '#lem: itud[moon]; n; n; zal[pass]', '7. nig₂-gu₇ nin-ga₂-še₃', '#lem: niŋgu[food]; nin[lady]', '8. 1(diš) ir₇{mušen} 1(diš) tu-gur₄{mušen}', '#lem: n; irsaŋ[pigeon]; n; tugur[dove]', '@reverse', '1. iti-ta u₄ 2(u) 7(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '2. a-ra₂ 1(diš)-kam', '#lem: ara[times]; n', '3. iti-ta u₄ 2(u) 8(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. a-ra₂ 2(diš)-kam', '#lem: ara[times]; n', '5. 1(diš) šah₂-NE-tur munus-geš-gi', '#lem: n; X; munusŋešgi[performer]', '6. iti-ta u₄ 2(u) 9(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '7. ri-ri-ga-am₃ e₂-gal-la ba-an-kuₓ(KWU147)', '#lem: deg[collect]; egal[palace]; X', '8. zi-ga a₂-bi₂-la-tum', '#lem: ziga[expenditure]; PN', '9. iti še-sag₁₁-ku₅ min?', '#lem: itud[moon]; MN; min[two]', '10. mu us₂#-sa#? e₂#? |KA×KAR₂.ŠA|#? iš#-da#-gan# [...] mu us₂-sa-bi', '#lem: mu[year]; us[follow]; e[house]; X; X; AN; mu[year]; us[follow]']]}
#
#
# P129463 {'Unknown': [['#project: epsd2/u3adm/p007', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) šah₂-NE-tur munus geš-gi', '#lem: n; X; munus[woman]; gi[thicket]', '2. ša₃ e₂-gal-še₃', '#lem: šag[heart]; egal[palace]', '3. 7(diš) uz-tur', '#lem: n; PN', '4. 1(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '@reverse', '1. ri-ri-ga-am₃', '#lem: deg[collect]', '2. e₂-gal-la ba-an-kuₓ(KWU147)', '#lem: egal[palace]; X', '3. iti-ta u₄ 1(u) 9(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. zi-ga {d}šul-gi-i₃-li₂', '#lem: ziga[expenditure]; PN', '5. iti ezem-me-ki-gal₂', '#lem: itud[moon]; MN', '6. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P134155 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) uz-tur', '#lem: n; PN', '2. 5(diš) tu-gur₄{mušen}', '#lem: n; tugur[dove]', '3. nig₂-gu₇ nin-ga₂-še₃', '#lem: niŋgu[food]; nin[lady]', '4. iti-ta u₄ 8(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; zal[pass]', '@reverse', '1. zi-ga', '#lem: ziga[expenditure]', '2. a₂-bi₂-li₂-a', '#lem: PN', '3. iti u₅-bi₂-gu₇', '#lem: itud[moon]; MN', '4. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; us[follow]; e[house]; X; du[build]']]}
#
#
# P134234 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. [...] x a', '#lem: AN; u; a[water]', '5. [...] x', '#lem: AN; u', '@reverse', '1. ki šu-ku₈-bu-um-ma-ta', '#lem: ki[place]; PN', '2. iti šu-eš-ša', '#lem: itud[moon]; MN', '3. mu dumu-munus lugal ensi₂ an-ša-an{ki}-ke₄ ba-an-tuku', '#lem: mu[year]; dumumunus[daughter]; lugal[king]; ensik[ruler]; GN; tuku[acquire]', '5. gaba-ri', '#lem: gabari[copy]']]}
#
#
# P134841 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) uz-tur', '#lem: n; PN', '2. ši-ba-at-e₂-kur', '#lem: PN', '3. iti-ta u₄ 1(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. 1(diš) uz-tur', '#lem: n; PN', '@reverse', '$ beginning broken', '1ʾ. [...]', '#lem: AN', '2ʾ. u₄ [x]-kam#', '#lem: ud[sun]; n', '3ʾ. mu-kuₓ(DU) {d}šul-gi-si₂-im-tum', '#lem: mu.DU[delivery]; PN', '4ʾ. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '5ʾ. iti ezem-an-na', '#lem: itud[moon]; MN', '6ʾ. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P134842 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) uz-tur', '#lem: n; PN', '2. 2(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '3. nir-i₃-da-gal₂', '#lem: PN', '4. iti-ta u₄ 1(u) 1(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '@reverse', '1. mu-kuₓ(DU) {d}šul-gi-si₂-im-ti', '#lem: mu.DU[delivery]; PN', '2. ur-{d}lugal-edin-ka i₃-dab₅', '#lem: PN; dab[seize]', '3. iti maš-da₃-gu₇', '#lem: itud[moon]; MN', '4. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
#
#
# P135051 {'Unknown': [['#project: epsd2/u3adm/p008', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) maš₂-nita₂', '#lem: n; X', '2. 2(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '3. 2(diš) u₈ 2(diš) udu-nita₂', '#lem: n; u[ewe]; n; udunita[ram]', '4. iti ezem-{d}šul-gi', '#lem: itud[moon]; MN', '5. 4(diš) u₈ 2(diš) udu-nita₂', '#lem: n; u[ewe]; n; udunita[ram]', '6. 2(diš) {munus}aš₂-gar₃', '#lem: n; ašgar[kid]', '7. iti šu-eš-ša', '#lem: itud[moon]; MN', '@reverse', '1. sa₂-du₁₁ {d}be-la-at-suh-ner', '#lem: sadug[offerings]; PN', '2. {d}be-la-at-dar-ra-ba-an', '#lem: PN', '3. an-nu-ni-tum', '#lem: PN', '4. u₃ {d}ul-ma-ši-tum', '#lem: u[and]; DN', '5. mu e₂ puzur₄-iš-{d}da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]']]}
#
#
# P142399 {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(diš) uz-tur', '#lem: n; PN', '2. nin₉ ṣe-lu-uš-{d}da-gan ba-du₃', '#lem: nin[sister]; X; du[build]', '3. iti-ta u₄ 2(u) 3(diš) ba-ra-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. {d}šul-gi-si₂-im-tum-še₃', '#lem: PN', '2. a₂-bi₂-li₂-a i₃-dab₅', '#lem: PN; dab[seize]', '3. iti šu-eš₅-ša', '#lem: itud[moon]; MN', '4. mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃ mu us₂-sa-bi', '#lem: mu[year]; us[follow]; e[house]; X; du[build]; mu[year]; us[follow]']]}
#
#
# P142400 {'Unknown': [['#project: epsd2/u3adm/p009', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '2. dam ur-nigar', '#lem: dam[spouse]; PN', '3. 5(diš) ir₇{mušen}', '#lem: n; irsaŋ[pigeon]', '4. 1(u) 4(diš) tu-gur₄{mušen}', '#lem: n; n; tugur[dove]', '5. [x] x x ki', '#lem: u; u; u; ki[place]', '6. [...]', '#lem: AN', '@reverse', '1. [...]', '#lem: AN', '2. {d}[šul-gi]-si₂#-im-tum', '#lem: PN', '3. a₂-bi₂-la-tum i₃-dab₅', '#lem: PN; dab[seize]', '4. iti ses-da-gu₇', '#lem: itud[moon]; MN', '5. mu si-mu-ru-um{ki} u₃ lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-ma-aš ba-hul', '#lem: mu[year]; GN; u[and]; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
#
#
# P101020 {'Unknown': [['#project: epsd2/u3adm/p014', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '2. bu-ra-an-hu-uh₂-ra-an', '#lem: X', '3. 1(geš₂) 2(u) 5(diš) sa gi', '#lem: n; n; n; sa[roast]; gi[reed]', '4. sahar-ki-ti', '#lem: X', '5. 1(u) sa gi 1(diš) dam', '#lem: n; sa[roast]; gi[reed]; n; dam[spouse]', '6. 3(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '@reverse', '1. šu ba ur ha-ab-ru', '#lem: šu[hand]; ba[allot]; ur[dog]; PN', '2. nu-banda₃ nir-i₃-da-gal₂', '#lem: nubanda[overseer]; PN', '$ blank space', '3. iti ezem-{d}nin-<a>-zu', '#lem: itud[moon]; MN', '@seal 1', '1. lu₂-du₁₀-ga', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ...', '#lem: dumu[child]; AN', '']]}
#
#
# P101018 {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf: lang sux', '@object tag', '@obverse', '1. 5(ban₂)# 8(diš) sila₃ zi₃ gazₓ(KUM)', '#lem: n; n; sila[unit]; zid[flour]; X', '2. sa₂-du₁₁ ku₅-da', '#lem: sadug[offerings]; PN', '3. bala er₃-ra-gar₃?', '#lem: bala[turn]; PN', '4. mu šu-šu#-mu-dar#', '#lem: mu[year]; X', '@reverse', '1. kišib₃# tu#-ra#-am-[i₃-li₂]', '#lem: kišib[seal]; PN', '2. [...] x', '#lem: AN; u', '3. iti# a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '4. mu e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; e[house]; TN; GN; du[build]', '@seal 1', '$ (illegible)', '']]}
#
#
# P101266 {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ blank space', '1. [...] x?', '#lem: AN; u', '2. [...] i₃? u₂-ki-im#', '#lem: AN; i[oil]; X', '3. [...] i₃-du₁₀-ga a-du₁₀', '#lem: AN; X; dug[good]', '4. nu-banda₃', '#lem: nubanda[overseer]', '5. ni-zu-hu#? šu-ma#-[x]', '#lem: X; u', '@reverse', '1. [...]-x-ga-ru#-ti-im#', '#lem: u', '2. [...] ti-u₂-ga₂?#', '#lem: AN; X', '3. [...] lu₂#-a₂-zi-da', '#lem: AN; PN', '$ blank space']]}
#
#
# Number without labels: 147

# %% [markdown]
# # Multinomial Naive Bayes Classifer
# For classifying queen's archives transactions

# %%
# Get lemmatized
all_lemmas = []
labels = []

for item in queen_training_list:
    all_lemmas.append(" ".join(item.get_sumerian_lemma()))
    labels.append("queen")
    
for item in non_queen_list[:200]:
    item.get_lemmatization()
    all_lemmas.append(" ".join(item.get_sumerian_lemma()))
    labels.append("not queen")
    
# Vectorize lemmas
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(all_lemmas) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)
# Out:
# (412, 303)
# (412, 303)

# %%
# Classifier
clf = MultinomialNB().fit(X_train_tfidf, labels)

# Predict
docs_new = []
labels_new = []

for item in queen_test_set:
    item.get_lemmatization()
    docs_new.append(" ".join(item.get_sumerian_lemma()))
    labels_new.append("queen")

for item in non_queen_list[200:]:
    item.get_lemmatization()
    docs_new.append(" ".join(item.get_sumerian_lemma()))
    labels_new.append("not queen")

X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

for doc, category in zip(docs_new, predicted):
    print('%r => %s' % (doc, category))
# Out:
# 'irsaŋ tugur itud ud zal irsaŋ a tugur itud ud zal irsaŋ a itud ud lal zal mu.DU dab itud mu ara lal hulu' => queen
# 'gud niga udu niga sag udu niga maškim udu niga maš maškim e u ziga ki itud akiti mu us en huŋ' => queen
# 'udu u maš udu u maš sila kuli šabra sila ensik mu.DU dab itud mu ara hulu' => queen
# 'udu niga u ud ma e ziga ŋiri itud akiti mu us hulu' => queen
# 'udu u ziga itud mu us bad mada du' => queen
# 'udu niga itud ud zal gud u udu niga u niga uzud niga emuhaldim udu niga sila siškur ud itud ud zal udu niga šag sila maš zag du udu niga sila siškur ud itud ud zal udu niga u gudeʾusa sila niŋ kizah ud itud ud zal udu niga siškur sila niga niŋgu lugal ud itud ud lal zal e ziga itud mu hulu' => queen
# 'sila mu.DU dab itud mu hulu' => queen
# 'u ašgar sadug u itud mu us e du mu us' => queen
# 'udu gukkal niga uš egal udu niga ezem itud ud lal zal udu niga giranum udu niga u giranum u udu niga siškur sila šag egal sila niŋ kizah maš udu niga mašgal niga šag itud ud zal maš uš egal ziga itud mu hulu' => queen
# 'itud ud zal itud ud lal zal dam nin itud ud zal dam itud ud zal mu.DU dab itud mu en maš pad' => queen
# 'munusŋešgi niŋgu nin itud ud zal ziga itud mu us hulu' => queen
# 'sila sukkal mu.DU dab itud mu us hulu' => queen
# 'udu niga giranum u udu niga udu niga siškur udu niga udu niga siškur ud gud niga udu niga ud udu niga ud udu niga ud lu šagia maškim itud mu dumumunus lugal ensik tuku' => queen
# 'udu u udunita uzud sadug u itud udunita uzud udu u sadug u itud mu e du' => not queen
# 'gud niga udu niga sila ašgar niga sila niŋ kud mašgal ga gu ud gud niga udu niga mašgal niga ašgar niga niŋ kud udu maš niŋ kizah ud udu niga udu u ud kašdea u itud ud zal ziga itud anna mu us e du mu us' => queen
# 'tugur ara niga tugur ara tugur ara uš egal niga tugur niga ud dab niŋgu nin ziga itud mu us bad mada du mu us' => queen
# 'ud dab niŋgu nin niŋgu nin itud ud zal uz babbar uš itud ud zal uš itud ud zal itud kašdea itud ud zal uš itud ud zal maškim egal ziga itud mu e du' => queen
# 'itud ud zal itud ud zal mu.DU dab itud mu hulu' => queen
# 'gud niga gud u udu niga udu gudeʾusa udu u mašgal nin mu.DU kurušda dab itud mu bad mada du' => queen
# 'udu niga sila niga šag egal itud ud zal ziga itud mu us u hulu' => queen
# 'udu e u ŋiri ziga ki itud mu dumumunus lugal ensik tuku' => queen
# 'gud u u udunita uzud mašgal maš ug geme ušbar gu ziga šag itud mu us e du mu us' => queen
# 'egal itud ud zal uš egal itud ud zal amar saŋ tugur kašdea itud ud zal amar saŋ uš egal itud ud lal zal amar saŋ tugur ud ud dab niŋgu nin itud ud zal ziga itud gu mu us e' => queen
# 'irsaŋ uš tugur uš itud ud zal egal uz babbar niga itud ud zal niŋgu nin uz babbar uš tum uš itud ud zal ziga itud mu e du' => queen
# 'sila mu.DU dab itud mu us hulu' => queen
# 'lal udu u maš udu u maš udu u maš sila maš mu.DU dab itud mu us en huŋ' => queen
# 'iri sadug kud itud ud zal ki geme ušbar dab mu' => queen
# 'u šag egal mu sila mu ua ziga itud mu en maš pad' => queen
# 'ašgar gudeʾusa sila sila sila niga ara mašgal niga udu u uš egal amar saŋ niŋgu nin itud ud zal udu niga sadug udu itud ud zal ziga itud mu us hulu' => queen
# 'tugur uš egal ziga itud mu us bad mada du' => queen
# 'udu niga sadug siškur maš e u ziga šag ŋiri itud mu bad du' => queen
# 'gud u udu u kan gud niga udu u mašgal sila en udu niga maš maš itud ud zal mu.DU dab itud mu us hulu' => queen
# 'ašgar mu.DU dab itud mu us e du' => queen
# 'ašgar giranum šag egal itud ud zal ziga itud mu us ara lal hulu' => queen
# 'gud u udu niga ma udu niga eš udu u šag ŋiri itud ud zal mašgal niga giranum udu niga mašgal niga siškur u udu niga siškur udu niga ara maš ara siškur ašgar kir niŋ kizah šag egal itud ud zal ziga itud mu us e du' => queen
# 'gud niga udu u udu niga sadug eš udu u maš e ud ma an udu niga sadug udu u siškur šag ŋiri ziga kurušda itud mu ara e' => queen
# 'uš egal itud ud zal ziga itud mu hulu' => queen
# 'irsaŋ itud ud zal uz babbar itud ud zal tugur itud ud zal uš egal niŋgu nin itud ud zal uš egal itud ud zal ziga itud mu us e du' => queen
# 'u uš egal itud ud zal ziga itud mu hulu' => queen
# 'gud u udu u irsaŋ uš egal itud ud zal ziga itud mu hulu' => queen
# 'tugur niŋgu nin ara lal tugur uš egal itud ud zal udu gudeʾusa giranum itud ud zal ziga itud mu us ara lal hulu' => queen
# 'uz babbar tugur uš egal ziga itud mu e du' => queen
# 'udu gudeʾusa uš egal itud ud zal ziga itud mu hulu' => queen
# 'udu niga e ŋiri ziga itud mu hulu' => queen
# 'amar saŋ irsaŋ itud ud zal mu.DU dab itud mu ara lal hulu' => queen
# 'irsaŋ ugula itud ud zal mu.DU dab itud mu ara lal hulu' => queen
# 'itud ud zal ziga itud mu e du' => queen
# 'tugur niŋgu nin tugur uš egal itud ud lal zal ziga šag itud mu us hulu' => queen
# 'amar saŋ uš egal itud ud zal tugur ud dab niŋgu nin itud ud zal tugur itud ud lal zal ara itud ud zal ara uš egal ziga itud mu en maš pad' => queen
# 'udu niga siškur itud ud zal ziga itud mu us e du mu us' => queen
# 'sila utuda mu.DU dab itud mu hulu' => queen
# 'sila sila tugur sila sila itud ud zal mu.DU dab itud mu us hulu' => queen
# 'itud mu us hulu' => queen
# 'irsaŋ santanak itud ud zal amar saŋ itud ud zal uz babbar irsaŋ tugur itud ud lal zal mu.DU dab itud mu en maš pad' => queen
# 'udu u sila uš lu azlag šag ugula ziga itud mu us e du mu us' => queen
# 'tugur niŋgu nin itud ud zal ziga itud akiti mu us u hulu' => queen
# 'uzud u udunita sila itud uzud mašgal u udunita maš sila sila itud sadug u mu us e du' => not queen
# 'maš siškur udu niga sadug siškur maškim šag maš niŋ kizah e u šag ŋiri ziga kurušda itud akiti mu bad mada du' => queen
# 'munusŋešgi utuda mu.DU dab itud mu u hulu' => queen
# 'itud ud lal zal mu.DU dab itud mu e du' => queen
# 'sila šag mu.DU dab itud akiti mu us bad mada du' => queen
# 'udu u ziga itud mu hulu' => queen
# 'gud udu u adda maš ziga ki itud mu us hulu' => queen
# 'sukkal itud ud mu.DU dab itud mu us hulu' => queen
# 'udunita uzud sadug u ziga itud mu en maš pad' => not queen
# 'udu u udu niga maš gud uš ki itud mu ara hulu mu us zir' => queen
# 'maš mu.DU dab itud akiti mu us hulu' => queen
# 'tugur nin itud ud zal mu.DU dab itud mu us hulu' => queen
# 'udu niga sila zabardab dab udu niga mu.DU dab itud ud zal itud anna mu e du' => queen
# 'maš u kir sila sadug u itud mu us e du mu us' => queen
# 'udu niga sadug sila maš maš itud ud zal udu niga sila itud sila udu niga sadug udu itud ud zal er siškur šag ŋiri ziga itud mu hulu' => queen
# 'mašgal giranum u kan itud mu ara hulu' => queen
# 'udu niga sadug giranum kan maškim ziga kurušda itud mu bad mada du' => queen
# 'irsaŋ niŋgu egal ziga itud mu e' => queen
# 'munus gi ud dab niŋgu nin uš egal itud ud zal ziga itud mu hulu' => queen
# 'niŋgu nin itud ud zal ziga itud akiti mu us hulu' => queen
# 'udu niga udu u e udu niga udu u e udu niga udu maš geme itud ud zal ziga itud mu us e du' => queen
# 'munus šah amagan nakabtum e ki dab itud mu us hulu' => queen
# 'udu niga sadug gud niga udu niga sadug eš udu niga sadug um ki ŋiri ašgar niga siškur šag egal itud ud zal ziga itud mu hulu' => queen
# 'gud niga udu u dam itud ud zal mu.DU dab itud mu e du' => queen
# 'udu niga mašgal niga udu niga itud ud zal mu.DU dab itud mu us hulu' => queen
# 'amar saŋ nar munus irsaŋ ara tum ara tugur tum mu.DU dab itud mu e du' => queen
# 'udu u u udu u šag ŋiri ziga itud mu us hulu' => queen
# 'sila niŋ kizah tugur uš egal maš kag ŋipar tugur niŋgu nin itud ud zal ziga šag itud mu us hulu' => queen
# 'sila dumu mu.DU dab itud mu hulu' => queen
# 'udu siškur udu e sadug gud sila šag' => queen
# 'udu niga sadug giranum udu uš egal itud ud zal niga gudeʾusa gudeʾusa sadug zal ziga itud mu hulu' => queen
# 'udu gudeʾusa uš egal itud ud zal udu niga ara itud ud zal udu niga ara gabari šag udu niga siškur udu niga u itud ud lal zal udu niga u siškur šag itud ud lal zal ziga itud mu us hulu' => queen
# 'udu niga udu u mašgal sila gaba tugur uš egal munus gi niŋgu nin itud ud zal ziga itud mu us ara lal hulu' => queen
# 'udu niga e udu niga udu u sila e gud niga sila e udu niga sila udu u lugal udu niga maš e ezem šag ŋiri ziga kurušda itud mu us e' => queen
# 'itud ud zal mu.DU' => queen
# 'gud u udu u maš dam mu.DU dab itud mu e du' => queen
# 'ašgar siškur u maškim ziga šag itud akiti mu ara e' => queen
# 'irsaŋ itud ud zal mu.DU dab itud mu us e du' => queen
# 'udu niga sadug u niga uš egal' => queen
# 'gi niŋgu nin itud ud lal zal ziga itud mu hulu' => queen
# 'gud u udu u mašgal šakkanak sila mu.DU dab itud mu us hulu' => queen
# 'maš šabra mu.DU dab itud mu us hulu' => queen
# 'tugur niŋgu nin tugur uš egal itud ud zal ziga itud akiti mu us hulu' => queen
# 'sila kag eš maš kag ŋipar ŋiri udu niga sadug maš siškur šag ŋiri udu niga gudeʾusa udu u ašgar deg egal itud ud zal ziga itud mu us hulu' => queen
# 'šah munus gi niŋin niga niŋgu lugal munus gi munus iri uš egal itud ud zal ziga itud mu us hulu' => queen
# 'gud niga udu u mašgal mu.DU dab itud mu hulu' => queen
# 'mu.DU itud mu en ziga mu en maš pad' => queen
# 'udu niga sila šabra itud ud zal mu.DU dab itud mu hulu' => queen
# 'maš niga niŋgu ziga itud mu us bad mada du' => queen
# 'gi niga sukkal itud ud zal šag irsaŋ itud ud zal šag itud ud zal šag mu.DU dab itud mu hulu' => queen
# 'ašgar maš uš egal ziga itud mu us hulu' => queen
# 'udu niga sadug u siškur šag egal u siškur uš egal itud ud lal zal ziga itud mu us hulu' => queen
# 'irsaŋ niga tugur niga niŋgu nin uš irsaŋ uš egal ziga itud mu us bad mada du' => queen
# 'tugur tum niŋgu nin tugur uš egal itud ud zal ziga itud mu us hulu' => queen
# 'tugur tugur uš egal itud ud zal ziga itud akiti mu us e du' => queen
# 'dam nubanda itud ud zal mu.DU dab itud mu us hulu' => queen
# 'amar saŋ itud ud zal mu.DU dab itud mu us hulu' => queen
# 'sila udu u dam mu.DU dab itud mu us e du' => queen
# 'tugur itud ud zal irsaŋ itud ud lal zal irsaŋ itud ud zal mu.DU dab itud mu e du' => queen
# 'irsaŋ ki mu.DU dab itud mu us bad mada du' => queen
# 'munus gi irsaŋ tugur niŋgu nin tugur uš egal itud ud zal ziga itud mu us hulu' => queen
# 'gud maš dam taba ab mu lal udu maš dam udu sila dam udu maš mu.DU kurušda dab itud mu ara e' => queen
# 'tugur uš egal itud ud zal ziga itud mu us hulu' => queen
# 'udu u sila dam sila mu.DU dab itud mu hulu' => queen
# 'udu niga sila niga ašgar niga lal udu gukkal sila sila gukkal u mašgal lal maš maš ga uzud mu.DU lugal ki dab itud mu u hulu' => queen
# 'sila še lugal engar dumu sila dab zig engar dumu zig dab engar dumu dumu dab engar šub dab engar dab engar dumu dab engar šagud dumu šinig tuš ašag arad adda dumu dab engar dab ašag engar dumu dab gi tuš ašag engar dumu dumu dab engar dumu dumu dab šu ziʾa dab engar min dumu dab mu lugal' => not queen
# 'gud ud gud ab šag gud šag mu.DU lugal gud ab gud lu ki gud ab gud lu ki šuniŋin gud šuniŋin ab ki dab itud akiti mu lugal' => not queen
# 'sila ga kir ga maš ga ašgar ga utuda ud lal dab itud mu lugal' => not queen
# 'gud ud ki dab itud mu lugal šag hul dim' => not queen
# 'u sila uzud edula niŋgur nubanda dab itud mu dim' => not queen
# 'gud niga mu.DU enna dab mu huŋ nita kalag lugal kurušda arad' => not queen
# 'udu udu ŋešdu sila udu sila kuš sila udu niga sila šabra sila sila sila lal udu udu ŋešdu udu udu udu ŋešdu udu ud mu.DU dab itud mu huŋ' => not queen
# 'amar ud ki dab itud mu en huŋ' => not queen
# 'udu maš hi ki dab šag itud mu en huŋ sipad lugal' => not queen
# 'udu mu.DU lugal udu u ensik udu barakara mu.DU dab ŋiri dubsar ud itud lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'sila maš ud duga dab itud mu du dumu kurušda' => queen
# 'sila ga kir ga utuda šag ud dab itud mu dim' => not queen
# 'udu ki duga dab itud mu du duga dubsar dumu sipad' => not queen
# 'udu sila ŋiri sila ŋiri ud lal sila ud ŋiri ki duga dab itud akiti mu ma du dumu kurušda' => queen
# 'gud ud gud ab ud gud mu ab ab mu kunga munus ud ud gud ud šuniŋin gud šuniŋin gud mu šuniŋin ab šuniŋin ab mu šuniŋin šuniŋin kunga munus mu.DU ki dab itud mu du lal gud anše' => not queen
# 'udu maš ki duga dab ŋiri itud mu ma du duga dubsar dumu sipad' => not queen
# 'sila maš amar ud ki duga dab itud mu us du dumu kurušda' => not queen
# 'sila ud sila ud ki duga dab itud akiti mu hulu duga dubsar dumu' => not queen
# 'udu mašgal udu mašgal dab udu mašgal e ud lal kišib itud mu hulu dubsar dumu' => not queen
# 'sila ki duga dab itud mu hulu duga dumu' => not queen
# 'sila ud mu.DU lugal dab ŋiri dubsar itud mu us lugal hulu udu' => not queen
# 'amar ki dab itud mu us hulu lugal kalag lugal maššugidgid arad' => not queen
# 'gud u udu u maš dam udu maš dumu udu maš šeš šabra sila mu.DU dab itud mu us bad mada du' => queen
# 'udu niga udu niga gudeʾusa ud udu niga us ud gud u gud mu gud mu ab u ab mu udu aslum niga us udu niga gukkal niga udu aslum niga gukkal u sila u udu aslum u gukkal u gukkal ŋešdu u ud sila ud sila ud gud niga us udu niga sila ud udu ud udu maš uzud ud udu aslum u ud gud udu mašgal ud udu niga us ud udu aslum niga udu u mašgal u ud gukkal u gukkal ŋešdu u udu gukkal u ud am gud gud u udu u mašgal ud šuniŋin gud niga us šuniŋin gud u šuniŋin ab u šuniŋin gud mu šuniŋin gud mu šuniŋin ab mu šuniŋin am gud šuniŋin udu niga us šuniŋin udu aslum niga us šuniŋin udu niga us šuniŋin udu šuniŋin gukkal šuniŋin udu šuniŋin šuniŋin šuniŋin šuniŋin gukkal u šuniŋin gukkal ŋešdu u šuniŋin udu aslum u šuniŋin udu gukkal u šuniŋin mašgal u šuniŋin uzud u šuniŋin sila gud am udu ki dab itud mu lugal du' => not queen
# 'gud niga gud u udu niga udu u gukkal sila ašgar maš u sila nagada udu sila nagada ugula kuš mu.DU dab itud mu us bad mada du' => queen
# 'udu u mašgal u ki ensik dab itud mu lugal mada hulu udu' => not queen
# 'gud niga udu u mašgal u sila gud niga mašgal u sila gud niga mašgal u dam gud niga mašgal u sila zig nubanda lu ugula gu mada mu.DU dab ŋiri dubsar ud itud mu lugal mada hulu gud udu' => not queen
# 'udu ki dab itud mu e du lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad' => not queen
# 'gud niga ki dab itud mu e du lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad' => not queen
# 'gud u udu u sila ud ki dab itud mu e du duga dubsar dumu sipad' => not queen
# 'sila sila mašgal niga mu.DU lugal dab ŋiri ud itud mu lugal arad' => queen
# 'gud ki dab itud akiti mu lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad' => not queen
# 'udu maš ki dab arad' => queen
# 'sila ki dab šag itud mu e du lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad' => not queen
# 'gukkal gukkal siškur ma gukkal gukkal kan gukkal siškur šag kiri gukkal ziga itud zusik mu ara hulu' => queen
# 'udu niga siškur u maškim udu niga udu niga udu niga udu niga ŋiri udu niga e u ŋiri udu niga ŋiri dumumunus ur maškim udu niga giranum ŋiri udu niga kašdea udu niga ŋiri ziga itud mu us ara hulu' => queen
# 'udu siki udu udu maš ziga didli udu sila lal maš kišib ki ziga mu us hulu' => queen
# 'ašgar giranum maškim ašgar giranum maškim ašgar giranum u maškim sila u ŋiri ziga itud akiti mu us hulu' => queen
# 'sila eš maš kag ŋipar maš šag ŋiri udu giranum e u maškim ziga šag itud mu us hulu' => queen
# 'udu niga sadug giranum udu niga udu niga e u udu niga siškur usakar šag udu niga e ziga kurušda šag itud mu us hulu mu us' => queen
# 'sila eš maš maš maš kag ŋipar maš siškur ud sila šag egal ziga ensik šag itud mu us hulu mu us' => queen
# 'udu siškur usakar ŋiri udu siškur šag ŋiri maš ga gu maš siškur maškim ziga šabra itud mu ara' => queen
# 'udu niga sadug ŋiri šag udu niga sadug giranum udu gudeʾusa udu u udu gudeʾusa e udu niga udu niga sadug e ŋiri sukkal udu niga sadug sila udu niga sila udu niga sadug udu u e udu gudeʾusa e ab niga udu niga udu u sila aguziga maš siškur sila ud udu niga maš ud kašdea ziga šag itud mu ara e' => queen
# 'udu niga udu u sila e udu niga udu u sila e udu niga šag egal maš giranum maš giranum e maš šag kisal gabari gud niga udu niga udu alan lugal ašgar niga maš sar maš e du ud kašdea šag egal maš erin kašdea udu u e ziga kurušda šag itud mu bad mada du' => queen
# 'gud niga udu niga udu u ma udu niga e udu niga eš sila e udu gudeʾusa maš siškur usakar šag ŋiri udu niga sadug giranum udu niga sadug siškur u sila egal sila udu niga siškur maškim ziga kurušda šag e itud akiti mu bad mada du' => queen
# 'udu u niŋgu anna udu niga udu u u udu niga gud niga udu niga ezem an itud ud zal ziga šag ŋiri itud mu us e du' => queen
# 'uš irsaŋ uš itud ud zal egal irsaŋ tugur er su itud ud zal ziga itud mu us e du mu us' => queen
# 'udu niga udu u siškur saŋ usakar šag ŋiri udu niga giranum udu niga mašgal siškur u udu niga siškur ašgar niga siškur sila šag egal itud ud zal ziga itud mu us e du' => queen
# 'udu niga mašgal siškur saŋ usakar šag ŋiri muhaldim udu niga giranum udu niga u siškur u siškur sila šag egal maš siškur udu u uš ara u uš ara egal itud ud lal zal ziga itud mu us e du' => queen
# 'udu niga mašgal mašgal u šag ŋiri itud ud zal sila uš egal ziga itud mu us e du mu us' => queen
# 'udu niga mašgal niga udu u kašdea dumumunus udu niga siškur udu niga udu niga sila udu niga maš siškur šag ŋiri itud ud zal ziga itud mu us e du mu us' => queen
# 'udu niga kag ŋipar udu niga udu niga sila kag eš ŋiri itud ud zal ziga itud mu us e du mu us' => queen
# 'uz babbar tugur ara itud ud zal tugur gi ara itud ud zal tugur ara itud ud zal deg egal gi amarsag ara itud ud zal munus gi amarsag ara itud ud zal gabari šag ki ŋar sadug ziga itud mu en maš pad' => queen
# 'udu niga itud ud zal udu niga sila udu niga maš udu niga udu itud ud zal siškur šag ziga itud mu en maš pad' => queen
# 'udu gudeʾusa siškur itud ud zal udu gudeʾusa giranum ara udu gudeʾusa siškur šag ŋiri udu u udu niga u siškur u tugur itud ud zal udu u sila gaba uš egal šag ziga itud mu us ara lal hulu' => queen
# 'udu u šunir udu gudeʾusa abzu udu udu udu maš maš maš dumu anna gud niga udu niga sila maš dag šag KA sila šag KA maš e NE u ŋiri itud ud zal ziga šag itud mu hulu' => queen
# 'šah NE tur gi niŋgu nin itud ud zal ziga itud mu hulu' => queen
# 'udu niga sadug siškur šag egal udu niga mašgal niga mu nin maš udu u maš uš egal itud ud zal ziga itud mu hulu' => queen
# 'udu niga sadug sila udu u maš maš itud ud zal udu niga sila udu niga sadug maš itud ud lal zal er siškur šag ŋiri udu u sila uš ziga itud mu hulu' => queen
# 'udu niga sadug udu u u udu u siškur udu niga sila udu niga sadug maš šag ŋiri udu u mašgal ašgar deg egal itud ud zal ziga itud mu hulu' => queen
# 'udu maš deg egal ziga itud mu hulu' => queen
# 'udu niga udu niga sila niga ŋiri zabardab maškim itud ud lal zal ziga ki itud mu u hulu' => queen
# 'iri irsaŋ itud ud zal irsaŋ itud ud zal uš egal ziga itud mu hulu' => queen
# 'munus gi gi amarsag amar tugur deg egal itud ud zal ziga itud mu us hulu' => queen
# 'udu niga sadug kan ŋipar itud ud zal ziga šag itud mu us hulu' => queen
# 'udu niga sadug udu niga udu niga gudeʾusa maš u maš itud ud lal zal udu u giranum u maš gud niga udu niga udu niga sadug sila aguziga ašgar niga sar maš an udu u kašdea šag egal itud ud zal ziga šag itud akiti mu us hulu' => queen
# 'udu u u ŋiri udu niga sila niga ašgar niga gabari ŋen itud ud zal ziga šag itud akiti mu us hulu' => queen
# 'u udu u ašgar uš egal ziga itud mu us hulu' => queen
# 'irsaŋ uš egal itud ud zal ziga itud mu us hulu' => queen
# 'udu u udu u šag egal sila udu niga sadug sila kag ŋipar udu niga gudeʾusa sila ara gud niga udu niga sila kag eš šag itud ud zal ŋiri ziga itud mu us hulu' => queen
# 'munus gi itud ud zal munus gi tugur itud ud lal zal gabari šag usim deg egal itud ud zal ziga itud mu us hulu' => queen
# 'gud mu geme zig zig inim maškim itud mu bad mada du' => not queen
# 'sila kan eš maš kan ŋipar udu maš sila maškim udu siškur ud šag maškim ziga itud' => queen
# 'udunita u maš sadug u u itud mu us e du mu us' => queen
# 'gud niga gud u u maš mu.DU lugal ki bala ensik itud akiti mu hulu' => queen
# 'gud udu maš hi uš ki itud ud zal itud itud ud mu hulu' => queen
# 'sila sila udu niga zu udu niga udu sila en eʾuzga sila sila mu.DU šeš sila mu.DU mašda mu.DU lal udu u šugid emuhaldim ud ki itud akiti mu us hulu mu us' => queen
# 'udu niga mu.DU sila mu.DU gukkal niga gukkal niga mu.DU sila mu.DU zabardab sila mu.DU maškim sila mu.DU maš mu.DU eʾuzga maškim udu maškim gud udu u maš uzud šugid emuhaldim ud lal ki itud mu u hulu' => queen
# 'gud niga maškim itud ud zal ki itud mu lugal hulu' => queen
# 'udu sila u kir lal mašgal maš ga šag gud šugid emuhaldim ud ki itud mu lugal hulu' => not queen
# 'lu dusu munus dumu dur MAR.TU ki itud mu lugal hulu' => not queen
# 'udu niga mašgal niga ud dumu utud ŋiri sukkal udu niga mu ŋiri sukkal emuhaldim udu niga ki MAR.TU ŋiri agaʾus udu niga gudeʾusa ŋiri mašgal niga lu kiŋgia ensik mašgal niga lu mašgal niga lu ŋiri sukkal mašgal niga lu kiŋgia ensik mašgal niga lu kiŋgia ensik ŋiri sukkal maškim itud ud zal ki itud mu en huŋ udu' => not queen
# 'udu ud udu gukkal niga udu aslum niga mašgal niga udu u mašgal u ud udu aslum niga us ud gukkal udu aslum u mašgal udu u udu aslum niga mašgal u ud udu niga udu ud udu ud ud šuniŋin šuniŋin šuniŋin šuniŋin šuniŋin šuniŋin maš šuniŋin šuniŋin udu aslum šuniŋin šuniŋin ki nu itud mu bad mada du' => not queen
# 'udu maš hi kišib udu udu sila ki itud mu lugal duga dubsar dumu sipad' => not queen
# 'mašda munus šag e mašda egia mu.DU egir šu teŋ maškim šag mu.DU ud ki ŋiri dubsar itud mu du' => not queen
# 'udu kišib unud ki itud mu du udu duga dubsar dumu sipad' => not queen
# 'udu u uš emuhaldim mu lu šukur ud udu u šugid emuhaldim mu geme dumu ud udu u alan didli šag e uzu bala siškur gal didli udu u šugid emuhaldim lugal du ud šag ki itud mu lugal dim lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'udu niga sag us gukkal niga us udu niga us mašgal niga us udu niga us udu niga us šag e gukkal niga sag us udu aslum niga sag us udu niga us niga us e alan du dupsik mu.DU lugal ki ŋiri dubsar itud ud mu lugal e du' => queen
# 'udu udu maš kišib didli ki itud ud mu e lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad' => not queen
# 'gud niga ki guza gud niga ki guza ŋiri muhaldim gud niga ki guza u ŋiri muhaldim ud šag ki itud mu lugal e du lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'udu u alan didli šag e udu u alan didli šag e uzu bala siškur gal lugal ab u udu u u u mašgal u šugid emuhaldim lugal du ma ŋar maškim šag gud udu ud udu u alan didli šag e uzu bala siškur gal lugal udu u alan didli šag e udu u alan didli šag e uzu bala siškur gal šagia maškim šag udu ud udu u u u mašgal u mu šag um mada du maškim šag gud udu ud udu u alan didli šag e udu u alan didli šag e uzu bala siškur gal šagia maškim šag udu ud gud u ab u udu u maš u uzud u šugid emuhaldim mu lu mašdarea ŋešbun er su maškim šag mašgal u šugid emuhaldim mu geme dumu ud kiʾutu ak maškim šag udu mu gud u udu u mašgal u mu lu šukur šugid emuhaldim maškim šag gud udu ud uzud u alan didli šag e uzu bala siškur gal šag ud ab u uzud u mu agaʾus a tu kag egal gud u mašgal u sila mu lu šukur šugid emuhaldim maškim šag gud udu ud udu u šugid emuhaldim mu lu šukur maškim šag udu ud udu u ŋiri šagia maškim udu u alan didli šag e lugal uzud u mu lu šukur ab u udu u mašgal u lugal du ma ŋar gud udu ud šag ud šuniŋin gud u šuniŋin ab u šuniŋin ab mu šuniŋin ab mu šuniŋin udu u šuniŋin u u šuniŋin mašgal u šuniŋin uzud u šuniŋin sila šuniŋin gud ab hi šuniŋin udu maš hi ki ŋiri dubsar itud mu lugal e du' => not queen
# 'gud ab ud gud niga ud lugal gag rah uzu ekišibak ki itud mu lugal e du lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'ŋešnud taškarin umbin sal halub mu ki šu teŋ' => not queen
# 'suhub esir hi eban itud mu en huŋ itud dirig mu en huŋ itud kiŋ ak mu.DU ašgab' => not queen
# 'mušalum kugbabbar arua lugal ŋiri ki šag itud mu en huŋ' => not queen
# 'mana kugbabbar mana kugbabbar mana kugbabbar arua lugal ki šag itud mu u ud hulu mana' => not queen
# 'har kugbabbar giŋ dumu da gala ud e da gala kaš ba ki šag itud mu lugal hulu' => not queen
# 'masab ud itud urud ur lahama kugbabbar igi KA kugsig niŋgur sig arua lugal ki šag itud mu en huŋ' => not queen
# 'suhub dušia eban suhub gada dušia eban suhub suhub eban suhub tug du eban esir dušia suhuš gub eban esir hab eban kiŋ ak gabari kišib šag itud mu lugal du' => not queen
# 'duksium lugal dušia eban duksium šakkanak dušia tug du kuš eban duksium šakkanak babbar eban kiŋ ak ki kišib ki ŋal gabari itud mu hulu' => not queen
# 'suhub tug du eban suhub eban atua ud ki šag itud mu us e du' => not queen
# 'ul kugsig sisa kila giŋ igi suhub kešed ki lu šu teŋ ŋiri šag itud mu hulu' => not queen
# 'šunir kugsig ŋeš du ugunu kugsig igi zabar šunir kugbabbar ŋeš du ugunu kugbabbar igi zabar ma lugal du arua lugal ŋiri ki šag itud dirig mu lugal ma du' => not queen
# 'kir esir kugsig huš kila giŋ še esir eban kešed ki šu teŋ ŋiri šag itud mu en huŋ' => not queen
# 'ŋešnud umbin gud halub kugbabbar ŋar ŋešnud gi umbin sal halub kugbabbar ŋar ki šu teŋ šag itud mu lugal ma dim' => not queen
# 'giŋ še kugbabbar kila samsatum usakar zir šu teŋ šag itud mu en huŋ giŋ še' => not queen
# 'har kugbabbar giŋ arua dumumunus lugal maškim ki šag itud mu hulu' => not queen
# 'suhub dušia eban suhub e eban esir dušia suhuš gub eban esir dušia eban esir dušia eban esir hab eban kiŋ ak ki šu teŋ ŋiri šag itud ud mu lugal hulu' => not queen
# 'zahum kugbabbar dumu ŋiri lu ŋiri udu uš zabar na šakkanak ŋiri ŋiri udu uš zabar ŋiri šu gal kugbabbar ŋiri udu uš zabar namraʾak mu.DU šu teŋ šag itud ud zal mu u ara lal hulu mu us niŋ₂.ŠID' => not queen
# 'sa gi sa gi sa gi dam sa gi šu ba ur nubanda itud dubsar dumu' => not queen
# 'a huŋ gur še šaggal udu še mušen še udu gur maš e azlag aš idub itud' => not queen
# 'sila zid sadug bala mu kišib itud akiti mu e du' => not queen
# 'i dug nubanda' => not queen

# %%
print("Accuracy: ", np.mean(predicted == labels_new))
# Out:
# Accuracy:  0.764957264957
