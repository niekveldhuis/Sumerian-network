# %%
# Import Libraries
import re
import numpy as np
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from collections import OrderedDict, Counter
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.cluster import DBSCAN
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, roc_auc_score

# %% [markdown]
# # Extract Transactions

# %%
DREHEM_IDS = 'clean_drehem_ids.txt'
QUEEN_ARCHIVES_IDS = 'queen_archives_pids.txt'
QUEEN_OIP_IDS = 'oip_pids.txt'

labels = {}
labels["domesticated_animal"] = ["ox", "cow", "sheep", "goat", "lamb"] # account for plural
labels["wild_animal"] = ["bear", "gazelle", "mountain"] # account for "mountain animal" and plural
labels["dead_animal"] = ["[die]"] # find "die" before finding domesticated or wild
labels["leather_object"] = ["boots", "sandals"]
labels["precious_object"] = ["copper", "bronze", "silver", "gold"]
labels["wool"] = ["wool"]
labels["queens_archive"] = []

class Transaction:
    def __init__(self, p_id):
        self.p_id = p_id
        self.lines = list()
        self.lemmas = OrderedDict() # Maps Sumerian text to its lemmatized form
        self.label = {} # Maps label to List of defining text
        self.sumerian_lemmas = []
        
    # Create mapping of Sumerian text to its lemmatized form
    def get_lemmatization(self):
        first_line = 0
        for i, s in enumerate(self.lines):
            if s.startswith("1."):
                  first_line = i
                  break
        while first_line < len(self.lines)-1:
            if self.lines[first_line] and self.lines[first_line][0].isnumeric() and self.lines[first_line+1].startswith("#lem"):
                self.lemmas[self.lines[first_line]] = self.lines[first_line+1]
                first_line += 2
            else:
                first_line += 1
                
        return self.lemmas
    
    # Get Sumerian lemmatized text only
    def get_sumerian_lemma(self):
        #print(item.sumerian_lemmas)
        item.sumerian_lemmas = []
        for k, v in self.lemmas.items():
            #print(v)
            result = re.findall(" .*\[[a-z]+\]", v)
            if len(result) == 0:
                continue
            lemmas = [s[:s.index("[")].strip() for s in result[0].split(";") if re.search("\[", s)]
            self.sumerian_lemmas += lemmas
        return self.sumerian_lemmas
    
    # Find the most likely label
    def set_label(self):
        def find_label(label, line, found) :
            for val in labels[label]:
                if val in line: 
                    if label in found.keys():
                        found[label].append(line)
                    else:
                        found[label] = [line]
                    return True
        found = {}
        for line in self.lines:
            label = None
            # Priority 1: Check for dead animal
            if find_label("dead_animal", line, found): break
            # Priority 2: Check for wild animal
            if find_label("wild_animal", line, found): break
            # Priority 3: Check for domesticated animal
            if find_label("domesticated_animal", line, found): break
            # Priority 4: Check leather, wool, or precious object
            if find_label("leather_object", line, found): break
            if find_label("precious_object", line, found): break
            if find_label("wool", line, found): break
        # If none match, label as "Unknown"
        if len(found.keys()) == 0:
            found["Unknown"] = [self.lines]
        self.label = found
        return found
            
    
# Read ORACC files to find transactions with p_ids in `ids`
def read_files(subdir, ids, reverse=False):
    transactions = list()
    for i in range(1, 16):
        file_name = ""
        if i < 10:
            file_name += subdir + "p00" + str(i) + ".atf"
        else:
            file_name += subdir + "p0" + str(i) + ".atf"
        
        curr_transaction = None
        
        with open(file_name, encoding="utf8") as file:
            print("Opening:", file_name)
            for line in file:
                line = line.strip()
                if line.startswith('&P'):
                    p_id = line.split()[0][1:]
                    if (not reverse and p_id in ids):
                        ids.remove(p_id)
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    elif (reverse and p_id not in ids and len(transactions) <= 200):
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    else:
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        curr_transaction = None
                else:
                    if curr_transaction:
                        curr_transaction.lines.append(line)
        
        if curr_transaction:
            transactions.append(curr_transaction)
    
    #print(ids)
    #assert len(ids) == 0
    print("Number of transactions:", len(transactions))
    return transactions

# Return the IDs of docs to annotate
def get_drehem_ids(file):
    lst = list()
    with open(file, encoding="utf8") as f:
        for line in f:
            if line.startswith("P"):
                line = line.strip()
                lst.append(line)
    return lst

# %%
list_drehem_ids = get_drehem_ids(DREHEM_IDS)
list_queen_ids = get_drehem_ids(QUEEN_ARCHIVES_IDS)
list_oip_queen_ids = get_drehem_ids(QUEEN_OIP_IDS)
#complete_list = list_drehem_ids + list_queen_ids + list_oip_queen_ids
# list_more_data = get_drehem_ids("more_training_data.txt")
# more_training_data = read_files("raw-data/", list_more_data)
# text = []
# with open('more_training_data2.txt', 'w', encoding="utf8") as f:
#     for item in more_training_data:
#         f.write(item.p_id+"\n")
#         item.get_lemmatization()
#         for i in item.lemmas.keys():
#             f.write(i+"\n")
#         f.write("\n")
#all_transactions = read_files("raw-data/", complete_list)
non_queen_list = read_files("raw-data/", list_drehem_ids)
queen_training_list = read_files("raw-data/", list_queen_ids)
queen_test_set = read_files("raw-data/", list_oip_queen_ids)
#more_training_data = read_files("raw-data/", complete_list, True)
# Out:
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 429
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 275
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 120

# %%
print(len(list_queen_ids))
# Out:
# 0

# %%
# Populate training and data set

for item in queen_training_list:
    item.get_lemmatization()
    item.set_label()
    
for item in non_queen_list:
    item.get_lemmatization()
    item.set_label()
    
for item in queen_test_set:
    item.get_lemmatization()
    item.set_label()
    
            
training_data = []
training_labels = []
test_data = []
test_labels = []

for item in queen_training_list:
    training_data.append(" ".join(item.get_sumerian_lemma()))
    training_labels.append("queen")
    
for i in range(len(non_queen_list)):
    if i < 350:
        training_data.append(" ".join(non_queen_list[i].get_sumerian_lemma()))
        training_labels.append("not queen")
    else:
        test_data.append(" ".join(non_queen_list[i].get_sumerian_lemma()))
        test_labels.append("not queen")
        
for item in queen_test_set:
    test_data.append(" ".join(item.get_sumerian_lemma()))
    test_labels.append("queen")

print(len(training_data))
print(len(training_labels))
print(len(test_data))
print(len(test_labels))

#print(training_data)
# print(test_labels)
# Out:
# 625
# 625
# 199
# 199

# %% [markdown]
# # Multinomial Naive Bayes Classifer
# For classifying queen's archives transactions
#
#
# <b>Accuracy</b>:
# (# true positives + # true negatives) / total #<br><br>
# <b>Recall</b>:
# true positives / (true positives + false positives) <br>
# High recall means that an algorithm returned most of the relevant results <br><br>
# <b>Precision</b>:
# true positives / (true positives + false negatives) <br>
# High precision means that an algorithm returned substantially more relevant results than irrelevant ones

# %%
# Bag of Words model
count_vect = CountVectorizer(analyzer = "word",
                                          tokenizer = None,    
                                          preprocessor = None,
                                          ngram_range = (1, 1),
                                          binary = False,
                                          strip_accents='unicode')

X_train_counts = count_vect.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)

# Classifier
bag_of_words_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = count_vect.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = bag_of_words_classifier.predict(X_new_tfidf)

# for doc, category in zip(docs_new, predicted):
#     print('%r => %s' % (doc, category))
    
print("Accuracy: ", np.mean(predicted == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, predicted, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, predicted, ["queen", "not queen"], average="macro")))
# Out:
# (625, 377)
# (625, 377)
# Accuracy:  0.929648241206
# Recall:  0.928691983122
# Precision:  0.925193555137

# %%
# Bigram Model
bigram_vectorizer = CountVectorizer(analyzer = "word",
                                    tokenizer = None,
                                    preprocessor = None,
                                    ngram_range = (2, 2),
                                    strip_accents='unicode')

# Train
X_train_counts = bigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)

# Classifier
bigram_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = bigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

bigram_multinomial_nb_prediction = bigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(bigram_multinomial_nb_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, bigram_multinomial_nb_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, bigram_multinomial_nb_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (475, 2049)
# (475, 2049)
# Accuracy:  0.813753581662
# Recall:  0.85807860262
# Precision:  0.824324324324

# %%
# Trigram Model
trigram_vectorizer = CountVectorizer(analyzer = "word",
                                    tokenizer = None,
                                    preprocessor = None,
                                    ngram_range = (3, 3),
                                    strip_accents='unicode')

# Train
X_train_counts = trigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)

# Classifier
trigram_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = trigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

trigram_prediction = trigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(trigram_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, trigram_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, trigram_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (475, 3829)
# (475, 3829)
# Accuracy:  0.776504297994
# Recall:  0.827711062591
# Precision:  0.800303454715

# %%
# Unigram and Bigram Model
uni_and_bigram_vectorizer = CountVectorizer(analyzer = "word",
                                            tokenizer = None,
                                            preprocessor = None,
                                            binary = False,
                                            ngram_range = (1,2),
                                            strip_accents='unicode')

# Train
X_train_counts = uni_and_bigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)

# Classifier
uni_and_bigram_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = uni_and_bigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

uni_and_bigram_prediction = uni_and_bigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(uni_and_bigram_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, uni_and_bigram_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, uni_and_bigram_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (625, 2949)
# (625, 2949)
# Accuracy:  0.954773869347
# Recall:  0.947362869198
# Precision:  0.958486486486

# %% [markdown]
# # Clustering
#
# GOAL: find more commodity labels in the set of non-queen data
#
# DBSCAN Model:
# Density-Based Spatial Clustering of Applications with Noise. Finds core samples of high density and expands clusters from them. Good for data which contains clusters of similar density

# %%
# Build DBSCAN model with Tf-idf vectorizer
tfidfvec = TfidfVectorizer(ngram_range=(1,2), min_df = 0.0, max_df = 1.0, decode_error = "ignore")

# Run DBSCAN
trans_list = []
trans_dict = {}

for trans in non_queen_list:
    trans_dict[" ".join([lemma[2:] for lemma in trans.lemmas])] = trans
    trans_list.append(" ".join([lemma[2:] for lemma in trans.lemmas]))
    
X1 = tfidfvec.fit_transform(trans_list).toarray()
# (1,2),1.0 = 9, (1,2),1.1 = 6, (1,3),1.2 = 7
db1 = DBSCAN(eps=1.0, min_samples=len(trans_list)/100).fit(X1)  # Higher eps => More leniency to be same cluster
core_samples_mask = np.zeros_like(db1.labels_, dtype=bool)
core_samples_mask[db1.core_sample_indices_] = True

labels1 = db1.labels_
n_clusters_ = len(set(labels1)) - (1 if -1 in labels1 else 0) # Number of clusters in labels
print('Estimated number of clusters: %d' % n_clusters_)
# Out:
# Estimated number of clusters: 10

# %%
# Print clusters
clusters = {}
for c, i in enumerate(labels1):
    if i == -1:
        continue
    elif i in clusters:
        clusters[i].append(trans_list[c] )
    else:
        clusters[i] = [trans_list[c]]

i= 0
for c in clusters:
    print("Cluster", i)
    print("=========","\n")
    for trans in clusters[c]:
        print(trans_dict[trans].p_id)
        print(trans)
    print()
    i += 1
    
# Brief analysis: number of clusters depends on eps and ngram range
# Out:
# Cluster 0
# =========
#
# P100041
#  6(diš) udu  kišib₃ lu₂-{d}suen  ki ab-ba-kal-la-ta  ba-zi#  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na#  dub-sar#  dumu [...]  ARAD₂-[zu]
# P100189
#  2(diš) udu niga  1(diš) sila₄ ga  ba-uš₂  u₄ 5(diš)-kam  ki lu₂-dingir-ra-ta  ur-nigar{gar}  šu ba-ti  iti šu-eš₅-ša  mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P100190
#  1(diš) sila₄  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) nu-i₃-da  zabar-dab₅ maškim  5(diš) u₈ 2(diš) udu 1(diš) maš₂  ba-uš₂ e₂-kišib₃-ba-še₃  [u₄] 3(u) [la₂ 1(diš)?]-kam  ki na-sa₆-ta [ba]-zi  iti ezem-{d}šul-gi  mu us₂-sa ki-maš{ki} ba-hul
# P100191
#  1(diš) maš₂-gal niga 4(diš)? udu  ba-uš₂  u₄ 2(u) 4(diš)-kam  ša₃ unu{ki}-ga  ki lu₂-dingir-ra-ta  ur-nigar{gar}  šu ba-ti  iti u₅-bi₂-gu₇  mu# [{d}]amar#-{d}suen lugal
# P100211
#  1(diš) udu a? x saga?  1(diš) udu niga  1(diš) maš₂-gal niga  1(diš) udu  2(diš) sila₄ ga  1(diš) kir₁₁ ga  ba-uš₂  u₄ 1(u) 1(diš)-kam  ki lu₂-dingir-ra-ta  ur-nigar{gar}  šu ba-ti  iti še-sag₁₁-ku₅  mu {d}amar-{d}suen lugal
# P100214
#  4(diš) udu niga 1(diš) sila₄ niga  lugal-pa-e₃  4(diš) udu 1(diš) sila₄  ensi₂ pu-us₂{ki}  1(diš) sila₄  ensi₂ gir₂-su{ki}  1(diš) sila₄ ARAD₂-mu  mu-kuₓ(DU)  iti ezem-mah  mu en {d}nanna maš-e i₃-pa₃  u₄ 1(u) 1(diš)-kam
# P100217
#  2(diš) amar maš-da₃ {d}li₉?-si₄?  1(diš) maš-da₃ 2(diš) amar x x  2(diš) amar maš-da₃  e₂-a-i₃-li₂  2(diš) sila₄ šeš-da-da sanga  1(diš) amar maš-da₃  a₂-bi₂-la-ta  1(diš) maš₂ si₂-mat-i₃-li₂  2(diš) sila₄ ensi₂ urum₂{ki}  mu-kuₓ(DU)  na-sa₆ i₃-dab₅  iti in?-gu₇  mu us₂-sa ki-maš{ki} ba-hul  u₄ 1(u) 7(diš)
# P100218
#  3(u) maš₂-gal  ki ab-ba-sa₆-ga-ta  lugal-me-lam₂ ensi₂ nibru{ki}  i₃-dab₅  iti ezem-mah  mu en-unu₆-gal {d}inanna ba-hun  3(u) udu
# P100228
#  1(diš) sila₄ {d}en-lil₂  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) šeš-da-da sanga  1(diš) sila₄ {d}en-lil₂  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) en {d}inanna  1(diš) sila₄ {d}utu  mu-kuₓ(DU) ur-du₆  zabar-dab₅ maškim  1(diš) gu₄ niga 3(diš) u₈ ba-uš₂  e₂-muhaldim-še₃  u₄ 1(u) 1(diš)-kam  zi-ga  iti ezem-{d}nin-a-zu  mu en {d}nanna maš-e i₃-pa₃
# P100259
#  6(diš) sila₄  u₄ 2(u) 7(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a  i₃-dab₅  iti u₅-bi₂-gu₇  mu en-unu₆-gal {d}inanna ba-hun  6(diš)
# P100262
#  3(diš) maš₂-gal babbar  u₄ 1(u) 4(diš)-kam  ki ab-ba-sa₆-ga-ta  u₂-ta₂-mi-šar-ra-am  i₃-dab₅  giri₃ kal-{d}šul-gi  iti ezem-{d}nin-a-zu  mu en-unu₆-gal {d}inanna ba-hun  3(diš) udu
# P100263
#  6(diš) sila₄ ga  2(diš) kir₁₁ ga  3(diš) maš₂ ga  2(diš) {munus}aš₂-gar₃ ga  u₃-tu-da  u₄ 1(u) 2(diš)-kam  ki a-hu-ni  iti ki-siki-{d}nin-a-zu  mu {d}amar-{d}suen lugal
# P100264
#  2(diš) udu niga  3(diš) udu a-lum  u₄ 1(u) la₂ 1(diš)-kam  ki ab-ba-sa₆-ga-ta  u₂-ta₂-mi-šar-ra-am  i₃-dab₅  iti šu-eš₅-ša  mu en-unu₆-gal {d}inanna ba-hun
# P100265
#  2(diš) udu niga saga us₂  1(diš) gukkal niga  1(diš) u₈ niga  1(diš) udu  1(diš) ud₅  4(diš) sila₄  1(diš) kir₁₁  ba-uš₂ u₄ 1(u) 6(diš)-kam  ki lu₂-dingir-ra-ta  ur-nigar{gar}  šu ba-ti  iti ki-siki-{d}nin-a-zu  mu {d}amar-{d}suen lugal
# P100266
#  2(u) sila₄ ga  8(diš) kir₁₁ ga  4(diš) maš₂ ga  3(diš) {munus}aš₂-gar₃ ga  u₃-tu-da  u₄ 8(diš)-kam  ša₃ na-gab₂-tum  lu₂-dingir-ra i₃-dab₅  iti ezem-me-ki-gal₂  mu {d}amar-{d}suen lugal  3(u) 5(diš)
# P100268
#  2(diš) udu  3(diš) sila₄  1(diš) maš₂  3(diš) sila₄ ga  1(diš) maš₂ ga  ba-uš₂  u₄ 2(u) 7(diš)-kam  ki {d}šul-gi-a-a-mu-ta  ur-nigar{gar}  šu ba-ti  u₅-bi₂-gu₇  mu {d}gu-za {d}en-lil₂-la₂ ba-dim₂
# P100269
#  1(diš) ab₂  3(diš) udu  1(diš) maš₂-gal  1(diš) ud₅  1(diš) sila₄ ga  ba-uš₂ u₄ 6(diš)-kam  ki {d}šul-gi-a-a-mu-ta  {d}šul-gi-iri-mu  šu ba-ti  iti ezem-{d}nin-a-zu  mu en-unu₆-gal {d}inanna ba-hun  1(diš) gu₄ 6(diš) udu
# P100284
#  1(u) 3(diš) gu₄ 1(u) 7(diš) ab₂  1(diš) gu₄ amar ga  a₂-bi₂-la-ša  1(u) ab₂ 1(diš) sila₄  dingir-su-ra-bi₂  1(diš) sila₄ lu₂-sun₂-zi#-da#  2(diš) amar maš-da₃ hu-un-ha-ab-ur  3(diš) udu 2(diš) maš₂-gal  zu-zu-ma-IŠ . 1(diš) sila₄ ti-ša-{d}da-hi  2(diš) amar maš-da₃ lu₂-{d}nanna  1(diš) sila₄ en {d}inanna  1(diš) sila₄# u₃-ma-ni  2(diš) amar# maš-da₃ ur-mu  1(diš) sila₄#? ku-ru-ub-e₂-a muhaldim  1(diš) sila₄#? bu-bu  1(diš) amar maš-da₃ te#?-la-a  mu-kuₓ(DU) iti maš-da₃-gu₇  mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul  u₄ 2(u) 4(diš)-kam
# P100287
#  1(diš) gu₄ 1(u) 5(diš) udu šu-gid₂  mu aga₃-us₂-e-ne-še₃  u₄ 2(u) 6(diš)-kam  2(diš) gu₄ 5(u) udu šu#-gid₂  8(diš) udu ba-uš₂  lugal nibru{ki}-še₃  du-ni ma₂-a ba-a!-gar  u₄ 2(u) 7(diš)-kam  ki du₁₁-ga-ta ba-zi  iti ezem-an-na  mu {d}šu-{d}suen lugal  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-{d}šul-pa-e₃  dub-sar  dumu ur-{d}ha-ia₃  ARAD₂-zu
# P100297
#  3(diš) gu₄ 2(diš) ab₂ e₂-muhaldim  u₄ 1(diš)-kam  1(diš) gu₄ 3(diš) ab₂  u₄ 2(diš)-kam  2(diš) gu₄ 4(diš) ab₂  u₄ 3(diš)-kam  4(diš) gu₄ 1(diš) ab₂  u₄ 4(diš)-kam  4(diš) gu₄ 2(diš) ab₂ . u₄ 5(diš)-kam . 1(diš) gu₄ u₄ 6(diš)-kam . 1(diš) gu₄ 3(diš) ab₂ . u₄ 7(diš)-kam . 3(diš) ab₂ u₄ 8(diš)-kam . 3(diš) gu₄ 1(diš) ab₂ . u₄ 1(u) la₂ 1(diš)-kam . 2(diš) gu₄ 4(diš) ab₂ u₄ 1(u)-kam . 1(diš) gu₄ 2(diš) ab₂ u₄ 1(u) 1(diš)-kam  2(diš) gu₄ u₄ 1(u) 2(diš)-kam  2(u) 2(diš) gu₄ 4(diš) ab₂  u₄ 1(u) 3(diš)-kam  1(diš) gu₄ u₄ 1(u) 7(diš)-kam  4(diš) gu₄ 2(diš) ab₂  u₄ 1(u) 8(diš)-kam  1(diš) gu₄ 2(diš) ab₂ u₄ 2(u) 1(diš)-kam  2(diš) gu₄ 2(diš) ab₂ u₄ 2(u) 2(diš)-kam  4(diš) gu₄ 1(diš) ab₂ u₄ 2(u) 3(diš)-kam . 1(diš) gu₄ u₄ 2(u) 4(diš)-kam . e₂-muhaldim-še₃ . šu+nigin 5(u) 8(diš) gu₄ . šu+nigin 3(u) 6(diš) ab₂ . ki {d}en-lil₂-la₂-ta ba-zi . iti a₂-ki-ti . mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} mu-hul  1(geš₂) 3(u) 4(diš) gu₄ ab₂ hi-<a>
# P100318
#  3(gešʾu) 4(u) udu maš₂ hi-a  ki nu-ur₂-gi-li₂-ta!  ba-zi  iti še-sag₁₁-ku₅-ta  iti ezem-{d}me-ki-gal₂-še₃  iti 1(u) 2(diš)-kam  mu {d}šu-{d}suen lugal uri₅{ki#}-<<ma>>-ma-ke₄ [ma]-da za-ab-ša-li{ki} mu-hul . e₂-tum  {d}[šu-{d}]suen  lugal [kal-ga]  [lugal] uri₅#{ki}-ma  [lugal an] ub!-da limmu₂-ba  lugal-iti?-da  dub-sar  dumu ur-{d}dumu-zi-da  ARAD₂-zu
# P100321
#  1(diš) sila₄ {d}en-lil₂  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) en {d}inanna  1(diš) sila₄ {d}en-lil₂ . 1(diš) maš₂?-nita₂ . 5(diš) udu-nita₂ . zu!-ri-im . lu₂ kin-gi₄-a lu₂ eb-la{ki} . mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P100327
#  2(diš) udu 2(diš) maš₂ 1(diš) sila₄ {d}en-lil₂  2(diš) udu 2(diš) maš₂ 1(diš) sila₄ {d}nin-lil₂  1(diš) sila₄ {d}nanna  1(diš) sila₄ {d}nusku  1(diš) sila₄ {d}nin-urta  ša₃ e₂ {d}nin-lil₂-la₂  1(diš) sila₄ {d}nin-ti₂-ug₅-ga  1(diš) sila₄ {d}nin-hur-sag  1(diš) sila₄ {d}en-ki . 1(diš) sila₄# {d}šul-gi . [a₂ ge₆]-ba-a . 2(diš) sila₄ du₆-[ku₃] . en-{d}nanše-ki-ag₂ maškim . u₄ 2(u) 8(diš)-[kam] . šu+nigin 1(diš) ab₂ mu [x] 1(u) 3(diš) udu . šu+nigin 3(u) la₂ 1(diš) udu# 1(u) 1(diš) maš₂ . bala a-hu-ma ensi₂ nibru{ki} . ki ab-ba-sa₆-ga-ta ba-zi . iti šu-eš-ša . mu {d}amar-{d}suen lugal  5(u) 4(diš)
# P100328
#  4(diš) udu a-lum niga 3(diš)-kam us₂  8(diš) udu niga 4(diš)-kam us₂  1(diš) sila₄  be-li₂-a-ri₂-ik  2(diš) maš₂-gal niga 4(diš)-kam us₂  1(diš) sila₄  ṣe-lu-uš-{d}da-gan  4(diš) udu u₂  1(diš) sila₄ . ku-ba-ba-e . 4(diš) udu niga saga  6(diš) udu a-lum niga [saga]  2(u) udu a-lum niga saga us₂  3(u) udu a-lum niga 3(diš)-kam us₂  ba-ba-ti  u₄ 5(diš)-kam  mu-kuₓ(DU) lugal  in-ta-e₃-a i₃-dab₅  [giri₃] nu-ur₂-{d}suen dub-sar  iti# u₅-bi₂-gu₇ . mu us₂-sa {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ si-ma-num₂{ki} mu-hul  1(geš₂) 2(u) 1(diš) udu  nu-ur₂-{d}suen  dub-sar  dumu i-di₃-er₃-ra
# P100329
#  1(geš₂) 1(u) 3(diš) [x] šimašgi  5(diš) kir₁₁#? gub  6(diš) udu 4(u) 6(diš) udu šimašgi  1(diš) maš₂-gal šimašgi  giri₃ ba-na-x  4(u) ud₅ šimašgi 3(u) maš₂-gal šimašgi  giri₃ a-bi₂-e₂  4(u) 1(diš) udu 5(diš) maš₂-gal  giri₃ puzur₄-{d}tišpak . 1(u) 2(diš) maš₂-gal 8(diš) maš₂-gal šimašgi . giri₃ a-za-ak-za-gaz . 2(u) 1(diš) u₈ 1(geš₂) 1(u) 3(diš) u₈ šimašgi . 5(diš) kir₁₁ gub 1(geš₂) 4(diš) udu . 4(u) 6(diš) udu šimašgi . giri₃ še-er-ha-num₂ . 4(u) ud₅ šimašgi 3(u) la₂ 1(diš) maš₂-gal šimašgi  giri₃ i-ri-ib  3(u) udu giri₃ e-la-ak-nu-id  1(u) 7(diš) maš₂-gal 7(diš) maš₂-gal šimašgi  giri₃ ib-ši-ka  šu+nigin 1(geš₂) 2(u) 2(diš) udu 1(geš₂) 3(u) 2(diš) udu šimašgi  šu+nigin 2(u) 1(diš) u₈ 2(geš₂) 2(u) 6(diš) u₈ šimašgi  šu+nigin 1(u) kir₁₁ gub 3(u) 4(diš) maš₂-gal  šu+nigin 1(geš₂) 1(u) 5(diš) maš₂-gal šimašgi  šu+nigin 1(geš₂) 2(u) ud₅ šimašgi . ki ab-ba-sa₆-ga-ta . nu-ur₂-{d}suen i₃-dab₅ . iti a₂-ki-ti . mu en# eridu{ki} ba-hun
# P100331
#  1(diš) gukkal 2(diš) gukkal geš-du₃  in-gi-mu-um  [x] gukkal 2(diš) gukkal  [...] IL₂  [...] x 2(diš) udu  x [...]-nu-um  mar-tu-me  1(diš) sila₄ niga {d}šul-gi-zi-mu  1(diš) sila₄ lu₂-{d}x . 1(diš) sila₄ ensi₂ šuruppak{ki} . 1(diš) sila₄ ur-{d}nin-gal elam . 1(diš) sila₄ niga lu₂-{d}nin-šubur šabra . 1(diš) sila₄ šeš-kal-la  1(diš) sila₄ ur-{d}en-lil₂-la₂ dub-sar  1(diš) sila₄ na-bi₂-{d}en-lil₂  1(diš) udu a-lum geš-du₃  1(diš) gukkal ur-nigar{gar} gudu₄  2(diš) maš₂ x {d}en-lil₂-la₂  1(diš) sila₄ za#-ri-iq  1(diš) sila₄ ša₃-ge  u₄ 2(u)-kam  mu-kuₓ(DU) . ab-ba-sa₆-ga i₃-dab₅ . iti a₂-ki-ti . mu {d}gu-za-mah {d}en-lil₂ ba-dim₂
# P100332
#  [x] 1(diš) udu niga saga us₂  [x] 5(diš) udu niga 3(diš)-kam us₂  1(u) udu niga 4(diš)-kam us₂  3(u) udu u₂  zi-ni-a ama ku-ba-tum  u₄ unu{ki}-še₃ i₃-gen-na-a  {d}nin-lil₂-ama-mu  [...] maškim#  [...]  [a₂] ge₆-ba-a  [u₄] 1(u) 3(diš)-kam  ki puzur₄-{d}en-lil₂-ta ba-zi  giri₃ er₃-re-šum šar₂-ra-ab-du  iti ki-siki-{d}nin-a-zu  mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ ma₂#-gur₈-mah [{d}en]-lil₂ {d}nin-lil₂-ra [mu]-ne-dim₂  5(u)!
# P100335
#  2(diš) udu  1(diš) sila₄  1(diš) sila₄ ga  ba-uš₂  u₄ 8(diš)-kam  ki na-lu₅-ta  ur-nigar{gar}  šu ba-ti  iti maš-da₃-gu₇  mu us₂-sa ki-maš{ki} ba-hul
# P100336
#  [x] gu₄ niga  4(diš)#? amar ku₅ mu 2(aš) niga  1(u) 5(diš) gu₄-geš šu-gid₂  siskur₂ gu-la₂ e₂ {d}en-lil₂ {d}nin-lil₂  iti u₄ 2(u) 6(diš) ba-zal  ki lu₂-dingir-ra-ta  na-sa₆ i₃-dab₅  iti šu-eš-ša  mu ki-maš{ki} u₃ hu#-ur₅-ti{ki} ba-hul
# P100337
#  2(diš) gu₄ niga  1(diš) amar gu₄  2(diš) udu niga  1(diš) gukkal niga  1(diš) sila₄#?  1(diš) kir₁₁ niga  1(diš) maš₂-gal niga  1(diš) ud₅ niga  1(diš) {munus}aš₂-gar₃  1(diš) udu?  7(diš) maš₂-gal  5(diš) x  1(diš) sila₄ bar-[gal₂]  ba-uš₂ u₄ 2(u) 2(diš)-[kam]  ki lu₂-dingir-ra-ta#  ur-nigar{gar} šu ba-ti#  iti maš-da₃-gu₇ . mu us₂-sa ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P100339
#  1(diš) udu niga  3(diš) sila₄# [...]  1(diš) maš₂-gal  ba-uš₂  u₄ 5(diš)-kam  ki lu₂-dingir-ra#-[ta]  ur-nigar[{gar}]  šu ba-ti#  iti ses-da-gu₇  mu {d}amar-{d}suen lugal-e {geš}gu-za {d}en-lil₂ in-dim₂
# P100564
#  1(geš₂) 5(u) 5(diš) guruš u₄ 1(diš)-še₃  ki ba-saga gu-za-la₂-ta  lu₂-sa₆-i₃-zu  šu ba-ti  mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul
# P100771
#  igi 3(diš)-gal₂ 5(diš) še ku₃  ki {d}šara₂-za-me-ta  da-da-ga  mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul
# P100774
#  1/2(diš) ma-na 9(diš) gin₂ ku₃-babbar  la₂-ia₃ su-ga udu  ki ba-sa₆-ta  ugu₂ da-da-ga ba-a-gar  kišib₃ ur-{d}šara₂  mu si-mu-ru-um{ki}  lu-lu-bu a-ra₂ 1(u) la₂ 1(diš)-kam ba-hul
# P100775
#  1/2(diš) ma#-na# ku₃-babbar  la₂-ia₃ su-ga siki#  ki ur-{geš}gigir sipa-ta  ugu₂ da-da-ga ba-a-gar  kišib₃ ur-{d}šara₂  mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš@t)-kam ba-hul
# P100776
#  2(diš) gin₂ ku₃  la₂-ia₃ su-ga  ki ur-{d}en-ki lunga-ta  da-da-ga  šu ba-ti  mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš@t)-kam-aš ba-hul
# P100972
#  1(diš) sila₄  ab-ba  2(diš) maš-da₃  ensi₂ umma{ki}  2(diš) gu₄ 2(diš) udu  2(diš) gukkal  3(diš) udu a-lum  3(diš) maš₂-gal  ma-ni-um mar-tu  2(diš) amar maš-da₃  e₂-a-i₃-li₂  [mu-kuₓ(DU)] iti maš-da₃-gu₇  mu us₂-sa ur-bi₂-lum{ki} ba-hul  u₄ 2(diš)-kam
# P100974
#  1(diš) gu₄ niga sag-gu₄  1(diš) amar gu₄ ga mar-tu  3(diš) kir₁₁ ga  3(diš) maš₂ ga  ba-uš₂ u₄ 1(u) 7(diš)-kam  ki lu₂-dingir-[ra]  ur-nigar{gar}  šu ba-ti  iti ezem-an-na  mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P100977
#  [n] 2(u) la₂ 1(diš@t) udu niga gu₄-e-us₂-sa  1(diš) sila₄ niga  ensi₂ ka-zal-lu{ki}  1(diš) sila₄ zabar-dab₅  1(diš) sila₄ ur-tilla₅  8(diš) udu 2(diš) maš₂-gal 1(diš) maš₂  kur-bi-la-ak lu₂ ba-šim-e{ki}  2(diš) gu₄ niga 6(diš) maš₂  1(u) 3(diš) udu 1(diš) maš₂ . ur-{d}suen dumu šeš-da-da sanga . 4(diš) udu niga 2(diš) sila₄ ad-da-tur  1(diš) sila₄ a-da-[...]  1(diš) sila₄ šeš-sa₆-[ga]  2(diš) udu 2(diš) ud₅ maš₂ nu₂-[a]  i-di₃-{d}iškur šuš₃  5(diš) udu 1(diš) maš₂ la-gi-ip dumu i-di₃-a-sur{ki}  4(diš) dusu₂-nita₂ 2(diš) dusu₂ munus  nam-ra-ak kur mar-tu  ki lu₂-{d}nanna šagina-ta  giri₃ la-muš-ta lu₂ kas₄ . mu-kuₓ(DU) na-sa₆ i₃-dab₅ . iti ezem-{d}šul-gi . [mu ha-ar-ši{ki}] ki-maš{ki} [hu-ur₅-ti{ki}] u₃ ma-da-bi ba-hul
# P100978
#  1(diš) sila₄ niga {d}en-lil₂#  mu-kuₓ(DU) ur#-nigar#{gar}  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) za-a-an-nu-um sipa  zabar#-dab₅ maškim  1(diš) maš₂# e₂#-uz#-ga  mu-kuₓ(DU) ku-na-ma#-tum mar-tu  a-a-kal-la maškim  3(diš) gu₄ 3(diš) ab₂  1(u) 3(diš) udu 1(u) 5(diš) u₈#  2(diš) ud₅ šu-gid₂ e₂#-muhaldim  mu aga₃-us₂-e-ne-še₃  ur-nigar{gar} šu ba-ti  u₄ 1(u) 1(diš)-kam  ki na-sa₆#-ta  ba-zi  iti# šu#-eš-ša  mu us₂-sa ki-maš{ki} ba-hul
# P100983
#  1(diš) sila₄ lugal-a₂-zi-da  1(diš) sila₄ {d}šara₂-kam ensi₂  1(diš) amar maš-da₃  bur-ma-ma dam-gar₃  o o o 3(diš)  u₄ 1(diš)-kam  u₄ 1(u)-a u₄ 2(diš)-kam  1(diš) maš₂ ur-{d}šul-pa-e₃ ra₂-gaba  2(diš) sila₄ en {d}inanna . 1(diš) sila₄ ensi₂ eriš₂{ki} . 1(diš) sila₄ i-bi₂-zu nu-banda₃ . 1(diš) sila₄ ensi₂ nibru{ki} . o o o 6(diš) . u₄ 3(diš)-kam . 4(diš) udu niga . 1(diš) sila₄ . {d}šara₂-kam ensi₂ . 1(diš) sila₄ lugal-dub-sar di-ku₅ . 1(diš) sila₄ ur-mes ensi₂ . a₂-bi₂-li₂-a nu-banda₃ . o o o 8(diš) . u₄ 4(diš)-kam . 2(diš) sila₄ wa-ta₂-ru-um sanga . o o o 2(diš) . [u₄] 5(diš)-kam . [...]-gi₄ [...] . [...]  3(diš) udu niga  1(diš) sila₄ ensi₂ urumₓ(|UR₂×U₂|){ki}  1(diš) sila₄  1(diš) maš₂-da₃  {d}šul-gi-na-da  1(diš) u₈  1(diš) sila₄ ga  1(diš) kir₁₁ ga  i₃-lal₃-lum . 1(diš) sila₄ šu-i₃-li₂ sukkal . 1(u) 3(diš) . u₄ 7(diš)-kam . 2(diš) gu₄ . 1(u) 4(diš) udu . 1(diš) sila₄ . 5(diš) maš₂-gal . šu-e₂-a nu-banda₃-gu₄ . ugula lugal-ma₂-gur₈-re . 2(diš) sila₄ . wa-ta₂-ru-um sanga . 1(diš) udu i-gi₄-ru-mah . 2(diš) udu AN-AN-ma-lik . 1(diš) sila₄ . i-me-er nu-banda₃ . 1(diš) amar maš-da₃ . nir-i₃-da-gal₂ . 1(diš) sila₄ . i-šar-ra-ku?-da-aš . o o o 3(u) . u₄ 8(diš)-kam . 3(diš) udu a-lum . 1(diš) udu a-lum ga . du₁₀-i₃-li₂ . ugula i₃-lal₃-lum . 1(diš) amar maš-da₃ . wa-ta₂-ru-um sanga . 5(diš) . [u₄] 1(u) la₂ 1(diš@t)-kam . [1(diš)] x a#-ba#-{d}en-lil₂  1(diš) amar maš-da₃  du-uk-ra  o o o 2(diš)  u₄ 1(u)-kam  2(diš) sila₄  ur-mes ensi₂  1(diš) sila₄ ensi₂ a-pi₅-ak{ki}  1(diš) sila₄ a-a-mu  1(diš) sila₄ a-da-gal . 1(diš) sila₄ ensi₂ adab{ki} . o o o 6(diš) . u₄ 1(u) 1(diš)-kam . 2(diš) gu₄ niga . 6(diš) udu niga . 1(u) 3(diš) udu . 1(diš) maš₂ . wa-ta₂-ru-um sanga . 2(diš) gu₄ niga . 6(diš) udu niga gu₄-e-us₂-sa . 1(u) 3(diš) udu . 1(diš) maš₂ . ensi₂ nibru{ki} . mu-kuₓ(DU) a₂-ki-ti še-sag₁₁-ku₅ . 1(diš) sila₄ lu₂-sa₆-ga šabra . 2(diš) udu niga . 1(diš) sila₄ . nu-ur₂-{d}da-gan . 1(diš) sila₄ . lu₂-{d}inanna šu-ku₆ . 3(diš) udu . 1(diš) sila₄ . i-ga-ri . 2(diš) sila₄ . 1(diš) amar maš-da₃ . id-da-a . 1(diš) sila₄ ur-{d}suen . 5(u) 7(diš) . u₄ 1(u) 2(diš)-kam . [2(diš)] amar maš-da₃ . [ša₃-ga]-na-kum  1(diš) [...]  x x [...]  1(diš) maš₂ ur-nig₂  1(diš) udu ge₆ geš-du₃  na-ra-am-e₂-a  1(diš) sila₄  lu₂-{d}nin-gir₂-su šabra  o o o 6(diš)  u₄ 1(u) 3(diš)-kam . 1(diš) udu niga . 1(diš) udu a-lum niga . 1(diš) u₈ niga . za-na-a šitim . 1(diš) sila₄ ur-mes ensi₂ . i-mi-id-dingir šabra . 1(diš) sila₄ šeš-sa₆-ga . 2(diš) amar maš-da₃ . ARAD₂-mu . o o o 8(diš) . u₄ 1(u) 4(diš)-kam . 1(diš) sila₄ . kur-giri₃-ni-i₃-dab₅!(ŠE₃) . 1(diš) sila₄ . gu₃-de₂-a ensi₂ . 1(diš) amar maš-da₃ . šeš-kal-la aga₃-us₂ . o o o 3(diš) . u₄ 1(u) 5(diš)-kam . 1(diš) sila₄ e-du-[x] . 1(diš) x . gu₃-de₂-a ensi₂ . 1(diš) sila₄ šar-ru-um-i₃-li₂ . 1(diš) maš₂ nig₂-e₂-nig₂-ki-du₁₀ . o o o 4(diš) . u₄ 1(u) 6(diš)-kam . 1(diš) sila₄ a₂-bi₂-la . 1(diš) sila₄ ga . ni-za-ni-lu₂-zi . [...] x x . [...]  [...]  1(diš) [...]  KA? x [...]  1(diš) [x]  lu₂-{d}[...]  2(diš) sila₄ [...]  1(diš) udu a-[lum]  lugal-x-[...]  o o o 2(diš) [n] . u₄ 1(u) 7(diš)!-[kam] . 1(diš) [sila₄] . za-ri₂!-[iq] lu₂# [aš-šur₆] . 1(diš) [sila₄] . ensi₂# [adab{ki}] . lugal-[...] . o o o 4(diš)! . u₄ 1(u) 8(diš)-[kam] . u₄ 1(u)-a u₄ 2(u) la₂ 1(diš)-[kam] . 1(diš) sila₄ . 1(diš) sila₄ . ha-an-za-ab-tum . ensi₂ nibru{ki} . 1(diš) sila₄ ku-um ensi₂ . 1(diš) sila₄ lu₂-dingir-ra šabra . o o o 6(diš) . u₄ 2(u)-kam . 1(diš) sila₄ . 1(diš) amar maš-da₃ . lugal-a₂-zi-da . 1(diš) sila₄ a-da-x-[x] . 1(diš) [...] . al-[...] . 1(diš) sila₄ [...] . 1(diš) [...] . a-ad-[...] . [...]  1(u) [...]  1(diš) šeg₉-bar [x]  1(u) 6(diš) udu?  1(diš) sila₄  4(diš) maš₂-gal  1(diš) pirig  za-ri₂-iq lu₂ as₂-sur{ki}  1(u) la₂ 1(diš) udu . 3(diš) udu a-lum . 8(diš) maš₂-gal . šu-mi-in-ni . a-ba-u₃ mar-tu . 2(diš) sila₄ . ensi₂ nibru{ki} . 1(diš) sila₄ ARAD₂-mu . 2(diš) {munus}aš₂-gar₃ niga . i₃-lal₃-lum . 1(diš) sila₄ da-da gala . 1(geš₂) 1(u) la₂ 1(diš) . u₄ 2(u) 2(diš)-kam . 1(diš) sila₄ ur-mes ensi₂ . 1(diš) sila₄ da-da dumu-luga ...
# P100986
#  [x] maš₂ niga 3(diš)-kam us₂  1(diš) udu niga 4(diš)-kam us₂  1(diš) {munus}aš₂-gar₃ niga 4(diš)-kam us₂  siskur₂ {d}inanna ša₃ e₂-gal  {d}nanna-igi-du sagi maškim  a₂-ge₆-ba-a  5(diš) udu niga gu₄-e-us₂-sa  5(diš) maš₂-gal niga gu₄-e-us₂-sa  i-zi-in-{d}da-gan . 3(diš) udu niga gu₄-e-us₂-sa . kur-bi-la-ak . lu₂ eb-la{ki}-me-eš₂ . 5(diš) udu niga gu₄-e-us₂-sa . 5(diš) maš₂-gal niga gu₄-e-us₂-sa . a-bu-du₁₀ lu₂ ma-ri₂{ki} . 5(diš) udu niga gu₄-e-us₂-sa . i-pi₂-iq-re-e-u₂ mar-tu ia₃-a-ma-di₃-um . iri-ne-ne-še₃ du-ni . ma₂-a ba-ne-gub . 3(diš) udu niga gu₄-e-us₂-sa . 2(diš) maš₂-gal niga gu₄-e-us₂-sa  i₃-u₃-ša dumu me-ša#-[nu-nu?] šimašgi  giri₃ ur-sukkal sukkal  ARAD₂-mu maškim  2(diš) udu niga saga us₂  8(diš) udu niga 3(diš)-kam us₂  a-bi₂-si₂-im-ti  tu-ra-am-{d}da-gan maškim  a₂ u₄!-te-na  u₄ 1(u) 4(diš)-kam . [ki a]-ba-{d}en-lil₂-gin₇-ta . [ba]-zi . [ša₃] nibru{ki} . giri₃ lu₂-{d}nin-šubur dub-sar . iti ezem-{d}šu-{d}suen . mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ na-ru₂-a-mah {d}en-lil₂ [{d}]nin-lil₂-ra [mu]-ne-du₃
# P100988
#  [...] gu₄ gun₃-a  [...]-um  1(diš) gu₄ geš-du₃ gun₃-a  mar-da-mu-um  3(diš) gukkal 2(diš) maš₂  i-wu-mu-ti  2(diš) gukkal 3(diš) maš₂ ap-ki-da  3(diš) gukkal 4(diš) maš₂ ma-li-kum  mar-tu-me . 2(diš) amar az ur-{d}suen . 4(diš) ud₅ maš₂ nu₂-a 1(diš) {munus}aš₂-gar₃ . šar-ru-um-i₃-li₂ šuš₃ . 2(diš) sila₄ zabar-dab₅ . 1(diš) sila₄ i-ti-ib-si-na-at  1(diš) sila₄ x-x-x-in-{d}EN-[x]  1(diš) sila₄ i-šar-x-x-aš  1(diš) sila₄ in-ta-e₃-a  1(diš) sila₄ la-ma-har nu-banda₃  1(diš) maš₂ dingir-a-zu nu-banda₃  1(diš) sila₄ ta₂-hi-še-en nu-banda₃  1(diš) maš₂ bur-{d}iškur nu-banda₃  1(diš) sila₄ 2(diš) maš₂ en {d}inanna  3(diš) udu niga 2(diš) maš₂-gal niga 1(diš) sila₄ . šu-{d}en-lil₂ . 1(diš) [...] x-e₃ ra₂-gaba . 1(diš) [... ARAD₂]-mu . 1(u) 4(diš) [...] x . [mu ...]{ki} [ba]-hul  [u₄] 7(diš)-kam
# P100997
#  3(diš) sila₄  3(diš) maš₂  ki na-sa₆-ta  mu-kuₓ(DU)  iti ki-siki-{d}nin-a-zu  mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ [1(u) la₂ 1(diš)]-kam-aš ba-hul  6(diš)
# P100998
#  1(diš) udu a-udu hur-sag  1(diš) amar maš-da₃  ba-uš₂  u₄ 2(u) 1(diš)-kam  ki a-hu-ni-ta  ur-nigar{gar}  šu ba-ti  iti ki-siki-{d}nin-a-zu min-kam  mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul
# P101000
#  1(diš) maš₂-gal  ba-uš₂  u₄ 1(diš)-kam  ša₃ tum-ma-al{ki}  ki en-dingir-mu-ta  ur-nigar{gar}  šu ba-ti  iti ses-da-gu₇  mu us₂-sa ki-maš{ki} ba-hul
# P101002
#  3(diš) udu  1(diš) maš₂  u₄ 3(u)-kam  ki na-lu₅-ta  {d}šul-gi-iri-mu  šu ba-ti  iti a₂-ki-ti  mu {d}gu-za {d}en-lil₂-la₂ ba-dim₂
# P101003
#  2(u) 3(diš) gu₄  2(u) ab₂  1(geš₂) 2(u) u₈ ge₆ šimašgi  1(geš₂) 4(u) 8(diš) u₈ su₄ šimašgi  3(u) 8(diš) maš₂-gal šimašgi  2(u) 8(diš) ud₅ šimašgi  mu-kuₓ(DU) lugal  ki ab-ba-sa₆-ga-ta  {d}nanna-zi-ša₃-gal₂  ensi₂ gir₂-su{ki} i₃-dab₅  kišib₃ ka₅-a-mu  iti šu-eš₅-ša  mu en-mah-gal-an-na en {d}nanna ba-hun  ka₅-a-mu  dumu i₃-li₂-[mu]  sipa na-gab₂-[tum]
# P101004
#  2(u) 8(diš) gu₄ niga  1(geš₂) 3(diš) gu₄  1(geš₂) 2(u) la₂ 1(diš) ab₂  2(u) 1(diš) ab₂ gun₃-a  2(geš₂) 2(u) udu  1(geš₂) 2(u) 3(diš) udu šimašgi  5(diš) udu ge₆ šimašgi  3(geš₂) la₂ 1(diš) u₈ šimašgi  1(geš₂) 1(u) 4(diš) u₈ ge₆ šimašgi  1(u) 2(diš) maš₂-gal šimašgi  6(geš₂) 5(u) 3(diš) ud₅ šimašgi  1(geš₂) 4(u) 6(diš) {munus}aš₂-gar₃ šimašgi  u₄ 1(u) 7(diš)-kam  ki ab-ba-sa₆-ga-ta  {d}šul-gi-a-a-mu  i₃-dab₅  iti šu-eš₅-ša  mu en-mah-gal-an-na en {d}nanna ba-hun  3(geš₂) 1(u) 1(diš) gu₄ 1(gešʾu) 3(geš₂) 5(u) 2(diš) udu
# P101005
#  1(diš) udu  1(u) 5(diš) maš₂-gal  u₄ 1(u) 3(diš)-kam  ki ab-ba-sa₆-ga-ta  na-lu₅ i₃-dab₅  iti šu-eš₅-ša  mu hu-uh₂-nu-ri{ki} ba-hul  1(geš₂) 1(u) 5(diš)
# P101006
#  2(u) 7(diš) udu  4(diš) sila₄  5(u) 5(diš) maš₂-gal  u₄ 3(u)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a  i₃-dab₅  iti šu-eš₅-ša  mu hu-uh₂-nu-ri{ki} ba-hul  1(geš₂) 3(u)
# P101007
#  1(diš) [...]  1(diš) [...]  1(u) [...]  2(diš) [...]  5(u) 3(diš) sila₄ kin-[gi₄-a]  1(geš₂) 3(u) 5(diš) sila₄  4(geš₂) 5(u) 1(diš) sila₄ ga  7(geš₂) 4(u) 3(diš) u₈  3(diš) maš₂  2(geš₂) 5(u) 5(diš) maš₂ ga  1(u) 7(diš) ud₅ maš₂ nu-a  3(u) la₂ 1(diš) ud₅ 2(u) {munus}aš₂-gar₃  bala ensi₂ gir₂-su{ki}  ki ab-ba-sa₆-ga-ta  lu₂-sa₆-ga i₃-[dab₅]  iti še-sag₁₁-[ku₅]  mu hu-uh₂-nu-[ri{ki} ba-hul]  2(u) 4(diš) gu₄ 2(gešʾu) 1(geš₂) 8(diš) udu 1(diš) dusu₂
# P101008
#  4(diš) sila₄  u₄ 2(u) 5(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a i₃-dab₅  iti ezem-mah  mu hu-uh₂-nu-ri{ki} ba-hul  4(diš)
# P101009
#  2(diš) ud₅  1(u) 7(diš) maš₂  u₄ 2(u) 8(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a  i₃-dab₅  iti ezem-mah?  mu hu-uh₂-nu-ri{ki} ba-hul  2(u) la₂ 1(diš)
# P101010
#  1(u) la₂ 1(diš) udu  2(u) sila₄  8(diš) maš₂  u₄ 2(u) 8(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a i₃-dab₅  iti ezem-mah  mu hu-uh₂-nu-[ri{ki}] ba-hul  3(u) 7(diš)
# P101013
#  1(diš) amar maš-da₃-nita₂  {d}en-lil₂  1(diš) [amar] maš-[da₃]-nita₂  [{d}nin-lil₂]  [...]  [...]  ša₃ mu-kuₓ(DU) udu? [...]  u₄ 2(u) 8(diš)-kam  ki ab-ba-sa₆-ga-ta ba-zi  giri₃ lu₂-sa₆-ga dub-sar  iti maš-da₃-gu₇  mu en {d}nanna kar-zi-da ba-hun  4(diš)
# P101016
#  1(diš) udu niga saga  1(diš) maš₂-gal niga saga  1(diš) udu niga saga us₂  1(diš) udu niga 3(diš)-kam us₂  1(diš) udu niga 4(diš)-kam us₂  1(diš) udu niga gu₄-e-us₂-sa  an  1(diš) maš₂-gal niga saga  1(diš) udu niga saga us₂ . 1(u) udu niga gu₄-e-us₂-sa . {d}en-lil₂ . 2(diš) udu niga saga . 2(diš) udu niga saga us₂ . 1(diš) maš₂-gal niga 3(diš)-kam us₂ . 1(u) udu niga gu₄-e-us₂-sa . {d}nin-lil₂ . 1(diš) udu niga 3(diš)-kam us₂ . 1(diš) udu niga 4(diš)-kam us₂ . {d}gu-za {d}en-lil₂-la₂ . 1(diš) udu niga 3(diš)-kam us₂ . 1(diš) udu niga 4(diš)-kam us₂ . hur-sag-ga-lam-ma . 1(diš) udu niga 4(diš)-kam us₂ . AN a-ba-{d}en-lil₂-gin₇ . šu-nir {d}en-lil₂-la₂ . ša₃ nibru{ki} . 2(diš) udu niga saga . 1(diš) maš₂-gal niga saga us₂ . [x] udu niga gu₄-e-us₂-sa  {d}nin-lil₂  1(diš) udu niga 3(diš)-kam us₂  2(diš) udu niga 4(diš)-kam us₂  {d}nanna  1(diš) udu niga 3(diš)-kam us₂  1(diš) udu niga 4(diš)-kam us₂  {d}nin-ti₂-ug₅-ga  1(diš) udu niga 3(diš)-kam us₂  {d}nisaba . 1(diš) udu niga 3(diš)-kam us₂ . {d}en-lil₂-la₂ GI . 1(diš) udu niga 3(diš)-kam us₂ . 1(diš) udu niga 4(diš)-kam us₂ . e₂-gal mah . ša₃ e₂ {d}nin-lil₂-la₂ . 1(diš) udu niga . 1(diš) udu niga gu₄-e-us₂-sa . {d}nin-e₂-gi₄-a . 2(diš) udu niga 4(diš)-kam us₂ . 1(diš) udu niga . {d}nin-hur-sag . 2(diš) udu niga . {d}nin-pa-e₃ . ša₃ e₂ {d}nin-hur-sag . 2(diš) udu niga saga us₂ . 2(diš) udu niga du₆-ku₃ . 1(diš) udu niga 4(diš)-kam us₂ . {d}inanna ka-giri₃ . {d}šu-{d}[suen]  1(diš) udu niga [...]  1(diš) udu [...]  {d}PA-[...]  2(diš) udu niga [...]  1(diš) udu niga [...]  nig₂-[...]  {d}nin-[...]  1(diš) udu niga [...]  {d}[...] . 2(diš) udu [...] . {d}nin-[...] . 1(diš) udu niga [...] . 1(diš) udu [...] . 2(diš) udu niga [...] . {d}nin-sa₆-[...] . 1(diš) udu niga 4(diš)-kam [us₂] . 1(diš) udu [...] . {d}šu-{d}suen . 1(diš) udu niga x [...] . 1(diš) udu niga [...] . 1(diš) udu niga [...] . {d}EN-[...] . 1(diš) udu niga [...] . 1(diš) udu [...] . 1(diš) udu [...] . 1(diš) [...] . 2(diš) [...] . {d}nin-[...] . 2(diš) udu [...] . {d}x-x [...] . 1(diš) x x [...] . 1(diš) [...] . [...] . 1(diš) [...] . {d}[...] . 1(diš) udu niga gu₄-[e-us₂-sa] . {d}nisaba? . 1(diš) udu niga nig₂-x x . {d}nusku . 1(diš) udu niga gu₄-e-us₂-sa . nig₂-diri ʾ. {d}al-la gu-la ʾ. 1(diš) udu niga gu₄-e-us₂-sa ʾ. nig₂-diri ʾ. {d}[x]-x ʾ. ša₃ [x]-x-la [...] um? ʾ. 1(diš) udu [...] x ʾ. 1(diš) [...] ʾ. {d}nanna ʾ. 1(diš) [...] ʾ. {d}[...] ʾ. 1(diš) udu [...] ʾ. {d}ba-[...] ʾ. 1(diš) udu niga [...] ʾ. {d}nin-gir₂?-[su] ʾ. 2(diš) [...] ʾ. {d}en-[lil₂] ʾ. 2(diš) udu [...] ʾ. {d}nin-lil₂ ʾ. giri₃ a₂!-na-na ʾ. nig₂-dab₅ ezem [...] ʾ. 4(diš) x [...] ʾ. {d}šu-{d}[suen]  [x] udu niga  [...] niga  [...] a  [...] tum?  [...] iš?  [...] du?  [...] nisaba?  [...] ti  [a₂]-ge₆-ba-a . u₄ 7(diš)-kam . ki a-ba-{d}en-lil₂-gin₇-ta ba-zi . ša₃ nibru{ki} . giri₃ lu₂-{d}nin-šubur dub-sar . iti diri ezem-{d}me-ki-gal₂ . mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ na-ru₂-a-mah {d}en-lil₂ {d}nin-lil₂-ra mu-ne-du₃  2(geš₂) 2(u)
# P101300
#  2(diš) sila₄  ki ur-ku₃-nun-na-ta  du₁₁-ga  i₃-dab₅  iti ezem-mah  mu en {d}inanna maš₂-e i₃-pa₃  du₁₁-ga dub-sar  dumu lu₂-{d}nin-gir₂-su  sipa na-gab₂-tum
# P101301
#  5(diš) {anše}kunga₂-nita₂  3(diš) {anše}kunga₂ munus  mu-kuₓ(DU) lugal  ki na-ra-am-i₃-li₂-ta  lugal-an-na-ab-tum₂ i₃-dab₅  iti ses-da-gu₇  mu si-mu-ru-um{ki} u₃ lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul
# P101305
#  2(diš) gu₄ niga sag-gu₄  4(diš) gu₄ niga  eš₃-eš₃  e₂-u₄ 1(u) 5(diš)  ki a-hu-ni-ta  [na]-sa₆# i₃-dab₅  [u₄ 1(u)] 1(u) 3(diš)# ba-zal  iti ezem-an-na  mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P101308
#  6(diš) udu 1(diš) u₈  3(diš) maš₂  u₄ 4(diš)-kam  8(diš) udu 2(diš) maš₂  u₄ 5(diš)-kam  6(diš) udu 3(diš) u₈  1(diš) maš₂ u₄ 8(diš)-kam  7(diš) udu 1(diš) u₈  2(diš) maš₂ u₄ 1(u)-kam  4(u)  šu-gid₂ e₂-muhaldim  ki na-lu₅-ta  na-sa₆ i₃-dab₅  iti še-sag₁₁-ku₅  mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P101312
#  1(geš₂) 5(u) 5(diš) udu niga  1(diš) sila₄ niga  2(diš) {munus}aš₂-gar₃ niga  1(geš₂) la₂ 1(diš) udu  1(u) 3(diš) gukkal  7(diš) sila₄  3(diš) sila₄ gukkal  1(u) 8(diš) u₈  1(u) 5(diš) |U₈+HUL₂| . 6(diš) maš₂-gal  1(u) la₂ 1(diš) maš₂  2(diš) maš₂ ga  3(diš) ud₅  mu-kuₓ(DU) lugal  ki na-sa₆-ta  na-lu₅ i₃-dab₅  iti še-sag₁₁-ku₅  mu ha-ar-ši{ki} u₃ ki-maš{ki} ba-hul
# P101314
#  [x] gu₄ u₄ 1(u) 3(diš)-kam  6(diš) gu₄ 2(diš) ab₂  ša₃ uri₅{ki}-ma  1(diš) gu₄ ša₃ unu{ki}-ga  mu-kuₓ(DU) lugal  1(u) gu₄ 1(u) ab₂ uri₅{ki}-še₃  2(u) 8(diš) gu₄ lu₂ mar-ha-ši{ki}  ki a-hu-ni-ta  2(u) gu₄ 2(u) ab₂  uri₅{ki}-še₃  2(u) 6(diš) gu₄ lu₂ mar-ha-ši{ki}  ki lu₂-dingir-ra-ta  šu+nigin 1(geš₂) 3(u) 2(diš) gu₄  šu+nigin 3(u) 2(diš) ab₂  ki ab-ba-sa₆-ga-ta  {d}en-lil₂-la₂ i₃-dab₅  iti a₂-ki-ti . mu {d}amar-{d}suen lugal  2(geš₂) 4(diš)
# P101315
#  7(diš) sila₄ ga  6(diš) kir₁₁ ga  5(diš) maš₂ ga  5(diš) {munus}aš₂-gar₃ ga  u₃-tu-da  u₄ 3(u) la₂ 1(diš)-kam  a-hu-ni i₃-dab₅  iti ezem-an-na  mu {d}amar-{d}suen lugal  2(u) 3(diš)
# P101319
#  7(diš) udu 2(diš) udu geš-du₃  1(diš) sila₄ ši-ha-lum  1(u) udu 1(diš) sila₄  ṣe-li₂-{d}iškur šuš₃  1(diš) sila₄ nir-i₃-da-gal₂  4(diš) udu niga 1(diš) sila₄  i-mi-id-dingir šabra  1(diš) sila₄ ti-ša-{d}da-hi  1(diš) sila₄ ri₂-ba-a . 1(diš) sila₄ dingir-su-ra-bi₂ . 1(u) la₂ 1(diš) udu 2(u) 1(diš) udu geš-du₃ . udu za-ri₂-iq-ta . 2(u) 5(diš) udu 5(diš) udu geš-du₃  udu u₁₈-ba-a-ta  u₄ 8(diš)-kam  mu-kuₓ(DU)  ab-ba-sa₆-ga i₃-dab₅  iti ki-siki-{d}nin-a-zu  mu en-unu₆-gal {d}inanna unu{ki}-ga ba-hun
# P101323
#  3(diš) sila₄  1(diš) maš₂  u₄ 8(diš)-kam  du₁₁-ga i₃-dab₅  iti u₅-bi₂-gu₇  mu ma₂-dara₃-abzu ba-ab-du₈  ur-mes  dumu la-na kurušda
# P101324
#  2(diš) sila₄ ga  2(diš) kir₁₁ ga  u₃-tu-da  ša₃ na-gab₂-tum  u₄ 1(u) 2(diš)-kam  {d}šul-gi-a-a-mu i₃-dab₅  iti ki-siki-{d}nin-a-zu  mu {d}gu-za {d}en-lil₂-la₂ ba-dim₂  4(diš)
# P101325
#  8(diš) udu  ki ka₅-a-mu-ta  du₁₁-ga i₃-dab₅  iti ezem-{d}nin-a-zu  mu ma₂-dara₃-abzu {d}en-ki ba-ab-du₈  du₁₁-ga dub-sar  dumu lu₂-{d}nin-gir₂-su  sipa na-gab₂-tum
# P101326
#  4(diš) udu 3(diš) sila₄  giri₃ zal?-la-ti-a  2(diš) sila₄ giri₃ lu₂-uš-gi-na  u₄ 1(u) la₂ 1(diš)-kam  2(diš) sila₄ u₄ 1(u)-kam  giri₃ i₃-pa₃-da  ki in-ta-e₃-a-ta  du₁₁-ga i₃-dab₅  iti a₂-ki-ti . mu ma₂ {d}en-ki ba-ab-du₈  ur-[mes]  dumu [la-na kurušda]
# P101327
#  1(diš) gu₄ u₄ 8(diš)-kam  5(diš) gu₄ 3(diš) ab₂  u₄ 1(u) 2(diš)-kam  1(u) 4(diš) gu₄ mu 3(diš)  1(diš) ab₂ 3(diš) ab₂ mu 3(diš)  1(diš) {anše}kunga₂-nita₂  4(diš) {anše}kunga₂ munus  [u₄] 1(u) 3(diš)-kam  [2(diš)] {anše}kunga₂-nita₂ . [u₄] 2(u)-kam . 1(diš) gu₄ u₄ 2(u) 6(diš)-kam . šu+nigin 8(diš) gu₄ . šu+nigin 1(u) 4(diš) gu₄ mu 3(diš) . šu+nigin 4(diš) ab₂ . šu+nigin 3(diš) ab₂ mu 3(diš) . šu+nigin 3(diš) {anše}kunga₂-nita₂ . šu+nigin 4(diš) {anše}kunga₂ munus . mu-kuₓ(DU) ki du₁₁-ga-ta . {d}en-lil₂-la₂ i₃-dab₅ . iti ezem-mah . mu ma₂-dara₃-abzu {d}en-ki-ka ba-ab-du₈  3(u) la₂ 1(diš) gu₄ 7(diš) anše
# P101328
#  4(diš) udu  8(diš) maš₂  ki ka₅-a-mu-ta  du₁₁-ga  i₃-dab₅  giri₃ al-la-mu  iti ezem-me-ki-gal₂  mu ma₂ {d}en-ki-ka ba-ab-du₈  du₁₁-ga dub#-[sar]  dumu lu₂-[{d}nin-gir₂-su]  sipa na-[gab₂]-tum
# P101329
#  4(diš) sila₄  1(diš) maš₂  1(diš) amar maš-da₃-nita₂  u₄ 2(u) 5(diš)-kam  ki in-ta-e₃-a-ta  du₁₁-ga i₃-dab₅  iti maš-da₃-gu₇  mu us₂-sa ma₂-dara₃-abzu ba-ab-du₈  ur-mes  dumu la-[na kurušda]
# P101330
#  1(diš) sila₄ u₄ 2(u) 5(diš)-kam  1(u) 4(diš) sila₄  u₄ 2(u) 6(diš)-kam  ki in-ta-e₃-a-ta  du₁₁-ga i₃-dab₅  iti a₂-ki-ti  mu si-ma-num₂{ki} ba-hul  du₁₁-ga  dub-sar  dumu [...]
# P101332
#  3(diš) sila₄  ki in-ta-e₃-a-ta  du₁₁-ga <i₃-dab₅>  iti ezem-mah  mu si-ma-num₂{ki} ba-hul  du₁₁-ga  dumu [...]
# P101336
#  5(u) 1(diš) udu niga  4(u) 3(diš) udu niga gu₄-e-us₂-sa  u₄ 1(diš)-kam  1(diš) udu niga 4(diš)-kam us₂  u₄ 2(diš)-kam  2(diš) gu₄ u₂  4(diš) gu₄ mu 3(diš)  1(u) 3(diš) gu₄ mu 2(diš)  1(diš) ab₂ u₂ . 2(diš) ab₂ mu 2(diš) . 1(diš) udu a-lum niga 3(diš)-kam us₂ . 2(diš) udu niga . 5(diš) gukkal niga . 5(diš) udu a-lum niga . 2(diš) gukkal u₂ . 1(u) 6(diš) sila₄ u₂ . 2(u) 3(diš) udu a-lum u₂ . 2(diš) gukkal u₂ . 1(u) 4(diš) gukkal geš-du₃ u₂ . u₄ 3(diš)-kam . 1(u) sila₄ . u₄ 4(diš)-kam . 1(u) sila₄ . u₄ 5(diš)-kam . 1(diš) gu₄ niga 3(diš)-kam us₂ . 3(diš) udu niga . 1(u) sila₄  u₄ [6(diš)-kam]  2(diš) udu [...]  u₄ [7(diš)-kam]  5(diš) udu [...]  2(u) 2(diš) maš₂ [...]  5(u) 2(diš) ud₅  u₄ 1(u)-kam  1(diš) udu a-lum u₂  u₄ 1(u) 1(diš)-kam . 6(diš) gu₄ [...] . 2(geš₂) 4(u) 1(diš) udu [...] . 6(diš) maš₂-gal . u₄ 1(u) 4(diš)-kam . 1(diš) udu niga 3(diš)-kam us₂ . u₄ 1(u) 9(diš)-kam . 2(diš) udu a-lum niga . 1(u) 2(diš) udu u₂ . 1(geš₂) maš₂-gal u₂ . u₄ 2(u) 3(diš)-kam . 1(u) 7(diš) gukkal u₂ . 2(diš) gukkal geš-du₃ u₂ . 1(u) 9(diš) udu gukkal u₂ . u₄ 2(u) 5(diš)-kam . 1(diš) am gu₄ . 2(diš) gu₄ u₂ . 1(geš₂) 4(u) 3(diš) udu u₂  3(diš) maš₂-gal  u₄ 2(u) 6(diš)-[kam]  šu+nigin 1(diš) gu₄ niga 3(diš)-kam us₂  šu+nigin 1(u) 5(diš) gu₄ u₂  šu+nigin 1(diš) ab₂ u₂  šu+nigin 4(diš) gu₄ mu 3(diš)  šu+nigin 1(u) 3(diš) gu₄ mu 2(diš)  šu+nigin 2(diš) ab₂ mu 2(diš)  šu+nigin 1(diš) am gu₄ . šu+nigin 1(diš) udu niga 3(diš)-kam us₂ . šu+nigin 1(diš) udu a-lum niga 3(diš)-kam us₂ . šu+nigin 1(diš) udu niga 4(diš)-kam us₂ . šu+nigin 5(u) 3(diš) udu [...] . šu+nigin 5(diš) gukkal [...] . šu+nigin 7(diš) udu [...] . šu+nigin 4(u) 1(diš) [...] . šu+nigin 2(diš) [...] . šu+nigin 1(diš) [...]  šu+nigin 3(u) 4(diš) gukkal u₂  šu+nigin 1(u) 6(diš) gukkal geš-du₃ u₂  šu+nigin 2(u) 4(diš) udu a-lum u₂  šu+nigin 2(u) 1(diš) udu gukkal u₂  šu+nigin 3(u) 2(diš) maš₂-gal u₂  šu+nigin 5(u) 2(diš) ud₅ u₂  šu+nigin 3(diš) sila₄  3(u) 6(diš) gu₄  1(diš) am . 8(geš₂) 3(u) 6(diš) udu . ki in-ta-e₃-a-ta . du-u₂-du . i₃-dab₅ . iti ki-siki-{d}nin-a-zu . mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ na-ru₂-a-mah {d}en-lil₂ {d}nin-lil₂-ra mu-ne-du₃
# P101340
#  2(diš) udu  ki a-ba-{d}en-lil₂-gin₇-ta  ur-ku₃-nun-na  i₃-dab₅  iti ezem-mah  mu e₂ {d}šara₂ ba-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-su [kurušda]  ARAD₂-zu
# P101341
#  [n] gu₄ [niga]  ki puzur₄-{d}en-lil₂-ta  ur-ku₃-nun-na  i₃-dab₅  iti ezem-mah  mu e₂ {d}šara₂ umma#{ki} ba-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-su kurušda  ARAD₂-zu
# P101342
#  1(diš) gu₄ u₂  2(diš) udu u₂  1(diš) sila₄  u₄ 2(u) 5(diš)-kam  ki in-ta-e₃-a-ta  ur-ku₃-nun-na  i₃-dab₅  iti ezem-me-ki-gal₂  mu e₂ {d}šara₂ ba-du₃  du₁₁-ga [dub-sar]  dumu lu₂-[{d}nin-gir₂-su]  sipa na-gab₂-tum
# P101344
#  [x] gu₄  [ki] la-diš-ip-ta  ur-ku₃-nun-na  i₃-dab₅  iti a₂-ki-ti  mu {d}i-bi₂-{d}suen  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-su kurušda  ARAD₂-zu
# P101346
#  1(diš) sila₄  ki ur-{d}ig-alim-ta  ur-ku₃-nun-na  i₃-dab₅  ša₃ unu{ki}  iti ezem-mah  mu e₂ {d}šara₂ ba-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-[su kurušda]  [ARAD₂-zu]
# P101389
#  1(diš) sila₄ {d}en-lil₂  1(diš) sila₄ {d}nin-lil₂  2(diš) udu niga  mu-kuₓ(DU)-ta x zu [...]  4(diš) udu niga 1(diš) udu [...]  1(diš) sila₄? [...] en [...]  e₂-uz-[ga]  1(diš) sila₄ {d}[en-lil₂]  1(diš) sila₄ {d}nin-lil₂ . mu-kuₓ(DU) šeš da-da#-[ga] . 1(diš) sila₄ {d}[...] . mu-kuₓ(DU) dingir-su-[ra-bi₂] . ARAD₂-mu [...]  2(diš) maš-da₃ [...]  mu-kuₓ(DU) e₂-a-i₃#-[li₂]  1(u) la₂ 1(diš) udu 4(diš) [...]  1(diš) u₈ 4(diš) [...]  3(diš) [...]  šu-gid₂ e₂-muhaldim-[še₃]  u₄ 1(u) 1(diš)-kam  ki na-sa₆-ta ba-zi  iti a₂-ki-ti . mu us₂-sa ki-maš{ki} ba-hul mu us₂-sa-bi
# P101390
#  1(diš) udu niga {d}en-lil₂  mu-kuₓ(DU) a-hi-e₂-a  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) ta-la-a-a  1(diš) gukkal niga {d}en-lil₂  1(diš) gukkal niga {d}nin-lil₂  mu-kuₓ(DU) ur-{d}en-lil₂  1(diš) sila₄ {d}en-lil₂  mu-kuₓ(DU) zabar-dab₅ . 1(diš) sila₄ {d}nin-lil₂ . mu-kuₓ(DU) ur-{d}suen  {d}nanše-GIR₂@g?-gal maškim  1(diš) sila₄ mu-kuₓ(DU) ARAD₂-mu  1(diš) maš₂ mu-kuₓ(DU) ṣe-lu-uš-{d}da-gan  e₂-uz-ga  ur-{d}ba-[ba₆ maškim]  2(diš) udu a-wa-at-i₃-li₂ x  ARAD₂-mu maškim  1(diš) gu₄ 3(diš) udu 4(diš) u₈ 3(diš) [...]  3(diš) maš₂ 2(diš) ud₅ šu-gid₂ e₂-muhaldim-še₃ . u₄ 3(u) la₂ 1(diš)-kam . ki na-sa₆-ta ba-zi . iti ezem-mah . mu ha-ar-ši{ki} u₃ ki-maš{ki} ba-hul
# P101395
#  1(diš) udu [...]  1(diš) [...]  u₄ 1(diš)-kam  2(diš) udu [...]  3(diš) gukkal niga  4(diš) udu a-lum niga  1(diš) maš₂-gal niga  1(diš) udu u₂  1(diš) maš₂-gal u₂ . u₄ 7(diš)-kam . 1(diš) udu a-lum niga 4(diš)-kam us₂ . u₄ 8(diš)-[kam] . 1(diš) gukkal [x] . 2(diš) udu a-lum u₂ . 1(diš) maš₂-gal [...] . 4(diš) udu u₂ . 1(diš) udu a-lum niga . 3(diš) maš₂-gal u₂ . u₄ 9(diš)-[kam] . 1(diš) udu niga . 4(diš) udu [x]  u₄ [x-kam]  1(diš) udu [...]  u₄ [x-kam]  4(diš) [...]  1(diš) [...]  1(diš) [...]  u₄ [x-kam]  šu+nigin [...] a. šu+nigin [...] b. šu+nigin 8(diš) [...] š. šu+nigin 4(diš) [...] d. šu+nigin 7(diš) [...] e. šu+nigin 2(diš) maš₂ [...] f. šu+nigin 1(u) [...] g. šu+nigin 1(diš) udu a-lum [...] h. šu+nigin 1(u) 1(diš) [...] i. šu+nigin 1(diš) [...] . ki in-[ta-e₃-a-ta] . nu x [...] . iti ezem-[...] . mu {d}šu-{d}suen [bad₃] ma-da [mu-du₃]
# P101396
#  2(geš₂) 1(u) 1(diš) udu maš₂ hi-a  kišib₃ ka₅-a-mu  1(diš) udu {d}šul-pa-e₃  1(diš) udu a-hu-um  1(diš) sila₄ šu-ku-bu-um  [...] a. [...]  [...]  ki ur-mes-ta ba-zi  iti še-sag₁₁-ku₅  mu {d}šu-{d}suen lugal  du₁₁-ga dub-[sar]  dumu lu₂-{d}nin-gir₂#-[su]  sipa na-gab₂-tum
# P101397
#  2(diš) maš-da₃-nita₂ {d}en-lil₂  1(diš) maš-da₃ munus {d}gu-za {d}en-lil₂  1(diš) maš-da₃-nita₂ hur-sag-ga-lam-ma  [ša₃ e₂] {d}en-lil₂-la₂  [x maš]-da₃-nita₂ {d}nin-lil₂  [...]  [...]  [...]  1(diš) maš-[da₃ ...]-nun . 1(diš) maš-da₃-nita₂ ša₃-ta-x-x . 1(diš) maš-da₃-nita₂ pe-ru-ru-ti . 1(diš) maš-da₃-nita₂ [...]  1(diš) maš-da₃-nita₂ e₂-gi₄-a  lugal-a₂-zi-da x [...]  x {d}a-ma-ga [...]  6(diš) maš-da₃-nita₂ x maš-da₃-gu₇  mu-kuₓ(DU) egir₂-še₃  {d}šul-gi-iri-mu  šu ba-ti  ARAD₂-mu maškim  ša₃ mu-kuₓ(DU)-ra-ta . u₄ 8(diš)-kam . ki in-ta-e₃-a-ta ba-zi . giri₃ nu-ur₂-{d}suen dub-sar . iti ezem-{d}nin-a-zu . mu ma₂-dara₃-abzu {d}en-ki!-ka ba-ab-du₈  2(u) 5(diš)
# P101398
#  1(diš) udu  kišib₃ {d}utu-bar-ra unu₃  ki ur-mes-ta  ba-zi  iti ezem-{d}šul-gi  mu ma₂-dara₃-abzu ba-ab-du₈  udu  du₁₁-ga dub-sar  dumu lu₂-{d}nin-[gir₂-su]  sipa na-gab₂-[tum]
# P101399
#  2(u) 4(diš) udu u₂ ba-uš₂ e₂-muhaldim  mu lu₂ šuku-ra-ke₄-ne-še₃  u₄ 1(u) 6(diš)-kam  3(u) udu u₂ šu-gid₂ e₂-muhaldim  mu geme₂ dumu {d}inanna-ke₄-ne-še₃  u₄ 1(u) 7(diš)-kam  1(u) udu u₂ alan didli  ša₃ e₂ {d}inanna  uzu-a bala . siskur₂ gu-la  [...] didli  [...] 7(diš) udu u₂  šu-gid₂ e₂-muhaldim  lugal nibru{ki}-še₃ du-ni  [...] 1/2(diš) a-geš-IGI-ri  [u₄ ...] 5(diš)-kam  [...] ša₃-ga  [ki x x]-ta ba-zi  [iti ezem]-mah . [mu {d}šu]-{d}suen [lugal] uri₅{ki}-ma-ke₄ [ma₂-gur₈]-mah {d}en-lil₂ [{d}]nin-lil₂-ra mu-ne-dim₂  [{d}šu]-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-{d}šul-pa-[e₃]  dub-[sar]  dumu ur-{d}[ha-ia₃]  ARAD₂#-[zu]
# P101400
#  [...] 1(u) 1(diš) udu niga saga us₂  [x] gukkal niga 3(diš)-kam us₂  [x] udu niga 3(diš)-kam us₂  [x] maš₂-gal niga 4(diš)-kam us₂  {d}en-lil₂  1(diš) udu niga 4(diš)-kam us₂  {d}gu-za {d}en-lil₂-la₂  1(diš) udu niga 4(diš)-kam us₂  hur-sag-ga-lam-ma . ša₃ e₂ {d}en-lil₂-la₂ . [x] gukkal niga saga us₂ . [x] udu a-lum niga saga us₂ . [...] udu niga 3(diš)-kam us₂ . [...] niga 4(diš)-kam us₂ . [...] e₂ . [...] alan du₃ [...] . [...] x hu-ba-a . [...] x 1(diš) dusu x [...] . [...] 1(u) 4(diš) [mu-kuₓ(DU)] lugal . [...] 1(u) 5(diš)-kam . [ki] ša-x-e₂-ta . [ba]-zi . [giri₃ x]-an-ni dub-sar . [iti] ses-da-gu₇ u₄ . [mu {d}]šu-{d}suen lugal uri₅[{ki}-ma-ke₄ e₂ {d}šara₂] umma{ki}-ka [mu]-du₃
# P101401
#  1(u) 1(diš)#? udu# x-tur  1(diš) udu# ur-nigar{gar}  9(diš) maš₂ kišib₃ didli  o o o 2(u) 1(diš)  ki sa₂-si₂-ta  ba-zi  iti ezem-mah  u₄ 1(diš)-kam  mu e₂ {d}šara₂  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃#-[nun-na]  dub-sar  dumu lu₂#-[{d}nin-gir₂-su kurušda]  ARAD₂-zu
# P101402
#  1(diš) gu₄ niga ki {geš}gu-za ur-{d}namma  1(diš) gu₄ niga ki {geš}gu-za {d}šu-{d}suen  giri₃ ur-šu muhaldim  1(diš) gu₄ niga ki {geš}gu-za {d}šul-gi u₃ {d}amar-{d}suen  giri₃ uri₅{ki}-ki-du₁₀ muhaldim  u₄ 4(diš)-kam  ša₃ uri₅{ki}-ma  ki puzur₄-{d}en-lil₂-ta  ba-zi  iti ezem-mah  mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ e₂ {d}šara₂ umma{ki}-ka mu-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-{d}šul-pa-e₃  dub-sar  dumu ur-{d}ha-ia₃  ARAD₂-zu
# P101403
#  2(u) udu u₂ alan didli  ša₃ e₂ {d}en-lil₂-la₂  1(u) 7(diš) udu u₂ alan didli  ša₃ e₂ {d}nin-lil₂-la₂  uzu-a bala  siskur₂ gu-la  lugal kuₓ(KWU636)-ra  1(diš) ab₂ u₂  2(u) udu u₂ . 1(u) 7(diš) u₈ u₂ . 1(u) 8(diš) maš₂-gal u₂ . šu-gid₂ e₂-muhaldim . lugal uri₅{ki}-še₃ du-ni ma₂-a ba-a-gar . ARAD₂-mu maškim . ša₃ nibru{ki} . 1(diš) gu₄ 1(geš₂) 3(u) 2(diš) udu . u₄ 1(diš)-kam . 1(u) udu u₂ alan didli . ša₃ e₂ {d}inanna . uzu-a bala . siskur₂ gu-la . lugal kuₓ(KWU636)-ra . 2(u) [udu u₂ alan didli] . ša₃ e₂ {d}en-lil₂-la₂ . 2(u) udu u₂ alan didli  ša₃ e₂ {d}nin-lil₂  uzu-a bala  siskur₂ gu-la  puzur₄-eš₁₈?-dar? sagi maškim  ša₃ nibru{ki}  4(u) udu  u₄ 6(diš)-kam  2(u) 4(diš) udu u₂ . 1(u) 1(diš) u₈ u₂ . 2(u) maš₂-gal u₂ . mu AŠ PAP i-bu-hu . ša₃ um ma du [...]-še₃? . lugal-ma₂-gur₈-re maškim . ša₃ uri₅{ki}-ma . 1(diš) gu₄ 5(u) 5(diš) udu . u₄ 1(u) 1(diš)-kam . 2(u) udu u₂ alan didli . ša₃ e₂ {d}en-lil₂-la₂ . 2(u) udu u₂ alan didli . ša₃ e₂ {d}nin-lil₂-la₂ . uzu-a bala . siskur₂ gu-la . {d}šu-{d}suen-ma-ha-ar sagi maškim . ša₃ nibru{ki} . 4(u) udu . u₄ 1(u) 3(diš)-kam . 2(diš) gu₄ u₂ . 5(diš) ab₂ u₂ . 4(u) 3(diš) udu u₂  3(u) 3(diš) maš₂ u₂  1(u) 4(diš) ud₅ u₂  šu-gid₂ e₂-muhaldim  mu lu₂ maš₂-da-re-a-ke₄-ne-še₃  gešbun₂ er₂ su₃-a  ARAD₂-mu maškim  ša₃ uri₅{ki}-ma  1(u) maš₂-gal u₂  šu-gid₂ e₂-muhaldim  mu geme₂ dumu {d}inanna-ke₄-ne-še₃  u₄ ki-{d}utu ba-ak?-a  lugal-ma₂-gur₈-re maškim  ša₃ unu{ki}-ga  3(u) udu . mu x [...] . 1(diš) gu₄ u₂ . 6(diš) udu u₂ . 7(diš) maš₂-gal u₂ . mu lu₂ šuku-ra-ke₄-ne-še₃ . šu-gid₂ e₂-muhaldim . lugal-ma₂-gur₈-re maškim . ša₃ unu{ki}-ga . 1(diš) gu₄ 2(u) 3(diš) udu ʾ. u₄ 2(u) 5(diš)-kam ʾ. 1(u) ud₅ u₂ alan didli ʾ. ša₃ e₂ {d}inanna ʾ. uzu-a bala ʾ. siskur₂ gu-la  ša₃ unu[{ki}-ga]  1(u)  u₄ 2(u) 6(diš)-<kam>  1(diš) ab₂ u₂  5(diš) ud₅ u₂  mu aga₃-us₂ a tu₅-a ka e₂-gal-la kuₓ(KWU636)-ra-ne-še₃  1(diš) gu₄ u₂  5(diš) maš₂-gal u₂  4(diš) sila₄ . mu lu₂ šuku-ra-ke₄-ne-še₃ . šu-gid₂ e₂-muhaldim . lugal-ma₂-gur₈-re maškim . ša₃ unu{ki}-ga . 2(diš) gu₄ 1(u) 4(diš) udu . u₄ 2(u) 7(diš)-kam . 1(u) udu u₂ . šu-gid₂ e₂-muhaldim . mu lu₂ šuku-ra-ke₄-ne-še₃ . lugal-ma₂-gur₈-re maškim . ša₃ unu{ki}-ga . 1(u) udu . u₄ 2(u) 8(diš)-kam . 5(diš) udu u₂ {d}inanna . giri₃ a-bi₂-si₂-im-ti . {d}suen-a-bu-šu sagi maškim . 1(u) udu u₂ alan didli  ša₃ e₂ {d}inanna  lugal kuₓ(KWU636)-ra  1(u) 4(diš) ud₅ u₂  mu lu₂ šuku-ra-ke₄-ne-še₃  2(diš) ab₂ u₂  3(u) udu u₂  2(u) maš₂-gal u₂ . lugal nibru{ki}-še₃ du-ni ma₂-a ba-a-ga₂-ar . 2(diš) gu₄ 1(geš₂) 1(u) 8(diš) udu . u₄ 2(u) 9(diš)-kam . ša₃ nibru{ki} . u₄ 3(u)-kam  šu+nigin 7(diš) gu₄ u₂  šu+nigin 1(u) 1(diš) ab₂ u₂  šu+nigin 3(diš) ab₂ mu 3(diš)  šu+nigin 4(diš) ab₂ mu 2(diš)  šu+nigin 7(geš₂) 1(u) 2(diš) udu u₂  šu+nigin 2(u) 8(diš) u₈ u₂  šu+nigin 3(geš₂) 4(u) 8(diš) maš₂-gal u₂  šu+nigin 4(u) 3(diš) ud₅ u₂  šu+nigin 4(diš) sila₄ . šu+nigin₂ 2(u) 5(diš) gu₄ ab₂ hi-a . šu+nigin₂ 1(gešʾu) 3(geš₂) 5(u) 6(diš) udu maš₂ hi-a . ki ur-ku₃-nun-na-ta . ba-zi . giri₃ nu-ur₂-{d}suen dub-sar . iti ezem-mah . mu {d}šu-{d}suen . lugal uri₅{ki}-ma-ke₄ . e₂ {d}šara₂ umma{ki}-ka mu-du₃
# P101404
#  1(diš) gu₄ ab₂ u₄ 6(diš)-kam  1(diš) gu₄ niga u₄ 1(u) 4(diš)-kam  lugal-e gag bi₂-in-ra  uzu-bi e₂-kišib₃-ba ba-an-ku₄#  a₂-ge₆-ba-a  ki {d}šul-gi-i₃-li₂-ta ba-zi  iti ezem-an-na  mu {d}[šu]-{d}suen lugal [uri₅{ki}-ma-ke₄]  e₂ {d}šara₂ umma{ki}-ka mu-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-{d}šul-pa-e₃  dub-sar  dumu ur-{d}ha-ia₃  ARAD₂-zu
#
# Cluster 1
# =========
#
# P100219
#  1(diš) sila₄  zabar-dab₅  1(diš) sila₄  ensi₂ umma{ki}  1(diš) sila₄  ensi₂ gir₂-su{ki}  mu-kuₓ(DU)  na-sa₆ i₃-dab₅  iti a₂-ki-ti  mu ha-ar-ši{ki} hu-ur₅-ti{ki} ki-maš{ki} u₃ ma-da-bi u₄ aš-a ba-hul  u₄ 3(u)-kam
# P100260
#  1(diš) sila₄ {d}utu  mu-kuₓ(DU) zabar-dab₅  er₃-ra-na-da maškim  u₄ 4(diš)-kam  ki na-sa₆-ta ba-zi  iti šu-eš₅-ša  mu ha-ar-ši{ki} ki-maš{ki} hu-ur₅-ti{ki} u₃ ma-da-bi u₄ aš-a ba-hul
# P100261
#  2(diš) maš-da₃  e₂-kišib₃-ba-še₃  mu-kuₓ(DU) e₂-a-i₃-li₂  u₄ 2(diš)-kam  ki na-sa₆-ta  ba-zi  iti ezem-{d}šul-gi  mu ha-ar-ši{ki} hu-ur₅-ti{ki} ki-maš{ki} u₃ ma-da-bi u₄ aš-a ba-hul
#
# Cluster 2
# =========
#
# P100752
#  1(u) 4(diš) maš₂  maš₂ ma₂-gur₈-ra  da-umma{ki}  giri₃ kas₄  kas₄ i₃-dab₅  mu ku₃ gu-za {d}en-lil₂-la₂ ba-dim₂
# P100768
#  1(diš) 2/3(diš) ma-na 8(diš) gin₂ igi 4(diš)-gal₂ ku₃  ki da-da-ga-ta  ur-{d}dumu-zi-da  šu ba-ti
# P100783
#  2(diš) ma-na 2(diš) 1/2(diš) gin₂ la₂ 4(diš) še ku₃-babbar  maš a-ša₃-ga a-ša₃ ka-ma-ri₂{ki} u₃ a-ša₃ lugal  ki ur-{geš}gigir-ta  da-da-ga  šu ba-ti  mu ki-maš{ki} ba-hul
# P100784
#  1/3(diš) ma-na 2(diš) 1/2(diš) gin₂ 2(u) 2(diš) 1/2(diš) še ku₃-babbar  maš a-ša₃-ga  a-ša₃ me-en-kar₂  ki šeš-kal-la dumu na-silim-ta  da-da-ga  šu ba-ti  mu ki-maš{ki} ba-hul
# P100799
#  1(barig) 2(ban₂) 8(diš) 5/6(diš) sila₃ 5(diš) gin₂ i₃-nun  2(barig) 3(ban₂) 8(diš) sila₃ [ga]-UD@g  7(aš) gu₂ 5(u) [... ma]-na siki-ud₅  2(u) 8(aš) gu₂ 5(u) 7(diš) ma-na 1(u) gin₂ siki-gi  [n] gu₂ 3(u) 7(diš) 5/6(diš) ma-[na n] gin₂ siki-kur-ra  [ki] kas₄#-ta  [lugal]-ezem šu ba-ti  mu en {d}nanna maš-e i₃-pa₃
# P100811
#  [n] 8(aš) gu₂ 2(u) 8(diš) 5/6(diš) ma-na siki-gi  mu an-ša-an{ki} ba-hul  [n] 2(aš) gu₂ 3(u) 4(diš) ma-na siki [...]  1(u) 8(aš) gu₂ 5(u) la₂ 2/3(diš) ma-na siki-gi  a-ra₂ 1(diš)-kam  7(aš) gu₂ 5(u) la₂ 1(diš@t) ma-na [siki ...]  a-ra₂ 2(diš)-kam  ki ur-e₁₁-e-ta  3(aš) gu₂ 1(u) 3(diš) 2/3(diš) ma-na [siki ...] . a-pi₄-sal₄{ki}-ta . [...] 8(diš) [...]  [...]  ki ur-{d}šara₂ [...]  mu us₂-sa an-[ša-an{ki} ba-hul]
# P100813
#  9(aš) gu₂ 1(u) 4(diš) ma-na siki-gi  1(aš) gu₂ 2(u) 7(diš) ma-na siki gir₂-gul  siki udu-lah₅  giri₃ kas₄  kas₄ i₃-dab₅  mu ur-bi₂-lum{ki} ba-hul
# P100814
#  2(u) 5(aš) gu₂ 3(u) 5(diš) 2/3(diš) ma-na siki-gi  ku₃-bi 2(diš) 1/2(diš) ma-na 3(diš) 1/2(diš) gin₂ 1(u) 2(diš) še  ki ensi₂-ta  ur#?-dumu#-zi-da#  šu ba-ti  mu ki-maš{ki} ba-hul
# P100815
#  1(aš) gu₂ siki-gi  siki udu-lah₅  giri₃ kas₄ šuš₃  mu ku₃ gu-za {d}en-lil₂-la₂ ba-dim₂
# P100816
#  6(aš) gu₂ 2(u) 8(diš) ma-na siki  siki udu-lah₅  kas₄ šu ba-ti  mu en-mah-gal-an-na [en {d}nanna ba-hun-ga₂]
#
# Cluster 3
# =========
#
# P100820
#  1(diš) {kuš}e-sir₂ e₂-ba-an  1(diš) {kuš}ummu₃  ba-saga sagi  1(diš) {kuš}e-sir₂ e₂-ba-an  1(diš) {kuš}ummu₃  lugal-mas-su  ur-sukkal nar  4(diš) dug šakkan  kuš u₂-hab₂-bi 1(diš)  ur-{d}iškur šu-i  1(diš) {kuš}ummu₃  lugal-iri-ni-še₃  {kuš}suhub₂ im še-ga₂ e₂-ba-an . ensi₂  2(diš) kuš maš₂ ur-nigar{gar} ab-ba-iri  zi-ga ensi₂
# P101012
#  1(diš) {kuš}suhub₂ du₈-ši-a e₂-ba-an-ta  [x] x dumu ur-nigar{gar} . [...] . ša₃ puzur₄-iš-{d}[da-gan] . iti ezem-mah# [u₄ x ba-zal] . mu en-nun-e-{d}amar-{d}suen-ki#-ag₂# en# eridu{ki} ba#-hun
# P112830
#  4(diš) {kuš}suhub₂ du₈-ši-a e₂-ba-an  2(diš) {kuš}suhub₂ gu-dim₄-ba gada du₈-ši-a e₂-ba-an  2(u) 6(diš) {kuš}suhub₂ e₂-uruda-ka-gaz {kuš}suhub₂ aktum₂ e₂-ba-an  1(diš) {kuš}suhub₂ tug₂ du₈-a e₂-ba-an  2(u) 6(diš) {kuš}e-sir₂ du₈-ši-a suhuš gub-ba e₂-ba-an  1(diš) {kuš}e-sir₂ u₂-hab₂ e₂-ba-an  kin ak kal-la-ma-ad  gaba-ri kišib₃ nu-ur₂#-[i₃]-li₂#  ša₃ puzur₄-iš-{d}[da]-gan  iti ezem-{d}nin-a-zu  mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ na-ru₂-a-mah {d}en-lil₂ {d}nin-lil₂-ra mu-ne-du₃
# P113699
#  4(diš) {kuš}du₁₀-uk-si-um lugal du₈-ši-a e₂-ba-an  4(diš) {kuš}du₁₀-uk-si-um šagina du₈-ši-a tug₂ du₈-a siki-kur kuš-a ra-a  e₂-ba-an  2(diš) {kuš}du₁₀-uk-si-um šagina babbar₂ e₂-ba-an  kin ak-e-de₃  ki en-dingir-mu-ta  ba-zi  kišib₃ i-tu-tu-a  ki en-dingir-mu-ka  mu-gal₂-la gaba-ri-bi  iti maš-ku₃-gu₇  mu an-ša-an{ki} ba-hul
# P113737
#  1(diš) {kuš}suhub₂ tug₂ du₈-a e₂-ba-an  1(diš) ša₃-TUG₂ {kuš}suhub₂ e₂-ba-an-bi  a-tu₅-a  u₄ 1(u) 5(diš)-ka  ki i-du-du-a-ta  ba-zi  ša₃ tum-ma-al{ki}  iti ezem-{d}šul-gi  mu us₂-sa e₂ puzur₄-iš-{d}da-gan ba-du₃
# P129700
#  5(diš) {kuš}suhub₂ du₈-ši-a e₂-ba-an  1(u) {kuš}suhub₂ e₂ dingir-ra e₂-ba-an  2(u) 1(diš) {kuš}e-sir₂ du₈-ši-a  suhuš gub-ba e₂-ba-an  3(diš) {kuš}e-sir₂ du₈-ši-a  ka-ur₄ e₂-ba-an  3(diš) {kuš}e-sir₂ du₈-ši-a ra-di  e₂-ba-an  3(diš) {kuš}e-sir₂ u₂-hab₂ e₂-ba-an . kin ak kal-la-ah  ki puzur₄-i₃-li₂-ta#  a-mur-dingir  šu ba-ti  giri₃ an-ne₂-ba-ab-du₇  ša₃ nibru{ki}  iti u₅-bi₂{mušen}-gu₇  u₄ 1(u) 8(diš)-kam  mu {d}i-bi₂-{d}suen lugal-e si-mu-ru-um{ki} mu-hul  {d}i-bi₂#-{d}suen#
#
# Cluster 4
# =========
#
# P101017
#  1(diš) u₈ šimašgi u₂  3(diš) maš₂-gal šimašgi u₂  1(u) 4(diš) ud₅ šimašgi u₂  iti ezem-{d}šu-{d}suen  2(u) 2(diš) ud₅ šimašgi u₂  iti ezem-mah  šu-gid₂  ki zu₂-ga-li-ta  ur-ku₃-nun-na i₃-dab₅  iti še-sag₁₁-ku₅-ta  iti ezem-{d}me-ki-gal₂-še₃  iti 1(u) 2(diš)-kam  mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ ma-da za-ab-ša-li{ki} mu-hul  4(u) udu
# P101338
#  1(geš₂) 1(u) 8(diš) udu u₂  4(u) 2(diš) maš₂-gal u₂  ki in-ta-e₃-a-ta  ku₃-{d}nanna ensi₂  i₃-dab₅  iti ezem-mah  mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ ma-da za-ab-ša-li{ki} mu-hul  2(diš) udu
# P101339
#  6(diš) gu₄ niga  3(u) 9(diš) udu u₂  4(u) maš₂-gal u₂  1(diš) sila₄  tabₓ(MAN)-ba-an-da-ra-ah  1(diš) gu₄ niga  9(diš) maš₂-gal u₂  1(diš) sila₄  te-ru-še-la-ah . 1(diš) gu₄ niga . 1(u) maš₂-gal u₂ . ad-du dam-a-ni . 1(diš) gu₄ niga . 9(diš) maš₂-gal u₂  1(diš) sila₄  u₃-zi nu-banda₃ lu₂ a-za-ma-an  ugula ṣe-lu-uš-{d}da-gan  gu₂ ma-da  mu-kuₓ(DU)  in-ta-e₃-a i₃-dab₅  giri₃ nu-ur₂-{d}suen dub-sar  u₄ 2(diš)-kam  iti ezem-an-na . mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ ma-da za-ab-ša-li{ki} mu-hul  9(diš) gu₄ 1(geš₂) 5(u) udu
#
# Cluster 5
# =========
#
# P100338
#  1(diš) dusu₂-nita₂  u₄ 3(u) la₂ 1(diš)-kam  ba-uš₂  ki šu-{d}idim  ur-nigar{gar}  šu ba-ti  iti šu-eš-ša  mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} mu-hul
# P100976
#  1(u) 7(diš) [...] dusu₂-nita₂  4(diš) dusu₂-nita₂ mu 2(diš)  3(u) 6(diš) dusu₂ munus  1(diš) dusu₂ munus mu 2(diš)  nam-ra-ak kur mar-tu  mu-kuₓ(DU) lugal  ki na-sa₆-ta  šu-{d}idim i₃-dab₅  5(diš) [...] 2(diš) ba-[zal]  mu us₂-sa ki-maš{ki} ba-hul
# P101393
#  1(diš) dusu₂-nita₂  lu₂ na-hi-mu-um  1(diš) dusu₂ munus  mu-da-num₂  dumu na-ap-la-num₂  1(diš) dur₃#  ra-ha-u₃  mar-tu  ki šu-{d}idim-ta#  ba-zi  iti šu-eš₅-ša  mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} mu-hul

# %% [markdown]
# # Predict

# %%
# Read all files to get all Drehem transactions
def read_files(subdir, ids, reverse=False):
    transactions = list()
    for i in range(1, 16):
        file_name = ""
        if i < 10:
            file_name += subdir + "p00" + str(i) + ".atf"
        else:
            file_name += subdir + "p0" + str(i) + ".atf"
        
        curr_transaction = None
        
        with open(file_name, encoding="utf8") as file:
            print("Opening:", file_name)
            for line in file:
                line = line.strip()
                if line.startswith('&P'):
                    p_id = line.split()[0][1:]
                    #print(p_id)
                    if (not reverse and p_id in ids):
                        ids.remove(p_id)
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    elif (reverse and p_id not in ids and len(transactions) <= 200):
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    else:
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        curr_transaction = None
                else:
                    if curr_transaction:
                        curr_transaction.lines.append(line)
        
        if curr_transaction:
            transactions.append(curr_transaction)
    
    #print(ids)
    #assert len(ids) == 0
    print("Number of transactions:", len(transactions))
    return transactions

# Return the IDs of docs to annotate
def get_drehem_ids(file):
    lst = list()
    with open(file, encoding="utf8") as f:
        for line in f:
            line = line.strip()
            lst.append("P" + line)
    return lst

# %%
all_ids = get_drehem_ids("drehem_p_ids.txt")
print(all_ids[:10])
all_transactions = read_files("raw-data/", all_ids)
# Out:
# ['P125693', 'P131063', 'P103742', 'P118642', 'P337724', 'P212008', 'P103154', 'P105823', 'P390986', 'P115492']
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 14594

# %%
data = []

for t in all_transactions:
    t.get_lemmatization()
    data.append(" ".join(t.get_sumerian_lemma()))
    
# Predict
X_new_counts = uni_and_bigram_vectorizer.transform(data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

uni_and_bigram_prediction = uni_and_bigram_classifier.predict(X_new_tfidf)

# %%
for doc, category in zip(data[:100], uni_and_bigram_prediction[:100]):
    print('%r => %s' % (doc, category))
# Out:
# 'ŋuruš itud a ud UN.IL₂ itud dumu ŋuruš ud UN.IL₂ gud gaba niŋ₂.ŠID šeš ŋuruš itud a ud UN.IL₂ itud dumu ŋuruš ud UN.IL₂ gud gaba niŋ₂.ŠID šeš' => not queen
# 'ŋuruš ud ki dumu šu teŋ mu ara lal hulu ŋuruš ud ki dumu šu teŋ mu ara lal hulu' => not queen
# 'geme ud ki diŋir šu teŋ mu hulu geme ud ki diŋir šu teŋ mu hulu' => not queen
# 'geme ki itud ud zal lungak dab itud mu hulu geme ki itud ud zal lungak dab itud mu hulu' => queen
# 'dumu lu lu lu didli dab itud ud zal šag ennun mu us huŋ dumu lu lu lu didli dab itud ud zal šag ennun mu us huŋ' => queen
# 'ŋuruš ŋuruš e gub ud ki kišib itud mu us e du mu us dumu ŋuruš ŋuruš e gub ud ki kišib itud mu us e du mu us dumu' => not queen
# 'šanabi sar al ak ŋuruš sar sar lal giŋ gabar ak ŋuruš sar ugula kišib itud mu hulu dubsar dug šanabi sar al ak ŋuruš sar sar lal giŋ gabar ak ŋuruš sar ugula kišib itud mu hulu dubsar dug' => not queen
# 'ŋuruš nagar ud gud apin gub ki kišib itud šunumun mu us hulu dumu ŋuruš nagar ud gud apin gub ki kišib itud šunumun mu us hulu dumu' => not queen
# 'ŋuruš ud kunzida id gub ŋuruš ud kunzida gub ugula kišib mu hulu dubsar dumu ŋuruš ud kunzida id gub ŋuruš ud kunzida gub ugula kišib mu hulu dubsar dumu' => not queen
# 'ŋuruš ud al sar ašag ugula kišib itud mu lugal dubsar dumu ŋuruš ud al sar ašag ugula kišib itud mu lugal dubsar dumu' => not queen
# 'ŋuruš ud ki ugu ŋar kišib mu guza dim dubsar dumu ŋuruš ud ki ugu ŋar kišib mu guza dim dubsar dumu' => not queen
# 'iku tuggur tuggur iku ŋušur ara iku a erin ud ašag ugula kišib mu us lugal bad MAR.TU du dubsar dumu da iku tuggur tuggur iku ŋušur ara iku a erin ud ašag ugula kišib mu us lugal bad MAR.TU du dubsar dumu da' => not queen
# 'sar al sar a ud sar gi kud sar a ud sar u ŋešgana sar a ud ašag gibil egir ugula kišib mu du dubsar dumu sar al sar a ud sar gi kud sar a ud sar u ŋešgana sar a ud ašag gibil egir ugula kišib mu du dubsar dumu' => not queen
# 'ŋuruš ud kisur ŋuruš ud kisur ašag ŋuruš ud kisur ŋuruš ud kisur gub še ŋeš ŋuruš ud ŋuruš ud še ŋeš rah im gurum ŋuruš ud še ga gur ud ugula kišib lukala itud u itud mu lugal du lukala dubsar dumu kuš ŋuruš ud kisur ŋuruš ud kisur ašag ŋuruš ud kisur ŋuruš ud kisur gub še ŋeš ŋuruš ud ŋuruš ud še ŋeš rah im gurum ŋuruš ud še ga gur ud ugula kišib lukala itud u itud mu lugal du lukala dubsar dumu kuš' => not queen
# 'ŋuruš ud kisur anzagar ašag gub ŋuruš ud kisur gub ŋuruš ud kisur gub ŋuruš ud kisur gub še ŋeš še de u kisur gub ugula kišib lukala itud mu lugal du lukala dubsar dumu kuš ŋuruš ud kisur anzagar ašag gub ŋuruš ud kisur gub ŋuruš ud kisur gub ŋuruš ud kisur gub še ŋeš še de u kisur gub ugula kišib lukala itud mu lugal du lukala dubsar dumu kuš' => not queen
# 'sila kaš sila ninda giŋ i giŋ naŋa iri sila kaš babbar giŋ ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa šuniŋin sila kaš sila ninda ud itud sila kaš sila ninda giŋ i giŋ naŋa iri sila kaš babbar giŋ ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa šuniŋin sila kaš sila ninda ud itud' => not queen
# 'sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa šuniŋin sila kaš sag šuniŋin sila kaš du šuniŋin sila i giŋ naŋa itud nesaŋ ud sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa šuniŋin sila kaš sag šuniŋin sila kaš du šuniŋin sila i giŋ naŋa itud nesaŋ ud' => not queen
# 'giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa ud itud mu hulu giŋ i giŋ naŋa sila kaš sila ninda giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa ud itud mu hulu' => not queen
# 'sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum sila i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa sila giŋ naŋa itud nesaŋ ud mu ma du sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum giŋ i giŋ naŋa sila kaš sag sila ninda giŋ šum sila i giŋ naŋa sila kaš sila ninda giŋ šum giŋ i giŋ naŋa sila giŋ naŋa itud nesaŋ ud mu ma du' => not queen
# 'sila kaš sag sila ninda giŋ i giŋ naŋa sa šum sukkal gaba dabin ninda gal bala ŋiri itud šunumun mu e du sila kaš sag sila ninda giŋ i giŋ naŋa sa šum sukkal gaba dabin ninda gal bala ŋiri itud šunumun mu e du' => not queen
# 'kaš dida du dabin lu kiŋgia sila kaš i ud ki lu itud kaš dida du dabin lu kiŋgia sila kaš i ud ki lu itud' => not queen
# 'geme geme a itud geme geme a itud geme geme a itud geme geme a itud nesaŋ geme geme a itud dal geme geme a itud geme geme a itud geme geme a itud geme geme a itud geme geme a itud geme geme a itud geme geme a itud šuniŋin lal geme šuniŋin geme a itud geme igi giŋ geme a igi a geme ugula ušbar itud itud mu lugal geme geme a itud geme geme a itud geme geme a itud geme geme a itud nesaŋ geme geme a itud dal geme geme a itud geme geme a itud geme geme a itud geme geme a itud geme geme a itud geme geme a itud geme geme a itud šuniŋin lal geme šuniŋin geme a itud geme igi giŋ geme a igi a geme ugula ušbar itud itud mu lugal' => queen
# 'še šukur gur šeš itud mu hulu še šukur gur šeš itud mu hulu' => not queen
# 'še šukur guru itud mu us bad MAR.TU du še šukur guru itud mu us bad MAR.TU du' => not queen
# 'ŋuruš ud ma udu niga gid ŋiri ensik itud nesaŋ mu us hulu nita kalag lugal lugal an anubda limmu ensik arad ŋuruš ud ma udu niga gid ŋiri ensik itud nesaŋ mu us hulu nita kalag lugal lugal an anubda limmu ensik arad' => not queen
# 'uzud mu.DU itud šunumun mu e du uzud mu.DU itud šunumun mu e du' => queen
# 'gud ab hi kan gud ki dab itud šunumun mu us hulu gud ab hi kan gud ki dab itud šunumun mu us hulu' => queen
# 'lal udu sila kišib ki dab itud mu us hulu lal udu sila kišib ki dab itud mu us hulu' => queen
# 'gud ab hi laʾu sug unud ki kaš dab mu hulu gud ab hi laʾu sug unud ki kaš dab mu hulu' => not queen
# 'a ri eš didli ki kaš dab mu en maš pad a ri eš didli ki kaš dab mu en maš pad' => not queen
# 'gud ki kaš dab itud mu en maš pad gud ki kaš dab itud mu en maš pad' => not queen
# 'še ki kaš dab itud mu ara lal hulu še ki kaš dab itud mu ara lal hulu' => not queen
# 'gud ab hi ki kaš dab mu hulu gud ab hi ki kaš dab mu hulu' => not queen
# 'gud ab ki dab itud dal mu us hulu gud ab ki dab itud dal mu us hulu' => queen
# 'ab ga gud ga amar ŋiri unud kaš dab mu hulu ab ga gud ga amar ŋiri unud kaš dab mu hulu' => not queen
# 'maš maš magur kaš dab mu hulu maš maš magur kaš dab mu hulu' => not queen
# 'u maš mu.DU še urra šakkanak kaš dab mu kug guza dim u maš mu.DU še urra šakkanak kaš dab mu kug guza dim' => not queen
# 'maš sag kaguruk bisaŋdubak lukala šuniŋin maš magur dab itud nesaŋ mu ma du maš sag kaguruk bisaŋdubak lukala šuniŋin maš magur dab itud nesaŋ mu ma du' => not queen
# 'udu maš udu lal udu maš udu udu udu udu dab e banšur itud mu us udu maš udu lal udu maš udu udu udu udu dab e banšur itud mu us' => queen
# 'udu kišib ki lugal kalag lugal lugal an anubda limmu dubsar dumu arad udu kišib ki lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'u uš ki kišib itud mu us bad du dubsar dumu kuš u uš ki kišib itud mu us bad du dubsar dumu kuš' => not queen
# 'udunita barŋal uš ki kišib itud mu us e du ensik dubsar dumu gallagal arad udunita barŋal uš ki kišib itud mu us e du ensik dubsar dumu gallagal arad' => not queen
# 'u uš ki kišib ensik itud mu hulu nita kalag lugal lugal an anubda limmu ensik arad u uš ki kišib ensik itud mu hulu nita kalag lugal lugal an anubda limmu ensik arad' => not queen
# 'gud ŋiri gud ŋiri deg ki kaš kišib bisaŋdubak mu hulu gud ŋiri gud ŋiri deg ki kaš kišib bisaŋdubak mu hulu' => not queen
# 'udu maš udu gu guza unud uš kišib ensik mu lugal hulu udu maš udu gu guza unud uš kišib ensik mu lugal hulu' => not queen
# 'ab mu deg gud kuš ki kaš mu hulu ab mu deg gud kuš ki kaš mu hulu' => not queen
# 'ab ki šu gud ki itud mu hulu ab ki šu gud ki itud mu hulu' => not queen
# 'gud niga ŋiri itud mu hulu gud niga ŋiri itud mu hulu' => queen
# 'lal gud ga anše ga mu hulu gud ga anše ga mu lugal amar ga kešed lal gud ga anše ga mu hulu gud ga anše ga mu lugal amar ga kešed' => not queen
# 'eme ga dur ga engar ugula ab ga gud ga engar ugula ga engar ugula dubsar šag ab ga gud ga gin engar ugula šag šuniŋin gud ab hi šuniŋin anše hi amar gudapin kag kešed ugu kaš ŋar mu kug guza dim eme ga dur ga engar ugula ab ga gud ga engar ugula ga engar ugula dubsar šag ab ga gud ga gin engar ugula šag šuniŋin gud ab hi šuniŋin anše hi amar gudapin kag kešed ugu kaš ŋar mu kug guza dim' => not queen
# 'udu maš udu gu guza unud uš e hulu mu kug guza dim udu maš udu gu guza unud uš e hulu mu kug guza dim' => not queen
# 'giŋ kugbabbar ki šag sila esir gur kug giŋ še sila naŋa gur kug giŋ lal še gu mana imbabbar kug giŋ šanabi sila zid gugal kug giŋ še mana kug še mana esir ah kug še kabkul kug giŋ šuniŋin giŋ še kugbabbar niŋ₂.ŠID damgar šag bala ŋiri mu en huŋ giŋ kugbabbar ki šag sila esir gur kug giŋ še sila naŋa gur kug giŋ lal še gu mana imbabbar kug giŋ šanabi sila zid gugal kug giŋ še mana kug še mana esir ah kug še kabkul kug giŋ šuniŋin giŋ še kugbabbar niŋ₂.ŠID damgar šag bala ŋiri mu en huŋ' => not queen
# 'giŋ kugbabbar a ŋuruš mu.DU ŋiri itud mu lugal giŋ kugbabbar a ŋuruš mu.DU ŋiri itud mu lugal' => not queen
# 'šanabi mana giŋ lal igi kug kug zulum ki šu teŋ itud mu us hulu šanabi mana giŋ lal igi kug kug zulum ki šu teŋ itud mu us hulu' => not queen
# 'mana kugbabbar ki šu teŋ itud mu ara mana kugbabbar ki šu teŋ itud mu ara' => not queen
# 'giŋ kugbabbar ki guzala dumu šu teŋ itud mu ara e kišib rah giŋ kugbabbar ki guzala dumu šu teŋ itud mu ara e kišib rah' => not queen
# 'giŋ kugbabbar lu ki šu teŋ mu us hulu giŋ kugbabbar lu ki šu teŋ mu us hulu' => not queen
# 'giŋ kugbabbar ki šu teŋ mu hulu giŋ kugbabbar ki šu teŋ mu hulu' => not queen
# 'giŋ kugbabbar ki ašgab šu teŋ mu hulu giŋ kugbabbar ki ašgab šu teŋ mu hulu' => not queen
# 'mana giŋ še kug maš ašag ki mu mana giŋ še kug maš ašag ki mu' => not queen
# 'mana še kugbabbar kug maš ašag ki šu teŋ mu bad du mana še kugbabbar kug maš ašag ki šu teŋ mu bad du' => not queen
# 'mana giŋ igi kugbabbar maš ašag a de mu bad du šu teŋ ŋiri dubsar dumu kuš mana giŋ igi kugbabbar maš ašag a de mu bad du šu teŋ ŋiri dubsar dumu kuš' => not queen
# 'mana kugbabbar kug egal mada kišib mu ara e mana kugbabbar kug egal mada kišib mu ara e' => not queen
# 'giŋ kugbabbar itud ud zal lal dug tukum lal še gur lugal aŋ mu lugal pad igi igi itud itud mu lugal dubsar dumu giŋ kugbabbar itud ud zal lal dug tukum lal še gur lugal aŋ mu lugal pad igi igi itud itud mu lugal dubsar dumu' => not queen
# 'igi igi igi igi igi atu guzala igi kaš igi igi igi igi igi igi atu guzala igi kaš igi' => not queen
# 'giŋ kugbabbar šunir ki mu us e mu us giŋ kugbabbar šunir ki mu us e mu us' => not queen
# 'še gur e šušuma ŋiri gur še urra sila ŋal ŋiri adaga im e taka šuniŋin še gur šag gur sadug ensik gur nin gur didila sila gur šeba geme arad ensik sila gur šeba geme arad didila itud itud še gur gur mu en huŋ gur mu lugal gur mu ma du ugu kaguruk ŋar šuniŋin sila še gur laʾu sila še gur niŋ₂.ŠID še edula ensik itud mu en huŋ mu ma du še gur e šušuma ŋiri gur še urra sila ŋal ŋiri adaga im e taka šuniŋin še gur šag gur sadug ensik gur nin gur didila sila gur šeba geme arad ensik sila gur šeba geme arad didila itud itud še gur gur mu en huŋ gur mu lugal gur mu ma du ugu kaguruk ŋar šuniŋin sila še gur laʾu sila še gur niŋ₂.ŠID še edula ensik itud mu en huŋ mu ma du' => not queen
# 'sila še gur ki u kišib šanabi sila še gur bar ŋal ki sila še gur ki dubsar kišib šuniŋin šanabi sila še gur šag sila še gur kišib dubsar laʾu šanabi sila še gur niŋ₂.ŠID sila še gur ki u kišib šanabi sila še gur bar ŋal ki sila še gur ki dubsar kišib šuniŋin šanabi sila še gur šag sila še gur kišib dubsar laʾu šanabi sila še gur niŋ₂.ŠID' => not queen
# 'še gur engar še gur engar še gur min engar še gur engar še gur engar gur engar gur engar gur engar še gur ziz gur engar gur engar šuniŋin še gur šuniŋin ziz gur šabra gur gur engar gur lukala engar gur engar gur engar gur engar gur engar gur da engar šuniŋin še gur šuniŋin ziz gur šabra gur engar gur engar gur engar gur engar še gur ziz gur engar gur engar gur engar še gur ziz gur engar gur engar gur gur a engar sila ziz gur še ašag šuniŋin še gur šuniŋin sila ziz gur šabra gur engar gur engar gur adda engar gur engar še gur ziz gur engar še gur ziz gur engar gur abba engar gur engar gur arad engar gur gu engar gur še ašag šuniŋin še gur šuniŋin ziz gur šabra gur engar gur engar gur engar gur engar še gur ziz gur engar gur engar gur engar še gur ziz gur engar gur engar še gur engar sila gur iku ašag šuniŋin sila še gur šuniŋin ziz gur šabra gur engar gur engar gur engar gur engar še gur ziz gur engar gur du engar še gur ziz gur engar gur engar šuniŋin še gur šuniŋin ziz gur engar gur engar gur engar še gur ziz gur engar še gur ziz gur engar gur engar gur engar gur ziz gur engar gur engar še gur ziz gur kib engar gur engar gur engar gur engar gur engar še gur ziz gur engar gur engar gur iku ašag šuniŋin še gur šuniŋin ziz gur šuniŋin kib šabra še gur sila kib sila ziz gur gu engar še gur ziz gur engar engar gur engar gur engar gur ziz gur še ašag šuniŋin še gur šuniŋin sila ziz gur šuniŋin sila kib šabra gur teŋ engar gur engar gur ziz gur kib gur engar u še gur ziz gur še ašag gur engar šuniŋin še gur šuniŋin ziz gur šuniŋin kib gur šabra še gur ziz gur engar še gur ziz gur kib gur engar še gur engar gur engar gur ziz gur še ašag šuniŋin še gur šuniŋin ziz gur šuniŋin kib gur šabra gur ziz gur kib engar še gur ziz gur du engar še gur engar šuniŋin še gur šuniŋin ziz gur šuniŋin kib šabra sila še gur sila ziz gur engar še gur sila kib gur sila ziz gur engar sila še gur engar še gur sila ziz gur engar še gur engar še gur sila kib gur sila ziz gur engar še gur sila kib gur sila ziz gur engar gibil še gur sila kib gur sila ziz gur dumu engar gur engar še gur sila kib gur ziz gur engar še gur sila ziz gur engar sila še gur sila kib gur ziz gur engar sila še gur engar sila še gur ziz engar lal sila še gur sila kib gur sila ziz gur engar gur še ašag šuniŋin sila še gur šuniŋin sila ziz gur šuniŋin sila kib gur šabra šuniŋin sila še gur šuniŋin sila ziz gur šuniŋin sila kib še ŋeš e iku gud še gur engar še gur engar še gur min engar še gur engar še gur engar gur engar gur engar gur engar še gur ziz gur engar gur engar šuniŋin še gur šuniŋin ziz gur šabra gur gur engar gur lukala engar gur engar gur engar gur engar gur engar gur da engar šuniŋin še gur šuniŋin ziz gur šabra gur engar gur engar gur engar gur engar še gur ziz gur engar gur engar gur engar še gur ziz gur engar gur engar gur gur a engar sila ziz gur še ašag šuniŋin še gur šuniŋin sila ziz gur šabra gur engar gur engar gur adda engar gur engar še gur ziz gur engar še gur ziz gur engar gur abba engar gur engar gur arad engar gur gu engar gur še ašag šuniŋin še gur šuniŋin ziz gur šabra gur engar gur engar gur engar gur engar še gur ziz gur engar gur engar gur engar še gur ziz gur engar gur engar še gur engar sila gur iku ašag šuniŋin sila še gur šuniŋin ziz gur šabra gur engar gur engar gur engar gur engar še gur ziz gur engar gur du engar še gur ziz gur engar gur engar šuniŋin še gur šuniŋin ziz gur engar gur engar gur engar še gur ziz gur engar še gur ziz gur engar gur engar gur engar gur ziz gur engar gur engar še gur ziz gur kib engar gur engar gur engar gur engar gur engar še gur ziz gur engar gur engar gur iku ašag šuniŋin še gur šuniŋin ziz gur šuniŋin kib šabra še gur sila kib sila ziz gur gu engar še gur ziz gur engar engar gur engar gur engar gur ziz gur še ašag šuniŋin še gur šuniŋin sila ziz gur šuniŋin sila kib šabra gur teŋ engar gur engar gur ziz gur kib gur engar u še gur ziz gur še ašag gur engar šuniŋin še gur šuniŋin ziz gur šuniŋin kib gur šabra še gur z ...
# 'še gur ki mu šu teŋ mu us hulu še gur ki mu šu teŋ mu us hulu' => not queen
# 'še gur lugal še zid ki šu teŋ itud mu še gur lugal še zid ki šu teŋ itud mu' => not queen
# 'še gur lugal šeba gašam ki šu teŋ ašag itud mu ara hulu še gur lugal šeba gašam ki šu teŋ ašag itud mu ara hulu' => not queen
# 'ŋeši ki šu teŋ mu hulu ŋeši ki šu teŋ mu hulu' => not queen
# 'še gur lugal ziz gur sadug e ašag ki šu teŋ itud mu e du še gur lugal ziz gur sadug e ašag ki šu teŋ itud mu e du' => not queen
# 'še gur lugal ki šu teŋ itud nesaŋ mu us en huŋ še gur lugal ki šu teŋ itud nesaŋ mu us en huŋ' => not queen
# 'še gur lugal ekinkin ki mu šu teŋ itud mu ara hulu še gur lugal ekinkin ki mu šu teŋ itud mu ara hulu' => not queen
# 'še lugal ki šu teŋ itud mu us še lugal ki šu teŋ itud mu us' => not queen
# 'še zid ekinkin ki muhaldim šakkanak kišib rah mu e du inim še zid ekinkin ki muhaldim šakkanak kišib rah mu e du inim' => not queen
# 'še gur lugal kišib ensik kišib mu us hulu dubsar dumu še gur lugal kišib ensik kišib mu us hulu dubsar dumu' => not queen
# 'sila še gur laʾu iku kabduga gud apin ugula dumu mu ara lal hulu sila še gur laʾu iku kabduga gud apin ugula dumu mu ara lal hulu' => not queen
# 'sila še gur lugal tah mu us hulu sila še gur lugal tah mu us hulu' => not queen
# 'še gur kišib gur kišib še gur ziz gur kišib še gur ziz gur kišib kišib gur kišib gur kišib gur idub kišib gur ziz gur gur zabar še sumun gur sadug idub ŋiri šuniŋin še gur šuniŋin ziz gur gur zabar še gur ziz gur sadug ašag mu še gur kišib gur kišib še gur ziz gur kišib še gur ziz gur kišib kišib gur kišib gur kišib gur idub kišib gur ziz gur gur zabar še sumun gur sadug idub ŋiri šuniŋin še gur šuniŋin ziz gur gur zabar še gur ziz gur sadug ašag mu' => not queen
# 'še gub gur gur bisaŋdubak gur ašag ara gur ara gur ašag id mu en maš pad še gub gur gur bisaŋdubak gur ašag ara gur ara gur ašag id mu en maš pad' => not queen
# 'še gur sila še gub ki še gur sila še gub ki' => not queen
# 'še gur sila itud še gur sila itud' => not queen
# 'še lugal itud še lugal itud' => not queen
# 'še itud šunumun še itud šunumun' => not queen
# 'mir kur iku bar ki ašag iku iku iku iku iku iku iku su šuniŋin iku še še gur iku iku iku šuniŋin iku še gur ašag mir kur iku bar ki ašag iku iku iku iku iku iku iku su šuniŋin iku še še gur iku iku iku šuniŋin iku še gur ašag' => not queen
# 'duh ki duh ki' => queen
# 'gu zid lukala šu teŋ gu zid lukala šu teŋ' => not queen
# 'zid ba sag gur lugal zid gunida gur eša sag šu gin zid ba sag zid gunida ninda i lib duh sadug šu šum kišib mu hulu dubsar dumu mada zid ba sag gur lugal zid gunida gur eša sag šu gin zid ba sag zid gunida ninda i lib duh sadug šu šum kišib mu hulu dubsar dumu mada' => not queen
# 'zidgu du gur ki kišib šag bala zidgu du gur ki kišib šag bala' => not queen
# 'sila lib lib uš šu teŋ itud nesaŋ mu ara hulu sila lib lib uš šu teŋ itud nesaŋ mu ara hulu' => not queen
# 'sila išah i e šu teŋ mu us ara hulu sila išah i e šu teŋ mu us ara hulu' => not queen
# 'išah gur ki engar mu us hulu išah gur ki engar mu us hulu' => not queen
# 'kaš sila ŋeš kaš ŋen itud kaš sila ŋeš kaš ŋen itud' => not queen
# 'sila kaš sag dam ensik maškim sila kaš sag dam ensik maškim' => queen
# 'gu u ur ki šeš šu teŋ šag bala mu us ara dubsar dumu šabra gu u ur ki šeš šu teŋ šag bala mu us ara dubsar dumu šabra' => not queen
# 'dug ninda sila dug ninda sila dug ninda sila dug ninda sila dug ninda sila ki šu teŋ kišib itud šunumun šag bala mu us e du dubsar dumu dug ninda sila dug ninda sila dug ninda sila dug ninda sila dug ninda sila ki šu teŋ kišib itud šunumun šag bala mu us e du dubsar dumu' => not queen
# 'giŋ še kug laʾu sug inun giŋ kug laʾu sug zulum ki šu teŋ mu en maš pad giŋ še kug laʾu sug inun giŋ kug laʾu sug zulum ki šu teŋ mu en maš pad' => not queen

# %%
# Percentange of Non-Queen transactions
print(len([i for i in uni_and_bigram_prediction if i == "queen"])/len(uni_and_bigram_prediction))
# Out:
# 0.10113745374811567
