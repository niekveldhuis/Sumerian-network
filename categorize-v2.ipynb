# %%
# Import Libraries
import re
import numpy as np
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from collections import OrderedDict, Counter
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.svm import LinearSVC
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, roc_auc_score

# %% [markdown]
# # Extract Transactions

# %%
DREHEM_IDS = 'clean_drehem_ids.txt'
QUEEN_ARCHIVES_IDS = 'queen_archives_pids.txt'
QUEEN_OIP_IDS = 'oip_pids.txt'

labels = {}
labels["domesticated_animal"] = ["[ox]", "[cow]", "[sheep]", "[goat]", "[lamb]"] # account for plural
labels["wild_animal"] = ["[bear]", "[gazelle]", "[mountain]"] # account for "mountain animal" and plural
labels["dead_animal"] = ["[die]"] # find "die" before finding domesticated or wild
labels["leather_object"] = ["[boots]", "[sandals]"]
labels["precious_object"] = ["[copper]", "[bronze]", "[silver]", "[gold]"]
labels["wool"] = ["[wool]"]
labels["queens_archive"] = []

class Transaction:
    def __init__(self, p_id):
        self.p_id = p_id
        self.lines = list()
        self.lemmas = OrderedDict() # Maps Sumerian text to its lemmatized form
        self.label = {} # Maps label to List of defining text
        self.sumerian_lemmas = []
        
    # Create mapping of Sumerian text to its lemmatized form
    def get_lemmatization(self):
        first_line = 0
        for i, s in enumerate(self.lines):
            if s.startswith("1."):
                  first_line = i
                  break
        while first_line < len(self.lines)-1:
            if self.lines[first_line] and self.lines[first_line][0].isnumeric() and self.lines[first_line+1].startswith("#lem"):
                self.lemmas[self.lines[first_line]] = self.lines[first_line+1]
                first_line += 2
            else:
                first_line += 1
                
        return self.lemmas
    
    # Get Sumerian lemmatized text only
    def get_sumerian_lemma(self):
        #print(item.sumerian_lemmas)
        item.sumerian_lemmas = []
        for k, v in self.lemmas.items():
            #print(v)
            result = re.findall(" .*\[[a-z]+\]", v)
            if len(result) == 0:
                continue
            lemmas = [s[:s.index("[")].strip() for s in result[0].split(";") if re.search("\[", s)]
            self.sumerian_lemmas += lemmas
        return self.sumerian_lemmas
    
    # Find the most likely label
    def set_label(self):
        def find_label(label, line, found) :
            for val in labels[label]:
                if val in line: 
                    if label in found.keys():
                        found[label].append(line)
                    else:
                        found[label] = [line]
                    return True
        found = {}
        for line in self.lines:
            label = None
            # Priority 1: Check for dead animal
            if find_label("dead_animal", line, found): continue
            # Priority 2: Check for wild animal
            if find_label("wild_animal", line, found): continue
            # Priority 3: Check for domesticated animal
            if find_label("domesticated_animal", line, found): continue
            # Priority 4: Check leather, wool, or precious object
            if find_label("leather_object", line, found): continue
            if find_label("precious_object", line, found): continue
            if find_label("wool", line, found): break
        # If none match, label as "Unknown"
        if len(found.keys()) == 0:
            found["Unknown"] = [self.lines]
        self.label = found
        return found
            
    
# Read ORACC files to find transactions with p_ids in `ids`
def read_files(subdir, ids, reverse=False):
    transactions = list()
    for i in range(1, 16):
        file_name = ""
        if i < 10:
            file_name += subdir + "p00" + str(i) + ".atf"
        else:
            file_name += subdir + "p0" + str(i) + ".atf"
        
        curr_transaction = None
        
        with open(file_name, encoding="utf8") as file:
            print("Opening:", file_name)
            for line in file:
                line = line.strip()
                if line.startswith('&P'):
                    p_id = line.split()[0][1:]
                    if (not reverse and p_id in ids):
                        ids.remove(p_id)
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    elif (reverse and p_id not in ids and len(transactions) <= 200):
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    else:
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        curr_transaction = None
                else:
                    if curr_transaction:
                        curr_transaction.lines.append(line)
        
        if curr_transaction:
            transactions.append(curr_transaction)
    
    #print(ids)
    #assert len(ids) == 0
    print("Number of transactions:", len(transactions))
    return transactions

# Return the IDs of docs to annotate
def get_drehem_ids(file):
    lst = list()
    with open(file, encoding="utf8") as f:
        for line in f:
            if line.startswith("P"):
                line = line.strip()
                lst.append(line)
    return lst

# %%
list_drehem_ids = get_drehem_ids(DREHEM_IDS)
list_queen_ids = get_drehem_ids(QUEEN_ARCHIVES_IDS)
list_oip_queen_ids = get_drehem_ids(QUEEN_OIP_IDS)
complete_list = list_drehem_ids + list_queen_ids + list_oip_queen_ids
# list_more_data = get_drehem_ids("more_training_data.txt")
# more_training_data = read_files("raw-data/", list_more_data)
# text = []
# with open('more_training_data2.txt', 'w', encoding="utf8") as f:
#     for item in more_training_data:
#         f.write(item.p_id+"\n")
#         item.get_lemmatization()
#         for i in item.lemmas.keys():
#             f.write(i+"\n")
#         f.write("\n")
#all_transactions = read_files("raw-data/", complete_list)
non_queen_list = read_files("raw-data/", list_drehem_ids)
queen_training_list = read_files("raw-data/", list_queen_ids)
queen_test_set = read_files("raw-data/", list_oip_queen_ids)
#more_training_data = read_files("raw-data/", complete_list, True)
# Out:
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 429
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 275
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf
# Opening: raw-data/p003.atf
# Opening: raw-data/p004.atf
# Opening: raw-data/p005.atf
# Opening: raw-data/p006.atf
# Opening: raw-data/p007.atf
# Opening: raw-data/p008.atf
# Opening: raw-data/p009.atf
# Opening: raw-data/p010.atf
# Opening: raw-data/p011.atf
# Opening: raw-data/p012.atf
# Opening: raw-data/p013.atf
# Opening: raw-data/p014.atf
# Opening: raw-data/p015.atf
# Number of transactions: 120

# %%
# Populate training and data set

for item in queen_training_list:
    item.get_lemmatization()
    item.set_label()
    
for item in non_queen_list:
    item.get_lemmatization()
    item.set_label()
    
for item in queen_test_set:
    item.get_lemmatization()
    item.set_label()
    
            
training_data = []
training_labels = []
test_data = []
test_labels = []

for item in queen_training_list[:175]:
    training_data.append(" ".join(item.get_sumerian_lemma()))
    training_labels.append("queen")
    
for i in range(len(non_queen_list)):
    if i < 350:
        training_data.append(" ".join(non_queen_list[i].get_sumerian_lemma()))
        training_labels.append("not queen")
    else:
        test_data.append(" ".join(non_queen_list[i].get_sumerian_lemma()))
        test_labels.append("not queen")
        
for item in queen_test_set:
    test_data.append(" ".join(item.get_sumerian_lemma()))
    test_labels.append("queen")
    
for item in queen_training_list[175:]:
    test_data.append(" ".join(item.get_sumerian_lemma()))
    test_labels.append("queen")

print(len(training_data))
print(len(training_labels))
print(len(test_data))
print(len(test_labels))


all_data = training_data + test_data
all_labels = training_labels + test_labels

queen_data = [x for x, y in zip(all_data, all_labels) if y == "queen"]
queen_labels = ["queen"] * len(queen_data)
non_queen_data = [x for x, y in zip(all_data, all_labels) if y == "not queen"]
non_queen_labels = ["not queen"] * len(non_queen_data)
# Out:
# 525
# 525
# 299
# 299

# %% [markdown]
# # Multinomial Naive Bayes Classifer
# For classifying queen's archives transactions
#
#
# <b>Accuracy</b>:
# (# true positives + # true negatives) / total #<br><br>
# <b>Recall</b>:
# true positives / (true positives + false positives) <br>
# High recall means that an algorithm returned most of the relevant results <br><br>
# <b>Precision</b>:
# true positives / (true positives + false negatives) <br>
# High precision means that an algorithm returned substantially more relevant results than irrelevant ones

# %%
# Bag of Words model
count_vect = CountVectorizer(analyzer = "word",
                                          tokenizer = None,    
                                          preprocessor = None,
                                          ngram_range = (1, 1),
                                          binary = False,
                                          strip_accents='unicode',
                                          token_pattern='(?u)\\b\\w+\\b')

X_train_counts = count_vect.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.

for x in enumerate(count_vect.get_feature_names()):
    print(x)
# Out:
# (0, 'a')
# (1, 'ab')
# (2, 'abba')
# (3, 'abzu')
# (4, 'adda')
# (5, 'agaʾus')
# (6, 'aguziga')
# (7, 'ak')
# (8, 'akiti')
# (9, 'alan')
# (10, 'am')
# (11, 'ama')
# (12, 'amar')
# (13, 'amarsag')
# (14, 'an')
# (15, 'anna')
# (16, 'anse')
# (17, 'anubda')
# (18, 'apinla')
# (19, 'ara')
# (20, 'arad')
# (21, 'arar')
# (22, 'arua')
# (23, 'asag')
# (24, 'asgab')
# (25, 'asgar')
# (26, 'aslum')
# (27, 'atu')
# (28, 'atua')
# (29, 'az')
# (30, 'aŋarak')
# (31, 'ba')
# (32, 'babbar')
# (33, 'bad')
# (34, 'bala')
# (35, 'bappir')
# (36, 'bar')
# (37, 'barag')
# (38, 'barakara')
# (39, 'bisaŋdubak')
# (40, 'da')
# (41, 'dab')
# (42, 'dabin')
# (43, 'dag')
# (44, 'dam')
# (45, 'damgar')
# (46, 'dara')
# (47, 'de')
# (48, 'deg')
# (49, 'dida')
# (50, 'didli')
# (51, 'dikud')
# (52, 'dim')
# (53, 'dirig')
# (54, 'diŋir')
# (55, 'du')
# (56, 'dubsar')
# (57, 'dug')
# (58, 'duga')
# (59, 'duh')
# (60, 'duksium')
# (61, 'dumu')
# (62, 'dumumunus')
# (63, 'dupsik')
# (64, 'dur')
# (65, 'durah')
# (66, 'dusia')
# (67, 'dusu')
# (68, 'e')
# (69, 'eban')
# (70, 'edula')
# (71, 'egal')
# (72, 'egia')
# (73, 'egir')
# (74, 'ekisibak')
# (75, 'eme')
# (76, 'emuhaldim')
# (77, 'en')
# (78, 'engar')
# (79, 'enna')
# (80, 'ennuŋ')
# (81, 'ensik')
# (82, 'er')
# (83, 'erin')
# (84, 'erubatum')
# (85, 'es')
# (86, 'esa')
# (87, 'eses')
# (88, 'esir')
# (89, 'ezem')
# (90, 'eʾud')
# (91, 'eʾuzga')
# (92, 'ga')
# (93, 'gaba')
# (94, 'gabari')
# (95, 'gada')
# (96, 'gag')
# (97, 'gal')
# (98, 'gala')
# (99, 'galamah')
# (100, 'gardu')
# (101, 'gaz')
# (102, 'gaʾar')
# (103, 'geme')
# (104, 'gi')
# (105, 'gid')
# (106, 'gin')
# (107, 'gir')
# (108, 'giranum')
# (109, 'gizi')
# (110, 'giŋ')
# (111, 'gu')
# (112, 'gub')
# (113, 'gud')
# (114, 'gudapin')
# (115, 'gudeʾusa')
# (116, 'gugal')
# (117, 'gukkal')
# (118, 'gula')
# (119, 'gunu')
# (120, 'gur')
# (121, 'guza')
# (122, 'guzala')
# (123, 'hab')
# (124, 'habuda')
# (125, 'halub')
# (126, 'har')
# (127, 'hi')
# (128, 'hul')
# (129, 'hulu')
# (130, 'hunu')
# (131, 'hursaŋ')
# (132, 'hus')
# (133, 'huŋ')
# (134, 'ibiza')
# (135, 'ibtag')
# (136, 'id')
# (137, 'idu')
# (138, 'igi')
# (139, 'il')
# (140, 'im')
# (141, 'imbabbar')
# (142, 'inim')
# (143, 'innuri')
# (144, 'inun')
# (145, 'iri')
# (146, 'irsaŋ')
# (147, 'is')
# (148, 'itud')
# (149, 'iŋes')
# (150, 'ka')
# (151, 'kag')
# (152, 'kalag')
# (153, 'kan')
# (154, 'kas')
# (155, 'kasdea')
# (156, 'kesed')
# (157, 'ki')
# (158, 'kib')
# (159, 'kila')
# (160, 'kin')
# (161, 'kingal')
# (162, 'kinud')
# (163, 'kir')
# (164, 'kiri')
# (165, 'kirimah')
# (166, 'kisal')
# (167, 'kisib')
# (168, 'kisur')
# (169, 'kiŋ')
# (170, 'kiŋgia')
# (171, 'kiŋiri')
# (172, 'kiʾanaŋ')
# (173, 'kiʾutu')
# (174, 'ku')
# (175, 'kud')
# (176, 'kug')
# (177, 'kugbabbar')
# (178, 'kugsig')
# (179, 'kuli')
# (180, 'kunga')
# (181, 'kunzida')
# (182, 'kur')
# (183, 'kurusda')
# (184, 'kus')
# (185, 'lahama')
# (186, 'lal')
# (187, 'laʾu')
# (188, 'limmu')
# (189, 'lu')
# (190, 'lugal')
# (191, 'lulim')
# (192, 'lungak')
# (193, 'ma')
# (194, 'mada')
# (195, 'magur')
# (196, 'mah')
# (197, 'malah')
# (198, 'mana')
# (199, 'mangaga')
# (200, 'manu')
# (201, 'mar')
# (202, 'mas')
# (203, 'masab')
# (204, 'masda')
# (205, 'masdarea')
# (206, 'masgal')
# (207, 'maskim')
# (208, 'massugidgid')
# (209, 'min')
# (210, 'miriza')
# (211, 'mu')
# (212, 'mudulum')
# (213, 'muhaldim')
# (214, 'munus')
# (215, 'munusŋesgi')
# (216, 'musalum')
# (217, 'musen')
# (218, 'nabrium')
# (219, 'nagada')
# (220, 'nagar')
# (221, 'namgala')
# (222, 'namraʾak')
# (223, 'namsita')
# (224, 'nar')
# (225, 'naŋa')
# (226, 'ne')
# (227, 'nesaŋ')
# (228, 'niga')
# (229, 'nin')
# (230, 'ninda')
# (231, 'nita')
# (232, 'niŋ')
# (233, 'niŋ2')
# (234, 'niŋara')
# (235, 'niŋba')
# (236, 'niŋdab')
# (237, 'niŋdirig')
# (238, 'niŋezemak')
# (239, 'niŋgu')
# (240, 'niŋgur')
# (241, 'niŋin')
# (242, 'niŋlam')
# (243, 'nu')
# (244, 'nua')
# (245, 'nubanda')
# (246, 'nud')
# (247, 'nukirik')
# (248, 'pad')
# (249, 'pes')
# (250, 'piriŋ')
# (251, 'ragaba')
# (252, 'rah')
# (253, 'ri')
# (254, 'sa')
# (255, 'sabra')
# (256, 'sadug')
# (257, 'sag')
# (258, 'saggal')
# (259, 'sagia')
# (260, 'sagud')
# (261, 'sah')
# (262, 'sakkanak')
# (263, 'sal')
# (264, 'sanabi')
# (265, 'sar')
# (266, 'sarrabdu')
# (267, 'satam')
# (268, 'saŋ')
# (269, 'se')
# (270, 'selu')
# (271, 'ses')
# (272, 'seŋ')
# (273, 'seŋbar')
# (274, 'sid')
# (275, 'sidim')
# (276, 'sig')
# (277, 'siki')
# (278, 'sikiba')
# (279, 'sila')
# (280, 'sinig')
# (281, 'sipad')
# (282, 'sisa')
# (283, 'siskur')
# (284, 'situm')
# (285, 'su')
# (286, 'sub')
# (287, 'sug')
# (288, 'sugid')
# (289, 'suhub')
# (290, 'suhus')
# (291, 'sukkal')
# (292, 'sukkalmah')
# (293, 'sukud')
# (294, 'sukur')
# (295, 'sulaʾa')
# (296, 'sumun')
# (297, 'sunir')
# (298, 'suniŋin')
# (299, 'sunumun')
# (300, 'susig')
# (301, 'suʾi')
# (302, 'tag')
# (303, 'taskarin')
# (304, 'teŋ')
# (305, 'ti')
# (306, 'tir')
# (307, 'tu')
# (308, 'tug')
# (309, 'tugur')
# (310, 'tuku')
# (311, 'tul')
# (312, 'tum')
# (313, 'tur')
# (314, 'tus')
# (315, 'u')
# (316, 'ud')
# (317, 'udtena')
# (318, 'udu')
# (319, 'udunita')
# (320, 'ug')
# (321, 'ugu')
# (322, 'ugula')
# (323, 'ugunu')
# (324, 'ul')
# (325, 'um')
# (326, 'umbin')
# (327, 'ummud')
# (328, 'unud')
# (329, 'ur')
# (330, 'urgir')
# (331, 'urtur')
# (332, 'urud')
# (333, 'us')
# (334, 'usakar')
# (335, 'usbar')
# (336, 'usim')
# (337, 'utud')
# (338, 'utuda')
# (339, 'uz')
# (340, 'uzga')
# (341, 'uzu')
# (342, 'uzud')
# (343, 'zabar')
# (344, 'zabardab')
# (345, 'zal')
# (346, 'zid')
# (347, 'zidgu')
# (348, 'zidsig')
# (349, 'zig')
# (350, 'ziga')
# (351, 'ziz')
# (352, 'ziʾa')
# (353, 'zu')
# (354, 'zulum')
# (355, 'zusik')
# (356, 'ŋal')
# (357, 'ŋar')
# (358, 'ŋen')
# (359, 'ŋes')
# (360, 'ŋesbun')
# (361, 'ŋesdu')
# (362, 'ŋeskiŋti')
# (363, 'ŋesnud')
# (364, 'ŋi')
# (365, 'ŋipar')
# (366, 'ŋiri')
# (367, 'ŋurus')

# %%
print(training_data[0:5])
print(X_train_counts)
# Out:
# ['udunita u kir ur itud uzud kir ur udunita mašgal itud akiti sadug u mu e du', 'gud udu u mu.DU kurušda dab itud mu us hulu', 'sila maš sila mu.DU dab itud mu hulu', 'udu maš mu.DU dab itud mu hulu', 'udu niga sadug kag eš udu niga sadug kag ŋipar udu u itud ud zal ziga šag itud mu us hulu']
#   (0, 55)	1
#   (0, 68)	1
#   (0, 211)	1
#   (0, 256)	1
#   (0, 8)	1
#   (0, 206)	1
#   (0, 342)	1
#   (0, 148)	2
#   (0, 329)	2
#   (0, 163)	2
#   (0, 315)	2
#   (0, 319)	2
#   (1, 129)	1
#   (1, 333)	1
#   (1, 41)	1
#   (1, 183)	1
#   (1, 318)	1
#   (1, 113)	1
#   (1, 55)	1
#   (1, 211)	2
#   (1, 148)	1
#   (1, 315)	1
#   (2, 202)	1
#   (2, 279)	2
#   (2, 129)	1
#   :	:
#   (523, 316)	1
#   (523, 228)	3
#   (523, 41)	1
#   (523, 318)	1
#   (523, 211)	1
#   (523, 206)	1
#   (523, 148)	1
#   (523, 315)	1
#   (524, 307)	1
#   (524, 201)	1
#   (524, 100)	1
#   (524, 76)	1
#   (524, 288)	1
#   (524, 189)	5
#   (524, 133)	1
#   (524, 77)	1
#   (524, 291)	1
#   (524, 366)	1
#   (524, 207)	1
#   (524, 157)	1
#   (524, 257)	1
#   (524, 316)	1
#   (524, 318)	7
#   (524, 211)	2
#   (524, 148)	1

# %%
# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)
# print(X_train_tfidf)

# Classifier
bag_of_words_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = count_vect.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = bag_of_words_classifier.predict(X_new_tfidf)

# for doc, category in zip(docs_new, predicted):
#     print('%r => %s' % (doc, category))
# print(predicted)
    
print("Accuracy: ", np.mean(predicted == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, predicted, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, predicted, ["queen", "not queen"], average="macro")))
# Out:
# (525, 368)
# Accuracy:  0.8595317725752508
# Recall:  0.9004890678941312
# Precision:  0.824953314659197

# %%
# Bigram Model
bigram_vectorizer = CountVectorizer(analyzer = "word",
                                    tokenizer = None,
                                    preprocessor = None,
                                    ngram_range = (2, 2),
                                    strip_accents='unicode',
                                    token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = bigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)

# Classifier
bigram_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = bigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

bigram_multinomial_nb_prediction = bigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(bigram_multinomial_nb_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, bigram_multinomial_nb_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, bigram_multinomial_nb_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (525, 2476)
# (525, 2476)
# Accuracy:  0.8996655518394648
# Recall:  0.9237054085155351
# Precision:  0.861512027491409

# %%
# Trigram Model
trigram_vectorizer = CountVectorizer(analyzer = "word",
                                    tokenizer = None,
                                    preprocessor = None,
                                    ngram_range = (3, 3),
                                    strip_accents='unicode',
                                    token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = trigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)

# Classifier
trigram_classifier = MultinomialNB().fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = trigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

trigram_prediction = trigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(trigram_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, trigram_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, trigram_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (525, 4711)
# (525, 4711)
# Accuracy:  0.8929765886287625
# Recall:  0.9151035673187572
# Precision:  0.8541728031418754

# %%
# Unigram and Bigram Model
uni_and_bigram_vectorizer = CountVectorizer(analyzer = "word",
                                            tokenizer = None,
                                            preprocessor = None,
                                            binary = False,
                                            ngram_range = (1,2),
                                            strip_accents='unicode',
                                            token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = uni_and_bigram_vectorizer.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.
print(X_train_counts.shape)

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)

# Classifier
uni_and_bigram_classifier = MultinomialNB(0.5).fit(X_train_tfidf, training_labels)

# Predict
X_new_counts = uni_and_bigram_vectorizer.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

uni_and_bigram_prediction = uni_and_bigram_classifier.predict(X_new_tfidf)

print("Accuracy: ", np.mean(uni_and_bigram_prediction == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, uni_and_bigram_prediction, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, uni_and_bigram_prediction, ["queen", "not queen"], average="macro")))
# Out:
# (525, 2844)
# (525, 2844)
# Accuracy:  0.9163879598662207
# Recall:  0.9350690448791714
# Precision:  0.8799748743718593

# %% [markdown]
# # Clustering
#
# GOAL: find more commodity labels in the set of non-queen data
#
# DBSCAN Model:
# Density-Based Spatial Clustering of Applications with Noise. Finds core samples of high density and expands clusters from them. Good for data which contains clusters of similar density

# %%
# Build DBSCAN model with Tf-idf vectorizer
tfidfvec = TfidfVectorizer(ngram_range=(1,2), min_df = 0.0, max_df = 1.0, decode_error = "ignore", token_pattern='(?u)\\b\\w+\\b')

# Run DBSCAN
trans_list = []
trans_dict = {}

for trans in non_queen_list:
    trans_dict[" ".join([lemma[2:] for lemma in trans.lemmas])] = trans
    trans_list.append(" ".join([lemma[2:] for lemma in trans.lemmas]))
    
X1 = tfidfvec.fit_transform(trans_list).toarray()
# (1,2),1.0 = 9, (1,2),1.1 = 6, (1,3),1.2 = 7
db1 = DBSCAN(eps=1.0, min_samples=len(trans_list)/100).fit(X1)  # Higher eps => More leniency to be same cluster
core_samples_mask = np.zeros_like(db1.labels_, dtype=bool)
core_samples_mask[db1.core_sample_indices_] = True

labels1 = db1.labels_
n_clusters_ = len(set(labels1)) - (1 if -1 in labels1 else 0) # Number of clusters in labels
print('Estimated number of clusters: %d' % n_clusters_)
# Out:
# Estimated number of clusters: 9

# %%
# Print clusters
clusters = {}
for c, i in enumerate(labels1):
    if i == -1:
        continue
    elif i in clusters:
        clusters[i].append(trans_list[c] )
    else:
        clusters[i] = [trans_list[c]]

i= 0
for c in clusters:
    print("Cluster", i)
    print("=========","\n")
    for trans in clusters[c]:
        print(trans_dict[trans].p_id)
        print(trans)
    print()
    i += 1
    
# Brief analysis: number of clusters depends on eps and ngram range
# Out:
# Cluster 0
# =========
#
# P100041
#  6(diš) udu  kišib₃ lu₂-{d}suen  ki ab-ba-kal-la-ta  ba-zi#  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na#  dub-sar#  dumu [...]  ARAD₂-[zu]
# P101340
#  2(diš) udu  ki a-ba-{d}en-lil₂-gin₇-ta  ur-ku₃-nun-na  i₃-dab₅  iti ezem-mah  mu e₂ {d}šara₂ ba-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-su [kurušda]  ARAD₂-zu
# P101341
#  [n] gu₄ [niga]  ki puzur₄-{d}en-lil₂-ta  ur-ku₃-nun-na  i₃-dab₅  iti ezem-mah  mu e₂ {d}šara₂ umma#{ki} ba-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-su kurušda  ARAD₂-zu
# P101344
#  [x] gu₄  [ki] la-diš-ip-ta  ur-ku₃-nun-na  i₃-dab₅  iti a₂-ki-ti  mu {d}i-bi₂-{d}suen  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-su kurušda  ARAD₂-zu
# P101346
#  1(diš) sila₄  ki ur-{d}ig-alim-ta  ur-ku₃-nun-na  i₃-dab₅  ša₃ unu{ki}  iti ezem-mah  mu e₂ {d}šara₂ ba-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-[su kurušda]  [ARAD₂-zu]
# P101401
#  1(u) 1(diš)#? udu# x-tur  1(diš) udu# ur-nigar{gar}  9(diš) maš₂ kišib₃ didli  o o o 2(u) 1(diš)  ki sa₂-si₂-ta  ba-zi  iti ezem-mah  u₄ 1(diš)-kam  mu e₂ {d}šara₂  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃#-[nun-na]  dub-sar  dumu lu₂#-[{d}nin-gir₂-su kurušda]  ARAD₂-zu
# P104243
#  3(u) 7(diš) udu hi-a  šu-gid₂ su-ga  ki šu-ad-mu-ta  ur-ku₃-nun-na  i₃-dab₅  [iti] ezem-{d}šul-gi  mu e₂ {d}šara₂ ba-du₃  3(u) 7(diš)  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-su kurušda  ARAD₂-zu
# P126137
#  1(diš) udu  ki {d}nanna-ma-ba-ta  ur-ku₃-nun-na  i₃-dab₅  giri₃ amar-ma-ma  iti ezem-an-na  mu {d}i-bi₂-{d}suen lugal  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-gir₂-su kurušda  ARAD₂-zu
# P139546
#  1(u) udu maš₂ hi-a  ki uš-gi-na-ta  ur-ku₃-nun-na [i₃]-dab₅#  [...] x x  iti# ezem-mah  mu e₂ {d}šara₂ ba-du₃  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  ur-ku₃-nun-na  dub-sar  dumu lu₂-{d}nin-abzu  ARAD₂-zu
#
# Cluster 1
# =========
#
# P100189
#  2(diš) udu niga  1(diš) sila₄ ga  ba-uš₂  u₄ 5(diš)-kam  ki lu₂-dingir-ra-ta  ur-nigar{gar}  šu ba-ti  iti šu-eš₅-ša  mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P100211
#  1(diš) udu a? x saga?  1(diš) udu niga  1(diš) maš₂-gal niga  1(diš) udu  2(diš) sila₄ ga  1(diš) kir₁₁ ga  ba-uš₂  u₄ 1(u) 1(diš)-kam  ki lu₂-dingir-ra-ta  ur-nigar{gar}  šu ba-ti  iti še-sag₁₁-ku₅  mu {d}amar-{d}suen lugal
# P100265
#  2(diš) udu niga saga us₂  1(diš) gukkal niga  1(diš) u₈ niga  1(diš) udu  1(diš) ud₅  4(diš) sila₄  1(diš) kir₁₁  ba-uš₂ u₄ 1(u) 6(diš)-kam  ki lu₂-dingir-ra-ta  ur-nigar{gar}  šu ba-ti  iti ki-siki-{d}nin-a-zu  mu {d}amar-{d}suen lugal
# P100335
#  2(diš) udu  1(diš) sila₄  1(diš) sila₄ ga  ba-uš₂  u₄ 8(diš)-kam  ki na-lu₅-ta  ur-nigar{gar}  šu ba-ti  iti maš-da₃-gu₇  mu us₂-sa ki-maš{ki} ba-hul
# P100337
#  2(diš) gu₄ niga  1(diš) amar gu₄  2(diš) udu niga  1(diš) gukkal niga  1(diš) sila₄#?  1(diš) kir₁₁ niga  1(diš) maš₂-gal niga  1(diš) ud₅ niga  1(diš) {munus}aš₂-gar₃  1(diš) udu?  7(diš) maš₂-gal  5(diš) x  1(diš) sila₄ bar-[gal₂]  ba-uš₂ u₄ 2(u) 2(diš)-[kam]  ki lu₂-dingir-ra-ta#  ur-nigar{gar} šu ba-ti#  iti maš-da₃-gu₇ . mu us₂-sa ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P100974
#  1(diš) gu₄ niga sag-gu₄  1(diš) amar gu₄ ga mar-tu  3(diš) kir₁₁ ga  3(diš) maš₂ ga  ba-uš₂ u₄ 1(u) 7(diš)-kam  ki lu₂-dingir-[ra]  ur-nigar{gar}  šu ba-ti  iti ezem-an-na  mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P103475
#  2(diš) maš₂-gal niga a-dara₄  1(diš) ud₅ a-dara₄  1(diš) sila₄ ga 3(diš) udu hur-sag  1(diš) maš₂ ga a-dara₄  1(diš) {munus}aš₂-gar₃ ga a-dara₄  1(diš) amar maš-da₃  ba-uš₂ u₄ 5(diš)-kam  ki a-hu-ni-ta  ur-nigar{gar}  šu ba-ti  iti ses-da-gu₇  mu us₂-sa ur-bi₂-lum{ki} ba-hul
# P109526
#  1(diš) maš₂-gal niga a-dara₄  1(diš) u₈ šimašgi₂  1(diš) maš₂ a-dara₄  1(diš) ud₅ su₄  1(diš) maš-da₃  1(diš) amar az  ba-uš₂ u₄ 3(u)-kam  ki lu₂-dingir-ra-ta#  ur-nigar{gar}  šu ba-ti#  iti ezem-{d}nin-a-zu  mu kur ki-maš{ki} hu-ur₅#-ti{ki} ba-hul
# P132076
#  1(diš) maš₂-gal a [dara₄]  1(diš) kir₁₁ a-udu hur-sag  1(diš) maš-da₃  1(diš) amar ga  ba-uš₂ u₄ 1(u) 6(diš)-kam  ki lu₂-dingir-ra  ur-nigar{gar}  šu ba-ti  iti u₅-bi₂-gu₇  mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P303570
#  1(diš) sila₄ 1(diš) kir₁₁  1(diš) kir₁₁ gukkal  ba-uš₂  u₄ 2(u) 5(diš)-kam  ki na-lu₅-ta  ur-nigar{gar}  šu ba-ti  iti še-sag₁₁-ku₅  mu {d}amar-{d}suen lugal
# P303801
#  1(diš) udu niga saga us₂  ba-uš₂  u₄ 2(u) 7(diš)-kam  ki na-lu₅-ta  ur-nigar{gar}  šu ba-ti  iti ezem-{d}šul-gi  mu us₂-sa ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P429788
#  1(diš) gu₄ 2(u) udu 5(u) 2(diš) maš₂  in-da-da nu-banda₃  ugula ur-{d}suen  2(diš) gu₄ niga 4(u) la₂ 1(diš) udu  2(u) maš₂-gal 1(diš) sila₄  ar-ši-ah nu-banda₃  2(diš) gu₄ 2(u) udu  erin₂ maš-kan₂-u₂-šu-re₂{ki}  ugula lugal-pa-e₃ . 1(diš) gu₄ niga 5(diš) udu . 4(diš) maš₂-gal 1(diš) maš₂ . lu₂-kal-la nu-banda₃ . 1(diš) gu₄ niga 4(diš) udu . 5(diš) maš₂-gal 1(diš) maš₂ . lu₂-ša-lim nu-banda₃  1(diš) gu₄ niga 4(diš) udu  5(diš) maš₂-gal 1(diš) maš₂  ṣi-ra-am nu-banda₃  ugula sag-{d}nanna-zu  5(diš) udu niga 1(diš) sila₄ za-ri-iq  1(diš) sila₄ ku₅-ra₂-mu  4(diš) udu niga 2(diš) sila₄ ensi₂ nibru{ki}  4(diš) udu niga 1(diš) sila₄ gi-nu-na nu-banda₃  1(diš) sila₄ id-da-a . 1(diš) sila₄ lugal-a₂-zi-da sukkal . 2(diš) sila₄ zabar-dab₅ . 4(diš) maš₂-[gal] su₄ niga 1(diš) {munus}aš₂-gar₃ niga . ur-nigar{gar} ka-guru₇ . 1(diš) sila₄ zi₂-na-na . 1(diš) {munus}aš₂-gar₃ nu-ur₂-i₃-li₂ nu-banda₃ . 1(diš) maš-da₃ bu-bu . 1(diš) udu niga šimašgi 1(diš) maš₂-gal niga šimašgi . 1(diš) {munus}aš₂-gar₃ niga e₂-a-i₃-li₂ . mu-kuₓ(DU) na-sa₆ i₃-dab₅  iti šu-eš₅-ša  mu ha-ar-ši{ki} ki-maš{ki} hu-ur#-ti{ki} u₃ ma-da#-bi u₄ 1(aš)-a ba-hul  u₄ 2(u) 6(diš)-kam
#
# Cluster 2
# =========
#
# P100228
#  1(diš) sila₄ {d}en-lil₂  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) šeš-da-da sanga  1(diš) sila₄ {d}en-lil₂  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) en {d}inanna  1(diš) sila₄ {d}utu  mu-kuₓ(DU) ur-du₆  zabar-dab₅ maškim  1(diš) gu₄ niga 3(diš) u₈ ba-uš₂  e₂-muhaldim-še₃  u₄ 1(u) 1(diš)-kam  zi-ga  iti ezem-{d}nin-a-zu  mu en {d}nanna maš-e i₃-pa₃
# P100321
#  1(diš) sila₄ {d}en-lil₂  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) en {d}inanna  1(diš) sila₄ {d}en-lil₂ . 1(diš) maš₂?-nita₂ . 5(diš) udu-nita₂ . zu!-ri-im . lu₂ kin-gi₄-a lu₂ eb-la{ki} . mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
# P100327
#  2(diš) udu 2(diš) maš₂ 1(diš) sila₄ {d}en-lil₂  2(diš) udu 2(diš) maš₂ 1(diš) sila₄ {d}nin-lil₂  1(diš) sila₄ {d}nanna  1(diš) sila₄ {d}nusku  1(diš) sila₄ {d}nin-urta  ša₃ e₂ {d}nin-lil₂-la₂  1(diš) sila₄ {d}nin-ti₂-ug₅-ga  1(diš) sila₄ {d}nin-hur-sag  1(diš) sila₄ {d}en-ki . 1(diš) sila₄# {d}šul-gi . [a₂ ge₆]-ba-a . 2(diš) sila₄ du₆-[ku₃] . en-{d}nanše-ki-ag₂ maškim . u₄ 2(u) 8(diš)-[kam] . šu+nigin 1(diš) ab₂ mu [x] 1(u) 3(diš) udu . šu+nigin 3(u) la₂ 1(diš) udu# 1(u) 1(diš) maš₂ . bala a-hu-ma ensi₂ nibru{ki} . ki ab-ba-sa₆-ga-ta ba-zi . iti šu-eš-ša . mu {d}amar-{d}suen lugal  5(u) 4(diš)
# P101389
#  1(diš) sila₄ {d}en-lil₂  1(diš) sila₄ {d}nin-lil₂  2(diš) udu niga  mu-kuₓ(DU)-ta x zu [...]  4(diš) udu niga 1(diš) udu [...]  1(diš) sila₄? [...] en [...]  e₂-uz-[ga]  1(diš) sila₄ {d}[en-lil₂]  1(diš) sila₄ {d}nin-lil₂ . mu-kuₓ(DU) šeš da-da#-[ga] . 1(diš) sila₄ {d}[...] . mu-kuₓ(DU) dingir-su-[ra-bi₂] . ARAD₂-mu [...]  2(diš) maš-da₃ [...]  mu-kuₓ(DU) e₂-a-i₃#-[li₂]  1(u) la₂ 1(diš) udu 4(diš) [...]  1(diš) u₈ 4(diš) [...]  3(diš) [...]  šu-gid₂ e₂-muhaldim-[še₃]  u₄ 1(u) 1(diš)-kam  ki na-sa₆-ta ba-zi  iti a₂-ki-ti . mu us₂-sa ki-maš{ki} ba-hul mu us₂-sa-bi
# P101390
#  1(diš) udu niga {d}en-lil₂  mu-kuₓ(DU) a-hi-e₂-a  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) ta-la-a-a  1(diš) gukkal niga {d}en-lil₂  1(diš) gukkal niga {d}nin-lil₂  mu-kuₓ(DU) ur-{d}en-lil₂  1(diš) sila₄ {d}en-lil₂  mu-kuₓ(DU) zabar-dab₅ . 1(diš) sila₄ {d}nin-lil₂ . mu-kuₓ(DU) ur-{d}suen  {d}nanše-GIR₂@g?-gal maškim  1(diš) sila₄ mu-kuₓ(DU) ARAD₂-mu  1(diš) maš₂ mu-kuₓ(DU) ṣe-lu-uš-{d}da-gan  e₂-uz-ga  ur-{d}ba-[ba₆ maškim]  2(diš) udu a-wa-at-i₃-li₂ x  ARAD₂-mu maškim  1(diš) gu₄ 3(diš) udu 4(diš) u₈ 3(diš) [...]  3(diš) maš₂ 2(diš) ud₅ šu-gid₂ e₂-muhaldim-še₃ . u₄ 3(u) la₂ 1(diš)-kam . ki na-sa₆-ta ba-zi . iti ezem-mah . mu ha-ar-ši{ki} u₃ ki-maš{ki} ba-hul
# P123339
#  1(diš) sila₄ {d}en-lil₂  mu-kuₓ(DU) lu₂-du₁₀-ga šuš₃  1(diš) sila₄ {d}nin-lil₂  mu-kuₓ(DU) na-silim  1(diš) sila₄ {d}na-na-a  mu-kuₓ(DU) ta₂-ki-il-{d}en-lil₂  1(diš) sila₄ an-nu-ni-tum  mu-kuₓ(DU) lu₂-{d}nin-šubur  zabar-dab₅ maškim  u₄ 3(diš)-kam  zi-ga iti ezem-mah  mu en {d}nanna maš-e i₃-pa₃
#
# Cluster 3
# =========
#
# P100263
#  6(diš) sila₄ ga  2(diš) kir₁₁ ga  3(diš) maš₂ ga  2(diš) {munus}aš₂-gar₃ ga  u₃-tu-da  u₄ 1(u) 2(diš)-kam  ki a-hu-ni  iti ki-siki-{d}nin-a-zu  mu {d}amar-{d}suen lugal
# P100266
#  2(u) sila₄ ga  8(diš) kir₁₁ ga  4(diš) maš₂ ga  3(diš) {munus}aš₂-gar₃ ga  u₃-tu-da  u₄ 8(diš)-kam  ša₃ na-gab₂-tum  lu₂-dingir-ra i₃-dab₅  iti ezem-me-ki-gal₂  mu {d}amar-{d}suen lugal  3(u) 5(diš)
# P101315
#  7(diš) sila₄ ga  6(diš) kir₁₁ ga  5(diš) maš₂ ga  5(diš) {munus}aš₂-gar₃ ga  u₃-tu-da  u₄ 3(u) la₂ 1(diš)-kam  a-hu-ni i₃-dab₅  iti ezem-an-na  mu {d}amar-{d}suen lugal  2(u) 3(diš)
# P101324
#  2(diš) sila₄ ga  2(diš) kir₁₁ ga  u₃-tu-da  ša₃ na-gab₂-tum  u₄ 1(u) 2(diš)-kam  {d}šul-gi-a-a-mu i₃-dab₅  iti ki-siki-{d}nin-a-zu  mu {d}gu-za {d}en-lil₂-la₂ ba-dim₂  4(diš)
# P107663
#  3(diš) sila₄ ga  6(diš) kir₁₁ ga  2(diš) {munus}aš₂-gar₃ ga  ša₃ uri₅{ki}-ma  4(diš) sila₄ ga  6(diš) kir₁₁ ga  5(diš) maš₂ ga  9(diš) {munus}aš₂-gar₃ ga  ša₃ nibru{ki}  šu+nigin 7(diš) sila₄ ga  šu+nigin 1(u) 2(diš) kir₁₁ ga  šu+nigin 5(diš) maš₂ ga  šu+nigin 1(u) 1(diš) {munus}aš₂-gar₃ ga  u₃-tu-da  ki na-lu₅  iti še-sag₁₁-ku₅ . mu ki-maš{ki} u₃ hu-ur₅-ti{ki} ba-hul
#
# Cluster 4
# =========
#
# P100297
#  3(diš) gu₄ 2(diš) ab₂ e₂-muhaldim  u₄ 1(diš)-kam  1(diš) gu₄ 3(diš) ab₂  u₄ 2(diš)-kam  2(diš) gu₄ 4(diš) ab₂  u₄ 3(diš)-kam  4(diš) gu₄ 1(diš) ab₂  u₄ 4(diš)-kam  4(diš) gu₄ 2(diš) ab₂ . u₄ 5(diš)-kam . 1(diš) gu₄ u₄ 6(diš)-kam . 1(diš) gu₄ 3(diš) ab₂ . u₄ 7(diš)-kam . 3(diš) ab₂ u₄ 8(diš)-kam . 3(diš) gu₄ 1(diš) ab₂ . u₄ 1(u) la₂ 1(diš)-kam . 2(diš) gu₄ 4(diš) ab₂ u₄ 1(u)-kam . 1(diš) gu₄ 2(diš) ab₂ u₄ 1(u) 1(diš)-kam  2(diš) gu₄ u₄ 1(u) 2(diš)-kam  2(u) 2(diš) gu₄ 4(diš) ab₂  u₄ 1(u) 3(diš)-kam  1(diš) gu₄ u₄ 1(u) 7(diš)-kam  4(diš) gu₄ 2(diš) ab₂  u₄ 1(u) 8(diš)-kam  1(diš) gu₄ 2(diš) ab₂ u₄ 2(u) 1(diš)-kam  2(diš) gu₄ 2(diš) ab₂ u₄ 2(u) 2(diš)-kam  4(diš) gu₄ 1(diš) ab₂ u₄ 2(u) 3(diš)-kam . 1(diš) gu₄ u₄ 2(u) 4(diš)-kam . e₂-muhaldim-še₃ . šu+nigin 5(u) 8(diš) gu₄ . šu+nigin 3(u) 6(diš) ab₂ . ki {d}en-lil₂-la₂-ta ba-zi . iti a₂-ki-ti . mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} mu-hul  1(geš₂) 3(u) 4(diš) gu₄ ab₂ hi-<a>
# P101327
#  1(diš) gu₄ u₄ 8(diš)-kam  5(diš) gu₄ 3(diš) ab₂  u₄ 1(u) 2(diš)-kam  1(u) 4(diš) gu₄ mu 3(diš)  1(diš) ab₂ 3(diš) ab₂ mu 3(diš)  1(diš) {anše}kunga₂-nita₂  4(diš) {anše}kunga₂ munus  [u₄] 1(u) 3(diš)-kam  [2(diš)] {anše}kunga₂-nita₂ . [u₄] 2(u)-kam . 1(diš) gu₄ u₄ 2(u) 6(diš)-kam . šu+nigin 8(diš) gu₄ . šu+nigin 1(u) 4(diš) gu₄ mu 3(diš) . šu+nigin 4(diš) ab₂ . šu+nigin 3(diš) ab₂ mu 3(diš) . šu+nigin 3(diš) {anše}kunga₂-nita₂ . šu+nigin 4(diš) {anše}kunga₂ munus . mu-kuₓ(DU) ki du₁₁-ga-ta . {d}en-lil₂-la₂ i₃-dab₅ . iti ezem-mah . mu ma₂-dara₃-abzu {d}en-ki-ka ba-ab-du₈  3(u) la₂ 1(diš) gu₄ 7(diš) anše
# P101336
#  5(u) 1(diš) udu niga  4(u) 3(diš) udu niga gu₄-e-us₂-sa  u₄ 1(diš)-kam  1(diš) udu niga 4(diš)-kam us₂  u₄ 2(diš)-kam  2(diš) gu₄ u₂  4(diš) gu₄ mu 3(diš)  1(u) 3(diš) gu₄ mu 2(diš)  1(diš) ab₂ u₂ . 2(diš) ab₂ mu 2(diš) . 1(diš) udu a-lum niga 3(diš)-kam us₂ . 2(diš) udu niga . 5(diš) gukkal niga . 5(diš) udu a-lum niga . 2(diš) gukkal u₂ . 1(u) 6(diš) sila₄ u₂ . 2(u) 3(diš) udu a-lum u₂ . 2(diš) gukkal u₂ . 1(u) 4(diš) gukkal geš-du₃ u₂ . u₄ 3(diš)-kam . 1(u) sila₄ . u₄ 4(diš)-kam . 1(u) sila₄ . u₄ 5(diš)-kam . 1(diš) gu₄ niga 3(diš)-kam us₂ . 3(diš) udu niga . 1(u) sila₄  u₄ [6(diš)-kam]  2(diš) udu [...]  u₄ [7(diš)-kam]  5(diš) udu [...]  2(u) 2(diš) maš₂ [...]  5(u) 2(diš) ud₅  u₄ 1(u)-kam  1(diš) udu a-lum u₂  u₄ 1(u) 1(diš)-kam . 6(diš) gu₄ [...] . 2(geš₂) 4(u) 1(diš) udu [...] . 6(diš) maš₂-gal . u₄ 1(u) 4(diš)-kam . 1(diš) udu niga 3(diš)-kam us₂ . u₄ 1(u) 9(diš)-kam . 2(diš) udu a-lum niga . 1(u) 2(diš) udu u₂ . 1(geš₂) maš₂-gal u₂ . u₄ 2(u) 3(diš)-kam . 1(u) 7(diš) gukkal u₂ . 2(diš) gukkal geš-du₃ u₂ . 1(u) 9(diš) udu gukkal u₂ . u₄ 2(u) 5(diš)-kam . 1(diš) am gu₄ . 2(diš) gu₄ u₂ . 1(geš₂) 4(u) 3(diš) udu u₂  3(diš) maš₂-gal  u₄ 2(u) 6(diš)-[kam]  šu+nigin 1(diš) gu₄ niga 3(diš)-kam us₂  šu+nigin 1(u) 5(diš) gu₄ u₂  šu+nigin 1(diš) ab₂ u₂  šu+nigin 4(diš) gu₄ mu 3(diš)  šu+nigin 1(u) 3(diš) gu₄ mu 2(diš)  šu+nigin 2(diš) ab₂ mu 2(diš)  šu+nigin 1(diš) am gu₄ . šu+nigin 1(diš) udu niga 3(diš)-kam us₂ . šu+nigin 1(diš) udu a-lum niga 3(diš)-kam us₂ . šu+nigin 1(diš) udu niga 4(diš)-kam us₂ . šu+nigin 5(u) 3(diš) udu [...] . šu+nigin 5(diš) gukkal [...] . šu+nigin 7(diš) udu [...] . šu+nigin 4(u) 1(diš) [...] . šu+nigin 2(diš) [...] . šu+nigin 1(diš) [...]  šu+nigin 3(u) 4(diš) gukkal u₂  šu+nigin 1(u) 6(diš) gukkal geš-du₃ u₂  šu+nigin 2(u) 4(diš) udu a-lum u₂  šu+nigin 2(u) 1(diš) udu gukkal u₂  šu+nigin 3(u) 2(diš) maš₂-gal u₂  šu+nigin 5(u) 2(diš) ud₅ u₂  šu+nigin 3(diš) sila₄  3(u) 6(diš) gu₄  1(diš) am . 8(geš₂) 3(u) 6(diš) udu . ki in-ta-e₃-a-ta . du-u₂-du . i₃-dab₅ . iti ki-siki-{d}nin-a-zu . mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ na-ru₂-a-mah {d}en-lil₂ {d}nin-lil₂-ra mu-ne-du₃
# P101395
#  1(diš) udu [...]  1(diš) [...]  u₄ 1(diš)-kam  2(diš) udu [...]  3(diš) gukkal niga  4(diš) udu a-lum niga  1(diš) maš₂-gal niga  1(diš) udu u₂  1(diš) maš₂-gal u₂ . u₄ 7(diš)-kam . 1(diš) udu a-lum niga 4(diš)-kam us₂ . u₄ 8(diš)-[kam] . 1(diš) gukkal [x] . 2(diš) udu a-lum u₂ . 1(diš) maš₂-gal [...] . 4(diš) udu u₂ . 1(diš) udu a-lum niga . 3(diš) maš₂-gal u₂ . u₄ 9(diš)-[kam] . 1(diš) udu niga . 4(diš) udu [x]  u₄ [x-kam]  1(diš) udu [...]  u₄ [x-kam]  4(diš) [...]  1(diš) [...]  1(diš) [...]  u₄ [x-kam]  šu+nigin [...] a. šu+nigin [...] b. šu+nigin 8(diš) [...] š. šu+nigin 4(diš) [...] d. šu+nigin 7(diš) [...] e. šu+nigin 2(diš) maš₂ [...] f. šu+nigin 1(u) [...] g. šu+nigin 1(diš) udu a-lum [...] h. šu+nigin 1(u) 1(diš) [...] i. šu+nigin 1(diš) [...] . ki in-[ta-e₃-a-ta] . nu x [...] . iti ezem-[...] . mu {d}šu-{d}suen [bad₃] ma-da [mu-du₃]
# P101403
#  2(u) udu u₂ alan didli  ša₃ e₂ {d}en-lil₂-la₂  1(u) 7(diš) udu u₂ alan didli  ša₃ e₂ {d}nin-lil₂-la₂  uzu-a bala  siskur₂ gu-la  lugal kuₓ(KWU636)-ra  1(diš) ab₂ u₂  2(u) udu u₂ . 1(u) 7(diš) u₈ u₂ . 1(u) 8(diš) maš₂-gal u₂ . šu-gid₂ e₂-muhaldim . lugal uri₅{ki}-še₃ du-ni ma₂-a ba-a-gar . ARAD₂-mu maškim . ša₃ nibru{ki} . 1(diš) gu₄ 1(geš₂) 3(u) 2(diš) udu . u₄ 1(diš)-kam . 1(u) udu u₂ alan didli . ša₃ e₂ {d}inanna . uzu-a bala . siskur₂ gu-la . lugal kuₓ(KWU636)-ra . 2(u) [udu u₂ alan didli] . ša₃ e₂ {d}en-lil₂-la₂ . 2(u) udu u₂ alan didli  ša₃ e₂ {d}nin-lil₂  uzu-a bala  siskur₂ gu-la  puzur₄-eš₁₈?-dar? sagi maškim  ša₃ nibru{ki}  4(u) udu  u₄ 6(diš)-kam  2(u) 4(diš) udu u₂ . 1(u) 1(diš) u₈ u₂ . 2(u) maš₂-gal u₂ . mu AŠ PAP i-bu-hu . ša₃ um ma du [...]-še₃? . lugal-ma₂-gur₈-re maškim . ša₃ uri₅{ki}-ma . 1(diš) gu₄ 5(u) 5(diš) udu . u₄ 1(u) 1(diš)-kam . 2(u) udu u₂ alan didli . ša₃ e₂ {d}en-lil₂-la₂ . 2(u) udu u₂ alan didli . ša₃ e₂ {d}nin-lil₂-la₂ . uzu-a bala . siskur₂ gu-la . {d}šu-{d}suen-ma-ha-ar sagi maškim . ša₃ nibru{ki} . 4(u) udu . u₄ 1(u) 3(diš)-kam . 2(diš) gu₄ u₂ . 5(diš) ab₂ u₂ . 4(u) 3(diš) udu u₂  3(u) 3(diš) maš₂ u₂  1(u) 4(diš) ud₅ u₂  šu-gid₂ e₂-muhaldim  mu lu₂ maš₂-da-re-a-ke₄-ne-še₃  gešbun₂ er₂ su₃-a  ARAD₂-mu maškim  ša₃ uri₅{ki}-ma  1(u) maš₂-gal u₂  šu-gid₂ e₂-muhaldim  mu geme₂ dumu {d}inanna-ke₄-ne-še₃  u₄ ki-{d}utu ba-ak?-a  lugal-ma₂-gur₈-re maškim  ša₃ unu{ki}-ga  3(u) udu . mu x [...] . 1(diš) gu₄ u₂ . 6(diš) udu u₂ . 7(diš) maš₂-gal u₂ . mu lu₂ šuku-ra-ke₄-ne-še₃ . šu-gid₂ e₂-muhaldim . lugal-ma₂-gur₈-re maškim . ša₃ unu{ki}-ga . 1(diš) gu₄ 2(u) 3(diš) udu ʾ. u₄ 2(u) 5(diš)-kam ʾ. 1(u) ud₅ u₂ alan didli ʾ. ša₃ e₂ {d}inanna ʾ. uzu-a bala ʾ. siskur₂ gu-la  ša₃ unu[{ki}-ga]  1(u)  u₄ 2(u) 6(diš)-<kam>  1(diš) ab₂ u₂  5(diš) ud₅ u₂  mu aga₃-us₂ a tu₅-a ka e₂-gal-la kuₓ(KWU636)-ra-ne-še₃  1(diš) gu₄ u₂  5(diš) maš₂-gal u₂  4(diš) sila₄ . mu lu₂ šuku-ra-ke₄-ne-še₃ . šu-gid₂ e₂-muhaldim . lugal-ma₂-gur₈-re maškim . ša₃ unu{ki}-ga . 2(diš) gu₄ 1(u) 4(diš) udu . u₄ 2(u) 7(diš)-kam . 1(u) udu u₂ . šu-gid₂ e₂-muhaldim . mu lu₂ šuku-ra-ke₄-ne-še₃ . lugal-ma₂-gur₈-re maškim . ša₃ unu{ki}-ga . 1(u) udu . u₄ 2(u) 8(diš)-kam . 5(diš) udu u₂ {d}inanna . giri₃ a-bi₂-si₂-im-ti . {d}suen-a-bu-šu sagi maškim . 1(u) udu u₂ alan didli  ša₃ e₂ {d}inanna  lugal kuₓ(KWU636)-ra  1(u) 4(diš) ud₅ u₂  mu lu₂ šuku-ra-ke₄-ne-še₃  2(diš) ab₂ u₂  3(u) udu u₂  2(u) maš₂-gal u₂ . lugal nibru{ki}-še₃ du-ni ma₂-a ba-a-ga₂-ar . 2(diš) gu₄ 1(geš₂) 1(u) 8(diš) udu . u₄ 2(u) 9(diš)-kam . ša₃ nibru{ki} . u₄ 3(u)-kam  šu+nigin 7(diš) gu₄ u₂  šu+nigin 1(u) 1(diš) ab₂ u₂  šu+nigin 3(diš) ab₂ mu 3(diš)  šu+nigin 4(diš) ab₂ mu 2(diš)  šu+nigin 7(geš₂) 1(u) 2(diš) udu u₂  šu+nigin 2(u) 8(diš) u₈ u₂  šu+nigin 3(geš₂) 4(u) 8(diš) maš₂-gal u₂  šu+nigin 4(u) 3(diš) ud₅ u₂  šu+nigin 4(diš) sila₄ . šu+nigin₂ 2(u) 5(diš) gu₄ ab₂ hi-a . šu+nigin₂ 1(gešʾu) 3(geš₂) 5(u) 6(diš) udu maš₂ hi-a . ki ur-ku₃-nun-na-ta . ba-zi . giri₃ nu-ur₂-{d}suen dub-sar . iti ezem-mah . mu {d}šu-{d}suen . lugal uri₅{ki}-ma-ke₄ . e₂ {d}šara₂ umma{ki}-ka mu-du₃
# P124103
#  2(diš) gu₄  1(diš) gu₄ amar ga  2(diš) ab₂ 1(u) 2(diš) udu  8(diš) maš₂  šu-gid₂  2(diš) gu₄ 2(diš) ab₂ ba-uš₂  e₂-muhaldim-še₃  u₄ 2(u) 4(diš@t)-kam  ki in-ta-e₃-a-ta  ba-zi  iti šu-eš₅-ša  mu en-mah-gal-an-na en {d}nanna ba-hun  1(u) la₂ 1(diš) gu₄ 2(u) udu
# P142868
#  3(u) 1(diš) gu₄  1(diš) ab₂  iti diri še-sag₁₁-ku₅  5(u) 8(diš) gu₄  3(u) 3(diš) ab₂  iti u₅-bi₂-gu₇  1(diš) gu₄ niga  iti ezem-{d}nin-a-zu  2(geš₂) 4(diš) . mu us₂-sa ki-maš{ki} ba-hul . 1(geš₂) 6(diš) gu₄ . 4(u) 4(diš) ab₂ . iti a₂-ki-ti . 4(geš₂) 5(u) 1(diš) gu₄ . 1(geš₂) 1(u) 7(diš) ab₂ . iti ezem-{d}šul-gi . 1(diš) gu₄ niga . 1(geš₂) 3(u) la₂ 1(diš) gu₄ . 1(u) 5(diš) ab₂ . [iti šu]-eš₅-ša . [x] gu₄ . [...] x  2(geš₂) 4(u) 8(diš) gu₄  1(u) ab₂  iti ezem-mah  2(u) 5(diš) gu₄  iti ezem-an-na  1(geš₂) 2(u) 4(diš) gu₄  1(u) 4(diš) ab₂  iti ezem-me-ki-gal₂  4(u) gu₄ . iti še-sag₁₁-ku₅ . 1(gešʾu) 4(geš₂) 4(u) 3(diš) . mu {d}amar-{d}suen lugal . 1(geš₂) 1(u) 1(diš) gu₄ . 6(diš) ab₂ . iti maš-da₃-gu₇ . 8(diš) gu₄ . iti ses-da-gu₇ . 4(u) 4(diš) gu₄ . 8(diš) ab₂ . iti u₅-bi₂-gu₇ . 3(diš) gu₄ . 3(diš) ab₂ . iti# ki-siki-{d}nin-a-zu . [x] gu₄#  6(diš) gu₄  ki ṣe-lu-uš-{d}da-gan-ta  1(diš) gu₄  1(diš) ab₂  ki {d}nisaba-an-dul₃-ta  3(diš) gu₄  1(diš) ab₂  ki šu-da-da-ta  5(diš) gu₄ . 2(diš) ab₂ . ki šu-i₃-li₂-ta . 5(diš) gu₄ . 1(diš) ab₂ . ki i-din-e₂-a-ta . 2(diš) gu₄ . 1(diš) ab₂ . iti ezem-{d}šul-gi . 1(diš) gu₄ . iti šu-eš₅-ša . ki ur-{d}suen dumu u₃-sa₆-a-ta  4(diš) [ab₂]  ki zabar?-[dab₅?-ta]  iti ezem-mah#  3(diš) [gu₄]  1(u) la₂ 1(diš) [ab₂]  ki KA#-[...]  3(diš) [gu₄]  4(diš) [ab₂]  ki zabar#?-[dab₅?-ta] . 1(diš) [gu₄] . ki ur-sa₆#-[ga-ta] . 2(u) 5(diš) [gu₄] . 6(diš) [ab₂] . ki kal-[...] . iti šu-[eš₅-ša] . 2(geš₂) 4(u) 1(diš) . mu {d}amar-{d}suen# lugal-[am₃] . 4(diš) gu₄# . 1(diš) ab₂# . ki i-din-e₂-a-ta . iti u₅-bi₂-gu₇ . 1(diš) gu₄ . [...] . 1(diš) [...] . 1(diš) [...] . ki x-[...] . 3(u) 6(diš)# [gu₄] . 1(u) [ab₂] . kišib₃ ur-{d}x-[x] dumu ur-sa₆-ga . iti ki-siki-{d}nin-a-zu . 3(u) la₂ 1(diš) gu₄ . 2(u) la₂ 1(diš) ab₂ . kišib₃ a₂-na-na . iti šu-eš₅-ša ʾ. 3(u) 7(diš) gu₄ ʾ. 3(diš) ab₂ ʾ. kišib₃ lugal#?-[...] ʾ. 3(u) 8(diš) [gu₄] ʾ. 2(diš) ab₂# ʾ. kišib₃ u₄-[...] ʾ. 1(u) 4(diš) gu₄# ʾ. kišib₃ ensi₂ lu₂#? [ka]-zal-lu{ki} ʾ. 1(diš) gu₄ kišib₃ {d}EN-x-[...] ʾ. 2(u) gu₄ a-hu-[...] u₃ lu₂-{d}[...] mu gu₄ x-[...-še₃] ʾ. iti ezem-[...] ʾ. 1(u) 2(diš) [gu₄] . [x] x [...] . iti# šu-eš₅-ša . 5(geš₂) 1(u) 4(diš) . mu {d}amar-{d}suen lugal-[am₃] . 4(diš) ab₂ mu 2(aš) . iti maš-da₃-gu₇ . 2(u) 7(diš) gu₄ . 4(diš) ab₂ . kišib₃ uš-mu ʾ. a-ra₂ 1(diš)-kam ʾ. 1(diš) gu₄ kišib₃ lu₂-{d}nanna dumu inim-{d}šara₂ ʾ. 2(diš) gu₄ ʾ. kišib₃ ši-ha-lum nu-banda₃ ʾ. 1(diš) gu₄ ʾ. kišib₃ nin-a₂-zi-da ʾ. 1(diš) gu₄ ʾ. kišib₃ be-li₂-du₁₀ ra₂-gaba ʾ. 2(diš) gu₄ ʾ. kišib₃ ka₅-a-mu ʾ. 1(diš) gu₄ kišib₃ {d}šul-gi-ra₂!?-gaba ra₂-gaba lu₂ ur-nigar ʾ. 1(diš) gu₄ ʾ. kišib₃ im-da-du₁₀ nu-banda₃ . kišib₃ ka₅-a-mu . iti ki-siki-{d}nin-a-zu . u₃ iti ezem-{d}nin-a-zu . 1(geš₂) 4(u) 7(diš) . mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} mu-hul . kišib₃ dab-ba . šu+nigin 5(diš) gu₄ niga . šu+nigin 3(gešʾu) 6(geš₂) 4(u) la₂ 1(diš) gu₄ . šu+nigin 1(gešʾu) 8(geš₂) 4(u) 3(diš) ab₂ ʾ. šu+nigin dusu₂-nita₂ ʾ. šu+nigin 2(diš) dusu₂ munus . nig₂-ka₉-ak . {d}en-lil₂-la₂ . ka la₂-a . giri₃ ur-ku₃-nun-na . iti diri še-sag₁₁-ku₅ . mu us₂-sa ki-maš{ki} ba-hul-ta . iti ezem-{d}nin-a-zu . mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} mu-hul-še₃ . iti 3(u)-kam
# P467616
#  6(diš) gu₄ 6(diš) ab₂ [...]  zi-ga u₄ 1(diš)-[kam]  1(diš) gu₄ 3(diš) ab₂ u₄ 2(diš)#-[kam]  1(diš) gu₄ u₄ 3(diš)-[kam]  5(diš) gu₄ 1(diš) ab₂ u₄ 4(diš)-[kam]  3(diš) gu₄ 2(diš) ab₂ u₄ 5(diš)-[kam]  1(diš) ab₂ u₄ 6(diš)-kam  1(diš) gu₄ 3(diš) ab₂ u₄ 7(diš)-kam  2(diš) gu₄ 3(diš) ab₂ u₄ 8(diš)-kam . 4(diš) gu₄ u₄ 1(u) la₂ 1(diš)-kam giri₃ {d}en-lil₂-la₂ . 3(diš) gu₄ 7(diš) ab₂ u₄ 1(u)-kam . 1(diš) gu₄ 1(diš) ab₂ u₄ 1(u) 4(diš)-kam . 1(diš) gu₄ 2(diš) ab₂ u₄ 1(u) 5(diš)-kam . 4(diš) gu₄ u₄ 1(u) 6(diš)-kam . 4(diš) gu₄ u₄ 1(u) 7(diš)-kam . 2(diš) gu₄ u₄ 1(u) 8(diš)-kam . 1(diš) ab₂ u₄ 2(u) la₂ 1(diš)-kam  2(diš) gu₄ u₄ 2(u) 2(diš)-kam  1(diš) ab₂ u₄ 2(u) 5(diš)-kam  1(diš) gu₄ u₄ 2(u) 7(diš)-kam  2(diš) gu₄ u₄ 3(u) la₂ 1(diš)-kam  šu+nigin 4(u) 3(diš) [gu₄]  šu+nigin 3(u) 1(diš) [ab₂]  ki {d}en-lil₂-[la₂-ta]  ba-[zi]  iti ki-siki-{d}nin#-[a-zu] . mu {d}amar-{d}[suen] ur-bi₂-lum#[{ki} ba-hul]  1(geš₂) 1(u) 4(diš)
#
# Cluster 5
# =========
#
# P100328
#  4(diš) udu a-lum niga 3(diš)-kam us₂  8(diš) udu niga 4(diš)-kam us₂  1(diš) sila₄  be-li₂-a-ri₂-ik  2(diš) maš₂-gal niga 4(diš)-kam us₂  1(diš) sila₄  ṣe-lu-uš-{d}da-gan  4(diš) udu u₂  1(diš) sila₄ . ku-ba-ba-e . 4(diš) udu niga saga  6(diš) udu a-lum niga [saga]  2(u) udu a-lum niga saga us₂  3(u) udu a-lum niga 3(diš)-kam us₂  ba-ba-ti  u₄ 5(diš)-kam  mu-kuₓ(DU) lugal  in-ta-e₃-a i₃-dab₅  [giri₃] nu-ur₂-{d}suen dub-sar  iti# u₅-bi₂-gu₇ . mu us₂-sa {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ si-ma-num₂{ki} mu-hul  1(geš₂) 2(u) 1(diš) udu  nu-ur₂-{d}suen  dub-sar  dumu i-di₃-er₃-ra
# P100986
#  [x] maš₂ niga 3(diš)-kam us₂  1(diš) udu niga 4(diš)-kam us₂  1(diš) {munus}aš₂-gar₃ niga 4(diš)-kam us₂  siskur₂ {d}inanna ša₃ e₂-gal  {d}nanna-igi-du sagi maškim  a₂-ge₆-ba-a  5(diš) udu niga gu₄-e-us₂-sa  5(diš) maš₂-gal niga gu₄-e-us₂-sa  i-zi-in-{d}da-gan . 3(diš) udu niga gu₄-e-us₂-sa . kur-bi-la-ak . lu₂ eb-la{ki}-me-eš₂ . 5(diš) udu niga gu₄-e-us₂-sa . 5(diš) maš₂-gal niga gu₄-e-us₂-sa . a-bu-du₁₀ lu₂ ma-ri₂{ki} . 5(diš) udu niga gu₄-e-us₂-sa . i-pi₂-iq-re-e-u₂ mar-tu ia₃-a-ma-di₃-um . iri-ne-ne-še₃ du-ni . ma₂-a ba-ne-gub . 3(diš) udu niga gu₄-e-us₂-sa . 2(diš) maš₂-gal niga gu₄-e-us₂-sa  i₃-u₃-ša dumu me-ša#-[nu-nu?] šimašgi  giri₃ ur-sukkal sukkal  ARAD₂-mu maškim  2(diš) udu niga saga us₂  8(diš) udu niga 3(diš)-kam us₂  a-bi₂-si₂-im-ti  tu-ra-am-{d}da-gan maškim  a₂ u₄!-te-na  u₄ 1(u) 4(diš)-kam . [ki a]-ba-{d}en-lil₂-gin₇-ta . [ba]-zi . [ša₃] nibru{ki} . giri₃ lu₂-{d}nin-šubur dub-sar . iti ezem-{d}šu-{d}suen . mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ na-ru₂-a-mah {d}en-lil₂ [{d}]nin-lil₂-ra [mu]-ne-du₃
# P101016
#  1(diš) udu niga saga  1(diš) maš₂-gal niga saga  1(diš) udu niga saga us₂  1(diš) udu niga 3(diš)-kam us₂  1(diš) udu niga 4(diš)-kam us₂  1(diš) udu niga gu₄-e-us₂-sa  an  1(diš) maš₂-gal niga saga  1(diš) udu niga saga us₂ . 1(u) udu niga gu₄-e-us₂-sa . {d}en-lil₂ . 2(diš) udu niga saga . 2(diš) udu niga saga us₂ . 1(diš) maš₂-gal niga 3(diš)-kam us₂ . 1(u) udu niga gu₄-e-us₂-sa . {d}nin-lil₂ . 1(diš) udu niga 3(diš)-kam us₂ . 1(diš) udu niga 4(diš)-kam us₂ . {d}gu-za {d}en-lil₂-la₂ . 1(diš) udu niga 3(diš)-kam us₂ . 1(diš) udu niga 4(diš)-kam us₂ . hur-sag-ga-lam-ma . 1(diš) udu niga 4(diš)-kam us₂ . AN a-ba-{d}en-lil₂-gin₇ . šu-nir {d}en-lil₂-la₂ . ša₃ nibru{ki} . 2(diš) udu niga saga . 1(diš) maš₂-gal niga saga us₂ . [x] udu niga gu₄-e-us₂-sa  {d}nin-lil₂  1(diš) udu niga 3(diš)-kam us₂  2(diš) udu niga 4(diš)-kam us₂  {d}nanna  1(diš) udu niga 3(diš)-kam us₂  1(diš) udu niga 4(diš)-kam us₂  {d}nin-ti₂-ug₅-ga  1(diš) udu niga 3(diš)-kam us₂  {d}nisaba . 1(diš) udu niga 3(diš)-kam us₂ . {d}en-lil₂-la₂ GI . 1(diš) udu niga 3(diš)-kam us₂ . 1(diš) udu niga 4(diš)-kam us₂ . e₂-gal mah . ša₃ e₂ {d}nin-lil₂-la₂ . 1(diš) udu niga . 1(diš) udu niga gu₄-e-us₂-sa . {d}nin-e₂-gi₄-a . 2(diš) udu niga 4(diš)-kam us₂ . 1(diš) udu niga . {d}nin-hur-sag . 2(diš) udu niga . {d}nin-pa-e₃ . ša₃ e₂ {d}nin-hur-sag . 2(diš) udu niga saga us₂ . 2(diš) udu niga du₆-ku₃ . 1(diš) udu niga 4(diš)-kam us₂ . {d}inanna ka-giri₃ . {d}šu-{d}[suen]  1(diš) udu niga [...]  1(diš) udu [...]  {d}PA-[...]  2(diš) udu niga [...]  1(diš) udu niga [...]  nig₂-[...]  {d}nin-[...]  1(diš) udu niga [...]  {d}[...] . 2(diš) udu [...] . {d}nin-[...] . 1(diš) udu niga [...] . 1(diš) udu [...] . 2(diš) udu niga [...] . {d}nin-sa₆-[...] . 1(diš) udu niga 4(diš)-kam [us₂] . 1(diš) udu [...] . {d}šu-{d}suen . 1(diš) udu niga x [...] . 1(diš) udu niga [...] . 1(diš) udu niga [...] . {d}EN-[...] . 1(diš) udu niga [...] . 1(diš) udu [...] . 1(diš) udu [...] . 1(diš) [...] . 2(diš) [...] . {d}nin-[...] . 2(diš) udu [...] . {d}x-x [...] . 1(diš) x x [...] . 1(diš) [...] . [...] . 1(diš) [...] . {d}[...] . 1(diš) udu niga gu₄-[e-us₂-sa] . {d}nisaba? . 1(diš) udu niga nig₂-x x . {d}nusku . 1(diš) udu niga gu₄-e-us₂-sa . nig₂-diri ʾ. {d}al-la gu-la ʾ. 1(diš) udu niga gu₄-e-us₂-sa ʾ. nig₂-diri ʾ. {d}[x]-x ʾ. ša₃ [x]-x-la [...] um? ʾ. 1(diš) udu [...] x ʾ. 1(diš) [...] ʾ. {d}nanna ʾ. 1(diš) [...] ʾ. {d}[...] ʾ. 1(diš) udu [...] ʾ. {d}ba-[...] ʾ. 1(diš) udu niga [...] ʾ. {d}nin-gir₂?-[su] ʾ. 2(diš) [...] ʾ. {d}en-[lil₂] ʾ. 2(diš) udu [...] ʾ. {d}nin-lil₂ ʾ. giri₃ a₂!-na-na ʾ. nig₂-dab₅ ezem [...] ʾ. 4(diš) x [...] ʾ. {d}šu-{d}[suen]  [x] udu niga  [...] niga  [...] a  [...] tum?  [...] iš?  [...] du?  [...] nisaba?  [...] ti  [a₂]-ge₆-ba-a . u₄ 7(diš)-kam . ki a-ba-{d}en-lil₂-gin₇-ta ba-zi . ša₃ nibru{ki} . giri₃ lu₂-{d}nin-šubur dub-sar . iti diri ezem-{d}me-ki-gal₂ . mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ na-ru₂-a-mah {d}en-lil₂ {d}nin-lil₂-ra mu-ne-du₃  2(geš₂) 2(u)
# P101400
#  [...] 1(u) 1(diš) udu niga saga us₂  [x] gukkal niga 3(diš)-kam us₂  [x] udu niga 3(diš)-kam us₂  [x] maš₂-gal niga 4(diš)-kam us₂  {d}en-lil₂  1(diš) udu niga 4(diš)-kam us₂  {d}gu-za {d}en-lil₂-la₂  1(diš) udu niga 4(diš)-kam us₂  hur-sag-ga-lam-ma . ša₃ e₂ {d}en-lil₂-la₂ . [x] gukkal niga saga us₂ . [x] udu a-lum niga saga us₂ . [...] udu niga 3(diš)-kam us₂ . [...] niga 4(diš)-kam us₂ . [...] e₂ . [...] alan du₃ [...] . [...] x hu-ba-a . [...] x 1(diš) dusu x [...] . [...] 1(u) 4(diš) [mu-kuₓ(DU)] lugal . [...] 1(u) 5(diš)-kam . [ki] ša-x-e₂-ta . [ba]-zi . [giri₃ x]-an-ni dub-sar . [iti] ses-da-gu₇ u₄ . [mu {d}]šu-{d}suen lugal uri₅[{ki}-ma-ke₄ e₂ {d}šara₂] umma{ki}-ka [mu]-du₃
# P103805
#  3(diš) udu niga 1(diš) maš₂ niga  {d}en-lil₂  3(diš) udu niga 1(diš) maš₂ niga  {d}nin-lil₂  siskur₂ ša₃ e₂-a  2(diš) udu niga du₆-ku₃  1(diš) maš₂ niga {d}nin-hur-sag  1(diš) maš₂ niga {d}nusku  1(diš) maš₂ niga {d}nin-urta . 1(diš) maš₂ niga {d}inanna . 1(diš) maš₂ niga {d}nin-sun₂ . 1(diš) maš₂ niga {d}lugal-banda₃{da} . 1(diš) udu [niga] {d}nin-ti₂-ug₅-ga . [siskur₂] ge₆ a-ra₂ 1(diš)-kam . 9(diš)? udu niga 3(diš) maš₂ niga an . 8(diš) udu niga 2(diš) maš₂ niga {d}en-lil₂ . 8(diš) udu niga 2(diš) maš₂ niga {d}nin-lil₂ . ša₃ e₂ {d}en-lil₂-la₂ . 7(diš) udu niga 3(diš) maš₂ niga {d}nin-lil₂ . 1(diš) udu niga {d}en-lil₂-la₂-zi . 1(diš) udu niga {d}nin-ti₂-ug₅-ga . 1(diš) udu niga {d}nisaba  ša₃ e₂ {d}nin-lil₂-la₂  1(diš) udu niga 1(diš) maš₂ niga {d}nin-hur-sag  1(diš) udu niga 1(diš) maš₂ niga {d}nusku  1(diš) udu niga 1(diš) maš₂ niga {d}nin-urta  1(diš) udu niga 1(diš) maš₂ niga {d}inanna  1(diš) udu niga 1(diš) maš₂ niga {d}nin-sun₂  1(diš) udu niga 1(diš) maš₂ niga {d}lugal-banda₃{da}  1(diš) udu niga 1(diš) maš₂ niga {d}en-ki  1(diš) udu niga 1(diš) maš₂ niga {d}nin-ti₂-ug₅-ga . 2(diš) udu niga {d}en-lil₂ . 2(diš) udu niga {d}nin-lil₂ . giri₃ {d}na-na-a e₂ {d}en-lil₂-la₂-še₃ tu-ra . {d}en-lil₂-ra {d}šul-gi-re kaš-de₂-a . 2(diš) udu niga 2(diš) maš₂ niga {geš}kiri₆-mah . 1(diš) udu niga siskur₂ {d}inanna ša₃ {geš}kiri₆ . {d}nanše-GIR₂@g?-gal maškim . 1(diš) udu niga {d}na-na-a . er₃-ra-na-da maškim? . iti u₄ 7(diš) ba-zal . šu+nigin# 4(diš) udu niga 2(u) 5(diš) maš₂ niga . zi-ga ki na-lu₅ . iti ezem-me-ki-gal₂ . mu ur-bi₂-lum{ki} ba-hul
# P126109
#  1(diš) udu niga 3(diš)-kam us₂  1(diš) udu niga 4(diš)-kam us₂  1(diš) maš₂-gal niga 4(diš)-kam us₂  {d}nin-lil₂  lugal ku₄?-ra  a₂-ge₆-ba-a  iti u₄ 1(u) 7(diš) ba-zal  ki {d}en-lil₂-zi-ša₃-gal₂-ta  ba-zi  iti ki-siki-{d}nin-a-zu  mu us₂-sa si-[ma]-num₂{ki} ba-hul  {d}šu-{d}suen  lugal kal-ga  lugal uri₅{ki}-ma  lugal an ub-da limmu₂-ba  {d}šul-gi-iri-mu sukkal  ra₂-gaba  ARAD₂-zu
# P126542
#  1(diš) udu niga saga  1(diš) udu niga 3(diš)-kam us₂  1(diš) maš₂-gal niga 4(diš)-kam us₂  {d}en-lil₂  1(diš) udu niga saga us₂  1(diš) udu niga 3(diš)-kam us₂  {d}nin-lil₂  lugal ku₄?-ra  2(diš) udu niga 3(diš)-kam us₂  {d}nanna  siskur₂ ša₃ e₂-gal  iti u₄ 1(u) 1(diš) ba-zal  ki a-hu-we-er-ta  ba-zi  giri₃ {d}šul-gi-al-mah dub-sar  iti a₂-ki-ti  mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ si-ma-num₂{ki} mu-hul  7(diš) udu  {d}šul-[gi]-al-mah  dub-[sar]  [dumu ...]
# P142809
#  1(diš) udu niga 1(diš) maš₂-gal niga  {d}en-lil₂  1(diš) udu niga {d}gu-za  1(diš) udu niga 1(diš) maš₂-gal niga  {d}nin-lil₂  a₂ gu₂ zi-ga  2(diš) udu niga {d}en-lil₂  1(diš) udu niga {d}gu-za  1(diš) maš₂-gal niga ki puzur₄-x-x  4(diš) udu niga [...]  a₂ x-x-na  a-tu maškim  1(u) [...]  [...]  ki# [...]  x ki [...]  x x [...]  iti [...] . x x [...] x x . iti ezem-mah . mu en-unu₆-gal {d}inanna# ba-hun  3(u) 1(diš)
#
# Cluster 6
# =========
#
# P101002
#  3(diš) udu  1(diš) maš₂  u₄ 3(u)-kam  ki na-lu₅-ta  {d}šul-gi-iri-mu  šu ba-ti  iti a₂-ki-ti  mu {d}gu-za {d}en-lil₂-la₂ ba-dim₂
# P107878
#  1(diš) maš₂-gal  ba-uš₂  u₄ 4(diš)-kam  ki na-lu₅-ta  {d}šul-gi-iri-mu  šu ba-ti  iti a₂-ki-ti  mu hu-uh₂-nu-ri{ki} ba-hul
# P124191
#  1(diš) gukkal  1(diš) maš₂-gal  ba-uš₂  u₄ 5(diš@t)-kam  ki na#-lu₅-ta  {d}šul-gi-iri-mu  šu ba-ti  iti šu-eš-ša  mu en eridu{ki} ba-hun  2(diš) udu
# P124264
#  1(diš) maš₂-gal  ba-uš₂#  u₄# 2(u)# 4(diš)-kam  ki# [tah]-ša#-tal-ta  {d}šul-gi-iri-mu  šu ba-ti  iti a₂-ki-ti  mu ša-aš-ru{ki} ba-hul  1(diš)
# P134996
#  4(diš) udu  1(diš) sila₄  1(diš) {munus}aš₂-gar₃  ba-uš₂ u₄ 2(u) 2(diš)-kam  ki na-lu₅-ta  {d}šul-gi-iri-mu  šu ba-ti  iti ki-siki-{d}nin-a-zu  mu hu-uh₂-nu-ri{ki} ba-hul  1(diš) udu
#
# Cluster 7
# =========
#
# P101005
#  1(diš) udu  1(u) 5(diš) maš₂-gal  u₄ 1(u) 3(diš)-kam  ki ab-ba-sa₆-ga-ta  na-lu₅ i₃-dab₅  iti šu-eš₅-ša  mu hu-uh₂-nu-ri{ki} ba-hul  1(geš₂) 1(u) 5(diš)
# P101006
#  2(u) 7(diš) udu  4(diš) sila₄  5(u) 5(diš) maš₂-gal  u₄ 3(u)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a  i₃-dab₅  iti šu-eš₅-ša  mu hu-uh₂-nu-ri{ki} ba-hul  1(geš₂) 3(u)
# P101008
#  4(diš) sila₄  u₄ 2(u) 5(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a i₃-dab₅  iti ezem-mah  mu hu-uh₂-nu-ri{ki} ba-hul  4(diš)
# P101009
#  2(diš) ud₅  1(u) 7(diš) maš₂  u₄ 2(u) 8(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a  i₃-dab₅  iti ezem-mah?  mu hu-uh₂-nu-ri{ki} ba-hul  2(u) la₂ 1(diš)
# P101010
#  1(u) la₂ 1(diš) udu  2(u) sila₄  8(diš) maš₂  u₄ 2(u) 8(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a i₃-dab₅  iti ezem-mah  mu hu-uh₂-nu-[ri{ki}] ba-hul  3(u) 7(diš)
# P124025
#  8(diš) udu  7(diš) sila₄#  2(diš) maš₂#  u₄# 2(u) 1(diš)-kam#  ša₃ uri₅{ki}-ma#  ki ab-ba-sa₆-ga-ta  in-ta-e₃#-a# i₃-dab₅#  iti ezem-an-na  mu en-unu₆-gal# {d}inanna unu{ki} ba-hun  1(u) 7(diš)
# P124071
#  2(diš) udu niga  1(diš) sila₄  u₄ 2(u) 4(diš@t)-kam  ki ab-ba-sa₆-ga-ta  na-lu₅  i₃-dab₅  iti ezem-an-na  mu hu-uh₂-nu-ri{ki} ba-hul  3(diš)
# P124539
#  8(diš) udu 1(u) 2(diš) u₈  2(diš) maš₂-gal  šu-gid₂  3(diš) udu 5(diš) ud₅  ba-uš₂  e₂-muhaldim-še₃  u₄ 1(u) la₂ 1(diš)-kam  ki in-ta-e₃-a-ta ba-zi  iti ezem-mah  mu hu-uh₂-nu-ri{ki} ba-hul  3(u)
# P407077
#  1(u) 2(diš) udu  5(diš) sila₄  8(diš) maš₂  u₄ 1(u) 1(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a  i₃-dab₅  iti ezem-an-na  mu {d}gu-za {d}en-lil₂-la₂ ba-dim₂  2(u) 5(diš)
# P407141
#  1(diš) sila₄  u₄ 1(u) 4(diš)-kam  ki ab-ba-sa₆-ga-ta  in-ta-e₃-a  i₃-dab₅  iti a₂-ki-ti  mu ša-aš-ru{ki} ba-hul  1(diš)
#
# Cluster 8
# =========
#
# P101300
#  2(diš) sila₄  ki ur-ku₃-nun-na-ta  du₁₁-ga  i₃-dab₅  iti ezem-mah  mu en {d}inanna maš₂-e i₃-pa₃  du₁₁-ga dub-sar  dumu lu₂-{d}nin-gir₂-su  sipa na-gab₂-tum
# P101325
#  8(diš) udu  ki ka₅-a-mu-ta  du₁₁-ga i₃-dab₅  iti ezem-{d}nin-a-zu  mu ma₂-dara₃-abzu {d}en-ki ba-ab-du₈  du₁₁-ga dub-sar  dumu lu₂-{d}nin-gir₂-su  sipa na-gab₂-tum
# P101328
#  4(diš) udu  8(diš) maš₂  ki ka₅-a-mu-ta  du₁₁-ga  i₃-dab₅  giri₃ al-la-mu  iti ezem-me-ki-gal₂  mu ma₂ {d}en-ki-ka ba-ab-du₈  du₁₁-ga dub#-[sar]  dumu lu₂-[{d}nin-gir₂-su]  sipa na-[gab₂]-tum
# P101398
#  1(diš) udu  kišib₃ {d}utu-bar-ra unu₃  ki ur-mes-ta  ba-zi  iti ezem-{d}šul-gi  mu ma₂-dara₃-abzu ba-ab-du₈  udu  du₁₁-ga dub-sar  dumu lu₂-{d}nin-[gir₂-su]  sipa na-gab₂-[tum]
# P104312
#  iti diri [...]-x  [mu ...]  du₁₁-ga dub-sar  dumu lu₂-{d}nin-gir₂-su  sipa na-gab₂-tum

# %% [markdown]
# # Predict

# %%
# Read all files to get all Drehem transactions
def read_files(subdir, ids, reverse=False):
    transactions = list()
    for i in range(1, 16):
        file_name = ""
        if i < 10:
            file_name += subdir + "p00" + str(i) + ".atf"
        else:
            file_name += subdir + "p0" + str(i) + ".atf"
        
        curr_transaction = None
        
        with open(file_name, encoding="utf8") as file:
            print("Opening:", file_name)
            for line in file:
                line = line.strip()
                if line.startswith('&P'):
                    p_id = line.split()[0][1:]
                    #print(p_id)
                    if (not reverse and p_id in ids):
                        ids.remove(p_id)
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    elif (reverse and p_id not in ids and len(transactions) <= 200):
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        transaction = Transaction(p_id)
                        curr_transaction = transaction
                    else:
                        if curr_transaction:
                            transactions.append(curr_transaction)
                        curr_transaction = None
                else:
                    if curr_transaction:
                        curr_transaction.lines.append(line)
        
        if curr_transaction:
            transactions.append(curr_transaction)
    
    #print(ids)
    #assert len(ids) == 0
    print("Number of transactions:", len(transactions))
    return transactions

# Return the IDs of docs to annotate
def get_drehem_ids(file):
    lst = list()
    with open(file, encoding="utf8") as f:
        for line in f:
            line = line.strip()
            lst.append("P" + line)
    return lst

# %%
all_ids = get_drehem_ids("drehem_p_ids.txt")
print(all_ids[:10])
all_transactions = read_files("raw-data/", all_ids)
# Out:
# ['P125693', 'P131063', 'P103742', 'P118642', 'P337724', 'P212008', 'P103154', 'P105823', 'P390986', 'P115492']
# Opening: raw-data/p001.atf
# Opening: raw-data/p002.atf

# %%
data = []
mapping = {}
labs = []

for t in all_transactions:
    t.get_lemmatization()
    labs.append(t.set_label())
    lemma = " ".join(t.get_sumerian_lemma())
    data.append(lemma)
    if lemma in mapping:
        mapping[lemma].append(t)
    else:
        mapping[lemma] = [t]
        
# Predict
X_new_counts = uni_and_bigram_vectorizer.transform(data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

uni_and_bigram_prediction = uni_and_bigram_classifier.predict(X_new_tfidf)

# %%
for doc, category in zip(data[:100], uni_and_bigram_prediction[:100]):
    print('%r => %s' % (doc, category))
# Out:
# 'udu kišib ki lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'udu niga sila ga uš ud ki šu teŋ itud mu u hulu' => not queen
# 'sila sila mu.DU zabardab maškim u udu maš uš ekišibak ud lal ki itud mu us hulu' => not queen
# 'mašgal niga udu uš ud šag ki šu teŋ itud mu lugal' => not queen
# 'udu a sag udu niga mašgal niga udu sila ga kir ga uš ud ki šu teŋ itud mu lugal' => not queen
# 'udu niga sila niga udu sila ensik sila ensik sila mu.DU itud mu en maš pad ud' => not queen
# 'mašgal niga egia ensik ragaba maškim itud ud lal zal ki ŋiri dubsar itud mu en huŋ udu' => not queen
# 'amar mašda mašda amar amar mašda sila amar mašda maš sila ensik mu.DU dab itud gu mu us hulu ud' => not queen
# 'mašgal ki ensik dab itud mu huŋ udu' => not queen
# 'sila zabardab sila ensik sila ensik mu.DU dab itud akiti mu u mada ud hulu ud' => not queen
# 'mašgal niga lu maškim itud ud zal ki itud mu lugal hulu' => not queen
# 'gud ab mu.DU lugal ki bala zig ensik dab ziga itud mu en maš pad' => not queen
# 'lal udu udu u u sila gub sila gub šugid udu a gukkal lal maš gub uzud ašgar ki ensik ud mu.DU dab itud mu du' => not queen
# 'udu sadug šag udu uš mu sipad šu teŋ ki itud mu us hulu' => not queen
# 'udu sadug šag udu u maš uš mu urgir sipad urgir šu teŋ ki itud mu us hulu' => not queen
# 'udunita u kir ur itud uzud kir ur udunita mašgal itud akiti sadug u mu e du' => queen
# 'udu u mašgal u uš sadug urgir sipad urgir šu teŋ ugula ki ŋiri dubsar itud mu lugal dim udu' => not queen
# 'sila sila mu.DU sila sila mu.DU en sila mu.DU zabardab maškim gud niga u uš emuhaldim ud ziga itud mu en maš pad' => not queen
# 'udu mašgal udu mašgal šagia maškim šag mu.DU ud ki ŋiri dubsar itud mu du' => not queen
# 'šugid emuhaldim mu gardu sukkal maškim itud ud zal ki itud mu en huŋ' => not queen
# 'u uzud šugid emuhaldim mu gardu maškim šag ašag ud ki ŋiri dubsar itud mu en huŋ' => not queen
# 'durah munus sila sila sila sila sila ud mu.DU dab itud mu huŋ' => not queen
# 'sila ud ki dab itud mu huŋ' => not queen
# 'sila mu.DU zabardab maškim ud ki itud mu u mada ud hulu' => not queen
# 'mašda ekišibak mu.DU ud ki itud mu u mada ud hulu' => not queen
# 'mašgal babbar ud ki dab ŋiri itud mu huŋ udu' => not queen
# 'sila ga kir ga maš ga ašgar ga utuda ud ki itud mu lugal' => not queen
# 'udu niga udu aslum ud lal ki dab itud mu huŋ' => not queen
# 'udu niga sag us gukkal niga u niga udu uzud sila kir uš ud ki šu teŋ itud mu lugal' => not queen
# 'sila ga kir ga maš ga ašgar ga utuda ud šag dab itud mu lugal' => not queen
# 'gud udu u mu.DU kurušda dab itud mu us hulu' => queen
# 'udu sila maš sila ga maš ga uš ud ki šu teŋ mu dim' => not queen
# 'ab udu mašgal uzud sila ga uš ud ki šu teŋ itud mu huŋ gud udu' => not queen
# 'sila maš sila mu.DU dab itud mu hulu' => queen
# 'udu maš mu.DU dab itud mu hulu' => queen
# 'gud niga šag ud ki dab itud mu huŋ gud' => not queen
# 'udu niga sadug kag eš udu niga sadug kag ŋipar udu u itud ud zal ziga šag itud mu us hulu' => queen
# 'gud niŋgur ugu de itud ud zal gud de dug mu lugal pad igi igi damgar igi mu en maš pad dumu' => not queen
# 'suhub eban ki ensik erin agaʾus lugal šu teŋ nubanda šag ŋiri mu en huŋ' => not queen
# 'gud ab gud amar ga ab sila sila amar mašda udu mašgal sila amar mašda sila en sila amar mašda sila muhaldim sila amar mašda mu.DU itud mu u hulu ud' => not queen
# 'gud udu mu agaʾus ud gud udu udu uš lugal du ma ŋar ud ki itud mu lugal lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'zidgu sadug ki itud mu e du' => not queen
# 'irsaŋ itud ud zal irsaŋ itud ud zal uš egal ziga mu us e du' => queen
# 'gud ab emuhaldim ud gud ab ud gud ab ud gud ab ud gud ab ud gud ud gud ab ud ab ud gud ab ud lal gud ab ud gud ab ud gud ud gud ab ud gud ud gud ab ud gud ab ud gud ab ud gud ab ud gud ud emuhaldim šuniŋin gud šuniŋin ab ki itud akiti mu lugal hulu gud ab hi' => not queen
# 'udunita mašgal kišib udunita kišib dumu ki šu teŋ itud itud mu dumu' => not queen
# 'udu maš hi ki itud itud itud mu lugal mada hulu lugal kalag lugal lugal an anubda limmu dubsar dumu arad' => not queen
# 'udu niga udu sadug kud bala ensik ki ud lal mu.DU dab itud mu en huŋ' => not queen
# 'sila sila mu.DU en sila udunita lu kiŋgia lu mu u hulu' => not queen
# 'udu maš sila udu maš sila sila sila sila šag e sila sila sila sila a sila maškim ud šuniŋin ab mu udu šuniŋin lal udu maš bala ensik ki itud mu lugal' => not queen
# 'udu aslum niga us udu niga us sila mašgal niga us sila udu u sila udu niga sag udu aslum niga sag udu aslum niga sag us udu aslum niga us ud mu.DU lugal dab ŋiri dubsar itud mu us lugal hulu udu dubsar dumu' => not queen
# 'kir gub udu udu mašgal ŋiri uzud mašgal ŋiri udu mašgal ŋiri mašgal mašgal ŋiri u u kir gub udu udu ŋiri uzud lal mašgal ŋiri udu ŋiri mašgal mašgal ŋiri šuniŋin udu udu šuniŋin u u šuniŋin kir gub mašgal šuniŋin mašgal šuniŋin uzud ki dab itud akiti mu en huŋ' => not queen
# 'gukkal ŋešdu u gukkal lal udu hursaŋ u hursaŋ mu.DU lugal šabra dab ki itud mu en huŋ' => not queen
# 'gukkal gukkal ŋešdu gin gukkal gukkal il udu MAR.TU sila niga sila sila ensik sila sila niga šabra sila sila dubsar sila udu aslum ŋešdu gukkal maš sila sila šag ud mu.DU dab itud akiti mu dim' => not queen
# 'udu niga sag us udu niga us udu niga us udu u zig ama ud ŋen maškim a ud ki ŋiri šarrabdu itud mu lugal dim' => not queen
# 'gud lal udu lal maš situm mu us hulu' => not queen
# 'udu udu maškim itud ud lal zal ziga ki itud mu hulu' => not queen
# 'udu sila sila ga uš ud ki šu teŋ itud mu us hulu' => not queen
# 'gud niga amar kud mu niga siškur gula e itud ud zal ki dab itud mu u hulu' => not queen
# 'gud niga amar gud udu niga gukkal niga sila kir niga mašgal niga uzud niga ašgar udu mašgal sila uš ud ki šu teŋ itud mu us u hulu' => not queen
# 'ud lal uš ki šu teŋ itud mu lugal hulu' => not queen
# 'udu niga sila mašgal uš ud ki šu teŋ itud mu lugal guza dim' => not queen
# 'sa gi še nubanda ŋiri' => not queen
# 'sa gi sadug ki itud mu us bad du' => not queen
# 'sa gi' => not queen
# 'gu gi' => not queen
# 'sa gi ugula' => not queen
# 'ŋuruš ud ma gid ŋuruš nagar ud ki kišib mu hulu' => not queen
# 'ŋuruš ud ki guzala šu teŋ mu ara lal hulu' => not queen
# 'ŋuruš ud kisur ašag gub ugula kišib mu lugal' => not queen
# 'ŋuruš ud ašag manu še ziga ŋiri mu us hulu' => not queen
# 'ŋuruš dubsar ud gub ugula dab mu hulu' => not queen
# 'še lugal kaš kišib bisaŋdubak' => not queen
# 'še gur ziz gur šu teŋ' => not queen
# 'ziz gur sisa kib gur ki šu teŋ' => not queen
# 'še gur lugal ziz gur kišib arad ki še šuniŋin še gur mu.DU itud mu hulu' => not queen
# 'sila še gur mu.DU u mu hulu' => not queen
# 'še gur sadug itud ki kišib mu hulu' => not queen
# 'šuʾi malah idu nukirik nukirik agaʾus' => not queen
# 'ŋiri še gur kišib' => not queen
# 'še gur lugal šag gur kišib gur kišib' => not queen
# 'še gur lugal maš tuku mu ki damgar šu teŋ' => not queen
# 'sila še gur lugal a ma huŋ še gur esir še gur miriza ki šu teŋ mu bad du' => not queen
# 'še gur a ma huŋ id e ki šabra šu teŋ mu hulu' => not queen
# 'dabin gu sag kišib' => not queen
# 'kaš du gur lugal ziga ki' => not queen
# 'kaš sag sadug lal sila du dirig sag ud ki' => not queen
# 'du kag sag duga ud lal lal sila du dirig sag du dirig sag dug ud du sadug sag du dirig ud ud tuku ki kišib mu hulu' => not queen
# 'zidgu lugal zid kaš dida sag kaš dida du kud kunzida šaggal maš mu' => not queen
# 'sila zulum kaš dida du kaš dida sag sila kaš du dabin sila inun sila gaʾar sila inun dug sila dug sila bappir dug sila eša zid zidgu du sila inun sila gaʾar sila bappir dug siškur šag e zid gur eša zid mu lugal' => not queen
# 'ara ma gur še gu mana mangaga sila dabin gur kaš du gur sila eša sila zidsig ki šu teŋ mu hulu' => not queen
# 'sila babbar ŋi šelu gur gugal gur sila ki lu tir mu us ara hulu' => not queen
# 'zulum gur lugal šu teŋ kišib mu e du' => not queen
# 'udu maš kišib udu maš kišib ki dab mu us ara hulu' => not queen
# 'u bar sug udunita sila dumu abba dab dab ki kaš kag kešed mu hulu' => not queen
# 'udunita uš ki šu teŋ mu bad du' => not queen
# 'šu gud anše deg gud ŋiri unud u sipad anše ki kaš kišib mu hulu' => not queen
# 'gud niga sadug gud niga niŋ ŋeš tag lugal ara ŋiri gud niga sadug ki kaš mu lugal hulu' => not queen
# 'ab ga gud ga udu sila maš nesaŋ udu mu mašda šeŋbar niŋdab ki kaš mu hulu' => not queen
# 'udu u uzud mašgal maš sadug babbar ki dab mu lugal hulu' => not queen
# 'maš maš magur ŋiri kaš kaš dab mu kug guza dim' => not queen

# %%
# Percentange of Queen transactions
print(len([i for i in uni_and_bigram_prediction if i == "queen"])/len(uni_and_bigram_prediction))
# Out:
# 0.05543373989310676

# %%
queens = [data[i] for i in range(len(uni_and_bigram_prediction)) if uni_and_bigram_prediction[i] == "queen"]

# This code is outdated; it relied on a one-to-one mapping of lemmatized lines to PIDs, but there are some duplicate lines.

# with open("predicted_queen_v2.txt", 'w', encoding="utf8") as f:
#     for q in queens:
#         qu = mapping[q]
#         f.write(qu.p_id+"\n")
#         for line in qu.lemmas.keys():
#             f.write(line+"\n")
#         f.write("\n")

# %% [markdown]
# # Support Vector Machine
# Good for classification and when you have small datasets (<1000 points)

# %%
from sklearn.linear_model import SGDClassifier

text_clf = Pipeline([
        ('vect', CountVectorizer(analyzer="word", ngram_range=(1, 2),token_pattern='(?u)\\b\\w+\\b')),
        ('tfidf', TfidfTransformer()),
        ('clf', SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42))])

text_clf.fit(training_data, training_labels)
predicted = text_clf.predict(test_data)
np.mean(predicted == test_labels)
# Out:
# c:\python36\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.9297658862876255

# %%
predict_v2 = text_clf.predict(data)

# %%
print(len([i for i in predict_v2 if i == 'queen'])/len(predict_v2))
print(predict_v2[:10])
#print(all_labels)
# Out:
# 0.05961353981088118
# ['not queen' 'not queen' 'not queen' 'not queen' 'not queen' 'not queen'
#  'not queen' 'not queen' 'not queen' 'not queen']

# %% [markdown]
# ## SVM v2

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV

uni_bi_vect = CountVectorizer(analyzer = "word",
                              ngram_range = (1,2),
                              token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = uni_bi_vect.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
# Classifier
# gamma = how far single training example influence can reach
# low values = far influence
# high values = close influence
# c = tradeoff of misclassification vs simplicity
# low values = smooth decision surface
# high values = classify everything correctly

params = [{'kernel': ['rbf', 'linear'],
          'gamma': [1e-4, 1e-3, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 100],
          'C': [1, 5, 10, 50]}]
uni_bi_clf = GridSearchCV(svm.SVC(decision_function_shape='ovr'), params)
# uni_bi_clf = GridSearchCV(svm.SVC(decision_function_shape='ovr'), params, cv = 10)
uni_bi_clf.fit(X_train_tfidf, training_labels)
print("Best parameters found:")
print(uni_bi_clf.best_params_)
# Out:
# Best parameters found:
# {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
# Predict
X_new_counts = uni_bi_vect.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

uni_bi_pred = uni_bi_clf.predict(X_new_tfidf)

print("Accuracy: ", np.mean(uni_bi_pred == test_labels))
print("Recall: ", str(metrics.recall_score(test_labels, uni_bi_pred, ["queen", "not queen"], average="macro")))
print("Precision: ", str(metrics.precision_score(test_labels, uni_bi_pred, ["queen", "not queen"], average="macro")))
# Out:
# Accuracy:  0.9331103678929766
# Recall:  0.9383199079401611
# Precision:  0.9024725274725274

# %%
X_all_counts = uni_bi_vect.transform(data) 
X_all_tfidf = tfidf_transformer.transform(X_all_counts)
uni_bi_pred_v2 = uni_bi_clf.predict(X_all_tfidf)
print("Percentage Queens' Texts Predicted")
print(len([i for i in uni_bi_pred_v2 if i == 'queen'])/len(uni_bi_pred_v2))
# Out:
# Percentage Queens' Texts Predicted
# 0.0650267233109497

# %% [markdown]
# # SVM v3

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV

n1 = len(queen_data)
n2 = len(non_queen_data)
q_fold_size = [i * (n1 // 10) for i in range(10)] + [n1] 
nq_fold_size = [i * (n2 // 10) for i in range(10)] + [n2] 
all_pred = []
all_true_lab = []
acc = []
rec = []
prec = []

for i in range(10):
    print("Starting fold", i)
    q_start, q_end = q_fold_size[i], q_fold_size[i + 1]
    nq_start, nq_end = nq_fold_size[i], nq_fold_size[i + 1]
    test_data = queen_data[q_start:q_end] + non_queen_data[nq_start:nq_end]
    test_labels = queen_labels[q_start:q_end] + non_queen_labels[nq_start:nq_end]
    training_data = queen_data[:q_start] + queen_data[q_end:] + non_queen_data[:nq_start] + non_queen_data[nq_end:]
    training_labels = queen_labels[:q_start] + queen_labels[q_end:] + non_queen_labels[:nq_start] + non_queen_labels[nq_end:]

    uni_bi_vect = CountVectorizer(analyzer = "word",
                                  ngram_range = (1,2),
                                  token_pattern='(?u)\\b\\w+\\b')

    # Train
    X_train_counts = uni_bi_vect.fit_transform(training_data) # Learn the vocabulary dictionary and return term-document matrix.

    # Get TF-IDF
    tfidf_transformer = TfidfTransformer()
    X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

    # Classifier
    params = [{'kernel': ['rbf', 'linear'],
              'gamma': [1e-4, 1e-3, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 100],
              'C': [1, 5, 10, 50]}]
    uni_bi_clf = GridSearchCV(svm.SVC(decision_function_shape='ovr'), params)
    uni_bi_clf.fit(X_train_tfidf, training_labels)
    print("Best parameters found:")
    print(uni_bi_clf.best_params_)

    # Predict
    X_new_counts = uni_bi_vect.transform(test_data)
    X_new_tfidf = tfidf_transformer.transform(X_new_counts)
    all_pred.extend(uni_bi_clf.predict(X_new_tfidf))
    all_true_lab.extend(test_labels)
    
    uni_bi_pred = uni_bi_clf.predict(X_new_tfidf)

    acc.append(np.mean(uni_bi_pred == test_labels))
    rec.append(metrics.recall_score(test_labels, uni_bi_pred, ["queen", "not queen"], average="macro"))
    prec.append(metrics.precision_score(test_labels, uni_bi_pred, ["queen", "not queen"], average="macro"))

print("Total Accuracy: ", sum([1 if all_pred[i] == all_true_lab[i] else 0 for i in range(len(all_pred))])/len(all_pred))
print("Average Accuracy: ", sum(acc) / len(acc))
print("Total Recall: ", str(metrics.recall_score(all_true_lab, all_pred, ["queen", "not queen"], average="macro")))
print("Average Recall: ", sum(rec) / len(rec))
print("Total Precision: ", str(metrics.precision_score(all_true_lab, all_pred, ["queen", "not queen"], average="macro")))
print("Average Precision: ", sum(prec) / len(prec))
# Out:
# Starting fold 0
# Best parameters found:
# {'C': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Starting fold 1
# Best parameters found:
# {'C': 5, 'gamma': 0.0001, 'kernel': 'linear'}
# Starting fold 2
# Best parameters found:
# {'C': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Starting fold 3
# Best parameters found:
# {'C': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Starting fold 4
# Best parameters found:
# {'C': 5, 'gamma': 1, 'kernel': 'rbf'}
# Starting fold 5
# Best parameters found:
# {'C': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Starting fold 6
# Best parameters found:
# {'C': 10, 'gamma': 0.05, 'kernel': 'rbf'}
# Starting fold 7
# Best parameters found:
# {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# Starting fold 8
# Best parameters found:
# {'C': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Starting fold 9
# Best parameters found:
# {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# Total Accuracy:  0.9514563106796117
# Average Accuracy:  0.9517089018843405
# Total Recall:  0.9507715912779204
# Average Recall:  0.9510029186499775
# Total Precision:  0.9522447795480247
# Average Precision:  0.9537631113274667

# %%
uni_bi_vect = CountVectorizer(analyzer = "word",
                                  ngram_range = (1,2),
                                  token_pattern='(?u)\\b\\w+\\b')

# Train
X_train_counts = uni_bi_vect.fit_transform(all_data) # Learn the vocabulary dictionary and return term-document matrix.

# Get TF-IDF
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# Classifier
params = [{'kernel': ['rbf', 'linear'],
          'gamma': [1e-4, 1e-3, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 100],
          'C': [1, 5, 10, 50]}]
uni_bi_clf = GridSearchCV(svm.SVC(decision_function_shape='ovr'), params)
uni_bi_clf.fit(X_train_tfidf, all_labels)
print("Best parameters found:")
print(uni_bi_clf.best_params_)

X_all_counts = uni_bi_vect.transform(data) 
X_all_tfidf = tfidf_transformer.transform(X_all_counts)
uni_bi_pred_v2 = uni_bi_clf.predict(X_all_tfidf)
print("Percentage Queens' Texts Predicted")
print(len([i for i in uni_bi_pred_v2 if i == 'queen'])/len(uni_bi_pred_v2))
# Out:
# Best parameters found:
# {'C': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Percentage Queens' Texts Predicted
# 0.06838426750719474

# %%
queen_data = [x for x, y in zip(data, uni_bi_pred_v2) if y == "queen"]
non_queens = [x for x, y in zip(data, uni_bi_pred_v2) if y == "not queen"]
non_queen_labs = [x for x, y in zip(labs, uni_bi_pred_v2) if y == "not queen"]

# set([x for x in non_queens if non_queens.count(x) > 1])
len(non_queens)
# Out:
# 13596

# %%
mult = [x for x in non_queen_labs if len(x) > 1]
len(mult)
# Out:
# 2871

# %%
len([x for x, y in zip(non_queens, non_queen_labs) if len(y) > 1 and "dead_animal" not in y])
# Out:
# 560

# %%
dead_animal_archive = []
domesticated_animal_archive = []
wild_animal_archive = []
leather_object_archive = []
precious_object_archive = []
wool_archive = []
Unknown_archive = []

counter = 0
for x, y in zip(non_queens, non_queen_labs):
    lab = max(y, key = lambda x: len(y[x]))
    if lab == "Unknown":
        print(y)
    if "animal" in lab and "dead_animal" in y.keys():
        dead_animal_archive.append(x)
    else:
        exec(lab + "_archive.append(x)")
    counter += 1
      
print("Dead Animals archive size:", len(dead_animal_archive))
print("Domesticated Animals archive size:", len(domesticated_animal_archive))
print("Leather Objects archive size:", len(leather_object_archive))
print("Precious Objects archive size:", len(precious_object_archive))
print("Wild Animals archive size:", len(wild_animal_archive))
print("Wool archive size:", len(wool_archive))
print("Unknown archive size:", len(Unknown_archive))
# Out:
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) lulim-nita₂', '#lem: n; X', '2. šu-gid₂ e₂-muhaldim', '#lem: šugid[~animal]; emuhaldim[kitchen]', '3. mu gar₃-du-ne-še₃', '#lem: mu[year]; gardu[soldier]', '4. dingir-dan sukkal maškim', '#lem: PN; sukkal[secretary]; maškim[administrator]', '5. iti u₄ 1(u) 6(diš) ba-zal', '#lem: itud[moon]; ud[sun]; n; n; zal[pass]', '6. ki lu₂-dingir-ra-ta', '#lem: ki[place]; PN', '@reverse', '1. ba-zi', '#lem: PN', '$ 1 line blank', '2. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '3. mu en eridu{ki} ba-hun', '#lem: mu[year]; en[priest]; GN; huŋ[hire]', '@left', '1. 1(diš)', '#lem: n']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(ban₂) zi₃-gu', '#lem: n; zidgu[flour]', '2. sa₂-du₁₁-še₃', '#lem: sadug[offerings]', '3. ki lu₂-du₁₀-ga-mu#-ta#', '#lem: ki[place]; PN', '4. ba-zi', '#lem: PN', '@reverse', '1. iti ezem-an-na', '#lem: itud[moon]; MN', '2. mu e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; e[house]; TN; GN; du[build]', '@left', '1. [...]', '#lem: AN']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) 3(u) sa gi', '#lem: n; n; sa[roast]; gi[reed]', '2. 2(ban₂) še ad-nu-ha', '#lem: n; še[barley]; X', '3. nu-banda₃ nir-i₃-da-gal₂', '#lem: nubanda[overseer]; PN', '@reverse', '1. giri₃ ur-mes', '#lem: ŋiri[foot]; PN', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 4(geš₂) 2(u) 4(diš) sa gi', '#lem: n; n; n; sa[roast]; gi[reed]', '2. sa₂-du₁₁ ur-{d}ba-ba₆', '#lem: sadug[offerings]; PN', '3. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '@reverse', '1. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '2. mu us₂-sa bad₃ ba-du₃', '#lem: mu[year]; us[follow]; bad[wall]; du[build]', '@seal 1', '$seal illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '@reverse', '$ blank space', '# seal impression', '@seal 1', '$ illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) gu₂ gi', '#lem: n; gu[pulse]; gi[reed]', '2. [ṣe]-li#-{d}iškur', '#lem: X', '@reverse', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '2. ur-{geš}gigir ugula', '#lem: PN; ugula[overseer]', '@reverse', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) guruš', '#lem: n; ŋuruš[male]', '2. u₄ 1(geš₂) 3(u)-še₃', '#lem: ud[sun]; n; n', '3. ma₂-da-ga-aš ma₂ gid₂-da', '#lem: X; ma[ship]; gid[long]', '4. 1(diš) guruš nagar', '#lem: n; ŋuruš[male]; nagar[carpenter]', '5. u₄ 2(u) 5(diš) [...-še₃]', '#lem: ud[sun]; n; n; DN', '6. [...]', '#lem: AN', '@reverse', '1. ki lu₂-[...]', '#lem: ki[place]; PN', '2. kišib₃ lugal-[...]', '#lem: kišib[seal]; PN', '3. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(geš₂) 5(u) 5(diš) guruš u₄ 1(diš)-še₃', '#lem: n; n; n; ŋuruš[male]; ud[sun]; n', '2. ki ba-saga gu-za-la₂-ta', '#lem: ki[place]; X; guzala[official]', '3. lu₂-sa₆-i₃-zu', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. mu si-mu-ru-um{ki} lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(geš₂) 4(u) guruš u₄ 1(diš)-še₃', '#lem: n; n; ŋuruš[male]; ud[sun]; n', '2. ki-su₇ a-ša₃ muru₁₃? gub-ba', '#lem: kisur[locus]; ašag[field]; FN; gub[stand]', '3. ugula ur-e₂-nun', '#lem: ugula[overseer]; PN', '@reverse', '1. kišib₃ da-a-gi₄', '#lem: kišib[seal]; PN', '2. mu {d}amar-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 8(diš) guruš u₄ 1(diš)-še₃', '#lem: n; ŋuruš[male]; ud[sun]; n', '2. a-ša₃ {geš}ma-nu-ta', '#lem: ašag[field]; manu[wood]', '3. še zi-ga', '#lem: še[barley]; ziga[expenditure]', '4. giri₃ nigar{gar}-ki-du₁₀', '#lem: ŋiri[foot]; PN', '@reverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. mu us₂-sa an-ša-an{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) guruš dub-sar', '#lem: n; ŋuruš[male]; dubsar[scribe]', '2. u₄ 4(u) 5(diš)-še₃', '#lem: ud[sun]; n; n', '3. uri₅{ki}-ma gub-ba', '#lem: GN; gub[stand]', '4. ugula a-a-gi-na', '#lem: ugula[overseer]; PN', '@reverse', '1. la-ni-mu i₃-dab₅', '#lem: PN; dab[seize]', '$ blank space', '# seal impression', '2. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(ban₂) še lugal', '#lem: n; še[barley]; lugal[king]', '2. [...] kas₄', '#lem: AN; kaš[runner]', '3. kišib₃ ur-{d}šara₂ ša₁₃-dub-ba', '#lem: kišib[seal]; PN; bisaŋdubak[archivist]', '@reverse', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) še gur 1(barig)-ta', '#lem: n; še[barley]; gur[unit]; n', '2. 3(aš) 1(barig) ziz₂ gur', '#lem: n; n; ziz[emmer]; gur[unit]', '3. ur-{d}a-šar₂', '#lem: PN', '@reverse', '1. ARAD₂-e₂-ninnu', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [x] 4(aš) ziz₂ gur si-sa₂-ta', '#lem: u; n; ziz[emmer]; gur[unit]; sisa[fair]', '2. 3(aš) gig gur', '#lem: n; kib[wheat]; gur[unit]', '3. ki lu₂-{d}er₃-ra-ta', '#lem: ki[place]; PN', '@reverse', '1. ha-lu₅-lu₅', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) 4(barig) še gur lugal', '#lem: n; n; še[barley]; gur[unit]; lugal[king]', '2. 2(aš) 2(barig) ziz₂ gur', '#lem: n; n; ziz[emmer]; gur[unit]', '3. kišib₃ ARAD₂', '#lem: kišib[seal]; arad[slave]', '4. ki ur-{d}suen-ta', '#lem: ki[place]; PN', '5. 1(barig) še lugal-gaba', '#lem: n; še[barley]; PN', '6. šu+nigin 4(aš) 2(barig) še gur', '#lem: šuniŋin[total]; n; n; še[barley]; gur[unit]', '@left', '1. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '@reverse', '1. ur-{d}[...]', '#lem: PN', '2. iti [...]', '#lem: itud[moon]; AN', '3. mu [...]{ki} ba-hul', '#lem: mu[year]; u; hulu[bad]', '']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(aš) 1(barig) 3(ban₂) 2(diš) sila₃ še gur', '#lem: n; n; n; n; sila[unit]; še[barley]; gur[unit]', '2. [mu]-kuₓ(DU) {d}šara₂', '#lem: mu.DU[delivery]; TN', '3. [...] a-pi₄-sal₄{ki}', '#lem: AN; GN', '4. [u₃ muš]-bi-an{ki}', '#lem: u[and]; GN', '5. [gu₂]-de₃-na-ta', '#lem: GN', '$ rest broken', '@reverse', '$ blank space', '1. mu [...]{ki} ba-hul', '#lem: mu[year]; u; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 2(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '2. sa₂-du₁₁ {d}šara₂', '#lem: sadug[offerings]; TN', '3. iti 1(u) 2(diš)-kam', '#lem: itud[moon]; n; n', '4. ki gu-du-du-ta', '#lem: ki[place]; PN', '5. kišib₃ ka-ku₃', '#lem: kišib[seal]; PN', '@reverse', '1. mu si-ma-num₂{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@seal 1', '$ (legend broken)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ beginning broken', '1ʾ. [...] da-[...]', '#lem: AN; PN', '2ʾ. 1(barig) 3(ban₂) er₁₁-ra-a', '#lem: n; n; PN', '3ʾ. 1(barig) 3(ban₂) a-ba-ki-ni', '#lem: n; n; PN', '4ʾ. 1(barig) 3(ban₂) lugal-ezem', '#lem: n; n; PN', '5ʾ. 1(barig) 3(ban₂) al-lu', '#lem: n; n; PN', '6ʾ. 1(barig) 3(ban₂) lu₂-{d}nin-šubur', '#lem: n; n; PN', '7ʾ. kikken₂ sa₂-du₁₁ [...]', '#lem: kinkin[miller]; sadug[offerings]; AN', '8ʾ. 1(barig) a-gu-gu# [...]', '#lem: n; PN; AN', '@reverse', '1. 1(barig) ur-{d}ma-mi', '#lem: n; PN', '2. 1(barig) ur-gu₂?-de₃?-na', '#lem: n; PN', '3. 2(barig) ur-{d}er₃-ra šu-i', '#lem: n; PN; šuʾi[barber]', '4. 1(barig) 3(ban₂) ša₃-ad-da ma₂-lah₅', '#lem: n; n; PN; malah[sailor]', '5. 5(ban₂) ur-saga i₃-du₈', '#lem: n; X; idu[doorkeeper]', '6. 1(barig) 1(ban₂) ad-da-mu nu-{geš}kiri₆', '#lem: n; n; PN; nukirik[gardener]', '7. 1(barig) 3(ban₂) pa₃-da nu-{geš}kiri₆', '#lem: n; n; PN; nukirik[gardener]', '8. 2(barig) lu₂-saga aga₃-us₂', '#lem: n; X; agaʾus[soldier]', '9. 3(ban₂) ur-{d}gilgamesₓ(|BIL₃.GA.MES|) [...]', '#lem: n; PN; AN', '10. 1(barig) 5(ban₂) 3(diš) lugal-a₂-zi-da [...]', '#lem: n; n; n; PN; AN', '$ rest broken']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ beginning broken', '1ʾ. [...] numun', '#lem: AN; numun[seed]', '2ʾ. ur-{d}geštin-an-ka', '#lem: PN', '3ʾ. [...] 1(u) 8(aš) x x še gur', '#lem: AN; n; n; u; u; še[barley]; gur[unit]', '4ʾ. ur-{d}nin-šubur nu-banda₃', '#lem: PN; nubanda[overseer]', '5ʾ. kišib₃ lu₂-eb-gal', '#lem: kišib[seal]; PN', '@reverse', '1. giri₃ lugal-mas-su', '#lem: ŋiri[foot]; PN', '2. 2(geš₂) 1(u) 4(aš) še gur', '#lem: n; n; n; še[barley]; gur[unit]', '3. ur-{geš}gigir nu-banda₃-gu₄', '#lem: PN; PN', '4. kišib₃ ur-{d}en-lil₂-la₂', '#lem: kišib[seal]; PN', '5. [...] ur-ge₆-par₄', '#lem: AN; PN', '$ rest broken']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. x x x še gur lugal', '#lem: u; u; u; še[barley]; gur[unit]; lugal[king]', '2. sag-nig₂-gur₁₁-ra-kam', '#lem: X', '3. ša₃-bi-ta', '#lem: šag[heart]', '4. 8(aš) gur kišib₃ ur-{d}suen', '#lem: n; gur[unit]; kišib[seal]; PN', '5. 2(aš) 1(barig) 5(ban₂) gur kišib₃ a-du-mu', '#lem: n; n; n; gur[unit]; kišib[seal]; PN', '@reverse', '$ broken']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [n] še gur lugal', '#lem: n; še[barley]; gur[unit]; lugal[king]', '2. maš nu-tuku', '#lem: maš[interest]; tuku[acquire]', '3. mu sag-{d}nanna-zu-še₃', '#lem: mu[year]; PN', '4. ki ur-e₁₁-e dam-gar₃-ta', '#lem: ki[place]; PN; damgar[merchant]', '# in irregular sequence', '@reverse', '1. ur-ba-gara₂', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 9(geš₂) 5(u) 4(barig) 2(ban₂) 6(diš) sila₃ še gur lugal', '#lem: n; n; n; n; n; sila[unit]; še[barley]; gur[unit]; lugal[king]', '3. a₂ ma₂ hun-ga₂', '#lem: a[arm]; ma[ship]; huŋ[hire]', '4. 2(u) 7(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '5. esir₂-a sa₁₀-a', '#lem: esir[bitumen]; X', '6. 1(u) 2(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '7. {geš}mi-ri₂-za', '#lem: miriza[plank]', '@reverse', '1. sa₁₀-a', '#lem: X', '2. ki ARAD₂-ta', '#lem: ki[place]; PN', '3. lugal-e-ba-<an>-sa₆', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '5. mu bad₃ ba-du₃', '#lem: mu[year]; bad[wall]; du[build]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 3(aš) še gur', '#lem: n; n; še[barley]; gur[unit]', '2. a₂ ma₂ hun-ga₂', '#lem: a[arm]; ma[ship]; huŋ[hire]', '3. i₇ e₃-ka', '#lem: id[river]; e[chaff]', '4. ki šabra bu₃-u₂-du-ta', '#lem: ki[place]; šabra[administrator]; PN', '@reverse', '1. lugal-e-ba-an-sa₆', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu ša-aš-ru{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(barig) 3(ban₂) dabin gu saga', '#lem: n; n; dabin[semolina]; gu[cord]; sag[rare]', '2. kišib₃ šeš-kal-la-ta zi-zi-dam', '#lem: kišib[seal]; PN; PN', '@reverse']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(aš) 1(barig) 4(ban₂) kaš du gur lugal', '#lem: n; n; n; kaš[beer]; du[go]; gur[unit]; lugal[king]', '2. zi-ga nin₉-tur-tur-ra', '#lem: ziga[expenditure]; PN', '3. ki si-NE-e-ta', '#lem: ki[place]; PN', '@reverse', '$ blank']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...] 6(aš) <kaš> saga sa₂-du₁₁', '#lem: AN; n; kaš[beer]; sag[rare]; sadug[offerings]', '2. 8(aš) la₂ 1(diš) sila₃ du diri', '#lem: n; lal[small]; n; sila[unit]; du[go]; dirig[exceed]', '3. 3(aš) saga elam-še₃', '#lem: n; sag[rare]; GN', '4. u₄ 1(u) 5(diš)-kam', '#lem: ud[sun]; n; n', '@reverse', '1. ki [...]-la-ta', '#lem: ki[place]; PN', '2. [...]-kal-la', '#lem: u', '3. [...]', '#lem: AN']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]-ka', '#lem: PN', '2. 6(aš)#? du ka e₂-sanga?', '#lem: n; du[go]; kag[mouth]; X', '3. o o o saga elam-še₃ du₁₁-ga', '#lem: u; u; u; sag[rare]; GN; duga[affliction]', '4. u₄ 1(u) la₂ 1(diš@t)-kam', '#lem: ud[sun]; n; lal[small]; n', '5. 4(aš) la₂ 4(diš) sila₃ du diri', '#lem: n; lal[small]; n; sila[unit]; du[go]; dirig[exceed]', '6. o o o saga du diri', '#lem: u; u; u; sag[rare]; du[go]; dirig[exceed]', '7. o o o saga elam-še₃ du₁₁?', '#lem: u; u; u; sag[rare]; GN; dug[pot]', '8. u₄ 1(u)-kam', '#lem: ud[sun]; n', '@reverse', '1. 1(aš) du sa₂-du₁₁', '#lem: n; du[go]; sadug[offerings]', '2. 2(aš) saga 7(aš) du diri', '#lem: n; sag[rare]; n; du[go]; dirig[exceed]', '3. u₄ 1(u) 1(diš)-kam', '#lem: ud[sun]; n; n', '4. u₄ 1(u) 2(diš) nu-tuku', '#lem: ud[sun]; n; n; tuku[acquire]', '5.  ki# {d}šara₂-a-zi-ta', '#lem: ki[place]; PN', '6. kišib₃ a-kal-la', '#lem: kišib[seal]; PN', '7. mu# lu-lu-bu-um{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '8. [...]', '#lem: AN', '@seal 1', '$(not given)']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(ban₂) zi₃-gu [...] lugal', '#lem: n; zidgu[flour]; AN; lugal[king]', '2. 1(ban₂) zi₃ [...]', '#lem: n; zid[flour]; AN', '3. 1(barig) kaš dida saga', '#lem: n; kaš[beer]; dida[wort]; sag[rare]', '4. 1(barig) kaš dida du', '#lem: n; kaš[beer]; dida[wort]; du[go]', '5. 1(u) 5(diš) ku₆ kun-zi-[da]', '#lem: n; n; kud[fish]; kunzida[weir]', '@reverse', '1. 1(ban₂) [...]', '#lem: n; AN', '2. [...]', '#lem: AN', '3. [...]', '#lem: AN', '4. ša₃-gal [...] maš [...] mu', '#lem: šaggal[food]; AN; maš[interest]; AN; mu[year]', '5. [...]-še₃', '#lem: DN', '6. [...]', '#lem: AN', '7. [...]', '#lem: AN']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(ban₂) 5(diš) sila₃ zu₂-lum', '#lem: n; n; sila[unit]; zulum[date]', '2. 1(barig) kaš dida du', '#lem: n; kaš[beer]; dida[wort]; du[go]', '3. 1(barig) kaš dida saga 1(ban₂) 5(diš) sila₃ <kaš du>', '#lem: n; kaš[beer]; dida[wort]; sag[rare]; n; n; sila[unit]; kaš[beer]; du[go]', '4. 1(barig) 3(ban₂) dabin', '#lem: n; n; dabin[semolina]', '5. 2(diš) sila₃ i₃-nun', '#lem: n; sila[unit]; inun[ghee]', '6. 2(diš) sila₃ ga-ar₃', '#lem: n; sila[unit]; gaʾar[cheese]', '7. x sila₃ i₃-nun du₁₀-ga', '#lem: u; sila[unit]; inun[ghee]; dug[good]', '8. x sila₃ i₃-gu du₁₀-ga', '#lem: u; sila[unit]; X; dug[good]', '9. [x] sila₃ bappir du₁₀-ga', '#lem: u; sila[unit]; bappir[~beer]; dug[good]', '$ rest broken', '@reverse', '$ beginning broken', '1ʾ. [x sila₃] eša', '#lem: u; sila[unit]; eša[flour]', '2ʾ. [...] zi₃ dub-dub', '#lem: AN; zid[flour]; dubdub[~flour]', '3ʾ. [...] 2(ban₂) zi₃-gu du', '#lem: AN; n; zidgu[flour]; du[go]', '4ʾ. 1(diš) sila₃ i₃-nun', '#lem: n; sila[unit]; inun[ghee]', '5ʾ. 1(diš) sila₃ ga-ar₃', '#lem: n; sila[unit]; gaʾar[cheese]', '6ʾ. 1(diš) sila₃ bappir du₁₀-ga', '#lem: n; sila[unit]; bappir[~beer]; dug[good]', '7ʾ. siskur₂ ša₃ e₂-a', '#lem: siškur[prayer]; šag[heart]; e[house]', '8ʾ. [...] 3(ban₂) zi₃ gur', '#lem: AN; n; zid[flour]; gur[unit]', '9ʾ. [...] 3(ban₂) eša', '#lem: AN; n; eša[flour]', '10ʾ. [...] 3(ban₂) zi₃ dub-dub', '#lem: AN; n; zid[flour]; dubdub[~flour]', '@left', '1. [mu {d}x]-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 8(diš) {geš}a-ra ma₂ 4(u) gur', '#lem: n; ara[~boat]; ma[ship]; n; gur[unit]', '2. še-ta sa₁₀-a', '#lem: še[barley]; X', '3. 3(u) 7(aš) gu₂ 4(u) 2(diš) ma-na mangaga', '#lem: n; n; gu[pulse]; n; n; mana[unit]; mangaga[fibers]', '4. 3(aš) 3(barig) 6(diš) sila₃ dabin gur', '#lem: n; n; n; sila[unit]; dabin[semolina]; gur[unit]', '5. 6(aš) 4(barig) 1(ban₂) kaš du gur', '#lem: n; n; n; kaš[beer]; du[go]; gur[unit]', '6. 2(ban₂) 8(diš) sila₃ eša', '#lem: n; n; sila[unit]; eša[flour]', '7. 1(ban₂) 5(diš) sila₃ zi₃-sig₁₅', '#lem: n; n; sila[unit]; zidsig[flour]', '@reverse', '1. ki ARAD₂-ta', '#lem: ki[place]; PN', '2. lu₂-sa₆-i₃-zu', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '$ blank space', '4. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(barig) 3(ban₂) 5(diš) sila₃ {u₂}gamun₂ babbar', '#lem: n; n; n; sila[unit]; X; babbar[white]', '2. 1(ban₂) {u₂}gamun₂ ge₆', '#lem: n; X; ŋi[night]', '3. 2(aš) 1(barig) še-lu₂ gur', '#lem: n; n; šelu[coriander]; gur[unit]', '4. 1(aš) gu₂-gal gur', '#lem: n; gugal[inspector]; gur[unit]', '5. 8(diš) sila₃ gu₂-tur', '#lem: n; sila[unit]; gutur[lentil?]', '6. ki lu₂-{d}šara₂ lu₂ tir-ta', '#lem: ki[place]; PN; lu[person]; tir[forest]', '@reverse', '$ blank space', '1. mu us₂-sa a-ra₂ 3(diš@t)-kam si-mu-ru-um{ki} ba-hul', '#lem: mu[year]; us[follow]; ara[times]; n; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 3(aš) zu₂-lum gur lugal', '#lem: n; zulum[date]; gur[unit]; lugal[king]', '2. lu₂-bulug₃-ga₂', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '4. kišib₃ a-kal-la', '#lem: kišib[seal]; PN', '@reverse', '1. mu e₂ puzur₄-da-gan ba-du₃', '#lem: mu[year]; e[house]; X; du[build]', '$ blank space']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@object tag', '@obverse', '1. pisan-dub-ba', '#lem: bisaŋdubak[archivist]', '2. sag-nig₂-gur₁₁-ra', '#lem: X', '3. ša₃-bi su-ga', '#lem: šag[heart]; sug[replace]', '4. kas₄ šuš₃', '#lem: kaš[runner]; kuš[official]', '5. i₃-gal₂', '#lem: ŋal[be]', '@reverse', '$blank space', '']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) 2/3(diš) ma-na 8(diš) gin₂ igi 4(diš)-gal₂ ku₃', '#lem: n; šanabi[two-thirds]; mana[unit]; n; giŋ[unit]; igi[face]; n; kug[metal]', '2. ki da-da-ga-ta', '#lem: ki[place]; PN', '3. ur-{d}dumu-zi-da', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '$ broken']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. igi 3(diš)-gal₂ 5(diš) še ku₃', '#lem: igi[face]; n; n; še[barley]; kug[metal]', '2. ki {d}šara₂-za-me-ta', '#lem: ki[place]; PN', '3. da-da-ga', '#lem: PN', '@reverse', '1. mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) gin₂ ku₃', '#lem: n; giŋ[unit]; kug[metal]', '2. la₂-ia₃ su-ga', '#lem: laʾu[arrears]; sug[replace]', '3. ki ur-{d}en-ki lunga-ta', '#lem: ki[place]; PN; lungak[brewer]', '@reverse', '1. da-da-ga', '#lem: PN', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu si-mu-ru-um{ki} lu-lu-bu a-ra₂ 1(u) la₂ 1(diš@t)-kam-aš ba-hul', '#lem: mu[year]; GN; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) gin₂ ku₃', '#lem: n; giŋ[unit]; kug[metal]', '2. šu-nir gu₂-<de₃-na>-še₃', '#lem: šunir[emblem]; ON', '3. mu us₂-sa a-ra₂ 1(u) la₂ 1(diš)-kam si-mu-ru-um{ki} ba-hul', '#lem: mu[year]; us[follow]; ara[times]; n; lal[small]; n; GN; hulu[bad]', '@reverse', '$blank space']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(gešʾu) 8(geš₂) 3(u) sa gu', '#lem: n; n; n; sa[roast]; gu[cord]', '2. ki ensi₂-ta', '#lem: ki[place]; ensik[ruler]', '3. da-da-ga šu ba-ti', '#lem: PN; šu[hand]; teŋ[approach]', '@reverse', '1. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [n] 8(aš) gu₂ 2(u) 8(diš) 5/6(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; n; n; mana[unit]; X', '2. mu an-ša-an{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '3. [n] 2(aš) gu₂ 3(u) 4(diš) ma-na siki [...]', '#lem: n; n; gu[pulse]; n; n; mana[unit]; siki[hair]; AN', '4. 1(u) 8(aš) gu₂ 5(u) la₂ 2/3(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; lal[small]; šanabi[two-thirds]; mana[unit]; X', '5. a-ra₂ 1(diš)-kam', '#lem: ara[times]; n', '6. 7(aš) gu₂ 5(u) la₂ 1(diš@t) ma-na [siki ...]', '#lem: n; gu[pulse]; n; lal[small]; n; mana[unit]; siki[hair]; AN', '7. a-ra₂ 2(diš)-kam', '#lem: ara[times]; n', '8. ki ur-e₁₁-e-ta', '#lem: ki[place]; PN', '9. 3(aš) gu₂ 1(u) 3(diš) 2/3(diš) ma-na [siki ...]', '#lem: n; gu[pulse]; n; n; šanabi[two-thirds]; mana[unit]; siki[hair]; AN', '10. a-pi₄-sal₄{ki}-ta', '#lem: GN', '11. [...] 8(diš) [...]', '#lem: AN; n; AN', '@reverse', '1. [...]', '#lem: AN', '2. ki ur-{d}šara₂ [...]', '#lem: ki[place]; PN; AN', '$ blank space', '3. mu us₂-sa an-[ša-an{ki} ba-hul]', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '$ blank space']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 9(aš) gu₂ 1(u) 4(diš) ma-na siki-gi', '#lem: n; gu[pulse]; n; n; mana[unit]; X', '2. 1(aš) gu₂ 2(u) 7(diš) ma-na siki gir₂-gul', '#lem: n; gu[pulse]; n; n; mana[unit]; siki[hair]; ŋirgul[~wool]', '3. siki udu-lah₅', '#lem: siki[hair]; X', '4. giri₃ kas₄', '#lem: ŋiri[foot]; kaš[runner]', '5. kas₄ i₃-dab₅', '#lem: kaš[runner]; dab[seize]', '@reverse', '1. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(u) 5(aš) gu₂ 3(u) 5(diš) 2/3(diš) ma-na siki-gi', '#lem: n; n; gu[pulse]; n; n; šanabi[two-thirds]; mana[unit]; X', '2. ku₃-bi 2(diš) 1/2(diš) ma-na 3(diš) 1/2(diš) gin₂ 1(u) 2(diš) še', '#lem: kug[metal]; n; n; mana[unit]; n; n; giŋ[unit]; n; n; še[barley]', '3. ki ensi₂-ta', '#lem: ki[place]; ensik[ruler]', '@reverse', '1. ur#?-dumu#-zi-da#', '#lem: X', '2. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '3. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '$ blank space']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(aš) gu₂ siki-gi', '#lem: n; gu[pulse]; X', '2. siki udu-lah₅', '#lem: siki[hair]; X', '3. giri₃ kas₄ šuš₃', '#lem: ŋiri[foot]; kaš[runner]; kuš[official]', '4. mu ku₃ gu-za {d}en-lil₂-la₂ ba-dim₂', '#lem: mu[year]; kug[metal]; guza[chair]; PN; dim[create]', '@reverse', '$blank space']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 6(aš) gu₂ 2(u) 8(diš) ma-na siki', '#lem: n; gu[pulse]; n; n; mana[unit]; siki[hair]', '2. siki udu-lah₅', '#lem: siki[hair]; X', '3. kas₄ šu ba-ti', '#lem: kaš[runner]; šu[hand]; teŋ[approach]', '@reverse', '4. mu en-mah-gal-an-na [en {d}nanna ba-hun-ga₂]', '#lem: mu[year]; PN; en[priest]; DN; huŋ[hire]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) 1(diš) tug₂ sag uš-bar', '#lem: n; n; tug[textile]; saŋ[head]; ušbar[weaver]', '2. tug₂ sa-gi₄-a', '#lem: tug[textile]; X', '3. ki ur-ama-na-ta', '#lem: ki[place]; PN', '4. ur-{d}iškur', '#lem: PN', '5. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. mu {d}nanna kar-zi-da a-ra₂ 2(diš)-kam', '#lem: mu[year]; DN; TN; ara[times]; n', '2. e₂-a-na kuₓ(KWU147)', '#lem: e[house]; X']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. ki lugal-šu-nir', '#lem: ki[place]; PN', '4. ma-an-zi-zi', '#lem: X', '5. u₃ ur-{d}suen-ta', '#lem: u[and]; PN', '6. gu-du-du', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '2. iti ezem-{d}[...]', '#lem: itud[moon]; PN', '3. [mu] {d}šu-{d}suen# [ma]-da [za-ab-ša]-li[{ki} ba-hul]', '#lem: mu[year]; TN; mada[land]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '@column 1', '$ beginning broken', '1ʾ. [...] x [...] kaš# saga 4(diš) sila₃ zi₃-gu-ta', '#lem: AN; u; AN; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '2ʾ. 1(u) guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '3ʾ. lu₂ šimašgi{ki}-me-eš₃', '#lem: lu[person]; X', '4ʾ. 1(diš) guruš 6(diš) sila₃ kaš saga 4(diš) sila₃ zi₃-gu', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '5ʾ. lu₂ ša-ri-it-x{ki}', '#lem: lu[person]; u', '6ʾ. 2(diš) guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '7ʾ. lu₂ hu-ur-ti{ki}-me-eš₂', '#lem: lu[person]; X', '8ʾ. 1(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '9ʾ. kas₄-me-eš₂ ša₃ en-nu-ga₂', '#lem: X; šag[heart]; ennuŋ[imprisonment]', '10ʾ. giri₃# be-li₂-šar', '#lem: ŋiri[foot]; PN', '11ʾ. ki na-we-er-dingir', '#lem: ki[place]; X', '12ʾ. 4(ban₂)# kaš saga#', '#lem: n; kaš[beer]; sag[rare]', '13ʾ. n(barig)# kaš du', '#lem: X; kaš[beer]; du[go]', '14ʾ. 2(ban₂)# zi₃-gu saga', '#lem: n; zidgu[flour]; sag[rare]', '15ʾ. 5(ban₂) dabin sa', '#lem: n; dabin[semolina]; sa[roast]', '16ʾ. 2(u)# sa gi', '#lem: n; sa[roast]; gi[reed]', '17ʾ. 1(aš)# gu₂# {geš}ma-nu', '#lem: n; gu[pulse]; manu[wood]', '18ʾ. ba#-na#-na# lu₂ mar-ha-ši{ki}', '#lem: PN; lu[person]; GN', '19ʾ. 1(diš)# guruš 1(ban₂) kaš saga 1(ban₂) zi₃-gu', '#lem: n; ŋuruš[male]; n; kaš[beer]; sag[rare]; n; zidgu[flour]', '20ʾ. 2(diš)# guruš 1(ban₂) kaš saga 5(diš) sila₃ zi₃-gu-ta', '#lem: n; ŋuruš[male]; n; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '21ʾ. [sukkal] eme#-bala lu₂ mar-ha-ši{ki} gub-ba-me-eš₂', '#lem: sukkal[secretary]; emebala[translator]; lu[person]; GN; gub[stand]', '22ʾ. n(ban₂)# kaš saga# 1(ban₂) zi₃-gu saga#', '#lem: X; kaš[beer]; sag[rare]; n; zidgu[flour]; sag[rare]', '23ʾ. [n(u)] sa gi', '#lem: X; sa[roast]; gi[reed]', '24ʾ. a#-ri-du-bu-uk', '#lem: PN', '25ʾ. [x] dumu-ni 5(diš) sila₃ kaš saga 5(diš) sila₃ zi₃-gu-ta', '#lem: u; dumu[child]; n; sila[unit]; kaš[beer]; sag[rare]; n; sila[unit]; zidgu[flour]', '26ʾ. x guruš 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: u; ŋuruš[male]; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '27ʾ. [x] guruš# 2(diš) sila₃ zi₃', '#lem: u; ŋuruš[male]; n; sila[unit]; zid[flour]', '28ʾ. [...] 1(diš)# sila₃# kaš', '#lem: AN; n; sila[unit]; kaš[beer]', '29ʾ. [...] x zi₃#', '#lem: AN; u; zid[flour]', '30ʾ. [...]', '#lem: AN', '@column 2', '$ beginning broken', '1ʾ. lu₂#-[...]', '#lem: PN', '2ʾ. 2(diš) guruš 4(diš) [...]', '#lem: n; ŋuruš[male]; n; AN', '3ʾ. lu₂ hu-la#-[...]', '#lem: lu[person]; u', '4ʾ. 2(ban₂) kaš saga [...]', '#lem: n; kaš[beer]; sag[rare]; AN', '5ʾ. 3(diš) x [...]', '#lem: n; u; AN', '6ʾ. hu-un-zi [...]', '#lem: X; AN', '7ʾ. 1(ban₂) kaš 1(ban₂) zi₃ 2(diš) [...]', '#lem: n; kaš[beer]; n; zid[flour]; n; AN', '8ʾ. še₃-eš₃-ba mar-[...]', '#lem: X; u', '9ʾ. 5(diš) sila₃ kaš 5(diš) sila₃ [...]', '#lem: n; sila[unit]; kaš[beer]; n; sila[unit]; AN', '10ʾ. ša-bu-lum sag-[...]', '#lem: X; PN', '11ʾ. 2(ban₂) kaš sag 1(ban₂) zi₃-gu# saga#', '#lem: n; kaš[beer]; saŋ[head]; n; zidgu[flour]; sag[rare]', '12ʾ. 5(geš₂) sa gi', '#lem: n; sa[roast]; gi[reed]', '13ʾ. kal-ad-da', '#lem: kal[rare]', '14ʾ. 5(diš) lu₂ us₂-sa-ni-me-[eš₂]', '#lem: n; lu[person]; X', '15ʾ. 1(barig) 2(diš) sila₃ kaš 2(diš) sila₃ zi₃-ta', '#lem: n; n; sila[unit]; kaš[beer]; n; sila[unit]; zid[flour]', '16ʾ. 2(ban₂) kaš saga 2(ban₂) kaš du', '#lem: n; kaš[beer]; sag[rare]; n; kaš[beer]; du[go]', '17ʾ. 1(ban₂) zi₃-gu saga', '#lem: n; zidgu[flour]; sag[rare]', '18ʾ. 1(u) sa gi', '#lem: n; sa[roast]; gi[reed]', '19ʾ. a-bu-du₁₀ lu₂ ma-ri₂{ki}', '#lem: PN; lu[person]; GN', '20ʾ. 2(diš) ab-ba 1(ban₂) kaš 5(diš) sila₃ zi₃ 1(diš) x [x]', '#lem: n; abba[father]; n; kaš[beer]; n; sila[unit]; zid[flour]; n; u; u', '21ʾ. 1(u) 5(diš) lu₂ ...
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...]', '#lem: AN', '3. [...] 6(geš₂) 2(u) 3(diš)? [...]', '#lem: AN; n; n; n; AN', '4. 2(gešʾu) 5(geš₂) [...]', '#lem: n; n; AN', '5. kišib₃ siki-ba sipa-e-ne', '#lem: kišib[seal]; sikiba[ration]; FN', '@reverse', '1. [iti] ses-da-gu₇-[ta]', '#lem: itud[moon]; MN', '2. [iti] ezem-{d}nin-a-zu-še₃', '#lem: itud[moon]; MN', '3. zi-ga', '#lem: ziga[expenditure]', '4. ki ur-ku₃-nun-na', '#lem: ki[place]; PN', '5. mu ki-maš{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@left', '1. [...] 5(u) la₂ 1(diš) [...]', '#lem: AN; n; lal[small]; n; AN']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) {uruda}ha-bu₃-da', '#lem: n; habuda[hoe]', '2. ša₃ umma{ki}-ta', '#lem: šag[heart]; GN', '3. a-pi₄-sal{ki}-še₃', '#lem: GN', '# sic sal', '4. giri₃ [...]-ku₅ sukkal', '#lem: ŋiri[foot]; u; sukkal[secretary]', '5. x-x-nanna', '#lem: u', '@reverse', '1. ki al-lu-ta', '#lem: ki[place]; PN', '2. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '3. mu {d}šu-{d}suen lugal', '#lem: mu[year]; TN; lugal[king]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) geš tug₂', '#lem: n; ŋeš[tree]; tug[textile]', '2. 1(diš) geš nig₂-ar₃ mar-ma-tag', '#lem: n; ŋeš[tree]; niŋara[groats]; X', '3. 1(diš) geš ha-gar-gu₇', '#lem: n; ŋeš[tree]; X', '4. 1(diš) geš uzu', '#lem: n; ŋeš[tree]; uzu[flesh]', '5. 1(barig) 3(ban₂) zi₃-gu', '#lem: n; n; zidgu[flour]', '6. 1(barig) 3(ban₂) dabin', '#lem: n; n; dabin[semolina]', '7. 4(ban₂) 4(diš) sila₃ ninda du', '#lem: n; n; sila[unit]; ninda[bread]; du[go]', '8. 1(diš) dug dida saga', '#lem: n; dug[pot]; dida[wort]; sag[rare]', '9. 1(diš) dug dida du', '#lem: n; dug[pot]; dida[wort]; du[go]', '10. [...]', '#lem: AN', '@reverse', '1. ma₂-a gar-ra', '#lem: ma[ship]; ŋar[place]', '2. gu₃-du₈-a{ki}-še₃', '#lem: GN', '3. iti ezem-{d}šu-{d}suen', '#lem: itud[moon]; MN', '4. u₄ 1(u) 4(diš) ba-zal-la', '#lem: ud[sun]; n; n; zal[pass]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) eme₆ dusu₂', '#lem: n; eme[donkey]; dusu[equid]', '2. 1(diš) amar eme₆ dusu₂', '#lem: n; amar[young]; eme[donkey]; dusu[equid]', '3. anše babbar₂', '#lem: anše[equid]; babbar[white]', '4. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '5. bar-bar', '#lem: bar[outside]', '@reverse', '1. i₃-dab₅', '#lem: dab[seize]', '2. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '3. mu [dumu-munus] lugal ensi₂ [an]-ša-an-na-ke₄ ba-an-tuku', '#lem: mu[year]; dumumunus[daughter]; lugal[king]; ensik[ruler]; PN; tuku[acquire]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 5(diš) {anše}kunga₂-nita₂', '#lem: n; X', '2. 3(diš) {anše}kunga₂ munus', '#lem: n; kunga[equid]; munus[woman]', '3. mu-kuₓ(DU) lugal', '#lem: mu.DU[delivery]; lugal[king]', '4. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '@reverse', '1. lugal-an-na-ab-tum₂ i₃-dab₅', '#lem: PN; dab[seize]', '2. iti ses-da-gu₇', '#lem: itud[moon]; MN', '3. mu si-mu-ru-um{ki} u₃ lu-lu-bu{ki} a-ra₂ 1(u) la₂ 1(diš)-kam-aš ba-hul', '#lem: mu[year]; GN; u[and]; GN; ara[times]; n; lal[small]; n; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '@column 1', '1. 2(barig) 5(diš) sila₃ še lugal', '#lem: n; n; sila[unit]; še[barley]; lugal[king]', '2. un-za-mu engar', '#lem: PN; engar[farmer]', '3. 3(ban₂) šeš-kal-la dumu-ni', '#lem: n; PN; dumu[child]', '4. 1(barig) 1(ban₂) 5(diš) sila₃ lu₂-me-lam₂', '#lem: n; n; n; sila[unit]; PN', '5. 1(barig) 1(ban₂) 5(diš) ur-a-ka-sahar', '#lem: n; n; n; PN', '6. un-za-mu i₃-dab₅', '#lem: PN; dab[seize]', '7. 2(barig) 5(diš) zi-zi-ga-ni engar', '#lem: n; n; zig[rise]; engar[farmer]', '8. 5(ban₂) ka-ba-lu₂-sa₆', '#lem: n; X', '9. 5(ban₂) lu₂-dingir-ra', '#lem: n; PN', '10. dumu-ni-me', '#lem: dumu[child]', '11. 1(barig) 1(ban₂) 5(diš) igi-ni-da-a', '#lem: n; n; n; PN', '12. zi-zi-ga-ni i₃-dab₅', '#lem: zig[rise]; dab[seize]', '13. 2(barig) 5(diš) ur-{d}utu engar', '#lem: n; n; PN; engar[farmer]', '14. 5(ban₂) ur-{d}ba-ba₆', '#lem: n; PN', '15. 1(barig) 1(ban₂) 5(diš) lu₂-gi-gun₄{ki}', '#lem: n; n; n; PN', '16. dumu-ni-me', '#lem: dumu[child]', '17. 1(barig) 1(ban₂) 5(diš) {d}utu-ug₃-e', '#lem: n; n; n; PN', '18. 1(ban₂) ur-{d}su₄-an-na dumu-ni', '#lem: n; X; dumu[child]', '19. ur-{d}utu i₃-dab₅', '#lem: PN; dab[seize]', '20. 2(barig) 5(diš) ur-{d}iškur engar', '#lem: n; n; PN; engar[farmer]', '21. 5(ban₂) i₃-šub-da', '#lem: n; šub[fall]', '22. 1(barig) 1(ban₂) 5(diš) ar-ši-ah', '#lem: n; n; n; PN', '@column 2', '1. 5(ban₂) a-hu-šu-ni', '#lem: n; PN', '2. ur-{d}iškur# i₃-dab₅', '#lem: PN; dab[seize]', '3. 2(barig) 5(diš) ur-{d}su₄-an-na engar', '#lem: n; n; X; engar[farmer]', '4. 1(barig) lu₂-{d}nanše', '#lem: n; PN', '5. 1(barig) dingir-ra', '#lem: n; X', '6. 1(barig) lugal-ur₂-ra-ni', '#lem: n; WN', '7. ur-{d}su₄-an-na i₃-dab₅', '#lem: X; dab[seize]', '8. 2(barig) 5(diš) lugal-za₃-ge-si engar', '#lem: n; n; PN; engar[farmer]', '9. 1(barig) 1(ban₂) 5(diš) engar-dumu', '#lem: n; n; n; X', '10. 1(ban₂) 5(diš) ab-ba-gi-na dumu-ni', '#lem: n; n; PN; dumu[child]', '11. 1(barig) da-da-a', '#lem: n; PN', '12. 3(ban₂) im-ti-dam', '#lem: n; PN', '13. lugal-za₃-ge-si i₃-dab₅', '#lem: PN; dab[seize]', '14. engar ša₃-gu₄-me', '#lem: engar[farmer]; šagud[drover]', '15. 1(barig) 1(ban₂) 5(diš) ur-{d}nun-gal', '#lem: n; n; n; PN', '16. 1(ban₂) lugal-ušumgal dumu-ni', '#lem: n; X; dumu[child]', '17. {geš}šinig-da tuš-a', '#lem: šinig[tamarisk]; tuš[sit]', '$ blank space', '18. a-ša₃ ga₂?-sug?-ge-hu-ra', '#lem: ašag[field]; FN', '@reverse', '@column 1', '1. 2(barig) 4(diš) [...]', '#lem: n; n; AN', '2. 1(barig) ARAD₂', '#lem: n; arad[slave]', '3. 1(barig) x-igi-x-da#', '#lem: n; u', '4. 1(barig) 1(ban₂) 5(diš) ad-da', '#lem: n; n; n; adda[father]', '5. 1(ban₂) lugal-ušumgal dumu-ni', '#lem: n; X; dumu[child]', '6. ur-{d}nin-geš-zi-da i₃-dab₅', '#lem: PN; dab[seize]', '7. 2(barig) 5(diš) ur-{d}ig-alim engar', '#lem: n; n; PN; engar[farmer]', '8. 3(ban₂) x-x', '#lem: n; u', '9. 1(barig) igi-ni-da-a', '#lem: n; PN', '10. 1(diš) 2(barig) 5(diš) ARAD₂-mu x-x', '#lem: n; n; n; PN; u', '11. ur-{d}ig-alim i₃-dab₅', '#lem: PN; dab[seize]', '12. a-ša₃ a-za-ru-um-da-gi', '#lem: ašag[field]; PN', '13. 2(barig) 5(diš) {d}ba-ba₆-da-nu-me-a engar', '#lem: n; n; PN; engar[farmer]', '14. 1(barig) 1(ban₂) 5(diš) ur-{d}lamma', '#lem: n; n; n; PN', '15. 1(barig) 1(ban₂) 5(diš) lugal-ša₃-la₂', '#lem: n; n; n; PN', '16. 1(ban₂) lu₂-gi-na dumu-ni', '#lem: n; PN; dumu[child]', '17. 3(ban₂) ku-ru-ub-er₃-ra', '#lem: n; PN', '18. [{d}ba]-ba₆-da-nu-me-a i₃-dab₅', '#lem: PN; dab[seize]', '19. [x] 5(diš) lu₂-banda₃{da} geš-gi-da tuš-a', '#lem: u; n; PN; gi[thicket]; tuš[sit]', '20. a#-ša₃ lum-ma-da-mu₂-a', '#lem: ašag[field]; FN', '@column 2', '1. 2(barig) 5(diš) lu₂-{d}geš-bar-e₃ engar', '#lem: n; n; PN; engar[farmer]', '2. 1(barig) lu₂-{d}nanna dumu-ni', '#lem: n; PN; dumu[child]', '3. 1(barig) 1(ban₂) 5(diš) x-ga-ra-ni', '#lem: n; n; n; u', '4. 1(ban₂) 5(diš) ur-{d}iškur', '#lem: n; n; PN', '5. 1(ban₂) giri₃-ni-i₃-sa₆', '#lem: n; PN', '6. dumu-ni-me', '#lem: dumu[child]',  ...
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) amar maš-da₃-nita₂', '#lem: n; amar[young]; X', '2. u₄ 7(diš)-kam', '#lem: ud[sun]; n', '3. [ki] lugal-amar-ku₃-ta', '#lem: ki[place]; PN', '4. u₂-[ta₂]-mi-šar-ra-am [i₃-dab₅]', '#lem: PN; dab[seize]', '@reverse', '1. iti ses-da-gu₇', '#lem: itud[moon]; MN', '2. mu en-nun-e-{d}amar-{d}suen-ra-ki-ag₂ en eridu{ki} ba-hun', '#lem: mu[year]; PN; en[priest]; GN; huŋ[hire]', '@left', '1. 2(diš)', '#lem: n']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [x] amar maš-da₃-nita₂', '#lem: u; amar[young]; X', '2. a₂!(DA)-ge₆-il₂-la sanga', '#lem: PN; FN', '# sic insertion', '3. ki na-we-er-dingir-ta', '#lem: ki[place]; PN', '4. ta₂-hi-iš-a-tal', '#lem: PN', '@reverse', '1. i₃-dab₅', '#lem: dab[seize]', '2. iti ses-da-gu₇', '#lem: itud[moon]; MN', '3. mu us₂-sa si-ma-num₂{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '@seal 1', '@column 1', '1. {d}šu-{d}suen', '#lem: TN', '2. lugal kal-ga', '#lem: lugal[king]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '@column 2', '1. ta₂-hi-iš-a-tal', '#lem: PN', '2. maš₂-šu-gid₂-gid₂', '#lem: maššugidgid[diviner]', '3. ARAD₂-[zu]', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) dusu₂-nita₂', '#lem: n; X', '2. lu₂ na-hi-mu-um', '#lem: lu[person]; PN', '3. 1(diš) dusu₂ munus', '#lem: n; dusu[equid]; munus[woman]', '4. mu-da-num₂', '#lem: X', '5. dumu na-ap-la-num₂', '#lem: dumu[child]; PN', '6. 1(diš) dur₃#', '#lem: n; dur[donkey]', '@reverse', '1. ra-ha-u₃', '#lem: PN', '2. mar-tu', '#lem: MAR.TU[westerner]', '3. ki šu-{d}idim-ta#', '#lem: ki[place]; X', '# idim = asz.asz@inv', '4. ba-zi', '#lem: PN', '5. iti šu-eš₅-ša', '#lem: itud[moon]; MN', '6. mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} mu-hul', '#lem: mu[year]; PN; lugal[king]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(aš) [...]', '#lem: n; AN', '2. ki na-ra-am-i₃-li₂-ta', '#lem: ki[place]; PN', '3. ur-mes', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. giri₃ it-ra-ak-i₃-li₂', '#lem: ŋiri[foot]; PN', '2. iti ezem-{d}[...]', '#lem: itud[moon]; PN', '3. mu {d}nanna [kar]-zi-da [a-ra₂ 2(diš)-kam] e₂-a-[na ba-ku₄?]', '#lem: mu[year]; DN; TN; ara[times]; n; e[house]; X']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) še gur lugal', '#lem: n; še[barley]; gur[unit]; lugal[king]', '2. mu lu₂-banda₃{da}-še₃', '#lem: mu[year]; PN', '3. ki lu₂-{d}suen-ta', '#lem: ki[place]; PN', '4. lugal-ezem-e', '#lem: PN', '5. šu ba-an-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '$ 1 line blank', '2. <mu> {d}nanna <<ki>> karₓ(TE)-zi-da e₂ ba-kuₓ(KWU147)!', '#lem: mu[year]; DN; X; e[house]; X']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '2. 2(diš) {uruda}ha-bu₃-da', '#lem: n; habuda[hoe]', '3. ša₃ 1(u) 4(diš)', '#lem: šag[heart]; n; n', '4. ki ur-šu-ga-lam-ma-ta', '#lem: ki[place]; PN', '5. lu₂-{d}utu', '#lem: PN', '@reverse', '1. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '$ 1 line blank', '2. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '3. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '@envelope', '@obverse', '1. 2(diš) {uruda}ha-bu₃-da', '#lem: n; habuda[hoe]', '2. ša₃ 1(u) 4(diš) ki ur-šu-ga-lam-ma-ta', '#lem: šag[heart]; n; n; ki[place]; PN', '$ seal impression', '3. lu₂-{d}utu', '#lem: PN', '4. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '@reverse', '1. ša₃ unu#{ki#}', '#lem: šag[heart]; GN', '$ seal impression', '2. iti ki-siki-{d}nin-a-zu', '#lem: itud[moon]; MN', '3. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]', '@seal 1', '1. lu₂-{d}utu', '#lem: PN', '2. dumu ma-an-šum₂?', '#lem: dumu[child]; X']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(aš) 2(barig) gazi gur', '#lem: n; n; gazi[condiment]; gur[unit]', '2. 2(u) 3(diš) u₂-kur', '#lem: n; n; X', '3. 5(diš) sila₃ še zi-bi₂-tum', '#lem: n; sila[unit]; še[barley]; PN', '4. gu₂ mu 2(diš)-kam', '#lem: gu[pulse]; mu[year]; n', '5. {geš}kiri₆ e₂-amar {d}šul-gi-ra', '#lem: kiri[orchard]; X; PN', '@reverse', '1. ma-da isin₂?{si}{ki}', '#lem: mada[land]; GN', '2. ki lugal-iti-da-ta', '#lem: ki[place]; PN', '3. ur-mes šu ba-ti', '#lem: PN; šu[hand]; teŋ[approach]', '4. giri₃ lu₂-{d}nin-šubur dub-sar', '#lem: ŋiri[foot]; PN; dubsar[scribe]', '5. mu ša-aš-ru{ki} ba-hul-ta', '#lem: mu[year]; GN; hulu[bad]', '6. mu hu-uh₂#-nu-ri{ki} ba-hul-še₃', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. la₂-ia₃ 1(aš) gu₂ 5(u) 5(diš) ma-na siki du', '#lem: laʾu[arrears]; n; gu[pulse]; n; n; mana[unit]; siki[hair]; du[go]', '2. <la₂>-NI 5(gešʾu) 4(geš₂) 7(diš) a₂ geme₂ u₄ 1(diš)-še₃', '#lem: PN; n; n; n; a[arm]; geme[worker]; ud[sun]; n', '3. kišib₃ {d}šul-gi-i₃-li₂', '#lem: kišib[seal]; PN', '@reverse', '$ blank space', '1. iti ezem-me-ki-gal₂', '#lem: itud[moon]; MN', '2. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 2(diš) tug₂ nig₂-lam₂ 3(diš)-kam us₂', '#lem: n; tug[textile]; niŋlam[garment]; n; us[side]', '2. ki-la₂-bi 3(diš) ma-na', '#lem: kila[weight]; n; mana[unit]', '3. 1(diš) tug₂ guz-za 3(diš)-kam us₂', '#lem: n; tug[textile]; guz[tufted]; n; us[side]', '4. ki-la₂-bi 5(diš) ma-na', '#lem: kila[weight]; n; mana[unit]', '5. 7(diš) tug₂ guz-za 4(diš)-kam us₂', '#lem: n; tug[textile]; guz[tufted]; n; us[side]', '6. ki-la₂-bi 2(u) 8(diš) 1/3(diš) ma-na', '#lem: kila[weight]; n; n; n; mana[unit]', '@reverse', '1. 1(diš) tug₂ uš-bar', '#lem: n; tug[textile]; ušbar[weaver]', '2. ki-la₂-bi 8(diš) 2/3(diš) ma-na', '#lem: kila[weight]; n; šanabi[two-thirds]; mana[unit]', '3. tug₂ ki-la₂ tag-ga', '#lem: tug[textile]; kila[weight]; tag[touch]', '4. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '5. ki {d}šul-gi-i₃-li₂-ta', '#lem: ki[place]; PN', '6. iti ezem-{d}šul-gi', '#lem: itud[moon]; MN', '7. mu us₂-sa ki-maš{ki} ba-hul', '#lem: mu[year]; us[follow]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(diš) tug₂ a₂-gu₄-hu-um geštu šar₃', '#lem: n; tug[textile]; aguhum[clothing]; X; šar[~cloth]', '2. 2(diš) tug₂ nig₂-lam₂ geštu šar₃', '#lem: n; tug[textile]; niŋlam[garment]; X; šar[~cloth]', '3. 1(diš) tug₂ guz-za šar₃', '#lem: n; tug[textile]; guz[tufted]; šar[~cloth]', '4. 2(diš) tug₂ guz-za us₂ šar₃', '#lem: n; tug[textile]; guz[tufted]; us[side]; šar[~cloth]', '5. 3(diš) tug₂ ba-tab duh-hu-um 3(diš)-kam us₂', '#lem: n; tug[textile]; tab[begin]; duh[loosen]; n; us[side]', '6. 2(diš) tug₂ nig₂-lam₂ 3(diš)-kam us₂', '#lem: n; tug[textile]; niŋlam[garment]; n; us[side]', '7. 3(diš) tug₂ guz-za 3(diš)-kam us₂', '#lem: n; tug[textile]; guz[tufted]; n; us[side]', '8. 2(u) la₂ 1(diš) tug₂ guz-za 4(diš)-kam us₂', '#lem: n; lal[small]; n; tug[textile]; guz[tufted]; n; us[side]', '9. 1(u) la₂ 1(diš) tug₂ sag uš-bar', '#lem: n; lal[small]; n; tug[textile]; saŋ[head]; ušbar[weaver]', '10. 3(diš) tug₂ uš-bar', '#lem: n; tug[textile]; ušbar[weaver]', '11. 1/2(diš) ma-na gu keš₂ {geš}ga-rig₂ ak 4(diš)-kam us₂', '#lem: n; mana[unit]; gu[cord]; kešed[bind]; garig[comb]; ak[do]; n; us[side]', '12. [...]-ka# gal₂-la', '#lem: PN; ŋal[be]', '@reverse', '1. la₂-ia₃ 5(diš) tug₂ guz-za du', '#lem: laʾu[arrears]; n; tug[textile]; guz[tufted]; du[go]', '2. la₂-ia₃ 3(diš) tug₂ sag uš-bar', '#lem: laʾu[arrears]; n; tug[textile]; saŋ[head]; ušbar[weaver]', '3. la₂-ia₃ 1(gešʾu) [...] 5(u) 4(diš) 1/2(diš) a₂ guruš u₄ 1(diš)-še₃', '#lem: laʾu[arrears]; n; AN; n; n; n; a[arm]; ŋuruš[male]; ud[sun]; n', '4. la₂-ia₃ 2(aš) 4(barig) 5(diš) sila₃ naga gur', '#lem: laʾu[arrears]; n; n; n; sila[unit]; naŋa[potash]; gur[unit]', '5. la₂-ia₃ 6(aš) gu₂ 4(diš) ma-na im-babbar', '#lem: laʾu[arrears]; n; gu[pulse]; n; mana[unit]; imbabbar[gypsum]', '6. si-i₃-tum nig₂-ka₉-ak', '#lem: situm[balance]; niŋ₂.ŠID[account]', '7. ki i-di₃-er₃-ra ugula lu₂ azlag₂', '#lem: ki[place]; PN; ugula[overseer]; lu[person]; azlag[fuller]', '$ 1 line blank', '8. iti ezem-an-na', '#lem: itud[moon]; MN', '9. mu ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. 1(u) la₂ 1(diš) tug₂ uš-bar', '#lem: n; lal[small]; n; tug[textile]; ušbar[weaver]', '2. iti šu-eš₅-ša', '#lem: itud[moon]; MN', '3. [ki] i-di₃-er₃-ra-ta', '#lem: ki[place]; PN', '4. [mu] en {d}nanna kar-zi-da ba-hun', '#lem: mu[year]; en[priest]; DN; TN; huŋ[hire]', '5. [sag]-nig₂-gur₁₁-ra nu-ur₂-zu-[bi nu]-mu-gal₂', '#lem: X; PN; ŋal[be]', '6. [...]-zu-bi', '#lem: u', '7. [...] nu-gal₂', '#lem: AN; ŋal[be]', '@reverse', '1. 1(u) la₂ 1(diš) tug₂ uš-bar iti šu-eš₅-ša', '#lem: n; lal[small]; n; tug[textile]; ušbar[weaver]; itud[moon]; MN', '2. ki i-di₃-er₃-ra-ta', '#lem: ki[place]; PN', '3. 5(u) 8(diš) 1/2(diš) ma-na siki-gi', '#lem: n; n; n; mana[unit]; X', '4. la₂-ia₃ su-ga ur-{d}lamma', '#lem: laʾu[arrears]; sug[replace]; PN', '5. mu {d}šu-{d}suen lugal', '#lem: mu[year]; TN; lugal[king]', '6. 3(diš) tug₂ uš-bar iti ki-siki-{d}nin-a-zu', '#lem: n; tug[textile]; ušbar[weaver]; itud[moon]; MN', '7. ki i-di₃-er₃-ra-ta', '#lem: ki[place]; PN', '8. 1(aš) gu₂ 5(diš) ma-na siki-gi', '#lem: n; gu[pulse]; n; mana[unit]; X', '9. ki be-li₂-a-zu-ta', '#lem: ki[place]; PN', '10. mu ma₂-dara₃-abzu ba-ab-du₈', '#lem: mu[year]; ON; du[spread]', '11. kišib₃ nu-ur₂-zu-bi', '#lem: kišib[seal]; PN', '12. ki ur-ku₃-nun-na-ka i₃-gal₂', '#lem: ki[place]; PN; ŋal[be]', '13. sag-nig₂-gur₁₁-ra nu-ur₂-zu-ka', '#lem: X; PN', '14. nu-mu-gal₂', '#lem: ŋal[be]']]}
# {'Unknown': [['#project: epsd2/u3adm/p001', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '1. [...]', '#lem: AN', '2. [...] du [...]', '#lem: AN; du[go]; AN', '3. [...] da# lu₂-[...]', '#lem: AN; dag[side]; PN', '4. giri₃ {d}iškur-illat nu-banda₃', '#lem: ŋiri[foot]; PN; nubanda[overseer]', '5. kaš-bi! kab₂-du₁₁-ga kaš ba-ab-si', '#lem: kaš[beer]; kabduga[checked]; kaš[beer]; si[fill]', '6. ninda-bi ba-la₂ ba-ab-si', '#lem: ninda[bread]; la[hang]; si[fill]', '@reverse', '1. giri₃# ur-lugal#', '#lem: ŋiri[foot]; PN', '2. u₃ a-kal-la', '#lem: u[and]; PN', '3. zi-ga bala ensi₂ umma{ki}-ka', '#lem: ziga[expenditure]; bala[turn]; ensik[ruler]; GN', '4. u₄ 1(u) 5(diš)-kam', '#lem: ud[sun]; n; n', '5. ša₃# e₂ puzur₄-iš-da-gan', '#lem: šag[heart]; e[house]; X', '6. [iti] še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '7. [mu ...] ki-maš{ki} [... ba]-hul#', '#lem: mu[year]; AN; GN; AN; hulu[bad]']]}
# ...
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@tablet', '@obverse', '1. 1(u) gu₂ siki-gi', '#lem: n; gu[pulse]; X', '2. 2(u) 4(aš) gu₂ 4(diš) 1/2(diš) ma-na siki gir₂-gul', '#lem: n; n; gu[pulse]; n; n; mana[unit]; siki[hair]; ŋirgul[~wool]', '3. ki lu₂-dingir-ra dumu-inim-{d}šara₂-ta', '#lem: ki[place]; PN; X', '@reverse', '1. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '2. {d}šul-gi-mi-šar', '#lem: PN', '3. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '4. iti šu-eš₅-ša', '#lem: itud[moon]; MN', '5. mu {geš}gu-za {d}en-lil₂-la₂ ba-dim₂', '#lem: mu[year]; guza[chair]; PN; dim[create]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@tablet', '@obverse', '1. 3(u) 8(diš) ma-na 3(diš) gin₂ siki tug₂ us₂ šar₃', '#lem: n; n; mana[unit]; n; giŋ[unit]; siki[hair]; tug[textile]; us[side]; šar[~cloth]', '2. 8(aš) gu₂ 4(diš) 2/3(diš) ma-na 5(diš) gin₂ siki tug₂ 3(diš)-kam us₂', '#lem: n; gu[pulse]; n; šanabi[two-thirds]; mana[unit]; n; giŋ[unit]; siki[hair]; tug[textile]; n; us[side]', '3. 6(u) 8(aš) gu₂ 1(u) 4(diš) ma-na siki tug₂ 4(diš)-kam us₂', '#lem: n; n; gu[pulse]; n; n; mana[unit]; siki[hair]; tug[textile]; n; us[side]', '4. 8(geš₂) 5(aš) gu₂ 6(diš) 5/6(diš) ma#-[na] siki tug₂ [...]', '#lem: n; n; gu[pulse]; n; n; mana[unit]; siki[hair]; tug[textile]; AN', '@reverse', '1. du₁₁-ga i₃-dab₅', '#lem: duga[affliction]; dab[seize]', '$ blank space', '# seal impression', '2. iti šu-eš-ša', '#lem: itud[moon]; MN', '3. mu ma₂-dara₄-abzu# ba-ab-du₈', '#lem: mu[year]; ON; du[spread]', '@seal 1', '1. ur-mes', '#lem: PN', '2. dumu la-na kurušda', '#lem: dumu[child]; PN; kurušda[fattener]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@tablet', '@obverse', '1. 1(diš) {geš}pisan ha-lu-ub₂ a₂-an{zabar} a tur', '#lem: n; bisaŋ[basket]; halub[tree]; X; a[water]; tur[small]', '2. ša₃ e₂-gal-še₃', '#lem: šag[heart]; egal[palace]', '3. u₂-la-i₃-ni-iš šu ba-ti', '#lem: X; šu[hand]; teŋ[approach]', '4. ki lu₂-dingir-ra-ta', '#lem: ki[place]; PN', '5. ba-zi', '#lem: PN', '@reverse', '1. ša₃ nibru{ki}', '#lem: šag[heart]; GN', '2. iti ki-siki-{d}nin-a-zu u₄ 4(diš)-kam', '#lem: itud[moon]; MN; ud[sun]; n', '3. mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ ma-da za-ab-ša-li{ki} mu-hul', '#lem: mu[year]; TN; lugal[king]; GN; mada[land]; GN; hulu[bad]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@tablet', '@obverse', '1. 4(gešʾu) 5(geš₂) 4(u) 1(aš) gu₂ 1(u) 5(diš) gin₂ gi-zi', '#lem: n; n; n; n; gu[pulse]; n; n; giŋ[unit]; gizi[reed]', '2. ša₃ puzur₄-iš-{d}da-gan{ki}', '#lem: šag[heart]; X', '3. 3(geš₂) 1(u) 2(aš) gu₂ gi-zi', '#lem: n; n; n; gu[pulse]; gizi[reed]', '4. ša₃ nibru{ki}', '#lem: šag[heart]; GN', '5. ur-{d}dam-gal-nun-na dub-sar-gu₄', '#lem: PN; X', '6. 5(gešʾu) 2(geš₂) 2(u) 2(aš) 2/3(aš) gu₂ gi-zi', '#lem: n; n; n; n; n; gu[pulse]; gizi[reed]', '7. ur-{d}šul-pa-e₃ dub-sar-gu₄', '#lem: PN; X', '8. ša₃ puzur₄-iš-{d}da-gan{ki}', '#lem: šag[heart]; X', '9. 2(gešʾu) 1(geš₂) 4(u) 5(aš) 2/3(aš) gu₂ gi-zi', '#lem: n; n; n; n; n; gu[pulse]; gizi[reed]', '@reverse', '1. he₂-sa₆-ge dub-sar-gu₄', '#lem: sag[good]; X', '2. ša₃ nibru{ki}', '#lem: šag[heart]; GN', '3. a₂ erin₂ gir₂-su{ki}', '#lem: a[arm]; erin[people]; GN', '4. ki sukkal-mah-ta', '#lem: ki[place]; sukkalmah[official]', '5. mu-kuₓ(DU)', '#lem: mu.DU[delivery]', '6. {d}šul-gi-i₃-li₂', '#lem: PN', '7. šu ba-ti', '#lem: šu[hand]; teŋ[approach]', '8. giri₃ lu₂-giri₁₇-zal', '#lem: ŋiri[foot]; PN', '$ blank space', '9. iti ses-da-gu₇', '#lem: itud[moon]; MN', '10. mu {d}i-bi₂-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. [...]', '#lem: AN', '2. kišib₃#? [...]-x-u₃ sipa', '#lem: kišib[seal]; u; sipad[shepherd]', '3. x-x ib₂-dab₅', '#lem: u; dab[seize]', '4. iti ezem-me-ki-gal₂-ta', '#lem: itud[moon]; MN', '5. iti še-sag₁₁-ku₅-še₃', '#lem: itud[moon]; X', '6. iti 2(diš)-kam', '#lem: itud[moon]; n', '7. mu ha-ar-ši{ki} u₃ ki-maš{ki} ba-hul', '#lem: mu[year]; GN; u[and]; GN; hulu[bad]', '$ blank space', '# seal impression', '@seal 1', '$ illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '$ blank space', '# seal impression', '1. iti ezem-mah', '#lem: itud[moon]; MN', '2. u₄ 3(u)-kam', '#lem: ud[sun]; n', '3. mu amar-{d}suen lugal', '#lem: mu[year]; PN; lugal[king]', '$ blank space', '# seal impression', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}šul-gi', '#lem: TN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '@column 2', '1. na-ra-am-i₃-li₂', '#lem: PN', '2. sukkal i₃-du₈', '#lem: sukkal[secretary]; idu[doorkeeper]', '3. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. zi-ga', '#lem: ziga[expenditure]', '2. u₄ 3(u)-kam', '#lem: ud[sun]; n', '3. iti ezem-{d}nin-a-zu', '#lem: itud[moon]; MN', '4. mu {d}amar-{d}suen lugal-e ur-bi₂-lum{ki} ba-hul', '#lem: mu[year]; PN; lugal[king]; GN; hulu[bad]', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}šul-gi', '#lem: TN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '@column 2', '1. na-ra-am-i₃-li₂', '#lem: PN', '2. sukkal i₃-du₈', '#lem: sukkal[secretary]; idu[doorkeeper]', '3. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. zi-ga u₄ 3(u)-kam', '#lem: ziga[expenditure]; ud[sun]; n', '$ blank space', '# seal impression', '2. iti ezem-mah', '#lem: itud[moon]; MN', '$ blank space', '# seal impression', '3. mu gu-za {d}en-lil₂-la₂ ba-dim₂', '#lem: mu[year]; guza[chair]; PN; dim[create]', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}šul-gi', '#lem: TN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '4. {d}šara₂-kam', '#lem: PN', '@column 2', '1. dub-sar', '#lem: dubsar[scribe]', '2. dumu inim-{d}šara₂', '#lem: dumu[child]; PN', '3. sa₁₂-du₅ lugal-ka', '#lem: FN; PN', '4. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. [...]', '#lem: AN', '2. mu {d}gu-za {d}en-lil₂-la₂ ba-dim₂', '#lem: mu[year]; ON; PN; dim[create]', '$ blank space', '# seal impression', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '$ illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. zi-ga ki ab-ba-sa₆-ga-ta', '#lem: ziga[expenditure]; ki[place]; PN', '2. iti u₅-bi₂-gu₇', '#lem: itud[moon]; MN', '3. mu hu-uh₂-nu-ri{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}amar-{d}suen', '#lem: PN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '4. lugal an ub-da limmu₂-ba', '#lem: lugal[king]; an[sky]; anubda[quarter]; limmu[four]', '@column 2', '1. lugal-iti-da', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ur-{d}dumu-zi-da', '#lem: dumu[child]; PN', '4. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. kurušda-e ib₂-dab₅', '#lem: kurušda[fattener]; dab[seize]', '2. ki ab-ba-sa₆-ga-ta ba-zi', '#lem: ki[place]; PN; PN', '3. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '4. mu hu-uh₂-nu-ri{ki} ba-hul', '#lem: mu[year]; GN; hulu[bad]', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}amar-{d}suen', '#lem: PN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '4. lugal an ub-da limmu₂-ba', '#lem: lugal[king]; an[sky]; anubda[quarter]; limmu[four]', '@column 2', '1. lugal-iti-da', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ur-{d}dumu-zi-da', '#lem: dumu[child]; PN', '4. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. kurušda-e ib₂-dab₅', '#lem: kurušda[fattener]; dab[seize]', '2. iti ezem-{d}šul-gi', '#lem: itud[moon]; MN', '3. mu en eridu{ki} ba-hun', '#lem: mu[year]; en[priest]; GN; huŋ[hire]', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}amar-{d}suen', '#lem: PN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '4. lugal an ub-da limmu₂-ba', '#lem: lugal[king]; an[sky]; anubda[quarter]; limmu[four]', '@column 2', '1. lugal-iti-da', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ur-{d}dumu-zi-da', '#lem: dumu[child]; PN', '4. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. zi-ga', '#lem: ziga[expenditure]', '2. iti šu-eš₅-ša', '#lem: itud[moon]; MN', '3. mu en {d}nanna ba-hun', '#lem: mu[year]; en[priest]; DN; huŋ[hire]', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}amar-{d}suen', '#lem: PN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '4. lugal an ub-da limmu₂-ba', '#lem: lugal[king]; an[sky]; anubda[quarter]; limmu[four]', '@column 2', '1. lugal-iti-da', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ur-{d}dumu-zi-da', '#lem: dumu[child]; PN', '4. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '1. zi-ga', '#lem: ziga[expenditure]', '2. iti še-sag₁₁-ku₅', '#lem: itud[moon]; MN', '3. mu en {d}nanna ba-hun', '#lem: mu[year]; en[priest]; DN; huŋ[hire]', '@surface b', '$ blank space', '# seal impression', '@surface c', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}amar-{d}suen', '#lem: PN', '2. nita kal-ga', '#lem: nita[male]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '4. lugal an ub-da limmu₂-ba', '#lem: lugal[king]; an[sky]; anubda[quarter]; limmu[four]', '@column 2', '1. lugal-iti-da', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ur-{d}dumu-zi-da', '#lem: dumu[child]; PN', '4. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object tag', '@obverse', '1. 3(ban₂) 8(diš) sila₃ zi₃-gum ša₃ du', '#lem: n; n; sila[unit]; X; šag[heart]; du[go]', '2. sa₂-du₁₁ ku₅-ra₂', '#lem: sadug[offerings]; kud[cut]', '3. bala lugal-ezem', '#lem: bala[turn]; PN', '4. mu šu-šu-mu-dar', '#lem: mu[year]; X', '@reverse', '1. kišib₃ tu-ra-am-i₃-li₂', '#lem: kišib[seal]; PN', '2. iti ses-da-gu₇', '#lem: itud[moon]; MN', '3. mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; TN; lugal[king]; GN; e[house]; TN; GN; du[build]', '@seal 1', '1. tu-ra-am-i₃-li₂', '#lem: PN', '2. ARAD₂ {d}nu-muš-da', '#lem: arad[slave]; DN']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object tag', '@obverse', '1. 5(ban₂) 8(diš) sila₃ zi₃ gazₓ(KUM) ša₃ du', '#lem: n; n; sila[unit]; zid[flour]; X; šag[heart]; du[go]', '2. sa₂-du₁₁ ku₅-ra₂', '#lem: sadug[offerings]; kud[cut]', '3. bala er₃-ra-qu₂-ra-ad', '#lem: bala[turn]; PN', '@reverse', '1. mu er₃-re-eb', '#lem: mu[year]; PN', '2. kišib₃ šeš-kal-la', '#lem: kišib[seal]; PN', '3. iti! ses-da-gu₇', '#lem: itud[moon]; MN', '4. mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; TN; lugal[king]; GN; e[house]; TN; GN; du[build]', '@seal 1', '1. šeš-kal-la', '#lem: PN', '2. dumu [...]', '#lem: dumu[child]; AN', '3. [...]', '#lem: AN']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object tag', '@obverse', '1. 1(ban₂) 3(diš) sila₃ zi₃ ba-ba saga', '#lem: n; n; sila[unit]; zid[flour]; ba[allot]; sag[rare]', '2. sa₂-du₁₁ ku₅-ra₂', '#lem: sadug[offerings]; kud[cut]', '3. bala er₃-ra-qar-<rad>', '#lem: bala[turn]; X', '4. mu ha-la-la-še₃', '#lem: mu[year]; PN', '@reverse', '1. kišib₃ šu-{d}iškur', '#lem: kišib[seal]; PN', '2. iti a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '3. mu {d}šu-{d}suen lugal uri₅{ki}-ma-ke₄ e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; TN; lugal[king]; GN; e[house]; TN; GN; du[build]', '@seal 1', '$ illegible']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}šu-{d}suen', '#lem: TN', '2. lugal kal-ga', '#lem: lugal[king]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '4. lugal an ub-da limmu₂-ba', '#lem: lugal[king]; an[sky]; anubda[quarter]; limmu[four]', '@column 2', '1. lugal-iti-da', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ur-{d}dumu-zi-da', '#lem: dumu[child]; PN', '4. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf lang sux', '@object bulla', '@surface a', '$ blank space', '# seal impression', '@seal 1', '@column 1', '1. {d}šu-{d}suen', '#lem: TN', '2. lugal kal-ga', '#lem: lugal[king]; kalag[strong]', '3. lugal uri₅{ki}-ma', '#lem: lugal[king]; GN', '4. lugal an ub-da limmu₂-ba', '#lem: lugal[king]; an[sky]; anubda[quarter]; limmu[four]', '@column 2', '1. lugal-iti-da', '#lem: PN', '2. dub-sar', '#lem: dubsar[scribe]', '3. dumu ur-{d}dumu-zi-da', '#lem: dumu[child]; PN', '4. ARAD₂-zu', '#lem: arad[slave]']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf: lang sux', '@object tag', '@obverse', '1. 5(ban₂)# 8(diš) sila₃ zi₃ gazₓ(KUM)', '#lem: n; n; sila[unit]; zid[flour]; X', '2. sa₂-du₁₁ ku₅-da', '#lem: sadug[offerings]; PN', '3. bala er₃-ra-gar₃?', '#lem: bala[turn]; PN', '4. mu šu-šu#-mu-dar#', '#lem: mu[year]; X', '@reverse', '1. kišib₃# tu#-ra#-am-[i₃-li₂]', '#lem: kišib[seal]; PN', '2. [...] x', '#lem: AN; u', '3. iti# a₂-ki-ti', '#lem: itud[moon]; akiti[festival]', '4. mu e₂ {d}šara₂ umma{ki}-ka mu-du₃', '#lem: mu[year]; e[house]; TN; GN; du[build]', '@seal 1', '$ (illegible)', '']]}
# {'Unknown': [['#project: epsd2/u3adm/p015', '#atf: use unicode', '#atf: lang sux', '@tablet', '@obverse', '$ blank space', '1. [...] x?', '#lem: AN; u', '2. [...] i₃? u₂-ki-im#', '#lem: AN; i[oil]; X', '3. [...] i₃-du₁₀-ga a-du₁₀', '#lem: AN; X; dug[good]', '4. nu-banda₃', '#lem: nubanda[overseer]', '5. ni-zu-hu#? šu-ma#-[x]', '#lem: X; u', '@reverse', '1. [...]-x-ga-ru#-ti-im#', '#lem: u', '2. [...] ti-u₂-ga₂?#', '#lem: AN; X', '3. [...] lu₂#-a₂-zi-da', '#lem: AN; PN', '$ blank space']]}
# Dead Animals archive size: 2470
# Domesticated Animals archive size: 8413
# Leather Objects archive size: 44
# Precious Objects archive size: 230
# Wild Animals archive size: 332
# Wool archive size: 14
# Unknown archive size: 2093

# %% [markdown]
# From above, we know that some lines correspond to multiple texts (with distinct PIDs). They should all be classified under the same archive; below, we'll match each PID with an archive. In addition, we'll do a check to make sure that duplicate texts are in the same archive according to the classifier.

# %%
id_archive_map = {}
extra_map = {}
    
for text in dead_animal_archive:
    if text not in extra_map:
        extra_map[text] = []
        t_list = mapping[text]
        for t in t_list:
            extra_map[text].append([t.p_id, "dead animal"])
            id_archive_map[t.p_id] = "dead animal"

for text in wild_animal_archive:
    if text not in extra_map:
        extra_map[text] = []
        t_list = mapping[text]
        for t in t_list:
            extra_map[text].append([t.p_id, "wild animal"])
            id_archive_map[t.p_id] = "wild animal"
    
for text in domesticated_animal_archive:
    if text not in extra_map:
        extra_map[text] = []
        t_list = mapping[text]
        for t in t_list:
            extra_map[text].append([t.p_id, "domesticated animal"])
            id_archive_map[t.p_id] = "domesticated animal"
        
for text in leather_object_archive:
    if text not in extra_map:
        extra_map[text] = []
        t_list = mapping[text]
        for t in t_list:
            extra_map[text].append([t.p_id, "leather object"])
            id_archive_map[t.p_id] = "leather object"
    
for text in precious_object_archive:
    if text not in extra_map:
        extra_map[text] = []
        t_list = mapping[text]
        for t in t_list:
            extra_map[text].append([t.p_id, "precious object"])
            id_archive_map[t.p_id] = "precious object"

for text in wool_archive:
    if text not in extra_map:
        extra_map[text] = []
        t_list = mapping[text]
        for t in t_list:
            extra_map[text].append([t.p_id, "wool"])
            id_archive_map[t.p_id] = "wool"
    
for text in Unknown_archive:
    if text not in extra_map:
        extra_map[text] = []
        t_list = mapping[text]
        for t in t_list:
            extra_map[text].append([t.p_id, "unknown"])
            id_archive_map[t.p_id] = "unknown"

for text in queen_data:
    if text not in extra_map:
        extra_map[text] = []
        t_list = mapping[text]
        for t in t_list:
            extra_map[text].append([t.p_id, "queen"])
            id_archive_map[t.p_id] = "queen"
            
len(id_archive_map)
# Out:
# 14594

# %%
duplicated_texts = [p for p in extra_map.items() if len(p[1]) > 1]

dup_archive_map = {}

for pair in duplicated_texts:
    archives = [t[1] for t in pair[1]]
    dup_archive_map[pair[0]] = set(archives)
    
conflicts = [p for p in dup_map.items() if len(p[1]) > 1]
len(conflicts)
# Out:
# 0

# %% [markdown]
# From the above results, we can see that all duplicated texts are classified as belonging to the same archive. There shouldn't be any issues.

# %%
# Write results of archive classification to CSV file

archive = open('archive_map.csv', 'w')
archive.write("PID,Archive\n")
for k, v in id_archive_map.items():
    archive.write(k + "," + v + "\n")
archive.close()

# %%
import random

training_ids = [id[1:] for id in complete_list]
all_texts_ids = list(id_archive_map.keys())
non_training_ids = [id for id in all_texts_ids if id not in training_ids]

random_indices = random.sample(range(len(non_training_ids)), 50)
random_ids = [non_training_ids[index] for index in range(len(non_training_ids)) if index in random_indices]

random_sample_ids = []
random_sample_texts = []
random_sample_labels = []

for text, t_list in mapping.items():
    for t in t_list:
        if t.p_id in random_ids:
            random_sample_ids.append(t.p_id)
            random_sample_texts.append(text)
            random_sample_labels.append(id_archive_map[t.p_id])
            
print(random_sample_labels)
print(random_sample_texts)
# Out:
# ['domesticated animal', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'dead animal', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'dead animal', 'dead animal', 'queen', 'domesticated animal', 'dead animal', 'domesticated animal', 'dead animal', 'dead animal', 'domesticated animal', 'dead animal', 'unknown', 'domesticated animal', 'domesticated animal', 'domesticated animal', 'wild animal', 'domesticated animal', 'domesticated animal', 'dead animal', 'dead animal', 'domesticated animal', 'dead animal', 'domesticated animal', 'unknown', 'unknown', 'domesticated animal', 'dead animal', 'domesticated animal', 'domesticated animal', 'unknown', 'domesticated animal', 'dead animal', 'domesticated animal', 'unknown', 'dead animal', 'unknown', 'domesticated animal']
# ['kišib ensik ab udu kišib ab kišib ab kišib', 'sila ud ki dab itud mu en huŋ', 'gud niga ud ki dab itud mu en huŋ', 'amar gud ga sila ga kir ga utuda šag ud dab itud mu en huŋ gud udu', 'gud ud ki dab itud mu hulu', 'udu maš hi ki lu kiŋgia lugal dab šag itud mu lugal', 'udu mašgal ki dab itud mu en en huŋ', 'udu mašgal sila uš ud ki šu teŋ itud mu us lugal bad MAR.TU du', 'udu ki dab ŋiri itud mu lugal lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad', 'udu maš ud ki dab itud mu huŋ', 'udu niga udu niga maškim itud ud zal ziga ki itud mu lugal u saŋdu šubur rah', 'udu niga sila ensik sila ašgar niga sila zabardab mu.DU itud akiti mu u hulu ud', 'sila ga kir ga maš ga ašgar utuda ud šag dab itud mu lugal', 'sila ga kir ga maš ga utuda ud dab itud mu lugal', 'uzud sila maš ga dara uš ud ki šu teŋ itud mu huŋ udu', 'kir uš ud šag ki šu teŋ itud mu hulu', 'gud niga udu sila niga ašgar niga udu šabra udu niga sila udu niga sila udu maš udu niga sila niga udu niga sila sukkal udu niga sila ensik udu niga ašgar niga nubanda mu.DU dab itud akiti mu us hulu mu us ud', 'sila ki kuš dab itud mu du lugal kalag lugal lugal an anubda limmu arad', 'udu u kir ga uš ud ki šu teŋ itud mu us hulu', 'udu sila ud ki dab itud mu dim', 'udu mu agaʾus udu sila mu agaʾus lugal du ma ŋar šugid emuhaldim ud udu ud lal ŋiri dubsar udu mu geme dumu udu udu uš mu agaʾus ud ki itud mu en huŋ lugal kalag lugal lugal an anubda limmu dubsar dumu arad', 'udu ud amar gud udu u uš ud ki šu teŋ itud mu lugal mada hulu lugal kalag lugal lugal an anubda limmu dubsar dumu arad', 'maš enzid ašgar ud lal ki dab itud mu hulu udu', 'u kir maš lal uzud uš ki šu teŋ šag itud mu hulu', 'itud mu huŋ', 'gud niga ab gud mu ab udu mu engar udu mu gu lal mašgal mu ašgar mašgal mu ašgar šulaʾa ki dab itud mu en huŋ', 'gud niga udu aslum niga sag mašgal babbar niga sag us atu šagia maškim ki itud mu hulu gud udu', 'šag e sila sila e sila šag e šag e lugal sila har kugbabbar šag e maškim sila sila atu šagia maškim sila kiŋgia maškim udu maš namerim e mu lu maškim šag šuniŋin lal udu sila kiŋgia šuniŋin sila uzud maš šuniŋin mašgal maš itud udu mu lugal', 'amar mu.DU lugal dab ŋiri dubsar ud itud akiti mu us lugal bad MAR.TU du mašda lugal kalag lugal lugal an anubda limmu dubsar dumu arad', 'lal udu u lal maš uzud bala ud ziga ki itud mu us hulu', 'sila sila sila sila sila ensik ud mu.DU dab itud mu huŋ', 'maš ga babbar šag u gukkal udu u mašgal uzud kir sila ga maš ga uš ud ki šu teŋ itud mu en huŋ udu', 'sila kir ga uš ud ki šu teŋ ŋiri itud mu us ma du udu', 'udu ud ki ugu ŋar itud mu hulu duga dubsar dumu sipad', 'ašgar a dar uš ud ki šu teŋ itud mu en huŋ', 'gud niga udu u maš kašdea da ensik e diŋir dab ŋiri dubsar ud mu.DU dab itud mu us lugal bad MAR.TU du gud udu dubsar dumu kurušda', 'dug gurgur ŋeštin dug ri ŋeštin gu ki nin šu teŋ itud mu hulu', 'še gur lu dubsar dumu', 'udu mašgal šugid ud ki dab kišib duga itud mu lugal dim duga dubsar dumu sipad', 'udu sadug šag udu maš uš sipad šu teŋ itud mu hulu', 'sila sila sila ensik sila sila sila nubanda ud lal mu.DU dab itud', 'mašda eʾuzga maškim maš niga ašgar niga mu.DU sila mu.DU sila mu.DU šabra zabardab maškim šugid emuhaldim ud ki itud mu us', 'dumu', 'gud udu maš hi kišib ki ŋiri sukkalmah mu dim lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad', 'gud u maš ga uš ud ki šu teŋ itud mu dim', 'udu sila maš itud bala ensik ki ziga', 'iku še iku še gur šenumun murgu gur a al ak u u zi engar šeba sila sila engar šeba itud itud itud itud še gur šuniŋin še gur ki šag mu du', 'gud uš ki šu teŋ itud mu lugal u saŋdu šubur rah', 'dubsar arad', 'udu niga udu maš sila ga ud ki dab itud mu en huŋ']

# %%
for t in all_transactions:
    if t.p_id in random_sample_ids:
        print(t.p_id)
        print(" ".join(t.get_sumerian_lemma()))
# Out:
# P101458
# kišib ensik ab udu kišib ab kišib ab kišib kišib ensik ab udu kišib ab kišib ab kišib kišib ensik ab udu kišib ab kišib ab kišib kišib ensik ab udu kišib ab kišib ab kišib
# P102321
# amar gud ga sila ga kir ga utuda šag ud dab itud mu en huŋ gud udu amar gud ga sila ga kir ga utuda šag ud dab itud mu en huŋ gud udu amar gud ga sila ga kir ga utuda šag ud dab itud mu en huŋ gud udu amar gud ga sila ga kir ga utuda šag ud dab itud mu en huŋ gud udu
# P102926
# udu maš hi ki lu kiŋgia lugal dab šag itud mu lugal udu maš hi ki lu kiŋgia lugal dab šag itud mu lugal udu maš hi ki lu kiŋgia lugal dab šag itud mu lugal udu maš hi ki lu kiŋgia lugal dab šag itud mu lugal
# P103205
# udu mašgal ki dab itud mu en en huŋ udu mašgal ki dab itud mu en en huŋ udu mašgal ki dab itud mu en en huŋ udu mašgal ki dab itud mu en en huŋ
# P103576
# udu mašgal sila uš ud ki šu teŋ itud mu us lugal bad MAR.TU du udu mašgal sila uš ud ki šu teŋ itud mu us lugal bad MAR.TU du udu mašgal sila uš ud ki šu teŋ itud mu us lugal bad MAR.TU du udu mašgal sila uš ud ki šu teŋ itud mu us lugal bad MAR.TU du
# P107601
# udu niga udu niga maškim itud ud zal ziga ki itud mu lugal u saŋdu šubur rah udu niga udu niga maškim itud ud zal ziga ki itud mu lugal u saŋdu šubur rah udu niga udu niga maškim itud ud zal ziga ki itud mu lugal u saŋdu šubur rah udu niga udu niga maškim itud ud zal ziga ki itud mu lugal u saŋdu šubur rah
# P107630
# udu niga sila ensik sila ašgar niga sila zabardab mu.DU itud akiti mu u hulu ud udu niga sila ensik sila ašgar niga sila zabardab mu.DU itud akiti mu u hulu ud udu niga sila ensik sila ašgar niga sila zabardab mu.DU itud akiti mu u hulu ud udu niga sila ensik sila ašgar niga sila zabardab mu.DU itud akiti mu u hulu ud
# P107754
# sila ga kir ga maš ga ašgar utuda ud šag dab itud mu lugal sila ga kir ga maš ga ašgar utuda ud šag dab itud mu lugal sila ga kir ga maš ga ašgar utuda ud šag dab itud mu lugal sila ga kir ga maš ga ašgar utuda ud šag dab itud mu lugal
# P109570
# sila ga kir ga maš ga utuda ud dab itud mu lugal sila ga kir ga maš ga utuda ud dab itud mu lugal sila ga kir ga maš ga utuda ud dab itud mu lugal sila ga kir ga maš ga utuda ud dab itud mu lugal
# P109688
# uzud sila maš ga dara uš ud ki šu teŋ itud mu huŋ udu uzud sila maš ga dara uš ud ki šu teŋ itud mu huŋ udu uzud sila maš ga dara uš ud ki šu teŋ itud mu huŋ udu uzud sila maš ga dara uš ud ki šu teŋ itud mu huŋ udu
# P113397
# gud niga udu sila niga ašgar niga udu šabra udu niga sila udu niga sila udu maš udu niga sila niga udu niga sila sukkal udu niga sila ensik udu niga ašgar niga nubanda mu.DU dab itud akiti mu us hulu mu us ud gud niga udu sila niga ašgar niga udu šabra udu niga sila udu niga sila udu maš udu niga sila niga udu niga sila sukkal udu niga sila ensik udu niga ašgar niga nubanda mu.DU dab itud akiti mu us hulu mu us ud gud niga udu sila niga ašgar niga udu šabra udu niga sila udu niga sila udu maš udu niga sila niga udu niga sila sukkal udu niga sila ensik udu niga ašgar niga nubanda mu.DU dab itud akiti mu us hulu mu us ud gud niga udu sila niga ašgar niga udu šabra udu niga sila udu niga sila udu maš udu niga sila niga udu niga sila sukkal udu niga sila ensik udu niga ašgar niga nubanda mu.DU dab itud akiti mu us hulu mu us ud
# P117256
# sila ki kuš dab itud mu du lugal kalag lugal lugal an anubda limmu arad sila ki kuš dab itud mu du lugal kalag lugal lugal an anubda limmu arad sila ki kuš dab itud mu du lugal kalag lugal lugal an anubda limmu arad sila ki kuš dab itud mu du lugal kalag lugal lugal an anubda limmu arad
# P123327
# udu u kir ga uš ud ki šu teŋ itud mu us hulu udu u kir ga uš ud ki šu teŋ itud mu us hulu udu u kir ga uš ud ki šu teŋ itud mu us hulu udu u kir ga uš ud ki šu teŋ itud mu us hulu
# P123873
# udu sila ud ki dab itud mu dim udu sila ud ki dab itud mu dim udu sila ud ki dab itud mu dim udu sila ud ki dab itud mu dim
# P124160
# udu mu agaʾus udu sila mu agaʾus lugal du ma ŋar šugid emuhaldim ud udu ud lal ŋiri dubsar udu mu geme dumu udu udu uš mu agaʾus ud ki itud mu en huŋ lugal kalag lugal lugal an anubda limmu dubsar dumu arad udu mu agaʾus udu sila mu agaʾus lugal du ma ŋar šugid emuhaldim ud udu ud lal ŋiri dubsar udu mu geme dumu udu udu uš mu agaʾus ud ki itud mu en huŋ lugal kalag lugal lugal an anubda limmu dubsar dumu arad udu mu agaʾus udu sila mu agaʾus lugal du ma ŋar šugid emuhaldim ud udu ud lal ŋiri dubsar udu mu geme dumu udu udu uš mu agaʾus ud ki itud mu en huŋ lugal kalag lugal lugal an anubda limmu dubsar dumu arad udu mu agaʾus udu sila mu agaʾus lugal du ma ŋar šugid emuhaldim ud udu ud lal ŋiri dubsar udu mu geme dumu udu udu uš mu agaʾus ud ki itud mu en huŋ lugal kalag lugal lugal an anubda limmu dubsar dumu arad
# P124578
# udu ki dab ŋiri itud mu lugal lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad udu ki dab ŋiri itud mu lugal lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad udu ki dab ŋiri itud mu lugal lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad udu ki dab ŋiri itud mu lugal lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad
# P125490
# udu maš ud ki dab itud mu huŋ udu maš ud ki dab itud mu huŋ udu maš ud ki dab itud mu huŋ udu maš ud ki dab itud mu huŋ
# P126124
# udu ud amar gud udu u uš ud ki šu teŋ itud mu lugal mada hulu lugal kalag lugal lugal an anubda limmu dubsar dumu arad udu ud amar gud udu u uš ud ki šu teŋ itud mu lugal mada hulu lugal kalag lugal lugal an anubda limmu dubsar dumu arad udu ud amar gud udu u uš ud ki šu teŋ itud mu lugal mada hulu lugal kalag lugal lugal an anubda limmu dubsar dumu arad udu ud amar gud udu u uš ud ki šu teŋ itud mu lugal mada hulu lugal kalag lugal lugal an anubda limmu dubsar dumu arad
# P126147
# sila ud ki dab itud mu en huŋ sila ud ki dab itud mu en huŋ sila ud ki dab itud mu en huŋ sila ud ki dab itud mu en huŋ
# P126209
# maš enzid ašgar ud lal ki dab itud mu hulu udu maš enzid ašgar ud lal ki dab itud mu hulu udu maš enzid ašgar ud lal ki dab itud mu hulu udu maš enzid ašgar ud lal ki dab itud mu hulu udu
# P126686
# u kir maš lal uzud uš ki šu teŋ šag itud mu hulu u kir maš lal uzud uš ki šu teŋ šag itud mu hulu u kir maš lal uzud uš ki šu teŋ šag itud mu hulu u kir maš lal uzud uš ki šu teŋ šag itud mu hulu
# P127483
# itud mu huŋ itud mu huŋ itud mu huŋ itud mu huŋ
# P128610
# gud niga ab gud mu ab udu mu engar udu mu gu lal mašgal mu ašgar mašgal mu ašgar šulaʾa ki dab itud mu en huŋ gud niga ab gud mu ab udu mu engar udu mu gu lal mašgal mu ašgar mašgal mu ašgar šulaʾa ki dab itud mu en huŋ gud niga ab gud mu ab udu mu engar udu mu gu lal mašgal mu ašgar mašgal mu ašgar šulaʾa ki dab itud mu en huŋ gud niga ab gud mu ab udu mu engar udu mu gu lal mašgal mu ašgar mašgal mu ašgar šulaʾa ki dab itud mu en huŋ
# P128916
# gud niga udu aslum niga sag mašgal babbar niga sag us atu šagia maškim ki itud mu hulu gud udu gud niga udu aslum niga sag mašgal babbar niga sag us atu šagia maškim ki itud mu hulu gud udu gud niga udu aslum niga sag mašgal babbar niga sag us atu šagia maškim ki itud mu hulu gud udu gud niga udu aslum niga sag mašgal babbar niga sag us atu šagia maškim ki itud mu hulu gud udu
# P128927
# šag e sila sila e sila šag e šag e lugal sila har kugbabbar šag e maškim sila sila atu šagia maškim sila kiŋgia maškim udu maš namerim e mu lu maškim šag šuniŋin lal udu sila kiŋgia šuniŋin sila uzud maš šuniŋin mašgal maš itud udu mu lugal šag e sila sila e sila šag e šag e lugal sila har kugbabbar šag e maškim sila sila atu šagia maškim sila kiŋgia maškim udu maš namerim e mu lu maškim šag šuniŋin lal udu sila kiŋgia šuniŋin sila uzud maš šuniŋin mašgal maš itud udu mu lugal šag e sila sila e sila šag e šag e lugal sila har kugbabbar šag e maškim sila sila atu šagia maškim sila kiŋgia maškim udu maš namerim e mu lu maškim šag šuniŋin lal udu sila kiŋgia šuniŋin sila uzud maš šuniŋin mašgal maš itud udu mu lugal šag e sila sila e sila šag e šag e lugal sila har kugbabbar šag e maškim sila sila atu šagia maškim sila kiŋgia maškim udu maš namerim e mu lu maškim šag šuniŋin lal udu sila kiŋgia šuniŋin sila uzud maš šuniŋin mašgal maš itud udu mu lugal
# P130760
# amar mu.DU lugal dab ŋiri dubsar ud itud akiti mu us lugal bad MAR.TU du mašda lugal kalag lugal lugal an anubda limmu dubsar dumu arad amar mu.DU lugal dab ŋiri dubsar ud itud akiti mu us lugal bad MAR.TU du mašda lugal kalag lugal lugal an anubda limmu dubsar dumu arad amar mu.DU lugal dab ŋiri dubsar ud itud akiti mu us lugal bad MAR.TU du mašda lugal kalag lugal lugal an anubda limmu dubsar dumu arad amar mu.DU lugal dab ŋiri dubsar ud itud akiti mu us lugal bad MAR.TU du mašda lugal kalag lugal lugal an anubda limmu dubsar dumu arad
# P131666
# lal udu u lal maš uzud bala ud ziga ki itud mu us hulu lal udu u lal maš uzud bala ud ziga ki itud mu us hulu lal udu u lal maš uzud bala ud ziga ki itud mu us hulu lal udu u lal maš uzud bala ud ziga ki itud mu us hulu
# P131927
# sila sila sila sila sila ensik ud mu.DU dab itud mu huŋ sila sila sila sila sila ensik ud mu.DU dab itud mu huŋ sila sila sila sila sila ensik ud mu.DU dab itud mu huŋ sila sila sila sila sila ensik ud mu.DU dab itud mu huŋ
# P132021
# maš ga babbar šag u gukkal udu u mašgal uzud kir sila ga maš ga uš ud ki šu teŋ itud mu en huŋ udu maš ga babbar šag u gukkal udu u mašgal uzud kir sila ga maš ga uš ud ki šu teŋ itud mu en huŋ udu maš ga babbar šag u gukkal udu u mašgal uzud kir sila ga maš ga uš ud ki šu teŋ itud mu en huŋ udu maš ga babbar šag u gukkal udu u mašgal uzud kir sila ga maš ga uš ud ki šu teŋ itud mu en huŋ udu
# P133974
# sila kir ga uš ud ki šu teŋ ŋiri itud mu us ma du udu sila kir ga uš ud ki šu teŋ ŋiri itud mu us ma du udu sila kir ga uš ud ki šu teŋ ŋiri itud mu us ma du udu sila kir ga uš ud ki šu teŋ ŋiri itud mu us ma du udu
# P134782
# udu ud ki ugu ŋar itud mu hulu duga dubsar dumu sipad udu ud ki ugu ŋar itud mu hulu duga dubsar dumu sipad udu ud ki ugu ŋar itud mu hulu duga dubsar dumu sipad udu ud ki ugu ŋar itud mu hulu duga dubsar dumu sipad
# P134839
# gud ud ki dab itud mu hulu gud ud ki dab itud mu hulu gud ud ki dab itud mu hulu gud ud ki dab itud mu hulu
# P135003
# ašgar a dar uš ud ki šu teŋ itud mu en huŋ ašgar a dar uš ud ki šu teŋ itud mu en huŋ ašgar a dar uš ud ki šu teŋ itud mu en huŋ ašgar a dar uš ud ki šu teŋ itud mu en huŋ
# P142141
# gud niga udu u maš kašdea da ensik e diŋir dab ŋiri dubsar ud mu.DU dab itud mu us lugal bad MAR.TU du gud udu dubsar dumu kurušda gud niga udu u maš kašdea da ensik e diŋir dab ŋiri dubsar ud mu.DU dab itud mu us lugal bad MAR.TU du gud udu dubsar dumu kurušda gud niga udu u maš kašdea da ensik e diŋir dab ŋiri dubsar ud mu.DU dab itud mu us lugal bad MAR.TU du gud udu dubsar dumu kurušda gud niga udu u maš kašdea da ensik e diŋir dab ŋiri dubsar ud mu.DU dab itud mu us lugal bad MAR.TU du gud udu dubsar dumu kurušda
# P142570
# dug gurgur ŋeštin dug ri ŋeštin gu ki nin šu teŋ itud mu hulu dug gurgur ŋeštin dug ri ŋeštin gu ki nin šu teŋ itud mu hulu dug gurgur ŋeštin dug ri ŋeštin gu ki nin šu teŋ itud mu hulu dug gurgur ŋeštin dug ri ŋeštin gu ki nin šu teŋ itud mu hulu
# P200512
# še gur lu dubsar dumu še gur lu dubsar dumu še gur lu dubsar dumu še gur lu dubsar dumu
# P201077
# udu mašgal šugid ud ki dab kišib duga itud mu lugal dim duga dubsar dumu sipad udu mašgal šugid ud ki dab kišib duga itud mu lugal dim duga dubsar dumu sipad udu mašgal šugid ud ki dab kišib duga itud mu lugal dim duga dubsar dumu sipad udu mašgal šugid ud ki dab kišib duga itud mu lugal dim duga dubsar dumu sipad
# P201130
# udu sadug šag udu maš uš sipad šu teŋ itud mu hulu udu sadug šag udu maš uš sipad šu teŋ itud mu hulu udu sadug šag udu maš uš sipad šu teŋ itud mu hulu udu sadug šag udu maš uš sipad šu teŋ itud mu hulu
# P210370
# gud niga ud ki dab itud mu en huŋ gud niga ud ki dab itud mu en huŋ gud niga ud ki dab itud mu en huŋ gud niga ud ki dab itud mu en huŋ
# P211366
# sila sila sila ensik sila sila sila nubanda ud lal mu.DU dab itud sila sila sila ensik sila sila sila nubanda ud lal mu.DU dab itud sila sila sila ensik sila sila sila nubanda ud lal mu.DU dab itud sila sila sila ensik sila sila sila nubanda ud lal mu.DU dab itud
# P235635
# mašda eʾuzga maškim maš niga ašgar niga mu.DU sila mu.DU sila mu.DU šabra zabardab maškim šugid emuhaldim ud ki itud mu us mašda eʾuzga maškim maš niga ašgar niga mu.DU sila mu.DU sila mu.DU šabra zabardab maškim šugid emuhaldim ud ki itud mu us mašda eʾuzga maškim maš niga ašgar niga mu.DU sila mu.DU sila mu.DU šabra zabardab maškim šugid emuhaldim ud ki itud mu us mašda eʾuzga maškim maš niga ašgar niga mu.DU sila mu.DU sila mu.DU šabra zabardab maškim šugid emuhaldim ud ki itud mu us
# P303517
# gud udu maš hi kišib ki ŋiri sukkalmah mu dim lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad gud udu maš hi kišib ki ŋiri sukkalmah mu dim lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad gud udu maš hi kišib ki ŋiri sukkalmah mu dim lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad gud udu maš hi kišib ki ŋiri sukkalmah mu dim lugal kalag lugal lugal an anubda limmu dubsar dumu kurušda arad
# P303542
# gud u maš ga uš ud ki šu teŋ itud mu dim gud u maš ga uš ud ki šu teŋ itud mu dim gud u maš ga uš ud ki šu teŋ itud mu dim gud u maš ga uš ud ki šu teŋ itud mu dim
# P330155
# udu sila maš itud bala ensik ki ziga udu sila maš itud bala ensik ki ziga udu sila maš itud bala ensik ki ziga udu sila maš itud bala ensik ki ziga
# P411980
# iku še iku še gur šenumun murgu gur a al ak u u zi engar šeba sila sila engar šeba itud itud itud itud še gur šuniŋin še gur ki šag mu du iku še iku še gur šenumun murgu gur a al ak u u zi engar šeba sila sila engar šeba itud itud itud itud še gur šuniŋin še gur ki šag mu du iku še iku še gur šenumun murgu gur a al ak u u zi engar šeba sila sila engar šeba itud itud itud itud še gur šuniŋin še gur ki šag mu du iku še iku še gur šenumun murgu gur a al ak u u zi engar šeba sila sila engar šeba itud itud itud itud še gur šuniŋin še gur ki šag mu du
# P416208
# gud uš ki šu teŋ itud mu lugal u saŋdu šubur rah gud uš ki šu teŋ itud mu lugal u saŋdu šubur rah gud uš ki šu teŋ itud mu lugal u saŋdu šubur rah gud uš ki šu teŋ itud mu lugal u saŋdu šubur rah
# P430499
# dubsar arad dubsar arad dubsar arad dubsar arad
# P430602
# dumu dumu dumu dumu
# P414536
# kir uš ud šag ki šu teŋ itud mu hulu kir uš ud šag ki šu teŋ itud mu hulu kir uš ud šag ki šu teŋ itud mu hulu kir uš ud šag ki šu teŋ itud mu hulu
# P235911
# udu niga udu maš sila ga ud ki dab itud mu en huŋ udu niga udu maš sila ga ud ki dab itud mu en huŋ udu niga udu maš sila ga ud ki dab itud mu en huŋ udu niga udu maš sila ga ud ki dab itud mu en huŋ

# %%
# Write results of random sample to CSV file
# import unicodecsv as csv

sample = open('random_sample.csv', 'w', encoding='utf-8')
sample.write("PID,Text,Archive\n")
for i in range(len(random_sample_ids)):
# for i in range(1):
    sample.write(random_sample_ids[i] + "," + random_sample_texts[i] + "," + random_sample_labels[i] + "\n")
sample.close()
