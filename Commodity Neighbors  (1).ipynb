# %% [markdown]
# # Commodity Neighbors

# %% [markdown]
# We want to create nodes for geographical location, people, and commodities. In this notebook, I aim to add a neighbors attribute for commodities mentioned in particular texts. I'll look into the original filtered dataset to extract the commodities and respective neighbors. The code will be very similar to how neighbors were created for each proper name.

# %% [markdown]
# What differs from the neighbors of commodities versus the neighbors of proper names is that commodity neighbors are particular people and geographical names, but since this dataset only contains the people, we'll take neighbors as just people.
#
# Best precaution is to cross check with the proper name neighbors to make sure that both neighbor sets contain one another. This would help in creating an edge between the proper name and the commodity.
#
# We will take as many lines necessary to find the neighbors, and will stop when the next commodity is hit, because if a line contains a commodity, it will be the first word of that line.

# %%
import pandas as pd

# %%
commodities_Pnum = pd.read_csv("Downloads/commodities_CSV.csv")
edgelist = pd.read_csv("Downloads/fa19_edgelist3.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
commodities_Pnum = commodities_Pnum.set_index('Unnamed: 0')

# %%
commodities_Pnum
# Out:
#                       0            1              2              3  \
# Unnamed: 0
# P124149      3(diš)[]NU  udu[sheep]N        u[ewe]N  mašgal[goat]N
# P405489      1(diš)[]NU     gud[ox]N    udu[sheep]N  mašgal[goat]N
# P332036        gud[ox]N     gud[ox]N    udu[sheep]N    udu[sheep]N
# P320496         x[NA]NA      x[NA]NA    udu[sheep]N  mašgal[goat]N
# P124307     sila[lamb]N          NaN            NaN            NaN
# ...                 ...          ...            ...            ...
# P201038     4(geš₂)[]NU  sila[unit]N      mu[name]N            NaN
# P124203     udu[sheep]N      u[ewe]N  mašgal[goat]N    uzud[goat]N
# P210433         x[NA]NA  ašgar[kid]N    ŋiri[foot]N            NaN
# P142905     udu[sheep]N  sila[lamb]N     maš[goat]N    ašgar[kid]N
# P218182        3(u)[]NU  udu[sheep]N     maš[goat]N            NaN
#
#                       4            5            6            7              8  \
# Unnamed: 0
# P124149             NaN          NaN          NaN          NaN            NaN
# P405489     uzud[goat]N  sila[lamb]N  sila[lamb]N   maš[goat]N       gud[ox]N
# P332036     udu[sheep]N  sila[lamb]N     gud[ox]N  udu[sheep]N  mašgal[goat]N
# P320496        ud[sun]N   2(diš)[]NU  udu[sheep]N  udu[sheep]N  mašgal[goat]N
# P124307             NaN          NaN          NaN          NaN            NaN
# ...                 ...          ...          ...          ...            ...
# P201038             NaN          NaN          NaN          NaN            NaN
# P124203             NaN          NaN          NaN          NaN            NaN
# P210433             NaN          NaN          NaN          NaN            NaN
# P142905             NaN          NaN          NaN          NaN            NaN
# P218182             NaN          NaN          NaN          NaN            NaN
#
#                       9  ...  517  518  519  520  521  522  523  524  525  526
# Unnamed: 0               ...
# P124149             NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P405489     udu[sheep]N  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P332036        gud[ox]N  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P320496        ud[sun]N  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P124307             NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                 ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# P201038             NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P124203             NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P210433             NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P142905             NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P218182             NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [13931 rows x 527 columns]

# %%
filtered_1 = pd.read_csv("Downloads/filtered_1_with_neighbors_normalized.csv")

# %%
filtered_1['P_Number'] = [filtered_1.loc[i]['id_text'][-7:] for i in range(len(filtered_1))]

# %%
#commodity: word that succeeds a number
commodities = filtered_1[filtered_1['commodity?'] == "Yes"]
commodities_ids = commodities['id']
#What to do about commodity groups that do not have PNs?

# %%
group_of_same_pnumber = filtered_1[filtered_1['P_Number'] == filtered_1.iloc[1]['P_Number']]
group_of_same_pnumber
# Out:
#     id  unnamed                lemma normalizaton                    id_text  \
# 0    0        0           3(diš)[]NU          NaN  epsd2/admin/u3adm/P124149
# 1    1        1          udu[sheep]N          NaN  epsd2/admin/u3adm/P124149
# 2    2        2           6(diš)[]NU          NaN  epsd2/admin/u3adm/P124149
# 3    3        3              u[ewe]N          NaN  epsd2/admin/u3adm/P124149
# 4    4        4           2(diš)[]NU          NaN  epsd2/admin/u3adm/P124149
# 5    5        5        mašgal[goat]N          NaN  epsd2/admin/u3adm/P124149
# 6    6        6      šugid[~animal]N          NaN  epsd2/admin/u3adm/P124149
# 7    7        7  emuhaldim[kitchen]N          NaN  epsd2/admin/u3adm/P124149
# 8    8        8            mu[name]N          NaN  epsd2/admin/u3adm/P124149
# 9    9        9      gardu[soldier]N          NaN  epsd2/admin/u3adm/P124149
# 10  10       10          šag[heart]N          NaN  epsd2/admin/u3adm/P124149
# 11  11       11    tum-ma-al{ki}[]GN   Tummal[]TN  epsd2/admin/u3adm/P124149
# 12  12       12             ud[sun]N          NaN  epsd2/admin/u3adm/P124149
# 13  13       13             1(u)[]NU          NaN  epsd2/admin/u3adm/P124149
# 14  14       14     5(diš@t)-kam[]NU          NaN  epsd2/admin/u3adm/P124149
# 15  15       15           ki[place]N          NaN  epsd2/admin/u3adm/P124149
# 16  16       16     du₁₁-ga-ta[NA]NA          NaN  epsd2/admin/u3adm/P124149
# 17  17       17         zig[rise]V/i          NaN  epsd2/admin/u3adm/P124149
# 18  18       18          itud[moon]N          NaN  epsd2/admin/u3adm/P124149
# 19  19       19        šu-eš₅-ša[]MN          NaN  epsd2/admin/u3adm/P124149
# 20  20       20            mu[name]N          NaN  epsd2/admin/u3adm/P124149
# 21  21       21          en[priest]N          NaN  epsd2/admin/u3adm/P124149
# 22  22       22        eridu{ki}[]GN   Eridug[]GN  epsd2/admin/u3adm/P124149
# 23  23       23         huŋ[hire]V/t          NaN  epsd2/admin/u3adm/P124149
# 24  24       24             1(u)[]NU          NaN  epsd2/admin/u3adm/P124149
# 25  25       25           1(diš)[]NU          NaN  epsd2/admin/u3adm/P124149
#
#     id_line       id_word   label prof? role? family? number? commodity?  \
# 0         3   P124149.3.1     o 1    No    No      No     Yes         No
# 1         3   P124149.3.2     o 1    No    No      No      No        Yes
# 2         4   P124149.4.1     o 2    No    No      No     Yes         No
# 3         4   P124149.4.2     o 2    No    No      No      No        Yes
# 4         5   P124149.5.1     o 3    No    No      No     Yes         No
# 5         5   P124149.5.2     o 3    No    No      No      No        Yes
# 6         6   P124149.6.1     o 4    No    No      No      No         No
# 7         6   P124149.6.2     o 4    No    No      No      No         No
# 8         7   P124149.7.1     o 5    No    No      No      No         No
# 9         7   P124149.7.2     o 5    No    No      No      No         No
# 10        9   P124149.9.1     r 1    No    No      No      No         No
# 11        9   P124149.9.2     r 1    No    No      No      No         No
# 12       10  P124149.10.1     r 2    No    No      No      No         No
# 13       10  P124149.10.2     r 2    No    No      No     Yes         No
# 14       10  P124149.10.3     r 2    No    No      No     Yes        Yes
# 15       11  P124149.11.1     r 3    No    No      No      No        Yes
# 16       11  P124149.11.2     r 3    No    No      No      No         No
# 17       12  P124149.12.1     r 4    No    No      No      No         No
# 18       13  P124149.13.1     r 5    No    No      No      No         No
# 19       13  P124149.13.2     r 5    No    No      No      No         No
# 20       14  P124149.14.1     r 6    No    No      No      No         No
# 21       14  P124149.14.2     r 6   Yes    No      No      No         No
# 22       14  P124149.14.3     r 6    No    No      No      No         No
# 23       14  P124149.14.4     r 6    No    No      No      No         No
# 24       16  P124149.16.1  l.e. 1    No    No      No     Yes         No
# 25       16  P124149.16.2  l.e. 1    No    No      No     Yes        Yes
#
#    P_Number neighbors
# 0   P124149        []
# 1   P124149        []
# 2   P124149        []
# 3   P124149        []
# 4   P124149        []
# 5   P124149        []
# 6   P124149        []
# 7   P124149        []
# 8   P124149        []
# 9   P124149        []
# 10  P124149        []
# 11  P124149        []
# 12  P124149        []
# 13  P124149        []
# 14  P124149        []
# 15  P124149        []
# 16  P124149        []
# 17  P124149        []
# 18  P124149        []
# 19  P124149        []
# 20  P124149        []
# 21  P124149        []
# 22  P124149        []
# 23  P124149        []
# 24  P124149        []
# 25  P124149        []

# %%
lines_befaf_commodity = group_of_same_pnumber[((group_of_same_pnumber['id_line'] >= filtered_1.iloc[1]['id_line'] - 2) 
                                                        &(group_of_same_pnumber['id_line'] <= filtered_1.iloc[1]['id_line']))
                                                    | ((group_of_same_pnumber['id_line'] <= filtered_1.iloc[1]['id_line'] + 2)
                                                       & (group_of_same_pnumber['id_line'] >= filtered_1.iloc[1]['id_line']))]

lines_befaf_commodity
# Out:
#    id  unnamed          lemma normalizaton                    id_text  \
# 0   0        0     3(diš)[]NU          NaN  epsd2/admin/u3adm/P124149
# 1   1        1    udu[sheep]N          NaN  epsd2/admin/u3adm/P124149
# 2   2        2     6(diš)[]NU          NaN  epsd2/admin/u3adm/P124149
# 3   3        3        u[ewe]N          NaN  epsd2/admin/u3adm/P124149
# 4   4        4     2(diš)[]NU          NaN  epsd2/admin/u3adm/P124149
# 5   5        5  mašgal[goat]N          NaN  epsd2/admin/u3adm/P124149
#
#    id_line      id_word label prof? role? family? number? commodity? P_Number  \
# 0        3  P124149.3.1   o 1    No    No      No     Yes         No  P124149
# 1        3  P124149.3.2   o 1    No    No      No      No        Yes  P124149
# 2        4  P124149.4.1   o 2    No    No      No     Yes         No  P124149
# 3        4  P124149.4.2   o 2    No    No      No      No        Yes  P124149
# 4        5  P124149.5.1   o 3    No    No      No     Yes         No  P124149
# 5        5  P124149.5.2   o 3    No    No      No      No        Yes  P124149
#
#   neighbors
# 0        []
# 1        []
# 2        []
# 3        []
# 4        []
# 5        []

# %%
for i in range(len(lines_befaf_commodity)):
    neighbors = []
    if  (lines_befaf_commodity.loc[i]['lemma'][-2:] == 'PN') | (lines_befaf_commodity.loc[i]['lemma'][-2:] == 'GN'):
        neighbors.append(lines_befaf_commodity.loc[i]['lemma'])
same = lines_befaf_commodity[lines_befaf_commodity['id_line'] == filtered_1.iloc[1]['id_line']]
neighbors += same['lemma'].tolist()
neighbors
# Out:
# ['3(diš)[]NU', 'udu[sheep]N']

# %%
#get the words in the same text
#use a line of text as an attribute , in case there's no PN as a neighbor , that could include other commodities as well
def neighbors_for_comm(filtered, commodity_id_list):
    list_of_neighbors = []
    for com_id in commodity_id_list:
        group_of_same_pnumber = filtered[filtered['P_Number'] == filtered.iloc[com_id]['P_Number']]
    #list_of_pnumb_groups.append(group_of_same_pnumber)
        lines_befaf_commodity = group_of_same_pnumber[((group_of_same_pnumber['id_line'] >= filtered.iloc[com_id]['id_line'] - 2) 
                                                        &(group_of_same_pnumber['id_line'] <= filtered.iloc[com_id]['id_line']))
                                                    | ((group_of_same_pnumber['id_line'] <= filtered.iloc[com_id]['id_line'] + 2)
                                                       & (group_of_same_pnumber['id_line'] >= filtered.iloc[com_id]['id_line']))]
    #If group doesn't contain PN or GN: just take neighbors to be the same line
    #Otherwise make them the individual neighbors
        for i in range(len(lines_befaf_commodity)):
            neighbors = []
            if  (lines_befaf_commodity.iloc[i]['lemma'][-2:] == 'PN') | (lines_befaf_commodity.iloc[i]['lemma'][-2:] == 'GN'):
                neighbors.append(lines_befaf_commodity.iloc[i]['lemma'])
        same = lines_befaf_commodity[lines_befaf_commodity['id_line'] == filtered.iloc[com_id]['id_line']]
        neighbors += same['lemma'].tolist()
        list_of_neighbors.append(neighbors)
    return list_of_neighbors

# %% [markdown]
# Applying above function to all the 10 filtered files (result of function would be adding new column with commodity neighbors:

# %%
filtered_files = ["Downloads/filtered_1_with_neighbors_normalized.csv", 
                 "Downloads/filtered_2_with_neighbors_normalized.csv", 
                 "Downloads/filtered_3_with_neighbors_normalized.csv", 
                 "Downloads/filtered_4_with_neighbors_normalized.csv", 
                 "Downloads/filtered_5_with_neighbors_normalized.csv", 
                 "Downloads/filtered_6_with_neighbors_normalized.csv", 
                  "Downloads/filtered_7_with_neighbors_normalized.csv", 
                 "Downloads/filtered_8_with_neighbors_normalized.csv", 
                 "Downloads/filtered_9_with_neighbors_normalized.csv", 
                 "Downloads/filtered_10_with_neighbors_normalized.csv"]
for j in range(len(filtered_files)):
    filtered = pd.read_csv(filtered_files[j])
    filtered['P_Number'] = [filtered.loc[i]['id_text'][-7:] for i in range(len(filtered))]
    commodities = filtered[filtered['commodity?'] == "Yes"]
    commodities_id_list = commodities['id'].to_list()
    
    list_comm = neighbors_for_comm(filtered, commodity_id_list)
    
    list_comm_copy = list_comm
    commodity_neighbor_column = [0] * len(filtered)
    for i in range(len(commodity_neighbor_column)):
        if i in commodity_id_list:
            commodity_neighbor_column[i] = list_comm_copy[0]
            list_comm_copy = list_comm_copy[1:]
        else:
            commodity_neighbor_column[i] = []
        
    filtered['commodity_neighbors'] = commodity_neighbor_column
    name_file = "filtered_" + str(j+1) + "_with_comm/PN_neighbors_normalized.csv"
    filtered.to_csv(name_file)

# %%
list_comm = neighbors_for_comm(list_of_neighbors, commodity_id_list)
list_comm
# Out:
# [['3(diš)[]NU', 'udu[sheep]N'],
#  ['6(diš)[]NU', 'u[ewe]N'],
#  ['2(diš)[]NU', 'mašgal[goat]N'],
#  ['ud[sun]N', '1(u)[]NU', '5(diš@t)-kam[]NU'],
#  ['ki[place]N', 'du₁₁-ga-ta[NA]NA'],
#  ['1(u)[]NU', '1(diš)[]NU'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'mašgal[goat]N'],
#  ['1(diš)[]NU', 'uzud[goat]N'],
#  ['5(diš)[]NU', 'sila[lamb]N'],
#  ['1(u)[]NU', '2(diš)[]NU', 'sila[lamb]N', 'ga[milk]N'],
#  ['1(u)[]NU', '2(diš)[]NU', 'sila[lamb]N', 'ga[milk]N'],
#  ['{d}šul-gi-a-a-mu-ta[]PN', '5(diš)[]NU', 'maš[goat]N', 'ga[milk]N'],
#  ['{d}šul-gi-iri-mu[]PN',
#   'uš[die]V/i',
#   'ud[sun]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['ki[place]N', '{d}šul-gi-a-a-mu-ta[]PN'],
#  ['1(diš)[]NU', 'gud[ox]N', '2(u)[]NU', '5(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'gud[ox]N', '2(u)[]NU', '5(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'gud[ox]N', '2(u)[]NU', '5(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['8(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['{d}utu-ba-ni[]PN', '1(u)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['2(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['zimbir{ki}[]GN', '1(u)[]NU', '4(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['zimbir{ki}[]GN', '1(u)[]NU', '4(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['6(diš)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['o[NA]NA', 'o[NA]NA', 'o[NA]NA', '4(diš)[]NU', 'gud[ox]N'],
#  ['di-ku₅-i₃-li₂[]PN',
#   'o[NA]NA',
#   'o[NA]NA',
#   'o[NA]NA',
#   '4(u)[]NU',
#   '4(diš)[]NU',
#   'udu[sheep]N'],
#  ['di-ku₅-i₃-li₂[]PN',
#   'o[NA]NA',
#   'o[NA]NA',
#   'o[NA]NA',
#   '4(u)[]NU',
#   '4(diš)[]NU',
#   'udu[sheep]N'],
#  ['1(diš)[]NU',
#   'sila[lamb]N',
#   'dingir-ki-ma-at[]PN',
#   '1(diš)[]NU',
#   'sila[lamb]N',
#   'di-ku₅-i₃-li₂[]PN'],
#  ['1(diš)[]NU',
#   'sila[lamb]N',
#   'dingir-ki-ma-at[]PN',
#   '1(diš)[]NU',
#   'sila[lamb]N',
#   'di-ku₅-i₃-li₂[]PN'],
#  ['la-gi-ip[]PN', '1(diš)[]NU', 'sila[lamb]N', 'ṣe-lu-uš-{d}šul-gi[NA]NA'],
#  ['a₂-bi₂-lum[]PN',
#   '1(diš)[]NU',
#   'sila[lamb]N',
#   'bar[cvve]V/t',
#   'nubanda[overseer]N'],
#  ['dam-ku-um[]PN', '1(diš)[]NU', 'sila[lamb]N', 'la-gi-ip[]PN'],
#  ['šu-ma-ma[]PN', '1(diš)[]NU', 'maš[goat]N', 'a₂-bi₂-lum[]PN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'dam-ku-um[]PN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'šu-ma-ma[]PN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'puzur₄-eš₁₈-dar[NA]NA'],
#  ['o[NA]NA', 'o[NA]NA', 'o[NA]NA', '9(diš)[]NU', 'udu[sheep]N'],
#  ['šuniŋin[total]N',
#   '1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['šuniŋin[total]N',
#   '1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['šuniŋin[total]N', '3(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['šuniŋin[total]N',
#   '3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['šuniŋin[total]N',
#   '3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['šuniŋin[total]N',
#   '2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['šuniŋin[total]N',
#   '2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['šuniŋin[total]N', '2(u)[]NU', '2(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['šuniŋin[total]N', '2(u)[]NU', '2(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['šuniŋin[total]N', '1(u)[]NU', '6(diš)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['šuniŋin[total]N', '1(u)[]NU', '6(diš)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['šuniŋin[total]N', '9(diš)[]NU', 'sila[lamb]N'],
#  ['šuniŋin[total]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['2(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['o[NA]NA',
#   'o[NA]NA',
#   'o[NA]NA',
#   '2(diš)[]NU',
#   'gud[ox]N',
#   '2(diš)[]NU',
#   'udu[sheep]N'],
#  ['o[NA]NA',
#   'o[NA]NA',
#   'o[NA]NA',
#   '2(diš)[]NU',
#   'gud[ox]N',
#   '2(diš)[]NU',
#   'udu[sheep]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['o[NA]NA',
#   'o[NA]NA',
#   'o[NA]NA',
#   '2(diš)[]NU',
#   'gud[ox]N',
#   '2(diš)[]NU',
#   'udu[sheep]N'],
#  ['o[NA]NA',
#   'o[NA]NA',
#   'o[NA]NA',
#   '2(diš)[]NU',
#   'gud[ox]N',
#   '2(diš)[]NU',
#   'udu[sheep]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['o[NA]NA', 'o[NA]NA', 'o[NA]NA', '2(diš)[]NU', 'udu[sheep]N'],
#  ['1(u)[]NU', '8(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['1(u)[]NU', '8(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['1(u)[]NU', '5(diš)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['1(u)[]NU', '5(diš)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['5(diš)[]NU', 'sila[lamb]N'],
#  ['5(diš)[]NU', 'maš[goat]N'],
#  ['o[NA]NA', 'o[NA]NA', 'o[NA]NA', '4(u)[]NU', '3(diš)[]NU', 'udu[sheep]N'],
#  ['o[NA]NA', 'o[NA]NA', 'o[NA]NA', '4(u)[]NU', '3(diš)[]NU', 'udu[sheep]N'],
#  ['4(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['o[NA]NA', 'o[NA]NA', 'o[NA]NA', '4(diš)[]NU', 'udu[sheep]N'],
#  ['x[NA]NA', 'niga[fattened]V/i'],
#  ['ud[sun]N', 'x[NA]NA', '1(u)[]NU', '7(diš)-kam[]NU'],
#  ['ud[sun]N', 'x[NA]NA', '1(u)[]NU', '7(diš)-kam[]NU'],
#  ['iri-sa₁₂-rig₇{ki}[]GN', 'x[NA]NA', 'sila[lamb]N'],
#  ['1(u)[]NU', '8(diš)[]NU', 'udu[sheep]N'],
#  ['1(u)[]NU', '8(diš)[]NU', 'udu[sheep]N'],
#  ['1(u)[]NU', '4(diš)[]NU', 'mašgal[goat]N'],
#  ['1(u)[]NU', '4(diš)[]NU', 'mašgal[goat]N'],
#  ['1(gešʾu)[]NU', '3(u)[]NU', '4(diš)[]NU'],
#  ['1(gešʾu)[]NU', '3(u)[]NU', '4(diš)[]NU'],
#  ['ur-{d}nin-gal[]PN', 'ud[sun]N', '2(u)[]NU', '2(diš)-kam[]NU'],
#  ['ur-{d}nin-gal[]PN', 'ud[sun]N', '2(u)[]NU', '2(diš)-kam[]NU'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'na-ap-la-nu-um[]PN',
#   'MAR.TU[westerner]N'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'na-ap-la-nu-um[]PN',
#   'MAR.TU[westerner]N'],
#  ['3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'mašgal[goat]N',
#   'niga[fattened]V/i'],
#  ['3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'mašgal[goat]N',
#   'niga[fattened]V/i'],
#  ['bu-u₂-du[]PN', 'ud[sun]N', '2(u)[]NU', '3(diš)-kam[]NU'],
#  ['bu-u₂-du[]PN', 'ud[sun]N', '2(u)[]NU', '3(diš)-kam[]NU'],
#  ['1(diš)[]NU', 'maš[goat]N', 'niga[fattened]V/i', '{d}nanna[]DN'],
#  ['1(diš)[]NU', 'maš[goat]N', 'niga[fattened]V/i', '{d}nanna[]DN'],
#  ['ud[sun]N', '2(u)[]NU', '4(diš)-kam[]NU'],
#  ['ud[sun]N', '2(u)[]NU', '4(diš)-kam[]NU'],
#  ['x[NA]NA', 'sila[lamb]N', '{d}en-lil₂[]FN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'ga[milk]N'],
#  ['KA.izi[burning]N'],
#  ['4(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['2(diš)[]NU', 'ašgar[kid]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', 'ud[sun]N', '1(u)[]NU', '1(diš)-kam[]NU'],
#  ['ab-ba-sa₆-ga-ta[]PN', 'mu.DU[delivery]N', 'lugal[king]N'],
#  ['3(diš)[]NU', 'x[NA]NA'],
#  ['3(diš)[]NU', 'x[NA]NA'],
#  ['ab-ba-sa₆-ga-ta[]PN', '2(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['{d}šul-gi-a-a-mu[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}en-lil₂[]FN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}en-lil₂[]FN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}nin-lil₂[]FN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}nin-hur-sag[]FN'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N',
#   'dukug[locus]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N',
#   'dukug[locus]N'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}utu[]FN'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N',
#   '1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N',
#   '1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N',
#   '1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}šu-{d}suen[]TN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}suen[]DN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}šul-gi[]TN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}nin-sun₂[]FN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}lugal-banda₃[]DN'],
#  ['{d}en-ki[]PN',
#   '1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '{d}nin-im-ma[]DN'],
#  ['{d}nin-ti₂-ug₅-ga[]PN',
#   '1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '{d}lugal-gu₄-si-su[]PN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}en-ki[]PN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i', '{d}nin-ti₂-ug₅-ga[]PN'],
#  ['si-ma-num₂{ki}[]GN', '1(diš)[]NU', 'udu[sheep]N', 'x[NA]NA', 'x-sa[NA]NA'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '2(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '2(diš)[]NU', 'zal[pass]V/t'],
#  ['ad-da-kal-la[]PN',
#   '1(u)[]NU',
#   '6(diš)[]NU',
#   'gud[ox]N',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['ad-da-kal-la[]PN',
#   '1(u)[]NU',
#   '6(diš)[]NU',
#   'gud[ox]N',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['ad-da-kal-la[]PN',
#   '1(u)[]NU',
#   '6(diš)[]NU',
#   'gud[ox]N',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(diš)[]NU', 'durah[goat]N', 'nita[male]N'],
#  ['ud[sun]N', '1(u)[]NU', '3(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['{d}en-lil₂-la₂[]PN', '6(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['{d}en-lil₂-la₂[]PN', '6(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['itud[moon]N', 'ud[sun]N', '1(u)[]NU', '1(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '1(u)[]NU', '1(diš)[]NU', 'zal[pass]V/t'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'u[and]CNJ',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš@t)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'u[and]CNJ',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš@t)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i'],
#  ['1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i'],
#  ['2(diš)[]NU', 'udu[sheep]N'],
#  ['itud[moon]N',
#   'ud[sun]N',
#   '2(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)[]NU',
#   'zal[pass]V/t'],
#  ['itud[moon]N',
#   'ud[sun]N',
#   '2(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)[]NU',
#   'zal[pass]V/t'],
#  ['4(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', 'zal[pass]V/t'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '2(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '2(diš)[]NU', 'zal[pass]V/t'],
#  ['1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['1(diš)[]NU', 'u[ewe]N', 'sila[lamb]N', 'nua[~animal]N'],
#  ['4(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['4(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '7(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '7(diš)[]NU', 'zal[pass]V/t'],
#  ['šuniŋin[total]N',
#   '3(u)[]NU',
#   '6(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i'],
#  ['šuniŋin[total]N',
#   '3(u)[]NU',
#   '6(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i'],
#  ['šuniŋin[total]N', '1(diš)[]NU', '7(diš)[]NU', 'udu[sheep]N'],
#  ['šuniŋin[total]N', '1(diš)[]NU', '7(diš)[]NU', 'udu[sheep]N'],
#  ['šuniŋin[total]N', '1(diš)[]NU', 'u[ewe]N', 'sila[lamb]N', 'nua[~animal]N'],
#  ['4(geš₂)[]NU', '4(diš)[]NU'],
#  ['2(u)[]NU', '4(diš)[]NU', 'udu[sheep]N'],
#  ['2(u)[]NU', '4(diš)[]NU', 'udu[sheep]N'],
#  ['2(u)[]NU', '4(diš)[]NU', 'udu[sheep]N'],
#  ['dingir-{d}šara₂[]PN', '6(diš)[]NU', 'maš[goat]N'],
#  ['5(geš₂)[]NU', 'tug[textile]N', 'hi[mix]V/t'],
#  ['1(gešʾu)[]NU',
#   '4(geš₂)[]NU',
#   '3(u)[]NU',
#   '4(aš)[]NU',
#   'gun[load]N',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N'],
#  ['1(gešʾu)[]NU',
#   '4(geš₂)[]NU',
#   '3(u)[]NU',
#   '4(aš)[]NU',
#   'gun[load]N',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N'],
#  ['1(gešʾu)[]NU',
#   '4(geš₂)[]NU',
#   '3(u)[]NU',
#   '4(aš)[]NU',
#   'gun[load]N',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N'],
#  ['1(gešʾu)[]NU',
#   '4(geš₂)[]NU',
#   '3(u)[]NU',
#   '4(aš)[]NU',
#   'gun[load]N',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N'],
#  ['1(gešʾu)[]NU',
#   '4(geš₂)[]NU',
#   '3(u)[]NU',
#   '4(aš)[]NU',
#   'gun[load]N',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N'],
#  ['1(gešʾu)[]NU',
#   '4(geš₂)[]NU',
#   '3(u)[]NU',
#   '4(aš)[]NU',
#   'gun[load]N',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N'],
#  ['1(u)[]NU',
#   '6(aš)[]NU',
#   'gun[load]N',
#   '4(u)[]NU',
#   '6(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N',
#   'uzud[goat]N'],
#  ['1(u)[]NU',
#   '6(aš)[]NU',
#   'gun[load]N',
#   '4(u)[]NU',
#   '6(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N',
#   'uzud[goat]N'],
#  ['1(u)[]NU',
#   '6(aš)[]NU',
#   'gun[load]N',
#   '4(u)[]NU',
#   '6(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N',
#   'uzud[goat]N'],
#  ['1(u)[]NU',
#   '6(aš)[]NU',
#   'gun[load]N',
#   '4(u)[]NU',
#   '6(diš)[]NU',
#   'mana[unit]N',
#   'siki[hair]N',
#   'uzud[goat]N'],
#  ['7(aš)[]NU',
#   '1(barig)[]NU',
#   '9(diš)[]NU',
#   '1/3(diš)[]NU',
#   'sila[unit]N',
#   'inun[ghee]N',
#   'gur[unit]N',
#   'lugal[king]N'],
#  ['7(aš)[]NU',
#   '1(barig)[]NU',
#   '9(diš)[]NU',
#   '1/3(diš)[]NU',
#   'sila[unit]N',
#   'inun[ghee]N',
#   'gur[unit]N',
#   'lugal[king]N'],
#  ['7(aš)[]NU',
#   '1(barig)[]NU',
#   '9(diš)[]NU',
#   '1/3(diš)[]NU',
#   'sila[unit]N',
#   'inun[ghee]N',
#   'gur[unit]N',
#   'lugal[king]N'],
#  ['7(aš)[]NU',
#   '1(barig)[]NU',
#   '9(diš)[]NU',
#   '1/3(diš)[]NU',
#   'sila[unit]N',
#   'inun[ghee]N',
#   'gur[unit]N',
#   'lugal[king]N'],
#  ['na-ra-am-i₃-li₂-ta[]PN',
#   '1(u)[]NU',
#   '1(barig)[]NU',
#   '4(ban₂)[]NU',
#   '7(diš)[]NU',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   'gur[unit]N'],
#  ['na-ra-am-i₃-li₂-ta[]PN',
#   '1(u)[]NU',
#   '1(barig)[]NU',
#   '4(ban₂)[]NU',
#   '7(diš)[]NU',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   'gur[unit]N'],
#  ['na-ra-am-i₃-li₂-ta[]PN',
#   '1(u)[]NU',
#   '1(barig)[]NU',
#   '4(ban₂)[]NU',
#   '7(diš)[]NU',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   'gur[unit]N'],
#  ['na-ra-am-i₃-li₂-ta[]PN',
#   '1(u)[]NU',
#   '1(barig)[]NU',
#   '4(ban₂)[]NU',
#   '7(diš)[]NU',
#   'sila[unit]N',
#   'gaʾar[cheese]N',
#   'gur[unit]N'],
#  ['a-bi₂-e₂[]PN',
#   '1(u)[]NU',
#   '3(diš)[]NU',
#   'u[ewe]N',
#   '1(diš)[]NU',
#   'uzud[goat]N'],
#  ['a-bi₂-e₂[]PN',
#   '1(u)[]NU',
#   '3(diš)[]NU',
#   'u[ewe]N',
#   '1(diš)[]NU',
#   'uzud[goat]N'],
#  ['a-bi₂-e₂[]PN',
#   '1(u)[]NU',
#   '3(diš)[]NU',
#   'u[ewe]N',
#   '1(diš)[]NU',
#   'uzud[goat]N'],
#  ['3(u)[]NU', 'uzud[goat]N', 'ŋiri[foot]N', 'a-bi₂-e₂[]PN'],
#  ['i-ri-ib[]PN',
#   '2(u)[]NU',
#   '3(diš)[]NU',
#   'mašgal[goat]N',
#   'ŋiri[foot]N',
#   'a-za-ak-za-kum[NA]NA'],
#  ['i-ri-ib[]PN',
#   '2(u)[]NU',
#   '3(diš)[]NU',
#   'mašgal[goat]N',
#   'ŋiri[foot]N',
#   'a-za-ak-za-kum[NA]NA'],
#  ['4(u)[]NU', 'uzud[goat]N', 'ŋiri[foot]N', 'i-ri-ib[]PN'],
#  ['3(u)[]NU', 'mašgal[goat]N', 'ŋiri[foot]N', 'ib-ši-ka[NA]NA'],
#  ['e-la-ak-nu-id[]PN', 'ud[sun]N', '2(u)[]NU', '1(diš)-kam[]NU'],
#  ['itud[moon]N', 'šu-eš₅-ša[]MN'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'ŋiri[foot]N', 'e-la-ak-nu-id[]PN'],
#  ['2(u)[]NU', 'mašgal[goat]N', 'ŋiri[foot]N', 'ib-ši-ka[NA]NA'],
#  ['ba-na-ha[]PN', 'ud[sun]N', '2(u)[]NU', '2(diš)-kam[]NU'],
#  ['1(diš)[]NU', 'kir[lamb]N', '1(u)[]NU', '6(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', '1(u)[]NU', '6(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', '1(u)[]NU', '6(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', '1(u)[]NU', '6(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', '1(u)[]NU', '6(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', '1(u)[]NU', '6(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', '1(u)[]NU', '6(diš)[]NU', 'udu[sheep]N'],
#  ['2(u)[]NU', '2(diš)[]NU', 'udu[sheep]N', 'ŋiri[foot]N', 'e-la-ak-nu-id[]PN'],
#  ['2(u)[]NU', '2(diš)[]NU', 'udu[sheep]N', 'ŋiri[foot]N', 'e-la-ak-nu-id[]PN'],
#  ['ba-na-ha[]PN', 'itud[moon]N', 'ezem-mah[]MN'],
#  ['a-bi₂-e₂[]PN',
#   '5(u)[]NU',
#   '7(diš)[]NU',
#   'udu[sheep]N',
#   '8(diš)[]NU',
#   'mašgal[goat]N'],
#  ['a-bi₂-e₂[]PN',
#   '5(u)[]NU',
#   '7(diš)[]NU',
#   'udu[sheep]N',
#   '8(diš)[]NU',
#   'mašgal[goat]N'],
#  ['a-bi₂-e₂[]PN',
#   '5(u)[]NU',
#   '7(diš)[]NU',
#   'udu[sheep]N',
#   '8(diš)[]NU',
#   'mašgal[goat]N'],
#  ['2(u)[]NU', '3(diš)[]NU', 'mašgal[goat]N', 'ŋiri[foot]N', 'a-bi₂-e₂[]PN'],
#  ['2(u)[]NU', '3(diš)[]NU', 'mašgal[goat]N', 'ŋiri[foot]N', 'a-bi₂-e₂[]PN'],
#  ['1(diš)[]NU', 'mašgal[goat]N', 'ŋiri[foot]N', 'a-za-ak-za-kum[NA]NA'],
#  ['6(diš)[]NU', 'mašgal[goat]N', 'ŋiri[foot]N', 'ib-ši-ka[NA]NA'],
#  ['ud[sun]N', '1(u)[]NU', '7(diš)-kam[]NU'],
#  ['ab-ba-sa₆-ga-ta[]PN', 'itud[moon]N', 'ezem-an-na[]MN'],
#  ['6(geš₂)[]NU', '8(diš)[]NU'],
#  ['2(diš)[]NU',
#   'ab[cow]N',
#   '1(diš)[]NU',
#   'ab[cow]N',
#   'mu[name]N',
#   '1(diš)[]NU'],
#  ['2(diš)[]NU',
#   'ab[cow]N',
#   '1(diš)[]NU',
#   'ab[cow]N',
#   'mu[name]N',
#   '1(diš)[]NU'],
#  ['2(diš)[]NU',
#   'ab[cow]N',
#   '1(diš)[]NU',
#   'ab[cow]N',
#   'mu[name]N',
#   '1(diš)[]NU'],
#  ['ab-ba-sa₆-ga-ta[]PN', '6(diš)[]NU', 'sila[lamb]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '6(diš)[]NU', 'sila[lamb]N'],
#  ['in-ta-e₃-a[]PN', 'ud[sun]N', '1(u)[]NU', '2(diš)-kam[]NU'],
#  ['in-ta-e₃-a[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(u)[]NU', 'lal[small]V/i', '1(diš)[]NU', '3(diš)[]NU'],
#  ['1(u)[]NU', 'lal[small]V/i', '1(diš)[]NU', '3(diš)[]NU'],
#  ['nibru{ki}-še₃[]GN',
#   '7(geš₂)[]NU',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'ŋuruš[male]N',
#   'ud[sun]N',
#   '1(diš)-še₃[]NU'],
#  ['nibru{ki}-še₃[]GN',
#   '7(geš₂)[]NU',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'ŋuruš[male]N',
#   'ud[sun]N',
#   '1(diš)-še₃[]NU'],
#  ['nibru{ki}-še₃[]GN',
#   '7(geš₂)[]NU',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'ŋuruš[male]N',
#   'ud[sun]N',
#   '1(diš)-še₃[]NU'],
#  ['nibru{ki}-še₃[]GN',
#   '7(geš₂)[]NU',
#   '5(u)[]NU',
#   '4(diš)[]NU',
#   'ŋuruš[male]N',
#   'ud[sun]N',
#   '1(diš)-še₃[]NU'],
#  ['uri₅{ki}-ta[]GN'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'x[NA]NA',
#   'x[NA]NA',
#   'x[NA]NA',
#   'x[NA]NA',
#   'ensik[ruler]N',
#   'x[NA]NA'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'ur-{d}amar-{d}suen[]PN'],
#  ['ur-{d}ištaran[]PN', '1(diš)[]NU', 'sila[lamb]N', 'lu₂-x-x-x[NA]NA'],
#  ['2(diš)[]NU', 'amar[young]N', 'az[bear]N'],
#  ['1(diš)[]NU', 'maš[goat]N', 'x-x-x[NA]NA'],
#  ['5(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['5(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['1(diš)[]NU', 'maš[goat]N', 'x-x-x[NA]NA'],
#  ['1(u)[]NU', '2(diš)[]NU'],
#  ['1(diš)[]NU', 'mašgal[goat]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'mašgal[goat]N', 'niga[fattened]V/i'],
#  ['zu-ba-ga-ta[]PN', 'ud[sun]N', '2(u)[]NU', '7(diš)-kam[]NU'],
#  ['{d}šul-gi-iri-mu[]PN', 'ki[place]N', 'zu-ba-ga-ta[]PN'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['itud[moon]N', 'maš-da₃-gu₇[]MN'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['{d}šul-gi-iri-mu[]PN', 'ki[place]N', 'zu-ba-ga-ta[]PN'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['4(diš)[]NU', 'gud[ox]N', 'u[grass]N'],
#  ['ki[place]N', 'in-ta-e₃-a-ta[]PN', 'zig[rise]V/i'],
#  ['4(diš)[]NU', 'gud[ox]N'],
#  ['2(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   '1(diš)[]NU',
#   'gudabak[bull]N',
#   'amar[young]N',
#   'ga[milk]N'],
#  ['šu-ma-ma[]PN', 'ud[sun]N', '2(u)[]NU', '4(diš)-kam[]NU'],
#  ['šu-ma-ma[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['uri₅{ki}-ma[]GN', '3(geš₂)[]NU', '1(u)[]NU', 'udu[sheep]N'],
#  ['uri₅{ki}-ma[]GN', '3(geš₂)[]NU', '1(u)[]NU', 'udu[sheep]N'],
#  ['uri₅{ki}-ma[]GN', '3(geš₂)[]NU', '1(u)[]NU', 'udu[sheep]N'],
#  ['sa₃-si₂[]PN', '2(geš₂)[]NU', '1(diš)[]NU', 'maš[goat]N'],
#  ['sa₃-si₂[]PN', '2(geš₂)[]NU', '1(diš)[]NU', 'maš[goat]N'],
#  ['5(geš₂)[]NU', '1(u)[]NU', '1(diš)[]NU'],
#  ['5(geš₂)[]NU', '1(u)[]NU', '1(diš)[]NU'],
#  ['na-lu₅-ta[]PN', '3(diš)[]NU', 'udu[sheep]N'],
#  ['na-lu₅-ta[]PN', '3(diš)[]NU', 'udu[sheep]N'],
#  ['ur-nigar{gar}[]PN', 'uš[die]V/i', 'ud[sun]N', '2(u)[]NU', '6(diš)-kam[]NU'],
#  ['ur-nigar{gar}[]PN', 'ki[place]N', 'na-lu₅-ta[]PN'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['2(diš)[]NU', 'sila[lamb]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '2(diš)[]NU', 'maš[goat]N'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['2(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'gukkal[sheep]N'],
#  ['1(diš)[]NU', 'kir[lamb]N'],
#  ['a-hu-we-er-ta[]PN', 'uš[die]V/i', 'ud[sun]N', '1(u)[]NU', '3(diš)-kam[]NU'],
#  ['ki[place]N', 'a-hu-we-er-ta[]PN'],
#  ['5(diš)[]NU', 'udu[sheep]N'],
#  ['5(u)[]NU', '1(diš)[]NU', 'udu[sheep]N'],
#  ['5(u)[]NU', '1(diš)[]NU', 'udu[sheep]N'],
#  ['1(geš₂)[]NU', '3(u)[]NU', '7(diš)[]NU', 'mašgal[goat]N'],
#  ['1(geš₂)[]NU', '3(u)[]NU', '7(diš)[]NU', 'mašgal[goat]N'],
#  ['1(geš₂)[]NU', '3(u)[]NU', '7(diš)[]NU', 'mašgal[goat]N'],
#  ['ud[sun]N', '2(u)[]NU', '1(diš)-kam[]NU'],
#  ['2(geš₂)[]NU', '1(u)[]NU', '8(diš)[]NU'],
#  ['2(geš₂)[]NU', '1(u)[]NU', '8(diš)[]NU'],
#  ['2(geš₂)[]NU', '1(u)[]NU', '8(diš)[]NU'],
#  ['šag[heart]N'],
#  ['5(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   '1(geš₂)[]NU',
#   '3(u)[]NU',
#   '7(diš)[]NU',
#   'mašgal[goat]N'],
#  ['5(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   '1(geš₂)[]NU',
#   '3(u)[]NU',
#   '7(diš)[]NU',
#   'mašgal[goat]N'],
#  ['5(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   '1(geš₂)[]NU',
#   '3(u)[]NU',
#   '7(diš)[]NU',
#   'mašgal[goat]N'],
#  ['5(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   '1(geš₂)[]NU',
#   '3(u)[]NU',
#   '7(diš)[]NU',
#   'mašgal[goat]N'],
#  ['5(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   '1(geš₂)[]NU',
#   '3(u)[]NU',
#   '7(diš)[]NU',
#   'mašgal[goat]N'],
#  ['6(diš)[]NU', 'udu[sheep]N'],
#  ['8(diš)[]NU', 'udu[sheep]N', '2(diš)[]NU', 'sila[lamb]N'],
#  ['8(diš)[]NU', 'udu[sheep]N', '2(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'uš[die]V/i'],
#  ['ud[sun]N', '2(u)[]NU', '8(diš)-kam[]NU'],
#  ['ki[place]N', 'du₁₁-ga-ta[NA]NA'],
#  ['ur-{d}ha-ia₃[]PN', 'ur-{d}šul-pa-e₃[]PN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'niga[fattened]V/i'],
#  ['nibru{ki}[]GN', '1(diš)[]NU', 'sila[lamb]N', 'i-ṣur-i₃-li₂[NA]NA'],
#  ['nibru{ki}[]GN',
#   '1(diš)[]NU',
#   'sila[lamb]N',
#   'i₃-li₂-mah-ri₂[]PN',
#   'mašgaʾen[status]N'],
#  ['ma-ri₂{ki}[]GN',
#   '1(diš)[]NU',
#   'sila[lamb]N',
#   'ensik[ruler]N',
#   'nibru{ki}[]GN'],
#  ['1(diš)[]NU',
#   'sila[lamb]N',
#   'dingir-a-hi[]PN',
#   'lu[person]N',
#   'ma-ri₂{ki}[]GN'],
#  ['ud[sun]N', '2(u)[]NU', '8(diš@t)-kam[]NU'],
#  ['{d}šul-gi-a-a-mu[]PN',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'un-da[NA]NA',
#   'šabra[administrator]N',
#   '{d}suen[]DN'],
#  ['{d}šul-gi-a-a-mu[]PN',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'un-da[NA]NA',
#   'šabra[administrator]N',
#   '{d}suen[]DN'],
#  ['2(u)[]NU', 'udu[sheep]N', 'hu-un-{d}šul-gi[]PN', 'nubanda[overseer]N'],
#  ['1(u)[]NU', 'udu[sheep]N', '{d}šul-gi-a-a-mu[]PN'],
#  ['5(diš)[]NU', 'udu[sheep]N', 'ur-{d}šul-gi-ra[]PN', 'x[NA]NA'],
#  ['4(diš)[]NU', 'udu[sheep]N', 'KU-x-du[NA]NA'],
#  ['tum-ma-al[]GN', '3(diš)[]NU', 'udu[sheep]N', 'a-hu-x[NA]NA'],
#  ['1(geš₂)[]NU', '4(u)[]NU', '2(diš)[]NU'],
#  ['1(geš₂)[]NU', '4(u)[]NU', '2(diš)[]NU'],
#  ['šag[heart]N', 'tum-ma-al[]GN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'lum-ma[]PN', 'šabra[administrator]N'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'ur-mes[]PN', 'ensik[ruler]N'],
#  ['ša₃-ga-na-kum[]PN', '3(diš)[]NU', 'šeŋbar[animal]N', 'nita[male]N'],
#  ['i₃-li₂-dan[]PN', '1(diš)[]NU', 'sila[lamb]N'],
#  ['ha-ab-ru-ša[]PN', '1(diš)[]NU', 'sila[lamb]N', 'i₃-li₂-dan[]PN'],
#  ['a-hu-a[]PN', '1(diš)[]NU', 'sila[lamb]N', 'ama-zi-mu[]PN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'ha-ab-ru-ša[]PN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'a-hu-a[]PN'],
#  ['5(diš)[]NU',
#   'udu[sheep]N',
#   'aslum[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'mašgal[goat]N',
#   'niga[fattened]V/i'],
#  ['5(diš)[]NU',
#   'udu[sheep]N',
#   'aslum[sheep]N',
#   'niga[fattened]V/i',
#   '1(diš)[]NU',
#   'mašgal[goat]N',
#   'niga[fattened]V/i'],
#  ['2(diš)[]NU', 'sila[lamb]N'],
#  ['i-ku-nu-um[]PN', '1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['1(u)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'sila[lamb]N'],
#  ['1(u)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'sila[lamb]N'],
#  ['mu.DU[delivery]N'],
#  ['3(u)[]NU', 'lal[small]V/i', '1(diš@t)[]NU'],
#  ['5(diš)[]NU', 'mašgal[goat]N', 'šimaški[~sheep]N'],
#  ['5(diš)[]NU', 'mašgal[goat]N', 'šimaški[~sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(diš)[]NU', 'sila[lamb]N'],
#  ['en-dingir-mu[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['5(diš)[]NU', 'udu[sheep]N'],
#  ['5(diš)[]NU', 'udu[sheep]N'],
#  ['2(diš)[]NU', 'udu[sheep]N', 'ŋi[night]N', 'šimaški[~sheep]N'],
#  ['2(diš)[]NU', 'u[ewe]N', 'šimaški[~sheep]N'],
#  ['1(diš)[]NU', 'u[ewe]N', 'ŋi[night]N', 'šimaški[~sheep]N'],
#  ['5(diš)[]NU', 'mašgal[goat]N'],
#  ['2(u)[]NU', 'uzud[goat]N', 'šimaški[~sheep]N'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['3(geš₂)[]NU', '3(u)[]NU', '2(diš)[]NU', 'udu[sheep]N'],
#  ['3(geš₂)[]NU', '3(u)[]NU', '2(diš)[]NU', 'udu[sheep]N'],
#  ['3(geš₂)[]NU', '3(u)[]NU', '2(diš)[]NU', 'udu[sheep]N'],
#  ['3(diš)[]NU', 'sila[lamb]N', 'ga[milk]N'],
#  ['5(diš)[]NU', 'ašgar[kid]N', 'ga[milk]N'],
#  ['ud[sun]N', '2(u)[]NU', '6(diš)-kam[]NU'],
#  ['{d}šul-gi-a-a-mu[]PN', 'dab[seize]V/t'],
#  ['bisaŋdubak[archivist]N'],
#  ['mu[name]N',
#   'ara[times]N',
#   '2(diš)-kam-aš[]NU',
#   'si-mu-ru-um{ki}[]GN',
#   'hulu[bad]V/i'],
#  ['mu[name]N', '1(u)[]NU', '3(diš)-kam[]NU'],
#  ['4(diš)[]NU', 'u[ewe]N', 'šimaški[~sheep]N'],
#  ['4(diš)[]NU', 'u[ewe]N', 'šimaški[~sheep]N'],
#  ['7(diš)[]NU', 'uzud[goat]N', 'šimaški[~sheep]N'],
#  ['itud[moon]N', 'ud[sun]N', '4(diš)[]NU', 'zal[pass]V/t'],
#  ['1(u)[]NU', '1(diš)[]NU'],
#  ['3(u)[]NU', 'udu[sheep]N', 'aslum[sheep]N', 'niga[fattened]V/i'],
#  ['3(u)[]NU', 'udu[sheep]N', 'aslum[sheep]N', 'niga[fattened]V/i'],
#  ['6(diš)[]NU', 'gud[ox]N', 'li-si-in[NA]NA', 'ragaba[rider]N'],
#  ['ud[sun]N', '2(u)[]NU', '4(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN', 'zig[rise]V/i'],
#  ['3(u)[]NU', '6(diš)[]NU'],
#  ['8(diš)[]NU', 'udu[sheep]N'],
#  ['8(diš)[]NU', 'udu[sheep]N'],
#  ['1(u)[]NU', '2(diš)[]NU', 'u[ewe]N'],
#  ['1(u)[]NU', '2(diš)[]NU', 'u[ewe]N'],
#  ['ud[sun]N', '1(u)[]NU', 'lal[small]V/i', '1(diš)-kam[]NU'],
#  ['ur-ku₃-nun-na[]PN', 'ziga[expenditure]N'],
#  ['a-bi₂-si₂-im-ti[]PN',
#   '5(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'emuhaldim[kitchen]N'],
#  ['ur-{d}nanna-ta[]PN',
#   'itud[moon]N',
#   'ud[sun]N',
#   '6(diš)[]NU',
#   'zal[pass]V/t'],
#  ['1(geš₂)[]NU', '1(u)[]NU', 'udu[sheep]N'],
#  ['1(geš₂)[]NU', '1(u)[]NU', 'udu[sheep]N'],
#  ['na-ra-am-i₃-li₂-ta[]PN', '1(u)[]NU', 'mašgal[goat]N'],
#  ['4(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['lu₂-ur₄-ša₃-ga-ta[]PN', 'ud[sun]N', '2(u)[]NU', '7(diš)-kam[]NU'],
#  ['ki[place]N', 'lu₂-ur₄-ša₃-ga-ta[]PN'],
#  ['4(diš)[]NU', 'udu[sheep]N'],
#  ['sagi-bi[]PN', '4(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['u₂-ta₂-mi-šar-ra-am[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['i-mi-id-dingir[]PN', 'zah[disappear]V/i', 'šu-i₃-li₂[]PN'],
#  ['1(aš@c)[]NU', 'iku[unit]N', 'nu-ur₂-i₃-li₂[]PN'],
#  ['edin-ša₃-ga-na[]PN', '1(aš)[]NU', 'i-mi-id-dingir[]PN'],
#  ['1(aš@c)[]NU', 'iku[unit]N', 'edin-ša₃-ga-na[]PN'],
#  ['1(aš@c)[]NU', 'iku[unit]N', 'du₁₀-i₃-li₂[]PN'],
#  ['1(diš)[]NU', 'u[and]CNJ', 'a-bu-na[NA]NA'],
#  ['a₂-li₂-id[]PN',
#   '1(diš)[]NU',
#   'u[and]CNJ',
#   'dumu[child]N',
#   'nita[male]N',
#   'gaba[chest]N'],
#  ['lugal-ezem[]PN', '1(aš@c)[]NU', 'iku[unit]N', 'a₂-li₂-id[]PN'],
#  ['1(aš@c)[]NU', 'iku[unit]N', 'ur-pu₂-mun-na[]PN'],
#  ['1(aš@c)[]NU', 'iku[unit]N', 'lugal-ezem[]PN'],
#  ['1(diš)[]NU', 'libir[old]V/i', 'a-bu-um-dingir[]PN', 'dumu[child]N'],
#  ['šuniŋin[total]N', '6(aš@c)[]NU', 'iku[unit]N', 'ŋuruš[male]N'],
#  ['šuniŋin[total]N', '1(aš)[]NU', 'ŋuruš[male]N'],
#  ['šuniŋin[total]N', 'zah[disappear]V/i', '1(aš)[]NU', 'ŋuruš[male]N'],
#  ['šuniŋin[total]N', '2(diš)[]NU', 'libir[old]V/i', 'dumunita[son]N'],
#  ['ur-{d}ba-ba₆-ta[]PN',
#   'šuniŋin[total]N',
#   '1(diš)[]NU',
#   'libir[old]V/i',
#   'dumunita[son]N',
#   'gaba[chest]N'],
#  ['o[NA]NA', 'o[NA]NA', 'o[NA]NA', '1(geš₂)[]NU', '1(u)[]NU', '1(diš)[]NU'],
#  ['o[NA]NA', 'o[NA]NA', 'o[NA]NA', '1(geš₂)[]NU', '1(u)[]NU', '1(diš)[]NU'],
#  ['ki[place]N', 'ur-{d}ba-ba₆-ta[]PN'],
#  ['1(diš)[]NU', 'mašgal[goat]N'],
#  ['zu-ba-ga-ta[]PN', '1(diš)[]NU', 'sila[lamb]N', 'ga[milk]N'],
#  ['{d}šul-gi-iri-mu[]PN', 'ki[place]N', 'zu-ba-ga-ta[]PN'],
#  ['2(diš)[]NU', 'udu[sheep]N'],
#  ['1(u)[]NU', 'lal[small]V/i', '1(diš)[]NU', 'tugur[dove]N'],
#  ['1(u)[]NU', 'lal[small]V/i', '1(diš)[]NU', 'tugur[dove]N'],
#  ['{d}šul-gi-si₂-im-tum[]PN',
#   'itud[moon]N',
#   'ud[sun]N',
#   '2(u)[]NU',
#   '3(diš)[]NU',
#   'zal[pass]V/t'],
#  ['{d}šul-gi-si₂-im-tum[]PN',
#   'itud[moon]N',
#   'ud[sun]N',
#   '2(u)[]NU',
#   '3(diš)[]NU',
#   'zal[pass]V/t'],
#  ['mu[name]N',
#   'us[follow]V/t',
#   'si-mu-ru-um{ki}[]GN',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['mu[name]N',
#   'us[follow]V/t',
#   'si-mu-ru-um{ki}[]GN',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['x[NA]NA', '3(u)[]NU', 'udu[sheep]N'],
#  ['na-ra-am-i₃-li₂-ta[]PN', 'x[NA]NA', '3(u)[]NU', 'maš[goat]N'],
#  ['3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'sag[rare]V/i',
#   'us[side]N'],
#  ['3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['3(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)-kam[]NU',
#   'us[side]N'],
#  ['6(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   '4(diš)[]NU',
#   'udu[sheep]N',
#   '2(diš)[]NU',
#   'sila[lamb]N'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   '4(diš)[]NU',
#   'udu[sheep]N',
#   '2(diš)[]NU',
#   'sila[lamb]N'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   'ud[sun]N',
#   '3(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(u)[]NU', '8(diš)[]NU'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   '1(u)[]NU',
#   '7(diš)[]NU',
#   'udu[sheep]N',
#   'šugid[~animal]N'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   '1(u)[]NU',
#   '7(diš)[]NU',
#   'udu[sheep]N',
#   'šugid[~animal]N'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   '1(u)[]NU',
#   '7(diš)[]NU',
#   'udu[sheep]N',
#   'šugid[~animal]N'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(u)[]NU', '7(diš)[]NU'],
#  ['1(diš)[]NU', 'gud[ox]N', 'u[grass]N'],
#  ['1(diš)[]NU', 'gud[ox]N', 'u[grass]N'],
#  ['1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'mašgal[goat]N', 'niga[fattened]V/i'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '4(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '4(diš)[]NU', 'zal[pass]V/t'],
#  ['3(diš)[]NU', 'kir[lamb]N'],
#  ['{d}šul-gi-iri-mu[]PN', 'ki[place]N', 'šu-ma-ma-ta[]PN'],
#  ['3(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU',
#   'gukkal[sheep]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'udu[sheep]N',
#   'aslum[sheep]N'],
#  ['1(diš)[]NU',
#   'gukkal[sheep]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'udu[sheep]N',
#   'aslum[sheep]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'aslum[sheep]N', 'ŋešdu[breeder]N'],
#  ['3(diš)[]NU', 'gukkal[sheep]N', 'ud[sun]N', '6(diš)-kam[]NU'],
#  ['3(diš)[]NU', 'gukkal[sheep]N', 'ud[sun]N', '6(diš)-kam[]NU'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'aslum[sheep]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'aslum[sheep]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'gukkal[sheep]N'],
#  ['ud[sun]N', '1(u)[]NU', '3(diš)-kam[]NU'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'ud[sun]N',
#   '2(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'ud[sun]N',
#   '2(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'ud[sun]N',
#   '2(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['2(diš)[]NU', 'gukkal[sheep]N', 'x[NA]NA'],
#  ['2(diš)[]NU', 'gukkal[sheep]N', 'x[NA]NA'],
#  ['1(u)[]NU', '2(diš)[]NU', 'udu[sheep]N'],
#  ['1(u)[]NU', '2(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'atua[lustration]N',
#   'lugal[king]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i', '{d}nin-ti₂-ug₅-ga[]PN'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'lulum[Lullubean]AJ',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'lulum[Lullubean]AJ',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU', 'ašgar[kid]N', 'niga[fattened]V/i', '{d}inanna[]TN'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i', 'x-an-na-lugal[NA]NA'],
#  ['1(u)[]NU', '2(diš)[]NU', 'udu[sheep]N'],
#  ['1(u)[]NU', '2(diš)[]NU', 'udu[sheep]N'],
#  ['mu[name]N', '{d}amar-{d}suen[]PN', 'lugal[king]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)-kam[]NU',
#   'us[side]N'],
#  ['eridu{ki}[]GN', '1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['ud[sun]N', '2(u)[]NU', '8(diš)-kam[]NU'],
#  ['ŋiri[foot]N', '{d}suen-a-bu-šu[]PN', 'šagia[cup-bearer]N'],
#  ['x[NA]NA'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['nibru{ki}[]GN', '2(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['3(diš)[]NU', 'gud[ox]N', 'gunu[speckled]V/i'],
#  ['3(diš)[]NU', 'gud[ox]N', 'gunu[speckled]V/i'],
#  ['4(diš)[]NU', 'gud[ox]N'],
#  ['4(diš)[]NU', 'ab[cow]N', 'gunu[speckled]V/i'],
#  ['2(diš)[]NU', 'ab[cow]N'],
#  ['{d}en-lil₂-la₂[]PN', 'šag[heart]N', 'unu{ki}[]GN'],
#  ['3(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', 'ga[milk]N'],
#  ['na-lu₅-ta[]PN', '1(diš)[]NU', 'maš[goat]N', 'ga[milk]N'],
#  ['ur-nigar{gar}[]PN', 'uš[die]V/i', 'ud[sun]N', '1(u)[]NU', '2(diš)-kam[]NU'],
#  ['ki[place]N', 'na-lu₅-ta[]PN'],
#  ['2(u)[]NU', '4(diš)[]NU', 'ab[cow]N', 'mah[mature]V/i'],
#  ['2(u)[]NU', '4(diš)[]NU', 'ab[cow]N', 'mah[mature]V/i'],
#  ['2(diš)[]NU', 'ab[cow]N', 'mah[mature]V/i', 'gunu[speckled]V/i'],
#  ['2(diš)[]NU', 'ab[cow]N', 'mu[name]N', '3(diš)[]NU', 'gunu[speckled]V/i'],
#  ['2(diš)[]NU', 'ab[cow]N', 'mu[name]N', '3(diš)[]NU', 'gunu[speckled]V/i'],
#  ['1(diš)[]NU', 'ab[cow]N', 'mu[name]N', '3(diš)[]NU'],
#  ['3(diš)[]NU', 'ab[cow]N', 'mu[name]N', '2(diš)[]NU'],
#  ['3(diš)[]NU', 'ab[cow]N', 'mu[name]N', '2(diš)[]NU'],
#  ['1(u)[]NU', '6(diš)[]NU', 'gud[ox]N', 'mu[name]N', '3(diš)[]NU'],
#  ['1(u)[]NU', '6(diš)[]NU', 'gud[ox]N', 'mu[name]N', '3(diš)[]NU'],
#  ['1(u)[]NU', '6(diš)[]NU', 'gud[ox]N', 'mu[name]N', '3(diš)[]NU'],
#  ['1(diš)[]NU', 'gud[ox]N', 'mu[name]N', '2(diš)[]NU'],
#  ['1(diš)[]NU', 'gud[ox]N', 'mu[name]N', '2(diš)[]NU'],
#  ['ab-ba-sa₆-ga-ta[]PN', '4(diš)[]NU', 'sila[lamb]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '4(diš)[]NU', 'sila[lamb]N'],
#  ['ud[sun]N', '1(u)[]NU', '4(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['5(u)[]NU', '3(diš)[]NU'],
#  ['be-li₂-a-ri₂-ik-še₃[]PN',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'gudeʾusa[drover]N'],
#  ['be-li₂-a-ri₂-ik-še₃[]PN',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'gudeʾusa[drover]N'],
#  ['mi-gir-{d}nin-lil₂-tum[]PN',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i'],
#  ['itud[moon]N', 'ud[sun]N', '1(u)[]NU', '6(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '1(u)[]NU', '6(diš)[]NU', 'zal[pass]V/t'],
#  ['2(diš)[]NU', 'udu[sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '2(diš)[]NU', 'udu[sheep]N'],
#  ['a-hu-we-er[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'a[water]N',
#   'udu[sheep]N',
#   'hursaŋ[mountain]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'a[water]N',
#   'udu[sheep]N',
#   'hursaŋ[mountain]N'],
#  ['1(diš)[]NU', 'uzud[goat]N', 'šimaški[~sheep]N'],
#  ['1(diš)[]NU', 'mašda[gazelle]N'],
#  ['a-hu-ni-ta[]PN', 'ud[sun]N', '1(u)[]NU', '7(diš)-kam[]NU'],
#  ['ki[place]N', 'a-hu-ni-ta[]PN'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'lu-lu-bu{ki}[]GN',
#   'a-ra[NA]NA',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'lu-lu-bu{ki}[]GN',
#   'a-ra[NA]NA',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'lu-lu-bu{ki}[]GN',
#   'a-ra[NA]NA',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'ašgar[kid]N'],
#  ['ki[place]N', 'a-hu-we-er-ta[]PN'],
#  ['3(diš)[]NU', 'udu[sheep]N'],
#  ['ur-{d}ba-ba₆[]PN', '4(diš)[]NU', 'kuš[skin]N', 'dusu[equid]N'],
#  ['3(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'gukkal[sheep]N'],
#  ['{d}šul-gi-iri-mu[]PN', 'ki[place]N', 'na-lu₅-ta[]PN'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'sag[rare]V/i',
#   'us[side]N'],
#  ['3(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i', '{d}inanna[]TN'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i', '{d}inanna[]TN'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'guza[chair]N',
#   'en[priest]N'],
#  ['1(diš)[]NU', 'mašgal[goat]N', 'niga[fattened]V/i'],
#  ['itud[moon]N', 'ud[sun]N', '1(u)[]NU', '3(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '1(u)[]NU', '3(diš)[]NU', 'zal[pass]V/t'],
#  ['8(diš)[]NU', 'udu[sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '3(diš)[]NU', 'x[NA]NA'],
#  ['{d}šul-gi-a-a-mu[]PN',
#   'ud[sun]N',
#   '1(u)[]NU',
#   '3(diš)[]NU',
#   'n[]NU',
#   'zal[pass]V/t'],
#  ['{d}šul-gi-a-a-mu[]PN',
#   'ud[sun]N',
#   '1(u)[]NU',
#   '3(diš)[]NU',
#   'n[]NU',
#   'zal[pass]V/t'],
#  ['{d}šul-gi-a-a-mu[]PN',
#   'ud[sun]N',
#   '1(u)[]NU',
#   '3(diš)[]NU',
#   'n[]NU',
#   'zal[pass]V/t'],
#  ['2(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['2(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['2(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i', 'sag[rare]V/i'],
#  ['na-ap-la-num₂[]PN',
#   '5(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'gudeʾusa[drover]N'],
#  ['3(diš)[]NU', 'udu[sheep]N', '2(diš)[]NU', 'maš[goat]N'],
#  ['3(diš)[]NU', 'udu[sheep]N', '2(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['ia₃-a-mu-tum[]PN', '1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['ia₃-a-mu-tum[]PN', '1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['{d}šul-gi-a-bi₂[]PN',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'na-ab-ša-nu-um[]PN',
#   'lu[person]N',
#   'kiŋgia[messenger]N',
#   'ia₃-a-mu-tum[]PN'],
#  ['hu-un-{d}šul-gi[]PN',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   '1(diš)[]NU',
#   'maš[goat]N'],
#  ['hu-un-{d}šul-gi[]PN',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   '1(diš)[]NU',
#   'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'hu-un-{d}šul-gi[]PN'],
#  ['mar-ha-ši{ki}[]GN', '1(diš)[]NU', 'gud[ox]N', 'niga[fattened]V/i'],
#  ['ki-ma-ni[]PN',
#   '5(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'gudeʾusa[drover]N'],
#  ['si-i₃-li₂[]PN', '1(diš)[]NU', 'maš[goat]N', 'ki-ma-ni[]PN'],
#  ['1(diš)[]NU', 'maš[goat]N', 'si-i₃-li₂[]PN'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['1(u)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['2(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['2(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['5(diš)[]NU', 'udu[sheep]N', '5(diš)[]NU', 'maš[goat]N'],
#  ['5(diš)[]NU', 'udu[sheep]N', '5(diš)[]NU', 'maš[goat]N'],
#  ['1(u)[]NU', '8(diš)[]NU', 'udu[sheep]N', '2(diš)[]NU', 'maš[goat]N'],
#  ['1(u)[]NU', '8(diš)[]NU', 'udu[sheep]N', '2(diš)[]NU', 'maš[goat]N'],
#  ['1(u)[]NU', '8(diš)[]NU', 'udu[sheep]N', '2(diš)[]NU', 'maš[goat]N'],
#  ['5(diš)[]NU', 'udu[sheep]N'],
#  ['2(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'sag[rare]V/i'],
#  ['2(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '4(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'sag[rare]V/i'],
#  ['lugal-inim-gi-na[]PN',
#   '1(u)[]NU',
#   '6(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'gudeʾusa[drover]N'],
#  ['lugal-inim-gi-na[]PN',
#   '1(u)[]NU',
#   '6(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'gudeʾusa[drover]N'],
#  ['2(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i', 'sag[rare]V/i'],
#  ['2(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['break'],
#  ['1(geš₂)[]NU', '5(u)[]NU', '3(diš)[]NU'],
#  ['1(geš₂)[]NU', '5(u)[]NU', '3(diš)[]NU'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N',
#   'sa[bundle]N',
#   'igi[eye]N',
#   'kugbabbar[silver]N'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N',
#   'sa[bundle]N',
#   'igi[eye]N',
#   'kugbabbar[silver]N'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N',
#   'sa[bundle]N',
#   'igi[eye]N',
#   'kugbabbar[silver]N'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N',
#   'sa[bundle]N',
#   'igi[eye]N',
#   'kugbabbar[silver]N'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N',
#   'sa[bundle]N',
#   'igi[eye]N',
#   'kugbabbar[silver]N'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N'],
#  ['1(u)[]NU',
#   '7(diš)[]NU',
#   'giŋ[unit]N',
#   '1(u)[]NU',
#   '5(diš)[]NU',
#   'še[barley]N'],
#  ['na-lu₅-ta[]PN',
#   '1(geš₂)[]NU',
#   '3(u)[]NU',
#   '2(diš)[]NU',
#   'udu[sheep]N',
#   'maš[goat]N',
#   'hi[mix]V/t'],
#  ['na-lu₅-ta[]PN',
#   '1(geš₂)[]NU',
#   '3(u)[]NU',
#   '2(diš)[]NU',
#   'udu[sheep]N',
#   'maš[goat]N',
#   'hi[mix]V/t'],
#  ['na-lu₅-ta[]PN',
#   '1(geš₂)[]NU',
#   '3(u)[]NU',
#   '2(diš)[]NU',
#   'udu[sheep]N',
#   'maš[goat]N',
#   'hi[mix]V/t'],
#  ['2(diš)[]NU', 'sila[lamb]N', 'ga[milk]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', 'ga[milk]N'],
#  ['1(diš)[]NU', 'maš[goat]N', 'ga[milk]N'],
#  ['1(diš)[]NU', 'ašgar[kid]N', 'ga[milk]N'],
#  ['{d}šul-gi-a-a-mu[]PN', 'dab[seize]V/t'],
#  ['itud[moon]N', 'ezem-me-ki-gal₂[]MN'],
#  ['6(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'uzud[goat]N'],
#  ['1(diš)[]NU', 'kir[lamb]N'],
#  ['na-lu₅-ta[]PN', 'ud[sun]N', '2(u)[]NU', '9(diš)-kam[]NU'],
#  ['ki[place]N', 'na-lu₅-ta[]PN'],
#  ['6(diš)[]NU', 'gud[ox]N', 'u[grass]N'],
#  ['itud[moon]N', 'maš-da₃-gu₇[]MN'],
#  ['2(geš₂)[]NU', '4(u)[]NU', '8(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['2(geš₂)[]NU', '4(u)[]NU', '8(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['2(geš₂)[]NU', '4(u)[]NU', '8(diš)[]NU', 'udu[sheep]N', 'u[grass]N'],
#  ['1(diš)[]NU', 'x[NA]NA', 'u[grass]N'],
#  ['2(u)[]NU', '2(diš)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['2(u)[]NU', '2(diš)[]NU', 'mašgal[goat]N', 'u[grass]N'],
#  ['1(u)[]NU', 'ašgar[kid]N', 'gaba[chest]N'],
#  ['ud[sun]N', '2(u)[]NU', '5(diš)-kam[]NU'],
#  ['itud[moon]N', 'ezem-{d}me-ki-gal₂[]MN'],
#  ['6(diš)[]NU',
#   'gud[ox]N',
#   '3(geš₂)[]NU',
#   '2(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['6(diš)[]NU',
#   'gud[ox]N',
#   '3(geš₂)[]NU',
#   '2(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['6(diš)[]NU',
#   'gud[ox]N',
#   '3(geš₂)[]NU',
#   '2(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['6(diš)[]NU',
#   'gud[ox]N',
#   '3(geš₂)[]NU',
#   '2(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N'],
#  ['ur-mes-ta[]PN', '1(diš)[]NU', 'sila[lamb]N'],
#  ['šu-er₃-ra[]PN', '1(diš)[]NU', 'maš[goat]N'],
#  ['x[NA]NA', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '1(diš)-kam[]NU'],
#  ['x[NA]NA', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '1(diš)-kam[]NU'],
#  ['3(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '3(diš)-kam[]NU'],
#  ['3(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '3(diš)-kam[]NU'],
#  ['3(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '3(diš)-kam[]NU'],
#  ['2(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '4(diš)-kam[]NU'],
#  ['2(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '4(diš)-kam[]NU'],
#  ['2(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '4(diš)-kam[]NU'],
#  ['5(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '7(diš)-kam[]NU'],
#  ['5(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '7(diš)-kam[]NU'],
#  ['5(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '7(diš)-kam[]NU'],
#  ['3(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '8(diš)-kam[]NU'],
#  ['3(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '8(diš)-kam[]NU'],
#  ['3(diš)[]NU', 'gud[ox]N', 'ud[sun]N', '2(u)[]NU', '8(diš)-kam[]NU'],
#  ['3(diš)[]NU',
#   'gud[ox]N',
#   'ud[sun]N',
#   '3(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['3(diš)[]NU',
#   'gud[ox]N',
#   'ud[sun]N',
#   '3(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['3(diš)[]NU',
#   'gud[ox]N',
#   'ud[sun]N',
#   '3(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['break'],
#  ['giri₃-lugal-iti-da[]PN',
#   '1(diš)[]NU',
#   'gud[ox]N',
#   'uš[die]V/i',
#   'ekišibak[storeroom]N'],
#  ['7(diš)[]NU', 'gud[ox]N', 'uš[die]V/i'],
#  ['7(diš)[]NU', 'gud[ox]N', 'gu₂-du₈-a{ki}-še₃[]GN'],
#  ['1(diš)[]NU', 'gud[ox]N', 'kišib[seal]N', 'šag[heart]N'],
#  ['si-du₃[]PN', '2(diš)[]NU', 'gud[ox]N', 'kišib[seal]N', 'enna[until]CNJ'],
#  ['qu₂-ra-ad-i₃-li₂[]PN',
#   '4(diš)[]NU',
#   'gud[ox]N',
#   'kišib[seal]N',
#   '{d}en-lil₂-la₂-i₃-sa₆[]PN'],
#  ['bi-ze₂-ze₂[]PN',
#   '3(geš₂)[]NU',
#   '5(diš)[]NU',
#   'gud[ox]N',
#   'kišib[seal]N',
#   'si-du₃[]PN'],
#  ['bi-ze₂-ze₂[]PN',
#   '3(geš₂)[]NU',
#   '5(diš)[]NU',
#   'gud[ox]N',
#   'kišib[seal]N',
#   'si-du₃[]PN'],
#  ['2(diš)[]NU', 'gud[ox]N', 'kišib[seal]N', 'qu₂-ra-ad-i₃-li₂[]PN'],
# ...
#   '8(diš)[]NU',
#   'udu[sheep]N',
#   '1(diš)[]NU',
#   'maš[goat]N'],
#  ['1(diš)[]NU', 'sila[lamb]N', '{d}utu-ba-ni[]PN'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'lu₂-inim-gi-na[]PN'],
#  ['{d}šul-gi-a-a-mu-ta[]PN',
#   '1(diš)[]NU',
#   'mašgal[goat]N',
#   'niga[fattened]V/i',
#   'sag[rare]V/i',
#   'us[side]N'],
#  ['{d}šul-gi-a-a-mu-ta[]PN',
#   '1(diš)[]NU',
#   'mašgal[goat]N',
#   'niga[fattened]V/i',
#   'sag[rare]V/i',
#   'us[side]N'],
#  ['{d}šul-gi-iri-mu[]PN', 'ki[place]N', '{d}šul-gi-a-a-mu-ta[]PN'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'mašda[gazelle]N'],
#  ['1(u)[]NU', 'udu[sheep]N'],
#  ['4(diš)[]NU', 'sila[lamb]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(diš)[]NU', 'maš[goat]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', 'ud[sun]N', '1(u)[]NU', '6(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(u)[]NU', '5(diš)[]NU'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'ŋi[night]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'ŋi[night]N'],
#  ['1(diš)[]NU', 'u[ewe]N'],
#  ['4(diš)[]NU', 'u[ewe]N', 'šimaški[~sheep]N'],
#  ['2(diš)[]NU', 'kir[lamb]N'],
#  ['1(diš)[]NU', 'maš[goat]N', 'babbar[white]V/i'],
#  ['1(diš)[]NU', 'sila[lamb]N', 'ga[milk]N'],
#  ['1(diš)[]NU', 'maš[goat]N', 'ga[milk]N', 'šimaški[~sheep]N'],
#  ['lu₂-dingir-ra-ta[]PN',
#   '1(diš)[]NU',
#   'ašgar[kid]N',
#   'ga[milk]N',
#   'šimaški[~sheep]N'],
#  ['ki[place]N', 'lu₂-dingir-ra-ta[]PN'],
#  ['6(diš)[]NU', 'gud[ox]N'],
#  ['1(diš)[]NU', 'ab[cow]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(u)[]NU', '5(diš)[]NU', 'udu[sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(u)[]NU', '5(diš)[]NU', 'udu[sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', 'ud[sun]N', '1(u)[]NU', '1(diš)-kam[]NU'],
#  ['{d}šul-gi-a-a-mu[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['ur-{d}ig-alim-ta[]PN', '3(diš)[]NU', 'ab[cow]N', 'mu[name]N', '3(diš)[]NU'],
#  ['nu-ur₂-{d}iškur[]PN', '2(diš)[]NU', 'ab[cow]N', 'mu[name]N', '2(diš)[]NU'],
#  ['nu-ur₂-{d}iškur[]PN', '2(diš)[]NU', 'ab[cow]N', 'mu[name]N', '2(diš)[]NU'],
#  ['ki[place]N', 'ur-{d}ig-alim-ta[]PN'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i'],
#  ['2(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i'],
#  ['2(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i', 'dukug[locus]N'],
#  ['1(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i',
#   'x[NA]NA',
#   'x[NA]NA',
#   'x-sag[NA]NA'],
#  ['1(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i',
#   'x[NA]NA',
#   'x[NA]NA',
#   'x[NA]NA'],
#  ['1(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i',
#   'x[NA]NA',
#   'x[NA]NA',
#   'x[NA]NA'],
#  ['1(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i',
#   'x[NA]NA',
#   'x[NA]NA',
#   'x[NA]NA'],
#  ['1(diš)[]NU',
#   'maš[goat]N',
#   'niga[fattened]V/i',
#   'x[NA]NA',
#   'x[NA]NA',
#   'x[NA]NA'],
#  ['1(diš)[]NU', 'x[NA]NA', 'UŠ[NA]NA'],
#  ['2(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i', '{d}nin-lil₂[]FN'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '2(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '2(u)[]NU', '2(diš)[]NU', 'zal[pass]V/t'],
#  ['šuniŋin[total]N',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'n[]NU',
#   'x[NA]NA',
#   'niga[fattened]V/i'],
#  ['šuniŋin[total]N',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'n[]NU',
#   'x[NA]NA',
#   'niga[fattened]V/i'],
#  ['šuniŋin[total]N',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'n[]NU',
#   'x[NA]NA',
#   'niga[fattened]V/i'],
#  ['šuniŋin[total]N',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'n[]NU',
#   'x[NA]NA',
#   'niga[fattened]V/i'],
#  ['šuniŋin[total]N',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'n[]NU',
#   'x[NA]NA',
#   'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'gukkal[sheep]N', 'ŋešdu[breeder]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '5(diš)[]NU', 'u[ewe]N', 'gukkal[sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', 'ud[sun]N', '1(u)[]NU', '1(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['3(diš)[]NU', 'gud[ox]N'],
#  ['3(diš)[]NU', 'gud[ox]N'],
#  ['1(diš)[]NU', 'ab[cow]N'],
#  ['ud[sun]N', '1(u)[]NU', '6(diš)-kam[]NU'],
#  ['{d}en-lil₂-la₂[]PN', 'ziga[expenditure]N'],
#  ['2(diš)[]NU',
#   'har[ring]N',
#   'kugbabbar[silver]N',
#   '5(diš)[]NU',
#   'giŋ[unit]N'],
#  ['2(diš)[]NU',
#   'har[ring]N',
#   'kugbabbar[silver]N',
#   '5(diš)[]NU',
#   'giŋ[unit]N'],
#  ['4(diš)[]NU',
#   'har[ring]N',
#   'kugbabbar[silver]N',
#   '9(diš)[]NU',
#   'giŋ[unit]N'],
#  ['4(diš)[]NU',
#   'har[ring]N',
#   'kugbabbar[silver]N',
#   '9(diš)[]NU',
#   'giŋ[unit]N'],
#  ['2(diš)[]NU',
#   'har[ring]N',
#   'kugbabbar[silver]N',
#   '8(diš)[]NU',
#   'giŋ[unit]N'],
#  ['2(diš)[]NU',
#   'har[ring]N',
#   'kugbabbar[silver]N',
#   '8(diš)[]NU',
#   'giŋ[unit]N'],
#  ['mu[name]N',
#   '{d}šu-{d}suen[]TN',
#   'lugal[king]N',
#   'uri₅{ki}-ma-ke₄[]GN',
#   'ma₂-gur₈-mah[NA]NA',
#   '{d}en-lil₂[]FN',
#   '{d}nin-lil₂-ra[]DN',
#   'dim[create]V/t'],
#  ['2(aš)[]NU', 'gun[load]N', '5(u)[]NU', 'mana[unit]N', 'siki[hair]N'],
#  ['2(aš)[]NU', 'gun[load]N', '5(u)[]NU', 'mana[unit]N', 'siki[hair]N'],
#  ['2(aš)[]NU', 'gun[load]N', '5(u)[]NU', 'mana[unit]N', 'siki[hair]N'],
#  ['1(diš)[]NU', 'lulim-nita₂[NA]NA'],
#  ['1(diš)[]NU', 'mašda[gazelle]N', 'nita[male]N'],
#  ['1(diš)[]NU', 'šeŋbar[animal]N', 'nita[male]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'mašda[gazelle]N', 'nita[male]N'],
#  ['itud[moon]N', 'ud[sun]N', '3(u)[]NU', 'zal[pass]V/t'],
#  ['1(diš)[]NU',
#   'sila[lamb]N',
#   'niga[fattened]V/i',
#   'ensik[ruler]N',
#   'umma{ki}[]GN'],
#  ['1(diš)[]NU',
#   'sila[lamb]N',
#   'niga[fattened]V/i',
#   'ensik[ruler]N',
#   'umma{ki}[]GN'],
#  ['ur-{d}hendur-sag[]PN',
#   '1(diš)[]NU',
#   'sila[lamb]N',
#   'en-um-i₃-li₂[]PN',
#   'saŋŋa[official]N',
#   '{d}utu[]FN'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'gud[ox]N',
#   '2(u)[]NU',
#   'udugal[sheep]N',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'gud[ox]N',
#   '2(u)[]NU',
#   'udugal[sheep]N',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'gud[ox]N',
#   '2(u)[]NU',
#   'udugal[sheep]N',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['1(diš)[]NU',
#   'gud[ox]N',
#   'niga[fattened]V/i',
#   '2(diš)[]NU',
#   'gud[ox]N',
#   '2(u)[]NU',
#   'udugal[sheep]N',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['kuara₂{ki}[]GN',
#   '2(diš)[]NU',
#   'udugal[sheep]N',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['kuara₂{ki}[]GN',
#   '2(diš)[]NU',
#   'udugal[sheep]N',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['1(diš)[]NU',
#   'mašda[gazelle]N',
#   '1(diš)[]NU',
#   'amar[young]N',
#   'mašda[gazelle]N'],
#  ['1(diš)[]NU',
#   'mašda[gazelle]N',
#   '1(diš)[]NU',
#   'amar[young]N',
#   'mašda[gazelle]N'],
#  ['2(diš)[]NU', 'gukkal[sheep]N', 'en-gi-mu-um[NA]NA', 'MAR.TU[westerner]N'],
#  ['2(diš)[]NU', 'sila[lamb]N', 'zabardab[official]N'],
#  ['2(diš)[]NU', 'sila[lamb]N', '{d}nin-lil₂-e-ba-zi-ge[]PN'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'u[and]CNJ',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['mu[name]N',
#   'si-mu-ru-um{ki}[]GN',
#   'u[and]CNJ',
#   'lu-lu-bu{ki}[]GN',
#   'ara[times]N',
#   '1(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam-aš[]NU',
#   'hulu[bad]V/i'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['1(diš)[]NU', 'maš[goat]N'],
#  ['1(diš)[]NU', 'sila[lamb]N'],
#  ['2(diš)[]NU', 'sila[lamb]N'],
#  ['mu.DU[delivery]N'],
#  ['da-da-a[]PN', '1(diš)[]NU', 'amar[young]N', 'mašda[gazelle]N'],
#  ['da-da-a[]PN', '1(diš)[]NU', 'amar[young]N', 'mašda[gazelle]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', 'ud[sun]N', '1(u)[]NU', '2(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(diš)[]NU', 'mašda[gazelle]N', 'emuhaldim[kitchen]N'],
#  ['1(diš)[]NU', 'mašda[gazelle]N', 'emuhaldim[kitchen]N'],
#  ['ud[sun]N', '2(u)[]NU', '8(diš)-kam[]NU'],
#  ['1(diš)[]NU', 'lulim[stag]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'lulim[stag]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'mašda[gazelle]N'],
#  ['1(diš)[]NU', 'šeŋbar[animal]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'mašda[gazelle]N', 'x[NA]NA'],
#  ['ud[sun]N', '2(u)[]NU', '9(diš)-kam[]NU'],
#  ['ki[place]N', 'x[NA]NA', 'x[NA]NA', 'x-ta[NA]NA'],
#  ['ur-{d}ha-ia₃[]PN', 'ur-{d}šul-pa-e₃[]PN'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   '1(u)[]NU',
#   '2(diš)[]NU',
#   'uzud[goat]N',
#   'šimaški[~sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN',
#   '1(u)[]NU',
#   '2(diš)[]NU',
#   'uzud[goat]N',
#   'šimaški[~sheep]N'],
#  ['tu-ra-am-{d}da-gan[]PN', 'ud[sun]N', '1(u)[]NU', '4(diš)-kam[]NU'],
#  ['tu-ra-am-{d}da-gan[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(u)[]NU', '2(diš)[]NU'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'sag[rare]V/i',
#   'us[side]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   'sag[rare]V/i',
#   'us[side]N'],
#  ['a-hu-we-er-ta[]PN', 'ud[sun]N', '2(u)[]NU', '6(diš)-kam[]NU'],
#  ['{d}šul-gi-iri-mu[]PN', 'ki[place]N', 'a-hu-we-er-ta[]PN'],
#  ['1(ban₂)[]NU', '6(diš)[]NU', 'sila[unit]N', 'ŋeštin[vine]N', 'ah[dry]V/i'],
#  ['1(ban₂)[]NU', '6(diš)[]NU', 'sila[unit]N', 'ŋeštin[vine]N', 'ah[dry]V/i'],
#  ['1(ban₂)[]NU', '6(diš)[]NU', 'sila[unit]N', 'ŋeštin[vine]N', 'ah[dry]V/i'],
#  ['1(u)[]NU',
#   '5(aš)[]NU',
#   '4(barig)[]NU',
#   '4(ban₂)[]NU',
#   '2(diš)[]NU',
#   '1/2(diš)[]NU',
#   'sila[unit]N',
#   'še[barley]N',
#   'gur[turn]V/i',
#   'lugal[king]N'],
#  ['1(u)[]NU',
#   '5(aš)[]NU',
#   '4(barig)[]NU',
#   '4(ban₂)[]NU',
#   '2(diš)[]NU',
#   '1/2(diš)[]NU',
#   'sila[unit]N',
#   'še[barley]N',
#   'gur[turn]V/i',
#   'lugal[king]N'],
#  ['1(u)[]NU',
#   '5(aš)[]NU',
#   '4(barig)[]NU',
#   '4(ban₂)[]NU',
#   '2(diš)[]NU',
#   '1/2(diš)[]NU',
#   'sila[unit]N',
#   'še[barley]N',
#   'gur[turn]V/i',
#   'lugal[king]N'],
#  ['1(u)[]NU',
#   '5(aš)[]NU',
#   '4(barig)[]NU',
#   '4(ban₂)[]NU',
#   '2(diš)[]NU',
#   '1/2(diš)[]NU',
#   'sila[unit]N',
#   'še[barley]N',
#   'gur[turn]V/i',
#   'lugal[king]N'],
#  ['1(u)[]NU',
#   '5(aš)[]NU',
#   '4(barig)[]NU',
#   '4(ban₂)[]NU',
#   '2(diš)[]NU',
#   '1/2(diš)[]NU',
#   'sila[unit]N',
#   'še[barley]N',
#   'gur[turn]V/i',
#   'lugal[king]N'],
#  ['1(u)[]NU',
#   '5(aš)[]NU',
#   '4(barig)[]NU',
#   '4(ban₂)[]NU',
#   '2(diš)[]NU',
#   '1/2(diš)[]NU',
#   'sila[unit]N',
#   'še[barley]N',
#   'gur[turn]V/i',
#   'lugal[king]N'],
#  ['1(diš)[]NU', 'kunga[equid]N', 'nita[male]N'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)[]NU',
#   'udu[sheep]N',
#   'aslum[sheep]N',
#   'niga[fattened]V/i'],
#  ['1(diš)[]NU',
#   'udu[sheep]N',
#   'niga[fattened]V/i',
#   '3(diš)[]NU',
#   'udu[sheep]N',
#   'aslum[sheep]N',
#   'niga[fattened]V/i'],
#  ['a₂-bi₂-si₂-im-ti[]PN',
#   '1(diš)[]NU',
#   'gukkal[sheep]N',
#   'ŋešdu[breeder]N',
#   'babbar[white]V/i',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['a₂-bi₂-si₂-im-ti[]PN',
#   '1(diš)[]NU',
#   'gukkal[sheep]N',
#   'ŋešdu[breeder]N',
#   'babbar[white]V/i',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['a₂-bi₂-si₂-im-ti[]PN',
#   '1(diš)[]NU',
#   'gukkal[sheep]N',
#   'ŋešdu[breeder]N',
#   'babbar[white]V/i',
#   '1(u)[]NU',
#   '1(diš)[]NU',
#   'sila[lamb]N'],
#  ['1(diš)[]NU',
#   'mašda[gazelle]N',
#   'nita[male]N',
#   '3(diš)[]NU',
#   'amar[young]N',
#   'mašda[gazelle]N',
#   'munus[woman]N'],
#  ['1(diš)[]NU',
#   'mašda[gazelle]N',
#   'nita[male]N',
#   '3(diš)[]NU',
#   'amar[young]N',
#   'mašda[gazelle]N',
#   'munus[woman]N'],
#  ['ud[sun]N', '2(u)[]NU', '6(diš)-kam[]NU'],
#  ['ki[place]N', 'lugal-amar-ku₃-ta[]PN'],
#  ['2(u)[]NU', '1(diš)[]NU'],
#  ['ur-šu-ga-lam-ma-ta[]PN', '2(diš)[]NU', 'gud[ox]N'],
#  ['ur-šu-ga-lam-ma-ta[]PN', '2(diš)[]NU', 'gud[ox]N'],
#  ['1(diš)[]NU', 'udu[sheep]N'],
#  ['1(diš)[]NU', 'u[ewe]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', 'ga[milk]N'],
#  ['ki[place]N', '{d}šul-gi-a-a-mu-ta[]PN'],
#  ['3(diš)[]NU', 'udu[sheep]N'],
#  ['an-nu-ni-tum-še₃[]PN', '1(geš₂)[]NU', '7(diš)[]NU', 'udu[sheep]N'],
#  ['an-nu-ni-tum-še₃[]PN', '1(geš₂)[]NU', '7(diš)[]NU', 'udu[sheep]N'],
#  ['{d}šara₂-kam-ta[]PN', '1(geš₂)[]NU', '3(u)[]NU', 'maš[goat]N'],
#  ['{d}šara₂-kam-ta[]PN', '1(geš₂)[]NU', '3(u)[]NU', 'maš[goat]N'],
#  ['2(geš₂)[]NU', '3(u)[]NU', '7(diš)[]NU'],
#  ['2(geš₂)[]NU', '3(u)[]NU', '7(diš)[]NU'],
#  ['4(diš)[]NU', 'kunga[equid]N', 'nita[male]N'],
#  ['4(diš)[]NU', 'kunga[equid]N', 'nita[male]N'],
#  ['4(diš)[]NU', 'kunga[equid]N', 'munus[woman]N'],
#  ['2(diš)[]NU', 'dusu[equid]N', 'nita[male]N'],
#  ['2(diš)[]NU', 'dusu[equid]N', 'munus[woman]N'],
#  ['1(diš)[]NU', 'dusu[equid]N', 'munus[woman]N', 'amar[young]N', 'gud[ox]N'],
#  ['ud[sun]N', '2(u)[]NU', '4(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['1(u)[]NU', '3(diš)[]NU'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['itud[moon]N', 'ud[sun]N', '1(u)[]NU', '5(diš)[]NU', 'zal[pass]V/t'],
#  ['itud[moon]N', 'ud[sun]N', '1(u)[]NU', '5(diš)[]NU', 'zal[pass]V/t'],
#  ['2(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['2(diš)[]NU', 'udu[sheep]N', 'niga[fattened]V/i'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(diš)[]NU', 'sila[lamb]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', 'ud[sun]N', '2(u)[]NU', '1(diš@t)-kam[]NU'],
#  ['na-lu₅[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['kurušda[fattener]N', 'dab[seize]V/t'],
#  ['{d}šara₂-kam[]PN'],
#  ['1(diš)[]NU', 'u[ewe]N', 'gukkal[sheep]N'],
#  ['en-dingir-mu[]PN',
#   'ud[sun]N',
#   '2(u)[]NU',
#   'lal[small]V/i',
#   '1(diš)-kam[]NU'],
#  ['{d}šul-gi-iri-mu[]PN', 'ki[place]N', 'en-dingir-mu[]PN'],
#  ['3(u)[]NU', '1(diš)[]NU', 'udu[sheep]N', 'maš[goat]N', 'hi[mix]V/t'],
#  ['3(u)[]NU', '1(diš)[]NU', 'udu[sheep]N', 'maš[goat]N', 'hi[mix]V/t'],
#  ['3(u)[]NU', '1(diš)[]NU', 'udu[sheep]N', 'maš[goat]N', 'hi[mix]V/t'],
#  ['ur-ku₃-nun-na[]PN'],
#  ['6(geš₂)[]NU', '4(u)[]NU', '1/3(diš)[]NU', 'x[NA]NA', 'gizi[reed]N'],
#  ['6(geš₂)[]NU', '4(u)[]NU', '1/3(diš)[]NU', 'x[NA]NA', 'gizi[reed]N'],
#  ['6(geš₂)[]NU', '4(u)[]NU', '1/3(diš)[]NU', 'x[NA]NA', 'gizi[reed]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(u)[]NU', 'sila[lamb]N'],
#  ['in-ta-e₃-a[]PN', 'ud[sun]N', '1(u)[]NU', '7(diš)-kam[]NU'],
#  ['in-ta-e₃-a[]PN', 'ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['4(diš)[]NU', 'sila[lamb]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['4(diš)[]NU', 'sila[lamb]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['4(diš)[]NU', 'sila[lamb]N', '1(diš)[]NU', 'maš[goat]N'],
#  ['ud[sun]N', '1(u)[]NU', '5(diš)-kam[]NU'],
#  ['2(diš)[]NU', 'sila[lamb]N', 'ud[sun]N', '1(u)[]NU', '4(diš)-kam[]NU'],
#  ['2(diš)[]NU', 'sila[lamb]N', 'ud[sun]N', '1(u)[]NU', '4(diš)-kam[]NU'],
#  ['2(diš)[]NU', 'sila[lamb]N', 'ud[sun]N', '1(u)[]NU', '4(diš)-kam[]NU'],
#  ['2(diš)[]NU', 'mašgal[goat]N', '1(diš)[]NU', 'sila[lamb]N'],
#  ['2(diš)[]NU', 'mašgal[goat]N', '1(diš)[]NU', 'sila[lamb]N'],
#  ['2(diš)[]NU', 'mašgal[goat]N', '1(diš)[]NU', 'sila[lamb]N'],
#  ['ud[sun]N', '1(u)[]NU', '6(diš)-kam[]NU'],
#  ['mu.DU[delivery]N', 'lugal[king]N'],
#  ['5(diš)[]NU', 'udu[sheep]N', '{d}en-lil₂[]FN'],
#  ['5(diš)[]NU', 'udu[sheep]N', '{d}nin-lil₂[]FN'],
#  ['ud[sun]N', '1(u)[]NU', '3(diš)-kam[]NU'],
#  ['6(diš)[]NU', 'udu[sheep]N', 'babbar[white]V/i', 'aʾabak[sea]N'],
#  ['6(diš)[]NU', 'udu[sheep]N', 'babbar[white]V/i', 'aʾabak[sea]N'],
#  ['5(diš)[]NU', 'udu[sheep]N', 'šugid[~animal]N'],
#  ['1(diš)[]NU', 'udu[sheep]N', 'uš[die]V/i'],
#  ['ud[sun]N', '1(u)[]NU', '4(diš)-kam[]NU'],
#  ['ki[place]N', 'du₁₁-ga-ta[NA]NA', 'zig[rise]V/i'],
#  ['ur-{d}ha-ia₃[]PN', 'ur-{d}šul-pa-e₃[]PN'],
#  ['4(diš)[]NU', 'udu[sheep]N'],
#  ['2(diš)[]NU', 'maš[goat]N'],
#  ['2(diš)[]NU', 'sila[lamb]N', 'ga[milk]N'],
#  ['1(diš)[]NU', 'kir[lamb]N', 'ga[milk]N'],
#  ['na-lu₅-ta[]PN', 'uš[die]V/i', 'ud[sun]N', '2(u)[]NU', '2(diš@t)-kam[]NU'],
#  ['ki[place]N', 'na-lu₅-ta[]PN'],
#  ['1(u)[]NU', 'lal[small]V/i', '1(diš)[]NU', 'udu[sheep]N'],
#  ['1(u)[]NU', 'lal[small]V/i', '1(diš)[]NU', 'udu[sheep]N'],
#  ['ab-ba-sa₆-ga-ta[]PN', '1(diš)[]NU', 'gud[ox]N'],
#  ['{d}en-lil₂-la₂[]PN', 'ud[sun]N', '2(u)[]NU', '8(diš)-kam[]NU'],
#  ['ki[place]N', 'ab-ba-sa₆-ga-ta[]PN'],
#  ['be-li₂-a-zu-ta[]PN', '7(diš)[]NU', 'ab[cow]N', 'mu[name]N', '2(diš)[]NU'],
#  ['be-li₂-a-zu-ta[]PN', '7(diš)[]NU', 'ab[cow]N', 'mu[name]N', '2(diš)[]NU'],
#  ['mu[name]N', 'bala[turn]V/t', 'ensik[ruler]N', 'zimbir{ki}[]GN'],
#  ...]

# %%
list_comm_copy = list_comm
commodity_neighbor_column = [0] * len(filtered_1)
for i in range(len(commodity_neighbor_column)):
    if i in commodity_id_list:
        commodity_neighbor_column[i] = list_comm_copy[0]
        list_comm_copy = list_comm_copy[1:]
    else:
        commodity_neighbor_column[i] = []

# %%
#we have running list of geogrpahic names
#for commodities, if we don't find the PN in the group- take the line as the neighbor
filtered_1['commodity_neighbors'] = commodity_neighbor_column
filtered_1
# Out:
#           id  unnamed                lemma  normalizaton  \
# 0          0        0           3(diš)[]NU           NaN
# 1          1        1          udu[sheep]N           NaN
# 2          2        2           6(diš)[]NU           NaN
# 3          3        3              u[ewe]N           NaN
# 4          4        4           2(diš)[]NU           NaN
# ...      ...      ...                  ...           ...
# 55276  55276   341667           1(diš)[]NU           NaN
# 55277  55277   341668          sila[lamb]N           NaN
# 55278  55278   341669  tu-ra-am-i₃-li₂[]PN  Turamili[]PN
# 55279  55279   341670           2(diš)[]NU           NaN
# 55280  55280   341671          ašgar[kid]N           NaN
#
#                          id_text  id_line       id_word label prof? role?  \
# 0      epsd2/admin/u3adm/P124149        3   P124149.3.1   o 1    No    No
# 1      epsd2/admin/u3adm/P124149        3   P124149.3.2   o 1    No    No
# 2      epsd2/admin/u3adm/P124149        4   P124149.4.1   o 2    No    No
# 3      epsd2/admin/u3adm/P124149        4   P124149.4.2   o 2    No    No
# 4      epsd2/admin/u3adm/P124149        5   P124149.5.1   o 3    No    No
# ...                          ...      ...           ...   ...   ...   ...
# 55276  epsd2/admin/u3adm/P126168       10  P126168.10.1   o 8    No    No
# 55277  epsd2/admin/u3adm/P126168       10  P126168.10.2   o 8    No    No
# 55278  epsd2/admin/u3adm/P126168       10  P126168.10.3   o 8    No    No
# 55279  epsd2/admin/u3adm/P126168       11  P126168.11.1   o 9    No    No
# 55280  epsd2/admin/u3adm/P126168       11  P126168.11.2   o 9    No    No
#
#       family? number? commodity? P_Number  \
# 0          No     Yes         No  P124149
# 1          No      No        Yes  P124149
# 2          No     Yes         No  P124149
# 3          No      No        Yes  P124149
# 4          No     Yes         No  P124149
# ...       ...     ...        ...      ...
# 55276      No     Yes         No  P126168
# 55277      No      No        Yes  P126168
# 55278      No      No         No  P126168
# 55279      No     Yes         No  P126168
# 55280      No      No        Yes  P126168
#
#                                                neighbors  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 55276                                                 []
# 55277                                                 []
# 55278  ['1(diš)[]NU', 'sila[lamb]N', 'tu-ra-am-i₃-li₂...
# 55279                                                 []
# 55280                                                 []
#
#                                   commodity_neighbors
# 0                                                  []
# 1                           [3(diš)[]NU, udu[sheep]N]
# 2                                                  []
# 3                               [6(diš)[]NU, u[ewe]N]
# 4                                                  []
# ...                                               ...
# 55276                                              []
# 55277  [1(diš)[]NU, sila[lamb]N, tu-ra-am-i₃-li₂[]PN]
# 55278                                              []
# 55279                                              []
# 55280                       [2(diš)[]NU, ašgar[kid]N]
#
# [55281 rows x 16 columns]

# %%
def n_neighbors_commodities(data, number_of_lines):
    big_list = [[] for i in range(len(data))]
    PN = data[data['lemma'].str.contains("PN")]
    pn_indices = PN.index.values.tolist()
    for i in pn_indices:
        #get rows of data to acquire the neighbors
        group_of_same_pnumber = data[data['P_Number'] == data.iloc[i]['P_Number']]
        group_of_n_lines_befaf = group_of_same_pnumber[((group_of_same_pnumber['id_line'] >= data.iloc[i]['id_line'] - number_of_lines) 
                                                        &(group_of_same_pnumber['id_line'] <= data.iloc[i]['id_line']))
                                                    | ((group_of_same_pnumber['id_line'] <= data.iloc[i]['id_line'] + number_of_lines)
                                                       & (group_of_same_pnumber['id_line'] >= data.iloc[i]['id_line']))]
        lemma_neighbors = group_of_n_lines_befaf['lemma'].values.tolist()
        if 'break' in lemma_neighbors:
            lemma_neighbors.remove('break')
        big_list[i] = lemma_neighbors
    return big_list

# %%
#Get neighbors from same text instead of 2 lines - get the PNs associated, GN
